# %% [markdown]
# # Burgers equation
#
# This code is modified from the code https://github.com/alexpapados/Physics-Informed-Deep-Learning-Solid-and-Fluid-Mechanics
#
# The paper about this work can ref https://www.researchgate.net/publication/359480166_Discontinuity_Computing_with_Physics-Informed_Neural_Network

# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
torch.manual_seed(124)
np.random.seed(124)
from smt.sampling_methods import LHS
#torch.set_default_tensor_type(torch.DoubleTensor)

# %%
def train(epoch):
    model.train()
    model.it = epoch
    def closure():
        optimizer.zero_grad()                                              
       # loss_pde = model.loss_pde(x_int)
       # loss_ic =  model.loss_ic(x_ic,u_ic)
       # loss_bd =  model.loss_bd(x_bdL,u_bdL) +\
       #            model.loss_bd(x_bdR,u_bdR)
        
        loss_pde = 0.0*model.loss_pde(x_int_ignore) + 0.01*model.loss_pde(x_int_covert) +\
                   100*model.loss_mm(x_int_memory,u_int_memory) + model.loss_pde(x_int_overt)
        
        loss_ic = 0.00*model.loss_ic(x_ic_ignore,u_ic_ignore) +\
                   0.01*model.loss_ic(x_ic_covert,u_ic_covert) +\
                    100*model.loss_ic(x_ic_memory,u_ic_memory) +\
                          model.loss_ic(x_ic_overt,u_ic_overt)
        
        #loss_bd = model.loss_bd(x_bdL,u_bdL_in,mark_bd) #+model.loss_bd(x_bdR,u_bdR_in,mark_bd) 
        loss_bd =  0.0*model.loss_bd(x_bdL_ignore,u_bdL_ignore) +\
                    0.01*model.loss_bd(x_bdL_covert,u_bdL_covert) +\
                     100*model.loss_bd(x_bdL_memory,u_bdL_memory) +\
                        model.loss_bd(x_bdL_overt,u_bdL_overt) +\
                   0.0*model.loss_bd(x_bdR_ignore,u_bdR_ignore) +\
                    0.01*model.loss_bd(x_bdR_covert,u_bdR_covert) +\
                     100*model.loss_bd(x_bdR_memory,u_bdR_memory) +\
                         model.loss_bd(x_bdR_overt,u_bdR_overt)
         
        loss = loss_pde + 10*loss_ic+10*loss_bd                                       

        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f}, loss_bd:{loss_bd:.8f}')
        #model.it = model.it + 1
        #outputfile = open('loss_history_burgers.dat','a+')
        #print(f'{model.it}  {loss_pde:.6f}  {loss_ic:.6f}  {loss:.6f}',file=outputfile)
        #outputfile.close() 
        loss.backward()
        return loss

    loss = optimizer.step(closure)
    loss_value = loss.item() if not isinstance(loss, float) else loss
    print(f'epoch {epoch}: loss {loss_value:.6f}')
    
def gradients(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

def to_numpy(input):
    if isinstance(input, torch.Tensor):
        return input.detach().cpu().numpy()
    elif isinstance(input, np.ndarray):
        return input
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                        'np.ndarray, but got {}'.format(type(input)))


class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.net = nn.Sequential()                                                  
        self.net.add_module('Linear_layer_1', nn.Linear(2, 120))                     
        self.net.add_module('Tanh_layer_1', nn.Tanh())                              

        for num in range(2, 5):                                                     
            self.net.add_module('Linear_layer_%d' % (num), nn.Linear(120, 120))       
            self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 
        self.net.add_module('Linear_layer_final', nn.Linear(120, 1))                 

    def forward(self, x):
        return self.net(x)

    def loss_pde(self, x):
        u = self.net(x)                                                
        du_g = gradients(u, x)[0]                                 
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        dux_g = gradients(u_x,x)[0]
        u_xx = dux_g[:,1:]
        f = ((u_t -0.001*u_xx+5*u**3-5*u)**2).mean() 
        if (len(x) == 0) :
            f = 0 
        #f = ((u_t +u_x)**2).mean() 
        return f
    
    def res_pde(self,x):
        y = self.net(x)
        Res = np.zeros((x.shape[0]))                                  
        u = y[:, 0:1]
        du_g = gradients(u, x)[0]                                  
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        Res = (u_t - u_x)**2 
        return Res 
    
    def lambda_pde(self,x):
        y = self.net(x)
        Res = np.zeros((x.shape[0]))                                  
        
        u = y[:, 0:1]
        du_g = gradients(u, x)[0]                                  
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        d = 0.1*(abs(u_x)-u_x) + 1
        return  d

    def loss_ic(self, x_ic, u_ic):
        y_ic = self.net(x_ic)                                                      
        u_ic_in = y_ic[:,0]
        loss_ics = ((u_ic_in - u_ic) ** 2).mean()
        if (len(x_ic) == 0):
            loss_ics = 0
        return loss_ics
    def loss_mm(self, x_ic, u_ic):
        y_ic = self.net(x_ic)                                                      
        u_ic_in = y_ic[:,0]
        loss_ics = ((u_ic_in - u_ic[:,0]) ** 2).mean()
        if (len(x_ic) == 0):
            loss_ics = 0
        return loss_ics
    def loss_bd(self, x,u_in):
        y = self.net(x)                                                      
        loss_bds = ((y[:,0] - u_in) ** 2).mean()
        if (len(x) == 0):
            loss_bds = 0
        return loss_bds
    def loss_bd1(self, x):
        y = self.net(x)                                                      
        u = y[:,0:1]
        du_g = gradients(y,x)[0]
        u_x = du_g[:,1:]
        
        loss_bds = ((u + 1.0) ** 2 + (u_x)**2).mean()
        
        return loss_bds
def BD_perid(X,T,N):
    xL = np.zeros((N,2)) 
    xR = np.zeros((N,2)) 
    
    for i in range(N):
        t = np.random.rand()*T
        xL[i,0] = t
        xL[i,1] = -X 
        xR[i,0] = t
        xR[i,1] = X
    return xL,xR
def BD(X):
    u = np.zeros((X.shape[0])) 
    
    for i in range(X.shape[0]):
        x = X[i,1]
        t = X[i,0]
        #u[i] =  np.sin(np.pi*(x-t))
        u[i] = -1
    return u
def IC1(x):
    N = x.shape[0]
    u = np.zeros((N))                                                
    for i in range(N):
        u[i] = np.sin(np.pi*(x[i,1]))
    return u
def IC(X):
    N = X.shape[0]
    u = np.zeros((X.shape[0]))                                                
    for i in range(N):
        x = X[i,1]
        u[i] =x**2*np.cos(np.pi*x)
        #u[i] = np.sin(np.pi*(x))
    return u

def Mark(x):
    N =x.shape[0]
    mark = np.zeros((N,2)) 
    
    for i in range(N):
        if (x[i,1] < 0):
            mark[i,1] = 1.0
        elif ( x[i,0]< 0.1 and x[i,1]< 0.3 ):
            mark[i,1] = 1.0
        elif ( x[i,0]< 0.1 and x[i,1] > 0.3 ):
            mark[i,1] = 0.1
        else:
            mark[i,1] =  0.01 
    return mark

# %%
def IgnoreAndAttention(X,xL,xR,tL,tR,num):
    A_covert    = []
    A_overt     = []
    A_memory    = []
    A_ignore    = []
    for i in range(num):
        x = X[i,1]
        t = X[i,0]
        if ((t - tL) < 0 ):
            A_memory.append(i)
        elif ((t - tL) >= 0 and (t- tR) <= 0 ):
            if ((x - xL) >= 0 and (x- xR) <= 0):
                A_overt.append(i)
            else:
                A_covert.append(i)
        else:
            A_ignore.append(i)
            
    x_ignore = np.zeros((len(A_ignore),2))
    x_covert = np.zeros((len(A_covert),2))
    x_overt = np.zeros((len(A_overt),2))
    x_memory = np.zeros((len(A_memory),2))
    for i in range( len(A_ignore)):
        x_ignore[i,:] = X[A_ignore[i],:]
    for i in range( len(A_memory)):
        x_memory[i,:] = X[A_memory[i],:]
        
    for i in range( len(A_covert)):
        x_covert[i,:] = X[A_covert[i],:]
    for i in range( len(A_overt)):
        x_overt[i,:] = X[A_overt[i],:]
    
    return x_memory, x_covert,x_overt,x_ignore

# %%
device = torch.device('cuda')                                      
num_x = 500                                                        
num_t = 1000                                                        
num_ic = 1000                                           
num_int = 8000                                            
Time = 1.0
L = 1

AT_xL = -1.0
AT_xR = 1.0 
AT_tL = 0.7
AT_tR = 1.0

xlimits = np.array([[0.,Time],[-L, L]])  #interal
sampling = LHS(xlimits=xlimits)
x_int= sampling(num_int)
x_int_memory,x_int_covert,x_int_overt,x_int_ignore \
  = IgnoreAndAttention(x_int,AT_xL,AT_xR,AT_tL,AT_tR,num_int)

xlimits = np.array([[0.,0],[-L, L]])  #interal
sampling = LHS(xlimits=xlimits)
x_ic  = sampling(num_ic)
x_ic_memory,x_ic_covert,x_ic_overt,x_ic_ignore \
  = IgnoreAndAttention(x_ic,AT_xL,AT_xR,AT_tL,AT_tR,num_ic)
#u_ic = IC(x_ic)                 
u_ic_ignore = IC(x_ic_ignore)                 
u_ic_memory = IC(x_ic_memory)                 
u_ic_covert = IC(x_ic_covert)                 
u_ic_overt = IC(x_ic_overt)                 


xlimits = np.array([[0.,Time],[-L,-L]])  #interal
sampling = LHS(xlimits=xlimits)
x_bdL  = sampling(num_ic)

xlimits = np.array([[0.,Time],[L,L]])  #interal
sampling = LHS(xlimits=xlimits)
x_bdR  = sampling(num_ic)

x_bdL_memory,x_bdL_covert,x_bdL_overt,x_bdL_ignore \
= IgnoreAndAttention(x_bdL,AT_xL,AT_xR,AT_tL,AT_tR,num_t)
x_bdR_memory,x_bdR_covert,x_bdR_overt,x_bdR_ignore \
= IgnoreAndAttention(x_bdR,AT_xL,AT_xR,AT_tL,AT_tR,num_t)

u_bdL_memory =  BD(x_bdL_memory)                            
u_bdL_covert =  BD(x_bdL_covert)                            
u_bdL_overt =   BD(x_bdL_overt)                            
u_bdL_ignore =  BD(x_bdL_ignore)                            

u_bdR_memory =  BD(x_bdR_memory)                            
u_bdR_covert =  BD(x_bdR_covert)                            
u_bdR_overt =   BD(x_bdR_overt)                            
u_bdR_ignore =  BD(x_bdR_ignore)                            


x_ic_memory    = torch.tensor(x_ic_memory,                       dtype=torch.float32).to(device)
u_ic_memory    = torch.tensor(u_ic_memory,                       dtype=torch.float32).to(device)
x_int_memory   = torch.tensor(x_int_memory,                      dtype=torch.float32).to(device)
x_bdL_memory   = torch.tensor(x_bdL_memory,                      dtype=torch.float32).to(device)
x_bdR_memory   = torch.tensor(x_bdR_memory,                      dtype=torch.float32).to(device)
u_bdL_memory   = torch.tensor(u_bdL_memory,                      dtype=torch.float32).to(device)
u_bdR_memory   = torch.tensor(u_bdR_memory,                      dtype=torch.float32).to(device)
x_ic_covert    = torch.tensor(x_ic_covert,                       dtype=torch.float32).to(device)
u_ic_covert    = torch.tensor(u_ic_covert,                       dtype=torch.float32).to(device)
x_int_covert   = torch.tensor(x_int_covert, requires_grad=True,  dtype=torch.float32).to(device)
x_bdL_covert   = torch.tensor(x_bdL_covert, requires_grad=True,  dtype=torch.float32).to(device)
x_bdR_covert   = torch.tensor(x_bdR_covert, requires_grad=True,  dtype=torch.float32).to(device)
u_bdL_covert   = torch.tensor(u_bdL_covert, requires_grad=True,  dtype=torch.float32).to(device)
u_bdR_covert   = torch.tensor(u_bdR_covert, requires_grad=True,  dtype=torch.float32).to(device)
x_ic_overt    = torch.tensor(x_ic_overt,                         dtype=torch.float32).to(device)
u_ic_overt    = torch.tensor(u_ic_overt,                         dtype=torch.float32).to(device)
x_int_overt   = torch.tensor(x_int_overt, requires_grad=True,    dtype=torch.float32).to(device)
x_bdL_overt   = torch.tensor(x_bdL_overt,requires_grad=True,     dtype=torch.float32).to(device)
x_bdR_overt   = torch.tensor(x_bdR_overt, requires_grad=True,    dtype=torch.float32).to(device)
u_bdL_overt   = torch.tensor(u_bdL_overt, requires_grad=True,    dtype=torch.float32).to(device)
u_bdR_overt   = torch.tensor(u_bdR_overt, requires_grad=True,    dtype=torch.float32).to(device)
x_ic_ignore    = torch.tensor(x_ic_ignore,                       dtype=torch.float32).to(device)
u_ic_ignore    = torch.tensor(u_ic_ignore,                       dtype=torch.float32).to(device)
x_int_ignore   = torch.tensor(x_int_ignore, requires_grad=True,  dtype=torch.float32).to(device)
x_bdL_ignore   = torch.tensor(x_bdL_ignore, requires_grad=True,  dtype=torch.float32).to(device)
x_bdR_ignore   = torch.tensor(x_bdR_ignore, requires_grad=True,  dtype=torch.float32).to(device)
u_bdL_ignore   = torch.tensor(u_bdL_ignore, requires_grad=True,  dtype=torch.float32).to(device)
u_bdR_ignore   = torch.tensor(u_bdR_ignore, requires_grad=True,  dtype=torch.float32).to(device)

#u_bdL =  BD(x_bdL)                            
#u_bdR =  BD(x_bdR)                            

#x_ic    = torch.tensor(x_ic, dtype=torch.float32).to(device)
#u_ic    = torch.tensor(u_ic, dtype=torch.float32).to(device)
#x_int   = torch.tensor(x_int, requires_grad=True, dtype=torch.float32).to(device)
#x_bdL   = torch.tensor(x_bdL, requires_grad=True,  dtype=torch.float32).to(device)
#x_bdR   = torch.tensor(x_bdR, requires_grad=True,  dtype=torch.float32).to(device)
#u_bdL   = torch.tensor(u_bdL, requires_grad=True,  dtype=torch.float32).to(device)
#u_bdR   = torch.tensor(u_bdR, requires_grad=True,  dtype=torch.float32).to(device)

#model = DNN().to(device)


lr = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
print('Start training...')
# Out:
# Start training...

# %%
u_int_memory = to_numpy(model(x_int_memory).to(device1))
u_int_memory   = torch.tensor(u_int_memory,  dtype=torch.float32).to(device)

# %%
u_int_memory
# Out:
# tensor([[ 0.1704],
#         [-0.9647],
#         [ 0.1042],
#         ...,
#         [ 0.0257],
#         [ 0.2865],
#         [-0.9731]], device='cuda:0')

# %%
optimizer = torch.optim.LBFGS(model.parameters(),lr=0.1,max_iter=20)
epochs = 10000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
    
toc = time.time()
# Out:
# epoch 1 loss_pde:0.02459237, loss_ic:0.00000018, loss_bd:0.00000442
# epoch 1 loss_pde:0.03267964, loss_ic:0.00647170, loss_bd:0.01479442
# epoch 1 loss_pde:0.03049738, loss_ic:0.00525973, loss_bd:0.01202987
# epoch 1 loss_pde:0.02879046, loss_ic:0.00427385, loss_bd:0.00978652
# epoch 1 loss_pde:0.02746283, loss_ic:0.00347265, loss_bd:0.00796655
# epoch 1 loss_pde:0.02643626, loss_ic:0.00282164, loss_bd:0.00648920
# epoch 1 loss_pde:0.02564796, loss_ic:0.00229270, loss_bd:0.00528964
# epoch 1 loss_pde:0.02504778, loss_ic:0.00186302, loss_bd:0.00431516
# epoch 1 loss_pde:0.02459535, loss_ic:0.00151382, loss_bd:0.00352290
# epoch 1 loss_pde:0.02425897, loss_ic:0.00123023, loss_bd:0.00287891
# epoch 1 loss_pde:0.02401294, loss_ic:0.00099986, loss_bd:0.00235495
# epoch 1 loss_pde:0.02383682, loss_ic:0.00081260, loss_bd:0.00192825
# epoch 1 loss_pde:0.02371468, loss_ic:0.00066053, loss_bd:0.00158096
# epoch 1 loss_pde:0.02363371, loss_ic:0.00053695, loss_bd:0.00129778
# epoch 1 loss_pde:0.02358384, loss_ic:0.00043654, loss_bd:0.00106679
# epoch 1 loss_pde:0.02355717, loss_ic:0.00035494, loss_bd:0.00087831
# epoch 1 loss_pde:0.02354750, loss_ic:0.00028856, loss_bd:0.00072425
# epoch 1 loss_pde:0.02355007, loss_ic:0.00023464, loss_bd:0.00059829
# epoch 1 loss_pde:0.02356107, loss_ic:0.00019079, loss_bd:0.00049524
# epoch 1 loss_pde:0.02357771, loss_ic:0.00015515, loss_bd:0.00041081
# epoch 1: loss 0.024638
# epoch 2 loss_pde:0.02359778, loss_ic:0.00012615, loss_bd:0.00034155
# epoch 2 loss_pde:0.02361959, loss_ic:0.00010252, loss_bd:0.00028459
# epoch 2 loss_pde:0.02364199, loss_ic:0.00008335, loss_bd:0.00023786
# epoch 2 loss_pde:0.02366412, loss_ic:0.00006772, loss_bd:0.00019932
# epoch 2 loss_pde:0.02368522, loss_ic:0.00005501, loss_bd:0.00016757
# epoch 2 loss_pde:0.02370496, loss_ic:0.00004463, loss_bd:0.00014126
# epoch 2 loss_pde:0.02372297, loss_ic:0.00003622, loss_bd:0.00011959
# epoch 2 loss_pde:0.02373913, loss_ic:0.00002934, loss_bd:0.00010154
# epoch 2 loss_pde:0.02375332, loss_ic:0.00002376, loss_bd:0.00008659
# epoch 2 loss_pde:0.02376553, loss_ic:0.00001921, loss_bd:0.00007413
# epoch 2 loss_pde:0.02377578, loss_ic:0.00001550, loss_bd:0.00006373
# epoch 2 loss_pde:0.02378416, loss_ic:0.00001247, loss_bd:0.00005500
# epoch 2 loss_pde:0.02379066, loss_ic:0.00001002, loss_bd:0.00004769
# epoch 2 loss_pde:0.02379533, loss_ic:0.00000802, loss_bd:0.00004157
# epoch 2 loss_pde:0.02379831, loss_ic:0.00000639, loss_bd:0.00003635
# epoch 2 loss_pde:0.02379965, loss_ic:0.00000508, loss_bd:0.00003198
# epoch 2 loss_pde:0.02379945, loss_ic:0.00000401, loss_bd:0.00002822
# epoch 2 loss_pde:0.02379765, loss_ic:0.00000316, loss_bd:0.00002506
# epoch 2 loss_pde:0.02379434, loss_ic:0.00000249, loss_bd:0.00002234
# epoch 2 loss_pde:0.02378948, loss_ic:0.00000196, loss_bd:0.00002001
# epoch 2: loss 0.028275
# epoch 3 loss_pde:0.02378306, loss_ic:0.00000155, loss_bd:0.00001802
# epoch 3 loss_pde:0.02377492, loss_ic:0.00000125, loss_bd:0.00001631
# epoch 3 loss_pde:0.02376509, loss_ic:0.00000105, loss_bd:0.00001484
# epoch 3 loss_pde:0.02375331, loss_ic:0.00000092, loss_bd:0.00001360
# epoch 3 loss_pde:0.02373934, loss_ic:0.00000088, loss_bd:0.00001256
# epoch 3 loss_pde:0.02372293, loss_ic:0.00000091, loss_bd:0.00001169
# epoch 3 loss_pde:0.02370375, loss_ic:0.00000102, loss_bd:0.00001101
# epoch 3 loss_pde:0.02368144, loss_ic:0.00000120, loss_bd:0.00001049
# epoch 3 loss_pde:0.02365555, loss_ic:0.00000145, loss_bd:0.00001015
# epoch 3 loss_pde:0.02362556, loss_ic:0.00000178, loss_bd:0.00001000
# epoch 3 loss_pde:0.02359106, loss_ic:0.00000220, loss_bd:0.00001004
# epoch 3 loss_pde:0.02355138, loss_ic:0.00000270, loss_bd:0.00001030
# epoch 3 loss_pde:0.02350607, loss_ic:0.00000327, loss_bd:0.00001076
# epoch 3 loss_pde:0.02345430, loss_ic:0.00000394, loss_bd:0.00001147
# epoch 3 loss_pde:0.02339569, loss_ic:0.00000468, loss_bd:0.00001243
# epoch 3 loss_pde:0.02333003, loss_ic:0.00000550, loss_bd:0.00001363
# epoch 3 loss_pde:0.02325724, loss_ic:0.00000637, loss_bd:0.00001508
# epoch 3 loss_pde:0.02317702, loss_ic:0.00000727, loss_bd:0.00001676
# epoch 3 loss_pde:0.02308979, loss_ic:0.00000817, loss_bd:0.00001863
# epoch 3 loss_pde:0.02299536, loss_ic:0.00000903, loss_bd:0.00002065
# epoch 3: loss 0.023979
# epoch 4 loss_pde:0.02289286, loss_ic:0.00000981, loss_bd:0.00002272
# epoch 4 loss_pde:0.02277832, loss_ic:0.00001042, loss_bd:0.00002473
# epoch 4 loss_pde:0.02264275, loss_ic:0.00001051, loss_bd:0.00002590
# epoch 4 loss_pde:0.02239169, loss_ic:0.00001145, loss_bd:0.00002947
# epoch 4 loss_pde:0.02223413, loss_ic:0.00001116, loss_bd:0.00003035
# epoch 4 loss_pde:0.02209947, loss_ic:0.00001092, loss_bd:0.00003097
# epoch 4 loss_pde:0.02196951, loss_ic:0.00001040, loss_bd:0.00003100
# epoch 4 loss_pde:0.02184283, loss_ic:0.00000979, loss_bd:0.00003059
# epoch 4 loss_pde:0.02172452, loss_ic:0.00000913, loss_bd:0.00002980
# epoch 4 loss_pde:0.02161578, loss_ic:0.00000849, loss_bd:0.00002871
# epoch 4 loss_pde:0.02151681, loss_ic:0.00000792, loss_bd:0.00002741
# epoch 4 loss_pde:0.02142720, loss_ic:0.00000747, loss_bd:0.00002599
# epoch 4 loss_pde:0.02134604, loss_ic:0.00000716, loss_bd:0.00002452
# epoch 4 loss_pde:0.02127237, loss_ic:0.00000701, loss_bd:0.00002307
# epoch 4 loss_pde:0.02120502, loss_ic:0.00000700, loss_bd:0.00002166
# epoch 4 loss_pde:0.02114306, loss_ic:0.00000714, loss_bd:0.00002035
# epoch 4 loss_pde:0.02108555, loss_ic:0.00000741, loss_bd:0.00001914
# epoch 4 loss_pde:0.02103148, loss_ic:0.00000779, loss_bd:0.00001803
# epoch 4 loss_pde:0.02098022, loss_ic:0.00000828, loss_bd:0.00001704
# epoch 4 loss_pde:0.02093107, loss_ic:0.00000884, loss_bd:0.00001616
# epoch 4: loss 0.023218
# epoch 5 loss_pde:0.02088322, loss_ic:0.00000947, loss_bd:0.00001540
# epoch 5 loss_pde:0.02083615, loss_ic:0.00001016, loss_bd:0.00001473
# epoch 5 loss_pde:0.02078925, loss_ic:0.00001088, loss_bd:0.00001418
# epoch 5 loss_pde:0.02074186, loss_ic:0.00001162, loss_bd:0.00001372
# epoch 5 loss_pde:0.02069336, loss_ic:0.00001236, loss_bd:0.00001336
# epoch 5 loss_pde:0.02064287, loss_ic:0.00001309, loss_bd:0.00001310
# epoch 5 loss_pde:0.02058978, loss_ic:0.00001377, loss_bd:0.00001293
# epoch 5 loss_pde:0.02053289, loss_ic:0.00001436, loss_bd:0.00001286
# epoch 5 loss_pde:0.02047114, loss_ic:0.00001483, loss_bd:0.00001289
# epoch 5 loss_pde:0.02040313, loss_ic:0.00001509, loss_bd:0.00001303
# epoch 5 loss_pde:0.02032722, loss_ic:0.00001506, loss_bd:0.00001325
# epoch 5 loss_pde:0.02024060, loss_ic:0.00001464, loss_bd:0.00001356
# epoch 5 loss_pde:0.02013522, loss_ic:0.00001373, loss_bd:0.00001375
# epoch 5 loss_pde:0.01990394, loss_ic:0.00001743, loss_bd:0.00001962
# epoch 5 loss_pde:0.01981748, loss_ic:0.00001522, loss_bd:0.00001933
# epoch 5 loss_pde:0.01972346, loss_ic:0.00001321, loss_bd:0.00001905
# epoch 5 loss_pde:0.01961844, loss_ic:0.00001138, loss_bd:0.00001880
# epoch 5 loss_pde:0.01950541, loss_ic:0.00000981, loss_bd:0.00001859
# epoch 5 loss_pde:0.01938642, loss_ic:0.00000859, loss_bd:0.00001847
# epoch 5 loss_pde:0.01926404, loss_ic:0.00000772, loss_bd:0.00001843
# epoch 5: loss 0.021132
# epoch 6 loss_pde:0.01913963, loss_ic:0.00000724, loss_bd:0.00001848
# epoch 6 loss_pde:0.01901492, loss_ic:0.00000713, loss_bd:0.00001862
# epoch 6 loss_pde:0.01889093, loss_ic:0.00000735, loss_bd:0.00001884
# epoch 6 loss_pde:0.01876856, loss_ic:0.00000787, loss_bd:0.00001915
# epoch 6 loss_pde:0.01864851, loss_ic:0.00000865, loss_bd:0.00001953
# epoch 6 loss_pde:0.01853098, loss_ic:0.00000964, loss_bd:0.00001999
# epoch 6 loss_pde:0.01841627, loss_ic:0.00001081, loss_bd:0.00002050
# epoch 6 loss_pde:0.01830443, loss_ic:0.00001210, loss_bd:0.00002107
# epoch 6 loss_pde:0.01819513, loss_ic:0.00001348, loss_bd:0.00002169
# epoch 6 loss_pde:0.01808827, loss_ic:0.00001492, loss_bd:0.00002235
# epoch 6 loss_pde:0.01798350, loss_ic:0.00001639, loss_bd:0.00002304
# epoch 6 loss_pde:0.01788045, loss_ic:0.00001786, loss_bd:0.00002375
# epoch 6 loss_pde:0.01777864, loss_ic:0.00001931, loss_bd:0.00002449
# epoch 6 loss_pde:0.01767771, loss_ic:0.00002071, loss_bd:0.00002524
# epoch 6 loss_pde:0.01757712, loss_ic:0.00002204, loss_bd:0.00002598
# epoch 6 loss_pde:0.01747631, loss_ic:0.00002329, loss_bd:0.00002672
# epoch 6 loss_pde:0.01737478, loss_ic:0.00002443, loss_bd:0.00002744
# epoch 6 loss_pde:0.01727187, loss_ic:0.00002544, loss_bd:0.00002812
# epoch 6 loss_pde:0.01716657, loss_ic:0.00002631, loss_bd:0.00002872
# epoch 6 loss_pde:0.01705736, loss_ic:0.00002704, loss_bd:0.00002923
# epoch 6: loss 0.019397
# epoch 7 loss_pde:0.01694117, loss_ic:0.00002765, loss_bd:0.00002959
# epoch 7 loss_pde:0.01681216, loss_ic:0.00002819, loss_bd:0.00002971
# epoch 7 loss_pde:0.01664527, loss_ic:0.00002911, loss_bd:0.00002929
# epoch 7 loss_pde:0.01643341, loss_ic:0.00002961, loss_bd:0.00002880
# epoch 7 loss_pde:0.01621787, loss_ic:0.00003062, loss_bd:0.00002770
# epoch 7 loss_pde:0.01600622, loss_ic:0.00003100, loss_bd:0.00002661
# epoch 7 loss_pde:0.01579594, loss_ic:0.00003178, loss_bd:0.00002515
# epoch 7 loss_pde:0.01557349, loss_ic:0.00003203, loss_bd:0.00002379
# epoch 7 loss_pde:0.01536962, loss_ic:0.00003246, loss_bd:0.00002208
# epoch 7 loss_pde:0.01518117, loss_ic:0.00003286, loss_bd:0.00002047
# epoch 7 loss_pde:0.01498851, loss_ic:0.00003321, loss_bd:0.00001863
# epoch 7 loss_pde:0.01480599, loss_ic:0.00003358, loss_bd:0.00001687
# epoch 7 loss_pde:0.01463374, loss_ic:0.00003373, loss_bd:0.00001539
# epoch 7 loss_pde:0.01447037, loss_ic:0.00003376, loss_bd:0.00001413
# epoch 7 loss_pde:0.01431652, loss_ic:0.00003373, loss_bd:0.00001303
# epoch 7 loss_pde:0.01417280, loss_ic:0.00003362, loss_bd:0.00001216
# epoch 7 loss_pde:0.01403998, loss_ic:0.00003347, loss_bd:0.00001148
# epoch 7 loss_pde:0.01391774, loss_ic:0.00003327, loss_bd:0.00001102
# epoch 7 loss_pde:0.01380586, loss_ic:0.00003304, loss_bd:0.00001071
# epoch 7 loss_pde:0.01370312, loss_ic:0.00003276, loss_bd:0.00001060
# epoch 7: loss 0.017514
# epoch 8 loss_pde:0.01360917, loss_ic:0.00003248, loss_bd:0.00001053
# epoch 8 loss_pde:0.01352158, loss_ic:0.00003214, loss_bd:0.00001073
# epoch 8 loss_pde:0.01344191, loss_ic:0.00003199, loss_bd:0.00001012
# epoch 8 loss_pde:0.01338286, loss_ic:0.00003175, loss_bd:0.00001025
# epoch 8 loss_pde:0.01331761, loss_ic:0.00003134, loss_bd:0.00001070
# epoch 8 loss_pde:0.01324614, loss_ic:0.00003077, loss_bd:0.00001160
# epoch 8 loss_pde:0.01317827, loss_ic:0.00003026, loss_bd:0.00001219
# epoch 8 loss_pde:0.01310672, loss_ic:0.00002966, loss_bd:0.00001251
# epoch 8 loss_pde:0.01302294, loss_ic:0.00002887, loss_bd:0.00001329
# epoch 8 loss_pde:0.01294433, loss_ic:0.00002805, loss_bd:0.00001380
# epoch 8 loss_pde:0.01285777, loss_ic:0.00002725, loss_bd:0.00001468
# epoch 8 loss_pde:0.01277816, loss_ic:0.00002635, loss_bd:0.00001518
# epoch 8 loss_pde:0.01267315, loss_ic:0.00002581, loss_bd:0.00001649
# epoch 8 loss_pde:0.01258437, loss_ic:0.00002494, loss_bd:0.00001690
# epoch 8 loss_pde:0.01248587, loss_ic:0.00002381, loss_bd:0.00001695
# epoch 8 loss_pde:0.01236667, loss_ic:0.00002268, loss_bd:0.00001736
# epoch 8 loss_pde:0.01224458, loss_ic:0.00002139, loss_bd:0.00001739
# epoch 8 loss_pde:0.01210718, loss_ic:0.00002022, loss_bd:0.00001744
# epoch 8 loss_pde:0.01197065, loss_ic:0.00001888, loss_bd:0.00001709
# epoch 8 loss_pde:0.01182548, loss_ic:0.00001790, loss_bd:0.00001667
# epoch 8: loss 0.014039
# epoch 9 loss_pde:0.01167689, loss_ic:0.00001673, loss_bd:0.00001607
# epoch 9 loss_pde:0.01152637, loss_ic:0.00001606, loss_bd:0.00001524
# epoch 9 loss_pde:0.01137132, loss_ic:0.00001526, loss_bd:0.00001477
# epoch 9 loss_pde:0.01122189, loss_ic:0.00001509, loss_bd:0.00001378
# epoch 9 loss_pde:0.01107607, loss_ic:0.00001487, loss_bd:0.00001323
# epoch 9 loss_pde:0.01092253, loss_ic:0.00001517, loss_bd:0.00001198
# epoch 9 loss_pde:0.01079052, loss_ic:0.00001553, loss_bd:0.00001119
# epoch 9 loss_pde:0.01066827, loss_ic:0.00001609, loss_bd:0.00001044
# epoch 9 loss_pde:0.01055041, loss_ic:0.00001675, loss_bd:0.00000967
# epoch 9 loss_pde:0.01044432, loss_ic:0.00001749, loss_bd:0.00000912
# epoch 9 loss_pde:0.01033659, loss_ic:0.00001824, loss_bd:0.00000831
# epoch 9 loss_pde:0.01024200, loss_ic:0.00001910, loss_bd:0.00000782
# epoch 9 loss_pde:0.01014236, loss_ic:0.00002033, loss_bd:0.00000764
# epoch 9 loss_pde:0.01005010, loss_ic:0.00002115, loss_bd:0.00000734
# epoch 9 loss_pde:0.00996248, loss_ic:0.00002220, loss_bd:0.00000720
# epoch 9 loss_pde:0.00987771, loss_ic:0.00002244, loss_bd:0.00000668
# epoch 9 loss_pde:0.00980263, loss_ic:0.00002333, loss_bd:0.00000659
# epoch 9 loss_pde:0.00967602, loss_ic:0.00002544, loss_bd:0.00000699
# epoch 9 loss_pde:0.00959150, loss_ic:0.00002648, loss_bd:0.00000693
# epoch 9 loss_pde:0.00950186, loss_ic:0.00002742, loss_bd:0.00000705
# epoch 9: loss 0.012005
# epoch 10 loss_pde:0.00939795, loss_ic:0.00002862, loss_bd:0.00000658
# epoch 10 loss_pde:0.00929845, loss_ic:0.00002942, loss_bd:0.00000672
# epoch 10 loss_pde:0.00918873, loss_ic:0.00003003, loss_bd:0.00000694
# epoch 10 loss_pde:0.00907844, loss_ic:0.00003041, loss_bd:0.00000712
# epoch 10 loss_pde:0.00896889, loss_ic:0.00003087, loss_bd:0.00000718
# epoch 10 loss_pde:0.00886059, loss_ic:0.00003066, loss_bd:0.00000766
# epoch 10 loss_pde:0.00875522, loss_ic:0.00003112, loss_bd:0.00000750
# epoch 10 loss_pde:0.00863580, loss_ic:0.00003013, loss_bd:0.00000876
# epoch 10 loss_pde:0.00856019, loss_ic:0.00002995, loss_bd:0.00000907
# epoch 10 loss_pde:0.00848836, loss_ic:0.00002935, loss_bd:0.00000968
# epoch 10 loss_pde:0.00841440, loss_ic:0.00002892, loss_bd:0.00000992
# epoch 10 loss_pde:0.00834379, loss_ic:0.00002817, loss_bd:0.00001051
# epoch 10 loss_pde:0.00827145, loss_ic:0.00002773, loss_bd:0.00001070
# epoch 10 loss_pde:0.00820114, loss_ic:0.00002685, loss_bd:0.00001133
# epoch 10 loss_pde:0.00810786, loss_ic:0.00002766, loss_bd:0.00001120
# epoch 10 loss_pde:0.00802618, loss_ic:0.00002665, loss_bd:0.00001175
# epoch 10 loss_pde:0.00795617, loss_ic:0.00002599, loss_bd:0.00001245
# epoch 10 loss_pde:0.00788911, loss_ic:0.00002531, loss_bd:0.00001290
# epoch 10 loss_pde:0.00782567, loss_ic:0.00002471, loss_bd:0.00001344
# epoch 10 loss_pde:0.00775787, loss_ic:0.00002404, loss_bd:0.00001390
# epoch 10: loss 0.009750
# epoch 11 loss_pde:0.00768989, loss_ic:0.00002345, loss_bd:0.00001438
# epoch 11 loss_pde:0.00760747, loss_ic:0.00002305, loss_bd:0.00001481
# epoch 11 loss_pde:0.00753189, loss_ic:0.00002271, loss_bd:0.00001516
# epoch 11 loss_pde:0.00742606, loss_ic:0.00002163, loss_bd:0.00001656
# epoch 11 loss_pde:0.00735326, loss_ic:0.00002139, loss_bd:0.00001680
# epoch 11 loss_pde:0.00726812, loss_ic:0.00002096, loss_bd:0.00001717
# epoch 11 loss_pde:0.00717676, loss_ic:0.00002084, loss_bd:0.00001719
# epoch 11 loss_pde:0.00708970, loss_ic:0.00002048, loss_bd:0.00001732
# epoch 11 loss_pde:0.00698156, loss_ic:0.00002150, loss_bd:0.00001699
# epoch 11 loss_pde:0.00691371, loss_ic:0.00002140, loss_bd:0.00001696
# epoch 11 loss_pde:0.00683020, loss_ic:0.00002120, loss_bd:0.00001658
# epoch 11 loss_pde:0.00676463, loss_ic:0.00002109, loss_bd:0.00001640
# epoch 11 loss_pde:0.00667986, loss_ic:0.00002081, loss_bd:0.00001640
# epoch 11 loss_pde:0.00661180, loss_ic:0.00002076, loss_bd:0.00001618
# epoch 11 loss_pde:0.00651723, loss_ic:0.00002020, loss_bd:0.00001563
# epoch 11 loss_pde:0.00645305, loss_ic:0.00001989, loss_bd:0.00001531
# epoch 11 loss_pde:0.00637460, loss_ic:0.00001991, loss_bd:0.00001464
# epoch 11 loss_pde:0.00629746, loss_ic:0.00001942, loss_bd:0.00001410
# epoch 11 loss_pde:0.00621361, loss_ic:0.00001909, loss_bd:0.00001364
# epoch 11 loss_pde:0.00613212, loss_ic:0.00001851, loss_bd:0.00001306
# epoch 11: loss 0.008068
# epoch 12 loss_pde:0.00604855, loss_ic:0.00001812, loss_bd:0.00001239
# epoch 12 loss_pde:0.00597068, loss_ic:0.00001754, loss_bd:0.00001178
# epoch 12 loss_pde:0.00589606, loss_ic:0.00001717, loss_bd:0.00001118
# epoch 12 loss_pde:0.00582297, loss_ic:0.00001668, loss_bd:0.00001066
# epoch 12 loss_pde:0.00575467, loss_ic:0.00001641, loss_bd:0.00001012
# epoch 12 loss_pde:0.00568899, loss_ic:0.00001603, loss_bd:0.00000963
# epoch 12 loss_pde:0.00562772, loss_ic:0.00001592, loss_bd:0.00000918
# epoch 12 loss_pde:0.00556889, loss_ic:0.00001572, loss_bd:0.00000871
# epoch 12 loss_pde:0.00551115, loss_ic:0.00001565, loss_bd:0.00000832
# epoch 12 loss_pde:0.00544948, loss_ic:0.00001591, loss_bd:0.00000803
# epoch 12 loss_pde:0.00539974, loss_ic:0.00001596, loss_bd:0.00000777
# epoch 12 loss_pde:0.00535153, loss_ic:0.00001594, loss_bd:0.00000734
# epoch 12 loss_pde:0.00530430, loss_ic:0.00001602, loss_bd:0.00000703
# epoch 12 loss_pde:0.00525709, loss_ic:0.00001608, loss_bd:0.00000677
# epoch 12 loss_pde:0.00521193, loss_ic:0.00001615, loss_bd:0.00000655
# epoch 12 loss_pde:0.00516839, loss_ic:0.00001620, loss_bd:0.00000633
# epoch 12 loss_pde:0.00512599, loss_ic:0.00001623, loss_bd:0.00000615
# epoch 12 loss_pde:0.00508488, loss_ic:0.00001627, loss_bd:0.00000596
# epoch 12 loss_pde:0.00504512, loss_ic:0.00001622, loss_bd:0.00000583
# epoch 12 loss_pde:0.00500612, loss_ic:0.00001626, loss_bd:0.00000566
# epoch 12: loss 0.006354
# epoch 13 loss_pde:0.00496900, loss_ic:0.00001612, loss_bd:0.00000557
# epoch 13 loss_pde:0.00493255, loss_ic:0.00001614, loss_bd:0.00000542
# epoch 13 loss_pde:0.00489556, loss_ic:0.00001587, loss_bd:0.00000543
# epoch 13 loss_pde:0.00485789, loss_ic:0.00001575, loss_bd:0.00000534
# epoch 13 loss_pde:0.00483174, loss_ic:0.00001563, loss_bd:0.00000530
# epoch 13 loss_pde:0.00480517, loss_ic:0.00001547, loss_bd:0.00000527
# epoch 13 loss_pde:0.00477816, loss_ic:0.00001529, loss_bd:0.00000525
# epoch 13 loss_pde:0.00475075, loss_ic:0.00001514, loss_bd:0.00000519
# epoch 13 loss_pde:0.00472434, loss_ic:0.00001495, loss_bd:0.00000516
# epoch 13 loss_pde:0.00469634, loss_ic:0.00001487, loss_bd:0.00000509
# epoch 13 loss_pde:0.00466821, loss_ic:0.00001472, loss_bd:0.00000505
# epoch 13 loss_pde:0.00462774, loss_ic:0.00001433, loss_bd:0.00000540
# epoch 13 loss_pde:0.00459656, loss_ic:0.00001420, loss_bd:0.00000536
# epoch 13 loss_pde:0.00453335, loss_ic:0.00001541, loss_bd:0.00000595
# epoch 13 loss_pde:0.00450177, loss_ic:0.00001522, loss_bd:0.00000583
# epoch 13 loss_pde:0.00446521, loss_ic:0.00001506, loss_bd:0.00000564
# epoch 13 loss_pde:0.00442292, loss_ic:0.00001491, loss_bd:0.00000540
# epoch 13 loss_pde:0.00437612, loss_ic:0.00001481, loss_bd:0.00000513
# epoch 13 loss_pde:0.00432626, loss_ic:0.00001475, loss_bd:0.00000483
# epoch 13 loss_pde:0.00427477, loss_ic:0.00001475, loss_bd:0.00000451
# epoch 13: loss 0.005186
# epoch 14 loss_pde:0.00422321, loss_ic:0.00001481, loss_bd:0.00000419
# epoch 14 loss_pde:0.00417279, loss_ic:0.00001492, loss_bd:0.00000389
# epoch 14 loss_pde:0.00412454, loss_ic:0.00001507, loss_bd:0.00000360
# epoch 14 loss_pde:0.00407918, loss_ic:0.00001526, loss_bd:0.00000335
# epoch 14 loss_pde:0.00403724, loss_ic:0.00001547, loss_bd:0.00000313
# epoch 14 loss_pde:0.00399904, loss_ic:0.00001569, loss_bd:0.00000295
# epoch 14 loss_pde:0.00396462, loss_ic:0.00001591, loss_bd:0.00000281
# epoch 14 loss_pde:0.00393386, loss_ic:0.00001613, loss_bd:0.00000271
# epoch 14 loss_pde:0.00390643, loss_ic:0.00001635, loss_bd:0.00000264
# epoch 14 loss_pde:0.00388216, loss_ic:0.00001655, loss_bd:0.00000259
# epoch 14 loss_pde:0.00386039, loss_ic:0.00001675, loss_bd:0.00000257
# epoch 14 loss_pde:0.00384153, loss_ic:0.00001691, loss_bd:0.00000253
# epoch 14 loss_pde:0.00382119, loss_ic:0.00001715, loss_bd:0.00000261
# epoch 14 loss_pde:0.00380562, loss_ic:0.00001731, loss_bd:0.00000259
# epoch 14 loss_pde:0.00379280, loss_ic:0.00001748, loss_bd:0.00000264
# epoch 14 loss_pde:0.00378207, loss_ic:0.00001760, loss_bd:0.00000264
# epoch 14 loss_pde:0.00377157, loss_ic:0.00001774, loss_bd:0.00000270
# epoch 14 loss_pde:0.00376238, loss_ic:0.00001783, loss_bd:0.00000269
# epoch 14 loss_pde:0.00375106, loss_ic:0.00001800, loss_bd:0.00000277
# epoch 14 loss_pde:0.00374111, loss_ic:0.00001811, loss_bd:0.00000281
# epoch 14: loss 0.004413
# epoch 15 loss_pde:0.00373476, loss_ic:0.00001820, loss_bd:0.00000285
# epoch 15 loss_pde:0.00372806, loss_ic:0.00001827, loss_bd:0.00000289
# epoch 15 loss_pde:0.00371773, loss_ic:0.00001834, loss_bd:0.00000293
# epoch 15 loss_pde:0.00370635, loss_ic:0.00001839, loss_bd:0.00000296
# epoch 15 loss_pde:0.00369376, loss_ic:0.00001842, loss_bd:0.00000298
# epoch 15 loss_pde:0.00367833, loss_ic:0.00001843, loss_bd:0.00000299
# epoch 15 loss_pde:0.00366135, loss_ic:0.00001840, loss_bd:0.00000299
# epoch 15 loss_pde:0.00364305, loss_ic:0.00001835, loss_bd:0.00000299
# epoch 15 loss_pde:0.00362662, loss_ic:0.00001830, loss_bd:0.00000299
# epoch 15 loss_pde:0.00360968, loss_ic:0.00001817, loss_bd:0.00000297
# epoch 15 loss_pde:0.00359175, loss_ic:0.00001806, loss_bd:0.00000295
# epoch 15 loss_pde:0.00357347, loss_ic:0.00001793, loss_bd:0.00000291
# epoch 15 loss_pde:0.00355665, loss_ic:0.00001776, loss_bd:0.00000287
# epoch 15 loss_pde:0.00353903, loss_ic:0.00001750, loss_bd:0.00000289
# epoch 15 loss_pde:0.00352231, loss_ic:0.00001729, loss_bd:0.00000288
# epoch 15 loss_pde:0.00350708, loss_ic:0.00001706, loss_bd:0.00000287
# epoch 15 loss_pde:0.00349108, loss_ic:0.00001684, loss_bd:0.00000287
# epoch 15 loss_pde:0.00347936, loss_ic:0.00001659, loss_bd:0.00000285
# epoch 15 loss_pde:0.00346734, loss_ic:0.00001635, loss_bd:0.00000278
# epoch 15 loss_pde:0.00345552, loss_ic:0.00001608, loss_bd:0.00000276
# epoch 15: loss 0.003945
# epoch 16 loss_pde:0.00344484, loss_ic:0.00001581, loss_bd:0.00000264
# epoch 16 loss_pde:0.00343609, loss_ic:0.00001555, loss_bd:0.00000260
# epoch 16 loss_pde:0.00342764, loss_ic:0.00001531, loss_bd:0.00000252
# epoch 16 loss_pde:0.00341913, loss_ic:0.00001504, loss_bd:0.00000248
# epoch 16 loss_pde:0.00341093, loss_ic:0.00001478, loss_bd:0.00000242
# epoch 16 loss_pde:0.00340180, loss_ic:0.00001448, loss_bd:0.00000237
# epoch 16 loss_pde:0.00339361, loss_ic:0.00001418, loss_bd:0.00000233
# epoch 16 loss_pde:0.00338544, loss_ic:0.00001391, loss_bd:0.00000228
# epoch 16 loss_pde:0.00337814, loss_ic:0.00001362, loss_bd:0.00000224
# epoch 16 loss_pde:0.00337018, loss_ic:0.00001339, loss_bd:0.00000218
# epoch 16 loss_pde:0.00336251, loss_ic:0.00001309, loss_bd:0.00000216
# epoch 16 loss_pde:0.00335428, loss_ic:0.00001302, loss_bd:0.00000203
# epoch 16 loss_pde:0.00334780, loss_ic:0.00001275, loss_bd:0.00000203
# epoch 16 loss_pde:0.00334065, loss_ic:0.00001247, loss_bd:0.00000203
# epoch 16 loss_pde:0.00333187, loss_ic:0.00001217, loss_bd:0.00000203
# epoch 16 loss_pde:0.00332118, loss_ic:0.00001180, loss_bd:0.00000203
# epoch 16 loss_pde:0.00330939, loss_ic:0.00001142, loss_bd:0.00000203
# epoch 16 loss_pde:0.00329487, loss_ic:0.00001106, loss_bd:0.00000200
# epoch 16 loss_pde:0.00328543, loss_ic:0.00001076, loss_bd:0.00000199
# epoch 16 loss_pde:0.00327258, loss_ic:0.00001041, loss_bd:0.00000206
# epoch 16: loss 0.003629
# epoch 17 loss_pde:0.00326120, loss_ic:0.00001009, loss_bd:0.00000206
# epoch 17 loss_pde:0.00324904, loss_ic:0.00000977, loss_bd:0.00000208
# epoch 17 loss_pde:0.00323679, loss_ic:0.00000948, loss_bd:0.00000206
# epoch 17 loss_pde:0.00322371, loss_ic:0.00000920, loss_bd:0.00000209
# epoch 17 loss_pde:0.00321109, loss_ic:0.00000895, loss_bd:0.00000207
# epoch 17 loss_pde:0.00319827, loss_ic:0.00000873, loss_bd:0.00000209
# epoch 17 loss_pde:0.00318553, loss_ic:0.00000856, loss_bd:0.00000209
# epoch 17 loss_pde:0.00317327, loss_ic:0.00000837, loss_bd:0.00000209
# epoch 17 loss_pde:0.00316133, loss_ic:0.00000826, loss_bd:0.00000210
# epoch 17 loss_pde:0.00315080, loss_ic:0.00000812, loss_bd:0.00000208
# epoch 17 loss_pde:0.00314069, loss_ic:0.00000805, loss_bd:0.00000210
# epoch 17 loss_pde:0.00313143, loss_ic:0.00000796, loss_bd:0.00000206
# epoch 17 loss_pde:0.00312366, loss_ic:0.00000793, loss_bd:0.00000206
# epoch 17 loss_pde:0.00311452, loss_ic:0.00000792, loss_bd:0.00000207
# epoch 17 loss_pde:0.00310498, loss_ic:0.00000790, loss_bd:0.00000207
# epoch 17 loss_pde:0.00309467, loss_ic:0.00000790, loss_bd:0.00000207
# epoch 17 loss_pde:0.00308313, loss_ic:0.00000790, loss_bd:0.00000207
# epoch 17 loss_pde:0.00306968, loss_ic:0.00000791, loss_bd:0.00000207
# epoch 17 loss_pde:0.00305731, loss_ic:0.00000791, loss_bd:0.00000206
# epoch 17 loss_pde:0.00304302, loss_ic:0.00000791, loss_bd:0.00000204
# epoch 17: loss 0.003383
# epoch 18 loss_pde:0.00302641, loss_ic:0.00000791, loss_bd:0.00000202
# epoch 18 loss_pde:0.00300915, loss_ic:0.00000791, loss_bd:0.00000202
# epoch 18 loss_pde:0.00299279, loss_ic:0.00000789, loss_bd:0.00000201
# epoch 18 loss_pde:0.00297677, loss_ic:0.00000785, loss_bd:0.00000199
# epoch 18 loss_pde:0.00296042, loss_ic:0.00000783, loss_bd:0.00000199
# epoch 18 loss_pde:0.00294539, loss_ic:0.00000775, loss_bd:0.00000198
# epoch 18 loss_pde:0.00293091, loss_ic:0.00000771, loss_bd:0.00000199
# epoch 18 loss_pde:0.00291787, loss_ic:0.00000761, loss_bd:0.00000199
# epoch 18 loss_pde:0.00290503, loss_ic:0.00000755, loss_bd:0.00000200
# epoch 18 loss_pde:0.00289388, loss_ic:0.00000746, loss_bd:0.00000202
# epoch 18 loss_pde:0.00288278, loss_ic:0.00000741, loss_bd:0.00000205
# epoch 18 loss_pde:0.00287340, loss_ic:0.00000732, loss_bd:0.00000208
# epoch 18 loss_pde:0.00286451, loss_ic:0.00000722, loss_bd:0.00000219
# epoch 18 loss_pde:0.00285756, loss_ic:0.00000715, loss_bd:0.00000220
# epoch 18 loss_pde:0.00285128, loss_ic:0.00000708, loss_bd:0.00000227
# epoch 18 loss_pde:0.00284512, loss_ic:0.00000702, loss_bd:0.00000229
# epoch 18 loss_pde:0.00284028, loss_ic:0.00000697, loss_bd:0.00000231
# epoch 18 loss_pde:0.00283588, loss_ic:0.00000694, loss_bd:0.00000233
# epoch 18 loss_pde:0.00283182, loss_ic:0.00000691, loss_bd:0.00000236
# epoch 18 loss_pde:0.00282815, loss_ic:0.00000688, loss_bd:0.00000238
# epoch 18: loss 0.003126
# epoch 19 loss_pde:0.00282478, loss_ic:0.00000686, loss_bd:0.00000241
# epoch 19 loss_pde:0.00282176, loss_ic:0.00000684, loss_bd:0.00000243
# epoch 19 loss_pde:0.00281894, loss_ic:0.00000683, loss_bd:0.00000245
# epoch 19 loss_pde:0.00281640, loss_ic:0.00000682, loss_bd:0.00000247
# epoch 19 loss_pde:0.00281398, loss_ic:0.00000681, loss_bd:0.00000250
# epoch 19 loss_pde:0.00281171, loss_ic:0.00000680, loss_bd:0.00000251
# epoch 19 loss_pde:0.00280947, loss_ic:0.00000679, loss_bd:0.00000254
# epoch 19 loss_pde:0.00280731, loss_ic:0.00000679, loss_bd:0.00000255
# epoch 19 loss_pde:0.00280511, loss_ic:0.00000679, loss_bd:0.00000257
# epoch 19 loss_pde:0.00280270, loss_ic:0.00000679, loss_bd:0.00000259
# epoch 19 loss_pde:0.00280040, loss_ic:0.00000678, loss_bd:0.00000261
# epoch 19 loss_pde:0.00279802, loss_ic:0.00000678, loss_bd:0.00000263
# epoch 19 loss_pde:0.00279495, loss_ic:0.00000677, loss_bd:0.00000265
# epoch 19 loss_pde:0.00279249, loss_ic:0.00000677, loss_bd:0.00000267
# epoch 19 loss_pde:0.00278958, loss_ic:0.00000676, loss_bd:0.00000268
# epoch 19 loss_pde:0.00278607, loss_ic:0.00000675, loss_bd:0.00000270
# epoch 19 loss_pde:0.00278232, loss_ic:0.00000674, loss_bd:0.00000271
# epoch 19 loss_pde:0.00277800, loss_ic:0.00000673, loss_bd:0.00000273
# epoch 19 loss_pde:0.00277299, loss_ic:0.00000671, loss_bd:0.00000274
# epoch 19 loss_pde:0.00276704, loss_ic:0.00000666, loss_bd:0.00000277
# epoch 19: loss 0.002917
# epoch 20 loss_pde:0.00276044, loss_ic:0.00000663, loss_bd:0.00000278
# epoch 20 loss_pde:0.00275313, loss_ic:0.00000657, loss_bd:0.00000282
# epoch 20 loss_pde:0.00274597, loss_ic:0.00000652, loss_bd:0.00000283
# epoch 20 loss_pde:0.00273762, loss_ic:0.00000647, loss_bd:0.00000287
# epoch 20 loss_pde:0.00272779, loss_ic:0.00000641, loss_bd:0.00000288
# epoch 20 loss_pde:0.00271658, loss_ic:0.00000634, loss_bd:0.00000294
# epoch 20 loss_pde:0.00270502, loss_ic:0.00000627, loss_bd:0.00000296
# epoch 20 loss_pde:0.00269211, loss_ic:0.00000621, loss_bd:0.00000302
# epoch 20 loss_pde:0.00267783, loss_ic:0.00000612, loss_bd:0.00000305
# epoch 20 loss_pde:0.00266455, loss_ic:0.00000607, loss_bd:0.00000310
# epoch 20 loss_pde:0.00265097, loss_ic:0.00000601, loss_bd:0.00000315
# epoch 20 loss_pde:0.00263594, loss_ic:0.00000599, loss_bd:0.00000321
# epoch 20 loss_pde:0.00262163, loss_ic:0.00000597, loss_bd:0.00000327
# epoch 20 loss_pde:0.00260632, loss_ic:0.00000598, loss_bd:0.00000334
# epoch 20 loss_pde:0.00259305, loss_ic:0.00000598, loss_bd:0.00000340
# epoch 20 loss_pde:0.00257837, loss_ic:0.00000607, loss_bd:0.00000342
# epoch 20 loss_pde:0.00256638, loss_ic:0.00000609, loss_bd:0.00000348
# epoch 20 loss_pde:0.00254629, loss_ic:0.00000770, loss_bd:0.00000437
# epoch 20 loss_pde:0.00253621, loss_ic:0.00000754, loss_bd:0.00000426
# epoch 20 loss_pde:0.00252626, loss_ic:0.00000740, loss_bd:0.00000417
# epoch 20: loss 0.002855
# epoch 21 loss_pde:0.00251664, loss_ic:0.00000727, loss_bd:0.00000411
# epoch 21 loss_pde:0.00250748, loss_ic:0.00000715, loss_bd:0.00000405
# epoch 21 loss_pde:0.00249882, loss_ic:0.00000706, loss_bd:0.00000401
# epoch 21 loss_pde:0.00249073, loss_ic:0.00000697, loss_bd:0.00000397
# epoch 21 loss_pde:0.00248320, loss_ic:0.00000691, loss_bd:0.00000394
# epoch 21 loss_pde:0.00247623, loss_ic:0.00000686, loss_bd:0.00000391
# epoch 21 loss_pde:0.00246976, loss_ic:0.00000682, loss_bd:0.00000389
# epoch 21 loss_pde:0.00246378, loss_ic:0.00000680, loss_bd:0.00000387
# epoch 21 loss_pde:0.00245825, loss_ic:0.00000678, loss_bd:0.00000385
# epoch 21 loss_pde:0.00245308, loss_ic:0.00000678, loss_bd:0.00000382
# epoch 21 loss_pde:0.00244827, loss_ic:0.00000677, loss_bd:0.00000380
# epoch 21 loss_pde:0.00244367, loss_ic:0.00000678, loss_bd:0.00000377
# epoch 21 loss_pde:0.00243942, loss_ic:0.00000679, loss_bd:0.00000374
# epoch 21 loss_pde:0.00243463, loss_ic:0.00000683, loss_bd:0.00000374
# epoch 21 loss_pde:0.00243089, loss_ic:0.00000685, loss_bd:0.00000371
# epoch 21 loss_pde:0.00242728, loss_ic:0.00000687, loss_bd:0.00000369
# epoch 21 loss_pde:0.00242376, loss_ic:0.00000690, loss_bd:0.00000365
# epoch 21 loss_pde:0.00241974, loss_ic:0.00000695, loss_bd:0.00000364
# epoch 21 loss_pde:0.00241600, loss_ic:0.00000698, loss_bd:0.00000359
# epoch 21 loss_pde:0.00241177, loss_ic:0.00000705, loss_bd:0.00000357
# epoch 21: loss 0.002630
# epoch 22 loss_pde:0.00240801, loss_ic:0.00000710, loss_bd:0.00000353
# epoch 22 loss_pde:0.00240407, loss_ic:0.00000716, loss_bd:0.00000351
# epoch 22 loss_pde:0.00239949, loss_ic:0.00000724, loss_bd:0.00000347
# epoch 22 loss_pde:0.00239512, loss_ic:0.00000731, loss_bd:0.00000344
# epoch 22 loss_pde:0.00239027, loss_ic:0.00000740, loss_bd:0.00000341
# epoch 22 loss_pde:0.00238471, loss_ic:0.00000742, loss_bd:0.00000340
# epoch 22 loss_pde:0.00237801, loss_ic:0.00000755, loss_bd:0.00000336
# epoch 22 loss_pde:0.00236998, loss_ic:0.00000764, loss_bd:0.00000341
# epoch 22 loss_pde:0.00236435, loss_ic:0.00000775, loss_bd:0.00000338
# epoch 22 loss_pde:0.00235699, loss_ic:0.00000787, loss_bd:0.00000336
# epoch 22 loss_pde:0.00234717, loss_ic:0.00000803, loss_bd:0.00000334
# epoch 22 loss_pde:0.00233537, loss_ic:0.00000819, loss_bd:0.00000335
# epoch 22 loss_pde:0.00232170, loss_ic:0.00000842, loss_bd:0.00000331
# epoch 22 loss_pde:0.00230868, loss_ic:0.00000862, loss_bd:0.00000332
# epoch 22 loss_pde:0.00229333, loss_ic:0.00000888, loss_bd:0.00000342
# epoch 22 loss_pde:0.00228103, loss_ic:0.00000906, loss_bd:0.00000343
# epoch 22 loss_pde:0.00226773, loss_ic:0.00000920, loss_bd:0.00000344
# epoch 22 loss_pde:0.00225204, loss_ic:0.00000938, loss_bd:0.00000347
# epoch 22 loss_pde:0.00223668, loss_ic:0.00000949, loss_bd:0.00000350
# epoch 22 loss_pde:0.00222056, loss_ic:0.00000964, loss_bd:0.00000354
# epoch 22: loss 0.002514
# epoch 23 loss_pde:0.00220553, loss_ic:0.00000972, loss_bd:0.00000355
# epoch 23 loss_pde:0.00219016, loss_ic:0.00000981, loss_bd:0.00000361
# epoch 23 loss_pde:0.00217624, loss_ic:0.00000987, loss_bd:0.00000359
# epoch 23 loss_pde:0.00216281, loss_ic:0.00000989, loss_bd:0.00000365
# epoch 23 loss_pde:0.00215107, loss_ic:0.00000992, loss_bd:0.00000364
# epoch 23 loss_pde:0.00214025, loss_ic:0.00000991, loss_bd:0.00000369
# epoch 23 loss_pde:0.00213090, loss_ic:0.00000991, loss_bd:0.00000369
# epoch 23 loss_pde:0.00212221, loss_ic:0.00000989, loss_bd:0.00000373
# epoch 23 loss_pde:0.00211462, loss_ic:0.00000988, loss_bd:0.00000374
# epoch 23 loss_pde:0.00210765, loss_ic:0.00000985, loss_bd:0.00000376
# epoch 23 loss_pde:0.00210160, loss_ic:0.00000983, loss_bd:0.00000377
# epoch 23 loss_pde:0.00209608, loss_ic:0.00000980, loss_bd:0.00000379
# epoch 23 loss_pde:0.00209104, loss_ic:0.00000978, loss_bd:0.00000380
# epoch 23 loss_pde:0.00208680, loss_ic:0.00000974, loss_bd:0.00000380
# epoch 23 loss_pde:0.00208324, loss_ic:0.00000971, loss_bd:0.00000382
# epoch 23 loss_pde:0.00208009, loss_ic:0.00000968, loss_bd:0.00000384
# epoch 23 loss_pde:0.00207334, loss_ic:0.00001002, loss_bd:0.00000390
# epoch 23 loss_pde:0.00207124, loss_ic:0.00000997, loss_bd:0.00000391
# epoch 23 loss_pde:0.00206917, loss_ic:0.00000992, loss_bd:0.00000391
# epoch 23 loss_pde:0.00206718, loss_ic:0.00000988, loss_bd:0.00000392
# epoch 23: loss 0.002338
# epoch 24 loss_pde:0.00206523, loss_ic:0.00000984, loss_bd:0.00000393
# epoch 24 loss_pde:0.00206332, loss_ic:0.00000980, loss_bd:0.00000394
# epoch 24 loss_pde:0.00206144, loss_ic:0.00000977, loss_bd:0.00000395
# epoch 24 loss_pde:0.00205955, loss_ic:0.00000974, loss_bd:0.00000395
# epoch 24 loss_pde:0.00205762, loss_ic:0.00000971, loss_bd:0.00000396
# epoch 24 loss_pde:0.00205569, loss_ic:0.00000968, loss_bd:0.00000397
# epoch 24 loss_pde:0.00205371, loss_ic:0.00000966, loss_bd:0.00000398
# epoch 24 loss_pde:0.00205168, loss_ic:0.00000965, loss_bd:0.00000398
# epoch 24 loss_pde:0.00204961, loss_ic:0.00000963, loss_bd:0.00000399
# epoch 24 loss_pde:0.00204748, loss_ic:0.00000962, loss_bd:0.00000400
# epoch 24 loss_pde:0.00204530, loss_ic:0.00000961, loss_bd:0.00000401
# epoch 24 loss_pde:0.00204307, loss_ic:0.00000961, loss_bd:0.00000401
# epoch 24 loss_pde:0.00204076, loss_ic:0.00000961, loss_bd:0.00000402
# epoch 24 loss_pde:0.00203839, loss_ic:0.00000962, loss_bd:0.00000403
# epoch 24 loss_pde:0.00203592, loss_ic:0.00000963, loss_bd:0.00000403
# epoch 24 loss_pde:0.00203336, loss_ic:0.00000964, loss_bd:0.00000404
# epoch 24 loss_pde:0.00203067, loss_ic:0.00000965, loss_bd:0.00000404
# epoch 24 loss_pde:0.00202792, loss_ic:0.00000965, loss_bd:0.00000405
# epoch 24 loss_pde:0.00202110, loss_ic:0.00000988, loss_bd:0.00000406
# epoch 24 loss_pde:0.00201911, loss_ic:0.00000989, loss_bd:0.00000406
# epoch 24: loss 0.002203
# epoch 25 loss_pde:0.00201674, loss_ic:0.00000989, loss_bd:0.00000406
# epoch 25 loss_pde:0.00201382, loss_ic:0.00000990, loss_bd:0.00000405
# epoch 25 loss_pde:0.00201029, loss_ic:0.00000989, loss_bd:0.00000405
# epoch 25 loss_pde:0.00200630, loss_ic:0.00000988, loss_bd:0.00000403
# epoch 25 loss_pde:0.00200188, loss_ic:0.00000987, loss_bd:0.00000401
# epoch 25 loss_pde:0.00199721, loss_ic:0.00000985, loss_bd:0.00000398
# epoch 25 loss_pde:0.00199231, loss_ic:0.00000983, loss_bd:0.00000396
# epoch 25 loss_pde:0.00198725, loss_ic:0.00000981, loss_bd:0.00000392
# epoch 25 loss_pde:0.00198241, loss_ic:0.00000978, loss_bd:0.00000388
# epoch 25 loss_pde:0.00197762, loss_ic:0.00000975, loss_bd:0.00000385
# epoch 25 loss_pde:0.00197282, loss_ic:0.00000972, loss_bd:0.00000381
# epoch 25 loss_pde:0.00196809, loss_ic:0.00000969, loss_bd:0.00000378
# epoch 25 loss_pde:0.00196343, loss_ic:0.00000966, loss_bd:0.00000374
# epoch 25 loss_pde:0.00195893, loss_ic:0.00000964, loss_bd:0.00000371
# epoch 25 loss_pde:0.00195439, loss_ic:0.00000961, loss_bd:0.00000368
# epoch 25 loss_pde:0.00195002, loss_ic:0.00000961, loss_bd:0.00000365
# epoch 25 loss_pde:0.00194608, loss_ic:0.00000956, loss_bd:0.00000365
# epoch 25 loss_pde:0.00194234, loss_ic:0.00000958, loss_bd:0.00000362
# epoch 25 loss_pde:0.00193707, loss_ic:0.00000972, loss_bd:0.00000384
# epoch 25 loss_pde:0.00193448, loss_ic:0.00000972, loss_bd:0.00000379
# epoch 25: loss 0.002156
# epoch 26 loss_pde:0.00193212, loss_ic:0.00000972, loss_bd:0.00000374
# epoch 26 loss_pde:0.00192961, loss_ic:0.00000974, loss_bd:0.00000370
# epoch 26 loss_pde:0.00192728, loss_ic:0.00000975, loss_bd:0.00000366
# epoch 26 loss_pde:0.00192487, loss_ic:0.00000978, loss_bd:0.00000363
# epoch 26 loss_pde:0.00192261, loss_ic:0.00000980, loss_bd:0.00000361
# epoch 26 loss_pde:0.00192029, loss_ic:0.00000984, loss_bd:0.00000358
# epoch 26 loss_pde:0.00191814, loss_ic:0.00000988, loss_bd:0.00000356
# epoch 26 loss_pde:0.00191599, loss_ic:0.00000992, loss_bd:0.00000355
# epoch 26 loss_pde:0.00191398, loss_ic:0.00000996, loss_bd:0.00000354
# epoch 26 loss_pde:0.00191197, loss_ic:0.00001001, loss_bd:0.00000353
# epoch 26 loss_pde:0.00191007, loss_ic:0.00001005, loss_bd:0.00000352
# epoch 26 loss_pde:0.00190822, loss_ic:0.00001010, loss_bd:0.00000351
# epoch 26 loss_pde:0.00190645, loss_ic:0.00001013, loss_bd:0.00000351
# epoch 26 loss_pde:0.00190470, loss_ic:0.00001018, loss_bd:0.00000351
# epoch 26 loss_pde:0.00190303, loss_ic:0.00001021, loss_bd:0.00000351
# epoch 26 loss_pde:0.00190139, loss_ic:0.00001024, loss_bd:0.00000351
# epoch 26 loss_pde:0.00189980, loss_ic:0.00001027, loss_bd:0.00000351
# epoch 26 loss_pde:0.00189824, loss_ic:0.00001030, loss_bd:0.00000351
# epoch 26 loss_pde:0.00189668, loss_ic:0.00001032, loss_bd:0.00000351
# epoch 26 loss_pde:0.00189513, loss_ic:0.00001034, loss_bd:0.00000352
# epoch 26: loss 0.002067
# epoch 27 loss_pde:0.00189357, loss_ic:0.00001035, loss_bd:0.00000352
# epoch 27 loss_pde:0.00189200, loss_ic:0.00001036, loss_bd:0.00000353
# epoch 27 loss_pde:0.00189042, loss_ic:0.00001036, loss_bd:0.00000354
# epoch 27 loss_pde:0.00188881, loss_ic:0.00001036, loss_bd:0.00000354
# epoch 27 loss_pde:0.00188715, loss_ic:0.00001036, loss_bd:0.00000355
# epoch 27 loss_pde:0.00188546, loss_ic:0.00001034, loss_bd:0.00000356
# epoch 27 loss_pde:0.00188363, loss_ic:0.00001032, loss_bd:0.00000357
# epoch 27 loss_pde:0.00188181, loss_ic:0.00001029, loss_bd:0.00000358
# epoch 27 loss_pde:0.00187989, loss_ic:0.00001026, loss_bd:0.00000360
# epoch 27 loss_pde:0.00187803, loss_ic:0.00001022, loss_bd:0.00000361
# epoch 27 loss_pde:0.00187604, loss_ic:0.00001018, loss_bd:0.00000362
# epoch 27 loss_pde:0.00187416, loss_ic:0.00001012, loss_bd:0.00000364
# epoch 27 loss_pde:0.00187176, loss_ic:0.00001006, loss_bd:0.00000367
# epoch 27 loss_pde:0.00187013, loss_ic:0.00001000, loss_bd:0.00000368
# epoch 27 loss_pde:0.00186833, loss_ic:0.00000993, loss_bd:0.00000369
# epoch 27 loss_pde:0.00186648, loss_ic:0.00000983, loss_bd:0.00000370
# epoch 27 loss_pde:0.00186265, loss_ic:0.00000979, loss_bd:0.00000374
# epoch 27 loss_pde:0.00186109, loss_ic:0.00000971, loss_bd:0.00000374
# epoch 27 loss_pde:0.00185910, loss_ic:0.00000958, loss_bd:0.00000377
# epoch 27 loss_pde:0.00185691, loss_ic:0.00000947, loss_bd:0.00000377
# epoch 27: loss 0.002032
# epoch 28 loss_pde:0.00185496, loss_ic:0.00000931, loss_bd:0.00000378
# epoch 28 loss_pde:0.00185212, loss_ic:0.00000919, loss_bd:0.00000377
# epoch 28 loss_pde:0.00184994, loss_ic:0.00000903, loss_bd:0.00000377
# epoch 28 loss_pde:0.00184761, loss_ic:0.00000889, loss_bd:0.00000376
# epoch 28 loss_pde:0.00184532, loss_ic:0.00000873, loss_bd:0.00000374
# epoch 28 loss_pde:0.00184286, loss_ic:0.00000856, loss_bd:0.00000373
# epoch 28 loss_pde:0.00184047, loss_ic:0.00000839, loss_bd:0.00000370
# epoch 28 loss_pde:0.00183801, loss_ic:0.00000823, loss_bd:0.00000369
# epoch 28 loss_pde:0.00183571, loss_ic:0.00000806, loss_bd:0.00000366
# epoch 28 loss_pde:0.00183342, loss_ic:0.00000790, loss_bd:0.00000364
# epoch 28 loss_pde:0.00183131, loss_ic:0.00000775, loss_bd:0.00000361
# epoch 28 loss_pde:0.00182923, loss_ic:0.00000761, loss_bd:0.00000359
# epoch 28 loss_pde:0.00182735, loss_ic:0.00000747, loss_bd:0.00000356
# epoch 28 loss_pde:0.00182547, loss_ic:0.00000734, loss_bd:0.00000355
# epoch 28 loss_pde:0.00182403, loss_ic:0.00000718, loss_bd:0.00000354
# epoch 28 loss_pde:0.00182263, loss_ic:0.00000708, loss_bd:0.00000353
# epoch 28 loss_pde:0.00182116, loss_ic:0.00000699, loss_bd:0.00000351
# epoch 28 loss_pde:0.00181915, loss_ic:0.00000689, loss_bd:0.00000353
# epoch 28 loss_pde:0.00181772, loss_ic:0.00000671, loss_bd:0.00000352
# epoch 28 loss_pde:0.00181635, loss_ic:0.00000663, loss_bd:0.00000352
# epoch 28: loss 0.001986
# epoch 29 loss_pde:0.00181522, loss_ic:0.00000655, loss_bd:0.00000351
# epoch 29 loss_pde:0.00181250, loss_ic:0.00000660, loss_bd:0.00000350
# epoch 29 loss_pde:0.00181153, loss_ic:0.00000654, loss_bd:0.00000350
# epoch 29 loss_pde:0.00181037, loss_ic:0.00000648, loss_bd:0.00000349
# epoch 29 loss_pde:0.00180898, loss_ic:0.00000641, loss_bd:0.00000348
# epoch 29 loss_pde:0.00180742, loss_ic:0.00000634, loss_bd:0.00000347
# epoch 29 loss_pde:0.00180579, loss_ic:0.00000628, loss_bd:0.00000346
# epoch 29 loss_pde:0.00180405, loss_ic:0.00000622, loss_bd:0.00000345
# epoch 29 loss_pde:0.00180225, loss_ic:0.00000616, loss_bd:0.00000344
# epoch 29 loss_pde:0.00180038, loss_ic:0.00000611, loss_bd:0.00000343
# epoch 29 loss_pde:0.00179846, loss_ic:0.00000607, loss_bd:0.00000342
# epoch 29 loss_pde:0.00179654, loss_ic:0.00000603, loss_bd:0.00000341
# epoch 29 loss_pde:0.00179460, loss_ic:0.00000600, loss_bd:0.00000339
# epoch 29 loss_pde:0.00179269, loss_ic:0.00000598, loss_bd:0.00000338
# epoch 29 loss_pde:0.00179080, loss_ic:0.00000597, loss_bd:0.00000337
# epoch 29 loss_pde:0.00178890, loss_ic:0.00000597, loss_bd:0.00000336
# epoch 29 loss_pde:0.00178707, loss_ic:0.00000597, loss_bd:0.00000335
# epoch 29 loss_pde:0.00178502, loss_ic:0.00000600, loss_bd:0.00000333
# epoch 29 loss_pde:0.00178315, loss_ic:0.00000600, loss_bd:0.00000332
# epoch 29 loss_pde:0.00178117, loss_ic:0.00000607, loss_bd:0.00000328
# epoch 29: loss 0.001916
# epoch 30 loss_pde:0.00177962, loss_ic:0.00000609, loss_bd:0.00000327
# epoch 30 loss_pde:0.00177812, loss_ic:0.00000611, loss_bd:0.00000326
# epoch 30 loss_pde:0.00177652, loss_ic:0.00000614, loss_bd:0.00000325
# epoch 30 loss_pde:0.00177484, loss_ic:0.00000617, loss_bd:0.00000323
# epoch 30 loss_pde:0.00177305, loss_ic:0.00000621, loss_bd:0.00000321
# epoch 30 loss_pde:0.00177091, loss_ic:0.00000628, loss_bd:0.00000319
# epoch 30 loss_pde:0.00176887, loss_ic:0.00000632, loss_bd:0.00000317
# epoch 30 loss_pde:0.00176610, loss_ic:0.00000642, loss_bd:0.00000313
# epoch 30 loss_pde:0.00176410, loss_ic:0.00000646, loss_bd:0.00000311
# epoch 30 loss_pde:0.00176175, loss_ic:0.00000651, loss_bd:0.00000308
# epoch 30 loss_pde:0.00175883, loss_ic:0.00000656, loss_bd:0.00000305
# epoch 30 loss_pde:0.00175587, loss_ic:0.00000662, loss_bd:0.00000300
# epoch 30 loss_pde:0.00175286, loss_ic:0.00000666, loss_bd:0.00000297
# epoch 30 loss_pde:0.00174953, loss_ic:0.00000672, loss_bd:0.00000292
# epoch 30 loss_pde:0.00174621, loss_ic:0.00000674, loss_bd:0.00000288
# epoch 30 loss_pde:0.00174286, loss_ic:0.00000678, loss_bd:0.00000284
# epoch 30 loss_pde:0.00173983, loss_ic:0.00000679, loss_bd:0.00000280
# epoch 30 loss_pde:0.00173677, loss_ic:0.00000681, loss_bd:0.00000277
# epoch 30 loss_pde:0.00173425, loss_ic:0.00000681, loss_bd:0.00000274
# epoch 30 loss_pde:0.00173203, loss_ic:0.00000676, loss_bd:0.00000271
# epoch 30: loss 0.001873
# epoch 31 loss_pde:0.00172844, loss_ic:0.00000678, loss_bd:0.00000269
# epoch 31 loss_pde:0.00172633, loss_ic:0.00000676, loss_bd:0.00000268
# epoch 31 loss_pde:0.00172369, loss_ic:0.00000677, loss_bd:0.00000268
# epoch 31 loss_pde:0.00172181, loss_ic:0.00000674, loss_bd:0.00000268
# epoch 31 loss_pde:0.00171987, loss_ic:0.00000672, loss_bd:0.00000267
# epoch 31 loss_pde:0.00171794, loss_ic:0.00000668, loss_bd:0.00000268
# epoch 31 loss_pde:0.00171604, loss_ic:0.00000664, loss_bd:0.00000268
# epoch 31 loss_pde:0.00171408, loss_ic:0.00000660, loss_bd:0.00000269
# epoch 31 loss_pde:0.00171226, loss_ic:0.00000655, loss_bd:0.00000270
# epoch 31 loss_pde:0.00171035, loss_ic:0.00000651, loss_bd:0.00000271
# epoch 31 loss_pde:0.00170862, loss_ic:0.00000645, loss_bd:0.00000273
# epoch 31 loss_pde:0.00170686, loss_ic:0.00000641, loss_bd:0.00000275
# epoch 31 loss_pde:0.00170524, loss_ic:0.00000636, loss_bd:0.00000277
# epoch 31 loss_pde:0.00170347, loss_ic:0.00000632, loss_bd:0.00000279
# epoch 31 loss_pde:0.00170185, loss_ic:0.00000627, loss_bd:0.00000281
# epoch 31 loss_pde:0.00170005, loss_ic:0.00000623, loss_bd:0.00000283
# epoch 31 loss_pde:0.00169835, loss_ic:0.00000618, loss_bd:0.00000286
# epoch 31 loss_pde:0.00169638, loss_ic:0.00000614, loss_bd:0.00000288
# epoch 31 loss_pde:0.00169449, loss_ic:0.00000609, loss_bd:0.00000291
# epoch 31 loss_pde:0.00169228, loss_ic:0.00000606, loss_bd:0.00000293
# epoch 31: loss 0.001823
# epoch 32 loss_pde:0.00168960, loss_ic:0.00000602, loss_bd:0.00000295
# epoch 32 loss_pde:0.00168676, loss_ic:0.00000598, loss_bd:0.00000297
# epoch 32 loss_pde:0.00168343, loss_ic:0.00000592, loss_bd:0.00000303
# epoch 32 loss_pde:0.00168114, loss_ic:0.00000588, loss_bd:0.00000305
# epoch 32 loss_pde:0.00167779, loss_ic:0.00000586, loss_bd:0.00000306
# epoch 32 loss_pde:0.00167456, loss_ic:0.00000583, loss_bd:0.00000309
# epoch 32 loss_pde:0.00167069, loss_ic:0.00000585, loss_bd:0.00000306
# epoch 32 loss_pde:0.00166720, loss_ic:0.00000582, loss_bd:0.00000307
# epoch 32 loss_pde:0.00166231, loss_ic:0.00000584, loss_bd:0.00000308
# epoch 32 loss_pde:0.00165856, loss_ic:0.00000580, loss_bd:0.00000309
# epoch 32 loss_pde:0.00165464, loss_ic:0.00000577, loss_bd:0.00000308
# epoch 32 loss_pde:0.00165056, loss_ic:0.00000568, loss_bd:0.00000309
# epoch 32 loss_pde:0.00164544, loss_ic:0.00000569, loss_bd:0.00000304
# epoch 32 loss_pde:0.00164131, loss_ic:0.00000564, loss_bd:0.00000302
# epoch 32 loss_pde:0.00163673, loss_ic:0.00000565, loss_bd:0.00000296
# epoch 32 loss_pde:0.00163299, loss_ic:0.00000561, loss_bd:0.00000293
# epoch 32 loss_pde:0.00162935, loss_ic:0.00000558, loss_bd:0.00000289
# epoch 32 loss_pde:0.00162563, loss_ic:0.00000551, loss_bd:0.00000287
# epoch 32 loss_pde:0.00162201, loss_ic:0.00000550, loss_bd:0.00000281
# epoch 32 loss_pde:0.00161892, loss_ic:0.00000550, loss_bd:0.00000276
# epoch 32: loss 0.001779
# epoch 33 loss_pde:0.00161583, loss_ic:0.00000550, loss_bd:0.00000270
# epoch 33 loss_pde:0.00161279, loss_ic:0.00000551, loss_bd:0.00000264
# epoch 33 loss_pde:0.00160993, loss_ic:0.00000551, loss_bd:0.00000258
# epoch 33 loss_pde:0.00160690, loss_ic:0.00000554, loss_bd:0.00000252
# epoch 33 loss_pde:0.00160412, loss_ic:0.00000556, loss_bd:0.00000246
# epoch 33 loss_pde:0.00160133, loss_ic:0.00000560, loss_bd:0.00000239
# epoch 33 loss_pde:0.00159882, loss_ic:0.00000562, loss_bd:0.00000234
# epoch 33 loss_pde:0.00159619, loss_ic:0.00000568, loss_bd:0.00000227
# epoch 33 loss_pde:0.00159395, loss_ic:0.00000571, loss_bd:0.00000222
# epoch 33 loss_pde:0.00159152, loss_ic:0.00000572, loss_bd:0.00000217
# epoch 33 loss_pde:0.00158886, loss_ic:0.00000573, loss_bd:0.00000212
# epoch 33 loss_pde:0.00158579, loss_ic:0.00000574, loss_bd:0.00000206
# epoch 33 loss_pde:0.00158262, loss_ic:0.00000572, loss_bd:0.00000202
# epoch 33 loss_pde:0.00157923, loss_ic:0.00000572, loss_bd:0.00000196
# epoch 33 loss_pde:0.00157629, loss_ic:0.00000568, loss_bd:0.00000193
# epoch 33 loss_pde:0.00158292, loss_ic:0.00000591, loss_bd:0.00000225
# epoch 33 loss_pde:0.00157888, loss_ic:0.00000581, loss_bd:0.00000218
# epoch 33 loss_pde:0.00157528, loss_ic:0.00000571, loss_bd:0.00000212
# epoch 33 loss_pde:0.00157209, loss_ic:0.00000561, loss_bd:0.00000207
# epoch 33 loss_pde:0.00156928, loss_ic:0.00000552, loss_bd:0.00000203
# epoch 33: loss 0.001698
# epoch 34 loss_pde:0.00156681, loss_ic:0.00000543, loss_bd:0.00000200
# epoch 34 loss_pde:0.00156466, loss_ic:0.00000534, loss_bd:0.00000197
# epoch 34 loss_pde:0.00156280, loss_ic:0.00000526, loss_bd:0.00000195
# epoch 34 loss_pde:0.00156108, loss_ic:0.00000518, loss_bd:0.00000194
# epoch 34 loss_pde:0.00156033, loss_ic:0.00000507, loss_bd:0.00000189
# epoch 34 loss_pde:0.00155909, loss_ic:0.00000501, loss_bd:0.00000189
# epoch 34 loss_pde:0.00155798, loss_ic:0.00000495, loss_bd:0.00000189
# epoch 34 loss_pde:0.00155699, loss_ic:0.00000490, loss_bd:0.00000189
# epoch 34 loss_pde:0.00155605, loss_ic:0.00000485, loss_bd:0.00000190
# epoch 34 loss_pde:0.00155522, loss_ic:0.00000480, loss_bd:0.00000190
# epoch 34 loss_pde:0.00155435, loss_ic:0.00000476, loss_bd:0.00000191
# epoch 34 loss_pde:0.00155368, loss_ic:0.00000471, loss_bd:0.00000191
# epoch 34 loss_pde:0.00155291, loss_ic:0.00000467, loss_bd:0.00000192
# epoch 34 loss_pde:0.00155211, loss_ic:0.00000464, loss_bd:0.00000194
# epoch 34 loss_pde:0.00155124, loss_ic:0.00000460, loss_bd:0.00000195
# epoch 34 loss_pde:0.00155021, loss_ic:0.00000457, loss_bd:0.00000197
# epoch 34 loss_pde:0.00154922, loss_ic:0.00000453, loss_bd:0.00000199
# epoch 34 loss_pde:0.00154807, loss_ic:0.00000451, loss_bd:0.00000201
# epoch 34 loss_pde:0.00154692, loss_ic:0.00000448, loss_bd:0.00000204
# epoch 34 loss_pde:0.00154565, loss_ic:0.00000445, loss_bd:0.00000207
# epoch 34: loss 0.001641
# epoch 35 loss_pde:0.00154425, loss_ic:0.00000444, loss_bd:0.00000209
# epoch 35 loss_pde:0.00154274, loss_ic:0.00000441, loss_bd:0.00000213
# epoch 35 loss_pde:0.00154117, loss_ic:0.00000440, loss_bd:0.00000216
# epoch 35 loss_pde:0.00153935, loss_ic:0.00000437, loss_bd:0.00000221
# epoch 35 loss_pde:0.00153766, loss_ic:0.00000435, loss_bd:0.00000225
# epoch 35 loss_pde:0.00153531, loss_ic:0.00000434, loss_bd:0.00000229
# ...
# epoch 742 loss_pde:0.00007808, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742 loss_pde:0.00007808, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742 loss_pde:0.00007808, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742 loss_pde:0.00007808, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742 loss_pde:0.00007808, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742 loss_pde:0.00007808, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742 loss_pde:0.00007808, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742 loss_pde:0.00007807, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742 loss_pde:0.00007807, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742 loss_pde:0.00007807, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 742: loss 0.000081
# epoch 743 loss_pde:0.00007807, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007807, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007807, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007807, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007807, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007806, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007806, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007806, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007806, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007806, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007806, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007805, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007805, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007805, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007805, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007805, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007804, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007804, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007804, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 743 loss_pde:0.00007804, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 743: loss 0.000081
# epoch 744 loss_pde:0.00007803, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 744 loss_pde:0.00007803, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 744 loss_pde:0.00007803, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 744: loss 0.000081
# epoch 745 loss_pde:0.00007803, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 745 loss_pde:0.00007802, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 745 loss_pde:0.00007802, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 745 loss_pde:0.00007802, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 745 loss_pde:0.00007801, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 745 loss_pde:0.00007801, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 745 loss_pde:0.00007801, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 745 loss_pde:0.00007800, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 745: loss 0.000081
# epoch 746 loss_pde:0.00007800, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 746 loss_pde:0.00007800, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 746 loss_pde:0.00007800, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 746 loss_pde:0.00007799, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 746 loss_pde:0.00007799, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 746 loss_pde:0.00007798, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 746 loss_pde:0.00007797, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 746: loss 0.000081
# epoch 747 loss_pde:0.00007797, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 747 loss_pde:0.00007797, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 747 loss_pde:0.00007796, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 747: loss 0.000081
# epoch 748 loss_pde:0.00007796, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 748 loss_pde:0.00007796, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 748 loss_pde:0.00007795, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 748 loss_pde:0.00007795, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 748 loss_pde:0.00007794, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 748 loss_pde:0.00007794, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 748 loss_pde:0.00007793, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 748: loss 0.000081
# epoch 749 loss_pde:0.00007793, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007792, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007791, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007791, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007790, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007789, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007788, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007787, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007786, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007786, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007785, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007784, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007783, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007783, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007782, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007782, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007781, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007780, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007780, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749 loss_pde:0.00007779, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 749: loss 0.000081
# epoch 750 loss_pde:0.00007779, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007779, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007778, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007778, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007778, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007777, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007777, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007777, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007777, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007776, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007776, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007776, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007776, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007776, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007776, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007775, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007775, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007775, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007775, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750 loss_pde:0.00007775, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 750: loss 0.000081
# epoch 751 loss_pde:0.00007775, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007775, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007775, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007775, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007774, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007774, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007774, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007774, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007773, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007773, loss_ic:0.00000018, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007773, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007773, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007772, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007772, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007772, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007772, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007771, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007771, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007771, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751 loss_pde:0.00007771, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 751: loss 0.000081
# epoch 752 loss_pde:0.00007771, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007771, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007771, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007771, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007770, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007770, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007770, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007770, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007770, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007770, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007769, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007769, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007769, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752 loss_pde:0.00007769, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 752: loss 0.000081
# epoch 753 loss_pde:0.00007769, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007768, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007768, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007767, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007767, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007766, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007765, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007764, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007763, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007762, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007761, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007760, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007759, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007758, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007757, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007756, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007755, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007754, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007753, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753 loss_pde:0.00007753, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 753: loss 0.000081
# epoch 754 loss_pde:0.00007752, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007751, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007751, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007750, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007750, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007749, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007749, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007749, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007748, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007748, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007748, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754 loss_pde:0.00007748, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 754: loss 0.000080
# epoch 755 loss_pde:0.00007748, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 755 loss_pde:0.00007747, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 755 loss_pde:0.00007747, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 755 loss_pde:0.00007747, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 755 loss_pde:0.00007747, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 755 loss_pde:0.00007746, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 755 loss_pde:0.00007746, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 755 loss_pde:0.00007746, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 755: loss 0.000080
# epoch 756 loss_pde:0.00007746, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 756 loss_pde:0.00007746, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 756 loss_pde:0.00007745, loss_ic:0.00000017, loss_bd:0.00000012
# epoch 756 loss_pde:0.00007745, loss_ic:0.00000017, loss_bd:0.00000012
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [187], in <module>
#       3 tic = time.time()
#       4 for epoch in range(1, epochs+1):
# ----> 5     train(epoch)
#       7 toc = time.time()
#
# Input In [117], in train(epoch)
#      36     loss.backward()
#      37     return loss
# ---> 39 loss = optimizer.step(closure)
#      40 loss_value = loss.item() if not isinstance(loss, float) else loss
#      41 print(f'epoch {epoch}: loss {loss_value:.6f}')
#
# File ~/.local/lib/python3.8/site-packages/torch/optim/optimizer.py:88, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#      86 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87 with torch.autograd.profiler.record_function(profile_name):
# ---> 88     return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/grad_mode.py:28, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      25 @functools.wraps(func)
#      26 def decorate_context(*args, **kwargs):
#      27     with self.__class__():
# ---> 28         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/optim/lbfgs.py:437, in LBFGS.step(self, closure)
#     432 if n_iter != max_iter:
#     433     # re-evaluate function only if not in last iteration
#     434     # the reason we do this: in a stochastic setting,
#     435     # no use to re-evaluate that function here
#     436     with torch.enable_grad():
# --> 437         loss = float(closure())
#     438     flat_grad = self._gather_flat_grad()
#     439     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/grad_mode.py:28, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      25 @functools.wraps(func)
#      26 def decorate_context(*args, **kwargs):
#      27     with self.__class__():
# ---> 28         return func(*args, **kwargs)
#
# Input In [117], in train.<locals>.closure()
#      31 print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f}, loss_bd:{loss_bd:.8f}')
#      32 #model.it = model.it + 1
#      33 #outputfile = open('loss_history_burgers.dat','a+')
#      34 #print(f'{model.it}  {loss_pde:.6f}  {loss_ic:.6f}  {loss:.6f}',file=outputfile)
#      35 #outputfile.close()
# ---> 36 loss.backward()
#      37 return loss
#
# File ~/.local/lib/python3.8/site-packages/torch/_tensor.py:307, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     298 if has_torch_function_unary(self):
#     299     return handle_torch_function(
#     300         Tensor.backward,
#     301         (self,),
#    (...)
#     305         create_graph=create_graph,
#     306         inputs=inputs)
# --> 307 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py:154, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     151 if retain_graph is None:
#     152     retain_graph = create_graph
# --> 154 Variable._execution_engine.run_backward(
#     155     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
    len(x_ic_memory)
# Out:
# 1000

# %%
x_bdR

# %%
device1 = torch.device("cpu")
torch.save(model,'AC_global.pt')

# %%
model_path = 'AC_global.pt'
model = torch.load(model_path, map_location=torch.device('cpu'))
model = model.to(device)

# %%
plt.figure()
plt.scatter(x_int_overt[:,0],x_int_overt[:,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [111], in <module>
#       1 plt.figure()
# ----> 2 plt.scatter(x_int_overt[:,0],x_int_overt[:,1])
#       3 plt.show()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2807, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2802 @_copy_docstring_and_deprecators(Axes.scatter)
#    2803 def scatter(
#    2804         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2810         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2811         **({"data": data} if data is not None else {}), **kwargs)
#    2812     sci(__ret)
#    2813     return __ret
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py:4366, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4363 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4364 # np.ma.ravel yields an ndarray, not a masked array,
#    4365 # unless its argument is a masked array.
# -> 4366 x = np.ma.ravel(x)
#    4367 y = np.ma.ravel(y)
#    4368 if x.size != y.size:
#
# File ~/.local/lib/python3.8/site-packages/numpy/ma/core.py:6770, in _frommethod.__call__(self, a, *args, **params)
#    6767     args = list(args)
#    6768     a, args[0] = args[0], a
# -> 6770 marr = asanyarray(a)
#    6771 method_name = self.__name__
#    6772 method = getattr(type(marr), method_name, None)
#
# File ~/.local/lib/python3.8/site-packages/numpy/ma/core.py:8002, in asanyarray(a, dtype)
#    8000 if isinstance(a, MaskedArray) and (dtype is None or dtype == a.dtype):
#    8001     return a
# -> 8002 return masked_array(a, dtype=dtype, copy=False, keep_mask=True, subok=True)
#
# File ~/.local/lib/python3.8/site-packages/numpy/ma/core.py:2829, in MaskedArray.__new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order)
#    2820 """
#    2821 Create a new masked array from scratch.
#    2822
#    (...)
#    2826
#    2827 """
#    2828 # Process data.
# -> 2829 _data = np.array(data, dtype=dtype, copy=copy,
#    2830                  order=order, subok=True, ndmin=ndmin)
#    2831 _baseclass = getattr(data, '_baseclass', type(_data))
#    2832 # Check that we're not erasing the mask.
#
# File ~/.local/lib/python3.8/site-packages/torch/_tensor.py:678, in Tensor.__array__(self, dtype)
#     676     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     677 if dtype is None:
# --> 678     return self.numpy()
#     679 else:
#     680     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
data = scipy.io.loadmat('AC.mat')

t = data['tt'].flatten()[:,None]
x_e = data['x'].flatten()[:,None]
Exact = data['uu']
Exact_u = np.real(Exact)

# %%
Nd = 400
x = np.linspace(-1, 1, 400)                                  
t = np.linspace(0, 1, 400)                                        
t_grid, x_grid = np.meshgrid(t, x)                              
T = t_grid.flatten()[:, None]                                   
X = x_grid.flatten()[:, None]                                   
x_test = np.hstack((T, X))                                      
x_test = torch.tensor(x_test, requires_grad=True, dtype=torch.float32).to(device)
u = to_numpy(model(x_test))
#res = to_numpy(model.res_pde(x_test))
#d   = to_numpy(model.lambda_pde(x_test))
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,0]
#loss = model.loss_pde(x_test)                                 

import matplotlib.pyplot as plt
plt.figure()
plt.figure()
plt.contourf(t_grid[:,:],x_grid[:,:],ue,60)
#plt.plot(x[:],u_pred[:,0])
plt.show()

# %%
Nd = 200
x = np.linspace(-1, 1, 512)                                  
t = np.linspace(1.0, 1.0, 1)                                        
t_grid, x_grid = np.meshgrid(t, x)                              
T = t_grid.flatten()[:, None]                                   
X = x_grid.flatten()[:, None]                                   
x_test = np.hstack((T, X))                                      
x_test = torch.tensor(x_test, requires_grad=True, dtype=torch.float32).to(device)
u = to_numpy(model(x_test))
#res = to_numpy(model.res_pde(x_test))
#d   = to_numpy(model.lambda_pde(x_test))

import matplotlib.pyplot as plt
plt.figure()
plt.plot(x[:],u[:,0])
plt.plot(x[:],Exact_u[:,200])
plt.show()

# %%
#x_in = np.zeros((512,2))
#for i in range(500):
#    x_in[i,0] = 1
#    x_in[i,1] = x[i]
#    
#x_test = torch.tensor(x_in, requires_grad=True, dtype=torch.float64).to(device)
#u = to_numpy(model(x_test))

err = 0
for i in range(512):
    err=err + (u[i,0] - Exact_u[i,100])**2

err = err/512

# %%
err
# Out:
# 0.00027237189040258346

# %%
plt.scatter(x[:],1/d[:,0])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [130], in <module>
# ----> 1 plt.scatter(x[:],1/d[:,0])
#       3 plt.show()
#
# NameError: name 'd' is not defined

# %%
file = open("AC_Time_And_Space_Sweep.dat", "w+")
for i in range(u.shape[0]):
    print(f'{x[i]}  {u[i,0]} ',file=file)
file.close()

# %%
new_array = np.array(res[:,0])
file = open("burgers_res_w_5000.dat", "w+")
for i in range(u_pred.shape[0]):
    print(f'{x_test}  {res[i,0]} ',file=file)
file.close()

# %%
file = open("burgers_d_w_14931.dat", "w+")
for i in range(d.shape[0]):
    print(f'{x[i]}  {1/d[i,0]} ',file=file)
file.close()
