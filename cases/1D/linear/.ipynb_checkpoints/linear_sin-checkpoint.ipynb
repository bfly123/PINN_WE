# %% [markdown]
# # Burgers equation
#
# This code is modified from the code https://github.com/alexpapados/Physics-Informed-Deep-Learning-Solid-and-Fluid-Mechanics
#
# The paper about this work can ref https://www.researchgate.net/publication/359480166_Discontinuity_Computing_with_Physics-Informed_Neural_Network

# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
torch.manual_seed(124)
np.random.seed(124)

# %%
def train(epoch):
    model.train()
    model.it = epoch
    def closure():
        optimizer.zero_grad()                                              
        loss_pde = model.loss_pde(x_int,mark)                                   
        loss_ic = model.loss_ic(x_ic, u_ic,mark_ic)  
        loss_bd = model.loss_bd(x_bdL,u_bdL_in,mark_bd) +model.loss_bd(x_bdR,u_bdR_in,mark_bd) 
        #loss_bd = model.loss_bd1(x_bdL,x_bdR,mark_bd) #+model.loss_bd(x_bdR,u_bdR_in,mark_bd) 
        loss = loss_pde + 10*(loss_ic+loss_bd)                                       

        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f}')
        #model.it = model.it + 1
        #outputfile = open('loss_history_burgers.dat','a+')
        #print(f'{model.it}  {loss_pde:.6f}  {loss_ic:.6f}  {loss:.6f}',file=outputfile)
        #outputfile.close() 
        loss.backward()
        return loss

    loss = optimizer.step(closure)
    loss_value = loss.item() if not isinstance(loss, float) else loss
    print(f'epoch {epoch}: loss {loss_value:.6f}')
    
def gradients(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

def to_numpy(input):
    if isinstance(input, torch.Tensor):
        return input.detach().cpu().numpy()
    elif isinstance(input, np.ndarray):
        return input
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                        'np.ndarray, but got {}'.format(type(input)))

def IC(x):
    N = len(x)
    u_init = np.zeros((x.shape[0]))                                                
    for i in range(N):
        u_init[i] = np.sin(np.pi*(x[i,1]))
    return u_init

class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.net = nn.Sequential()                                                  
        self.net.add_module('Linear_layer_1', nn.Linear(2, 30))                     
        self.net.add_module('Tanh_layer_1', nn.Tanh())                              

        for num in range(2, 5):                                                     
            self.net.add_module('Linear_layer_%d' % (num), nn.Linear(30, 30))       
            self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 
        self.net.add_module('Linear_layer_final', nn.Linear(30, 1))                 

    def forward(self, x):
        return self.net(x)

    def loss_pde(self, x,mark):
        y = self.net(x)                                                
        u = y[:, 0:1]
        

        du_g = gradients(u, x)[0]                                 
        u_t,u_x = du_g[:, :1],du_g[:,1:]
      #  d = 0.1*(abs(u_x)-u_x) + 1
        d = 1
        f = ((mark*(u_t - u_x))**2).mean() 
         
        return f
    def res_pde(self,x):
        y = self.net(x)
        Res = np.zeros((x.shape[0]))                                  
        
        u = y[:, 0:1]
        du_g = gradients(u, x)[0]                                  
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        Res = (u_t - u_x)**2 
        return Res 
    
    def lambda_pde(self,x):
        y = self.net(x)
        Res = np.zeros((x.shape[0]))                                  
        
        u = y[:, 0:1]
        du_g = gradients(u, x)[0]                                  
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        d = 0.1*(abs(u_x)-u_x) + 1
        return  d

    def loss_ic(self, x_ic, u_ic,mark_ic):
        y_ic = self.net(x_ic)                                                      
        u_ic_nn = y_ic[:, 0]
        loss_ics = ((mark_ic*(u_ic_nn - u_ic)) ** 2).mean()
        return loss_ics
    def loss_bd(self, x_bd,u_bd_in,mark_bd):
        y_bd = self.net(x_bd)                                                      
        u_bd = y_bd[:, 0]
        loss_bds = (((u_bd - u_bd_in)) ** 2).mean()
        return loss_bds
    def loss_bd1(self, x_bdL,x_bdR,mark_bd):
        y_bdL = self.net(x_bdL)                                                      
        y_bdR = self.net(x_bdR)                                                      
        loss_bds = (((y_bdL[:,0] - y_bdR[:,0])) ** 2).mean()
        return loss_bds
def BD_perid(X,T,N):
    xL = np.zeros((N,2)) 
    xR = np.zeros((N,2)) 
    
    for i in range(N):
        t = T*(i+1)/N
        xL[i,0] = t
        xL[i,1] = 0
        xR[i,0] = t
        xR[i,1] = X
    return xL,xR
def BD(X):
    N =X.shape[0]
    u = np.zeros((N,1)) 
    
    for i in range(N):
        x = X[i,1]
        t = X[i,0]
        u[i,0] =  np.sin(np.pi*(x+t))
    return u
def Mark(x):
    N =x.shape[0]
    mark = np.zeros((N,1)) 
    
    for i in range(N):
        if (x[i,0] < 0 ):
            mark[i,0] = 1.0
        elif ( x[i,0]< 1 and x[i,1]<1):
            mark[i,0] = 1.0
        else:
            mark[i,0] =  1.0 
    return mark

# %%
device = torch.device('cuda')                                      
num_x = 200                                                        
num_t = 200                                                        
num_i_train = 200                                           
num_f_train = 20000                                            
Time = 2
L = 2
x = np.linspace(0, L, num_x)                                   
t = np.linspace(0, Time, num_t)                                   
t_grid, x_grid = np.meshgrid(t, x)                             
T = t_grid.flatten()[:, None]                                  
X = x_grid.flatten()[:, None]                                  

id_ic = np.random.choice(num_x, num_i_train, replace=False)    
id_f = np.random.choice(num_x*num_t, num_f_train, replace=False)

x_ic = x_grid[id_ic, 0][:, None]                               
t_ic = t_grid[id_ic, 0][:, None]                               
x_ic_train = np.hstack((t_ic, x_ic))                               
u_ic_train = IC(x_ic_train)                 

x_int = X[:, 0][id_f, None]                                        
t_int = T[:, 0][id_f, None]                                        
x_int_train = np.hstack((t_int, x_int))                            

x_bdL,x_bdR = BD_perid(L,Time,num_t)                            
u_bdL_in = BD(x_bdL)                            
u_bdR_in = BD(x_bdR)                            
mark = Mark(x_int_train)
mark_ic = Mark(x_ic_train)
mark_bd = Mark(x_bdL)
x_ic = torch.tensor(x_ic_train, dtype=torch.float32).to(device)
x_int = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)
u_ic = torch.tensor(u_ic_train, dtype=torch.float32).to(device)
x_bdL = torch.tensor(x_bdL, dtype=torch.float32).to(device)
x_bdR = torch.tensor(x_bdR, dtype=torch.float32).to(device)
u_bdL_in = torch.tensor(u_bdL_in, dtype=torch.float32).to(device)
u_bdR_in = torch.tensor(u_bdR_in, dtype=torch.float32).to(device)
mark = torch.tensor(mark, dtype=torch.float32).to(device)
mark_ic = torch.tensor(mark_ic, dtype=torch.float32).to(device)
mark_bd = torch.tensor(mark_bd, dtype=torch.float32).to(device)

model = DNN().to(device)

lr = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
print('Start training...')
# Out:
# Start training...

# %%
optimizer = torch.optim.LBFGS(model.parameters(),lr=0.5,max_iter=20)
epochs = 15000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
    
toc = time.time()
# Out:
# epoch 1 loss_pde:0.00104186, loss_ic:0.49794120
# epoch 1 loss_pde:0.00070937, loss_ic:0.49328208
# epoch 1 loss_pde:0.00027466, loss_ic:0.48647517
# epoch 1 loss_pde:0.00003469, loss_ic:0.47619089
# epoch 1 loss_pde:0.00080744, loss_ic:0.45835850
# epoch 1 loss_pde:0.00524114, loss_ic:0.42761946
# epoch 1 loss_pde:0.01651394, loss_ic:0.38232559
# epoch 1 loss_pde:0.01813727, loss_ic:0.37483817
# epoch 1 loss_pde:0.01802800, loss_ic:0.37144887
# epoch 1 loss_pde:0.01689462, loss_ic:0.36741504
# epoch 1 loss_pde:0.01484029, loss_ic:0.36249956
# epoch 1 loss_pde:0.01176520, loss_ic:0.35601392
# epoch 1 loss_pde:0.00772426, loss_ic:0.34837314
# epoch 1 loss_pde:0.00953364, loss_ic:0.41673934
# epoch 1 loss_pde:0.00773385, loss_ic:0.36001185
# epoch 1 loss_pde:0.00866754, loss_ic:0.35185513
# epoch 1 loss_pde:0.01125139, loss_ic:0.33761287
# epoch 1 loss_pde:0.01366999, loss_ic:0.32833046
# epoch 1 loss_pde:0.01620867, loss_ic:0.32062486
# epoch 1 loss_pde:0.02009392, loss_ic:0.31062660
# epoch 1: loss 15.145153
# epoch 2 loss_pde:0.02627583, loss_ic:0.29697233
# epoch 2 loss_pde:0.03095461, loss_ic:0.28771812
# epoch 2 loss_pde:0.03419689, loss_ic:0.28116894
# epoch 2 loss_pde:0.03733811, loss_ic:0.27416196
# epoch 2 loss_pde:0.03986683, loss_ic:0.26820174
# epoch 2 loss_pde:0.04225159, loss_ic:0.26448211
# epoch 2 loss_pde:0.05386284, loss_ic:0.25422698
# epoch 2 loss_pde:0.06021256, loss_ic:0.24940810
# epoch 2 loss_pde:0.06104562, loss_ic:0.24851039
# epoch 2 loss_pde:0.06124291, loss_ic:0.24773937
# epoch 2 loss_pde:0.06164845, loss_ic:0.24641579
# epoch 2 loss_pde:0.06226056, loss_ic:0.24446823
# epoch 2 loss_pde:0.06310067, loss_ic:0.24196345
# epoch 2 loss_pde:0.06399194, loss_ic:0.23964873
# epoch 2 loss_pde:0.06750017, loss_ic:0.23621623
# epoch 2 loss_pde:0.07198359, loss_ic:0.23500273
# epoch 2 loss_pde:0.08046782, loss_ic:0.23237175
# epoch 2 loss_pde:0.09043312, loss_ic:0.23960258
# epoch 2 loss_pde:0.09953005, loss_ic:0.23598628
# epoch 2 loss_pde:0.12276943, loss_ic:0.23165229
# epoch 2: loss 13.660714
# epoch 3 loss_pde:0.14050610, loss_ic:0.22820762
# epoch 3 loss_pde:0.16245872, loss_ic:0.22462121
# epoch 3 loss_pde:0.18949936, loss_ic:0.22080976
# epoch 3 loss_pde:0.26125699, loss_ic:0.20273623
# epoch 3 loss_pde:0.32358167, loss_ic:0.19406001
# epoch 3 loss_pde:0.36382291, loss_ic:0.17985101
# epoch 3 loss_pde:0.37240151, loss_ic:0.17305486
# epoch 3 loss_pde:0.40813494, loss_ic:0.15671055
# epoch 3 loss_pde:0.40249825, loss_ic:0.14844702
# epoch 3 loss_pde:0.43160728, loss_ic:0.12931208
# epoch 3 loss_pde:0.45558897, loss_ic:0.10438474
# epoch 3 loss_pde:0.44413266, loss_ic:0.08288458
# epoch 3 loss_pde:0.38440803, loss_ic:0.06886104
# epoch 3 loss_pde:0.36054021, loss_ic:0.05510015
# epoch 3 loss_pde:0.35692641, loss_ic:0.05085932
# epoch 3 loss_pde:0.37311196, loss_ic:0.06582043
# epoch 3 loss_pde:0.38238207, loss_ic:0.05582355
# epoch 3 loss_pde:0.40223202, loss_ic:0.05042019
# epoch 3 loss_pde:0.42769012, loss_ic:0.04580738
# epoch 3 loss_pde:0.45907298, loss_ic:0.04123634
# epoch 3: loss 12.923511
# epoch 4 loss_pde:0.49116698, loss_ic:0.03692820
# epoch 4 loss_pde:0.51060337, loss_ic:0.03280479
# epoch 4 loss_pde:0.45540652, loss_ic:0.03288858
# epoch 4 loss_pde:0.35090712, loss_ic:0.03428581
# epoch 4 loss_pde:0.30419561, loss_ic:0.03395957
# epoch 4 loss_pde:0.27321255, loss_ic:0.03456179
# epoch 4 loss_pde:0.26603755, loss_ic:0.03336671
# epoch 4 loss_pde:0.25871727, loss_ic:0.03454332
# epoch 4 loss_pde:0.25621346, loss_ic:0.03562278
# epoch 4 loss_pde:0.25263557, loss_ic:0.03688246
# epoch 4 loss_pde:0.25871152, loss_ic:0.03718236
# epoch 4 loss_pde:0.26065278, loss_ic:0.03717834
# epoch 4 loss_pde:0.27095050, loss_ic:0.03580714
# epoch 4 loss_pde:0.27042103, loss_ic:0.03228544
# epoch 4 loss_pde:0.27737847, loss_ic:0.02994596
# epoch 4 loss_pde:0.29148662, loss_ic:0.02703819
# epoch 4 loss_pde:0.29702070, loss_ic:0.02482996
# epoch 4 loss_pde:0.30745247, loss_ic:0.02290496
# epoch 4 loss_pde:0.30796471, loss_ic:0.02166590
# epoch 4 loss_pde:0.32351646, loss_ic:0.01932169
# epoch 4: loss 11.095852
# epoch 5 loss_pde:0.34551772, loss_ic:0.01641394
# epoch 5 loss_pde:0.36230424, loss_ic:0.01480620
# epoch 5 loss_pde:0.36515364, loss_ic:0.01282335
# epoch 5 loss_pde:0.34985229, loss_ic:0.01236547
# epoch 5 loss_pde:0.33470696, loss_ic:0.01015757
# epoch 5 loss_pde:0.32660967, loss_ic:0.00991262
# epoch 5 loss_pde:0.31079477, loss_ic:0.01090833
# epoch 5 loss_pde:0.31026170, loss_ic:0.01089699
# epoch 5 loss_pde:0.30677623, loss_ic:0.01096479
# epoch 5 loss_pde:0.30196235, loss_ic:0.01086775
# epoch 5 loss_pde:0.29855415, loss_ic:0.01143388
# epoch 5 loss_pde:0.29715341, loss_ic:0.01089271
# epoch 5 loss_pde:0.29930103, loss_ic:0.01039193
# epoch 5 loss_pde:0.30292127, loss_ic:0.00956116
# epoch 5 loss_pde:0.30637547, loss_ic:0.00893488
# epoch 5 loss_pde:0.30969644, loss_ic:0.00816117
# epoch 5 loss_pde:0.31093931, loss_ic:0.00780893
# epoch 5 loss_pde:0.31119788, loss_ic:0.00725503
# epoch 5 loss_pde:0.30971146, loss_ic:0.00692612
# epoch 5 loss_pde:0.30624580, loss_ic:0.00660171
# epoch 5: loss 10.575058
# epoch 6 loss_pde:0.30596802, loss_ic:0.00613697
# epoch 6 loss_pde:0.30323255, loss_ic:0.00607206
# epoch 6 loss_pde:0.30252996, loss_ic:0.00536764
# epoch 6 loss_pde:0.30216017, loss_ic:0.00551042
# epoch 6 loss_pde:0.29979983, loss_ic:0.00546231
# epoch 6 loss_pde:0.29814214, loss_ic:0.00573038
# epoch 6 loss_pde:0.29670179, loss_ic:0.00566045
# epoch 6 loss_pde:0.29690382, loss_ic:0.00561301
# epoch 6 loss_pde:0.29801321, loss_ic:0.00557328
# epoch 6 loss_pde:0.30012250, loss_ic:0.00557489
# epoch 6 loss_pde:0.30175850, loss_ic:0.00560348
# epoch 6 loss_pde:0.30302426, loss_ic:0.00562568
# epoch 6 loss_pde:0.30416825, loss_ic:0.00564865
# epoch 6 loss_pde:0.30542278, loss_ic:0.00567496
# epoch 6 loss_pde:0.30655590, loss_ic:0.00570742
# epoch 6 loss_pde:0.30726668, loss_ic:0.00574154
# epoch 6 loss_pde:0.30710611, loss_ic:0.00576362
# epoch 6 loss_pde:0.30596957, loss_ic:0.00571842
# epoch 6 loss_pde:0.30556342, loss_ic:0.00540042
# epoch 6 loss_pde:0.30111170, loss_ic:0.00533320
# epoch 6: loss 10.418214
# epoch 7 loss_pde:0.30090261, loss_ic:0.00506295
# epoch 7 loss_pde:0.29883197, loss_ic:0.00509741
# epoch 7 loss_pde:0.29816690, loss_ic:0.00509813
# epoch 7 loss_pde:0.29596201, loss_ic:0.00520543
# epoch 7 loss_pde:0.29515541, loss_ic:0.00523004
# epoch 7 loss_pde:0.29230154, loss_ic:0.00535355
# epoch 7 loss_pde:0.29150695, loss_ic:0.00534843
# epoch 7 loss_pde:0.28859684, loss_ic:0.00547788
# epoch 7 loss_pde:0.28950757, loss_ic:0.00537621
# epoch 7 loss_pde:0.28887698, loss_ic:0.00541258
# epoch 7 loss_pde:0.29018223, loss_ic:0.00528477
# epoch 7 loss_pde:0.29354763, loss_ic:0.00508267
# epoch 7 loss_pde:0.29247767, loss_ic:0.00514639
# epoch 7 loss_pde:0.29269654, loss_ic:0.00512422
# epoch 7 loss_pde:0.29464471, loss_ic:0.00493632
# epoch 7 loss_pde:0.29412070, loss_ic:0.00496279
# epoch 7 loss_pde:0.29553482, loss_ic:0.00478480
# epoch 7 loss_pde:0.29644951, loss_ic:0.00460253
# epoch 7 loss_pde:0.29545906, loss_ic:0.00456884
# epoch 7 loss_pde:0.29719487, loss_ic:0.00404415
# epoch 7: loss 10.393039
# epoch 8 loss_pde:0.29762915, loss_ic:0.00388286
# epoch 8 loss_pde:0.30251041, loss_ic:0.00333491
# epoch 8 loss_pde:0.29957905, loss_ic:0.00344735
# epoch 8 loss_pde:0.29905799, loss_ic:0.00346660
# epoch 8 loss_pde:0.29644638, loss_ic:0.00353981
# epoch 8 loss_pde:0.29344949, loss_ic:0.00370435
# epoch 8 loss_pde:0.29220435, loss_ic:0.00365511
# epoch 8 loss_pde:0.28751707, loss_ic:0.00382711
# epoch 8 loss_pde:0.28783005, loss_ic:0.00393943
# epoch 8 loss_pde:0.28757203, loss_ic:0.00391116
# epoch 8 loss_pde:0.28763357, loss_ic:0.00388489
# epoch 8 loss_pde:0.28724846, loss_ic:0.00390111
# epoch 8 loss_pde:0.28802612, loss_ic:0.00379458
# epoch 8 loss_pde:0.28736925, loss_ic:0.00384495
# epoch 8 loss_pde:0.28758159, loss_ic:0.00380702
# epoch 8 loss_pde:0.28743961, loss_ic:0.00380149
# epoch 8 loss_pde:0.28741992, loss_ic:0.00377961
# epoch 8 loss_pde:0.28715047, loss_ic:0.00377830
# epoch 8 loss_pde:0.28687605, loss_ic:0.00376195
# epoch 8 loss_pde:0.28592336, loss_ic:0.00383309
# epoch 8: loss 10.374180
# epoch 9 loss_pde:0.28610826, loss_ic:0.00372922
# epoch 9 loss_pde:0.28465575, loss_ic:0.00382337
# epoch 9 loss_pde:0.28632393, loss_ic:0.00361662
# epoch 9 loss_pde:0.28507715, loss_ic:0.00365318
# epoch 9 loss_pde:0.28491619, loss_ic:0.00361425
# epoch 9 loss_pde:0.28305927, loss_ic:0.00374240
# epoch 9 loss_pde:0.28163651, loss_ic:0.00382545
# epoch 9 loss_pde:0.28078040, loss_ic:0.00388785
# epoch 9 loss_pde:0.27916929, loss_ic:0.00401340
# epoch 9 loss_pde:0.27812198, loss_ic:0.00408263
# epoch 9 loss_pde:0.27571133, loss_ic:0.00423558
# epoch 9 loss_pde:0.27448612, loss_ic:0.00424491
# epoch 9 loss_pde:0.27265432, loss_ic:0.00425487
# epoch 9 loss_pde:0.27284992, loss_ic:0.00417824
# epoch 9 loss_pde:0.27278090, loss_ic:0.00414254
# epoch 9 loss_pde:0.27339414, loss_ic:0.00395634
# epoch 9 loss_pde:0.27323687, loss_ic:0.00396654
# epoch 9 loss_pde:0.27215970, loss_ic:0.00380275
# epoch 9 loss_pde:0.27170932, loss_ic:0.00384240
# epoch 9 loss_pde:0.27128699, loss_ic:0.00387688
# epoch 9: loss 10.360280
# epoch 10 loss_pde:0.27060559, loss_ic:0.00390885
# epoch 10 loss_pde:0.27033865, loss_ic:0.00390560
# epoch 10 loss_pde:0.26988286, loss_ic:0.00395917
# epoch 10 loss_pde:0.27002430, loss_ic:0.00386717
# epoch 10 loss_pde:0.26977593, loss_ic:0.00387319
# epoch 10 loss_pde:0.27009788, loss_ic:0.00379385
# epoch 10 loss_pde:0.27051854, loss_ic:0.00374532
# epoch 10 loss_pde:0.27084410, loss_ic:0.00373410
# epoch 10 loss_pde:0.27103907, loss_ic:0.00369285
# epoch 10 loss_pde:0.27002969, loss_ic:0.00389940
# epoch 10 loss_pde:0.26998118, loss_ic:0.00386111
# epoch 10 loss_pde:0.26952520, loss_ic:0.00388029
# epoch 10 loss_pde:0.26899663, loss_ic:0.00393611
# epoch 10 loss_pde:0.26855835, loss_ic:0.00392805
# epoch 10 loss_pde:0.26802981, loss_ic:0.00394183
# epoch 10 loss_pde:0.26788345, loss_ic:0.00394785
# epoch 10 loss_pde:0.26736265, loss_ic:0.00393897
# epoch 10 loss_pde:0.26731580, loss_ic:0.00400531
# epoch 10 loss_pde:0.26720068, loss_ic:0.00396457
# epoch 10 loss_pde:0.26678634, loss_ic:0.00402821
# epoch 10: loss 10.344905
# epoch 11 loss_pde:0.26631194, loss_ic:0.00402736
# epoch 11 loss_pde:0.26652578, loss_ic:0.00404535
# epoch 11 loss_pde:0.26614782, loss_ic:0.00408897
# epoch 11 loss_pde:0.26635122, loss_ic:0.00409644
# epoch 11 loss_pde:0.26636055, loss_ic:0.00408900
# epoch 11 loss_pde:0.26627293, loss_ic:0.00409546
# epoch 11 loss_pde:0.26647758, loss_ic:0.00406521
# epoch 11 loss_pde:0.26622486, loss_ic:0.00406344
# epoch 11 loss_pde:0.26656884, loss_ic:0.00401139
# epoch 11 loss_pde:0.26645312, loss_ic:0.00398553
# epoch 11 loss_pde:0.26681885, loss_ic:0.00392543
# epoch 11 loss_pde:0.26705170, loss_ic:0.00388515
# epoch 11 loss_pde:0.26726136, loss_ic:0.00384168
# epoch 11 loss_pde:0.26802915, loss_ic:0.00379016
# epoch 11 loss_pde:0.26808801, loss_ic:0.00379135
# epoch 11 loss_pde:0.26852947, loss_ic:0.00376455
# epoch 11 loss_pde:0.26802361, loss_ic:0.00379743
# epoch 11 loss_pde:0.26821762, loss_ic:0.00383352
# epoch 11 loss_pde:0.26803082, loss_ic:0.00382786
# epoch 11 loss_pde:0.26792523, loss_ic:0.00380271
# epoch 11: loss 10.339916
# epoch 12 loss_pde:0.26764917, loss_ic:0.00380412
# epoch 12 loss_pde:0.26787794, loss_ic:0.00376118
# epoch 12 loss_pde:0.26809716, loss_ic:0.00370610
# epoch 12 loss_pde:0.26829368, loss_ic:0.00368164
# epoch 12 loss_pde:0.26871690, loss_ic:0.00358845
# epoch 12 loss_pde:0.26897332, loss_ic:0.00356448
# epoch 12 loss_pde:0.26915342, loss_ic:0.00348959
# epoch 12 loss_pde:0.26946059, loss_ic:0.00345454
# epoch 12 loss_pde:0.26894289, loss_ic:0.00349844
# epoch 12 loss_pde:0.26889122, loss_ic:0.00348493
# epoch 12 loss_pde:0.26841059, loss_ic:0.00354897
# epoch 12 loss_pde:0.26809502, loss_ic:0.00356545
# epoch 12 loss_pde:0.26774064, loss_ic:0.00364506
# epoch 12 loss_pde:0.26765060, loss_ic:0.00365039
# epoch 12 loss_pde:0.26766855, loss_ic:0.00364598
# epoch 12 loss_pde:0.26774064, loss_ic:0.00364559
# epoch 12 loss_pde:0.26785046, loss_ic:0.00363506
# epoch 12 loss_pde:0.26792440, loss_ic:0.00363261
# epoch 12 loss_pde:0.26797217, loss_ic:0.00362242
# epoch 12 loss_pde:0.26792803, loss_ic:0.00362155
# epoch 12: loss 10.336002
# epoch 13 loss_pde:0.26773393, loss_ic:0.00361791
# epoch 13 loss_pde:0.26738396, loss_ic:0.00362375
# epoch 13 loss_pde:0.26685539, loss_ic:0.00363350
# epoch 13 loss_pde:0.26667109, loss_ic:0.00360369
# epoch 13 loss_pde:0.26584196, loss_ic:0.00362026
# epoch 13 loss_pde:0.26626158, loss_ic:0.00351509
# epoch 13 loss_pde:0.26606268, loss_ic:0.00358048
# epoch 13 loss_pde:0.26618096, loss_ic:0.00357090
# epoch 13 loss_pde:0.26654515, loss_ic:0.00351857
# epoch 13 loss_pde:0.26621312, loss_ic:0.00346237
# epoch 13 loss_pde:0.26618624, loss_ic:0.00346127
# epoch 13 loss_pde:0.26607302, loss_ic:0.00344789
# epoch 13 loss_pde:0.26620629, loss_ic:0.00342798
# epoch 13 loss_pde:0.26627442, loss_ic:0.00341572
# epoch 13 loss_pde:0.26559180, loss_ic:0.00348384
# epoch 13 loss_pde:0.26582515, loss_ic:0.00343752
# epoch 13 loss_pde:0.26494783, loss_ic:0.00348924
# epoch 13 loss_pde:0.26462284, loss_ic:0.00355778
# epoch 13 loss_pde:0.26410854, loss_ic:0.00350696
# epoch 13 loss_pde:0.26397195, loss_ic:0.00351210
# epoch 13: loss 10.334330
# epoch 14 loss_pde:0.26385486, loss_ic:0.00347010
# epoch 14 loss_pde:0.26373827, loss_ic:0.00344440
# epoch 14 loss_pde:0.26364818, loss_ic:0.00343015
# epoch 14 loss_pde:0.26274016, loss_ic:0.00344368
# epoch 14 loss_pde:0.26250562, loss_ic:0.00349204
# epoch 14 loss_pde:0.26241717, loss_ic:0.00349845
# epoch 14 loss_pde:0.26218441, loss_ic:0.00350245
# epoch 14 loss_pde:0.26244229, loss_ic:0.00347697
# epoch 14 loss_pde:0.26279691, loss_ic:0.00350244
# epoch 14 loss_pde:0.26265585, loss_ic:0.00344884
# epoch 14 loss_pde:0.26287594, loss_ic:0.00343969
# epoch 14 loss_pde:0.26265648, loss_ic:0.00344150
# epoch 14 loss_pde:0.26254684, loss_ic:0.00344833
# epoch 14 loss_pde:0.26241362, loss_ic:0.00344086
# epoch 14 loss_pde:0.26198709, loss_ic:0.00346355
# epoch 14 loss_pde:0.26196674, loss_ic:0.00343612
# epoch 14 loss_pde:0.26183379, loss_ic:0.00344558
# epoch 14 loss_pde:0.26210755, loss_ic:0.00341468
# epoch 14 loss_pde:0.26165009, loss_ic:0.00346307
# epoch 14 loss_pde:0.26190424, loss_ic:0.00343039
# epoch 14: loss 10.329769
# epoch 15 loss_pde:0.26252100, loss_ic:0.00339265
# epoch 15 loss_pde:0.26309046, loss_ic:0.00336530
# epoch 15 loss_pde:0.26387453, loss_ic:0.00330875
# epoch 15 loss_pde:0.26409644, loss_ic:0.00330595
# epoch 15 loss_pde:0.26409474, loss_ic:0.00331624
# epoch 15 loss_pde:0.26402318, loss_ic:0.00330471
# epoch 15 loss_pde:0.26357201, loss_ic:0.00334097
# epoch 15 loss_pde:0.26317391, loss_ic:0.00333839
# epoch 15 loss_pde:0.26256636, loss_ic:0.00335779
# epoch 15 loss_pde:0.26213998, loss_ic:0.00332921
# epoch 15 loss_pde:0.26149186, loss_ic:0.00332859
# epoch 15 loss_pde:0.26147959, loss_ic:0.00332083
# epoch 15 loss_pde:0.26023674, loss_ic:0.00331625
# epoch 15 loss_pde:0.26062655, loss_ic:0.00332846
# epoch 15 loss_pde:0.26192984, loss_ic:0.00334133
# epoch 15 loss_pde:0.26247382, loss_ic:0.00325580
# epoch 15 loss_pde:0.26243672, loss_ic:0.00332003
# epoch 15 loss_pde:0.26256049, loss_ic:0.00331876
# epoch 15 loss_pde:0.26260337, loss_ic:0.00333701
# epoch 15 loss_pde:0.26281419, loss_ic:0.00331315
# epoch 15: loss 10.327321
# epoch 16 loss_pde:0.26276892, loss_ic:0.00326541
# epoch 16 loss_pde:0.26255450, loss_ic:0.00333611
# epoch 16 loss_pde:0.26202944, loss_ic:0.00324124
# epoch 16 loss_pde:0.26222083, loss_ic:0.00329472
# epoch 16 loss_pde:0.26088431, loss_ic:0.00321133
# epoch 16 loss_pde:0.26093504, loss_ic:0.00315395
# epoch 16 loss_pde:0.26098874, loss_ic:0.00317675
# epoch 16 loss_pde:0.26057062, loss_ic:0.00318954
# epoch 16 loss_pde:0.26086786, loss_ic:0.00318790
# epoch 16 loss_pde:0.26066160, loss_ic:0.00321258
# epoch 16 loss_pde:0.26036763, loss_ic:0.00322564
# epoch 16 loss_pde:0.26101959, loss_ic:0.00319326
# epoch 16 loss_pde:0.26081923, loss_ic:0.00320702
# epoch 16 loss_pde:0.26073986, loss_ic:0.00318776
# epoch 16 loss_pde:0.26010218, loss_ic:0.00320434
# epoch 16 loss_pde:0.26044017, loss_ic:0.00315653
# epoch 16 loss_pde:0.25933287, loss_ic:0.00307481
# epoch 16 loss_pde:0.25977769, loss_ic:0.00312531
# epoch 16 loss_pde:0.25995687, loss_ic:0.00319572
# epoch 16 loss_pde:0.25968939, loss_ic:0.00302208
# epoch 16: loss 10.325469
# epoch 17 loss_pde:0.25993606, loss_ic:0.00298916
# epoch 17 loss_pde:0.25908226, loss_ic:0.00297910
# epoch 17 loss_pde:0.25872222, loss_ic:0.00309348
# epoch 17 loss_pde:0.25845143, loss_ic:0.00303018
# epoch 17 loss_pde:0.25862217, loss_ic:0.00309563
# epoch 17 loss_pde:0.25935981, loss_ic:0.00308214
# epoch 17 loss_pde:0.25914672, loss_ic:0.00312570
# epoch 17 loss_pde:0.25919300, loss_ic:0.00311754
# epoch 17 loss_pde:0.25929195, loss_ic:0.00312914
# epoch 17 loss_pde:0.25892052, loss_ic:0.00315040
# epoch 17 loss_pde:0.25879902, loss_ic:0.00315376
# epoch 17 loss_pde:0.25876522, loss_ic:0.00313951
# epoch 17 loss_pde:0.25872782, loss_ic:0.00316656
# epoch 17 loss_pde:0.25855127, loss_ic:0.00314430
# epoch 17 loss_pde:0.25873765, loss_ic:0.00314486
# epoch 17 loss_pde:0.25870326, loss_ic:0.00312450
# epoch 17 loss_pde:0.25924176, loss_ic:0.00310063
# epoch 17 loss_pde:0.25916889, loss_ic:0.00310268
# epoch 17 loss_pde:0.25935945, loss_ic:0.00309169
# epoch 17 loss_pde:0.25950131, loss_ic:0.00308425
# epoch 17: loss 10.322274
# epoch 18 loss_pde:0.25960484, loss_ic:0.00308204
# epoch 18 loss_pde:0.25968143, loss_ic:0.00307819
# epoch 18 loss_pde:0.25967288, loss_ic:0.00308101
# epoch 18 loss_pde:0.25969848, loss_ic:0.00308496
# epoch 18 loss_pde:0.25957426, loss_ic:0.00305707
# epoch 18 loss_pde:0.25958362, loss_ic:0.00307596
# epoch 18 loss_pde:0.25965884, loss_ic:0.00307105
# epoch 18 loss_pde:0.25965089, loss_ic:0.00308437
# epoch 18 loss_pde:0.25961152, loss_ic:0.00307272
# epoch 18 loss_pde:0.25954810, loss_ic:0.00305950
# epoch 18 loss_pde:0.25914112, loss_ic:0.00312223
# epoch 18 loss_pde:0.25884590, loss_ic:0.00309807
# epoch 18 loss_pde:0.25862679, loss_ic:0.00307405
# epoch 18 loss_pde:0.25859234, loss_ic:0.00307943
# epoch 18 loss_pde:0.25852820, loss_ic:0.00306080
# epoch 18 loss_pde:0.25842398, loss_ic:0.00306255
# epoch 18 loss_pde:0.25834751, loss_ic:0.00305969
# epoch 18 loss_pde:0.25820306, loss_ic:0.00306309
# epoch 18 loss_pde:0.25819480, loss_ic:0.00306297
# epoch 18 loss_pde:0.25804335, loss_ic:0.00306534
# epoch 18: loss 10.320161
# epoch 19 loss_pde:0.25801831, loss_ic:0.00306874
# epoch 19 loss_pde:0.25824288, loss_ic:0.00305504
# epoch 19 loss_pde:0.25820166, loss_ic:0.00306905
# epoch 19 loss_pde:0.25820792, loss_ic:0.00304519
# epoch 19 loss_pde:0.25812802, loss_ic:0.00306387
# epoch 19 loss_pde:0.25820839, loss_ic:0.00302672
# epoch 19 loss_pde:0.25803956, loss_ic:0.00304935
# epoch 19 loss_pde:0.25808966, loss_ic:0.00302307
# epoch 19 loss_pde:0.25787967, loss_ic:0.00303769
# epoch 19 loss_pde:0.25785223, loss_ic:0.00304294
# epoch 19 loss_pde:0.25783050, loss_ic:0.00304279
# epoch 19 loss_pde:0.25781307, loss_ic:0.00305057
# epoch 19 loss_pde:0.25783563, loss_ic:0.00305413
# epoch 19 loss_pde:0.25782967, loss_ic:0.00306068
# epoch 19 loss_pde:0.25780267, loss_ic:0.00306531
# epoch 19 loss_pde:0.25776526, loss_ic:0.00307794
# epoch 19 loss_pde:0.25754640, loss_ic:0.00308285
# epoch 19 loss_pde:0.25763816, loss_ic:0.00307939
# epoch 19 loss_pde:0.25757378, loss_ic:0.00307670
# epoch 19 loss_pde:0.25761333, loss_ic:0.00306348
# epoch 19: loss 10.319313
# epoch 20 loss_pde:0.25788045, loss_ic:0.00304131
# epoch 20 loss_pde:0.25797930, loss_ic:0.00303758
# epoch 20 loss_pde:0.25819251, loss_ic:0.00301503
# epoch 20 loss_pde:0.25835916, loss_ic:0.00302283
# epoch 20 loss_pde:0.25855073, loss_ic:0.00297736
# epoch 20 loss_pde:0.25863093, loss_ic:0.00298519
# epoch 20 loss_pde:0.25852680, loss_ic:0.00298545
# epoch 20 loss_pde:0.25833413, loss_ic:0.00300407
# epoch 20 loss_pde:0.25824955, loss_ic:0.00299417
# epoch 20 loss_pde:0.25778538, loss_ic:0.00302070
# epoch 20 loss_pde:0.25778228, loss_ic:0.00301870
# epoch 20 loss_pde:0.25765038, loss_ic:0.00302018
# epoch 20 loss_pde:0.25765237, loss_ic:0.00300979
# epoch 20 loss_pde:0.25768316, loss_ic:0.00300032
# epoch 20 loss_pde:0.25768951, loss_ic:0.00299765
# epoch 20 loss_pde:0.25788134, loss_ic:0.00298032
# epoch 20 loss_pde:0.25777635, loss_ic:0.00299962
# epoch 20 loss_pde:0.25776616, loss_ic:0.00300642
# epoch 20 loss_pde:0.25779721, loss_ic:0.00300589
# epoch 20 loss_pde:0.25772142, loss_ic:0.00303101
# epoch 20: loss 10.318742
# epoch 21 loss_pde:0.25780785, loss_ic:0.00302570
# epoch 21 loss_pde:0.25777492, loss_ic:0.00302810
# epoch 21 loss_pde:0.25780708, loss_ic:0.00303650
# epoch 21 loss_pde:0.25781059, loss_ic:0.00303897
# epoch 21 loss_pde:0.25790024, loss_ic:0.00303895
# epoch 21 loss_pde:0.25791535, loss_ic:0.00304142
# epoch 21 loss_pde:0.25808436, loss_ic:0.00302795
# epoch 21 loss_pde:0.25796825, loss_ic:0.00303687
# epoch 21 loss_pde:0.25800824, loss_ic:0.00302189
# epoch 21 loss_pde:0.25805330, loss_ic:0.00301111
# epoch 21 loss_pde:0.25803491, loss_ic:0.00300999
# epoch 21 loss_pde:0.25803936, loss_ic:0.00299316
# epoch 21 loss_pde:0.25859544, loss_ic:0.00309044
# epoch 21 loss_pde:0.25809893, loss_ic:0.00304287
# epoch 21 loss_pde:0.25786060, loss_ic:0.00303451
# epoch 21 loss_pde:0.25802898, loss_ic:0.00301679
# epoch 21 loss_pde:0.25774676, loss_ic:0.00302827
# epoch 21 loss_pde:0.25756055, loss_ic:0.00302299
# epoch 21 loss_pde:0.25703621, loss_ic:0.00308267
# epoch 21 loss_pde:0.25758359, loss_ic:0.00306718
# epoch 21: loss 10.318135
# epoch 22 loss_pde:0.25768048, loss_ic:0.00303711
# epoch 22 loss_pde:0.25730062, loss_ic:0.00306838
# epoch 22 loss_pde:0.25733119, loss_ic:0.00305744
# epoch 22 loss_pde:0.25727734, loss_ic:0.00305233
# epoch 22 loss_pde:0.25730684, loss_ic:0.00303552
# epoch 22 loss_pde:0.25729036, loss_ic:0.00303624
# epoch 22 loss_pde:0.25737882, loss_ic:0.00303276
# epoch 22 loss_pde:0.25739625, loss_ic:0.00302726
# epoch 22 loss_pde:0.25745538, loss_ic:0.00301691
# epoch 22 loss_pde:0.25744057, loss_ic:0.00302155
# epoch 22 loss_pde:0.25749749, loss_ic:0.00300142
# epoch 22 loss_pde:0.25735831, loss_ic:0.00302299
# epoch 22 loss_pde:0.25737929, loss_ic:0.00302052
# epoch 22 loss_pde:0.25735331, loss_ic:0.00302480
# epoch 22 loss_pde:0.25731584, loss_ic:0.00302762
# epoch 22 loss_pde:0.25724971, loss_ic:0.00303497
# epoch 22 loss_pde:0.25716957, loss_ic:0.00304151
# epoch 22 loss_pde:0.25706044, loss_ic:0.00304813
# epoch 22 loss_pde:0.25699541, loss_ic:0.00305149
# epoch 22 loss_pde:0.25690511, loss_ic:0.00305770
# epoch 22: loss 10.317847
# epoch 23 loss_pde:0.25701165, loss_ic:0.00304588
# epoch 23 loss_pde:0.25693500, loss_ic:0.00305306
# epoch 23 loss_pde:0.25710464, loss_ic:0.00303612
# epoch 23 loss_pde:0.25720084, loss_ic:0.00303196
# epoch 23 loss_pde:0.25736192, loss_ic:0.00301232
# epoch 23 loss_pde:0.25751409, loss_ic:0.00301500
# epoch 23 loss_pde:0.25758958, loss_ic:0.00300503
# epoch 23 loss_pde:0.25752920, loss_ic:0.00300773
# epoch 23: loss 10.317749
# epoch 24 loss_pde:0.25752920, loss_ic:0.00300773
# epoch 24 loss_pde:0.25758609, loss_ic:0.00300022
# epoch 24 loss_pde:0.25753418, loss_ic:0.00300409
# epoch 24 loss_pde:0.25747055, loss_ic:0.00300786
# epoch 24 loss_pde:0.25736195, loss_ic:0.00301831
# epoch 24 loss_pde:0.25724429, loss_ic:0.00302226
# epoch 24 loss_pde:0.25697562, loss_ic:0.00303161
# epoch 24 loss_pde:0.25693262, loss_ic:0.00302850
# epoch 24 loss_pde:0.25666896, loss_ic:0.00305120
# epoch 24 loss_pde:0.25690755, loss_ic:0.00300622
# epoch 24 loss_pde:0.25686908, loss_ic:0.00300472
# epoch 24 loss_pde:0.25687754, loss_ic:0.00299289
# epoch 24 loss_pde:0.25688648, loss_ic:0.00299173
# epoch 24 loss_pde:0.25686112, loss_ic:0.00299077
# epoch 24 loss_pde:0.25694418, loss_ic:0.00298688
# epoch 24 loss_pde:0.25693023, loss_ic:0.00299848
# epoch 24 loss_pde:0.25689766, loss_ic:0.00300799
# epoch 24 loss_pde:0.25707826, loss_ic:0.00302615
# epoch 24 loss_pde:0.25698379, loss_ic:0.00304266
# epoch 24 loss_pde:0.25707105, loss_ic:0.00305331
# epoch 24: loss 10.317720
# epoch 25 loss_pde:0.25705761, loss_ic:0.00306119
# epoch 25 loss_pde:0.25715062, loss_ic:0.00305426
# epoch 25 loss_pde:0.25720760, loss_ic:0.00303540
# epoch 25 loss_pde:0.25731322, loss_ic:0.00301983
# epoch 25 loss_pde:0.25738519, loss_ic:0.00300809
# epoch 25 loss_pde:0.25744984, loss_ic:0.00300259
# epoch 25 loss_pde:0.25740999, loss_ic:0.00299900
# epoch 25 loss_pde:0.25745609, loss_ic:0.00300907
# epoch 25 loss_pde:0.25741270, loss_ic:0.00300950
# epoch 25 loss_pde:0.25735924, loss_ic:0.00301620
# epoch 25 loss_pde:0.25729218, loss_ic:0.00302272
# epoch 25 loss_pde:0.25720662, loss_ic:0.00303046
# epoch 25 loss_pde:0.25712284, loss_ic:0.00303941
# epoch 25 loss_pde:0.25703108, loss_ic:0.00304745
# epoch 25 loss_pde:0.25695848, loss_ic:0.00305617
# epoch 25 loss_pde:0.25694564, loss_ic:0.00305614
# epoch 25 loss_pde:0.25701728, loss_ic:0.00304880
# epoch 25 loss_pde:0.25710171, loss_ic:0.00303092
# epoch 25 loss_pde:0.25723541, loss_ic:0.00301581
# epoch 25 loss_pde:0.25731251, loss_ic:0.00299942
# epoch 25: loss 10.317435
# epoch 26 loss_pde:0.25753739, loss_ic:0.00298463
# epoch 26 loss_pde:0.25765857, loss_ic:0.00297859
# epoch 26 loss_pde:0.25775880, loss_ic:0.00297621
# epoch 26 loss_pde:0.25736675, loss_ic:0.00303559
# epoch 26 loss_pde:0.25755185, loss_ic:0.00297264
# epoch 26 loss_pde:0.25738770, loss_ic:0.00299510
# epoch 26 loss_pde:0.25725836, loss_ic:0.00301995
# epoch 26 loss_pde:0.25712723, loss_ic:0.00302815
# epoch 26 loss_pde:0.25707334, loss_ic:0.00303294
# epoch 26 loss_pde:0.25693268, loss_ic:0.00303612
# epoch 26 loss_pde:0.25698256, loss_ic:0.00303386
# epoch 26 loss_pde:0.25688016, loss_ic:0.00303297
# epoch 26 loss_pde:0.25691381, loss_ic:0.00302933
# epoch 26 loss_pde:0.25696522, loss_ic:0.00302469
# epoch 26 loss_pde:0.25701538, loss_ic:0.00301930
# epoch 26 loss_pde:0.25727621, loss_ic:0.00300904
# epoch 26 loss_pde:0.25749043, loss_ic:0.00298792
# epoch 26 loss_pde:0.25736192, loss_ic:0.00298157
# epoch 26 loss_pde:0.25736392, loss_ic:0.00301173
# epoch 26 loss_pde:0.25728020, loss_ic:0.00300129
# epoch 26: loss 10.317220
# epoch 27 loss_pde:0.25706276, loss_ic:0.00299934
# epoch 27 loss_pde:0.25703803, loss_ic:0.00300345
# epoch 27 loss_pde:0.25702104, loss_ic:0.00299557
# epoch 27 loss_pde:0.25717929, loss_ic:0.00299358
# epoch 27 loss_pde:0.25717962, loss_ic:0.00300492
# epoch 27 loss_pde:0.25723535, loss_ic:0.00300097
# epoch 27 loss_pde:0.25729260, loss_ic:0.00300384
# epoch 27 loss_pde:0.25737873, loss_ic:0.00299850
# epoch 27 loss_pde:0.25746155, loss_ic:0.00299787
# epoch 27 loss_pde:0.25793275, loss_ic:0.00295481
# epoch 27 loss_pde:0.25785595, loss_ic:0.00296919
# epoch 27 loss_pde:0.25775072, loss_ic:0.00297202
# epoch 27 loss_pde:0.25759208, loss_ic:0.00299028
# epoch 27 loss_pde:0.25721744, loss_ic:0.00299835
# epoch 27 loss_pde:0.25716290, loss_ic:0.00299703
# epoch 27 loss_pde:0.25703290, loss_ic:0.00299450
# epoch 27 loss_pde:0.25689471, loss_ic:0.00299116
# epoch 27 loss_pde:0.25681919, loss_ic:0.00299091
# epoch 27 loss_pde:0.25677818, loss_ic:0.00299161
# epoch 27 loss_pde:0.25695184, loss_ic:0.00297277
# epoch 27: loss 10.316981
# epoch 28 loss_pde:0.25707015, loss_ic:0.00297569
# epoch 28 loss_pde:0.25710508, loss_ic:0.00296641
# epoch 28 loss_pde:0.25722313, loss_ic:0.00296751
# epoch 28 loss_pde:0.25730726, loss_ic:0.00296066
# epoch 28 loss_pde:0.25731584, loss_ic:0.00296172
# epoch 28 loss_pde:0.25738341, loss_ic:0.00296038
# epoch 28 loss_pde:0.25737655, loss_ic:0.00296028
# epoch 28 loss_pde:0.25735244, loss_ic:0.00296266
# epoch 28 loss_pde:0.25731650, loss_ic:0.00296416
# epoch 28 loss_pde:0.25724891, loss_ic:0.00296960
# epoch 28 loss_pde:0.25719407, loss_ic:0.00297430
# epoch 28: loss 10.316690
# epoch 29 loss_pde:0.25719407, loss_ic:0.00297430
# epoch 29 loss_pde:0.25716478, loss_ic:0.00297761
# epoch 29 loss_pde:0.25712508, loss_ic:0.00298151
# epoch 29 loss_pde:0.25710577, loss_ic:0.00298573
# epoch 29 loss_pde:0.25709340, loss_ic:0.00298740
# epoch 29 loss_pde:0.25707704, loss_ic:0.00299241
# epoch 29 loss_pde:0.25709867, loss_ic:0.00299163
# epoch 29: loss 10.316673
# epoch 30 loss_pde:0.25709867, loss_ic:0.00299163
# epoch 30 loss_pde:0.25703970, loss_ic:0.00300495
# epoch 30 loss_pde:0.25709674, loss_ic:0.00300303
# epoch 30 loss_pde:0.25718784, loss_ic:0.00300375
# epoch 30 loss_pde:0.25729492, loss_ic:0.00299788
# epoch 30 loss_pde:0.25744697, loss_ic:0.00299266
# epoch 30 loss_pde:0.25749090, loss_ic:0.00298486
# epoch 30 loss_pde:0.25756380, loss_ic:0.00297397
# epoch 30 loss_pde:0.25747016, loss_ic:0.00297625
# epoch 30 loss_pde:0.25740081, loss_ic:0.00296221
# epoch 30 loss_pde:0.25732338, loss_ic:0.00296484
# epoch 30 loss_pde:0.25709912, loss_ic:0.00297555
# epoch 30 loss_pde:0.25697720, loss_ic:0.00298190
# epoch 30 loss_pde:0.25686464, loss_ic:0.00298572
# epoch 30 loss_pde:0.25680047, loss_ic:0.00299107
# epoch 30 loss_pde:0.25678766, loss_ic:0.00299198
# epoch 30 loss_pde:0.25671142, loss_ic:0.00300129
# epoch 30 loss_pde:0.25674698, loss_ic:0.00300262
# epoch 30 loss_pde:0.25682279, loss_ic:0.00299901
# epoch 30 loss_pde:0.25693530, loss_ic:0.00300245
# epoch 30: loss 10.316668
# epoch 31 loss_pde:0.25707254, loss_ic:0.00299011
# epoch 31 loss_pde:0.25717896, loss_ic:0.00298815
# epoch 31 loss_pde:0.25726128, loss_ic:0.00298382
# epoch 31 loss_pde:0.25707948, loss_ic:0.00299699
# epoch 31 loss_pde:0.25698286, loss_ic:0.00299356
# epoch 31 loss_pde:0.25687730, loss_ic:0.00299959
# epoch 31 loss_pde:0.25673974, loss_ic:0.00299358
# epoch 31 loss_pde:0.25668314, loss_ic:0.00299144
# epoch 31 loss_pde:0.25653565, loss_ic:0.00300785
# epoch 31 loss_pde:0.25663152, loss_ic:0.00298396
# epoch 31 loss_pde:0.25660858, loss_ic:0.00299375
# epoch 31 loss_pde:0.25667351, loss_ic:0.00299619
# epoch 31 loss_pde:0.25677183, loss_ic:0.00299530
# epoch 31 loss_pde:0.25686240, loss_ic:0.00299311
# epoch 31 loss_pde:0.25691679, loss_ic:0.00299012
# epoch 31 loss_pde:0.25695047, loss_ic:0.00298814
# epoch 31 loss_pde:0.25695190, loss_ic:0.00298566
# epoch 31: loss 10.316562
# epoch 32 loss_pde:0.25695190, loss_ic:0.00298566
# epoch 32 loss_pde:0.25692892, loss_ic:0.00298530
# epoch 32 loss_pde:0.25689569, loss_ic:0.00298307
# epoch 32: loss 10.316451
# epoch 33 loss_pde:0.25689569, loss_ic:0.00298307
# epoch 33 loss_pde:0.25683424, loss_ic:0.00298559
# epoch 33 loss_pde:0.25682989, loss_ic:0.00298211
# epoch 33 loss_pde:0.25677928, loss_ic:0.00298464
# epoch 33 loss_pde:0.25677267, loss_ic:0.00298602
# epoch 33: loss 10.316448
# epoch 34 loss_pde:0.25677267, loss_ic:0.00298602
# epoch 34 loss_pde:0.25679532, loss_ic:0.00298523
# epoch 34 loss_pde:0.25680736, loss_ic:0.00298749
# epoch 34 loss_pde:0.25684899, loss_ic:0.00298679
# epoch 34 loss_pde:0.25688604, loss_ic:0.00298686
# epoch 34 loss_pde:0.25692725, loss_ic:0.00298608
# epoch 34 loss_pde:0.25696599, loss_ic:0.00298511
# epoch 34 loss_pde:0.25698113, loss_ic:0.00298440
# epoch 34 loss_pde:0.25698557, loss_ic:0.00298660
# epoch 34 loss_pde:0.25692302, loss_ic:0.00298682
# epoch 34 loss_pde:0.25682211, loss_ic:0.00299457
# epoch 34 loss_pde:0.25662875, loss_ic:0.00299709
# epoch 34 loss_pde:0.25642195, loss_ic:0.00300129
# epoch 34 loss_pde:0.25635496, loss_ic:0.00298858
# epoch 34 loss_pde:0.25650439, loss_ic:0.00297815
# epoch 34 loss_pde:0.25660089, loss_ic:0.00298433
# epoch 34 loss_pde:0.25667393, loss_ic:0.00299066
# epoch 34 loss_pde:0.25675949, loss_ic:0.00297575
# epoch 34 loss_pde:0.25677264, loss_ic:0.00296986
# epoch 34 loss_pde:0.25682715, loss_ic:0.00297083
# epoch 34: loss 10.316445
# epoch 35 loss_pde:0.25679457, loss_ic:0.00296326
# epoch 35 loss_pde:0.25683233, loss_ic:0.00296334
# epoch 35 loss_pde:0.25684023, loss_ic:0.00296845
# epoch 35 loss_pde:0.25694469, loss_ic:0.00296224
# epoch 35 loss_pde:0.25697210, loss_ic:0.00296120
# epoch 35 loss_pde:0.25707227, loss_ic:0.00295762
# epoch 35 loss_pde:0.25696966, loss_ic:0.00295821
# epoch 35 loss_pde:0.25695047, loss_ic:0.00295994
# epoch 35 loss_pde:0.25695324, loss_ic:0.00296213
# epoch 35 loss_pde:0.25684848, loss_ic:0.00296404
# epoch 35 loss_pde:0.25698459, loss_ic:0.00296883
# epoch 35 loss_pde:0.25693396, loss_ic:0.00296586
# epoch 35 loss_pde:0.25683609, loss_ic:0.00296444
# epoch 35 loss_pde:0.25675818, loss_ic:0.00296459
# epoch 35 loss_pde:0.25672972, loss_ic:0.00296112
# epoch 35: loss 10.316255
# epoch 36 loss_pde:0.25672972, loss_ic:0.00296112
# epoch 36 loss_pde:0.25668544, loss_ic:0.00296349
# epoch 36 loss_pde:0.25673199, loss_ic:0.00296019
# epoch 36 loss_pde:0.25673923, loss_ic:0.00296620
# epoch 36: loss 10.316225
# epoch 37 loss_pde:0.25673923, loss_ic:0.00296620
# epoch 37 loss_pde:0.25681499, loss_ic:0.00296409
# epoch 37 loss_pde:0.25689241, loss_ic:0.00296220
# epoch 37 loss_pde:0.25695312, loss_ic:0.00296592
# epoch 37: loss 10.316218
# epoch 38 loss_pde:0.25695312, loss_ic:0.00296592
# epoch 38 loss_pde:0.25700974, loss_ic:0.00296225
# epoch 38 loss_pde:0.25702691, loss_ic:0.00296102
# epoch 38: loss 10.316215
# epoch 39 loss_pde:0.25702691, loss_ic:0.00296102
# epoch 39 loss_pde:0.25703549, loss_ic:0.00295634
# epoch 39 loss_pde:0.25700435, loss_ic:0.00295862
# epoch 39 loss_pde:0.25682709, loss_ic:0.00294327
# epoch 39 loss_pde:0.25691259, loss_ic:0.00294627
# epoch 39 loss_pde:0.25694937, loss_ic:0.00295197
# epoch 39 loss_pde:0.25698221, loss_ic:0.00295214
# epoch 39 loss_pde:0.25699466, loss_ic:0.00295283
# epoch 39 loss_pde:0.25701186, loss_ic:0.00295335
# epoch 39 loss_pde:0.25702003, loss_ic:0.00295390
# epoch 39 loss_pde:0.25701970, loss_ic:0.00295403
# epoch 39 loss_pde:0.25702801, loss_ic:0.00295300
# epoch 39 loss_pde:0.25701192, loss_ic:0.00295386
# epoch 39 loss_pde:0.25699744, loss_ic:0.00295440
# epoch 39 loss_pde:0.25696889, loss_ic:0.00295520
# epoch 39 loss_pde:0.25698325, loss_ic:0.00295549
# epoch 39 loss_pde:0.25692454, loss_ic:0.00296691
# epoch 39 loss_pde:0.25686079, loss_ic:0.00297676
# epoch 39 loss_pde:0.25684786, loss_ic:0.00295879
# epoch 39 loss_pde:0.25668845, loss_ic:0.00297764
# epoch 39: loss 10.316213
# epoch 40 loss_pde:0.25660506, loss_ic:0.00296761
# epoch 40 loss_pde:0.25661632, loss_ic:0.00296426
# epoch 40 loss_pde:0.25668123, loss_ic:0.00296444
# epoch 40 loss_pde:0.25689146, loss_ic:0.00294663
# epoch 40 loss_pde:0.25697920, loss_ic:0.00295136
# epoch 40 loss_pde:0.25703090, loss_ic:0.00294211
# epoch 40 loss_pde:0.25705215, loss_ic:0.00295149
# epoch 40 loss_pde:0.25700986, loss_ic:0.00295116
# epoch 40 loss_pde:0.25697464, loss_ic:0.00296291
# epoch 40 loss_pde:0.25693589, loss_ic:0.00296638
# epoch 40 loss_pde:0.25683704, loss_ic:0.00297452
# epoch 40 loss_pde:0.25682881, loss_ic:0.00298307
# epoch 40 loss_pde:0.25683969, loss_ic:0.00298285
# epoch 40 loss_pde:0.25690657, loss_ic:0.00298035
# epoch 40 loss_pde:0.25687107, loss_ic:0.00299803
# epoch 40 loss_pde:0.25697601, loss_ic:0.00298031
# epoch 40 loss_pde:0.25702381, loss_ic:0.00297983
# epoch 40 loss_pde:0.25708979, loss_ic:0.00297393
# epoch 40 loss_pde:0.25718206, loss_ic:0.00296759
# epoch 40 loss_pde:0.25716493, loss_ic:0.00296249
# epoch 40: loss 10.316143
# epoch 41 loss_pde:0.25711191, loss_ic:0.00297015
# epoch 41 loss_pde:0.25711140, loss_ic:0.00295528
# epoch 41: loss 10.316005
# epoch 42 loss_pde:0.25711140, loss_ic:0.00295528
# epoch 42 loss_pde:0.25708100, loss_ic:0.00296032
# epoch 42 loss_pde:0.25711551, loss_ic:0.00295220
# epoch 42 loss_pde:0.25710404, loss_ic:0.00296259
# epoch 42 loss_pde:0.25714597, loss_ic:0.00296059
# epoch 42 loss_pde:0.25722313, loss_ic:0.00295917
# epoch 42 loss_pde:0.25731939, loss_ic:0.00297260
# epoch 42 loss_pde:0.25756890, loss_ic:0.00290915
# epoch 42 loss_pde:0.25738183, loss_ic:0.00292768
# epoch 42 loss_pde:0.25722313, loss_ic:0.00295781
# epoch 42 loss_pde:0.25711754, loss_ic:0.00295842
# epoch 42 loss_pde:0.25702214, loss_ic:0.00295614
# epoch 42 loss_pde:0.25703856, loss_ic:0.00295577
# epoch 42 loss_pde:0.25683916, loss_ic:0.00296148
# epoch 42 loss_pde:0.25683609, loss_ic:0.00295949
# epoch 42 loss_pde:0.25694609, loss_ic:0.00295793
# epoch 42 loss_pde:0.25700843, loss_ic:0.00294715
# epoch 42 loss_pde:0.25702947, loss_ic:0.00296348
# epoch 42 loss_pde:0.25711390, loss_ic:0.00295137
# epoch 42 loss_pde:0.25709310, loss_ic:0.00294852
# epoch 42: loss 10.316005
# epoch 43 loss_pde:0.25713822, loss_ic:0.00294243
# epoch 43 loss_pde:0.25706965, loss_ic:0.00294317
# epoch 43 loss_pde:0.25704902, loss_ic:0.00293060
# epoch 43 loss_pde:0.25710738, loss_ic:0.00293601
# epoch 43 loss_pde:0.25712430, loss_ic:0.00293095
# epoch 43 loss_pde:0.25709018, loss_ic:0.00293148
# epoch 43 loss_pde:0.25708431, loss_ic:0.00292485
# epoch 43 loss_pde:0.25697452, loss_ic:0.00293071
# epoch 43 loss_pde:0.25692850, loss_ic:0.00292836
# epoch 43 loss_pde:0.25691563, loss_ic:0.00293696
# epoch 43 loss_pde:0.25693062, loss_ic:0.00292987
# epoch 43 loss_pde:0.25697416, loss_ic:0.00293075
# epoch 43 loss_pde:0.25701928, loss_ic:0.00293213
# epoch 43 loss_pde:0.25713471, loss_ic:0.00292417
# epoch 43 loss_pde:0.25714388, loss_ic:0.00293017
# epoch 43 loss_pde:0.25724286, loss_ic:0.00292130
# epoch 43 loss_pde:0.25689346, loss_ic:0.00295136
# epoch 43 loss_pde:0.25695330, loss_ic:0.00294777
# epoch 43 loss_pde:0.25700980, loss_ic:0.00293290
# epoch 43 loss_pde:0.25697196, loss_ic:0.00293275
# epoch 43: loss 10.315914
# epoch 44 loss_pde:0.25697210, loss_ic:0.00293512
# epoch 44 loss_pde:0.25695413, loss_ic:0.00292985
# epoch 44 loss_pde:0.25698054, loss_ic:0.00293641
# epoch 44 loss_pde:0.25699571, loss_ic:0.00293596
# epoch 44 loss_pde:0.25702170, loss_ic:0.00293791
# epoch 44 loss_pde:0.25697100, loss_ic:0.00294012
# epoch 44 loss_pde:0.25714046, loss_ic:0.00293579
# epoch 44 loss_pde:0.25718242, loss_ic:0.00294376
# epoch 44 loss_pde:0.25714445, loss_ic:0.00295128
# epoch 44 loss_pde:0.25725552, loss_ic:0.00294331
# epoch 44 loss_pde:0.25717571, loss_ic:0.00294438
# epoch 44 loss_pde:0.25707060, loss_ic:0.00294371
# epoch 44 loss_pde:0.25695911, loss_ic:0.00293973
# epoch 44 loss_pde:0.25689539, loss_ic:0.00293607
# epoch 44 loss_pde:0.25682065, loss_ic:0.00293016
# epoch 44 loss_pde:0.25697666, loss_ic:0.00292247
# epoch 44 loss_pde:0.25689283, loss_ic:0.00292437
# epoch 44 loss_pde:0.25686789, loss_ic:0.00292506
# epoch 44 loss_pde:0.25694251, loss_ic:0.00292452
# epoch 44 loss_pde:0.25696811, loss_ic:0.00292723
# epoch 44: loss 10.315824
# epoch 45 loss_pde:0.25701097, loss_ic:0.00292830
# epoch 45 loss_pde:0.25700456, loss_ic:0.00293336
# epoch 45 loss_pde:0.25703624, loss_ic:0.00293242
# epoch 45 loss_pde:0.25647339, loss_ic:0.00300691
# epoch 45 loss_pde:0.25673163, loss_ic:0.00297297
# epoch 45 loss_pde:0.25686112, loss_ic:0.00295454
# epoch 45 loss_pde:0.25693372, loss_ic:0.00294335
# epoch 45 loss_pde:0.25697529, loss_ic:0.00293614
# epoch 45 loss_pde:0.25700247, loss_ic:0.00293139
# epoch 45 loss_pde:0.25701347, loss_ic:0.00292813
# epoch 45 loss_pde:0.25702193, loss_ic:0.00292625
# epoch 45 loss_pde:0.25701866, loss_ic:0.00292480
# epoch 45 loss_pde:0.25701293, loss_ic:0.00292444
# epoch 45 loss_pde:0.25700241, loss_ic:0.00292374
# epoch 45 loss_pde:0.25698650, loss_ic:0.00292434
# epoch 45 loss_pde:0.25693291, loss_ic:0.00292530
# epoch 45 loss_pde:0.25692636, loss_ic:0.00292598
# epoch 45 loss_pde:0.25638643, loss_ic:0.00293925
# epoch 45: loss 10.315710
# epoch 46 loss_pde:0.25638643, loss_ic:0.00293925
# epoch 46 loss_pde:0.25661352, loss_ic:0.00293262
# epoch 46 loss_pde:0.25680870, loss_ic:0.00292920
# epoch 46 loss_pde:0.25703669, loss_ic:0.00292212
# epoch 46 loss_pde:0.25714681, loss_ic:0.00292067
# epoch 46 loss_pde:0.25719994, loss_ic:0.00292356
# epoch 46 loss_pde:0.25710633, loss_ic:0.00292927
# epoch 46 loss_pde:0.25707251, loss_ic:0.00293381
# epoch 46 loss_pde:0.25689709, loss_ic:0.00294688
# epoch 46 loss_pde:0.25680220, loss_ic:0.00294651
# epoch 46 loss_pde:0.25673929, loss_ic:0.00295356
# epoch 46 loss_pde:0.25676563, loss_ic:0.00294619
# epoch 46 loss_pde:0.25680092, loss_ic:0.00294802
# epoch 46 loss_pde:0.25686988, loss_ic:0.00294450
# epoch 46 loss_pde:0.25692451, loss_ic:0.00294194
# epoch 46 loss_pde:0.25690073, loss_ic:0.00296616
# epoch 46 loss_pde:0.25695148, loss_ic:0.00295342
# epoch 46 loss_pde:0.25695056, loss_ic:0.00294460
# epoch 46 loss_pde:0.25697330, loss_ic:0.00293379
# epoch 46 loss_pde:0.25669965, loss_ic:0.00293787
# epoch 46: loss 10.315688
# epoch 47 loss_pde:0.25683877, loss_ic:0.00292947
# epoch 47 loss_pde:0.25681069, loss_ic:0.00292463
# epoch 47 loss_pde:0.25659373, loss_ic:0.00294293
# epoch 47 loss_pde:0.25679648, loss_ic:0.00293336
# epoch 47 loss_pde:0.25681910, loss_ic:0.00293460
# epoch 47 loss_pde:0.25686067, loss_ic:0.00293261
# epoch 47 loss_pde:0.25683814, loss_ic:0.00293868
# epoch 47 loss_pde:0.25687912, loss_ic:0.00293610
# epoch 47 loss_pde:0.25695121, loss_ic:0.00293354
# epoch 47 loss_pde:0.25692081, loss_ic:0.00293432
# epoch 47 loss_pde:0.25700462, loss_ic:0.00293319
# epoch 47 loss_pde:0.25699085, loss_ic:0.00293339
# epoch 47 loss_pde:0.25704756, loss_ic:0.00292870
# epoch 47 loss_pde:0.25683421, loss_ic:0.00295335
# epoch 47 loss_pde:0.25700390, loss_ic:0.00293585
# epoch 47 loss_pde:0.25701216, loss_ic:0.00293377
# epoch 47 loss_pde:0.25705147, loss_ic:0.00292115
# epoch 47 loss_pde:0.25698915, loss_ic:0.00292893
# epoch 47 loss_pde:0.25702029, loss_ic:0.00292542
# epoch 47: loss 10.315526
# epoch 48 loss_pde:0.25702029, loss_ic:0.00292542
# epoch 48 loss_pde:0.25697264, loss_ic:0.00292455
# epoch 48 loss_pde:0.25700110, loss_ic:0.00292450
# epoch 48 loss_pde:0.25698569, loss_ic:0.00292320
# epoch 48 loss_pde:0.25697464, loss_ic:0.00292353
# epoch 48 loss_pde:0.25698555, loss_ic:0.00292342
# epoch 48 loss_pde:0.25696620, loss_ic:0.00292623
# epoch 48 loss_pde:0.25697362, loss_ic:0.00292387
# epoch 48 loss_pde:0.25696465, loss_ic:0.00292691
# epoch 48 loss_pde:0.25687972, loss_ic:0.00293590
# epoch 48 loss_pde:0.25695682, loss_ic:0.00292017
# epoch 48 loss_pde:0.25693685, loss_ic:0.00292472
# epoch 48 loss_pde:0.25690028, loss_ic:0.00292862
# epoch 48 loss_pde:0.25688934, loss_ic:0.00293024
# epoch 48 loss_pde:0.25686523, loss_ic:0.00293142
# epoch 48 loss_pde:0.25685376, loss_ic:0.00293081
# epoch 48 loss_pde:0.25684452, loss_ic:0.00293321
# epoch 48 loss_pde:0.25681728, loss_ic:0.00292787
# epoch 48 loss_pde:0.25682831, loss_ic:0.00293114
# epoch 48 loss_pde:0.25684309, loss_ic:0.00292631
# epoch 48: loss 10.315471
# epoch 49 loss_pde:0.25684309, loss_ic:0.00292631
# epoch 49 loss_pde:0.25685650, loss_ic:0.00292843
# epoch 49 loss_pde:0.25690675, loss_ic:0.00292115
# epoch 49 loss_pde:0.25690794, loss_ic:0.00292606
# epoch 49: loss 10.315451
# epoch 50 loss_pde:0.25690794, loss_ic:0.00292606
# epoch 50 loss_pde:0.25696099, loss_ic:0.00291669
# epoch 50 loss_pde:0.25694269, loss_ic:0.00292641
# epoch 50 loss_pde:0.25697231, loss_ic:0.00292554
# epoch 50 loss_pde:0.25697109, loss_ic:0.00290474
# epoch 50 loss_pde:0.25701705, loss_ic:0.00292634
# epoch 50 loss_pde:0.25694203, loss_ic:0.00292844
# epoch 50 loss_pde:0.25685784, loss_ic:0.00292930
# epoch 50 loss_pde:0.25698823, loss_ic:0.00290945
# epoch 50 loss_pde:0.25671807, loss_ic:0.00293959
# epoch 50 loss_pde:0.25653675, loss_ic:0.00292681
# epoch 50 loss_pde:0.25664121, loss_ic:0.00292265
# epoch 50 loss_pde:0.25685266, loss_ic:0.00292041
# epoch 50 loss_pde:0.25690946, loss_ic:0.00291140
# epoch 50 loss_pde:0.25688836, loss_ic:0.00290674
# epoch 50 loss_pde:0.25688958, loss_ic:0.00291655
# epoch 50 loss_pde:0.25645223, loss_ic:0.00292655
# epoch 50 loss_pde:0.25652742, loss_ic:0.00286729
# epoch 50 loss_pde:0.25665864, loss_ic:0.00293743
# epoch 50 loss_pde:0.25695559, loss_ic:0.00291150
# epoch 50: loss 10.315443
# epoch 51 loss_pde:0.25635502, loss_ic:0.00295574
# epoch 51 loss_pde:0.25653100, loss_ic:0.00292837
# epoch 51 loss_pde:0.25647080, loss_ic:0.00293078
# epoch 51 loss_pde:0.25695506, loss_ic:0.00291947
# epoch 51 loss_pde:0.25658628, loss_ic:0.00293728
# epoch 51 loss_pde:0.25665191, loss_ic:0.00295011
# epoch 51 loss_pde:0.25672406, loss_ic:0.00294881
# epoch 51 loss_pde:0.25667599, loss_ic:0.00294419
# epoch 51 loss_pde:0.25658655, loss_ic:0.00295341
# epoch 51 loss_pde:0.25672323, loss_ic:0.00292440
# epoch 51 loss_pde:0.25656274, loss_ic:0.00293301
# epoch 51 loss_pde:0.25636971, loss_ic:0.00293575
# epoch 51 loss_pde:0.25645310, loss_ic:0.00293383
# epoch 51 loss_pde:0.25642210, loss_ic:0.00293316
# epoch 51 loss_pde:0.25645301, loss_ic:0.00292738
# epoch 51 loss_pde:0.25649056, loss_ic:0.00292875
# epoch 51 loss_pde:0.25633129, loss_ic:0.00293975
# epoch 51 loss_pde:0.25631899, loss_ic:0.00294791
# epoch 51 loss_pde:0.25632456, loss_ic:0.00295486
# epoch 51 loss_pde:0.25629801, loss_ic:0.00296592
# epoch 51: loss 10.315258
# epoch 52 loss_pde:0.25642744, loss_ic:0.00294843
# epoch 52 loss_pde:0.25667447, loss_ic:0.00296234
# epoch 52 loss_pde:0.25666392, loss_ic:0.00295454
# epoch 52 loss_pde:0.25675407, loss_ic:0.00293746
# epoch 52 loss_pde:0.25714144, loss_ic:0.00289826
# epoch 52 loss_pde:0.25707889, loss_ic:0.00290895
# epoch 52 loss_pde:0.25696543, loss_ic:0.00291969
# epoch 52 loss_pde:0.25698045, loss_ic:0.00292606
# epoch 52 loss_pde:0.25688300, loss_ic:0.00293529
# epoch 52 loss_pde:0.25682142, loss_ic:0.00294330
# epoch 52 loss_pde:0.25673956, loss_ic:0.00294502
# epoch 52 loss_pde:0.25673494, loss_ic:0.00294452
# epoch 52 loss_pde:0.25671908, loss_ic:0.00294300
# epoch 52 loss_pde:0.25673336, loss_ic:0.00293985
# epoch 52 loss_pde:0.25669122, loss_ic:0.00293882
# epoch 52 loss_pde:0.25673407, loss_ic:0.00293394
# epoch 52 loss_pde:0.25667182, loss_ic:0.00293590
# epoch 52 loss_pde:0.25668153, loss_ic:0.00293285
# epoch 52 loss_pde:0.25667405, loss_ic:0.00293400
# epoch 52 loss_pde:0.25665477, loss_ic:0.00293793
# epoch 52: loss 10.315040
# epoch 53 loss_pde:0.25667971, loss_ic:0.00293267
# epoch 53 loss_pde:0.25669926, loss_ic:0.00293602
# epoch 53 loss_pde:0.25670800, loss_ic:0.00293657
# epoch 53 loss_pde:0.25671348, loss_ic:0.00294345
# epoch 53 loss_pde:0.25670522, loss_ic:0.00294394
# epoch 53 loss_pde:0.25670907, loss_ic:0.00294687
# epoch 53 loss_pde:0.25673467, loss_ic:0.00294499
# epoch 53 loss_pde:0.25665584, loss_ic:0.00295590
# epoch 53 loss_pde:0.25669369, loss_ic:0.00295060
# epoch 53 loss_pde:0.25668243, loss_ic:0.00294978
# epoch 53 loss_pde:0.25669548, loss_ic:0.00294418
# epoch 53 loss_pde:0.25665313, loss_ic:0.00295441
# epoch 53 loss_pde:0.25664085, loss_ic:0.00295009
# epoch 53 loss_pde:0.25665128, loss_ic:0.00294947
# epoch 53: loss 10.314934
# epoch 54 loss_pde:0.25665128, loss_ic:0.00294947
# epoch 54 loss_pde:0.25665152, loss_ic:0.00294747
# epoch 54 loss_pde:0.25665522, loss_ic:0.00294636
# epoch 54 loss_pde:0.25665665, loss_ic:0.00294542
# epoch 54: loss 10.314882
# epoch 55 loss_pde:0.25665665, loss_ic:0.00294542
# epoch 55 loss_pde:0.25665399, loss_ic:0.00294315
# epoch 55 loss_pde:0.25662827, loss_ic:0.00294682
# epoch 55 loss_pde:0.25669849, loss_ic:0.00293288
# epoch 55 loss_pde:0.25653207, loss_ic:0.00296549
# epoch 55 loss_pde:0.25654012, loss_ic:0.00297400
# epoch 55 loss_pde:0.25669077, loss_ic:0.00295811
# epoch 55 loss_pde:0.25675902, loss_ic:0.00292897
# epoch 55 loss_pde:0.25657755, loss_ic:0.00294038
# epoch 55 loss_pde:0.25669593, loss_ic:0.00292518
# epoch 55 loss_pde:0.25660554, loss_ic:0.00292643
# epoch 55 loss_pde:0.25651506, loss_ic:0.00294039
# epoch 55 loss_pde:0.25647086, loss_ic:0.00294069
# epoch 55 loss_pde:0.25642186, loss_ic:0.00294879
# epoch 55 loss_pde:0.25636211, loss_ic:0.00297295
# epoch 55 loss_pde:0.25675642, loss_ic:0.00289644
# epoch 55 loss_pde:0.25668627, loss_ic:0.00289896
# epoch 55 loss_pde:0.25647217, loss_ic:0.00292698
# epoch 55 loss_pde:0.25637561, loss_ic:0.00294332
# epoch 55 loss_pde:0.25640160, loss_ic:0.00294762
# epoch 55: loss 10.314878
# epoch 56 loss_pde:0.25636482, loss_ic:0.00294715
# epoch 56 loss_pde:0.25649321, loss_ic:0.00293834
# epoch 56 loss_pde:0.25649744, loss_ic:0.00292838
# epoch 56 loss_pde:0.25650647, loss_ic:0.00293217
# epoch 56 loss_pde:0.25664896, loss_ic:0.00290456
# epoch 56 loss_pde:0.25659326, loss_ic:0.00291017
# epoch 56 loss_pde:0.25655338, loss_ic:0.00291302
# epoch 56 loss_pde:0.25653335, loss_ic:0.00291185
# epoch 56 loss_pde:0.25651640, loss_ic:0.00291457
# epoch 56 loss_pde:0.25657105, loss_ic:0.00290681
# epoch 56 loss_pde:0.25657833, loss_ic:0.00290614
# epoch 56 loss_pde:0.25662667, loss_ic:0.00290628
# epoch 56 loss_pde:0.25667974, loss_ic:0.00289910
# epoch 56 loss_pde:0.25671464, loss_ic:0.00290075
# epoch 56: loss 10.314718
# epoch 57 loss_pde:0.25671464, loss_ic:0.00290075
# epoch 57 loss_pde:0.25677761, loss_ic:0.00289374
# epoch 57 loss_pde:0.25680971, loss_ic:0.00289914
# epoch 57 loss_pde:0.25681332, loss_ic:0.00290117
# epoch 57 loss_pde:0.25676242, loss_ic:0.00291611
# epoch 57 loss_pde:0.25667563, loss_ic:0.00294517
# epoch 57 loss_pde:0.25677520, loss_ic:0.00293020
# epoch 57 loss_pde:0.25658840, loss_ic:0.00294118
# epoch 57 loss_pde:0.25657010, loss_ic:0.00292252
# epoch 57 loss_pde:0.25644550, loss_ic:0.00293010
# epoch 57 loss_pde:0.25662762, loss_ic:0.00290056
# epoch 57 loss_pde:0.25651175, loss_ic:0.00292137
# epoch 57 loss_pde:0.25653389, loss_ic:0.00291195
# epoch 57 loss_pde:0.25664067, loss_ic:0.00291276
# epoch 57 loss_pde:0.25660384, loss_ic:0.00290264
# epoch 57 loss_pde:0.25667500, loss_ic:0.00289922
# epoch 57 loss_pde:0.25648478, loss_ic:0.00290621
# epoch 57 loss_pde:0.25652269, loss_ic:0.00289737
# epoch 57 loss_pde:0.25653756, loss_ic:0.00289234
# epoch 57 loss_pde:0.25657076, loss_ic:0.00288394
# epoch 57: loss 10.314678
# epoch 58 loss_pde:0.25648123, loss_ic:0.00289112
# epoch 58 loss_pde:0.25654972, loss_ic:0.00288330
# ...
# epoch 1908 loss_pde:0.17147134, loss_ic:0.00106752
# epoch 1908 loss_pde:0.17093714, loss_ic:0.00105469
# epoch 1908 loss_pde:0.17107868, loss_ic:0.00109947
# epoch 1908 loss_pde:0.17105046, loss_ic:0.00108569
# epoch 1908 loss_pde:0.17104727, loss_ic:0.00106083
# epoch 1908 loss_pde:0.17103453, loss_ic:0.00104177
# epoch 1908 loss_pde:0.17094024, loss_ic:0.00103447
# epoch 1908: loss 10.206457
# epoch 1909 loss_pde:0.17072426, loss_ic:0.00103841
# epoch 1909 loss_pde:0.17018573, loss_ic:0.00106563
# epoch 1909 loss_pde:0.16935180, loss_ic:0.00110784
# epoch 1909 loss_pde:0.16848156, loss_ic:0.00116532
# epoch 1909 loss_pde:0.16759914, loss_ic:0.00121771
# epoch 1909 loss_pde:0.16646290, loss_ic:0.00127833
# epoch 1909 loss_pde:0.16543688, loss_ic:0.00132114
# epoch 1909 loss_pde:0.16444798, loss_ic:0.00135049
# epoch 1909 loss_pde:0.16379696, loss_ic:0.00135232
# epoch 1909 loss_pde:0.16324702, loss_ic:0.00132574
# epoch 1909 loss_pde:0.16276336, loss_ic:0.00128079
# epoch 1909 loss_pde:0.16235967, loss_ic:0.00119550
# epoch 1909 loss_pde:0.16225134, loss_ic:0.00110563
# epoch 1909 loss_pde:0.16214727, loss_ic:0.00103407
# epoch 1909 loss_pde:0.16217636, loss_ic:0.00099571
# epoch 1909 loss_pde:0.16196623, loss_ic:0.00097323
# epoch 1909 loss_pde:0.16149929, loss_ic:0.00098008
# epoch 1909 loss_pde:0.16069999, loss_ic:0.00101392
# epoch 1909 loss_pde:0.15964240, loss_ic:0.00107055
# epoch 1909 loss_pde:0.15904668, loss_ic:0.00113537
# epoch 1909: loss 10.198558
# epoch 1910 loss_pde:0.15712105, loss_ic:0.00119091
# epoch 1910 loss_pde:0.15688308, loss_ic:0.00119361
# epoch 1910 loss_pde:0.15679079, loss_ic:0.00119199
# epoch 1910 loss_pde:0.15678199, loss_ic:0.00116093
# epoch 1910 loss_pde:0.15687707, loss_ic:0.00115474
# epoch 1910 loss_pde:0.15688266, loss_ic:0.00115009
# epoch 1910 loss_pde:0.15667665, loss_ic:0.00115166
# epoch 1910 loss_pde:0.15659592, loss_ic:0.00115726
# epoch 1910 loss_pde:0.15627356, loss_ic:0.00115916
# epoch 1910 loss_pde:0.15609628, loss_ic:0.00117269
# epoch 1910 loss_pde:0.15593585, loss_ic:0.00116756
# epoch 1910 loss_pde:0.15582070, loss_ic:0.00115918
# epoch 1910 loss_pde:0.15553962, loss_ic:0.00116993
# epoch 1910 loss_pde:0.15526244, loss_ic:0.00115955
# epoch 1910 loss_pde:0.15442720, loss_ic:0.00120994
# epoch 1910 loss_pde:0.15406789, loss_ic:0.00121582
# epoch 1910 loss_pde:0.15320460, loss_ic:0.00126080
# epoch 1910 loss_pde:0.15266560, loss_ic:0.00128923
# epoch 1910 loss_pde:0.15171003, loss_ic:0.00133579
# epoch 1910 loss_pde:0.15066415, loss_ic:0.00138213
# epoch 1910: loss 10.186215
# epoch 1911 loss_pde:0.14926243, loss_ic:0.00147153
# epoch 1911 loss_pde:0.14820999, loss_ic:0.00149412
# epoch 1911 loss_pde:0.14647946, loss_ic:0.00158041
# epoch 1911 loss_pde:0.14560409, loss_ic:0.00161524
# epoch 1911 loss_pde:0.14545801, loss_ic:0.00152514
# epoch 1911 loss_pde:0.14372653, loss_ic:0.00175794
# epoch 1911 loss_pde:0.14420767, loss_ic:0.00156631
# epoch 1911 loss_pde:0.14522991, loss_ic:0.00145917
# epoch 1911 loss_pde:0.14470515, loss_ic:0.00148397
# epoch 1911 loss_pde:0.14535336, loss_ic:0.00140831
# epoch 1911 loss_pde:0.14498416, loss_ic:0.00141582
# epoch 1911 loss_pde:0.14446677, loss_ic:0.00141600
# epoch 1911 loss_pde:0.14340635, loss_ic:0.00149561
# epoch 1911 loss_pde:0.14346071, loss_ic:0.00144769
# epoch 1911 loss_pde:0.14353485, loss_ic:0.00141986
# epoch 1911 loss_pde:0.14390637, loss_ic:0.00132946
# epoch 1911 loss_pde:0.14367138, loss_ic:0.00133228
# epoch 1911 loss_pde:0.14382273, loss_ic:0.00130941
# epoch 1911 loss_pde:0.14372900, loss_ic:0.00131389
# epoch 1911 loss_pde:0.14384231, loss_ic:0.00129350
# epoch 1911: loss 10.177100
# epoch 1912 loss_pde:0.14355463, loss_ic:0.00129414
# epoch 1912 loss_pde:0.14344864, loss_ic:0.00126329
# epoch 1912 loss_pde:0.14266305, loss_ic:0.00130094
# epoch 1912 loss_pde:0.14216386, loss_ic:0.00131174
# epoch 1912 loss_pde:0.14154689, loss_ic:0.00133245
# epoch 1912 loss_pde:0.14080602, loss_ic:0.00136404
# epoch 1912 loss_pde:0.14040117, loss_ic:0.00137360
# epoch 1912 loss_pde:0.13989523, loss_ic:0.00138567
# epoch 1912 loss_pde:0.13970256, loss_ic:0.00137598
# epoch 1912 loss_pde:0.13946994, loss_ic:0.00137133
# epoch 1912 loss_pde:0.13931198, loss_ic:0.00135890
# epoch 1912 loss_pde:0.13893102, loss_ic:0.00135670
# epoch 1912 loss_pde:0.13883454, loss_ic:0.00132732
# epoch 1912 loss_pde:0.13828819, loss_ic:0.00133726
# epoch 1912 loss_pde:0.13787121, loss_ic:0.00133473
# epoch 1912 loss_pde:0.13746455, loss_ic:0.00131859
# epoch 1912 loss_pde:0.13725418, loss_ic:0.00129035
# epoch 1912 loss_pde:0.13601489, loss_ic:0.00135902
# epoch 1912 loss_pde:0.13612328, loss_ic:0.00129705
# epoch 1912 loss_pde:0.13566564, loss_ic:0.00129944
# epoch 1912: loss 10.164312
# epoch 1913 loss_pde:0.13501687, loss_ic:0.00130591
# epoch 1913 loss_pde:0.13446596, loss_ic:0.00130769
# epoch 1913 loss_pde:0.13374776, loss_ic:0.00133200
# epoch 1913 loss_pde:0.13331462, loss_ic:0.00133389
# epoch 1913 loss_pde:0.13347356, loss_ic:0.00140772
# epoch 1913 loss_pde:0.13294797, loss_ic:0.00137742
# epoch 1913 loss_pde:0.13282934, loss_ic:0.00135482
# epoch 1913 loss_pde:0.13276918, loss_ic:0.00134170
# epoch 1913 loss_pde:0.13284735, loss_ic:0.00131596
# epoch 1913 loss_pde:0.13288529, loss_ic:0.00128179
# epoch 1913 loss_pde:0.13300519, loss_ic:0.00122022
# epoch 1913 loss_pde:0.13252167, loss_ic:0.00118575
# epoch 1913 loss_pde:0.13247868, loss_ic:0.00112924
# epoch 1913 loss_pde:0.13221821, loss_ic:0.00112046
# epoch 1913 loss_pde:0.13165024, loss_ic:0.00113501
# epoch 1913 loss_pde:0.13129248, loss_ic:0.00114514
# epoch 1913 loss_pde:0.13113756, loss_ic:0.00113246
# epoch 1913 loss_pde:0.13073327, loss_ic:0.00113373
# epoch 1913 loss_pde:0.13061003, loss_ic:0.00111578
# epoch 1913 loss_pde:0.13269065, loss_ic:0.00094422
# epoch 1913: loss 10.157241
# epoch 1914 loss_pde:0.13137852, loss_ic:0.00099139
# epoch 1914 loss_pde:0.13091220, loss_ic:0.00101216
# epoch 1914 loss_pde:0.13036887, loss_ic:0.00104232
# epoch 1914 loss_pde:0.12994906, loss_ic:0.00106894
# epoch 1914 loss_pde:0.12974705, loss_ic:0.00107384
# epoch 1914 loss_pde:0.12932298, loss_ic:0.00109712
# epoch 1914 loss_pde:0.12902281, loss_ic:0.00110461
# epoch 1914 loss_pde:0.12862727, loss_ic:0.00111113
# epoch 1914 loss_pde:0.12836762, loss_ic:0.00110806
# epoch 1914 loss_pde:0.12800390, loss_ic:0.00110701
# epoch 1914 loss_pde:0.12765737, loss_ic:0.00110603
# epoch 1914 loss_pde:0.12723011, loss_ic:0.00110377
# epoch 1914 loss_pde:0.12685756, loss_ic:0.00110165
# epoch 1914 loss_pde:0.12622739, loss_ic:0.00111623
# epoch 1914 loss_pde:0.12561755, loss_ic:0.00113131
# epoch 1914 loss_pde:0.12495971, loss_ic:0.00115223
# epoch 1914 loss_pde:0.12439099, loss_ic:0.00117441
# epoch 1914 loss_pde:0.12380367, loss_ic:0.00120183
# epoch 1914 loss_pde:0.12306815, loss_ic:0.00124296
# epoch 1914 loss_pde:0.12239651, loss_ic:0.00129040
# epoch 1914: loss 10.152075
# epoch 1915 loss_pde:0.12162133, loss_ic:0.00133792
# epoch 1915 loss_pde:0.12132446, loss_ic:0.00136271
# epoch 1915 loss_pde:0.12027915, loss_ic:0.00144263
# epoch 1915 loss_pde:0.12015008, loss_ic:0.00142552
# epoch 1915 loss_pde:0.12022431, loss_ic:0.00139845
# epoch 1915 loss_pde:0.12023366, loss_ic:0.00138326
# epoch 1915 loss_pde:0.12006167, loss_ic:0.00137934
# epoch 1915 loss_pde:0.12012759, loss_ic:0.00135462
# epoch 1915 loss_pde:0.12021162, loss_ic:0.00133236
# epoch 1915 loss_pde:0.11979590, loss_ic:0.00133816
# epoch 1915 loss_pde:0.11975142, loss_ic:0.00132379
# epoch 1915 loss_pde:0.11944797, loss_ic:0.00132928
# epoch 1915 loss_pde:0.11924343, loss_ic:0.00133638
# epoch 1915 loss_pde:0.11961446, loss_ic:0.00133301
# epoch 1915 loss_pde:0.11939543, loss_ic:0.00140183
# epoch 1915 loss_pde:0.11934322, loss_ic:0.00138221
# epoch 1915 loss_pde:0.11942907, loss_ic:0.00136102
# epoch 1915 loss_pde:0.11956047, loss_ic:0.00134593
# epoch 1915 loss_pde:0.11973576, loss_ic:0.00131586
# epoch 1915 loss_pde:0.11962724, loss_ic:0.00131684
# epoch 1915: loss 10.147919
# epoch 1916 loss_pde:0.11959319, loss_ic:0.00131546
# epoch 1916 loss_pde:0.11969863, loss_ic:0.00129041
# epoch 1916 loss_pde:0.11949158, loss_ic:0.00129375
# epoch 1916 loss_pde:0.11934058, loss_ic:0.00130026
# epoch 1916 loss_pde:0.11916021, loss_ic:0.00135710
# epoch 1916 loss_pde:0.11912526, loss_ic:0.00134566
# epoch 1916 loss_pde:0.11882506, loss_ic:0.00136899
# epoch 1916 loss_pde:0.11850697, loss_ic:0.00139320
# epoch 1916 loss_pde:0.11851923, loss_ic:0.00138926
# epoch 1916 loss_pde:0.11840910, loss_ic:0.00138552
# epoch 1916 loss_pde:0.11847827, loss_ic:0.00137263
# epoch 1916 loss_pde:0.11829817, loss_ic:0.00138521
# epoch 1916 loss_pde:0.11801985, loss_ic:0.00138073
# epoch 1916 loss_pde:0.11776958, loss_ic:0.00137873
# epoch 1916 loss_pde:0.11749895, loss_ic:0.00137159
# epoch 1916 loss_pde:0.11727887, loss_ic:0.00137438
# epoch 1916 loss_pde:0.11704758, loss_ic:0.00136494
# epoch 1916 loss_pde:0.11681774, loss_ic:0.00135966
# epoch 1916 loss_pde:0.11799028, loss_ic:0.00125702
# epoch 1916 loss_pde:0.11701830, loss_ic:0.00128798
# epoch 1916: loss 10.140897
# epoch 1917 loss_pde:0.11650444, loss_ic:0.00131564
# epoch 1917 loss_pde:0.11619376, loss_ic:0.00132664
# epoch 1917 loss_pde:0.11613832, loss_ic:0.00132150
# epoch 1917 loss_pde:0.11631599, loss_ic:0.00129568
# epoch 1917 loss_pde:0.11632167, loss_ic:0.00127969
# epoch 1917 loss_pde:0.11639477, loss_ic:0.00126321
# epoch 1917 loss_pde:0.11653090, loss_ic:0.00123224
# epoch 1917 loss_pde:0.11654253, loss_ic:0.00121434
# epoch 1917 loss_pde:0.11670887, loss_ic:0.00117983
# epoch 1917 loss_pde:0.11664433, loss_ic:0.00117068
# epoch 1917 loss_pde:0.11654174, loss_ic:0.00116157
# epoch 1917 loss_pde:0.11635913, loss_ic:0.00115970
# epoch 1917 loss_pde:0.11622050, loss_ic:0.00115896
# epoch 1917 loss_pde:0.11603728, loss_ic:0.00115983
# epoch 1917 loss_pde:0.11582525, loss_ic:0.00115651
# epoch 1917 loss_pde:0.11571191, loss_ic:0.00114408
# epoch 1917 loss_pde:0.11540057, loss_ic:0.00114796
# epoch 1917 loss_pde:0.11568968, loss_ic:0.00111634
# epoch 1917 loss_pde:0.11553814, loss_ic:0.00112333
# epoch 1917 loss_pde:0.11790337, loss_ic:0.00102155
# epoch 1917: loss 10.135945
# epoch 1918 loss_pde:0.11690210, loss_ic:0.00104050
# epoch 1918 loss_pde:0.11612289, loss_ic:0.00108165
# epoch 1918 loss_pde:0.11591064, loss_ic:0.00108729
# epoch 1918 loss_pde:0.11597341, loss_ic:0.00108391
# epoch 1918 loss_pde:0.11594070, loss_ic:0.00108424
# epoch 1918 loss_pde:0.11587762, loss_ic:0.00108423
# epoch 1918 loss_pde:0.11578528, loss_ic:0.00108317
# epoch 1918 loss_pde:0.11565388, loss_ic:0.00108091
# epoch 1918 loss_pde:0.11547188, loss_ic:0.00106601
# epoch 1918 loss_pde:0.11512858, loss_ic:0.00106383
# epoch 1918 loss_pde:0.11514026, loss_ic:0.00105289
# epoch 1918 loss_pde:0.11515929, loss_ic:0.00103312
# epoch 1918 loss_pde:0.11532937, loss_ic:0.00100796
# epoch 1918 loss_pde:0.11539429, loss_ic:0.00099451
# epoch 1918 loss_pde:0.11548232, loss_ic:0.00098149
# epoch 1918 loss_pde:0.11544620, loss_ic:0.00097832
# epoch 1918 loss_pde:0.11715534, loss_ic:0.00089322
# epoch 1918 loss_pde:0.11633510, loss_ic:0.00091480
# epoch 1918 loss_pde:0.11580205, loss_ic:0.00094603
# epoch 1918 loss_pde:0.11554074, loss_ic:0.00095948
# epoch 1918: loss 10.133136
# epoch 1919 loss_pde:0.11525488, loss_ic:0.00097638
# epoch 1919 loss_pde:0.11501338, loss_ic:0.00098500
# epoch 1919 loss_pde:0.11477889, loss_ic:0.00098893
# epoch 1919 loss_pde:0.11477749, loss_ic:0.00094842
# epoch 1919 loss_pde:0.11473332, loss_ic:0.00094248
# epoch 1919 loss_pde:0.11484849, loss_ic:0.00092535
# epoch 1919 loss_pde:0.11490794, loss_ic:0.00090687
# epoch 1919 loss_pde:0.11490155, loss_ic:0.00089191
# epoch 1919 loss_pde:0.11477292, loss_ic:0.00088237
# epoch 1919 loss_pde:0.11463193, loss_ic:0.00087391
# epoch 1919 loss_pde:0.11434685, loss_ic:0.00086549
# epoch 1919 loss_pde:0.11393518, loss_ic:0.00086451
# epoch 1919 loss_pde:0.11339587, loss_ic:0.00086917
# epoch 1919 loss_pde:0.11293294, loss_ic:0.00087478
# epoch 1919 loss_pde:0.11246306, loss_ic:0.00088632
# epoch 1919 loss_pde:0.11200505, loss_ic:0.00090023
# epoch 1919 loss_pde:0.11177175, loss_ic:0.00090850
# epoch 1919 loss_pde:0.11151022, loss_ic:0.00090603
# epoch 1919 loss_pde:0.11189023, loss_ic:0.00087836
# epoch 1919 loss_pde:0.11162633, loss_ic:0.00088779
# epoch 1919: loss 10.130722
# epoch 1920 loss_pde:0.11143647, loss_ic:0.00089148
# epoch 1920 loss_pde:0.11138607, loss_ic:0.00089449
# epoch 1920 loss_pde:0.11152456, loss_ic:0.00088874
# epoch 1920 loss_pde:0.11158404, loss_ic:0.00088687
# epoch 1920 loss_pde:0.11166985, loss_ic:0.00088173
# epoch 1920 loss_pde:0.11190626, loss_ic:0.00082561
# epoch 1920 loss_pde:0.11209048, loss_ic:0.00081483
# epoch 1920 loss_pde:0.11191311, loss_ic:0.00083001
# epoch 1920 loss_pde:0.11180942, loss_ic:0.00083695
# epoch 1920 loss_pde:0.11160449, loss_ic:0.00084796
# epoch 1920 loss_pde:0.11132342, loss_ic:0.00086256
# epoch 1920 loss_pde:0.11105552, loss_ic:0.00087518
# epoch 1920 loss_pde:0.11081015, loss_ic:0.00088613
# epoch 1920 loss_pde:0.11059665, loss_ic:0.00089707
# epoch 1920 loss_pde:0.11045247, loss_ic:0.00090104
# epoch 1920 loss_pde:0.11038139, loss_ic:0.00090327
# epoch 1920 loss_pde:0.11037263, loss_ic:0.00089947
# epoch 1920 loss_pde:0.11038141, loss_ic:0.00089500
# epoch 1920 loss_pde:0.11046799, loss_ic:0.00088478
# epoch 1920 loss_pde:0.11039224, loss_ic:0.00087868
# epoch 1920: loss 10.127397
# epoch 1921 loss_pde:0.11063235, loss_ic:0.00084988
# epoch 1921 loss_pde:0.11073449, loss_ic:0.00084865
# epoch 1921 loss_pde:0.11033711, loss_ic:0.00087744
# epoch 1921 loss_pde:0.11028986, loss_ic:0.00087822
# epoch 1921 loss_pde:0.11011323, loss_ic:0.00088525
# epoch 1921 loss_pde:0.11005627, loss_ic:0.00088018
# epoch 1921 loss_pde:0.10995507, loss_ic:0.00087786
# epoch 1921 loss_pde:0.10987551, loss_ic:0.00088084
# epoch 1921 loss_pde:0.10984892, loss_ic:0.00087748
# epoch 1921 loss_pde:0.10988081, loss_ic:0.00087067
# epoch 1921 loss_pde:0.10982931, loss_ic:0.00087277
# epoch 1921 loss_pde:0.10992098, loss_ic:0.00085415
# epoch 1921 loss_pde:0.10973716, loss_ic:0.00086637
# epoch 1921 loss_pde:0.10969909, loss_ic:0.00085551
# epoch 1921 loss_pde:0.10992712, loss_ic:0.00083909
# epoch 1921 loss_pde:0.10994880, loss_ic:0.00083682
# epoch 1921 loss_pde:0.11000017, loss_ic:0.00082778
# epoch 1921 loss_pde:0.10992923, loss_ic:0.00082861
# epoch 1921 loss_pde:0.10974500, loss_ic:0.00082623
# epoch 1921 loss_pde:0.10903291, loss_ic:0.00089017
# epoch 1921: loss 10.125186
# epoch 1922 loss_pde:0.10991382, loss_ic:0.00087065
# epoch 1922 loss_pde:0.10917675, loss_ic:0.00084724
# epoch 1922 loss_pde:0.10911667, loss_ic:0.00081542
# epoch 1922 loss_pde:0.10912351, loss_ic:0.00080533
# epoch 1922 loss_pde:0.10914125, loss_ic:0.00079068
# epoch 1922 loss_pde:0.10927513, loss_ic:0.00076474
# epoch 1922 loss_pde:0.10934401, loss_ic:0.00073944
# epoch 1922 loss_pde:0.10944630, loss_ic:0.00071345
# epoch 1922 loss_pde:0.10943127, loss_ic:0.00068828
# epoch 1922 loss_pde:0.10944805, loss_ic:0.00066945
# epoch 1922 loss_pde:0.10930756, loss_ic:0.00066196
# epoch 1922 loss_pde:0.10917178, loss_ic:0.00066158
# epoch 1922 loss_pde:0.10898755, loss_ic:0.00066825
# epoch 1922 loss_pde:0.10879514, loss_ic:0.00067941
# epoch 1922 loss_pde:0.10890390, loss_ic:0.00067722
# epoch 1922 loss_pde:0.10855410, loss_ic:0.00069508
# epoch 1922 loss_pde:0.10843573, loss_ic:0.00070271
# epoch 1922 loss_pde:0.10828735, loss_ic:0.00071124
# epoch 1922 loss_pde:0.10820605, loss_ic:0.00071662
# epoch 1922 loss_pde:0.10813423, loss_ic:0.00072088
# epoch 1922: loss 10.124596
# epoch 1923 loss_pde:0.10810241, loss_ic:0.00072303
# epoch 1923 loss_pde:0.10806235, loss_ic:0.00072500
# epoch 1923 loss_pde:0.10796078, loss_ic:0.00073075
# epoch 1923 loss_pde:0.10785677, loss_ic:0.00073656
# epoch 1923 loss_pde:0.10729289, loss_ic:0.00078414
# epoch 1923 loss_pde:0.10742231, loss_ic:0.00076720
# epoch 1923 loss_pde:0.10757621, loss_ic:0.00074670
# epoch 1923 loss_pde:0.10750151, loss_ic:0.00074281
# epoch 1923 loss_pde:0.10749995, loss_ic:0.00073230
# epoch 1923 loss_pde:0.10724053, loss_ic:0.00072987
# epoch 1923 loss_pde:0.10706782, loss_ic:0.00072843
# epoch 1923 loss_pde:0.10681439, loss_ic:0.00073087
# epoch 1923 loss_pde:0.10663991, loss_ic:0.00070334
# epoch 1923 loss_pde:0.10627584, loss_ic:0.00072135
# epoch 1923 loss_pde:0.10599673, loss_ic:0.00073386
# epoch 1923 loss_pde:0.10581866, loss_ic:0.00074361
# epoch 1923 loss_pde:0.10574770, loss_ic:0.00074287
# epoch 1923 loss_pde:0.10572535, loss_ic:0.00074210

# %%
device1 = torch.device("cpu")
model = torch.save('1.pt')

# %%
model_path = '1.pth'
model = torch.load(model_path, map_location=torch.device('cpu'))
model = model.to(device)

# %%
x = np.linspace(0.0, 2.0, 100)                                  
t = np.linspace(0.5, 0.5, 1)                                        
t_grid, x_grid = np.meshgrid(t, x)                              
T = t_grid.flatten()[:, None]                                   
X = x_grid.flatten()[:, None]                                   
x_test = np.hstack((T, X))                                      
x_test = torch.tensor(x_test, requires_grad=True, dtype=torch.float32).to(device)
u_pred = to_numpy(model(x_test))
res = to_numpy(model.res_pde(x_test))
d   = to_numpy(model.lambda_pde(x_test))

#loss = model.loss_pde(x_test)                                 

import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x[:],u_pred[:,0])
plt.show()

# %%
plt.scatter(x[:],1/d[:,0])

plt.show()

# %%
new_array = np.array(u_pred[:,0])
file = open("burgers_u_we_11500.dat", "w+")
for i in range(u_pred.shape[0]):
    print(f'{x[i]}  {u_pred[i,0]} ',file=file)
file.close()

# %%
new_array = np.array(res[:,0])
file = open("burgers_res_w_5000.dat", "w+")
for i in range(u_pred.shape[0]):
    print(f'{x[i]}  {res[i,0]} ',file=file)
file.close()

# %%
file = open("burgers_d_w_14931.dat", "w+")
for i in range(d.shape[0]):
    print(f'{x[i]}  {1/d[i,0]} ',file=file)
file.close()
