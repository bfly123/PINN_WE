# %% [markdown]
# # Burgers equation
#
# This code is modified from the code https://github.com/alexpapados/Physics-Informed-Deep-Learning-Solid-and-Fluid-Mechanics
#
# The paper about this work can ref https://www.researchgate.net/publication/359480166_Discontinuity_Computing_with_Physics-Informed_Neural_Network

# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
torch.manual_seed(124)
np.random.seed(124)

# %%
def train(epoch):
    model.train()
    model.it = epoch
    def closure():
        optimizer.zero_grad()                                              
        loss_pde = model.loss_pde(x_int,mark)                                   
        loss_ic = model.loss_ic(x_ic, u_ic,mark_ic)  
        loss_bd = model.loss_bd(x_bdL,u_bdL_in,mark_bd) #+model.loss_bd(x_bdR,u_bdR_in,mark_bd) 
        #loss_bd = model.loss_bd1(x_bdL,x_bdR,mark_bd) #+model.loss_bd(x_bdR,u_bdR_in,mark_bd) 
        loss = loss_pde + 10*(loss_ic+loss_bd)                                       

        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f}')
        #model.it = model.it + 1
        #outputfile = open('loss_history_burgers.dat','a+')
        #print(f'{model.it}  {loss_pde:.6f}  {loss_ic:.6f}  {loss:.6f}',file=outputfile)
        #outputfile.close() 
        loss.backward()
        return loss

    loss = optimizer.step(closure)
    loss_value = loss.item() if not isinstance(loss, float) else loss
    print(f'epoch {epoch}: loss {loss_value:.6f}')
    
def gradients(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

def to_numpy(input):
    if isinstance(input, torch.Tensor):
        return input.detach().cpu().numpy()
    elif isinstance(input, np.ndarray):
        return input
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                        'np.ndarray, but got {}'.format(type(input)))

def IC(x):
    N = len(x)
    u_init = np.zeros((x.shape[0]))                                                
    for i in range(N):
        u_init[i] = np.sin(np.pi*(x[i,1]))
    return u_init

class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.net = nn.Sequential()                                                  
        self.net.add_module('Linear_layer_1', nn.Linear(2, 30))                     
        self.net.add_module('Tanh_layer_1', nn.Tanh())                              

        for num in range(2, 5):                                                     
            self.net.add_module('Linear_layer_%d' % (num), nn.Linear(30, 30))       
            self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 
        self.net.add_module('Linear_layer_final', nn.Linear(30, 1))                 

    def forward(self, x):
        return self.net(x)

    def loss_pde(self, x,mark):
        y = self.net(x)                                                
        u = y[:, 0:1]
        

        du_g = gradients(u, x)[0]                                 
        u_t,u_x = du_g[:, :1],du_g[:,1:]
      #  d = 0.1*(abs(u_x)-u_x) + 1
        d = 1
        f = ((mark*(u_t - u_x))**2).mean() 
         
        return f
    def res_pde(self,x):
        y = self.net(x)
        Res = np.zeros((x.shape[0]))                                  
        
        u = y[:, 0:1]
        du_g = gradients(u, x)[0]                                  
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        Res = (u_t - u_x)**2 
        return Res 
    
    def lambda_pde(self,x):
        y = self.net(x)
        Res = np.zeros((x.shape[0]))                                  
        
        u = y[:, 0:1]
        du_g = gradients(u, x)[0]                                  
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        d = 0.1*(abs(u_x)-u_x) + 1
        return  d

    def loss_ic(self, x_ic, u_ic,mark_ic):
        y_ic = self.net(x_ic)                                                      
        u_ic_nn = y_ic[:, 0]
        loss_ics = ((mark_ic*(u_ic_nn - u_ic)) ** 2).mean()
        return loss_ics
    def loss_bd(self, x_bd,u_bd_in,mark_bd):
        y_bd = self.net(x_bd)                                                      
        u_bd = y_bd[:, 0]
        loss_bds = (((u_bd - u_bd_in)) ** 2).mean()
        return loss_bds
    def loss_bd1(self, x_bdL,x_bdR,mark_bd):
        y_bdL = self.net(x_bdL)                                                      
        y_bdR = self.net(x_bdR)                                                      
        loss_bds = (((y_bdL[:,0] - y_bdR[:,0])) ** 2).mean()
        return loss_bds
def BD_perid(X,T,N):
    xL = np.zeros((N,2)) 
    xR = np.zeros((N,2)) 
    
    for i in range(N):
        t = T*(i+1)/N
        xL[i,0] = t
        xL[i,1] = 0
        xR[i,0] = t
        xR[i,1] = X
    return xL,xR
def BD(X):
    N =X.shape[0]
    u = np.zeros((N,1)) 
    
    for i in range(N):
        x = X[i,1]
        t = X[i,0]
        u[i,0] =  np.sin(np.pi*(x+t))
    return u
def Mark(x):
    N =x.shape[0]
    mark = np.zeros((N,1)) 
    
    for i in range(N):
        if (x[i,0] < 0 ):
            mark[i,0] = 1.0
        elif ( x[i,0]< 1 and x[i,1]<1):
            mark[i,0] = 1.0
        else:
            mark[i,0] =  1.0 
    return mark

# %%
device = torch.device('cuda')                                      
num_x = 1000                                                        
num_t = 1000                                                        
num_i_train = 1000                                           
num_f_train = 50000                                            
Time = 2
L = 2
x = np.linspace(0, L, num_x)                                   
t = np.linspace(0, Time, num_t)                                   
t_grid, x_grid = np.meshgrid(t, x)                             
T = t_grid.flatten()[:, None]                                  
X = x_grid.flatten()[:, None]                                  

id_ic = np.random.choice(num_x, num_i_train, replace=False)    
id_f = np.random.choice(num_x*num_t, num_f_train, replace=False)

x_ic = x_grid[id_ic, 0][:, None]                               
t_ic = t_grid[id_ic, 0][:, None]                               
x_ic_train = np.hstack((t_ic, x_ic))                               
u_ic_train = IC(x_ic_train)                 

x_int = X[:, 0][id_f, None]                                        
t_int = T[:, 0][id_f, None]                                        
x_int_train = np.hstack((t_int, x_int))                            

x_bdL,x_bdR = BD_perid(L,Time,num_t)                            
u_bdL_in = BD(x_bdL)                            
u_bdR_in = BD(x_bdR)                            
mark = Mark(x_int_train)
mark_ic = Mark(x_ic_train)
mark_bd = Mark(x_bdL)
x_ic = torch.tensor(x_ic_train, dtype=torch.float32).to(device)
x_int = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)
u_ic = torch.tensor(u_ic_train, dtype=torch.float32).to(device)
x_bdL = torch.tensor(x_bdL, dtype=torch.float32).to(device)
x_bdR = torch.tensor(x_bdR, dtype=torch.float32).to(device)
u_bdL_in = torch.tensor(u_bdL_in, dtype=torch.float32).to(device)
u_bdR_in = torch.tensor(u_bdR_in, dtype=torch.float32).to(device)
mark = torch.tensor(mark, dtype=torch.float32).to(device)
mark_ic = torch.tensor(mark_ic, dtype=torch.float32).to(device)
mark_bd = torch.tensor(mark_bd, dtype=torch.float32).to(device)

model = DNN().to(device)

lr = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
print('Start training...')
# Out:
# Start training...

# %%
optimizer = torch.optim.LBFGS(model.parameters(),lr=0.1,max_iter=20)
epochs = 10000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
    
toc = time.time()
# Out:
# epoch 1 loss_pde:0.00231218, loss_ic:0.49494129
# epoch 1 loss_pde:0.00247863, loss_ic:0.49370906
# epoch 1 loss_pde:0.00332800, loss_ic:0.48894206
# epoch 1 loss_pde:0.00530279, loss_ic:0.48034045
# epoch 1 loss_pde:0.00915148, loss_ic:0.46750957
# epoch 1 loss_pde:0.01577701, loss_ic:0.45040593
# epoch 1 loss_pde:0.02550670, loss_ic:0.43005851
# epoch 1 loss_pde:0.03796537, loss_ic:0.40734971
# epoch 1 loss_pde:0.05374062, loss_ic:0.38017482
# epoch 1 loss_pde:0.07411604, loss_ic:0.34323150
# epoch 1 loss_pde:0.08863703, loss_ic:0.29993960
# epoch 1 loss_pde:0.08261900, loss_ic:0.27659801
# epoch 1 loss_pde:0.07236075, loss_ic:0.26754233
# epoch 1 loss_pde:0.06440502, loss_ic:0.26093653
# epoch 1 loss_pde:0.05825795, loss_ic:0.25765824
# epoch 1 loss_pde:0.05319761, loss_ic:0.25414196
# epoch 1 loss_pde:0.04930013, loss_ic:0.25182292
# epoch 1 loss_pde:0.04586533, loss_ic:0.24939215
# epoch 1 loss_pde:0.04285108, loss_ic:0.24728099
# epoch 1 loss_pde:0.04008244, loss_ic:0.24503948
# epoch 1: loss 9.956738
# epoch 2 loss_pde:0.03756130, loss_ic:0.24283147
# epoch 2 loss_pde:0.03524375, loss_ic:0.24044359
# epoch 2 loss_pde:0.03315857, loss_ic:0.23791069
# epoch 2 loss_pde:0.03134466, loss_ic:0.23509024
# epoch 2 loss_pde:0.02991172, loss_ic:0.23193437
# epoch 2 loss_pde:0.02906660, loss_ic:0.22829629
# epoch 2 loss_pde:0.02923062, loss_ic:0.22405837
# epoch 2 loss_pde:0.03126403, loss_ic:0.21908723
# epoch 2 loss_pde:0.03685294, loss_ic:0.21344644
# epoch 2 loss_pde:0.04855089, loss_ic:0.20768623
# epoch 2 loss_pde:0.06782423, loss_ic:0.20283704
# epoch 2 loss_pde:0.09333584, loss_ic:0.19936909
# epoch 2 loss_pde:0.12435475, loss_ic:0.19693966
# epoch 2 loss_pde:0.15880693, loss_ic:0.19506143
# epoch 2 loss_pde:0.18701576, loss_ic:0.19371769
# epoch 2 loss_pde:0.21024279, loss_ic:0.19234152
# epoch 2 loss_pde:0.22761104, loss_ic:0.19126032
# epoch 2 loss_pde:0.24096391, loss_ic:0.19009426
# epoch 2 loss_pde:0.25314215, loss_ic:0.18878099
# epoch 2 loss_pde:0.26459071, loss_ic:0.18717949
# epoch 2: loss 8.108305
# epoch 3 loss_pde:0.27538571, loss_ic:0.18530764
# epoch 3 loss_pde:0.28545663, loss_ic:0.18312712
# epoch 3 loss_pde:0.29480231, loss_ic:0.18062176
# epoch 3 loss_pde:0.30336356, loss_ic:0.17776041
# epoch 3 loss_pde:0.31104130, loss_ic:0.17453550
# epoch 3 loss_pde:0.31768963, loss_ic:0.17096743
# epoch 3 loss_pde:0.32318783, loss_ic:0.16712557
# epoch 3 loss_pde:0.32754606, loss_ic:0.16312225
# epoch 3 loss_pde:0.33101243, loss_ic:0.15908135
# epoch 3 loss_pde:0.33407539, loss_ic:0.15507765
# epoch 3 loss_pde:0.33732694, loss_ic:0.15108214
# epoch 3 loss_pde:0.34122360, loss_ic:0.14694507
# epoch 3 loss_pde:0.34584412, loss_ic:0.14246349
# epoch 3 loss_pde:0.35095227, loss_ic:0.13751251
# epoch 3 loss_pde:0.35642838, loss_ic:0.13208866
# epoch 3 loss_pde:0.36261949, loss_ic:0.12620065
# epoch 3 loss_pde:0.37055588, loss_ic:0.11984345
# epoch 3 loss_pde:0.38128281, loss_ic:0.11286192
# epoch 3 loss_pde:0.39606485, loss_ic:0.10539005
# epoch 3 loss_pde:0.41350985, loss_ic:0.09744836
# epoch 3: loss 7.393294
# epoch 4 loss_pde:0.43253076, loss_ic:0.08996670
# epoch 4 loss_pde:0.44790933, loss_ic:0.08278447
# epoch 4 loss_pde:0.46391389, loss_ic:0.07709195
# epoch 4 loss_pde:0.47442201, loss_ic:0.07188857
# epoch 4 loss_pde:0.48088866, loss_ic:0.06847513
# epoch 4 loss_pde:0.48459357, loss_ic:0.06505895
# epoch 4 loss_pde:0.48691702, loss_ic:0.06197481
# epoch 4 loss_pde:0.48723266, loss_ic:0.05883982
# epoch 4 loss_pde:0.48716733, loss_ic:0.05585813
# epoch 4 loss_pde:0.48313293, loss_ic:0.05325802
# epoch 4 loss_pde:0.48174131, loss_ic:0.05048363
# epoch 4 loss_pde:0.47562310, loss_ic:0.04852553
# epoch 4 loss_pde:0.47092798, loss_ic:0.04675775
# epoch 4 loss_pde:0.46457377, loss_ic:0.04538756
# epoch 4 loss_pde:0.45641300, loss_ic:0.04443654
# epoch 4 loss_pde:0.45006967, loss_ic:0.04322874
# epoch 4 loss_pde:0.44254857, loss_ic:0.04267221
# epoch 4 loss_pde:0.43655500, loss_ic:0.04193551
# epoch 4 loss_pde:0.42893371, loss_ic:0.04152592
# epoch 4 loss_pde:0.42259273, loss_ic:0.04097010
# epoch 4: loss 6.461805
# epoch 5 loss_pde:0.41507542, loss_ic:0.04057779
# epoch 5 loss_pde:0.40823907, loss_ic:0.04006127
# epoch 5 loss_pde:0.40053964, loss_ic:0.03963690
# epoch 5 loss_pde:0.39301154, loss_ic:0.03907069
# epoch 5 loss_pde:0.38454035, loss_ic:0.03853974
# epoch 5 loss_pde:0.37560156, loss_ic:0.03782258
# epoch 5 loss_pde:0.36550897, loss_ic:0.03709136
# epoch 5 loss_pde:0.35401490, loss_ic:0.03608727
# epoch 5 loss_pde:0.34085545, loss_ic:0.03490509
# epoch 5 loss_pde:0.32372165, loss_ic:0.03319082
# epoch 5 loss_pde:0.30547157, loss_ic:0.03112526
# epoch 5 loss_pde:0.29103044, loss_ic:0.02886983
# epoch 5 loss_pde:0.28590462, loss_ic:0.02682984
# epoch 5 loss_pde:0.28831971, loss_ic:0.02478256
# epoch 5 loss_pde:0.29209012, loss_ic:0.02296038
# epoch 5 loss_pde:0.29695615, loss_ic:0.02173148
# epoch 5 loss_pde:0.29999438, loss_ic:0.02085364
# epoch 5 loss_pde:0.30305418, loss_ic:0.02010561
# epoch 5 loss_pde:0.30501884, loss_ic:0.01943758
# epoch 5 loss_pde:0.30700320, loss_ic:0.01877617
# epoch 5: loss 5.841599
# epoch 6 loss_pde:0.30801970, loss_ic:0.01813477
# epoch 6 loss_pde:0.30891246, loss_ic:0.01747527
# epoch 6 loss_pde:0.30876836, loss_ic:0.01676937
# epoch 6 loss_pde:0.30828527, loss_ic:0.01606503
# epoch 6 loss_pde:0.30739310, loss_ic:0.01538582
# epoch 6 loss_pde:0.30591726, loss_ic:0.01465057
# epoch 6 loss_pde:0.30397111, loss_ic:0.01399654
# epoch 6 loss_pde:0.30142102, loss_ic:0.01312719
# epoch 6 loss_pde:0.29899946, loss_ic:0.01253765
# epoch 6 loss_pde:0.29650211, loss_ic:0.01171251
# epoch 6 loss_pde:0.29425853, loss_ic:0.01125465
# epoch 6 loss_pde:0.29246432, loss_ic:0.01076834
# epoch 6 loss_pde:0.29049596, loss_ic:0.01042631
# epoch 6 loss_pde:0.28916308, loss_ic:0.01005138
# epoch 6 loss_pde:0.28764170, loss_ic:0.00974775
# epoch 6 loss_pde:0.28673178, loss_ic:0.00942498
# epoch 6 loss_pde:0.28556845, loss_ic:0.00916042
# epoch 6 loss_pde:0.28514117, loss_ic:0.00887898
# epoch 6 loss_pde:0.28442043, loss_ic:0.00863087
# epoch 6 loss_pde:0.28455099, loss_ic:0.00831381
# epoch 6: loss 5.536440
# epoch 7 loss_pde:0.28449911, loss_ic:0.00801055
# epoch 7 loss_pde:0.28488272, loss_ic:0.00766298
# epoch 7 loss_pde:0.28534633, loss_ic:0.00731380
# epoch 7 loss_pde:0.28616530, loss_ic:0.00698992
# epoch 7 loss_pde:0.28700325, loss_ic:0.00667539
# epoch 7 loss_pde:0.28753611, loss_ic:0.00644380
# epoch 7 loss_pde:0.28826588, loss_ic:0.00618718
# epoch 7 loss_pde:0.28887299, loss_ic:0.00600174
# epoch 7 loss_pde:0.28961620, loss_ic:0.00578480
# epoch 7 loss_pde:0.29022324, loss_ic:0.00563459
# epoch 7 loss_pde:0.29087922, loss_ic:0.00545268
# epoch 7 loss_pde:0.29143780, loss_ic:0.00532771
# epoch 7 loss_pde:0.29181954, loss_ic:0.00516108
# epoch 7 loss_pde:0.29226249, loss_ic:0.00505391
# epoch 7 loss_pde:0.29248524, loss_ic:0.00488785
# epoch 7 loss_pde:0.29292902, loss_ic:0.00476927
# epoch 7 loss_pde:0.29315922, loss_ic:0.00465481
# epoch 7 loss_pde:0.29342407, loss_ic:0.00454329
# epoch 7 loss_pde:0.29352242, loss_ic:0.00445451
# epoch 7 loss_pde:0.29363033, loss_ic:0.00433980
# epoch 7: loss 5.419082
# epoch 8 loss_pde:0.29354557, loss_ic:0.00426206
# epoch 8 loss_pde:0.29339555, loss_ic:0.00415565
# epoch 8 loss_pde:0.29314125, loss_ic:0.00407346
# epoch 8 loss_pde:0.29269806, loss_ic:0.00398539
# epoch 8 loss_pde:0.29228044, loss_ic:0.00388151
# epoch 8 loss_pde:0.29164025, loss_ic:0.00382322
# epoch 8 loss_pde:0.29105034, loss_ic:0.00372774
# epoch 8 loss_pde:0.29035792, loss_ic:0.00368398
# epoch 8 loss_pde:0.28963464, loss_ic:0.00360919
# epoch 8 loss_pde:0.28896102, loss_ic:0.00356419
# epoch 8 loss_pde:0.28822085, loss_ic:0.00351758
# epoch 8 loss_pde:0.28762630, loss_ic:0.00347249
# epoch 8 loss_pde:0.28705433, loss_ic:0.00344947
# epoch 8 loss_pde:0.28659046, loss_ic:0.00339337
# epoch 8 loss_pde:0.28614455, loss_ic:0.00340382
# epoch 8 loss_pde:0.28576842, loss_ic:0.00332876
# epoch 8 loss_pde:0.28543058, loss_ic:0.00336115
# epoch 8 loss_pde:0.28516725, loss_ic:0.00333971
# epoch 8 loss_pde:0.28497007, loss_ic:0.00332053
# epoch 8 loss_pde:0.28479809, loss_ic:0.00331149
# epoch 8: loss 5.371614
# epoch 9 loss_pde:0.28462365, loss_ic:0.00328667
# epoch 9 loss_pde:0.28448373, loss_ic:0.00328684
# epoch 9 loss_pde:0.28430805, loss_ic:0.00326224
# epoch 9 loss_pde:0.28418168, loss_ic:0.00326014
# epoch 9 loss_pde:0.28395751, loss_ic:0.00325482
# epoch 9 loss_pde:0.28383479, loss_ic:0.00324316
# epoch 9 loss_pde:0.28363827, loss_ic:0.00324545
# epoch 9 loss_pde:0.28347543, loss_ic:0.00323575
# epoch 9 loss_pde:0.28328541, loss_ic:0.00323932
# epoch 9 loss_pde:0.28307843, loss_ic:0.00323302
# epoch 9 loss_pde:0.28286794, loss_ic:0.00323679
# epoch 9 loss_pde:0.28260943, loss_ic:0.00323408
# epoch 9 loss_pde:0.28236175, loss_ic:0.00323820
# epoch 9 loss_pde:0.28204277, loss_ic:0.00323882
# epoch 9 loss_pde:0.28176901, loss_ic:0.00324179
# epoch 9 loss_pde:0.28138041, loss_ic:0.00324580
# epoch 9 loss_pde:0.28110015, loss_ic:0.00324503
# epoch 9 loss_pde:0.28064632, loss_ic:0.00325310
# epoch 9 loss_pde:0.28036445, loss_ic:0.00324611
# epoch 9 loss_pde:0.27987906, loss_ic:0.00325841
# epoch 9: loss 5.348862
# epoch 10 loss_pde:0.27953741, loss_ic:0.00325043
# epoch 10 loss_pde:0.27907416, loss_ic:0.00326368
# epoch 10 loss_pde:0.27868879, loss_ic:0.00326052
# epoch 10 loss_pde:0.27825963, loss_ic:0.00327219
# epoch 10 loss_pde:0.27786928, loss_ic:0.00327190
# epoch 10 loss_pde:0.27746078, loss_ic:0.00328291
# epoch 10 loss_pde:0.27707365, loss_ic:0.00328463
# epoch 10 loss_pde:0.27667844, loss_ic:0.00329583
# epoch 10 loss_pde:0.27628666, loss_ic:0.00329924
# epoch 10 loss_pde:0.27589321, loss_ic:0.00331140
# epoch 10 loss_pde:0.27547920, loss_ic:0.00331665
# epoch 10 loss_pde:0.27507430, loss_ic:0.00333070
# epoch 10 loss_pde:0.27461758, loss_ic:0.00333766
# epoch 10 loss_pde:0.27418968, loss_ic:0.00335494
# epoch 10 loss_pde:0.27365756, loss_ic:0.00336234
# epoch 10 loss_pde:0.27319211, loss_ic:0.00338677
# epoch 10 loss_pde:0.27254176, loss_ic:0.00339103
# epoch 10 loss_pde:0.27202186, loss_ic:0.00342500
# epoch 10 loss_pde:0.27131489, loss_ic:0.00343716
# epoch 10 loss_pde:0.27081996, loss_ic:0.00346226
# epoch 10: loss 5.344002
# epoch 11 loss_pde:0.27019283, loss_ic:0.00348146
# epoch 11 loss_pde:0.26978210, loss_ic:0.00349699
# epoch 11 loss_pde:0.26920968, loss_ic:0.00351479
# epoch 11 loss_pde:0.26897809, loss_ic:0.00352035
# epoch 11 loss_pde:0.26832730, loss_ic:0.00353720
# epoch 11 loss_pde:0.26848003, loss_ic:0.00352636
# epoch 11 loss_pde:0.26822057, loss_ic:0.00352410
# epoch 11 loss_pde:0.26783067, loss_ic:0.00353477
# epoch 11 loss_pde:0.26765266, loss_ic:0.00352425
# epoch 11 loss_pde:0.26733518, loss_ic:0.00352715
# epoch 11 loss_pde:0.26710495, loss_ic:0.00352375
# epoch 11 loss_pde:0.26689500, loss_ic:0.00351541
# epoch 11 loss_pde:0.26652288, loss_ic:0.00352708
# epoch 11 loss_pde:0.26640794, loss_ic:0.00350655
# epoch 11 loss_pde:0.26606727, loss_ic:0.00351625
# epoch 11 loss_pde:0.26613045, loss_ic:0.00348006
# epoch 11 loss_pde:0.26592186, loss_ic:0.00347916
# epoch 11 loss_pde:0.26604921, loss_ic:0.00343596
# epoch 11 loss_pde:0.26593378, loss_ic:0.00343013
# epoch 11 loss_pde:0.26605538, loss_ic:0.00338942
# epoch 11: loss 5.338140
# epoch 12 loss_pde:0.26604766, loss_ic:0.00337534
# epoch 12 loss_pde:0.26612768, loss_ic:0.00334854
# epoch 12 loss_pde:0.26621675, loss_ic:0.00332504
# epoch 12 loss_pde:0.26628980, loss_ic:0.00330637
# epoch 12 loss_pde:0.26639438, loss_ic:0.00328396
# epoch 12 loss_pde:0.26646784, loss_ic:0.00327012
# epoch 12 loss_pde:0.26656729, loss_ic:0.00325129
# epoch 12 loss_pde:0.26664618, loss_ic:0.00324028
# epoch 12 loss_pde:0.26674166, loss_ic:0.00322486
# epoch 12 loss_pde:0.26682273, loss_ic:0.00321569
# epoch 12 loss_pde:0.26691705, loss_ic:0.00320287
# epoch 12 loss_pde:0.26698425, loss_ic:0.00319592
# epoch 12 loss_pde:0.26707008, loss_ic:0.00318511
# epoch 12 loss_pde:0.26711264, loss_ic:0.00318161
# epoch 12 loss_pde:0.26716909, loss_ic:0.00317248
# epoch 12 loss_pde:0.26720640, loss_ic:0.00317194
# epoch 12 loss_pde:0.26720262, loss_ic:0.00316559
# epoch 12 loss_pde:0.26726854, loss_ic:0.00316523
# epoch 12 loss_pde:0.26718071, loss_ic:0.00316435
# epoch 12 loss_pde:0.26726878, loss_ic:0.00316120
# epoch 12: loss 5.331669
# epoch 13 loss_pde:0.26714584, loss_ic:0.00316608
# epoch 13 loss_pde:0.26719311, loss_ic:0.00316199
# epoch 13 loss_pde:0.26707920, loss_ic:0.00316951
# epoch 13 loss_pde:0.26707315, loss_ic:0.00316580
# epoch 13 loss_pde:0.26696700, loss_ic:0.00317419
# epoch 13 loss_pde:0.26691937, loss_ic:0.00317086
# epoch 13 loss_pde:0.26681715, loss_ic:0.00317907
# epoch 13 loss_pde:0.26673552, loss_ic:0.00317506
# epoch 13 loss_pde:0.26663819, loss_ic:0.00318231
# epoch 13 loss_pde:0.26649839, loss_ic:0.00317726
# epoch 13 loss_pde:0.26640406, loss_ic:0.00318262
# epoch 13 loss_pde:0.26609874, loss_ic:0.00318438
# epoch 13 loss_pde:0.26598817, loss_ic:0.00318720
# epoch 13 loss_pde:0.26597452, loss_ic:0.00318447
# epoch 13 loss_pde:0.26591542, loss_ic:0.00317963
# epoch 13 loss_pde:0.26577225, loss_ic:0.00318348
# epoch 13 loss_pde:0.26568478, loss_ic:0.00317992
# epoch 13 loss_pde:0.26553831, loss_ic:0.00318846
# epoch 13 loss_pde:0.26551217, loss_ic:0.00317684
# epoch 13 loss_pde:0.26537344, loss_ic:0.00318539
# epoch 13: loss 5.328043
# epoch 14 loss_pde:0.26537988, loss_ic:0.00317169
# epoch 14 loss_pde:0.26525363, loss_ic:0.00318147
# epoch 14 loss_pde:0.26527891, loss_ic:0.00316739
# epoch 14 loss_pde:0.26520512, loss_ic:0.00317217
# epoch 14 loss_pde:0.26519719, loss_ic:0.00316423
# epoch 14 loss_pde:0.26520595, loss_ic:0.00315830
# epoch 14 loss_pde:0.26520616, loss_ic:0.00315307
# epoch 14 loss_pde:0.26524597, loss_ic:0.00314464
# epoch 14 loss_pde:0.26525620, loss_ic:0.00314084
# epoch 14 loss_pde:0.26531202, loss_ic:0.00313181
# epoch 14 loss_pde:0.26532364, loss_ic:0.00312912
# epoch 14 loss_pde:0.26539424, loss_ic:0.00311985
# epoch 14 loss_pde:0.26540589, loss_ic:0.00311741
# epoch 14 loss_pde:0.26547629, loss_ic:0.00310910
# epoch 14 loss_pde:0.26549420, loss_ic:0.00310644
# epoch 14 loss_pde:0.26555464, loss_ic:0.00309940
# epoch 14 loss_pde:0.26557651, loss_ic:0.00309685
# epoch 14 loss_pde:0.26562461, loss_ic:0.00309082
# epoch 14 loss_pde:0.26564837, loss_ic:0.00308873
# epoch 14 loss_pde:0.26567981, loss_ic:0.00308340
# epoch 14: loss 5.326052
# epoch 15 loss_pde:0.26572254, loss_ic:0.00308169
# epoch 15 loss_pde:0.26573786, loss_ic:0.00307746
# epoch 15 loss_pde:0.26580545, loss_ic:0.00307197
# epoch 15 loss_pde:0.26579747, loss_ic:0.00307018
# epoch 15 loss_pde:0.26581797, loss_ic:0.00306338
# epoch 15 loss_pde:0.26576781, loss_ic:0.00306512
# epoch 15 loss_pde:0.26576057, loss_ic:0.00305983
# epoch 15 loss_pde:0.26570022, loss_ic:0.00306281
# epoch 15 loss_pde:0.26566163, loss_ic:0.00305852
# epoch 15 loss_pde:0.26559430, loss_ic:0.00306225
# epoch 15 loss_pde:0.26551649, loss_ic:0.00305825
# epoch 15 loss_pde:0.26543474, loss_ic:0.00306188
# epoch 15 loss_pde:0.26532754, loss_ic:0.00306040
# epoch 15 loss_pde:0.26524013, loss_ic:0.00306391
# epoch 15 loss_pde:0.26511258, loss_ic:0.00306376
# epoch 15 loss_pde:0.26502147, loss_ic:0.00306751
# epoch 15 loss_pde:0.26486221, loss_ic:0.00306608
# epoch 15 loss_pde:0.26475531, loss_ic:0.00307082
# epoch 15 loss_pde:0.26464018, loss_ic:0.00305974
# epoch 15 loss_pde:0.26452434, loss_ic:0.00306450
# epoch 15: loss 5.324767
# epoch 16 loss_pde:0.26442862, loss_ic:0.00306820
# epoch 16 loss_pde:0.26427329, loss_ic:0.00307297
# epoch 16 loss_pde:0.26418912, loss_ic:0.00307412
# epoch 16 loss_pde:0.26404077, loss_ic:0.00307864
# epoch 16 loss_pde:0.26390958, loss_ic:0.00307850
# epoch 16 loss_pde:0.26377842, loss_ic:0.00308646
# epoch 16 loss_pde:0.26359323, loss_ic:0.00308338
# epoch 16 loss_pde:0.26364762, loss_ic:0.00309869
# epoch 16 loss_pde:0.26355326, loss_ic:0.00309777
# epoch 16 loss_pde:0.26338196, loss_ic:0.00310354
# epoch 16 loss_pde:0.26329219, loss_ic:0.00309947
# epoch 16 loss_pde:0.26311490, loss_ic:0.00310299
# epoch 16 loss_pde:0.26298285, loss_ic:0.00310384
# epoch 16 loss_pde:0.26280165, loss_ic:0.00310810
# epoch 16 loss_pde:0.26266789, loss_ic:0.00310874
# epoch 16 loss_pde:0.26250565, loss_ic:0.00311223
# epoch 16 loss_pde:0.26240927, loss_ic:0.00310973
# epoch 16 loss_pde:0.26223609, loss_ic:0.00311554
# epoch 16 loss_pde:0.26216033, loss_ic:0.00311013
# epoch 16 loss_pde:0.26194534, loss_ic:0.00312508
# epoch 16: loss 5.323808
# epoch 17 loss_pde:0.26184905, loss_ic:0.00312175
# epoch 17 loss_pde:0.26183856, loss_ic:0.00311874
# epoch 17 loss_pde:0.26176348, loss_ic:0.00311359
# epoch 17 loss_pde:0.26172277, loss_ic:0.00310989
# epoch 17 loss_pde:0.26166767, loss_ic:0.00310608
# epoch 17 loss_pde:0.26164150, loss_ic:0.00310088
# epoch 17 loss_pde:0.26160234, loss_ic:0.00309862
# epoch 17 loss_pde:0.26159406, loss_ic:0.00309199
# epoch 17 loss_pde:0.26156348, loss_ic:0.00309092
# epoch 17 loss_pde:0.26157221, loss_ic:0.00308246
# epoch 17 loss_pde:0.26154840, loss_ic:0.00308176
# epoch 17 loss_pde:0.26157674, loss_ic:0.00307058
# epoch 17 loss_pde:0.26155844, loss_ic:0.00306957
# epoch 17 loss_pde:0.26160124, loss_ic:0.00305780
# epoch 17 loss_pde:0.26159400, loss_ic:0.00305551
# epoch 17 loss_pde:0.26162043, loss_ic:0.00304826
# epoch 17 loss_pde:0.26162183, loss_ic:0.00304526
# epoch 17 loss_pde:0.26165012, loss_ic:0.00303917
# epoch 17 loss_pde:0.26165619, loss_ic:0.00303583
# epoch 17 loss_pde:0.26169437, loss_ic:0.00303017
# epoch 17: loss 5.322311
# epoch 18 loss_pde:0.26169789, loss_ic:0.00302631
# epoch 18 loss_pde:0.26174653, loss_ic:0.00302119
# epoch 18 loss_pde:0.26174456, loss_ic:0.00301728
# epoch 18 loss_pde:0.26179028, loss_ic:0.00301217
# epoch 18 loss_pde:0.26177529, loss_ic:0.00300952
# epoch 18 loss_pde:0.26181561, loss_ic:0.00300367
# epoch 18 loss_pde:0.26178983, loss_ic:0.00300298
# epoch 18 loss_pde:0.26182362, loss_ic:0.00299642
# epoch 18 loss_pde:0.26179147, loss_ic:0.00299766
# epoch 18 loss_pde:0.26181516, loss_ic:0.00299094
# epoch 18 loss_pde:0.26178762, loss_ic:0.00299335
# epoch 18 loss_pde:0.26180124, loss_ic:0.00298649
# epoch 18 loss_pde:0.26178354, loss_ic:0.00298950
# epoch 18 loss_pde:0.26178312, loss_ic:0.00298251
# epoch 18 loss_pde:0.26177469, loss_ic:0.00298953
# epoch 18 loss_pde:0.26177570, loss_ic:0.00298558
# epoch 18 loss_pde:0.26177272, loss_ic:0.00298287
# epoch 18 loss_pde:0.26173854, loss_ic:0.00298271
# epoch 18 loss_pde:0.26171872, loss_ic:0.00297942
# epoch 18 loss_pde:0.26167977, loss_ic:0.00298058
# epoch 18: loss 5.321373
# epoch 19 loss_pde:0.26165813, loss_ic:0.00297706
# epoch 19 loss_pde:0.26164114, loss_ic:0.00297586
# epoch 19 loss_pde:0.26158267, loss_ic:0.00297678
# epoch 19 loss_pde:0.26156610, loss_ic:0.00297377
# epoch 19 loss_pde:0.26149333, loss_ic:0.00297763
# epoch 19 loss_pde:0.26148182, loss_ic:0.00297282
# epoch 19 loss_pde:0.26140633, loss_ic:0.00297727
# epoch 19 loss_pde:0.26140362, loss_ic:0.00297068
# epoch 19 loss_pde:0.26132846, loss_ic:0.00297427
# epoch 19 loss_pde:0.26135290, loss_ic:0.00296593
# epoch 19 loss_pde:0.26128358, loss_ic:0.00296765
# epoch 19 loss_pde:0.26133510, loss_ic:0.00295991
# epoch 19 loss_pde:0.26129550, loss_ic:0.00295883
# epoch 19 loss_pde:0.26125741, loss_ic:0.00295474
# epoch 19 loss_pde:0.26122022, loss_ic:0.00295218
# epoch 19 loss_pde:0.26122519, loss_ic:0.00294927
# epoch 19 loss_pde:0.26118121, loss_ic:0.00294448
# epoch 19 loss_pde:0.26117042, loss_ic:0.00294223
# epoch 19 loss_pde:0.26115093, loss_ic:0.00293611
# epoch 19 loss_pde:0.26112774, loss_ic:0.00293320
# epoch 19: loss 5.320467
# epoch 20 loss_pde:0.26110280, loss_ic:0.00292876
# epoch 20 loss_pde:0.26109102, loss_ic:0.00292421
# epoch 20 loss_pde:0.26106945, loss_ic:0.00292080
# epoch 20 loss_pde:0.26106760, loss_ic:0.00291482
# epoch 20 loss_pde:0.26104760, loss_ic:0.00291212
# epoch 20 loss_pde:0.26105815, loss_ic:0.00290484
# epoch 20 loss_pde:0.26104066, loss_ic:0.00290250
# epoch 20 loss_pde:0.26106140, loss_ic:0.00289434
# epoch 20 loss_pde:0.26104859, loss_ic:0.00289208
# epoch 20 loss_pde:0.26107141, loss_ic:0.00288383
# epoch 20 loss_pde:0.26106730, loss_ic:0.00288143
# epoch 20 loss_pde:0.26108369, loss_ic:0.00287382
# epoch 20 loss_pde:0.26109302, loss_ic:0.00287087
# epoch 20 loss_pde:0.26110256, loss_ic:0.00286477
# epoch 20 loss_pde:0.26112336, loss_ic:0.00286124
# epoch 20 loss_pde:0.26113081, loss_ic:0.00285612
# epoch 20 loss_pde:0.26115754, loss_ic:0.00285262
# epoch 20 loss_pde:0.26116559, loss_ic:0.00284712
# epoch 20 loss_pde:0.26119795, loss_ic:0.00284501
# epoch 20 loss_pde:0.26120904, loss_ic:0.00283886
# epoch 20: loss 5.319767
# epoch 21 loss_pde:0.26124969, loss_ic:0.00283892
# epoch 21 loss_pde:0.26126447, loss_ic:0.00283231
# epoch 21 loss_pde:0.26129773, loss_ic:0.00283246
# epoch 21 loss_pde:0.26130739, loss_ic:0.00282603
# epoch 21 loss_pde:0.26132694, loss_ic:0.00282582
# epoch 21 loss_pde:0.26133180, loss_ic:0.00282034
# epoch 21 loss_pde:0.26133114, loss_ic:0.00281909
# epoch 21 loss_pde:0.26132983, loss_ic:0.00281651
# epoch 21 loss_pde:0.26135027, loss_ic:0.00281690
# epoch 21 loss_pde:0.26135620, loss_ic:0.00281389
# epoch 21 loss_pde:0.26132619, loss_ic:0.00281393
# epoch 21 loss_pde:0.26130542, loss_ic:0.00281271
# epoch 21 loss_pde:0.26125109, loss_ic:0.00281436
# epoch 21 loss_pde:0.26121989, loss_ic:0.00281490
# epoch 21 loss_pde:0.26114291, loss_ic:0.00281756
# epoch 21 loss_pde:0.26110345, loss_ic:0.00281995
# epoch 21 loss_pde:0.26102147, loss_ic:0.00282330
# epoch 21 loss_pde:0.26099142, loss_ic:0.00282605
# epoch 21 loss_pde:0.26090667, loss_ic:0.00283025
# epoch 21 loss_pde:0.26089135, loss_ic:0.00283220
# epoch 21: loss 5.319430
# epoch 22 loss_pde:0.26081297, loss_ic:0.00283719
# epoch 22 loss_pde:0.26080301, loss_ic:0.00283731
# epoch 22 loss_pde:0.26072517, loss_ic:0.00284441
# epoch 22 loss_pde:0.26070559, loss_ic:0.00284385
# epoch 22 loss_pde:0.26065433, loss_ic:0.00285145
# epoch 22 loss_pde:0.26060376, loss_ic:0.00285142
# epoch 22 loss_pde:0.26058987, loss_ic:0.00285624
# epoch 22 loss_pde:0.26051444, loss_ic:0.00285964
# epoch 22 loss_pde:0.26050743, loss_ic:0.00286232
# epoch 22 loss_pde:0.26046321, loss_ic:0.00286802
# epoch 22 loss_pde:0.26044539, loss_ic:0.00286916
# epoch 22 loss_pde:0.26043549, loss_ic:0.00287301
# epoch 22 loss_pde:0.26037210, loss_ic:0.00287370
# epoch 22 loss_pde:0.26034918, loss_ic:0.00287733
# epoch 22 loss_pde:0.26042718, loss_ic:0.00287721
# epoch 22 loss_pde:0.26040784, loss_ic:0.00287890
# epoch 22 loss_pde:0.26043436, loss_ic:0.00288168
# epoch 22 loss_pde:0.26043680, loss_ic:0.00288285
# epoch 22 loss_pde:0.26046306, loss_ic:0.00288539
# epoch 22 loss_pde:0.26047680, loss_ic:0.00288633
# epoch 22: loss 5.319089
# epoch 23 loss_pde:0.26050702, loss_ic:0.00288712
# epoch 23 loss_pde:0.26052898, loss_ic:0.00288761
# epoch 23 loss_pde:0.26056343, loss_ic:0.00288737
# epoch 23 loss_pde:0.26059127, loss_ic:0.00288726
# epoch 23 loss_pde:0.26062781, loss_ic:0.00288621
# epoch 23 loss_pde:0.26066223, loss_ic:0.00288536
# epoch 23 loss_pde:0.26069549, loss_ic:0.00288382
# epoch 23 loss_pde:0.26073733, loss_ic:0.00288224
# epoch 23 loss_pde:0.26076019, loss_ic:0.00288064
# epoch 23 loss_pde:0.26081410, loss_ic:0.00287799
# epoch 23 loss_pde:0.26082477, loss_ic:0.00287699
# epoch 23 loss_pde:0.26088887, loss_ic:0.00287281
# epoch 23 loss_pde:0.26091012, loss_ic:0.00287172
# epoch 23 loss_pde:0.26096848, loss_ic:0.00286681
# epoch 23 loss_pde:0.26099658, loss_ic:0.00286532
# epoch 23 loss_pde:0.26104817, loss_ic:0.00285948
# epoch 23 loss_pde:0.26107323, loss_ic:0.00285853
# epoch 23 loss_pde:0.26111373, loss_ic:0.00285320
# epoch 23 loss_pde:0.26113594, loss_ic:0.00285204
# epoch 23 loss_pde:0.26117563, loss_ic:0.00284563
# epoch 23: loss 5.318892
# epoch 24 loss_pde:0.26119521, loss_ic:0.00284334
# epoch 24 loss_pde:0.26119095, loss_ic:0.00284278
# epoch 24 loss_pde:0.26120397, loss_ic:0.00284021
# epoch 24 loss_pde:0.26119420, loss_ic:0.00283756
# epoch 24 loss_pde:0.26140615, loss_ic:0.00284475
# epoch 24 loss_pde:0.26136446, loss_ic:0.00284395
# epoch 24 loss_pde:0.26133725, loss_ic:0.00284146
# epoch 24 loss_pde:0.26128194, loss_ic:0.00284105
# epoch 24 loss_pde:0.26122272, loss_ic:0.00284083
# epoch 24 loss_pde:0.26115125, loss_ic:0.00284140
# epoch 24 loss_pde:0.26107326, loss_ic:0.00284272
# epoch 24 loss_pde:0.26099330, loss_ic:0.00284422
# epoch 24 loss_pde:0.26090404, loss_ic:0.00284704
# epoch 24 loss_pde:0.26082936, loss_ic:0.00284850
# epoch 24 loss_pde:0.26073447, loss_ic:0.00285293
# epoch 24 loss_pde:0.26067850, loss_ic:0.00285327
# epoch 24 loss_pde:0.26057988, loss_ic:0.00285900
# epoch 24 loss_pde:0.26054940, loss_ic:0.00285770
# epoch 24 loss_pde:0.26046452, loss_ic:0.00286162
# epoch 24 loss_pde:0.26040664, loss_ic:0.00286441
# epoch 24: loss 5.318693
# epoch 25 loss_pde:0.26035744, loss_ic:0.00286590
# epoch 25 loss_pde:0.26031089, loss_ic:0.00286843
# epoch 25 loss_pde:0.26027712, loss_ic:0.00286974
# epoch 25 loss_pde:0.26017684, loss_ic:0.00287648
# epoch 25 loss_pde:0.26014695, loss_ic:0.00287861
# epoch 25 loss_pde:0.26010317, loss_ic:0.00287990
# epoch 25 loss_pde:0.26008096, loss_ic:0.00288301
# epoch 25 loss_pde:0.26002768, loss_ic:0.00288437
# epoch 25 loss_pde:0.26001871, loss_ic:0.00288526
# epoch 25 loss_pde:0.25995398, loss_ic:0.00289288
# epoch 25 loss_pde:0.25995544, loss_ic:0.00289215
# epoch 25 loss_pde:0.25994253, loss_ic:0.00289370
# epoch 25 loss_pde:0.25993514, loss_ic:0.00289351
# epoch 25 loss_pde:0.25992829, loss_ic:0.00289506
# epoch 25 loss_pde:0.25992402, loss_ic:0.00289532
# epoch 25 loss_pde:0.25992677, loss_ic:0.00289542
# epoch 25 loss_pde:0.25992128, loss_ic:0.00289665
# epoch 25 loss_pde:0.25992912, loss_ic:0.00289628
# epoch 25 loss_pde:0.25992873, loss_ic:0.00289722
# epoch 25 loss_pde:0.25993660, loss_ic:0.00289602
# epoch 25: loss 5.318331
# epoch 26 loss_pde:0.25993675, loss_ic:0.00289858
# epoch 26 loss_pde:0.25994933, loss_ic:0.00289166
# epoch 26 loss_pde:0.25996390, loss_ic:0.00289298
# epoch 26 loss_pde:0.25997117, loss_ic:0.00289312
# epoch 26 loss_pde:0.25997278, loss_ic:0.00289901
# epoch 26 loss_pde:0.25997785, loss_ic:0.00289935
# epoch 26 loss_pde:0.25997871, loss_ic:0.00290065
# epoch 26 loss_pde:0.25997815, loss_ic:0.00290070
# epoch 26 loss_pde:0.25997400, loss_ic:0.00290213
# epoch 26 loss_pde:0.25998214, loss_ic:0.00290221
# epoch 26 loss_pde:0.25996828, loss_ic:0.00290383
# epoch 26 loss_pde:0.25997820, loss_ic:0.00290408
# epoch 26 loss_pde:0.25996870, loss_ic:0.00290465
# epoch 26 loss_pde:0.25997424, loss_ic:0.00290488
# epoch 26 loss_pde:0.25996941, loss_ic:0.00290467
# epoch 26 loss_pde:0.25997189, loss_ic:0.00290472
# epoch 26 loss_pde:0.25997078, loss_ic:0.00290378
# epoch 26 loss_pde:0.25996745, loss_ic:0.00290379
# epoch 26 loss_pde:0.25997338, loss_ic:0.00290256
# epoch 26 loss_pde:0.25996342, loss_ic:0.00290189
# epoch 26: loss 5.318201
# epoch 27 loss_pde:0.25997499, loss_ic:0.00290109
# epoch 27 loss_pde:0.25995508, loss_ic:0.00289935
# epoch 27 loss_pde:0.25998995, loss_ic:0.00289962
# epoch 27 loss_pde:0.25997147, loss_ic:0.00289706
# epoch 27 loss_pde:0.25996998, loss_ic:0.00289671
# epoch 27 loss_pde:0.25997800, loss_ic:0.00289427
# epoch 27 loss_pde:0.25996077, loss_ic:0.00289421
# epoch 27 loss_pde:0.25998467, loss_ic:0.00289060
# epoch 27 loss_pde:0.25996941, loss_ic:0.00289034
# epoch 27 loss_pde:0.25998980, loss_ic:0.00288678
# epoch 27 loss_pde:0.25997797, loss_ic:0.00288687
# epoch 27 loss_pde:0.26001522, loss_ic:0.00288035
# epoch 27 loss_pde:0.26002714, loss_ic:0.00287957
# epoch 27 loss_pde:0.26002520, loss_ic:0.00287647
# epoch 27 loss_pde:0.26004329, loss_ic:0.00287471
# epoch 27 loss_pde:0.26004860, loss_ic:0.00287282
# epoch 27 loss_pde:0.26006120, loss_ic:0.00287062
# epoch 27 loss_pde:0.26012501, loss_ic:0.00286970
# epoch 27 loss_pde:0.26015389, loss_ic:0.00286601
# epoch 27 loss_pde:0.26014358, loss_ic:0.00286533
# epoch 27: loss 5.318059
# epoch 28 loss_pde:0.26019847, loss_ic:0.00286322
# epoch 28 loss_pde:0.25999409, loss_ic:0.00286396
# epoch 28 loss_pde:0.26001307, loss_ic:0.00286279
# epoch 28 loss_pde:0.26001993, loss_ic:0.00286569
# epoch 28 loss_pde:0.26003551, loss_ic:0.00286427
# epoch 28 loss_pde:0.26004702, loss_ic:0.00286358
# epoch 28 loss_pde:0.26013327, loss_ic:0.00285890
# epoch 28 loss_pde:0.26019797, loss_ic:0.00285486
# epoch 28 loss_pde:0.26020876, loss_ic:0.00285558
# epoch 28 loss_pde:0.26024273, loss_ic:0.00285350
# epoch 28 loss_pde:0.26025385, loss_ic:0.00285333
# epoch 28 loss_pde:0.26029065, loss_ic:0.00285162
# epoch 28 loss_pde:0.26027530, loss_ic:0.00285343
# epoch 28 loss_pde:0.26029819, loss_ic:0.00285160
# epoch 28 loss_pde:0.26026905, loss_ic:0.00285447
# epoch 28 loss_pde:0.26028174, loss_ic:0.00285136
# epoch 28 loss_pde:0.26023132, loss_ic:0.00285717
# epoch 28 loss_pde:0.26023760, loss_ic:0.00285236
# epoch 28 loss_pde:0.26017076, loss_ic:0.00285893
# epoch 28 loss_pde:0.26015219, loss_ic:0.00285574
# epoch 28: loss 5.317935
# epoch 29 loss_pde:0.26008463, loss_ic:0.00286067
# epoch 29 loss_pde:0.26004595, loss_ic:0.00285930
# epoch 29 loss_pde:0.25997788, loss_ic:0.00286352
# epoch 29 loss_pde:0.25993282, loss_ic:0.00286249
# epoch 29 loss_pde:0.25986633, loss_ic:0.00286707
# epoch 29 loss_pde:0.25980389, loss_ic:0.00287035
# epoch 29 loss_pde:0.25972041, loss_ic:0.00287118
# epoch 29 loss_pde:0.25965586, loss_ic:0.00287372
# epoch 29 loss_pde:0.25959748, loss_ic:0.00287501
# epoch 29 loss_pde:0.25954878, loss_ic:0.00287420
# epoch 29 loss_pde:0.25947246, loss_ic:0.00287907
# epoch 29 loss_pde:0.25944543, loss_ic:0.00287620
# epoch 29 loss_pde:0.25938714, loss_ic:0.00288028
# epoch 29 loss_pde:0.25937542, loss_ic:0.00287730
# epoch 29 loss_pde:0.25933203, loss_ic:0.00288003
# epoch 29 loss_pde:0.25936139, loss_ic:0.00287681
# epoch 29 loss_pde:0.25935039, loss_ic:0.00287829
# epoch 29 loss_pde:0.25927565, loss_ic:0.00288129
# epoch 29 loss_pde:0.25925839, loss_ic:0.00288042
# epoch 29 loss_pde:0.25922385, loss_ic:0.00288262
# epoch 29: loss 5.317514
# epoch 30 loss_pde:0.25920463, loss_ic:0.00288172
# epoch 30 loss_pde:0.25918147, loss_ic:0.00288424
# epoch 30 loss_pde:0.25917929, loss_ic:0.00288116
# epoch 30 loss_pde:0.25916183, loss_ic:0.00288495
# epoch 30 loss_pde:0.25915891, loss_ic:0.00288027
# epoch 30 loss_pde:0.25914776, loss_ic:0.00288436
# epoch 30 loss_pde:0.25914952, loss_ic:0.00288035
# epoch 30 loss_pde:0.25914767, loss_ic:0.00288296
# epoch 30 loss_pde:0.25915250, loss_ic:0.00287701
# epoch 30 loss_pde:0.25915211, loss_ic:0.00288147
# epoch 30 loss_pde:0.25918558, loss_ic:0.00287421
# epoch 30 loss_pde:0.25919750, loss_ic:0.00287703
# epoch 30 loss_pde:0.25922516, loss_ic:0.00287284
# epoch 30 loss_pde:0.25924671, loss_ic:0.00287181
# epoch 30 loss_pde:0.25928396, loss_ic:0.00286920
# epoch 30 loss_pde:0.25930649, loss_ic:0.00286641
# epoch 30 loss_pde:0.25934994, loss_ic:0.00286490
# epoch 30 loss_pde:0.25938106, loss_ic:0.00286089
# epoch 30 loss_pde:0.25942180, loss_ic:0.00285954
# epoch 30 loss_pde:0.25944996, loss_ic:0.00285580
# epoch 30: loss 5.317150
# epoch 31 loss_pde:0.25949457, loss_ic:0.00285347
# epoch 31 loss_pde:0.25954643, loss_ic:0.00285099
# epoch 31 loss_pde:0.25956973, loss_ic:0.00285022
# epoch 31 loss_pde:0.25961137, loss_ic:0.00284717
# epoch 31 loss_pde:0.25964060, loss_ic:0.00284744
# epoch 31 loss_pde:0.25969183, loss_ic:0.00284284
# epoch 31 loss_pde:0.25972483, loss_ic:0.00284176
# epoch 31 loss_pde:0.25976902, loss_ic:0.00283844
# epoch 31 loss_pde:0.25979716, loss_ic:0.00283650
# epoch 31 loss_pde:0.25984788, loss_ic:0.00283514
# epoch 31 loss_pde:0.25987574, loss_ic:0.00283173
# epoch 31 loss_pde:0.25991786, loss_ic:0.00283066
# epoch 31 loss_pde:0.25994828, loss_ic:0.00282837
# epoch 31 loss_pde:0.25998235, loss_ic:0.00282714
# epoch 31 loss_pde:0.26001069, loss_ic:0.00282561
# epoch 31 loss_pde:0.26004195, loss_ic:0.00282384
# epoch 31 loss_pde:0.26006234, loss_ic:0.00282443
# epoch 31 loss_pde:0.26010504, loss_ic:0.00282165
# epoch 31 loss_pde:0.26006383, loss_ic:0.00283054
# epoch 31 loss_pde:0.26009870, loss_ic:0.00282899
# epoch 31: loss 5.316861
# epoch 32 loss_pde:0.26009852, loss_ic:0.00282916
# epoch 32 loss_pde:0.26008856, loss_ic:0.00282929
# epoch 32 loss_pde:0.26008087, loss_ic:0.00283043
# epoch 32 loss_pde:0.26007077, loss_ic:0.00283054
# epoch 32 loss_pde:0.26008534, loss_ic:0.00283103
# epoch 32 loss_pde:0.25994670, loss_ic:0.00283589
# epoch 32 loss_pde:0.25994223, loss_ic:0.00283624
# epoch 32 loss_pde:0.25993386, loss_ic:0.00283636
# epoch 32 loss_pde:0.25995407, loss_ic:0.00283538
# epoch 32 loss_pde:0.25988761, loss_ic:0.00284044
# epoch 32 loss_pde:0.25986856, loss_ic:0.00284038
# epoch 32 loss_pde:0.25987792, loss_ic:0.00283875
# epoch 32 loss_pde:0.25987542, loss_ic:0.00283841
# epoch 32 loss_pde:0.25989401, loss_ic:0.00283708
# epoch 32 loss_pde:0.25988632, loss_ic:0.00283611
# epoch 32 loss_pde:0.25990021, loss_ic:0.00283444
# epoch 32 loss_pde:0.25989881, loss_ic:0.00283352
# epoch 32 loss_pde:0.25991380, loss_ic:0.00283166
# epoch 32 loss_pde:0.25990915, loss_ic:0.00283075
# epoch 32 loss_pde:0.25992167, loss_ic:0.00282865
# epoch 32: loss 5.316756
# epoch 33 loss_pde:0.25991592, loss_ic:0.00282868
# epoch 33 loss_pde:0.25992525, loss_ic:0.00282630
# epoch 33 loss_pde:0.25992289, loss_ic:0.00282665
# epoch 33 loss_pde:0.25993234, loss_ic:0.00282512
# epoch 33 loss_pde:0.25993225, loss_ic:0.00282493
# epoch 33 loss_pde:0.25993910, loss_ic:0.00282399
# epoch 33 loss_pde:0.25993332, loss_ic:0.00282378
# epoch 33 loss_pde:0.25996187, loss_ic:0.00282230
# epoch 33 loss_pde:0.25991771, loss_ic:0.00282339
# epoch 33 loss_pde:0.26003706, loss_ic:0.00281910
# epoch 33 loss_pde:0.26002139, loss_ic:0.00281912
# epoch 33 loss_pde:0.26000574, loss_ic:0.00281905
# epoch 33 loss_pde:0.25999519, loss_ic:0.00281928
# epoch 33 loss_pde:0.25997826, loss_ic:0.00281892
# epoch 33 loss_pde:0.25996411, loss_ic:0.00281960
# epoch 33 loss_pde:0.25994569, loss_ic:0.00281922
# epoch 33 loss_pde:0.25992957, loss_ic:0.00282011
# epoch 33 loss_pde:0.25990781, loss_ic:0.00281970
# epoch 33 loss_pde:0.25989360, loss_ic:0.00282128
# epoch 33 loss_pde:0.25987259, loss_ic:0.00282022
# epoch 33: loss 5.316450
# epoch 34 loss_pde:0.25985867, loss_ic:0.00282272
# epoch 34 loss_pde:0.25984183, loss_ic:0.00282063
# epoch 34 loss_pde:0.25982285, loss_ic:0.00282346
# epoch 34 loss_pde:0.25980714, loss_ic:0.00282064
# epoch 34 loss_pde:0.25978342, loss_ic:0.00282325
# epoch 34 loss_pde:0.25976232, loss_ic:0.00282020
# epoch 34 loss_pde:0.25974539, loss_ic:0.00282317
# epoch 34 loss_pde:0.25972891, loss_ic:0.00282108
# epoch 34 loss_pde:0.25973663, loss_ic:0.00282329
# epoch 34 loss_pde:0.25972578, loss_ic:0.00282209
# epoch 34 loss_pde:0.25972709, loss_ic:0.00282102
# epoch 34 loss_pde:0.25971183, loss_ic:0.00282054
# epoch 34 loss_pde:0.25971729, loss_ic:0.00281857
# epoch 34 loss_pde:0.25970501, loss_ic:0.00281792
# epoch 34 loss_pde:0.25970873, loss_ic:0.00281624
# epoch 34 loss_pde:0.25969741, loss_ic:0.00281528
# epoch 34 loss_pde:0.25969452, loss_ic:0.00281397
# epoch 34 loss_pde:0.25970411, loss_ic:0.00281016
# epoch 34 loss_pde:0.25970232, loss_ic:0.00280981
# epoch 34 loss_pde:0.25969672, loss_ic:0.00282513
# epoch 34: loss 5.316317
# epoch 35 loss_pde:0.25969446, loss_ic:0.00282307
# epoch 35 loss_pde:0.25968948, loss_ic:0.00282270
# epoch 35 loss_pde:0.25969401, loss_ic:0.00282092
# epoch 35 loss_pde:0.25968447, loss_ic:0.00282155
# epoch 35 loss_pde:0.25969610, loss_ic:0.00281901
# epoch 35 loss_pde:0.25967863, loss_ic:0.00282096
# epoch 35 loss_pde:0.25969368, loss_ic:0.00281821
# epoch 35 loss_pde:0.25967640, loss_ic:0.00282039
# epoch 35 loss_pde:0.25968769, loss_ic:0.00281859
# epoch 35 loss_pde:0.25967497, loss_ic:0.00282034
# epoch 35 loss_pde:0.25968760, loss_ic:0.00281890
# epoch 35 loss_pde:0.25967246, loss_ic:0.00282056
# epoch 35 loss_pde:0.25974190, loss_ic:0.00281568
# epoch 35 loss_pde:0.25974655, loss_ic:0.00281505
# epoch 35 loss_pde:0.25973418, loss_ic:0.00281766
# epoch 35 loss_pde:0.25973210, loss_ic:0.00281749
# epoch 35 loss_pde:0.25971892, loss_ic:0.00281987
# epoch 35 loss_pde:0.25971672, loss_ic:0.00282005
# epoch 35 loss_pde:0.25969627, loss_ic:0.00282254
# epoch 35 loss_pde:0.25969338, loss_ic:0.00282300
# epoch 35: loss 5.316146
# epoch 36 loss_pde:0.25964960, loss_ic:0.00282487
# epoch 36 loss_pde:0.25964183, loss_ic:0.00282612
# epoch 36 loss_pde:0.25962266, loss_ic:0.00282439
# epoch 36 loss_pde:0.25960407, loss_ic:0.00282629
# epoch 36 loss_pde:0.25959527, loss_ic:0.00282662
# epoch 36 loss_pde:0.25957683, loss_ic:0.00282847
# epoch 36 loss_pde:0.25956562, loss_ic:0.00282881
# epoch 36 loss_pde:0.25955200, loss_ic:0.00282998
# epoch 36 loss_pde:0.25953424, loss_ic:0.00283084
# epoch 36 loss_pde:0.25952598, loss_ic:0.00283142
# epoch 36 loss_pde:0.25950757, loss_ic:0.00283236
# epoch 36 loss_pde:0.25949827, loss_ic:0.00283297
# epoch 36 loss_pde:0.25948450, loss_ic:0.00283365
# epoch 36 loss_pde:0.25947434, loss_ic:0.00283443
# epoch 36 loss_pde:0.25946674, loss_ic:0.00283441
# epoch 36 loss_pde:0.25944999, loss_ic:0.00283651
# epoch 36 loss_pde:0.25944334, loss_ic:0.00283583
# epoch 36 loss_pde:0.25943208, loss_ic:0.00283745
# epoch 36 loss_pde:0.25943151, loss_ic:0.00283626
# epoch 36 loss_pde:0.25941762, loss_ic:0.00283795
# epoch 36: loss 5.316036
# epoch 37 loss_pde:0.25942674, loss_ic:0.00283605
# epoch 37 loss_pde:0.25941139, loss_ic:0.00283795
# epoch 37 loss_pde:0.25942615, loss_ic:0.00283578
# epoch 37 loss_pde:0.25941262, loss_ic:0.00283771
# epoch 37 loss_pde:0.25943673, loss_ic:0.00283459
# epoch 37 loss_pde:0.25943047, loss_ic:0.00283607
# epoch 37 loss_pde:0.25944647, loss_ic:0.00283487
# epoch 37 loss_pde:0.25945714, loss_ic:0.00283353
# epoch 37 loss_pde:0.25946900, loss_ic:0.00283307
# epoch 37 loss_pde:0.25948179, loss_ic:0.00283180
# epoch 37 loss_pde:0.25949666, loss_ic:0.00283106
# epoch 37 loss_pde:0.25949928, loss_ic:0.00282977
# epoch 37 loss_pde:0.25959131, loss_ic:0.00282658
# epoch 37 loss_pde:0.25959221, loss_ic:0.00282602
# epoch 37 loss_pde:0.25960594, loss_ic:0.00282441
# epoch 37 loss_pde:0.25960666, loss_ic:0.00282411
# epoch 37 loss_pde:0.25962362, loss_ic:0.00282221
# epoch 37 loss_pde:0.25962815, loss_ic:0.00282173
# epoch 37 loss_pde:0.25964728, loss_ic:0.00281977
# epoch 37 loss_pde:0.25965825, loss_ic:0.00281866
# epoch 37: loss 5.315973
# epoch 38 loss_pde:0.25966972, loss_ic:0.00281763
# epoch 38 loss_pde:0.25968346, loss_ic:0.00281632
# epoch 38 loss_pde:0.25969172, loss_ic:0.00281562
# epoch 38 loss_pde:0.25970948, loss_ic:0.00281401
# epoch 38 loss_pde:0.25971836, loss_ic:0.00281331
# epoch 38 loss_pde:0.25973937, loss_ic:0.00281158
# epoch 38 loss_pde:0.25974700, loss_ic:0.00281098
# epoch 38 loss_pde:0.25978020, loss_ic:0.00280854
# epoch 38 loss_pde:0.25978881, loss_ic:0.00280778
# epoch 38 loss_pde:0.25982285, loss_ic:0.00280470
# epoch 38 loss_pde:0.25984061, loss_ic:0.00280295
# epoch 38 loss_pde:0.25985426, loss_ic:0.00280229
# epoch 38 loss_pde:0.25986758, loss_ic:0.00280039
# epoch 38 loss_pde:0.25987795, loss_ic:0.00280006
# epoch 38 loss_pde:0.25989136, loss_ic:0.00279860
# epoch 38 loss_pde:0.25990218, loss_ic:0.00279827
# epoch 38 loss_pde:0.25991127, loss_ic:0.00279725
# epoch 38 loss_pde:0.25992024, loss_ic:0.00279716
# epoch 38 loss_pde:0.25992462, loss_ic:0.00279658
# epoch 38 loss_pde:0.25993055, loss_ic:0.00279685
# epoch 38: loss 5.315932
# epoch 39 loss_pde:0.25993097, loss_ic:0.00279665
# epoch 39 loss_pde:0.25993219, loss_ic:0.00279738
# epoch 39 loss_pde:0.25992841, loss_ic:0.00279740
# epoch 39 loss_pde:0.25992024, loss_ic:0.00279902
# epoch 39 loss_pde:0.25992051, loss_ic:0.00279842
# epoch 39 loss_pde:0.25988856, loss_ic:0.00280214
# epoch 39 loss_pde:0.25988272, loss_ic:0.00280298
# epoch 39 loss_pde:0.25986379, loss_ic:0.00280399
# epoch 39 loss_pde:0.25984710, loss_ic:0.00280589
# epoch 39 loss_pde:0.25982565, loss_ic:0.00280664
# epoch 39 loss_pde:0.25980332, loss_ic:0.00280912
# epoch 39 loss_pde:0.25977647, loss_ic:0.00280999
# epoch 39 loss_pde:0.25975749, loss_ic:0.00281286
# epoch 39 loss_pde:0.25972530, loss_ic:0.00281363
# epoch 39 loss_pde:0.25973433, loss_ic:0.00281812
# epoch 39 loss_pde:0.25971293, loss_ic:0.00281961
# epoch 39 loss_pde:0.25968522, loss_ic:0.00282050
# epoch 39 loss_pde:0.25965276, loss_ic:0.00282238
# epoch 39 loss_pde:0.25962198, loss_ic:0.00282348
# epoch 39 loss_pde:0.25959048, loss_ic:0.00282502
# epoch 39: loss 5.315893
# epoch 40 loss_pde:0.25956222, loss_ic:0.00282585
# epoch 40 loss_pde:0.25950223, loss_ic:0.00282897
# epoch 40 loss_pde:0.25947648, loss_ic:0.00283025
# epoch 40 loss_pde:0.25945231, loss_ic:0.00283104
# epoch 40 loss_pde:0.25943649, loss_ic:0.00283119
# epoch 40 loss_pde:0.25941274, loss_ic:0.00283181
# epoch 40 loss_pde:0.25939018, loss_ic:0.00283168
# epoch 40 loss_pde:0.25936553, loss_ic:0.00283259
# epoch 40 loss_pde:0.25935143, loss_ic:0.00283136
# epoch 40 loss_pde:0.25932807, loss_ic:0.00283216
# epoch 40 loss_pde:0.25930765, loss_ic:0.00283162
# epoch 40 loss_pde:0.25928780, loss_ic:0.00283289
# epoch 40 loss_pde:0.25927189, loss_ic:0.00283162
# epoch 40 loss_pde:0.25925645, loss_ic:0.00283228
# epoch 40 loss_pde:0.25924757, loss_ic:0.00283124
# epoch 40 loss_pde:0.25923863, loss_ic:0.00283142
# epoch 40 loss_pde:0.25923496, loss_ic:0.00283028
# epoch 40 loss_pde:0.25923166, loss_ic:0.00283016
# epoch 40 loss_pde:0.25923315, loss_ic:0.00282895
# epoch 40 loss_pde:0.25923464, loss_ic:0.00282871
# epoch 40: loss 5.315847
# epoch 41 loss_pde:0.25924164, loss_ic:0.00282725
# epoch 41 loss_pde:0.25924584, loss_ic:0.00282741
# epoch 41 loss_pde:0.25926122, loss_ic:0.00282511
# epoch 41 loss_pde:0.25926951, loss_ic:0.00282510
# epoch 41 loss_pde:0.25928405, loss_ic:0.00282340
# epoch 41 loss_pde:0.25929573, loss_ic:0.00282373
# epoch 41 loss_pde:0.25931191, loss_ic:0.00282195
# epoch 41 loss_pde:0.25932598, loss_ic:0.00282214
# epoch 41 loss_pde:0.25934198, loss_ic:0.00282098
# epoch 41 loss_pde:0.25935590, loss_ic:0.00282081
# epoch 41 loss_pde:0.25937206, loss_ic:0.00281989
# epoch 41 loss_pde:0.25938281, loss_ic:0.00281976
# epoch 41 loss_pde:0.25940108, loss_ic:0.00281887
# epoch 41 loss_pde:0.25940391, loss_ic:0.00281920
# epoch 41 loss_pde:0.25942329, loss_ic:0.00281832
# epoch 41 loss_pde:0.25942272, loss_ic:0.00281878
# epoch 41 loss_pde:0.25943899, loss_ic:0.00281807
# epoch 41 loss_pde:0.25942537, loss_ic:0.00281875
# epoch 41 loss_pde:0.25943640, loss_ic:0.00281851
# epoch 41 loss_pde:0.25944197, loss_ic:0.00281825
# epoch 41: loss 5.315808
# epoch 42 loss_pde:0.25944436, loss_ic:0.00281902
# epoch 42 loss_pde:0.25944328, loss_ic:0.00281925
# epoch 42 loss_pde:0.25944924, loss_ic:0.00281884
# epoch 42 loss_pde:0.25944775, loss_ic:0.00281938
# epoch 42 loss_pde:0.25946197, loss_ic:0.00281799
# epoch 42 loss_pde:0.25944167, loss_ic:0.00282016
# epoch 42 loss_pde:0.25945693, loss_ic:0.00281891
# epoch 42 loss_pde:0.25944465, loss_ic:0.00282009
# epoch 42 loss_pde:0.25944516, loss_ic:0.00282018
# epoch 42: loss 5.315780
# epoch 43 loss_pde:0.25944516, loss_ic:0.00282018
# epoch 43 loss_pde:0.25943917, loss_ic:0.00282068
# epoch 43 loss_pde:0.25943449, loss_ic:0.00282117
# epoch 43 loss_pde:0.25942945, loss_ic:0.00282149
# epoch 43 loss_pde:0.25942269, loss_ic:0.00282216
# epoch 43 loss_pde:0.25941575, loss_ic:0.00282252
# epoch 43 loss_pde:0.25940600, loss_ic:0.00282341
# epoch 43: loss 5.315773
# epoch 44 loss_pde:0.25940600, loss_ic:0.00282341
# epoch 44 loss_pde:0.25939810, loss_ic:0.00282361
# epoch 44 loss_pde:0.25938797, loss_ic:0.00282496
# epoch 44 loss_pde:0.25937748, loss_ic:0.00282499
# epoch 44 loss_pde:0.25937042, loss_ic:0.00282579
# epoch 44 loss_pde:0.25935706, loss_ic:0.00282643
# epoch 44: loss 5.315769
# epoch 45 loss_pde:0.25935706, loss_ic:0.00282643
# epoch 45 loss_pde:0.25934827, loss_ic:0.00282686
# epoch 45 loss_pde:0.25933027, loss_ic:0.00282781
# epoch 45: loss 5.315767
# epoch 46 loss_pde:0.25933027, loss_ic:0.00282781
# epoch 46 loss_pde:0.25931883, loss_ic:0.00282831
# epoch 46 loss_pde:0.25929940, loss_ic:0.00282929
# epoch 46 loss_pde:0.25930098, loss_ic:0.00282926
# epoch 46 loss_pde:0.25926596, loss_ic:0.00283076
# epoch 46 loss_pde:0.25925711, loss_ic:0.00283123
# epoch 46 loss_pde:0.25923967, loss_ic:0.00283191
# epoch 46 loss_pde:0.25922140, loss_ic:0.00283266
# epoch 46 loss_pde:0.25920630, loss_ic:0.00283316
# epoch 46 loss_pde:0.25917876, loss_ic:0.00283458
# epoch 46 loss_pde:0.25916249, loss_ic:0.00283491
# epoch 46 loss_pde:0.25913975, loss_ic:0.00283610
# epoch 46 loss_pde:0.25912541, loss_ic:0.00283597
# epoch 46 loss_pde:0.25910303, loss_ic:0.00283704
# epoch 46 loss_pde:0.25909325, loss_ic:0.00283629
# epoch 46 loss_pde:0.25907117, loss_ic:0.00283761
# epoch 46 loss_pde:0.25906342, loss_ic:0.00283615
# epoch 46 loss_pde:0.25904375, loss_ic:0.00283754
# epoch 46 loss_pde:0.25903779, loss_ic:0.00283608
# epoch 46 loss_pde:0.25902605, loss_ic:0.00283652
# epoch 46: loss 5.315766
# epoch 47 loss_pde:0.25902709, loss_ic:0.00283496
# epoch 47 loss_pde:0.25902316, loss_ic:0.00283480
# epoch 47 loss_pde:0.25903541, loss_ic:0.00283267
# epoch 47 loss_pde:0.25903866, loss_ic:0.00283216
# epoch 47 loss_pde:0.25905874, loss_ic:0.00282959
# epoch 47 loss_pde:0.25906819, loss_ic:0.00282870
# epoch 47 loss_pde:0.25908959, loss_ic:0.00282635
# epoch 47 loss_pde:0.25910547, loss_ic:0.00282529
# epoch 47 loss_pde:0.25912720, loss_ic:0.00282313
# epoch 47 loss_pde:0.25914592, loss_ic:0.00282219
# epoch 47 loss_pde:0.25916860, loss_ic:0.00281997
# epoch 47 loss_pde:0.25918877, loss_ic:0.00281921
# epoch 47 loss_pde:0.25921234, loss_ic:0.00281685
# epoch 47 loss_pde:0.25923446, loss_ic:0.00281617
# epoch 47 loss_pde:0.25925723, loss_ic:0.00281400
# epoch 47 loss_pde:0.25927851, loss_ic:0.00281317
# epoch 47 loss_pde:0.25930023, loss_ic:0.00281163
# epoch 47 loss_pde:0.25932354, loss_ic:0.00281097
# epoch 47 loss_pde:0.25934801, loss_ic:0.00280892
# epoch 47 loss_pde:0.25938043, loss_ic:0.00281351
# epoch 47: loss 5.315728
# epoch 48 loss_pde:0.25940323, loss_ic:0.00281199
# epoch 48 loss_pde:0.25942472, loss_ic:0.00281061
# epoch 48 loss_pde:0.25944567, loss_ic:0.00280894
# epoch 48 loss_pde:0.25946456, loss_ic:0.00280775
# epoch 48 loss_pde:0.25948179, loss_ic:0.00280625
# epoch 48 loss_pde:0.25949842, loss_ic:0.00280525
# epoch 48 loss_pde:0.25951272, loss_ic:0.00280379
# epoch 48 loss_pde:0.25953001, loss_ic:0.00280296
# epoch 48 loss_pde:0.25954416, loss_ic:0.00280164
# epoch 48 loss_pde:0.25955713, loss_ic:0.00280104
# epoch 48 loss_pde:0.25956863, loss_ic:0.00280011
# epoch 48 loss_pde:0.25953659, loss_ic:0.00279951
# epoch 48 loss_pde:0.25954154, loss_ic:0.00279955
# epoch 48 loss_pde:0.25954768, loss_ic:0.00279855
# epoch 48 loss_pde:0.25954726, loss_ic:0.00279897
# epoch 48 loss_pde:0.25954974, loss_ic:0.00279791
# epoch 48 loss_pde:0.25954318, loss_ic:0.00279870
# epoch 48 loss_pde:0.25954109, loss_ic:0.00279799
# epoch 48 loss_pde:0.25953096, loss_ic:0.00279866
# epoch 48 loss_pde:0.25952241, loss_ic:0.00279855
# epoch 48: loss 5.315686
# epoch 49 loss_pde:0.25950807, loss_ic:0.00279931
# epoch 49 loss_pde:0.25949234, loss_ic:0.00279930
# epoch 49 loss_pde:0.25947297, loss_ic:0.00280092
# epoch 49 loss_pde:0.25945377, loss_ic:0.00280043
# epoch 49 loss_pde:0.25943249, loss_ic:0.00280254
# epoch 49 loss_pde:0.25940940, loss_ic:0.00280219
# epoch 49 loss_pde:0.25938860, loss_ic:0.00280421
# epoch 49 loss_pde:0.25935999, loss_ic:0.00280444
# epoch 49 loss_pde:0.25934148, loss_ic:0.00280576
# epoch 49 loss_pde:0.25931442, loss_ic:0.00280674
# epoch 49 loss_pde:0.25929636, loss_ic:0.00280748
# epoch 49 loss_pde:0.25927275, loss_ic:0.00280864
# epoch 49 loss_pde:0.25924796, loss_ic:0.00280988
# epoch 49 loss_pde:0.25922674, loss_ic:0.00281066
# epoch 49 loss_pde:0.25920379, loss_ic:0.00281161
# epoch 49 loss_pde:0.25918147, loss_ic:0.00281229
# epoch 49 loss_pde:0.25916183, loss_ic:0.00281281
# epoch 49 loss_pde:0.25913891, loss_ic:0.00281387
# epoch 49 loss_pde:0.25912571, loss_ic:0.00281375
# epoch 49 loss_pde:0.25907311, loss_ic:0.00281740
# epoch 49: loss 5.315656
# epoch 50 loss_pde:0.25907481, loss_ic:0.00281635
# epoch 50 loss_pde:0.25906157, loss_ic:0.00281658
# epoch 50 loss_pde:0.25904977, loss_ic:0.00281678
# epoch 50 loss_pde:0.25905162, loss_ic:0.00281649
# epoch 50 loss_pde:0.25904307, loss_ic:0.00281593
# epoch 50 loss_pde:0.25904337, loss_ic:0.00281613
# epoch 50 loss_pde:0.25904903, loss_ic:0.00281494
# epoch 50 loss_pde:0.25904888, loss_ic:0.00281511
# epoch 50 loss_pde:0.25905874, loss_ic:0.00281410
# epoch 50 loss_pde:0.25905898, loss_ic:0.00281404
# epoch 50 loss_pde:0.25907111, loss_ic:0.00281327
# epoch 50: loss 5.315631
# epoch 51 loss_pde:0.25907111, loss_ic:0.00281327
# epoch 51 loss_pde:0.25907633, loss_ic:0.00281281
# epoch 51 loss_pde:0.25909391, loss_ic:0.00281207
# epoch 51: loss 5.315623
# epoch 52 loss_pde:0.25909391, loss_ic:0.00281207
# epoch 52 loss_pde:0.25910312, loss_ic:0.00281141
# epoch 52 loss_pde:0.25913233, loss_ic:0.00281043
# epoch 52 loss_pde:0.25914311, loss_ic:0.00280977
# epoch 52: loss 5.315622
# epoch 53 loss_pde:0.25914311, loss_ic:0.00280977
# epoch 53 loss_pde:0.25915501, loss_ic:0.00280947
# epoch 53 loss_pde:0.25916687, loss_ic:0.00280896
# epoch 53 loss_pde:0.25917819, loss_ic:0.00280864
# epoch 53 loss_pde:0.25919247, loss_ic:0.00280800
# epoch 53 loss_pde:0.25920534, loss_ic:0.00280764
# epoch 53: loss 5.315620
# epoch 54 loss_pde:0.25920534, loss_ic:0.00280764
# epoch 54 loss_pde:0.25922027, loss_ic:0.00280705
# epoch 54: loss 5.315618
# epoch 55 loss_pde:0.25922027, loss_ic:0.00280705
# epoch 55 loss_pde:0.25923255, loss_ic:0.00280669
# epoch 55 loss_pde:0.25924617, loss_ic:0.00280621
# epoch 55 loss_pde:0.25925848, loss_ic:0.00280586
# epoch 55: loss 5.315618
# epoch 56 loss_pde:0.25925848, loss_ic:0.00280586
# ...
# epoch 453 loss_pde:0.25889665, loss_ic:0.00278914
# epoch 453: loss 5.314678
# epoch 454 loss_pde:0.25889665, loss_ic:0.00278914
# epoch 454 loss_pde:0.25889671, loss_ic:0.00278918
# epoch 454: loss 5.314677
# epoch 455 loss_pde:0.25889671, loss_ic:0.00278918
# epoch 455 loss_pde:0.25890118, loss_ic:0.00278883
# epoch 455 loss_pde:0.25890106, loss_ic:0.00278883
# epoch 455 loss_pde:0.25890338, loss_ic:0.00278870
# epoch 455 loss_pde:0.25890592, loss_ic:0.00278854
# epoch 455 loss_pde:0.25890464, loss_ic:0.00278854
# epoch 455 loss_pde:0.25890756, loss_ic:0.00278839
# epoch 455 loss_pde:0.25889885, loss_ic:0.00278880
# epoch 455: loss 5.314677
# epoch 456 loss_pde:0.25889885, loss_ic:0.00278880
# epoch 456 loss_pde:0.25890100, loss_ic:0.00278856
# epoch 456: loss 5.314674
# epoch 457 loss_pde:0.25890100, loss_ic:0.00278856
# epoch 457 loss_pde:0.25889879, loss_ic:0.00278896
# epoch 457 loss_pde:0.25890237, loss_ic:0.00278859
# epoch 457: loss 5.314674
# epoch 458 loss_pde:0.25890237, loss_ic:0.00278859
# epoch 458 loss_pde:0.25890186, loss_ic:0.00278867
# epoch 458 loss_pde:0.25890389, loss_ic:0.00278848
# epoch 458 loss_pde:0.25890264, loss_ic:0.00278852
# epoch 458 loss_pde:0.25890496, loss_ic:0.00278846
# epoch 458: loss 5.314674
# epoch 459 loss_pde:0.25890496, loss_ic:0.00278846
# epoch 459 loss_pde:0.25889927, loss_ic:0.00278853
# epoch 459 loss_pde:0.25890526, loss_ic:0.00278852
# epoch 459 loss_pde:0.25889894, loss_ic:0.00278853
# epoch 459 loss_pde:0.25890616, loss_ic:0.00278867
# epoch 459 loss_pde:0.25890401, loss_ic:0.00278874
# epoch 459 loss_pde:0.25890726, loss_ic:0.00278868
# epoch 459 loss_pde:0.25890481, loss_ic:0.00278925
# epoch 459 loss_pde:0.25890633, loss_ic:0.00278895
# epoch 459 loss_pde:0.25890610, loss_ic:0.00278940
# epoch 459 loss_pde:0.25890723, loss_ic:0.00278928
# epoch 459 loss_pde:0.25890753, loss_ic:0.00278953
# epoch 459: loss 5.314673
# epoch 460 loss_pde:0.25890753, loss_ic:0.00278953
# epoch 460 loss_pde:0.25890881, loss_ic:0.00278941
# epoch 460: loss 5.314671
# epoch 461 loss_pde:0.25890881, loss_ic:0.00278941
# epoch 461 loss_pde:0.25890961, loss_ic:0.00278956
# epoch 461: loss 5.314671
# epoch 462 loss_pde:0.25890961, loss_ic:0.00278956
# epoch 462 loss_pde:0.25891107, loss_ic:0.00278947
# epoch 462 loss_pde:0.25891173, loss_ic:0.00278960
# epoch 462 loss_pde:0.25891307, loss_ic:0.00278958
# epoch 462 loss_pde:0.25891262, loss_ic:0.00278973
# epoch 462: loss 5.314671
# epoch 463 loss_pde:0.25891262, loss_ic:0.00278973
# epoch 463 loss_pde:0.25891760, loss_ic:0.00278935
# epoch 463: loss 5.314670
# epoch 464 loss_pde:0.25891760, loss_ic:0.00278935
# epoch 464 loss_pde:0.25891948, loss_ic:0.00278939
# epoch 464 loss_pde:0.25892144, loss_ic:0.00278925
# epoch 464: loss 5.314670
# epoch 465 loss_pde:0.25892144, loss_ic:0.00278925
# epoch 465 loss_pde:0.25892106, loss_ic:0.00278949
# epoch 465 loss_pde:0.25892514, loss_ic:0.00278917
# epoch 465 loss_pde:0.25892535, loss_ic:0.00278934
# epoch 465 loss_pde:0.25892973, loss_ic:0.00278905
# epoch 465 loss_pde:0.25892869, loss_ic:0.00278926
# epoch 465 loss_pde:0.25893223, loss_ic:0.00278908
# epoch 465 loss_pde:0.25892904, loss_ic:0.00278941
# epoch 465: loss 5.314671
# epoch 466 loss_pde:0.25892904, loss_ic:0.00278941
# epoch 466 loss_pde:0.25893161, loss_ic:0.00278927
# epoch 466: loss 5.314669
# epoch 467 loss_pde:0.25893161, loss_ic:0.00278927
# epoch 467 loss_pde:0.25892854, loss_ic:0.00278975
# epoch 467 loss_pde:0.25892889, loss_ic:0.00278969
# epoch 467: loss 5.314669
# epoch 468 loss_pde:0.25892889, loss_ic:0.00278969
# epoch 468 loss_pde:0.25892723, loss_ic:0.00278964
# epoch 468: loss 5.314669
# epoch 469 loss_pde:0.25892723, loss_ic:0.00278964
# epoch 469 loss_pde:0.25892729, loss_ic:0.00278996
# epoch 469 loss_pde:0.25892746, loss_ic:0.00278970
# epoch 469 loss_pde:0.25892109, loss_ic:0.00279144
# epoch 469 loss_pde:0.25891966, loss_ic:0.00279120
# epoch 469 loss_pde:0.25892130, loss_ic:0.00279109
# epoch 469 loss_pde:0.25891107, loss_ic:0.00279121
# epoch 469: loss 5.314669
# epoch 470 loss_pde:0.25891107, loss_ic:0.00279121
# epoch 470 loss_pde:0.25891224, loss_ic:0.00279107
# epoch 470 loss_pde:0.25891492, loss_ic:0.00279039
# epoch 470 loss_pde:0.25891268, loss_ic:0.00279051
# epoch 470 loss_pde:0.25891095, loss_ic:0.00279041
# epoch 470 loss_pde:0.25891408, loss_ic:0.00279096
# epoch 470 loss_pde:0.25891292, loss_ic:0.00279081
# epoch 470 loss_pde:0.25891528, loss_ic:0.00279039
# epoch 470 loss_pde:0.25890800, loss_ic:0.00279078
# epoch 470 loss_pde:0.25892183, loss_ic:0.00278914
# epoch 470: loss 5.314668
# epoch 471 loss_pde:0.25892183, loss_ic:0.00278914
# epoch 471 loss_pde:0.25891653, loss_ic:0.00278946
# epoch 471 loss_pde:0.25891876, loss_ic:0.00278833
# epoch 471: loss 5.314666
# epoch 472 loss_pde:0.25891876, loss_ic:0.00278833
# epoch 472 loss_pde:0.25891680, loss_ic:0.00278847
# epoch 472: loss 5.314666
# epoch 473 loss_pde:0.25891680, loss_ic:0.00278847
# epoch 473 loss_pde:0.25891593, loss_ic:0.00278831
# epoch 473 loss_pde:0.25891268, loss_ic:0.00278866
# epoch 473 loss_pde:0.25891310, loss_ic:0.00278833
# epoch 473: loss 5.314666
# epoch 474 loss_pde:0.25891310, loss_ic:0.00278833
# epoch 474 loss_pde:0.25890946, loss_ic:0.00278872
# epoch 474: loss 5.314665
# epoch 475 loss_pde:0.25890946, loss_ic:0.00278872
# epoch 475 loss_pde:0.25891042, loss_ic:0.00278842
# epoch 475: loss 5.314665
# epoch 476 loss_pde:0.25891042, loss_ic:0.00278842
# epoch 476 loss_pde:0.25890803, loss_ic:0.00278866
# epoch 476: loss 5.314665
# epoch 477 loss_pde:0.25890803, loss_ic:0.00278866
# epoch 477 loss_pde:0.25890848, loss_ic:0.00278841
# epoch 477: loss 5.314665
# epoch 478 loss_pde:0.25890848, loss_ic:0.00278841
# epoch 478 loss_pde:0.25890696, loss_ic:0.00278867
# epoch 478 loss_pde:0.25890768, loss_ic:0.00278853
# epoch 478: loss 5.314665
# epoch 479 loss_pde:0.25890768, loss_ic:0.00278853
# epoch 479 loss_pde:0.25890464, loss_ic:0.00278890
# epoch 479 loss_pde:0.25891075, loss_ic:0.00278812
# epoch 479 loss_pde:0.25890842, loss_ic:0.00278833
# epoch 479 loss_pde:0.25890458, loss_ic:0.00278857
# epoch 479 loss_pde:0.25891069, loss_ic:0.00278863
# epoch 479: loss 5.314664
# epoch 480 loss_pde:0.25891069, loss_ic:0.00278863
# epoch 480 loss_pde:0.25890422, loss_ic:0.00278853
# epoch 480: loss 5.314663
# epoch 481 loss_pde:0.25890422, loss_ic:0.00278853
# epoch 481 loss_pde:0.25890610, loss_ic:0.00278847
# epoch 481: loss 5.314663
# epoch 482 loss_pde:0.25890610, loss_ic:0.00278847
# epoch 482 loss_pde:0.25890514, loss_ic:0.00278862
# epoch 482 loss_pde:0.25890747, loss_ic:0.00278840
# epoch 482 loss_pde:0.25890604, loss_ic:0.00278863
# epoch 482 loss_pde:0.25890860, loss_ic:0.00278842
# epoch 482 loss_pde:0.25890848, loss_ic:0.00278859
# epoch 482 loss_pde:0.25890961, loss_ic:0.00278840
# epoch 482: loss 5.314663
# epoch 483 loss_pde:0.25890961, loss_ic:0.00278840
# epoch 483 loss_pde:0.25891033, loss_ic:0.00278854
# epoch 483 loss_pde:0.25891119, loss_ic:0.00278840
# epoch 483 loss_pde:0.25891283, loss_ic:0.00278850
# epoch 483: loss 5.314662
# epoch 484 loss_pde:0.25891283, loss_ic:0.00278850
# epoch 484 loss_pde:0.25891367, loss_ic:0.00278835
# epoch 484 loss_pde:0.25891602, loss_ic:0.00278837
# epoch 484 loss_pde:0.25891721, loss_ic:0.00278828
# epoch 484: loss 5.314662
# epoch 485 loss_pde:0.25891721, loss_ic:0.00278828
# epoch 485 loss_pde:0.25892073, loss_ic:0.00278825
# epoch 485 loss_pde:0.25891998, loss_ic:0.00278823
# epoch 485 loss_pde:0.25892687, loss_ic:0.00278805
# epoch 485 loss_pde:0.25891864, loss_ic:0.00278828
# epoch 485: loss 5.314662
# epoch 486 loss_pde:0.25891864, loss_ic:0.00278828
# epoch 486 loss_pde:0.25892758, loss_ic:0.00278799
# epoch 486 loss_pde:0.25892219, loss_ic:0.00278819
# epoch 486 loss_pde:0.25893724, loss_ic:0.00278803
# epoch 486 loss_pde:0.25893998, loss_ic:0.00278781
# epoch 486: loss 5.314662
# epoch 487 loss_pde:0.25893998, loss_ic:0.00278781
# epoch 487 loss_pde:0.25894260, loss_ic:0.00278801
# epoch 487: loss 5.314661
# epoch 488 loss_pde:0.25894260, loss_ic:0.00278801
# epoch 488 loss_pde:0.25894538, loss_ic:0.00278776
# epoch 488: loss 5.314661
# epoch 489 loss_pde:0.25894538, loss_ic:0.00278776
# epoch 489 loss_pde:0.25894728, loss_ic:0.00278792
# epoch 489: loss 5.314661
# epoch 490 loss_pde:0.25894728, loss_ic:0.00278792
# epoch 490 loss_pde:0.25894940, loss_ic:0.00278775
# epoch 490 loss_pde:0.25895134, loss_ic:0.00278789
# epoch 490 loss_pde:0.25895280, loss_ic:0.00278783
# epoch 490 loss_pde:0.25895059, loss_ic:0.00278738
# epoch 490: loss 5.314661
# epoch 491 loss_pde:0.25895059, loss_ic:0.00278738
# epoch 491 loss_pde:0.25895271, loss_ic:0.00278771
# epoch 491: loss 5.314660
# epoch 492 loss_pde:0.25895271, loss_ic:0.00278771
# epoch 492 loss_pde:0.25895342, loss_ic:0.00278762
# epoch 492 loss_pde:0.25894663, loss_ic:0.00278798
# epoch 492 loss_pde:0.25894758, loss_ic:0.00278794
# epoch 492 loss_pde:0.25894204, loss_ic:0.00278813
# epoch 492 loss_pde:0.25894022, loss_ic:0.00278819
# epoch 492 loss_pde:0.25893921, loss_ic:0.00278835
# epoch 492 loss_pde:0.25893557, loss_ic:0.00278847
# epoch 492: loss 5.314660
# epoch 493 loss_pde:0.25893557, loss_ic:0.00278847
# epoch 493 loss_pde:0.25893626, loss_ic:0.00278866
# epoch 493: loss 5.314659
# epoch 494 loss_pde:0.25893626, loss_ic:0.00278866
# epoch 494 loss_pde:0.25893268, loss_ic:0.00278872
# epoch 494: loss 5.314659
# epoch 495 loss_pde:0.25893268, loss_ic:0.00278872
# epoch 495 loss_pde:0.25893390, loss_ic:0.00278885
# epoch 495 loss_pde:0.25893176, loss_ic:0.00278890
# epoch 495 loss_pde:0.25892764, loss_ic:0.00278914
# epoch 495 loss_pde:0.25892434, loss_ic:0.00278931
# epoch 495: loss 5.314659
# epoch 496 loss_pde:0.25892434, loss_ic:0.00278931
# epoch 496 loss_pde:0.25891930, loss_ic:0.00278945
# epoch 496 loss_pde:0.25891680, loss_ic:0.00278950
# epoch 496 loss_pde:0.25890803, loss_ic:0.00278943
# epoch 496 loss_pde:0.25890610, loss_ic:0.00278953
# epoch 496 loss_pde:0.25890332, loss_ic:0.00278952
# epoch 496: loss 5.314658
# epoch 497 loss_pde:0.25890332, loss_ic:0.00278952
# epoch 497 loss_pde:0.25889936, loss_ic:0.00278972
# epoch 497 loss_pde:0.25889605, loss_ic:0.00278977
# epoch 497 loss_pde:0.25889242, loss_ic:0.00278993
# epoch 497 loss_pde:0.25888893, loss_ic:0.00279001
# epoch 497: loss 5.314658
# epoch 498 loss_pde:0.25888893, loss_ic:0.00279001
# epoch 498 loss_pde:0.25888577, loss_ic:0.00279010
# epoch 498: loss 5.314657
# epoch 499 loss_pde:0.25888577, loss_ic:0.00279010
# epoch 499 loss_pde:0.25888264, loss_ic:0.00279021
# epoch 499 loss_pde:0.25887963, loss_ic:0.00279026
# epoch 499: loss 5.314657
# epoch 500 loss_pde:0.25887963, loss_ic:0.00279026
# epoch 500 loss_pde:0.25887698, loss_ic:0.00279037
# epoch 500 loss_pde:0.25887477, loss_ic:0.00279035
# epoch 500 loss_pde:0.25887266, loss_ic:0.00279046
# epoch 500 loss_pde:0.25887072, loss_ic:0.00279051
# epoch 500 loss_pde:0.25886852, loss_ic:0.00279065
# epoch 500: loss 5.314657
# epoch 501 loss_pde:0.25886852, loss_ic:0.00279065
# epoch 501 loss_pde:0.25886732, loss_ic:0.00279068
# epoch 501 loss_pde:0.25886694, loss_ic:0.00279061
# epoch 501 loss_pde:0.25886637, loss_ic:0.00279055
# epoch 501: loss 5.314656
# epoch 502 loss_pde:0.25886637, loss_ic:0.00279055
# epoch 502 loss_pde:0.25886548, loss_ic:0.00279070
# epoch 502 loss_pde:0.25886539, loss_ic:0.00279069
# epoch 502: loss 5.314656
# epoch 503 loss_pde:0.25886539, loss_ic:0.00279069
# epoch 503 loss_pde:0.25886416, loss_ic:0.00279079
# epoch 503 loss_pde:0.25886449, loss_ic:0.00279081
# epoch 503 loss_pde:0.25886422, loss_ic:0.00279088
# epoch 503 loss_pde:0.25886497, loss_ic:0.00279087
# epoch 503 loss_pde:0.25886568, loss_ic:0.00279108
# epoch 503: loss 5.314656
# epoch 504 loss_pde:0.25886568, loss_ic:0.00279108
# epoch 504 loss_pde:0.25886562, loss_ic:0.00279117
# epoch 504: loss 5.314656
# epoch 505 loss_pde:0.25886562, loss_ic:0.00279117
# epoch 505 loss_pde:0.25887245, loss_ic:0.00278959
# epoch 505: loss 5.314656
# epoch 506 loss_pde:0.25887245, loss_ic:0.00278959
# epoch 506 loss_pde:0.25887379, loss_ic:0.00278965
# epoch 506 loss_pde:0.25887632, loss_ic:0.00278970
# epoch 506 loss_pde:0.25887853, loss_ic:0.00278973
# epoch 506 loss_pde:0.25888175, loss_ic:0.00278973
# epoch 506: loss 5.314656
# epoch 507 loss_pde:0.25888175, loss_ic:0.00278973
# epoch 507 loss_pde:0.25888473, loss_ic:0.00278973
# epoch 507: loss 5.314655
# epoch 508 loss_pde:0.25888473, loss_ic:0.00278973
# epoch 508 loss_pde:0.25888857, loss_ic:0.00278974
# epoch 508 loss_pde:0.25889203, loss_ic:0.00278971
# epoch 508 loss_pde:0.25889590, loss_ic:0.00278972
# epoch 508 loss_pde:0.25890020, loss_ic:0.00278965
# epoch 508 loss_pde:0.25890225, loss_ic:0.00278993
# epoch 508 loss_pde:0.25890699, loss_ic:0.00278979
# epoch 508: loss 5.314655
# epoch 509 loss_pde:0.25890699, loss_ic:0.00278979
# epoch 509 loss_pde:0.25891000, loss_ic:0.00278992
# epoch 509 loss_pde:0.25891379, loss_ic:0.00278992
# epoch 509: loss 5.314654
# epoch 510 loss_pde:0.25891379, loss_ic:0.00278992
# epoch 510 loss_pde:0.25891724, loss_ic:0.00278985
# epoch 510 loss_pde:0.25892061, loss_ic:0.00279002
# epoch 510 loss_pde:0.25892460, loss_ic:0.00278966
# epoch 510 loss_pde:0.25892764, loss_ic:0.00279012
# epoch 510: loss 5.314655
# epoch 511 loss_pde:0.25892764, loss_ic:0.00279012
# epoch 511 loss_pde:0.25893119, loss_ic:0.00278980
# epoch 511 loss_pde:0.25893381, loss_ic:0.00279011
# epoch 511: loss 5.314655
# epoch 512 loss_pde:0.25893381, loss_ic:0.00279011
# epoch 512 loss_pde:0.25893721, loss_ic:0.00278976
# epoch 512 loss_pde:0.25893965, loss_ic:0.00278997
# epoch 512 loss_pde:0.25894231, loss_ic:0.00278956
# epoch 512 loss_pde:0.25894493, loss_ic:0.00278963
# epoch 512 loss_pde:0.25894374, loss_ic:0.00278937
# epoch 512 loss_pde:0.25894538, loss_ic:0.00278940
# epoch 512 loss_pde:0.25894788, loss_ic:0.00278908
# epoch 512 loss_pde:0.25894043, loss_ic:0.00278996
# epoch 512: loss 5.314654
# epoch 513 loss_pde:0.25894043, loss_ic:0.00278996
# epoch 513 loss_pde:0.25894466, loss_ic:0.00278951
# epoch 513 loss_pde:0.25893807, loss_ic:0.00279001
# epoch 513: loss 5.314654
# epoch 514 loss_pde:0.25893807, loss_ic:0.00279001
# epoch 514 loss_pde:0.25895154, loss_ic:0.00278921
# epoch 514 loss_pde:0.25895104, loss_ic:0.00278916
# epoch 514 loss_pde:0.25894269, loss_ic:0.00278991
# epoch 514 loss_pde:0.25893974, loss_ic:0.00278989
# epoch 514 loss_pde:0.25893694, loss_ic:0.00278994
# epoch 514 loss_pde:0.25893420, loss_ic:0.00278990
# epoch 514 loss_pde:0.25892574, loss_ic:0.00279016
# epoch 514 loss_pde:0.25892571, loss_ic:0.00278999
# epoch 514: loss 5.314653
# epoch 515 loss_pde:0.25892571, loss_ic:0.00278999
# epoch 515 loss_pde:0.25891718, loss_ic:0.00279019
# epoch 515 loss_pde:0.25891566, loss_ic:0.00279011
# epoch 515 loss_pde:0.25890797, loss_ic:0.00279027
# epoch 515 loss_pde:0.25890356, loss_ic:0.00279032
# epoch 515: loss 5.314652
# epoch 516 loss_pde:0.25890356, loss_ic:0.00279032
# epoch 516 loss_pde:0.25889623, loss_ic:0.00279040
# epoch 516 loss_pde:0.25889122, loss_ic:0.00279063
# epoch 516: loss 5.314651
# epoch 517 loss_pde:0.25889122, loss_ic:0.00279063
# epoch 517 loss_pde:0.25888419, loss_ic:0.00279046
# epoch 517: loss 5.314651
# epoch 518 loss_pde:0.25888419, loss_ic:0.00279046
# epoch 518 loss_pde:0.25887674, loss_ic:0.00279088
# epoch 518 loss_pde:0.25886980, loss_ic:0.00278987
# epoch 518 loss_pde:0.25886506, loss_ic:0.00279001
# epoch 518: loss 5.314651
# epoch 519 loss_pde:0.25886506, loss_ic:0.00279001
# epoch 519 loss_pde:0.25885808, loss_ic:0.00279026
# epoch 519 loss_pde:0.25885960, loss_ic:0.00279028
# epoch 519 loss_pde:0.25885472, loss_ic:0.00279047
# epoch 519 loss_pde:0.25884846, loss_ic:0.00279066
# epoch 519 loss_pde:0.25884676, loss_ic:0.00279089
# epoch 519 loss_pde:0.25881380, loss_ic:0.00279109
# epoch 519: loss 5.314650
# epoch 520 loss_pde:0.25881380, loss_ic:0.00279109
# epoch 520 loss_pde:0.25881287, loss_ic:0.00279140
# epoch 520 loss_pde:0.25881156, loss_ic:0.00279153
# epoch 520 loss_pde:0.25881127, loss_ic:0.00279165
# epoch 520 loss_pde:0.25881132, loss_ic:0.00279173
# epoch 520 loss_pde:0.25881192, loss_ic:0.00279180
# epoch 520: loss 5.314649
# epoch 521 loss_pde:0.25881192, loss_ic:0.00279180
# epoch 521 loss_pde:0.25881276, loss_ic:0.00279184
# epoch 521 loss_pde:0.25881416, loss_ic:0.00279192
# epoch 521 loss_pde:0.25881767, loss_ic:0.00279168
# epoch 521 loss_pde:0.25881758, loss_ic:0.00279191
# epoch 521: loss 5.314649
# epoch 522 loss_pde:0.25881758, loss_ic:0.00279191
# epoch 522 loss_pde:0.25882110, loss_ic:0.00279180
# epoch 522 loss_pde:0.25882253, loss_ic:0.00279183
# epoch 522 loss_pde:0.25882515, loss_ic:0.00279173

# %%
device1 = torch.device("cpu")
model = torch.save('1.pt')

# %%
model_path = '1.pth'
model = torch.load(model_path, map_location=torch.device('cpu'))
model = model.to(device)

# %%
x = np.linspace(0.0, 2.0, 100)                                  
t = np.linspace(0.5, 0.5, 1)                                        
t_grid, x_grid = np.meshgrid(t, x)                              
T = t_grid.flatten()[:, None]                                   
X = x_grid.flatten()[:, None]                                   
x_test = np.hstack((T, X))                                      
x_test = torch.tensor(x_test, requires_grad=True, dtype=torch.float32).to(device)
u_pred = to_numpy(model(x_test))
res = to_numpy(model.res_pde(x_test))
d   = to_numpy(model.lambda_pde(x_test))

#loss = model.loss_pde(x_test)                                 

import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x[:],u_pred[:,0])
plt.show()

# %%
plt.scatter(x[:],1/d[:,0])

plt.show()

# %%
new_array = np.array(u_pred[:,0])
file = open("burgers_u_we_11500.dat", "w+")
for i in range(u_pred.shape[0]):
    print(f'{x[i]}  {u_pred[i,0]} ',file=file)
file.close()

# %%
new_array = np.array(res[:,0])
file = open("burgers_res_w_5000.dat", "w+")
for i in range(u_pred.shape[0]):
    print(f'{x[i]}  {res[i,0]} ',file=file)
file.close()

# %%
file = open("burgers_d_w_14931.dat", "w+")
for i in range(d.shape[0]):
    print(f'{x[i]}  {1/d[i,0]} ',file=file)
file.close()
