# %% [markdown]
# # Burgers equation
#
# This code is modified from the code https://github.com/alexpapados/Physics-Informed-Deep-Learning-Solid-and-Fluid-Mechanics
#
# The paper about this work can ref https://www.researchgate.net/publication/359480166_Discontinuity_Computing_with_Physics-Informed_Neural_Network

# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
import math
#import matplotlib

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
  #  random.seed(seed)
    torch.backends.cudnn.deterministic = True
    
setup_seed(124)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1949789/2661428818.py in <module>
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import numpy as np
#       4 import time
#       5 import scipy.io
#
# ModuleNotFoundError: No module named 'torch'

# %%
def train(epoch):
    model.train()
    model.it = epoch
    def closure():
        optimizer.zero_grad()                                              
        loss_pde = model.loss_pde(x_int)                                   
        loss_ic = model.loss_ic(x_ic, u_ic)  
        loss = loss_pde + 10*loss_ic                                       

        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f}')
        #model.it = model.it + 1
        #outputfile = open('loss_history_burgers.dat','a+')
        #print(f'{model.it}  {loss_pde:.6f}  {loss_ic:.6f}  {loss:.6f}',file=outputfile)
        #outputfile.close() 
        loss.backward()
        return loss

    loss = optimizer.step(closure)
    loss_value = loss.item() if not isinstance(loss, float) else loss
    print(f'epoch {epoch}: loss {loss_value:.6f}')
    
def gradients(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

def to_numpy(input):
    if isinstance(input, torch.Tensor):
        return input.detach().cpu().numpy()
    elif isinstance(input, np.ndarray):
        return input
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                        'np.ndarray, but got {}'.format(type(input)))

def IC(x):
    N = len(x)
    u_init = np.zeros((x.shape[0]))                                                
    for i in range(N):
        u_init[i] = -np.sin(np.pi*(x[i,1]-1))
    return u_init

class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.net = nn.Sequential()                                                  
        self.net.add_module('Linear_layer_1', nn.Linear(2, 30))                     
        self.net.add_module('Tanh_layer_1', nn.Tanh())                              

        for num in range(2, 4):                                                     
            self.net.add_module('Linear_layer_%d' % (num), nn.Linear(30, 30))       
            self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 
        self.net.add_module('Linear_layer_final', nn.Linear(30, 1))                 

    def forward(self, x):
        return self.net(x)

    def loss_pde(self, x):
        y = self.net(x)                                                
        u = y[:, 0:1]
        
        U = u**2/2

        dU_g = gradients(U, x)[0]                                  
        U_x = dU_g[:, 1:]
        du_g = gradients(u, x)[0]                                 
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        d = 0.1*(abs(u_x)-u_x) + 1
       # d = 1
        
        f = (((u_t + U_x)/d)**2).mean() 
         
        return f
    def res_pde(self,x):
        y = self.net(x)
        Res = np.zeros((x.shape[0]))                                  
        
        u = y[:, 0:1]
        U = u**2/2
        dU_g = gradients(U, x)[0]                                 
        U_x = dU_g[:, 1:]
        du_g = gradients(u, x)[0]                                  
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        Res = (u_t + U_x)**2 
        return Res 
    
    def lambda_pde(self,x):
        y = self.net(x)
        Res = np.zeros((x.shape[0]))                                  
        
        u = y[:, 0:1]
        du_g = gradients(u, x)[0]                                  
        u_t,u_x = du_g[:, :1],du_g[:,1:]
        d = 0.1*(abs(u_x)-u_x) + 1
        return  d
        

    def loss_ic(self, x_ic, u_ic):
        y_ic = self.net(x_ic)                                                      
        u_ic_nn = y_ic[:, 0]
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean()
        return loss_ics

# %%
device = torch.device('cuda')                                      
#device = torch.device('cpu')                                      
num_x = 50                                                        
num_t = 50                                                        
num_i_train = 50                                          
num_f_train = 2500                                          
x = np.linspace(0, 2, num_x)                                   
t = np.linspace(0, 1, num_t)                                   
t_grid, x_grid = np.meshgrid(t, x)                             
T = t_grid.flatten()[:, None]                                  
X = x_grid.flatten()[:, None]                                  

id_ic = np.random.choice(num_x, num_i_train, replace=False)    
id_f = np.random.choice(num_x*num_t, num_f_train, replace=False)

x_ic = x_grid[id_ic, 0][:, None]                               
t_ic = t_grid[id_ic, 0][:, None]                               
x_ic_train = np.hstack((t_ic, x_ic))                               
u_ic_train = IC(x_ic_train)                 

x_int = X[:, 0][id_f, None]                                        
t_int = T[:, 0][id_f, None]                                        
x_int_train = np.hstack((t_int, x_int))                            

u_ic_train = IC(x_ic_train)                 

x_ic = torch.tensor(x_ic_train, dtype=torch.float32).to(device)
x_int = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)
u_ic = torch.tensor(u_ic_train, dtype=torch.float32).to(device)

model = DNN().to(device)

lr = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
print('Start training...')
# Out:
# Start training...

# %%
#optimizer = torch.optim.LBFGS(model.parameters(),lr=1.1,max_iter=20)
#optimizer = torch.optim.LBFGS(PINN.parameters(), lr=1.1, 
#                              max_iter = 25, 
#                              max_eval = None, 
#                              tolerance_grad = 1e-05, 
#                              tolerance_change = 1e-09, 
#                              history_size = 100, 
#                              line_search_fn = 'strong_wolfe')
epochs = 15000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
    
toc = time.time()
# Out:
# epoch 1 loss_pde:0.00107175, loss_ic:0.59482706
# epoch 1: loss 5.949343
# epoch 2 loss_pde:0.00068887, loss_ic:0.56411862
# epoch 2: loss 5.641875
# epoch 3 loss_pde:0.00044602, loss_ic:0.53729343
# epoch 3: loss 5.373380
# epoch 4 loss_pde:0.00031794, loss_ic:0.51404142
# epoch 4: loss 5.140732
# epoch 5 loss_pde:0.00027201, loss_ic:0.49412483
# epoch 5: loss 4.941520
# epoch 6 loss_pde:0.00028272, loss_ic:0.47735697
# epoch 6: loss 4.773852
# epoch 7 loss_pde:0.00034229, loss_ic:0.46352077
# epoch 7: loss 4.635550
# epoch 8 loss_pde:0.00045452, loss_ic:0.45229661
# epoch 8: loss 4.523421
# epoch 9 loss_pde:0.00062982, loss_ic:0.44322875
# epoch 9: loss 4.432918
# epoch 10 loss_pde:0.00087873, loss_ic:0.43575087
# epoch 10: loss 4.358387
# epoch 11 loss_pde:0.00120685, loss_ic:0.42925248
# epoch 11: loss 4.293732
# epoch 12 loss_pde:0.00161204, loss_ic:0.42315334
# epoch 12: loss 4.233146
# epoch 13 loss_pde:0.00208410, loss_ic:0.41697443
# epoch 13: loss 4.171829
# epoch 14 loss_pde:0.00260675, loss_ic:0.41038603
# epoch 14: loss 4.106467
# epoch 15 loss_pde:0.00316086, loss_ic:0.40322149
# epoch 15: loss 4.035376
# epoch 16 loss_pde:0.00372788, loss_ic:0.39546052
# epoch 16: loss 3.958333
# epoch 17 loss_pde:0.00429278, loss_ic:0.38719374
# epoch 17: loss 3.876230
# epoch 18 loss_pde:0.00484610, loss_ic:0.37858066
# epoch 18: loss 3.790653
# epoch 19 loss_pde:0.00538512, loss_ic:0.36980918
# epoch 19: loss 3.703477
# epoch 20 loss_pde:0.00591443, loss_ic:0.36106116
# epoch 20: loss 3.616526
# epoch 21 loss_pde:0.00644610, loss_ic:0.35248533
# epoch 21: loss 3.531299
# epoch 22 loss_pde:0.00699948, loss_ic:0.34417889
# epoch 22: loss 3.448788
# epoch 23 loss_pde:0.00760091, loss_ic:0.33617863
# epoch 23: loss 3.369387
# epoch 24 loss_pde:0.00828342, loss_ic:0.32846168
# epoch 24: loss 3.292900
# epoch 25 loss_pde:0.00908647, loss_ic:0.32095614
# epoch 25: loss 3.218648
# epoch 26 loss_pde:0.01005541, loss_ic:0.31355980
# epoch 26: loss 3.145653
# epoch 27 loss_pde:0.01124072, loss_ic:0.30616498
# epoch 27: loss 3.072891
# epoch 28 loss_pde:0.01269694, loss_ic:0.29868427
# epoch 28: loss 2.999540
# epoch 29 loss_pde:0.01448160, loss_ic:0.29107219
# epoch 29: loss 2.925203
# epoch 30 loss_pde:0.01665406, loss_ic:0.28333732
# epoch 30: loss 2.850027
# epoch 31 loss_pde:0.01927398, loss_ic:0.27554339
# epoch 31: loss 2.774708
# epoch 32 loss_pde:0.02239915, loss_ic:0.26779827
# epoch 32: loss 2.700382
# epoch 33 loss_pde:0.02608212, loss_ic:0.26023430
# epoch 33: loss 2.628425
# epoch 34 loss_pde:0.03036562, loss_ic:0.25298202
# epoch 34: loss 2.560186
# epoch 35 loss_pde:0.03527694, loss_ic:0.24614456
# epoch 35: loss 2.496722
# epoch 36 loss_pde:0.04082278, loss_ic:0.23977834
# epoch 36: loss 2.438606
# epoch 37 loss_pde:0.04698637, loss_ic:0.23388828
# epoch 37: loss 2.385869
# epoch 38 loss_pde:0.05372920, loss_ic:0.22844085
# epoch 38: loss 2.338138
# epoch 39 loss_pde:0.06099799, loss_ic:0.22339237
# epoch 39: loss 2.294922
# epoch 40 loss_pde:0.06873482, loss_ic:0.21872060
# epoch 40: loss 2.255941
# epoch 41 loss_pde:0.07688665, loss_ic:0.21444538
# epoch 41: loss 2.221340
# epoch 42 loss_pde:0.08541044, loss_ic:0.21062714
# epoch 42: loss 2.191682
# epoch 43 loss_pde:0.09427176, loss_ic:0.20734394
# epoch 43: loss 2.167711
# epoch 44 loss_pde:0.10343740, loss_ic:0.20465484
# epoch 44: loss 2.149986
# epoch 45 loss_pde:0.11286296, loss_ic:0.20256543
# epoch 45: loss 2.138517
# epoch 46 loss_pde:0.12247837, loss_ic:0.20101207
# epoch 46: loss 2.132599
# epoch 47 loss_pde:0.13217458, loss_ic:0.19987659
# epoch 47: loss 2.130940
# epoch 48 loss_pde:0.14179575, loss_ic:0.19902728
# epoch 48: loss 2.132069
# epoch 49 loss_pde:0.15113874, loss_ic:0.19836406
# epoch 49: loss 2.134779
# epoch 50 loss_pde:0.15996037, loss_ic:0.19784139
# epoch 50: loss 2.138374
# epoch 51 loss_pde:0.16799057, loss_ic:0.19745637
# epoch 51: loss 2.142554
# epoch 52 loss_pde:0.17495206, loss_ic:0.19721484
# epoch 52: loss 2.147100
# epoch 53 loss_pde:0.18058798, loss_ic:0.19709902
# epoch 53: loss 2.151578
# epoch 54 loss_pde:0.18469584, loss_ic:0.19705860
# epoch 54: loss 2.155282
# epoch 55 loss_pde:0.18716109, loss_ic:0.19702883
# epoch 55: loss 2.157449
# epoch 56 loss_pde:0.18797813, loss_ic:0.19696085
# epoch 56: loss 2.157587
# epoch 57 loss_pde:0.18725078, loss_ic:0.19684181
# epoch 57: loss 2.155669
# epoch 58 loss_pde:0.18517178, loss_ic:0.19669247
# epoch 58: loss 2.152097
# epoch 59 loss_pde:0.18199009, loss_ic:0.19654666
# epoch 59: loss 2.147457
# epoch 60 loss_pde:0.17797506, loss_ic:0.19642866
# epoch 60: loss 2.142262
# epoch 61 loss_pde:0.17338617, loss_ic:0.19634274
# epoch 61: loss 2.136813
# epoch 62 loss_pde:0.16845205, loss_ic:0.19627833
# epoch 62: loss 2.131235
# epoch 63 loss_pde:0.16335960, loss_ic:0.19622476
# epoch 63: loss 2.125607
# epoch 64 loss_pde:0.15825154, loss_ic:0.19618246
# epoch 64: loss 2.120076
# epoch 65 loss_pde:0.15323015, loss_ic:0.19616489
# epoch 65: loss 2.114879
# epoch 66 loss_pde:0.14836426, loss_ic:0.19619045
# epoch 66: loss 2.110269
# epoch 67 loss_pde:0.14369790, loss_ic:0.19627166
# epoch 67: loss 2.106415
# epoch 68 loss_pde:0.13925937, loss_ic:0.19640830
# epoch 68: loss 2.103342
# epoch 69 loss_pde:0.13506933, loss_ic:0.19658799
# epoch 69: loss 2.100949
# epoch 70 loss_pde:0.13114712, loss_ic:0.19679229
# epoch 70: loss 2.099070
# epoch 71 loss_pde:0.12751423, loss_ic:0.19700390
# epoch 71: loss 2.097553
# epoch 72 loss_pde:0.12419499, loss_ic:0.19721065
# epoch 72: loss 2.096302
# epoch 73 loss_pde:0.12121451, loss_ic:0.19740531
# epoch 73: loss 2.095268
# epoch 74 loss_pde:0.11859560, loss_ic:0.19758227
# epoch 74: loss 2.094418
# epoch 75 loss_pde:0.11635539, loss_ic:0.19773450
# epoch 75: loss 2.093700
# epoch 76 loss_pde:0.11450253, loss_ic:0.19785288
# epoch 76: loss 2.093031
# epoch 77 loss_pde:0.11303572, loss_ic:0.19792797
# epoch 77: loss 2.092315
# epoch 78 loss_pde:0.11194332, loss_ic:0.19795312
# epoch 78: loss 2.091475
# epoch 79 loss_pde:0.11120412, loss_ic:0.19792658
# epoch 79: loss 2.090470
# epoch 80 loss_pde:0.11078862, loss_ic:0.19785154
# epoch 80: loss 2.089304
# epoch 81 loss_pde:0.11066112, loss_ic:0.19773455
# epoch 81: loss 2.088006
# epoch 82 loss_pde:0.11078205, loss_ic:0.19758281
# epoch 82: loss 2.086610
# epoch 83 loss_pde:0.11111068, loss_ic:0.19740248
# epoch 83: loss 2.085135
# epoch 84 loss_pde:0.11160786, loss_ic:0.19719821
# epoch 84: loss 2.083590
# epoch 85 loss_pde:0.11223833, loss_ic:0.19697396
# epoch 85: loss 2.081978
# epoch 86 loss_pde:0.11297239, loss_ic:0.19673385
# epoch 86: loss 2.080311
# epoch 87 loss_pde:0.11378634, loss_ic:0.19648287
# epoch 87: loss 2.078615
# epoch 88 loss_pde:0.11466196, loss_ic:0.19622612
# epoch 88: loss 2.076923
# epoch 89 loss_pde:0.11558495, loss_ic:0.19596811
# epoch 89: loss 2.075266
# epoch 90 loss_pde:0.11654282, loss_ic:0.19571193
# epoch 90: loss 2.073662
# epoch 91 loss_pde:0.11752280, loss_ic:0.19545904
# epoch 91: loss 2.072113
# epoch 92 loss_pde:0.11851013, loss_ic:0.19521022
# epoch 92: loss 2.070612
# epoch 93 loss_pde:0.11948708, loss_ic:0.19496635
# epoch 93: loss 2.069150
# epoch 94 loss_pde:0.12043269, loss_ic:0.19472893
# epoch 94: loss 2.067722
# epoch 95 loss_pde:0.12132363, loss_ic:0.19450024
# epoch 95: loss 2.066326
# epoch 96 loss_pde:0.12213568, loss_ic:0.19428246
# epoch 96: loss 2.064960
# epoch 97 loss_pde:0.12284584, loss_ic:0.19407730
# epoch 97: loss 2.063619
# epoch 98 loss_pde:0.12343456, loss_ic:0.19388546
# epoch 98: loss 2.062289
# epoch 99 loss_pde:0.12388781, loss_ic:0.19370688
# epoch 99: loss 2.060957
# epoch 100 loss_pde:0.12419856, loss_ic:0.19354105
# epoch 100: loss 2.059609
# epoch 101 loss_pde:0.12436698, loss_ic:0.19338726
# epoch 101: loss 2.058239
# epoch 102 loss_pde:0.12440000, loss_ic:0.19324465
# epoch 102: loss 2.056846
# epoch 103 loss_pde:0.12430975, loss_ic:0.19311212
# epoch 103: loss 2.055431
# epoch 104 loss_pde:0.12411163, loss_ic:0.19298823
# epoch 104: loss 2.053994
# epoch 105 loss_pde:0.12382217, loss_ic:0.19287129
# epoch 105: loss 2.052535
# epoch 106 loss_pde:0.12345722, loss_ic:0.19275954
# epoch 106: loss 2.051053
# epoch 107 loss_pde:0.12303071, loss_ic:0.19265170
# epoch 107: loss 2.049548
# epoch 108 loss_pde:0.12255415, loss_ic:0.19254687
# epoch 108: loss 2.048023
# epoch 109 loss_pde:0.12203659, loss_ic:0.19244459
# epoch 109: loss 2.046483
# epoch 110 loss_pde:0.12148545, loss_ic:0.19234456
# epoch 110: loss 2.044931
# epoch 111 loss_pde:0.12090722, loss_ic:0.19224645
# epoch 111: loss 2.043372
# epoch 112 loss_pde:0.12030859, loss_ic:0.19214959
# epoch 112: loss 2.041805
# epoch 113 loss_pde:0.11969714, loss_ic:0.19205321
# epoch 113: loss 2.040229
# epoch 114 loss_pde:0.11908174, loss_ic:0.19195633
# epoch 114: loss 2.038645
# epoch 115 loss_pde:0.11847238, loss_ic:0.19185790
# epoch 115: loss 2.037051
# epoch 116 loss_pde:0.11787966, loss_ic:0.19175686
# epoch 116: loss 2.035448
# epoch 117 loss_pde:0.11731401, loss_ic:0.19165206
# epoch 117: loss 2.033835
# epoch 118 loss_pde:0.11678460, loss_ic:0.19154251
# epoch 118: loss 2.032210
# epoch 119 loss_pde:0.11629865, loss_ic:0.19142717
# epoch 119: loss 2.030570
# epoch 120 loss_pde:0.11586074, loss_ic:0.19130538
# epoch 120: loss 2.028915
# epoch 121 loss_pde:0.11547258, loss_ic:0.19117673
# epoch 121: loss 2.027240
# epoch 122 loss_pde:0.11513325, loss_ic:0.19104120
# epoch 122: loss 2.025545
# epoch 123 loss_pde:0.11483955, loss_ic:0.19089903
# epoch 123: loss 2.023830
# epoch 124 loss_pde:0.11458676, loss_ic:0.19075060
# epoch 124: loss 2.022093
# epoch 125 loss_pde:0.11436941, loss_ic:0.19059640
# epoch 125: loss 2.020334
# epoch 126 loss_pde:0.11418198, loss_ic:0.19043687
# epoch 126: loss 2.018551
# epoch 127 loss_pde:0.11401949, loss_ic:0.19027242
# epoch 127: loss 2.016744
# epoch 128 loss_pde:0.11387772, loss_ic:0.19010349
# epoch 128: loss 2.014913
# epoch 129 loss_pde:0.11375332, loss_ic:0.18993033
# epoch 129: loss 2.013057
# epoch 130 loss_pde:0.11364350, loss_ic:0.18975328
# epoch 130: loss 2.011176
# epoch 131 loss_pde:0.11354576, loss_ic:0.18957254
# epoch 131: loss 2.009271
# epoch 132 loss_pde:0.11345748, loss_ic:0.18938829
# epoch 132: loss 2.007340
# epoch 133 loss_pde:0.11337556, loss_ic:0.18920082
# epoch 133: loss 2.005384
# epoch 134 loss_pde:0.11329638, loss_ic:0.18901046
# epoch 134: loss 2.003401
# epoch 135 loss_pde:0.11321565, loss_ic:0.18881747
# epoch 135: loss 2.001390
# epoch 136 loss_pde:0.11312873, loss_ic:0.18862236
# epoch 136: loss 1.999352
# epoch 137 loss_pde:0.11303099, loss_ic:0.18842541
# epoch 137: loss 1.997285
# epoch 138 loss_pde:0.11291816, loss_ic:0.18822700
# epoch 138: loss 1.995188
# epoch 139 loss_pde:0.11278674, loss_ic:0.18802738
# epoch 139: loss 1.993061
# epoch 140 loss_pde:0.11263431, loss_ic:0.18782669
# epoch 140: loss 1.990901
# epoch 141 loss_pde:0.11245961, loss_ic:0.18762490
# epoch 141: loss 1.988709
# epoch 142 loss_pde:0.11226264, loss_ic:0.18742196
# epoch 142: loss 1.986482
# epoch 143 loss_pde:0.11204424, loss_ic:0.18721767
# epoch 143: loss 1.984221
# epoch 144 loss_pde:0.11180605, loss_ic:0.18701178
# epoch 144: loss 1.981924
# epoch 145 loss_pde:0.11155005, loss_ic:0.18680398
# epoch 145: loss 1.979590
# epoch 146 loss_pde:0.11127826, loss_ic:0.18659398
# epoch 146: loss 1.977218
# epoch 147 loss_pde:0.11099255, loss_ic:0.18638144
# epoch 147: loss 1.974807
# epoch 148 loss_pde:0.11069455, loss_ic:0.18616621
# epoch 148: loss 1.972357
# epoch 149 loss_pde:0.11038558, loss_ic:0.18594791
# epoch 149: loss 1.969865
# epoch 150 loss_pde:0.11006677, loss_ic:0.18572645
# epoch 150: loss 1.967331
# epoch 151 loss_pde:0.10973928, loss_ic:0.18550155
# epoch 151: loss 1.964755
# epoch 152 loss_pde:0.10940427, loss_ic:0.18527298
# epoch 152: loss 1.962134
# epoch 153 loss_pde:0.10906316, loss_ic:0.18504047
# epoch 153: loss 1.959468
# epoch 154 loss_pde:0.10871755, loss_ic:0.18480377
# epoch 154: loss 1.956755
# epoch 155 loss_pde:0.10836928, loss_ic:0.18456252
# epoch 155: loss 1.953994
# epoch 156 loss_pde:0.10802019, loss_ic:0.18431643
# epoch 156: loss 1.951184
# epoch 157 loss_pde:0.10767204, loss_ic:0.18406515
# epoch 157: loss 1.948324
# epoch 158 loss_pde:0.10732634, loss_ic:0.18380840
# epoch 158: loss 1.945410
# epoch 159 loss_pde:0.10698415, loss_ic:0.18354595
# epoch 159: loss 1.942444
# epoch 160 loss_pde:0.10664608, loss_ic:0.18327755
# epoch 160: loss 1.939422
# epoch 161 loss_pde:0.10631216, loss_ic:0.18300302
# epoch 161: loss 1.936342
# epoch 162 loss_pde:0.10598203, loss_ic:0.18272226
# epoch 162: loss 1.933205
# epoch 163 loss_pde:0.10565495, loss_ic:0.18243514
# epoch 163: loss 1.930006
# epoch 164 loss_pde:0.10532993, loss_ic:0.18214165
# epoch 164: loss 1.926746
# epoch 165 loss_pde:0.10500591, loss_ic:0.18184164
# epoch 165: loss 1.923422
# epoch 166 loss_pde:0.10468183, loss_ic:0.18153507
# epoch 166: loss 1.920033
# epoch 167 loss_pde:0.10435677, loss_ic:0.18122184
# epoch 167: loss 1.916575
# epoch 168 loss_pde:0.10402986, loss_ic:0.18090184
# epoch 168: loss 1.913048
# epoch 169 loss_pde:0.10370029, loss_ic:0.18057498
# epoch 169: loss 1.909450
# epoch 170 loss_pde:0.10336738, loss_ic:0.18024105
# epoch 170: loss 1.905778
# epoch 171 loss_pde:0.10303037, loss_ic:0.17989993
# epoch 171: loss 1.902030
# epoch 172 loss_pde:0.10268845, loss_ic:0.17955154
# epoch 172: loss 1.898204
# epoch 173 loss_pde:0.10234074, loss_ic:0.17919564
# epoch 173: loss 1.894297
# epoch 174 loss_pde:0.10198631, loss_ic:0.17883214
# epoch 174: loss 1.890308
# epoch 175 loss_pde:0.10162421, loss_ic:0.17846087
# epoch 175: loss 1.886233
# epoch 176 loss_pde:0.10125356, loss_ic:0.17808162
# epoch 176: loss 1.882070
# epoch 177 loss_pde:0.10087359, loss_ic:0.17769425
# epoch 177: loss 1.877816
# epoch 178 loss_pde:0.10048371, loss_ic:0.17729850
# epoch 178: loss 1.873469
# epoch 179 loss_pde:0.10008357, loss_ic:0.17689413
# epoch 179: loss 1.869025
# epoch 180 loss_pde:0.09967299, loss_ic:0.17648086
# epoch 180: loss 1.864482
# epoch 181 loss_pde:0.09925205, loss_ic:0.17605835
# epoch 181: loss 1.859836
# epoch 182 loss_pde:0.09882092, loss_ic:0.17562629
# epoch 182: loss 1.855084
# epoch 183 loss_pde:0.09837986, loss_ic:0.17518428
# epoch 183: loss 1.850223
# epoch 184 loss_pde:0.09792917, loss_ic:0.17473197
# epoch 184: loss 1.845249
# epoch 185 loss_pde:0.09746910, loss_ic:0.17426896
# epoch 185: loss 1.840159
# epoch 186 loss_pde:0.09699987, loss_ic:0.17379485
# epoch 186: loss 1.834948
# epoch 187 loss_pde:0.09652159, loss_ic:0.17330928
# epoch 187: loss 1.829614
# epoch 188 loss_pde:0.09603434, loss_ic:0.17281181
# epoch 188: loss 1.824152
# epoch 189 loss_pde:0.09553815, loss_ic:0.17230205
# epoch 189: loss 1.818559
# epoch 190 loss_pde:0.09503300, loss_ic:0.17177956
# epoch 190: loss 1.812829
# epoch 191 loss_pde:0.09451891, loss_ic:0.17124391
# epoch 191: loss 1.806958
# epoch 192 loss_pde:0.09399589, loss_ic:0.17069462
# epoch 192: loss 1.800942
# epoch 193 loss_pde:0.09346391, loss_ic:0.17013130
# epoch 193: loss 1.794777
# epoch 194 loss_pde:0.09292293, loss_ic:0.16955341
# epoch 194: loss 1.788457
# epoch 195 loss_pde:0.09237286, loss_ic:0.16896050
# epoch 195: loss 1.781978
# epoch 196 loss_pde:0.09181357, loss_ic:0.16835207
# epoch 196: loss 1.775334
# epoch 197 loss_pde:0.09124477, loss_ic:0.16772763
# epoch 197: loss 1.768521
# epoch 198 loss_pde:0.09066617, loss_ic:0.16708675
# epoch 198: loss 1.761534
# epoch 199 loss_pde:0.09007736, loss_ic:0.16642886
# epoch 199: loss 1.754366
# epoch 200 loss_pde:0.08947789, loss_ic:0.16575347
# epoch 200: loss 1.747013
# epoch 201 loss_pde:0.08886731, loss_ic:0.16506012
# epoch 201: loss 1.739468
# epoch 202 loss_pde:0.08824521, loss_ic:0.16434821
# epoch 202: loss 1.731727
# epoch 203 loss_pde:0.08761123, loss_ic:0.16361724
# epoch 203: loss 1.723784
# epoch 204 loss_pde:0.08696508, loss_ic:0.16286670
# epoch 204: loss 1.715632
# epoch 205 loss_pde:0.08630656, loss_ic:0.16209598
# epoch 205: loss 1.707266
# epoch 206 loss_pde:0.08563560, loss_ic:0.16130447
# epoch 206: loss 1.698680
# epoch 207 loss_pde:0.08495218, loss_ic:0.16049163
# epoch 207: loss 1.689869
# epoch 208 loss_pde:0.08425640, loss_ic:0.15965685
# epoch 208: loss 1.680825
# epoch 209 loss_pde:0.08354841, loss_ic:0.15879953
# epoch 209: loss 1.671544
# epoch 210 loss_pde:0.08282850, loss_ic:0.15791902
# epoch 210: loss 1.662019
# epoch 211 loss_pde:0.08209699, loss_ic:0.15701477
# epoch 211: loss 1.652245
# epoch 212 loss_pde:0.08135435, loss_ic:0.15608610
# epoch 212: loss 1.642215
# epoch 213 loss_pde:0.08060113, loss_ic:0.15513250
# epoch 213: loss 1.631926
# epoch 214 loss_pde:0.07983804, loss_ic:0.15415332
# epoch 214: loss 1.621371
# epoch 215 loss_pde:0.07906588, loss_ic:0.15314794
# epoch 215: loss 1.610545
# epoch 216 loss_pde:0.07828563, loss_ic:0.15211585
# epoch 216: loss 1.599444
# epoch 217 loss_pde:0.07749838, loss_ic:0.15105648
# epoch 217: loss 1.588063
# epoch 218 loss_pde:0.07670540, loss_ic:0.14996929
# epoch 218: loss 1.576398
# epoch 219 loss_pde:0.07590802, loss_ic:0.14885382
# epoch 219: loss 1.564446
# epoch 220 loss_pde:0.07510776, loss_ic:0.14770958
# epoch 220: loss 1.552204
# epoch 221 loss_pde:0.07430623, loss_ic:0.14653616
# epoch 221: loss 1.539668
# epoch 222 loss_pde:0.07350517, loss_ic:0.14533323
# epoch 222: loss 1.526837
# epoch 223 loss_pde:0.07270647, loss_ic:0.14410052
# epoch 223: loss 1.513712
# epoch 224 loss_pde:0.07191215, loss_ic:0.14283772
# epoch 224: loss 1.500289
# epoch 225 loss_pde:0.07112442, loss_ic:0.14154473
# epoch 225: loss 1.486572
# epoch 226 loss_pde:0.07034568, loss_ic:0.14022142
# epoch 226: loss 1.472560
# epoch 227 loss_pde:0.06957853, loss_ic:0.13886780
# epoch 227: loss 1.458256
# epoch 228 loss_pde:0.06882575, loss_ic:0.13748394
# epoch 228: loss 1.443665
# epoch 229 loss_pde:0.06809036, loss_ic:0.13606997
# epoch 229: loss 1.428790
# epoch 230 loss_pde:0.06737561, loss_ic:0.13462619
# epoch 230: loss 1.413638
# epoch 231 loss_pde:0.06668489, loss_ic:0.13315295
# epoch 231: loss 1.398214
# epoch 232 loss_pde:0.06602180, loss_ic:0.13165070
# epoch 232: loss 1.382529
# epoch 233 loss_pde:0.06539020, loss_ic:0.13012004
# epoch 233: loss 1.366591
# epoch 234 loss_pde:0.06479403, loss_ic:0.12856165
# epoch 234: loss 1.350410
# epoch 235 loss_pde:0.06423740, loss_ic:0.12697631
# epoch 235: loss 1.334000
# epoch 236 loss_pde:0.06372459, loss_ic:0.12536500
# epoch 236: loss 1.317375
# epoch 237 loss_pde:0.06325997, loss_ic:0.12372876
# epoch 237: loss 1.300548
# epoch 238 loss_pde:0.06284802, loss_ic:0.12206872
# epoch 238: loss 1.283535
# epoch 239 loss_pde:0.06249323, loss_ic:0.12038620
# epoch 239: loss 1.266355
# epoch 240 loss_pde:0.06220014, loss_ic:0.11868260
# epoch 240: loss 1.249026
# epoch 241 loss_pde:0.06197321, loss_ic:0.11695947
# epoch 241: loss 1.231568
# epoch 242 loss_pde:0.06181687, loss_ic:0.11521842
# epoch 242: loss 1.214001
# epoch 243 loss_pde:0.06173532, loss_ic:0.11346119
# epoch 243: loss 1.196347
# epoch 244 loss_pde:0.06173266, loss_ic:0.11168966
# epoch 244: loss 1.178629
# epoch 245 loss_pde:0.06181272, loss_ic:0.10990577
# epoch 245: loss 1.160870
# epoch 246 loss_pde:0.06197916, loss_ic:0.10811155
# epoch 246: loss 1.143095
# epoch 247 loss_pde:0.06223530, loss_ic:0.10630912
# epoch 247: loss 1.125327
# epoch 248 loss_pde:0.06258392, loss_ic:0.10450064
# epoch 248: loss 1.107590
# epoch 249 loss_pde:0.06302767, loss_ic:0.10268834
# epoch 249: loss 1.089911
# epoch 250 loss_pde:0.06356891, loss_ic:0.10087448
# epoch 250: loss 1.072314
# epoch 251 loss_pde:0.06420962, loss_ic:0.09906132
# epoch 251: loss 1.054823
# epoch 252 loss_pde:0.06495166, loss_ic:0.09725116
# epoch 252: loss 1.037463
# epoch 253 loss_pde:0.06579649, loss_ic:0.09544633
# epoch 253: loss 1.020260
# epoch 254 loss_pde:0.06674526, loss_ic:0.09364908
# epoch 254: loss 1.003236
# epoch 255 loss_pde:0.06779904, loss_ic:0.09186169
# epoch 255: loss 0.986416
# epoch 256 loss_pde:0.06895828, loss_ic:0.09008633
# epoch 256: loss 0.969822
# epoch 257 loss_pde:0.07022361, loss_ic:0.08832523
# epoch 257: loss 0.953476
# epoch 258 loss_pde:0.07159499, loss_ic:0.08658046
# epoch 258: loss 0.937400
# epoch 259 loss_pde:0.07307231, loss_ic:0.08485405
# epoch 259: loss 0.921613
# epoch 260 loss_pde:0.07465503, loss_ic:0.08314799
# epoch 260: loss 0.906135
# epoch 261 loss_pde:0.07634213, loss_ic:0.08146419
# epoch 261: loss 0.890984
# epoch 262 loss_pde:0.07813240, loss_ic:0.07980439
# epoch 262: loss 0.876176
# epoch 263 loss_pde:0.08002379, loss_ic:0.07817034
# epoch 263: loss 0.861727
# epoch 264 loss_pde:0.08201410, loss_ic:0.07656364
# epoch 264: loss 0.847651
# epoch 265 loss_pde:0.08410054, loss_ic:0.07498581
# epoch 265: loss 0.833959
# epoch 266 loss_pde:0.08627956, loss_ic:0.07343823
# epoch 266: loss 0.820662
# epoch 267 loss_pde:0.08854730, loss_ic:0.07192221
# epoch 267: loss 0.807769
# epoch 268 loss_pde:0.09089948, loss_ic:0.07043891
# epoch 268: loss 0.795289
# epoch 269 loss_pde:0.09333104, loss_ic:0.06898937
# epoch 269: loss 0.783225
# epoch 270 loss_pde:0.09583641, loss_ic:0.06757455
# epoch 270: loss 0.771582
# epoch 271 loss_pde:0.09840977, loss_ic:0.06619524
# epoch 271: loss 0.760362
# epoch 272 loss_pde:0.10104489, loss_ic:0.06485213
# epoch 272: loss 0.749566
# epoch 273 loss_pde:0.10373508, loss_ic:0.06354581
# epoch 273: loss 0.739193
# epoch 274 loss_pde:0.10647333, loss_ic:0.06227668
# epoch 274: loss 0.729240
# epoch 275 loss_pde:0.10925259, loss_ic:0.06104506
# epoch 275: loss 0.719703
# epoch 276 loss_pde:0.11206561, loss_ic:0.05985118
# epoch 276: loss 0.710577
# epoch 277 loss_pde:0.11490516, loss_ic:0.05869512
# epoch 277: loss 0.701856
# epoch 278 loss_pde:0.11776399, loss_ic:0.05757684
# epoch 278: loss 0.693532
# epoch 279 loss_pde:0.12063475, loss_ic:0.05649622
# epoch 279: loss 0.685597
# epoch 280 loss_pde:0.12351023, loss_ic:0.05545302
# epoch 280: loss 0.678040
# epoch 281 loss_pde:0.12638336, loss_ic:0.05444694
# epoch 281: loss 0.670853
# epoch 282 loss_pde:0.12924729, loss_ic:0.05347753
# epoch 282: loss 0.664023
# epoch 283 loss_pde:0.13209528, loss_ic:0.05254433
# epoch 283: loss 0.657539
# epoch 284 loss_pde:0.13492085, loss_ic:0.05164672
# epoch 284: loss 0.651388
# epoch 285 loss_pde:0.13771769, loss_ic:0.05078405
# epoch 285: loss 0.645558
# epoch 286 loss_pde:0.14047980, loss_ic:0.04995561
# epoch 286: loss 0.640036
# epoch 287 loss_pde:0.14320114, loss_ic:0.04916062
# epoch 287: loss 0.634807
# epoch 288 loss_pde:0.14587606, loss_ic:0.04839822
# epoch 288: loss 0.629858
# epoch 289 loss_pde:0.14849913, loss_ic:0.04766753
# epoch 289: loss 0.625174
# epoch 290 loss_pde:0.15106511, loss_ic:0.04696766
# epoch 290: loss 0.620742
# epoch 291 loss_pde:0.15356913, loss_ic:0.04629763
# epoch 291: loss 0.616545
# epoch 292 loss_pde:0.15600660, loss_ic:0.04565646
# epoch 292: loss 0.612571
# epoch 293 loss_pde:0.15837322, loss_ic:0.04504314
# epoch 293: loss 0.608805
# epoch 294 loss_pde:0.16066509, loss_ic:0.04445667
# epoch 294: loss 0.605232
# epoch 295 loss_pde:0.16287863, loss_ic:0.04389599
# epoch 295: loss 0.601838
# epoch 296 loss_pde:0.16501066, loss_ic:0.04336007
# epoch 296: loss 0.598611
# epoch 297 loss_pde:0.16705833, loss_ic:0.04284786
# epoch 297: loss 0.595537
# epoch 298 loss_pde:0.16901921, loss_ic:0.04235833
# epoch 298: loss 0.592603
# epoch 299 loss_pde:0.17089118, loss_ic:0.04189043
# epoch 299: loss 0.589795
# epoch 300 loss_pde:0.17267257, loss_ic:0.04144315
# epoch 300: loss 0.587104
# epoch 301 loss_pde:0.17436208, loss_ic:0.04101544
# epoch 301: loss 0.584517
# epoch 302 loss_pde:0.17595877, loss_ic:0.04060633
# epoch 302: loss 0.582022
# epoch 303 loss_pde:0.17746200, loss_ic:0.04021478
# epoch 303: loss 0.579610
# epoch 304 loss_pde:0.17887150, loss_ic:0.03983984
# epoch 304: loss 0.577270
# epoch 305 loss_pde:0.18018721, loss_ic:0.03948055
# epoch 305: loss 0.574993
# epoch 306 loss_pde:0.18140934, loss_ic:0.03913598
# epoch 306: loss 0.572769
# epoch 307 loss_pde:0.18253833, loss_ic:0.03880524
# epoch 307: loss 0.570591
# epoch 308 loss_pde:0.18357475, loss_ic:0.03848742
# epoch 308: loss 0.568449
# epoch 309 loss_pde:0.18451931, loss_ic:0.03818171
# epoch 309: loss 0.566336
# epoch 310 loss_pde:0.18537287, loss_ic:0.03788732
# epoch 310: loss 0.564246
# epoch 311 loss_pde:0.18613647, loss_ic:0.03760345
# epoch 311: loss 0.562171
# epoch 312 loss_pde:0.18681127, loss_ic:0.03732936
# epoch 312: loss 0.560105
# epoch 313 loss_pde:0.18739870, loss_ic:0.03706434
# epoch 313: loss 0.558042
# epoch 314 loss_pde:0.18790027, loss_ic:0.03680766
# epoch 314: loss 0.555977
# epoch 315 loss_pde:0.18831770, loss_ic:0.03655868
# epoch 315: loss 0.553905
# epoch 316 loss_pde:0.18865280, loss_ic:0.03631677
# epoch 316: loss 0.551821
# epoch 317 loss_pde:0.18890753, loss_ic:0.03608127
# epoch 317: loss 0.549720
# epoch 318 loss_pde:0.18908398, loss_ic:0.03585161
# epoch 318: loss 0.547600
# epoch 319 loss_pde:0.18918429, loss_ic:0.03562720
# epoch 319: loss 0.545456
# epoch 320 loss_pde:0.18921068, loss_ic:0.03540751
# epoch 320: loss 0.543286
# epoch 321 loss_pde:0.18916552, loss_ic:0.03519198
# epoch 321: loss 0.541085
# epoch 322 loss_pde:0.18905105, loss_ic:0.03498011
# epoch 322: loss 0.538852
# epoch 323 loss_pde:0.18886958, loss_ic:0.03477142
# epoch 323: loss 0.536584
# epoch 324 loss_pde:0.18862350, loss_ic:0.03456542
# epoch 324: loss 0.534278
# epoch 325 loss_pde:0.18831518, loss_ic:0.03436168
# epoch 325: loss 0.531932
# epoch 326 loss_pde:0.18794702, loss_ic:0.03415973
# epoch 326: loss 0.529544
# epoch 327 loss_pde:0.18752141, loss_ic:0.03395916
# epoch 327: loss 0.527113
# epoch 328 loss_pde:0.18704081, loss_ic:0.03375953
# epoch 328: loss 0.524636
# epoch 329 loss_pde:0.18650763, loss_ic:0.03356045
# epoch 329: loss 0.522112
# epoch 330 loss_pde:0.18592423, loss_ic:0.03336152
# epoch 330: loss 0.519539
# epoch 331 loss_pde:0.18529309, loss_ic:0.03316234
# epoch 331: loss 0.516917
# epoch 332 loss_pde:0.18461660, loss_ic:0.03296255
# epoch 332: loss 0.514242
# epoch 333 loss_pde:0.18389712, loss_ic:0.03276178
# epoch 333: loss 0.511515
# epoch 334 loss_pde:0.18313701, loss_ic:0.03255968
# epoch 334: loss 0.508734
# epoch 335 loss_pde:0.18233857, loss_ic:0.03235593
# epoch 335: loss 0.505898
# epoch 336 loss_pde:0.18150413, loss_ic:0.03215017
# epoch 336: loss 0.503006
# epoch 337 loss_pde:0.18063593, loss_ic:0.03194213
# epoch 337: loss 0.500057
# epoch 338 loss_pde:0.17973639, loss_ic:0.03173149
# epoch 338: loss 0.497051
# epoch 339 loss_pde:0.17880782, loss_ic:0.03151799
# epoch 339: loss 0.493988
# epoch 340 loss_pde:0.17785262, loss_ic:0.03130133
# epoch 340: loss 0.490866
# epoch 341 loss_pde:0.17687313, loss_ic:0.03108130
# epoch 341: loss 0.487686
# epoch 342 loss_pde:0.17587179, loss_ic:0.03085767
# epoch 342: loss 0.484448
# epoch 343 loss_pde:0.17485107, loss_ic:0.03063022
# epoch 343: loss 0.481153
# epoch 344 loss_pde:0.17381352, loss_ic:0.03039880
# epoch 344: loss 0.477802
# epoch 345 loss_pde:0.17276177, loss_ic:0.03016323
# epoch 345: loss 0.474394
# epoch 346 loss_pde:0.17169859, loss_ic:0.02992338
# epoch 346: loss 0.470932
# epoch 347 loss_pde:0.17062683, loss_ic:0.02967915
# epoch 347: loss 0.467418
# epoch 348 loss_pde:0.16954958, loss_ic:0.02943044
# epoch 348: loss 0.463854
# epoch 349 loss_pde:0.16847011, loss_ic:0.02917717
# epoch 349: loss 0.460242
# epoch 350 loss_pde:0.16739191, loss_ic:0.02891930
# epoch 350: loss 0.456585
# epoch 351 loss_pde:0.16631864, loss_ic:0.02865677
# epoch 351: loss 0.452886
# epoch 352 loss_pde:0.16525401, loss_ic:0.02838962
# epoch 352: loss 0.449150
# epoch 353 loss_pde:0.16420193, loss_ic:0.02811787
# epoch 353: loss 0.445381
# epoch 354 loss_pde:0.16316652, loss_ic:0.02784155
# epoch 354: loss 0.441582
# epoch 355 loss_pde:0.16215202, loss_ic:0.02756074
# epoch 355: loss 0.437759
# epoch 356 loss_pde:0.16116278, loss_ic:0.02727555
# epoch 356: loss 0.433918
# epoch 357 loss_pde:0.16020334, loss_ic:0.02698611
# epoch 357: loss 0.430064
# epoch 358 loss_pde:0.15927832, loss_ic:0.02669256
# epoch 358: loss 0.426204
# epoch 359 loss_pde:0.15839252, loss_ic:0.02639504
# epoch 359: loss 0.422343
# epoch 360 loss_pde:0.15755072, loss_ic:0.02609378
# epoch 360: loss 0.418489
# epoch 361 loss_pde:0.15675785, loss_ic:0.02578897
# epoch 361: loss 0.414648
# epoch 362 loss_pde:0.15601870, loss_ic:0.02548085
# epoch 362: loss 0.410827
# epoch 363 loss_pde:0.15533808, loss_ic:0.02516966
# epoch 363: loss 0.407035
# epoch 364 loss_pde:0.15472050, loss_ic:0.02485570
# epoch 364: loss 0.403278
# epoch 365 loss_pde:0.15417041, loss_ic:0.02453928
# epoch 365: loss 0.399563
# epoch 366 loss_pde:0.15369214, loss_ic:0.02422070
# epoch 366: loss 0.395899
# epoch 367 loss_pde:0.15328968, loss_ic:0.02390031
# epoch 367: loss 0.392293
# epoch 368 loss_pde:0.15296638, loss_ic:0.02357847
# epoch 368: loss 0.388751
# epoch 369 loss_pde:0.15272500, loss_ic:0.02325560
# epoch 369: loss 0.385281
# epoch 370 loss_pde:0.15256757, loss_ic:0.02293212
# epoch 370: loss 0.381889
# epoch 371 loss_pde:0.15249531, loss_ic:0.02260854
# epoch 371: loss 0.378581
# epoch 372 loss_pde:0.15250893, loss_ic:0.02228531
# epoch 372: loss 0.375362
# epoch 373 loss_pde:0.15260816, loss_ic:0.02196294
# epoch 373: loss 0.372238
# epoch 374 loss_pde:0.15279199, loss_ic:0.02164193
# epoch 374: loss 0.369211
# epoch 375 loss_pde:0.15305835, loss_ic:0.02132280
# epoch 375: loss 0.366286
# epoch 376 loss_pde:0.15340437, loss_ic:0.02100606
# epoch 376: loss 0.363465
# epoch 377 loss_pde:0.15382662, loss_ic:0.02069222
# epoch 377: loss 0.360749
# epoch 378 loss_pde:0.15431988, loss_ic:0.02038181
# epoch 378: loss 0.358138
# epoch 379 loss_pde:0.15487821, loss_ic:0.02007541
# epoch 379: loss 0.355632
# epoch 380 loss_pde:0.15549517, loss_ic:0.01977349
# epoch 380: loss 0.353230
# epoch 381 loss_pde:0.15616277, loss_ic:0.01947661
# epoch 381: loss 0.350929
# epoch 382 loss_pde:0.15687284, loss_ic:0.01918527
# epoch 382: loss 0.348726
# epoch 383 loss_pde:0.15761629, loss_ic:0.01889999
# epoch 383: loss 0.346616
# epoch 384 loss_pde:0.15838398, loss_ic:0.01862118
# epoch 384: loss 0.344596
# epoch 385 loss_pde:0.15916665, loss_ic:0.01834926
# epoch 385: loss 0.342659
# epoch 386 loss_pde:0.15995479, loss_ic:0.01808459
# epoch 386: loss 0.340801
# epoch 387 loss_pde:0.16073973, loss_ic:0.01782743
# epoch 387: loss 0.339014
# epoch 388 loss_pde:0.16151294, loss_ic:0.01757801
# epoch 388: loss 0.337293
# epoch 389 loss_pde:0.16226670, loss_ic:0.01733646
# epoch 389: loss 0.335631
# epoch 390 loss_pde:0.16299233, loss_ic:0.01710302
# epoch 390: loss 0.334023
# epoch 391 loss_pde:0.16368310, loss_ic:0.01687774
# epoch 391: loss 0.332460
# epoch 392 loss_pde:0.16433351, loss_ic:0.01666061
# epoch 392: loss 0.330940
# epoch 393 loss_pde:0.16493821, loss_ic:0.01645161
# epoch 393: loss 0.329454
# epoch 394 loss_pde:0.16549380, loss_ic:0.01625058
# epoch 394: loss 0.328000
# epoch 395 loss_pde:0.16599718, loss_ic:0.01605740
# epoch 395: loss 0.326571
# epoch 396 loss_pde:0.16644721, loss_ic:0.01587178
# epoch 396: loss 0.325165
# epoch 397 loss_pde:0.16684349, loss_ic:0.01569344
# epoch 397: loss 0.323778
# epoch 398 loss_pde:0.16718611, loss_ic:0.01552208
# epoch 398: loss 0.322407
# epoch 399 loss_pde:0.16747621, loss_ic:0.01535738
# epoch 399: loss 0.321050
# epoch 400 loss_pde:0.16771650, loss_ic:0.01519889
# epoch 400: loss 0.319705
# epoch 401 loss_pde:0.16791020, loss_ic:0.01504616
# epoch 401: loss 0.318372
# epoch 402 loss_pde:0.16806072, loss_ic:0.01489878
# epoch 402: loss 0.317048
# epoch 403 loss_pde:0.16817103, loss_ic:0.01475641
# epoch 403: loss 0.315735
# epoch 404 loss_pde:0.16824529, loss_ic:0.01461865
# epoch 404: loss 0.314432
# epoch 405 loss_pde:0.16828707, loss_ic:0.01448513
# epoch 405: loss 0.313138
# epoch 406 loss_pde:0.16830124, loss_ic:0.01435542
# epoch 406: loss 0.311855
# epoch 407 loss_pde:0.16829441, loss_ic:0.01422889
# epoch 407: loss 0.310583
# epoch 408 loss_pde:0.16827336, loss_ic:0.01410491
# epoch 408: loss 0.309323
# epoch 409 loss_pde:0.16823938, loss_ic:0.01398346
# epoch 409: loss 0.308074
# epoch 410 loss_pde:0.16819440, loss_ic:0.01386439
# epoch 410: loss 0.306838
# epoch 411 loss_pde:0.16814305, loss_ic:0.01374734
# epoch 411: loss 0.305616
# epoch 412 loss_pde:0.16808884, loss_ic:0.01363197
# epoch 412: loss 0.304409
# epoch 413 loss_pde:0.16803423, loss_ic:0.01351814
# epoch 413: loss 0.303216
# epoch 414 loss_pde:0.16798291, loss_ic:0.01340548
# epoch 414: loss 0.302038
# epoch 415 loss_pde:0.16794062, loss_ic:0.01329348
# epoch 415: loss 0.300875
# epoch 416 loss_pde:0.16790992, loss_ic:0.01318190
# epoch 416: loss 0.299729
# epoch 417 loss_pde:0.16788848, loss_ic:0.01307097
# epoch 417: loss 0.298598
# epoch 418 loss_pde:0.16787750, loss_ic:0.01296058
# epoch 418: loss 0.297483
# epoch 419 loss_pde:0.16787781, loss_ic:0.01285064
# epoch 419: loss 0.296384
# epoch 420 loss_pde:0.16788955, loss_ic:0.01274110
# epoch 420: loss 0.295300
# epoch 421 loss_pde:0.16791278, loss_ic:0.01263191
# epoch 421: loss 0.294232
# epoch 422 loss_pde:0.16795030, loss_ic:0.01252275
# epoch 422: loss 0.293178
# epoch 423 loss_pde:0.16800474, loss_ic:0.01241331
# epoch 423: loss 0.292138
# epoch 424 loss_pde:0.16807334, loss_ic:0.01230380
# epoch 424: loss 0.291111
# epoch 425 loss_pde:0.16815564, loss_ic:0.01219423
# epoch 425: loss 0.290098
# epoch 426 loss_pde:0.16824841, loss_ic:0.01208487
# epoch 426: loss 0.289097
# epoch 427 loss_pde:0.16835019, loss_ic:0.01197582
# epoch 427: loss 0.288108
# epoch 428 loss_pde:0.16846174, loss_ic:0.01186699
# epoch 428: loss 0.287132
# epoch 429 loss_pde:0.16858400, loss_ic:0.01175822
# epoch 429: loss 0.286166
# epoch 430 loss_pde:0.16871738, loss_ic:0.01164943
# epoch 430: loss 0.285212
# epoch 431 loss_pde:0.16886237, loss_ic:0.01154058
# epoch 431: loss 0.284268
# epoch 432 loss_pde:0.16901499, loss_ic:0.01143202
# epoch 432: loss 0.283335
# epoch 433 loss_pde:0.16917226, loss_ic:0.01132404
# epoch 433: loss 0.282413
# epoch 434 loss_pde:0.16933280, loss_ic:0.01121675
# epoch 434: loss 0.281500
# epoch 435 loss_pde:0.16949582, loss_ic:0.01111023
# epoch 435: loss 0.280598
# epoch 436 loss_pde:0.16965969, loss_ic:0.01100461
# epoch 436: loss 0.279706
# epoch 437 loss_pde:0.16982405, loss_ic:0.01089993
# epoch 437: loss 0.278823
# epoch 438 loss_pde:0.16998927, loss_ic:0.01079611
# epoch 438: loss 0.277950
# epoch 439 loss_pde:0.17015299, loss_ic:0.01069339
# epoch 439: loss 0.277087
# epoch 440 loss_pde:0.17031321, loss_ic:0.01059194
# epoch 440: loss 0.276233
# epoch 441 loss_pde:0.17046958, loss_ic:0.01049177
# epoch 441: loss 0.275387
# epoch 442 loss_pde:0.17062034, loss_ic:0.01039302
# epoch 442: loss 0.274551
# epoch 443 loss_pde:0.17076340, loss_ic:0.01029588
# epoch 443: loss 0.273722
# epoch 444 loss_pde:0.17089920, loss_ic:0.01020027
# epoch 444: loss 0.272902
# epoch 445 loss_pde:0.17102663, loss_ic:0.01010629
# epoch 445: loss 0.272090
# epoch 446 loss_pde:0.17114389, loss_ic:0.01001407
# epoch 446: loss 0.271285
# epoch 447 loss_pde:0.17125244, loss_ic:0.00992347
# epoch 447: loss 0.270487
# epoch 448 loss_pde:0.17134979, loss_ic:0.00983468
# epoch 448: loss 0.269697
# epoch 449 loss_pde:0.17143677, loss_ic:0.00974763
# epoch 449: loss 0.268913
# epoch 450 loss_pde:0.17151323, loss_ic:0.00966231
# epoch 450: loss 0.268136
# epoch 451 loss_pde:0.17157865, loss_ic:0.00957875
# epoch 451: loss 0.267366
# epoch 452 loss_pde:0.17163393, loss_ic:0.00949686
# epoch 452: loss 0.266603
# epoch 453 loss_pde:0.17168137, loss_ic:0.00941638
# epoch 453: loss 0.265845
# epoch 454 loss_pde:0.17172195, loss_ic:0.00933721
# epoch 454: loss 0.265094
# epoch 455 loss_pde:0.17175581, loss_ic:0.00925932
# epoch 455: loss 0.264349
# epoch 456 loss_pde:0.17178208, loss_ic:0.00918278
# epoch 456: loss 0.263610
# epoch 457 loss_pde:0.17180173, loss_ic:0.00910749
# epoch 457: loss 0.262877
# epoch 458 loss_pde:0.17181695, loss_ic:0.00903323
# epoch 458: loss 0.262149
# epoch 459 loss_pde:0.17182714, loss_ic:0.00896003
# epoch 459: loss 0.261427
# epoch 460 loss_pde:0.17183354, loss_ic:0.00888777
# epoch 460: loss 0.260711
# epoch 461 loss_pde:0.17183821, loss_ic:0.00881624
# epoch 461: loss 0.260001
# epoch 462 loss_pde:0.17184120, loss_ic:0.00874542
# epoch 462: loss 0.259295
# epoch 463 loss_pde:0.17184263, loss_ic:0.00867528
# epoch 463: loss 0.258595
# epoch 464 loss_pde:0.17184503, loss_ic:0.00860557
# epoch 464: loss 0.257901
# epoch 465 loss_pde:0.17184781, loss_ic:0.00853633
# epoch 465: loss 0.257211
# epoch 466 loss_pde:0.17184991, loss_ic:0.00846767
# epoch 466: loss 0.256527
# epoch 467 loss_pde:0.17185247, loss_ic:0.00839945
# epoch 467: loss 0.255847
# epoch 468 loss_pde:0.17185485, loss_ic:0.00833175
# epoch 468: loss 0.255172
# epoch 469 loss_pde:0.17185645, loss_ic:0.00826461
# epoch 469: loss 0.254503
# epoch 470 loss_pde:0.17185792, loss_ic:0.00819796
# epoch 470: loss 0.253838
# epoch 471 loss_pde:0.17185910, loss_ic:0.00813181
# epoch 471: loss 0.253177
# epoch 472 loss_pde:0.17185906, loss_ic:0.00806624
# epoch 472: loss 0.252521
# epoch 473 loss_pde:0.17185819, loss_ic:0.00800122
# epoch 473: loss 0.251870
# epoch 474 loss_pde:0.17185842, loss_ic:0.00793653
# epoch 474: loss 0.251224
# epoch 475 loss_pde:0.17185672, loss_ic:0.00787247
# epoch 475: loss 0.250581
# epoch 476 loss_pde:0.17185134, loss_ic:0.00780922
# epoch 476: loss 0.249944
# epoch 477 loss_pde:0.17184341, loss_ic:0.00774665
# epoch 477: loss 0.249310
# epoch 478 loss_pde:0.17183444, loss_ic:0.00768460
# epoch 478: loss 0.248680
# epoch 479 loss_pde:0.17182463, loss_ic:0.00762304
# epoch 479: loss 0.248055
# epoch 480 loss_pde:0.17181279, loss_ic:0.00756209
# epoch 480: loss 0.247434
# epoch 481 loss_pde:0.17179722, loss_ic:0.00750191
# epoch 481: loss 0.246816
# epoch 482 loss_pde:0.17177553, loss_ic:0.00744273
# epoch 482: loss 0.246203
# epoch 483 loss_pde:0.17174907, loss_ic:0.00738441
# epoch 483: loss 0.245593
# epoch 484 loss_pde:0.17172158, loss_ic:0.00732657
# epoch 484: loss 0.244987
# epoch 485 loss_pde:0.17169341, loss_ic:0.00726917
# epoch 485: loss 0.244385
# epoch 486 loss_pde:0.17166498, loss_ic:0.00721217
# epoch 486: loss 0.243787
# epoch 487 loss_pde:0.17163533, loss_ic:0.00715566
# epoch 487: loss 0.243192
# epoch 488 loss_pde:0.17160268, loss_ic:0.00709979
# epoch 488: loss 0.242601
# epoch 489 loss_pde:0.17156728, loss_ic:0.00704457
# epoch 489: loss 0.242013
# epoch 490 loss_pde:0.17153136, loss_ic:0.00698974
# epoch 490: loss 0.241429
# epoch 491 loss_pde:0.17149590, loss_ic:0.00693522
# epoch 491: loss 0.240848
# epoch 492 loss_pde:0.17146054, loss_ic:0.00688103
# epoch 492: loss 0.240271
# epoch 493 loss_pde:0.17142540, loss_ic:0.00682715
# epoch 493: loss 0.239697
# epoch 494 loss_pde:0.17138813, loss_ic:0.00677384
# epoch 494: loss 0.239127
# epoch 495 loss_pde:0.17134883, loss_ic:0.00672107
# epoch 495: loss 0.238560
# epoch 496 loss_pde:0.17130937, loss_ic:0.00666866
# epoch 496: loss 0.237996
# epoch 497 loss_pde:0.17127043, loss_ic:0.00661654
# epoch 497: loss 0.237436
# epoch 498 loss_pde:0.17123185, loss_ic:0.00656473
# epoch 498: loss 0.236879
# epoch 499 loss_pde:0.17119397, loss_ic:0.00651320
# epoch 499: loss 0.236326
# epoch 500 loss_pde:0.17115518, loss_ic:0.00646210
# epoch 500: loss 0.235776
# epoch 501 loss_pde:0.17111501, loss_ic:0.00641149
# epoch 501: loss 0.235230
# epoch 502 loss_pde:0.17107508, loss_ic:0.00636121
# epoch 502: loss 0.234687
# epoch 503 loss_pde:0.17103592, loss_ic:0.00631121
# epoch 503: loss 0.234148
# epoch 504 loss_pde:0.17099680, loss_ic:0.00626155
# epoch 504: loss 0.233612
# epoch 505 loss_pde:0.17095847, loss_ic:0.00621218
# epoch 505: loss 0.233080
# epoch 506 loss_pde:0.17091933, loss_ic:0.00616325
# epoch 506: loss 0.232552
# epoch 507 loss_pde:0.17087761, loss_ic:0.00611494
# epoch 507: loss 0.232027
# epoch 508 loss_pde:0.17083371, loss_ic:0.00606723
# epoch 508: loss 0.231506
# epoch 509 loss_pde:0.17078894, loss_ic:0.00601997
# epoch 509: loss 0.230989
# epoch 510 loss_pde:0.17074457, loss_ic:0.00597307
# epoch 510: loss 0.230475
# epoch 511 loss_pde:0.17070189, loss_ic:0.00592638
# epoch 511: loss 0.229966
# epoch 512 loss_pde:0.17065971, loss_ic:0.00588003
# epoch 512: loss 0.229460
# epoch 513 loss_pde:0.17061596, loss_ic:0.00583424
# epoch 513: loss 0.228958
# epoch 514 loss_pde:0.17057286, loss_ic:0.00578877
# epoch 514: loss 0.228461
# epoch 515 loss_pde:0.17052814, loss_ic:0.00574388
# epoch 515: loss 0.227967
# epoch 516 loss_pde:0.17048182, loss_ic:0.00569955
# epoch 516: loss 0.227477
# epoch 517 loss_pde:0.17043483, loss_ic:0.00565571
# epoch 517: loss 0.226992
# epoch 518 loss_pde:0.17038819, loss_ic:0.00561225
# epoch 518: loss 0.226511
# epoch 519 loss_pde:0.17034252, loss_ic:0.00556911
# epoch 519: loss 0.226034
# epoch 520 loss_pde:0.17029735, loss_ic:0.00552634
# epoch 520: loss 0.225561
# epoch 521 loss_pde:0.17025371, loss_ic:0.00548385
# epoch 521: loss 0.225092
# epoch 522 loss_pde:0.17020661, loss_ic:0.00544212
# epoch 522: loss 0.224628
# epoch 523 loss_pde:0.17015995, loss_ic:0.00540079
# epoch 523: loss 0.224168
# epoch 524 loss_pde:0.17011513, loss_ic:0.00535971
# epoch 524: loss 0.223712
# epoch 525 loss_pde:0.17007017, loss_ic:0.00531909
# epoch 525: loss 0.223261
# epoch 526 loss_pde:0.17002666, loss_ic:0.00527876
# epoch 526: loss 0.222814
# epoch 527 loss_pde:0.16998257, loss_ic:0.00523893
# epoch 527: loss 0.222372
# epoch 528 loss_pde:0.16993631, loss_ic:0.00519975
# epoch 528: loss 0.221934
# epoch 529 loss_pde:0.16989055, loss_ic:0.00516098
# epoch 529: loss 0.221500
# epoch 530 loss_pde:0.16984619, loss_ic:0.00512250
# epoch 530: loss 0.221071
# epoch 531 loss_pde:0.16980314, loss_ic:0.00508435
# epoch 531: loss 0.220647
# epoch 532 loss_pde:0.16975839, loss_ic:0.00504679
# epoch 532: loss 0.220226
# epoch 533 loss_pde:0.16971062, loss_ic:0.00500999
# epoch 533: loss 0.219811
# epoch 534 loss_pde:0.16966176, loss_ic:0.00497373
# epoch 534: loss 0.219399
# epoch 535 loss_pde:0.16961253, loss_ic:0.00493796
# epoch 535: loss 0.218992
# epoch 536 loss_pde:0.16956486, loss_ic:0.00490247
# epoch 536: loss 0.218590
# epoch 537 loss_pde:0.16951834, loss_ic:0.00486730
# epoch 537: loss 0.218191
# epoch 538 loss_pde:0.16946813, loss_ic:0.00483294
# epoch 538: loss 0.217798
# epoch 539 loss_pde:0.16941549, loss_ic:0.00479925
# epoch 539: loss 0.217408
# epoch 540 loss_pde:0.16936445, loss_ic:0.00476584
# epoch 540: loss 0.217023
# epoch 541 loss_pde:0.16930975, loss_ic:0.00473323
# epoch 541: loss 0.216642
# epoch 542 loss_pde:0.16925366, loss_ic:0.00470118
# epoch 542: loss 0.216265
# epoch 543 loss_pde:0.16919635, loss_ic:0.00466968
# epoch 543: loss 0.215893
# epoch 544 loss_pde:0.16913401, loss_ic:0.00463910
# epoch 544: loss 0.215525
# epoch 545 loss_pde:0.16907381, loss_ic:0.00460873
# epoch 545: loss 0.215161
# epoch 546 loss_pde:0.16901428, loss_ic:0.00457870
# epoch 546: loss 0.214801
# epoch 547 loss_pde:0.16895206, loss_ic:0.00454936
# epoch 547: loss 0.214446
# epoch 548 loss_pde:0.16888766, loss_ic:0.00452064
# epoch 548: loss 0.214094
# epoch 549 loss_pde:0.16882192, loss_ic:0.00449246
# epoch 549: loss 0.213746
# epoch 550 loss_pde:0.16875300, loss_ic:0.00446500
# epoch 550: loss 0.213403
# epoch 551 loss_pde:0.16868620, loss_ic:0.00443773
# epoch 551: loss 0.213064
# epoch 552 loss_pde:0.16861965, loss_ic:0.00441083
# epoch 552: loss 0.212728
# epoch 553 loss_pde:0.16855049, loss_ic:0.00438459
# epoch 553: loss 0.212396
# epoch 554 loss_pde:0.16848233, loss_ic:0.00435864
# epoch 554: loss 0.212069
# epoch 555 loss_pde:0.16841345, loss_ic:0.00433314
# epoch 555: loss 0.211745
# epoch 556 loss_pde:0.16834229, loss_ic:0.00430825
# epoch 556: loss 0.211425
# epoch 557 loss_pde:0.16827121, loss_ic:0.00428373
# epoch 557: loss 0.211108
# epoch 558 loss_pde:0.16819558, loss_ic:0.00426003
# epoch 558: loss 0.210796
# epoch 559 loss_pde:0.16811870, loss_ic:0.00423682
# epoch 559: loss 0.210487
# epoch 560 loss_pde:0.16804254, loss_ic:0.00421390
# epoch 560: loss 0.210182
# epoch 561 loss_pde:0.16796513, loss_ic:0.00419147
# epoch 561: loss 0.209880
# epoch 562 loss_pde:0.16788691, loss_ic:0.00416948
# epoch 562: loss 0.209582
# epoch 563 loss_pde:0.16780636, loss_ic:0.00414807
# epoch 563: loss 0.209287
# epoch 564 loss_pde:0.16772331, loss_ic:0.00412725
# epoch 564: loss 0.208996
# epoch 565 loss_pde:0.16764010, loss_ic:0.00410679
# epoch 565: loss 0.208708
# epoch 566 loss_pde:0.16755712, loss_ic:0.00408663
# epoch 566: loss 0.208423
# epoch 567 loss_pde:0.16747203, loss_ic:0.00406701
# epoch 567: loss 0.208142
# epoch 568 loss_pde:0.16738731, loss_ic:0.00404768
# epoch 568: loss 0.207864
# epoch 569 loss_pde:0.16729924, loss_ic:0.00402900
# epoch 569: loss 0.207589
# epoch 570 loss_pde:0.16720983, loss_ic:0.00401077
# epoch 570: loss 0.207317
# epoch 571 loss_pde:0.16712084, loss_ic:0.00399279
# epoch 571: loss 0.207049
# epoch 572 loss_pde:0.16703098, loss_ic:0.00397520
# epoch 572: loss 0.206783
# epoch 573 loss_pde:0.16694224, loss_ic:0.00395779
# epoch 573: loss 0.206520
# epoch 574 loss_pde:0.16685526, loss_ic:0.00394048
# epoch 574: loss 0.206260
# epoch 575 loss_pde:0.16676714, loss_ic:0.00392357
# epoch 575: loss 0.206003
# epoch 576 loss_pde:0.16667885, loss_ic:0.00390695
# epoch 576: loss 0.205748
# epoch 577 loss_pde:0.16658886, loss_ic:0.00389077
# epoch 577: loss 0.205497
# epoch 578 loss_pde:0.16649757, loss_ic:0.00387497
# epoch 578: loss 0.205247
# epoch 579 loss_pde:0.16640434, loss_ic:0.00385962
# epoch 579: loss 0.205001
# epoch 580 loss_pde:0.16631109, loss_ic:0.00384453
# epoch 580: loss 0.204756
# epoch 581 loss_pde:0.16621843, loss_ic:0.00382962
# epoch 581: loss 0.204515
# epoch 582 loss_pde:0.16612589, loss_ic:0.00381494
# epoch 582: loss 0.204275
# epoch 583 loss_pde:0.16603199, loss_ic:0.00380063
# epoch 583: loss 0.204038
# epoch 584 loss_pde:0.16593674, loss_ic:0.00378667
# epoch 584: loss 0.203803
# epoch 585 loss_pde:0.16583997, loss_ic:0.00377309
# epoch 585: loss 0.203571
# epoch 586 loss_pde:0.16574429, loss_ic:0.00375961
# epoch 586: loss 0.203340
# epoch 587 loss_pde:0.16564903, loss_ic:0.00374629
# epoch 587: loss 0.203112
# epoch 588 loss_pde:0.16555455, loss_ic:0.00373309
# epoch 588: loss 0.202885
# epoch 589 loss_pde:0.16546161, loss_ic:0.00371993
# epoch 589: loss 0.202661
# epoch 590 loss_pde:0.16536738, loss_ic:0.00370709
# epoch 590: loss 0.202438
# epoch 591 loss_pde:0.16527103, loss_ic:0.00369464
# epoch 591: loss 0.202217
# epoch 592 loss_pde:0.16517624, loss_ic:0.00368223
# epoch 592: loss 0.201999
# epoch 593 loss_pde:0.16508067, loss_ic:0.00367006
# epoch 593: loss 0.201781
# epoch 594 loss_pde:0.16498688, loss_ic:0.00365788
# epoch 594: loss 0.201566
# epoch 595 loss_pde:0.16489242, loss_ic:0.00364594
# epoch 595: loss 0.201352
# epoch 596 loss_pde:0.16479526, loss_ic:0.00363443
# epoch 596: loss 0.201140
# epoch 597 loss_pde:0.16469824, loss_ic:0.00362305
# epoch 597: loss 0.200929
# epoch 598 loss_pde:0.16460276, loss_ic:0.00361167
# epoch 598: loss 0.200719
# epoch 599 loss_pde:0.16450891, loss_ic:0.00360027
# epoch 599: loss 0.200512
# epoch 600 loss_pde:0.16441254, loss_ic:0.00358926
# epoch 600: loss 0.200305
# epoch 601 loss_pde:0.16431598, loss_ic:0.00357840
# epoch 601: loss 0.200100
# epoch 602 loss_pde:0.16421700, loss_ic:0.00356792
# epoch 602: loss 0.199896
# epoch 603 loss_pde:0.16412254, loss_ic:0.00355711
# epoch 603: loss 0.199694
# epoch 604 loss_pde:0.16402608, loss_ic:0.00354663
# epoch 604: loss 0.199492
# epoch 605 loss_pde:0.16392690, loss_ic:0.00353655
# epoch 605: loss 0.199292
# epoch 606 loss_pde:0.16382803, loss_ic:0.00352655
# epoch 606: loss 0.199094
# epoch 607 loss_pde:0.16372739, loss_ic:0.00351685
# epoch 607: loss 0.198896
# epoch 608 loss_pde:0.16363002, loss_ic:0.00350692
# epoch 608: loss 0.198699
# epoch 609 loss_pde:0.16353203, loss_ic:0.00349717
# epoch 609: loss 0.198504
# epoch 610 loss_pde:0.16343231, loss_ic:0.00348769
# epoch 610: loss 0.198309
# epoch 611 loss_pde:0.16333094, loss_ic:0.00347848
# epoch 611: loss 0.198116
# epoch 612 loss_pde:0.16323237, loss_ic:0.00346908
# epoch 612: loss 0.197923
# epoch 613 loss_pde:0.16313459, loss_ic:0.00345971
# epoch 613: loss 0.197732
# epoch 614 loss_pde:0.16303745, loss_ic:0.00345037
# epoch 614: loss 0.197541
# epoch 615 loss_pde:0.16293634, loss_ic:0.00344151
# epoch 615: loss 0.197351
# epoch 616 loss_pde:0.16283156, loss_ic:0.00343311
# epoch 616: loss 0.197163
# epoch 617 loss_pde:0.16272943, loss_ic:0.00342454
# epoch 617: loss 0.196975
# epoch 618 loss_pde:0.16262932, loss_ic:0.00341584
# epoch 618: loss 0.196788
# epoch 619 loss_pde:0.16252886, loss_ic:0.00340726
# epoch 619: loss 0.196601
# epoch 620 loss_pde:0.16242763, loss_ic:0.00339882
# epoch 620: loss 0.196416
# epoch 621 loss_pde:0.16232422, loss_ic:0.00339069
# epoch 621: loss 0.196231
# epoch 622 loss_pde:0.16222280, loss_ic:0.00338242
# epoch 622: loss 0.196047
# epoch 623 loss_pde:0.16212368, loss_ic:0.00337400
# epoch 623: loss 0.195864
# epoch 624 loss_pde:0.16202033, loss_ic:0.00336607
# epoch 624: loss 0.195681
# epoch 625 loss_pde:0.16191953, loss_ic:0.00335795
# epoch 625: loss 0.195499
# epoch 626 loss_pde:0.16181862, loss_ic:0.00334991
# epoch 626: loss 0.195318
# epoch 627 loss_pde:0.16172034, loss_ic:0.00334167
# epoch 627: loss 0.195137
# epoch 628 loss_pde:0.16162187, loss_ic:0.00333351
# epoch 628: loss 0.194957
# epoch 629 loss_pde:0.16151841, loss_ic:0.00332592
# epoch 629: loss 0.194778
# epoch 630 loss_pde:0.16141567, loss_ic:0.00331831
# epoch 630: loss 0.194599
# epoch 631 loss_pde:0.16131285, loss_ic:0.00331077
# epoch 631: loss 0.194421
# epoch 632 loss_pde:0.16121128, loss_ic:0.00330316
# epoch 632: loss 0.194243
# epoch 633 loss_pde:0.16111051, loss_ic:0.00329554
# epoch 633: loss 0.194066
# epoch 634 loss_pde:0.16100603, loss_ic:0.00328833
# epoch 634: loss 0.193889
# epoch 635 loss_pde:0.16090186, loss_ic:0.00328115
# epoch 635: loss 0.193713
# epoch 636 loss_pde:0.16079815, loss_ic:0.00327397
# epoch 636: loss 0.193538
# epoch 637 loss_pde:0.16069385, loss_ic:0.00326690
# epoch 637: loss 0.193363
# epoch 638 loss_pde:0.16059156, loss_ic:0.00325968
# epoch 638: loss 0.193188
# epoch 639 loss_pde:0.16048265, loss_ic:0.00325316
# epoch 639: loss 0.193014
# epoch 640 loss_pde:0.16037968, loss_ic:0.00324609
# epoch 640: loss 0.192841
# epoch 641 loss_pde:0.16027726, loss_ic:0.00323901
# epoch 641: loss 0.192667
# epoch 642 loss_pde:0.16017929, loss_ic:0.00323152
# epoch 642: loss 0.192495
# epoch 643 loss_pde:0.16007915, loss_ic:0.00322430
# ...
# epoch 2424: loss 0.108443
# epoch 2425 loss_pde:0.10030913, loss_ic:0.00081343
# epoch 2425: loss 0.108443
# epoch 2426 loss_pde:0.10031953, loss_ic:0.00081308
# epoch 2426: loss 0.108450
# epoch 2427 loss_pde:0.10028642, loss_ic:0.00081579
# epoch 2427: loss 0.108444
# epoch 2428 loss_pde:0.10030081, loss_ic:0.00081191
# epoch 2428: loss 0.108420
# epoch 2429 loss_pde:0.10026996, loss_ic:0.00081184
# epoch 2429: loss 0.108388
# epoch 2430 loss_pde:0.10026538, loss_ic:0.00080990
# epoch 2430: loss 0.108364
# epoch 2431 loss_pde:0.10025480, loss_ic:0.00080992
# epoch 2431: loss 0.108354
# epoch 2432 loss_pde:0.10023077, loss_ic:0.00081204
# epoch 2432: loss 0.108351
# epoch 2433 loss_pde:0.10023765, loss_ic:0.00081072
# epoch 2433: loss 0.108345
# epoch 2434 loss_pde:0.10020822, loss_ic:0.00081211
# epoch 2434: loss 0.108329
# epoch 2435 loss_pde:0.10021159, loss_ic:0.00080956
# epoch 2435: loss 0.108307
# epoch 2436 loss_pde:0.10018869, loss_ic:0.00080972
# epoch 2436: loss 0.108286
# epoch 2437 loss_pde:0.10017657, loss_ic:0.00080943
# epoch 2437: loss 0.108271
# epoch 2438 loss_pde:0.10017366, loss_ic:0.00080879
# epoch 2438: loss 0.108262
# epoch 2439 loss_pde:0.10015426, loss_ic:0.00080990
# epoch 2439: loss 0.108253
# epoch 2440 loss_pde:0.10015472, loss_ic:0.00080865
# epoch 2440: loss 0.108241
# epoch 2441 loss_pde:0.10012802, loss_ic:0.00080967
# epoch 2441: loss 0.108225
# epoch 2442 loss_pde:0.10013091, loss_ic:0.00080757
# epoch 2442: loss 0.108207
# epoch 2443 loss_pde:0.10011604, loss_ic:0.00080742
# epoch 2443: loss 0.108190
# epoch 2444 loss_pde:0.10010341, loss_ic:0.00080739
# epoch 2444: loss 0.108177
# epoch 2445 loss_pde:0.10010082, loss_ic:0.00080655
# epoch 2445: loss 0.108166
# epoch 2446 loss_pde:0.10008174, loss_ic:0.00080731
# epoch 2446: loss 0.108155
# epoch 2447 loss_pde:0.10007741, loss_ic:0.00080639
# epoch 2447: loss 0.108141
# epoch 2448 loss_pde:0.10005543, loss_ic:0.00080704
# epoch 2448: loss 0.108126
# epoch 2449 loss_pde:0.10005138, loss_ic:0.00080587
# epoch 2449: loss 0.108110
# epoch 2450 loss_pde:0.10003517, loss_ic:0.00080603
# epoch 2450: loss 0.108096
# epoch 2451 loss_pde:0.10001872, loss_ic:0.00080638
# epoch 2451: loss 0.108082
# epoch 2452 loss_pde:0.10001169, loss_ic:0.00080585
# epoch 2452: loss 0.108070
# epoch 2453 loss_pde:0.09999367, loss_ic:0.00080638
# epoch 2453: loss 0.108057
# epoch 2454 loss_pde:0.09998823, loss_ic:0.00080555
# epoch 2454: loss 0.108044
# epoch 2455 loss_pde:0.09997127, loss_ic:0.00080578
# epoch 2455: loss 0.108029
# epoch 2456 loss_pde:0.09996685, loss_ic:0.00080476
# epoch 2456: loss 0.108014
# epoch 2457 loss_pde:0.09995387, loss_ic:0.00080465
# epoch 2457: loss 0.108000
# epoch 2458 loss_pde:0.09994094, loss_ic:0.00080460
# epoch 2458: loss 0.107987
# epoch 2459 loss_pde:0.09993456, loss_ic:0.00080394
# epoch 2459: loss 0.107974
# epoch 2460 loss_pde:0.09991933, loss_ic:0.00080414
# epoch 2460: loss 0.107961
# epoch 2461 loss_pde:0.09991196, loss_ic:0.00080350
# epoch 2461: loss 0.107947
# epoch 2462 loss_pde:0.09989507, loss_ic:0.00080378
# epoch 2462: loss 0.107933
# epoch 2463 loss_pde:0.09988674, loss_ic:0.00080319
# epoch 2463: loss 0.107919
# epoch 2464 loss_pde:0.09987184, loss_ic:0.00080328
# epoch 2464: loss 0.107905
# epoch 2465 loss_pde:0.09985846, loss_ic:0.00080325
# epoch 2465: loss 0.107891
# epoch 2466 loss_pde:0.09984932, loss_ic:0.00080281
# epoch 2466: loss 0.107877
# epoch 2467 loss_pde:0.09983465, loss_ic:0.00080293
# epoch 2467: loss 0.107864
# epoch 2468 loss_pde:0.09982580, loss_ic:0.00080244
# epoch 2468: loss 0.107850
# epoch 2469 loss_pde:0.09981071, loss_ic:0.00080256
# epoch 2469: loss 0.107836
# epoch 2470 loss_pde:0.09980277, loss_ic:0.00080195
# epoch 2470: loss 0.107822
# epoch 2471 loss_pde:0.09978934, loss_ic:0.00080189
# epoch 2471: loss 0.107808
# epoch 2472 loss_pde:0.09977803, loss_ic:0.00080163
# epoch 2472: loss 0.107794
# epoch 2473 loss_pde:0.09976790, loss_ic:0.00080127
# epoch 2473: loss 0.107781
# epoch 2474 loss_pde:0.09975410, loss_ic:0.00080128
# epoch 2474: loss 0.107767
# epoch 2475 loss_pde:0.09974360, loss_ic:0.00080095
# epoch 2475: loss 0.107753
# epoch 2476 loss_pde:0.09972779, loss_ic:0.00080114
# epoch 2476: loss 0.107739
# epoch 2477 loss_pde:0.09971847, loss_ic:0.00080067
# epoch 2477: loss 0.107725
# epoch 2478 loss_pde:0.09970504, loss_ic:0.00080061
# epoch 2478: loss 0.107711
# epoch 2479 loss_pde:0.09969422, loss_ic:0.00080029
# epoch 2479: loss 0.107697
# epoch 2480 loss_pde:0.09968306, loss_ic:0.00080001
# epoch 2480: loss 0.107683
# epoch 2481 loss_pde:0.09967060, loss_ic:0.00079987
# epoch 2481: loss 0.107669
# epoch 2482 loss_pde:0.09965909, loss_ic:0.00079963
# epoch 2482: loss 0.107655
# epoch 2483 loss_pde:0.09964503, loss_ic:0.00079964
# epoch 2483: loss 0.107641
# epoch 2484 loss_pde:0.09963554, loss_ic:0.00079919
# epoch 2484: loss 0.107627
# epoch 2485 loss_pde:0.09962232, loss_ic:0.00079910
# epoch 2485: loss 0.107613
# epoch 2486 loss_pde:0.09961127, loss_ic:0.00079880
# epoch 2486: loss 0.107599
# epoch 2487 loss_pde:0.09959847, loss_ic:0.00079867
# epoch 2487: loss 0.107585
# epoch 2488 loss_pde:0.09958633, loss_ic:0.00079847
# epoch 2488: loss 0.107571
# epoch 2489 loss_pde:0.09957457, loss_ic:0.00079824
# epoch 2489: loss 0.107557
# epoch 2490 loss_pde:0.09956222, loss_ic:0.00079807
# epoch 2490: loss 0.107543
# epoch 2491 loss_pde:0.09955168, loss_ic:0.00079772
# epoch 2491: loss 0.107529
# epoch 2492 loss_pde:0.09953802, loss_ic:0.00079767
# epoch 2492: loss 0.107515
# epoch 2493 loss_pde:0.09952656, loss_ic:0.00079740
# epoch 2493: loss 0.107501
# epoch 2494 loss_pde:0.09951323, loss_ic:0.00079731
# epoch 2494: loss 0.107486
# epoch 2495 loss_pde:0.09950165, loss_ic:0.00079705
# epoch 2495: loss 0.107472
# epoch 2496 loss_pde:0.09948914, loss_ic:0.00079688
# epoch 2496: loss 0.107458
# epoch 2497 loss_pde:0.09947655, loss_ic:0.00079672
# epoch 2497: loss 0.107444
# epoch 2498 loss_pde:0.09946452, loss_ic:0.00079650
# epoch 2498: loss 0.107429
# epoch 2499 loss_pde:0.09945198, loss_ic:0.00079633
# epoch 2499: loss 0.107415
# epoch 2500 loss_pde:0.09944077, loss_ic:0.00079602
# epoch 2500: loss 0.107401
# epoch 2501 loss_pde:0.09942830, loss_ic:0.00079584
# epoch 2501: loss 0.107387
# epoch 2502 loss_pde:0.09941700, loss_ic:0.00079554
# epoch 2502: loss 0.107372
# epoch 2503 loss_pde:0.09940364, loss_ic:0.00079544
# epoch 2503: loss 0.107358
# epoch 2504 loss_pde:0.09939121, loss_ic:0.00079525
# epoch 2504: loss 0.107344
# epoch 2505 loss_pde:0.09937861, loss_ic:0.00079507
# epoch 2505: loss 0.107329
# epoch 2506 loss_pde:0.09936637, loss_ic:0.00079486
# epoch 2506: loss 0.107315
# epoch 2507 loss_pde:0.09935410, loss_ic:0.00079465
# epoch 2507: loss 0.107301
# epoch 2508 loss_pde:0.09934117, loss_ic:0.00079450
# epoch 2508: loss 0.107286
# epoch 2509 loss_pde:0.09932895, loss_ic:0.00079428
# epoch 2509: loss 0.107272
# epoch 2510 loss_pde:0.09931595, loss_ic:0.00079413
# epoch 2510: loss 0.107257
# epoch 2511 loss_pde:0.09930424, loss_ic:0.00079386
# epoch 2511: loss 0.107243
# epoch 2512 loss_pde:0.09929173, loss_ic:0.00079366
# epoch 2512: loss 0.107228
# epoch 2513 loss_pde:0.09927969, loss_ic:0.00079341
# epoch 2513: loss 0.107214
# epoch 2514 loss_pde:0.09926680, loss_ic:0.00079325
# epoch 2514: loss 0.107199
# epoch 2515 loss_pde:0.09925414, loss_ic:0.00079307
# epoch 2515: loss 0.107185
# epoch 2516 loss_pde:0.09924146, loss_ic:0.00079288
# epoch 2516: loss 0.107170
# epoch 2517 loss_pde:0.09922884, loss_ic:0.00079268
# epoch 2517: loss 0.107156
# epoch 2518 loss_pde:0.09921639, loss_ic:0.00079247
# epoch 2518: loss 0.107141
# epoch 2519 loss_pde:0.09920168, loss_ic:0.00079248
# epoch 2519: loss 0.107126
# epoch 2520 loss_pde:0.09919141, loss_ic:0.00079204
# epoch 2520: loss 0.107112
# epoch 2521 loss_pde:0.09918003, loss_ic:0.00079171
# epoch 2521: loss 0.107097
# epoch 2522 loss_pde:0.09916519, loss_ic:0.00079172
# epoch 2522: loss 0.107082
# epoch 2523 loss_pde:0.09915231, loss_ic:0.00079154
# epoch 2523: loss 0.107068
# epoch 2524 loss_pde:0.09914340, loss_ic:0.00079096
# epoch 2524: loss 0.107053
# epoch 2525 loss_pde:0.09913158, loss_ic:0.00079066
# epoch 2525: loss 0.107038
# epoch 2526 loss_pde:0.09911843, loss_ic:0.00079050
# epoch 2526: loss 0.107023
# epoch 2527 loss_pde:0.09910714, loss_ic:0.00079015
# epoch 2527: loss 0.107009
# epoch 2528 loss_pde:0.09909412, loss_ic:0.00078997
# epoch 2528: loss 0.106994
# epoch 2529 loss_pde:0.09907901, loss_ic:0.00078999
# epoch 2529: loss 0.106979
# epoch 2530 loss_pde:0.09906570, loss_ic:0.00078984
# epoch 2530: loss 0.106964
# epoch 2531 loss_pde:0.09905341, loss_ic:0.00078958
# epoch 2531: loss 0.106949
# epoch 2532 loss_pde:0.09903809, loss_ic:0.00078962
# epoch 2532: loss 0.106934
# epoch 2533 loss_pde:0.09902358, loss_ic:0.00078958
# epoch 2533: loss 0.106919
# epoch 2534 loss_pde:0.09901138, loss_ic:0.00078930
# epoch 2534: loss 0.106904
# epoch 2535 loss_pde:0.09899909, loss_ic:0.00078904
# epoch 2535: loss 0.106889
# epoch 2536 loss_pde:0.09898604, loss_ic:0.00078884
# epoch 2536: loss 0.106874
# epoch 2537 loss_pde:0.09897379, loss_ic:0.00078857
# epoch 2537: loss 0.106859
# epoch 2538 loss_pde:0.09896199, loss_ic:0.00078824
# epoch 2538: loss 0.106844
# epoch 2539 loss_pde:0.09894925, loss_ic:0.00078801
# epoch 2539: loss 0.106829
# epoch 2540 loss_pde:0.09893689, loss_ic:0.00078774
# epoch 2540: loss 0.106814
# epoch 2541 loss_pde:0.09892528, loss_ic:0.00078739
# epoch 2541: loss 0.106799
# epoch 2542 loss_pde:0.09891161, loss_ic:0.00078724
# epoch 2542: loss 0.106784
# epoch 2543 loss_pde:0.09889643, loss_ic:0.00078725
# epoch 2543: loss 0.106769
# epoch 2544 loss_pde:0.09888268, loss_ic:0.00078711
# epoch 2544: loss 0.106754
# epoch 2545 loss_pde:0.09886973, loss_ic:0.00078688
# epoch 2545: loss 0.106739
# epoch 2546 loss_pde:0.09885642, loss_ic:0.00078669
# epoch 2546: loss 0.106723
# epoch 2547 loss_pde:0.09884346, loss_ic:0.00078647
# epoch 2547: loss 0.106708
# epoch 2548 loss_pde:0.09883116, loss_ic:0.00078617
# epoch 2548: loss 0.106693
# epoch 2549 loss_pde:0.09881764, loss_ic:0.00078599
# epoch 2549: loss 0.106678
# epoch 2550 loss_pde:0.09880455, loss_ic:0.00078577
# epoch 2550: loss 0.106662
# epoch 2551 loss_pde:0.09879260, loss_ic:0.00078543
# epoch 2551: loss 0.106647
# epoch 2552 loss_pde:0.09877989, loss_ic:0.00078517
# epoch 2552: loss 0.106632
# epoch 2553 loss_pde:0.09876561, loss_ic:0.00078506
# epoch 2553: loss 0.106616
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb Cell 5 in <module>
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> tic = time.time()
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> for epoch in range(1, epochs+1):
# ---> <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a>     train(epoch)
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> toc = time.time()
#
# /home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb Cell 5 in train(epoch)
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a>     loss.backward()
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a>     return loss
# ---> <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a> loss = optimizer.step(closure)
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=18'>19</a> loss_value = loss.item() if not isinstance(loss, float) else loss
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=19'>20</a> print(f'epoch {epoch}: loss {loss_value:.6f}')
#
# File ~/.local/lib/python3.8/site-packages/torch/optim/optimizer.py:88, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#      86 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87 with torch.autograd.profiler.record_function(profile_name):
# ---> 88     return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/grad_mode.py:28, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      25 @functools.wraps(func)
#      26 def decorate_context(*args, **kwargs):
#      27     with self.__class__():
# ---> 28         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/optim/adam.py:92, in Adam.step(self, closure)
#      90 if closure is not None:
#      91     with torch.enable_grad():
# ---> 92         loss = closure()
#      94 for group in self.param_groups:
#      95     params_with_grad = []
#
# /home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb Cell 5 in train.<locals>.closure()
#       <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> def closure():
#       <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     optimizer.zero_grad()
# ----> <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>     loss_pde = model.loss_pde(x_int)
#       <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     loss_ic = model.loss_ic(x_ic, u_ic)
#       <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a>     loss = loss_pde + 10*loss_ic
#
# /home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb Cell 5 in DNN.loss_pde(self, x)
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=61'>62</a> dU_g = gradients(U, x)[0]
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=62'>63</a> U_x = dU_g[:, 1:]
# ---> <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=63'>64</a> du_g = gradients(u, x)[0]
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=64'>65</a> u_t,u_x = du_g[:, :1],du_g[:,1:]
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=65'>66</a> d = 0.1*(abs(u_x)-u_x) + 1
#
# /home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb Cell 5 in gradients(outputs, inputs)
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=21'>22</a> def gradients(outputs, inputs):
# ---> <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W4sZmlsZQ%3D%3D?line=22'>23</a>     return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py:234, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     231 if retain_graph is None:
#     232     retain_graph = create_graph
# --> 234 return Variable._execution_engine.run_backward(
#     235     outputs, grad_outputs_, retain_graph, create_graph,
#     236     inputs, allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:

# %%
x = np.linspace(0.0, 2.0, 50)                                  
t = np.linspace(1.0, 1.0, 50)                                        
t_grid, x_grid = np.meshgrid(t, x)                              
T = t_grid.flatten()[:, None]                                   
X = x_grid.flatten()[:, None]                                   
x_test = np.hstack((T, X))                                      
x_test = torch.tensor(x_test, requires_grad=True, dtype=torch.float32).to(device)
u_pred = to_numpy(model(x_test))
res = to_numpy(model.res_pde(x_test))
d   = to_numpy(model.lambda_pde(x_test))

#loss = model.loss_pde(x_test)                                 

import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x,u_pred[:,0])
#plt.plot(x,ur)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb Cell 6 in <module>
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> d   = to_numpy(model.lambda_pde(x_test))
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> #loss = model.loss_pde(x_test)
# ---> <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a> import matplotlib.pyplot as plt
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a> plt.figure()
#      <a href='vscode-notebook-cell:/home/bfly/workspace/computeforcfd/PINN/1D/Burgers/Burgers_PINN-WE-share.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a> plt.scatter(x,u_pred[:,0])
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py:113, in <module>
#     109 from packaging.version import parse as parse_version
#     111 # cbook must import matplotlib only within function
#     112 # definitions, so it is safe to import from it here.
# --> 113 from . import _api, _version, cbook, _docstring, rcsetup
#     114 from matplotlib.cbook import sanitize_sequence
#     115 from matplotlib._api import MatplotlibDeprecationWarning
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/rcsetup.py:27, in <module>
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/colors.py:51, in <module>
#      49 from numbers import Number
#      50 import re
# ---> 51 from PIL import Image
#      52 from PIL.PngImagePlugin import PngInfo
#      54 import matplotlib as mpl
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:89, in <module>
#      80 MAX_IMAGE_PIXELS = int(1024 * 1024 * 1024 // 4 // 3)
#      83 try:
#      84     # If the _imaging C module is not present, Pillow will not load.
#      85     # Note that other modules should not refer to _imaging directly;
#      86     # import Image and use the Image.core variable instead.
#      87     # Also note that Image.core is not a publicly documented interface,
#      88     # and should be considered private and subject to change.
# ---> 89     from . import _imaging as core
#      91     if __version__ != getattr(core, "PILLOW_VERSION", None):
#      92         raise ImportError(
#      93             "The _imaging extension was built for another version of Pillow or PIL:\n"
#      94             f"Core version: {getattr(core, 'PILLOW_VERSION', None)}\n"
#      95             f"Pillow version: {__version__}"
#      96         )
#
# ImportError: cannot import name '_imaging' from 'PIL' (/usr/lib/python3/dist-packages/PIL/__init__.py)
