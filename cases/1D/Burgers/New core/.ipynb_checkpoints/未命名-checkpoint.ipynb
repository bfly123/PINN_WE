# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
import math
import Exact_burgers
import matplotlib.pyplot as plt
from matplotlib.ticker import FixedLocator, FixedFormatter

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
  #  random.seed(seed)
    torch.backends.cudnn.deterministic = True
#WENO = np.loadtxt('1D/Burgers/result50WENO.dat')

num_seed = 20
lr = 1 
epochN = 1500
Mesh =  [11,21,41,81,161,321]
Mesh_num= len(Mesh)


#*** PINNs-WE****#

L2_var = np.zeros((Mesh_num,3))
Linf_var = np.zeros((Mesh_num ,3))
L2_shock_var = np.zeros((Mesh_num,3))
L2_smooth_var = np.zeros((Mesh_num,3))
Loss_var = np.zeros((Mesh_num,3))
Mesh_i = 0
f= open("result.dat", "w+") 
for nnode in Mesh:
#for nnode in [25,51]:
    f.write('###########nnode: %d ########### \n' % nnode)
#nnode = 25 
    L2_smooth_ave = [] 
    L2_shock_ave = [] 
    L2_ave = []
    L2_max_ave = []
    loss_ave = []
    starttime = time.time()
    for i in range(num_seed):  
        seed = i 
        setup_seed(seed)
 #   f.write('****seed: %d ***** \n' % seed)
    #How to count the computing time


        def train(epoch):
            model.it = epoch
            def closure():
                optimizer.zero_grad()                                              
                loss_pde = model.loss_pde(x_int)                                   
                loss_ic = model.loss_ic(x_ic, u_ic)  
                loss_symetry = model.loss_symetry(x_int,x_int_mirror)  
                loss_zero = model.loss_zero(x_zero)
                loss = loss_pde + 10*loss_ic + loss_zero                                      
    
                print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f},loss_symetry:{loss_symetry:.8f},loss:{loss:.8f},loss_zero:{loss_zero:.8f}')
                #model.it = model.it + 1
                #outputfile = open('loss_history_burgers.dat','a+')
                #print(f'{model.it}  {loss_pde:.6f}  {loss_ic:.6f}  {loss:.6f}',file=outputfile)
                #outputfile.close() 
                loss.backward()
                return loss
    
            loss = optimizer.step(closure)
            loss_value = loss.item()
            print(f'epoch {epoch}: loss {loss_value:.6f}')
            return loss
    
        def gradients(outputs, inputs):
            return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)
    
        def to_numpy(input):
            if isinstance(input, torch.Tensor):
                return input.detach().cpu().numpy()
            elif isinstance(input, np.ndarray):
                return input
            else:
                raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                                'np.ndarray, but got {}'.format(type(input)))
    
        def IC(x):
            N = len(x)
            u_init = np.zeros((x.shape[0]))                                                
            for i in range(N):
                u_init[i] = -np.sin(np.pi*(x[i,1]-1))
            return u_init
    
        class DNN(nn.Module):
            def __init__(self):
                super(DNN, self).__init__()
                self.net = nn.Sequential()                                                  
                self.net.add_module('Linear_layer_1', nn.Linear(2, 30))                     
                self.net.add_module('Tanh_layer_1', nn.Tanh())                              
    
                for num in range(2, 4):                                                     
                    self.net.add_module('Linear_layer_%d' % (num), nn.Linear(30, 30))       
                    self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 
                self.net.add_module('Linear_layer_final', nn.Linear(30, 1))                 
    
            def forward(self, x):
                return self.net(x)
            def loss_symetry(self, x,x_mirror):
                y = self.net(x)                                                
                y_mirror = self.net(x_mirror)                                                
                f = (((y + y_mirror))**2).mean() 
                return f
    
            def loss_zero(self, x_zero):
                y = self.net(x_zero)                                                
                f = ((y)**2).mean() 
                return f
            def loss_pde(self, x):
                y = self.net(x)                                                
                u = y[:, 0:1]
    
                U = u**2/2
    
                dU_g = gradients(U, x)[0]                                  
                U_x = dU_g[:, 1:]
                du_g = gradients(u, x)[0]                                 
                u_t,u_x = du_g[:, :1],du_g[:,1:]
                d = 0.1*(abs(u_x)-u_x) + 1
                #d = 1
    
                f = (((u_t + U_x)/d)**2).mean() 
    
                return f
            def res_pde(self,x):
                y = self.net(x)
                Res = np.zeros((x.shape[0]))                                  
    
                u = y[:, 0:1]
                U = u**2/2
                dU_g = gradients(U, x)[0]                                 
                U_x = dU_g[:, 1:]
                du_g = gradients(u, x)[0]                                  
                u_t,u_x = du_g[:, :1],du_g[:,1:]
                Res = (u_t + U_x)**2 
                return Res 
    
            def lambda_pde(self,x):
                y = self.net(x)
                Res = np.zeros((x.shape[0]))                                  
    
                u = y[:, 0:1]
                du_g = gradients(u, x)[0]                                  
                u_t,u_x = du_g[:, :1],du_g[:,1:]
                d = 0.1*(abs(u_x)-u_x) + 1
                return  d
    
    
            def loss_ic(self, x_ic, u_ic):
                y_ic = self.net(x_ic)                                                      
                u_ic_nn = y_ic[:, 0]
                loss_ics = ((u_ic_nn - u_ic) ** 2).mean()
                return loss_ics
    
        device = torch.device('cuda')                                      
        #device = torch.device('cpu')                                      
        num_x = nnode                                                        
        num_t =  nnode                                                       
        num_i_train = nnode                                          
        num_f_train =  nnode*nnode                                         
        x = np.linspace(0, 2, num_x)                                   
        t = np.linspace(0, 1, num_t)                                   
        t_grid, x_grid = np.meshgrid(t, x)                             
        T = t_grid.flatten()[:, None]                                  
        X = x_grid.flatten()[:, None]                                  
    
        x_zero = np.zeros((num_t, 2))
        x_zero[:,0] = t
        x_zero[:,1] = 1
    
        id_ic = np.random.choice(num_x, num_i_train, replace=False)    
        id_f = np.random.choice(num_x*num_t, num_f_train, replace=False)
    
        x_ic = x_grid[id_ic, 0][:, None]                               
        t_ic = t_grid[id_ic, 0][:, None]                               
        x_ic_train = np.hstack((t_ic, x_ic))                               
        u_ic_train = IC(x_ic_train)                 
    
        x_int = X[:, 0][id_f, None]                                        
        t_int = T[:, 0][id_f, None]                                        
        x_int_train = np.hstack((t_int, x_int))                            
        x_int_mirror = np.hstack((t_int, 2-x_int))                            
    
        u_ic_train = IC(x_ic_train)                 
    
        x_ic = torch.tensor(x_ic_train, dtype=torch.float32).to(device)
        x_int = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)
        x_int_mirror = torch.tensor(x_int_mirror, requires_grad=True, dtype=torch.float32).to(device)
        x_zero = torch.tensor(x_zero, requires_grad=True, dtype=torch.float32).to(device)
        u_ic = torch.tensor(u_ic_train, dtype=torch.float32).to(device)
    
        model = DNN().to(device)
    
        #lr = 0.001
    
        optimizer = torch.optim.LBFGS(model.parameters(), lr=lr, 
                                      max_iter = 30, 
                                      max_eval = None, 
                                      tolerance_grad = 1e-06, 
                                      tolerance_change = 1e-09, 
                                      history_size = 100, 
                                      line_search_fn = 'strong_wolfe')
        epochs = epochN
        tic = time.time()
        
        loss_test = 100.0
        num_epoch = 0
        for epoch in range(1, epochs+1):
          #if int(epoch/10) > num_epoch:
          #  loss_test = loss
          #  abs(loss - loss_test)
          loss=train(epoch)
    
    
        x = np.linspace(0.0, 2.0, nnode)                                  
        t = np.linspace(1.0, 1.0, 1)                                        
        t_grid, x_grid = np.meshgrid(t, x)                              
        T = t_grid.flatten()[:, None]                                   
        X = x_grid.flatten()[:, None]                                   
        x_test = np.hstack((T, X))                                      
        x_test = torch.tensor(x_test, requires_grad=True, dtype=torch.float32).to(device)
        u_pred = to_numpy(model(x_test))
        res = to_numpy(model.res_pde(x_test))
        d   = to_numpy(model.lambda_pde(x_test))
    
    
        y_e = Exact_burgers.Exact_Burgers(x)
        L2_error = np.sqrt(np.sum((u_pred[:,0]-y_e)**2)/nnode)
        #f.write('L2 error: %e\n' % L2_error)
        num = 0
        num_shock = 0
        sum = 0.0
        sum_shock = 0
        for i in range(nnode):
            if abs(x[i]-1)> 0.05:
                sum = sum +  np.sum((u_pred[i,0]-y_e[i])**2)
                num = num + 1
            #np.sqrt(np.sum((u_pred[:,0]-y_e)**2)/100)
            else:
                sum_shock = sum_shock +  np.sum((u_pred[i,0]-y_e[i])**2)
                num_shock = num_shock + 1
        sum = sum/num
        sum_shock = sum_shock/num_shock
        L2_error_smooth = np.sqrt(sum)
        L2_error_shock = np.sqrt(sum_shock)
        #f.write('L2_smooth error: %e\n' % L2_error_smooth)
        #f.write('L2_shock  error: %e\n' % L2_error_shock)
        L2_Max =  (np.max(np.abs(u_pred[:,0]-y_e)))
        #f.write('Max error: %e\n' % L2_Max )
        #f.write('Loss: %e\n' % loss)
        L2_max_ave.append(L2_Max)
        L2_ave.append(L2_error)
        L2_smooth_ave.append(L2_error_smooth)
        L2_shock_ave.append(L2_error_shock)
        loss_ave.append(to_numpy(loss))
        #loss_ave = loss_ave + loss
    
    #  f.write('Linf ave, top, bottom %e %e %e\n' %(np.mean(L2_max_ave),np.max(L2_max_ave),np.min(L2_max_ave)))
    #  f.write('L2 ave, top, bottom: %e %e %e \n' %(np.mean(L2_ave), np.max(L2_ave), np.min(L2_ave)))
    #  f.write('L2_smooth ave, top, bottom: %e %e %e \n' % (np.mean(L2_smooth_ave), np.max(L2_smooth_ave), np.min(L2_smooth_ave)))
    #  f.write('L2_shoc _ave, top, bottom: %e %e %e \n' % (np.mean(L2_shock_ave),np.max(L2_shock_ave),np.min(L2_shock_ave)))
    #  f.write('loss ave, top, bottom: %e %e %e \n' % (np.mean(loss_ave),np.max(loss_ave),np.min(loss_ave)))
    
        Linf_var[Mesh_i,0] = np.mean(L2_max_ave)
        Linf_var[Mesh_i,1] = np.max(L2_max_ave)
        Linf_var[Mesh_i,2] = np.min(L2_max_ave)
    
        L2_var[Mesh_i,0] = np.mean(L2_ave)
        L2_var[Mesh_i,1] = np.max(L2_ave)
        L2_var[Mesh_i,2] = np.min(L2_ave)
    
        L2_smooth_var[Mesh_i,0] = np.mean(L2_smooth_ave)
        L2_smooth_var[Mesh_i,1] = np.max(L2_smooth_ave)
        L2_smooth_var[Mesh_i,2] = np.min(L2_smooth_ave)
    
        L2_shock_var[Mesh_i,0] = np.mean(L2_shock_ave)
        L2_shock_var[Mesh_i,1] = np.max(L2_shock_ave)
        L2_shock_var[Mesh_i,2] = np.min(L2_shock_ave)
    
        Loss_var[Mesh_i,0] = np.mean(loss_ave) 
        Loss_var[Mesh_i,1] = np.max(loss_ave)
        Loss_var[Mesh_i,2] = np.min(loss_ave)
    
      #f.write('L2_max_ave_array: \n')
      #f.write(str(L2_max_ave))
      #f.write('\n L2_ave_array: \n')
      #f.write(str(L2_ave))
      #f.write('\n loss_ave_array: \n')
      #f.write(str(loss_ave))
      #L2_ave = L2_ave.mean()
      #L2_max_ave = L2_max_ave/num_seed  
      #loss_ave = loss_ave/num_seed
        endtime = time.time()
        train_time = (endtime - starttime)/num_seed
        f.write('\n train_time: %e\n' % (train_time/num_seed))
        Mesh_i = Mesh_i + 1
      #y_e_WENO = Exact_burgers.Exact_Burgers(WENO[:,0])
      #f.write('L2 error WENO: %e\n' % (np.sqrt(np.sum((WENO[:,1]-y_e_WENO)**2)/nnode)))
      #num = 0
      #sum = 0.0
      #for i in range(nnode):
      #  if abs(WENO[i,0]-1)> 0.05:
      #    sum = sum +  np.sum((WENO[i,1]-y_e_WENO)**2)
      #    num = num + 1
          #np.sqrt(np.sum((u_pred[:,0]-y_e)**2)/100)
      #sum = sum/num
      #L2_error_smooth = np.sqrt(sum)
      #f.write('L2 error smmoth WENO: %e\n' % L2_error_smooth)
    #for i in range(nnode):
    #  if abs(x[i]-1)> 0.01:
    #    sum = sum +  np.sum((red[i,0]-y_e_WENO)**2)
    #    num = num + 1
    #    #np.sqrt(np.sum((u_pred[:,0]-y_e)**2)/100)
    #sum = sum/num
    #f.write('L2_smooth error: %e\n' % np.sqrt(sum))
    #f.write('Max error: %e\n' % (np.max(np.abs(u_pred[:,0]-y_e))))
    #f.write('Loss: %e\n' % loss)
    #f.close()
# Out:
# epoch 1 loss_pde:0.00058022, loss_ic:0.44383425,loss_symetry:0.13298672,loss:4.47540045,loss_zero:0.03647752
# epoch 1 loss_pde:0.00116879, loss_ic:0.41778630,loss_symetry:0.05519731,loss:4.19477749,loss_zero:0.01574573
# epoch 1 loss_pde:0.00882843, loss_ic:0.35870910,loss_symetry:0.00492097,loss:3.59662366,loss_zero:0.00070438
# epoch 1 loss_pde:0.03918969, loss_ic:0.30287752,loss_symetry:0.02094685,loss:3.07078719,loss_zero:0.00282231
# epoch 1 loss_pde:0.41922474, loss_ic:0.34044853,loss_symetry:0.32629722,loss:3.96167731,loss_zero:0.13796733
# epoch 1 loss_pde:0.12208609, loss_ic:0.24996327,loss_symetry:0.02758753,loss:2.63284278,loss_zero:0.01112409
# epoch 1 loss_pde:0.09180350, loss_ic:0.24777782,loss_symetry:0.04355388,loss:2.58829808,loss_zero:0.01871626
# epoch 1 loss_pde:0.08586258, loss_ic:0.24801601,loss_symetry:0.03941353,loss:2.58305860,loss_zero:0.01703579
# epoch 1 loss_pde:0.06250913, loss_ic:0.24651526,loss_symetry:0.01738244,loss:2.53599596,loss_zero:0.00833448
# epoch 1 loss_pde:0.05385166, loss_ic:0.24022202,loss_symetry:0.00415991,loss:2.45738006,loss_zero:0.00130815
# epoch 1 loss_pde:0.07118580, loss_ic:0.22827777,loss_symetry:0.05677693,loss:2.37202096,loss_zero:0.01805729
# epoch 1 loss_pde:0.12793700, loss_ic:0.20307989,loss_symetry:0.21860705,loss:2.24589515,loss_zero:0.08715912
# epoch 1 loss_pde:0.24684797, loss_ic:0.17970943,loss_symetry:0.14309283,loss:2.09577632,loss_zero:0.05183411
# epoch 1 loss_pde:0.19475940, loss_ic:0.16005984,loss_symetry:0.07446181,loss:1.87265444,loss_zero:0.07729670
# epoch 1 loss_pde:0.35450566, loss_ic:0.21642883,loss_symetry:0.57940304,loss:2.63423729,loss_zero:0.11544311
# epoch 1 loss_pde:0.19213831, loss_ic:0.15071377,loss_symetry:0.09398071,loss:1.74273169,loss_zero:0.04345560
# epoch 1 loss_pde:0.11466625, loss_ic:0.11319374,loss_symetry:0.06518497,loss:1.27394605,loss_zero:0.02734247
# epoch 1 loss_pde:0.09276997, loss_ic:0.11161774,loss_symetry:0.05016305,loss:1.26362789,loss_zero:0.05468043
# epoch 1 loss_pde:0.09505181, loss_ic:0.10907236,loss_symetry:0.05123884,loss:1.22989154,loss_zero:0.04411615
# epoch 1 loss_pde:0.09582198, loss_ic:0.10534893,loss_symetry:0.05917393,loss:1.18955970,loss_zero:0.04024845
# epoch 1 loss_pde:0.09458680, loss_ic:0.09759936,loss_symetry:0.07277104,loss:1.11596704,loss_zero:0.04538656
# epoch 1 loss_pde:0.09858830, loss_ic:0.08031169,loss_symetry:0.07482351,loss:0.96695471,loss_zero:0.06524950
# epoch 1 loss_pde:0.40853551, loss_ic:0.11010007,loss_symetry:0.10479892,loss:1.51141560,loss_zero:0.00187940
# epoch 1 loss_pde:0.15160653, loss_ic:0.06622262,loss_symetry:0.05024154,loss:0.85915601,loss_zero:0.04532323
# epoch 1 loss_pde:0.22065544, loss_ic:0.05877284,loss_symetry:0.03891204,loss:0.82709229,loss_zero:0.01870840
# epoch 1 loss_pde:0.18150124, loss_ic:0.05890357,loss_symetry:0.03999450,loss:0.78384799,loss_zero:0.01331112
# epoch 1 loss_pde:0.17825198, loss_ic:0.05828491,loss_symetry:0.03832371,loss:0.76487291,loss_zero:0.00377182
# epoch 1 loss_pde:0.16270570, loss_ic:0.05891393,loss_symetry:0.05808147,loss:0.75280207,loss_zero:0.00095706
# epoch 1 loss_pde:0.17000397, loss_ic:0.05715783,loss_symetry:0.04843374,loss:0.74294555,loss_zero:0.00136327
# epoch 1 loss_pde:0.17347057, loss_ic:0.05540058,loss_symetry:0.03831505,loss:0.73088175,loss_zero:0.00340536
# epoch 1 loss_pde:0.17641848, loss_ic:0.05323987,loss_symetry:0.03458107,loss:0.71642131,loss_zero:0.00760415
# epoch 1 loss_pde:0.17399833, loss_ic:0.04947543,loss_symetry:0.02734014,loss:0.68180770,loss_zero:0.01305509
# epoch 1 loss_pde:0.16984725, loss_ic:0.04430227,loss_symetry:0.02557196,loss:0.62848425,loss_zero:0.01561425
# epoch 1 loss_pde:0.13660638, loss_ic:0.03950504,loss_symetry:0.01845651,loss:0.53489095,loss_zero:0.00323415
# epoch 1 loss_pde:0.18386020, loss_ic:0.03453448,loss_symetry:0.02999432,loss:0.54552442,loss_zero:0.01631938
# epoch 1 loss_pde:0.15472937, loss_ic:0.03335205,loss_symetry:0.01296408,loss:0.48949090,loss_zero:0.00124106
# epoch 1: loss 4.475400
# epoch 2 loss_pde:0.15472937, loss_ic:0.03335205,loss_symetry:0.01296408,loss:0.48949090,loss_zero:0.00124106
# epoch 2 loss_pde:0.23343249, loss_ic:0.02008997,loss_symetry:0.02422971,loss:0.44306970,loss_zero:0.00873753
# epoch 2 loss_pde:0.24914594, loss_ic:0.01979089,loss_symetry:0.02062829,loss:0.45088914,loss_zero:0.00383427
# epoch 2 loss_pde:0.23673694, loss_ic:0.01873386,loss_symetry:0.02220876,loss:0.43029270,loss_zero:0.00621715
# epoch 2 loss_pde:0.21841773, loss_ic:0.02218264,loss_symetry:0.03889824,loss:0.45077392,loss_zero:0.01052981
# epoch 2 loss_pde:0.22470851, loss_ic:0.01954942,loss_symetry:0.01960562,loss:0.42071012,loss_zero:0.00050744
# epoch 2 loss_pde:0.19371308, loss_ic:0.02188235,loss_symetry:0.00884686,loss:0.41455394,loss_zero:0.00201732
# epoch 2 loss_pde:0.21670720, loss_ic:0.01864313,loss_symetry:0.00972916,loss:0.40397877,loss_zero:0.00084027
# epoch 2 loss_pde:0.22870432, loss_ic:0.01719792,loss_symetry:0.01190243,loss:0.40178505,loss_zero:0.00110158
# epoch 2 loss_pde:0.23754521, loss_ic:0.01595828,loss_symetry:0.01044714,loss:0.39847013,loss_zero:0.00134214
# epoch 2 loss_pde:0.22947575, loss_ic:0.01647019,loss_symetry:0.00835384,loss:0.39495730,loss_zero:0.00077970
# epoch 2 loss_pde:0.22327134, loss_ic:0.01636763,loss_symetry:0.00637149,loss:0.38805911,loss_zero:0.00111147
# epoch 2 loss_pde:0.22155021, loss_ic:0.01551342,loss_symetry:0.00558617,loss:0.37861457,loss_zero:0.00193014
# epoch 2 loss_pde:0.22434436, loss_ic:0.01430573,loss_symetry:0.00541021,loss:0.36960724,loss_zero:0.00220561
# epoch 2 loss_pde:0.21640915, loss_ic:0.01358633,loss_symetry:0.00358945,loss:0.35275942,loss_zero:0.00048691
# epoch 2 loss_pde:0.21662542, loss_ic:0.01231189,loss_symetry:0.00349207,loss:0.34084186,loss_zero:0.00109752
# epoch 2 loss_pde:0.21408047, loss_ic:0.01219571,loss_symetry:0.00263341,loss:0.33633327,loss_zero:0.00029566
# epoch 2 loss_pde:0.22064510, loss_ic:0.01131126,loss_symetry:0.00245506,loss:0.33389881,loss_zero:0.00014111
# epoch 2 loss_pde:0.21741061, loss_ic:0.01146841,loss_symetry:0.00150860,loss:0.33255747,loss_zero:0.00046275
# epoch 2 loss_pde:0.22084408, loss_ic:0.01089691,loss_symetry:0.00147867,loss:0.33075795,loss_zero:0.00094481
# epoch 2 loss_pde:0.22750610, loss_ic:0.00968287,loss_symetry:0.00142473,loss:0.32573497,loss_zero:0.00140017
# epoch 2 loss_pde:0.21454723, loss_ic:0.01357579,loss_symetry:0.01248369,loss:0.35623825,loss_zero:0.00593310
# epoch 2 loss_pde:0.22479557, loss_ic:0.00929058,loss_symetry:0.00093912,loss:0.31783038,loss_zero:0.00012903
# epoch 2 loss_pde:0.26609033, loss_ic:0.01347910,loss_symetry:0.02873006,loss:0.41740388,loss_zero:0.01652255
# epoch 2 loss_pde:0.22754528, loss_ic:0.00875771,loss_symetry:0.00164585,loss:0.31522968,loss_zero:0.00010730
# epoch 2 loss_pde:0.25971261, loss_ic:0.00498128,loss_symetry:0.00305511,loss:0.31003541,loss_zero:0.00051001
# epoch 2 loss_pde:0.24644881, loss_ic:0.00599360,loss_symetry:0.00179516,loss:0.30668381,loss_zero:0.00029897
# epoch 2 loss_pde:0.23483840, loss_ic:0.00716207,loss_symetry:0.00184315,loss:0.30667749,loss_zero:0.00021837
# epoch 2 loss_pde:0.24034140, loss_ic:0.00652782,loss_symetry:0.00166329,loss:0.30587506,loss_zero:0.00025549
# epoch 2 loss_pde:0.24402420, loss_ic:0.00610853,loss_symetry:0.00159475,loss:0.30543911,loss_zero:0.00032962
# epoch 2 loss_pde:0.24511045, loss_ic:0.00593613,loss_symetry:0.00168789,loss:0.30490443,loss_zero:0.00043264
# epoch 2 loss_pde:0.24618736, loss_ic:0.00550494,loss_symetry:0.00155130,loss:0.30205259,loss_zero:0.00081582
# epoch 2 loss_pde:0.24241634, loss_ic:0.00537501,loss_symetry:0.00161806,loss:0.29852468,loss_zero:0.00235826
# epoch 2 loss_pde:0.23661472, loss_ic:0.00563648,loss_symetry:0.00112962,loss:0.29459929,loss_zero:0.00161976
# epoch 2 loss_pde:0.22861975, loss_ic:0.00604644,loss_symetry:0.00148398,loss:0.29078150,loss_zero:0.00169729
# epoch 2 loss_pde:0.21043333, loss_ic:0.00803751,loss_symetry:0.00046669,loss:0.29109231,loss_zero:0.00028388
# epoch 2 loss_pde:0.21936813, loss_ic:0.00685203,loss_symetry:0.00072597,loss:0.28872117,loss_zero:0.00083277
# epoch 2: loss 0.489491
# epoch 3 loss_pde:0.21936813, loss_ic:0.00685203,loss_symetry:0.00072597,loss:0.28872117,loss_zero:0.00083277
# epoch 3 loss_pde:0.22273971, loss_ic:0.00637819,loss_symetry:0.00066053,loss:0.28702012,loss_zero:0.00049849
# epoch 3 loss_pde:0.22450486, loss_ic:0.00613993,loss_symetry:0.00088399,loss:0.28636128,loss_zero:0.00045711
# epoch 3 loss_pde:0.22496890, loss_ic:0.00590855,loss_symetry:0.00091393,loss:0.28455520,loss_zero:0.00050086
# epoch 3 loss_pde:0.22502215, loss_ic:0.00529636,loss_symetry:0.00134103,loss:0.27836201,loss_zero:0.00037620
# epoch 3 loss_pde:0.21314855, loss_ic:0.00605216,loss_symetry:0.00131838,loss:0.27513191,loss_zero:0.00146177
# epoch 3 loss_pde:0.20904195, loss_ic:0.00611881,loss_symetry:0.00031887,loss:0.27041811,loss_zero:0.00018805
# epoch 3 loss_pde:0.22236210, loss_ic:0.00449242,loss_symetry:0.00059763,loss:0.26763728,loss_zero:0.00035103
# epoch 3 loss_pde:0.21277636, loss_ic:0.00500324,loss_symetry:0.00141608,loss:0.26302561,loss_zero:0.00021687
# epoch 3 loss_pde:0.19863817, loss_ic:0.00600584,loss_symetry:0.00049848,loss:0.25872725,loss_zero:0.00003072
# epoch 3 loss_pde:0.20633937, loss_ic:0.00480106,loss_symetry:0.00122511,loss:0.25450212,loss_zero:0.00015216
# epoch 3 loss_pde:0.21010900, loss_ic:0.00412504,loss_symetry:0.00138739,loss:0.25163049,loss_zero:0.00027107
# epoch 3 loss_pde:0.21566007, loss_ic:0.00352568,loss_symetry:0.00090185,loss:0.25100857,loss_zero:0.00009171
# epoch 3 loss_pde:0.21351080, loss_ic:0.00368206,loss_symetry:0.00071769,loss:0.25040069,loss_zero:0.00006930
# epoch 3 loss_pde:0.21330896, loss_ic:0.00364880,loss_symetry:0.00073040,loss:0.24988253,loss_zero:0.00008554
# epoch 3 loss_pde:0.21380158, loss_ic:0.00349193,loss_symetry:0.00069251,loss:0.24888828,loss_zero:0.00016738
# epoch 3 loss_pde:0.21417205, loss_ic:0.00334557,loss_symetry:0.00066347,loss:0.24783641,loss_zero:0.00020862
# epoch 3 loss_pde:0.21258523, loss_ic:0.00307469,loss_symetry:0.00068055,loss:0.24358147,loss_zero:0.00024939
# epoch 3 loss_pde:0.20442998, loss_ic:0.00316218,loss_symetry:0.00120270,loss:0.23610656,loss_zero:0.00005473
# epoch 3 loss_pde:0.20400541, loss_ic:0.00289847,loss_symetry:0.00104920,loss:0.23303545,loss_zero:0.00004533
# epoch 3 loss_pde:0.19168133, loss_ic:0.00398101,loss_symetry:0.00217491,loss:0.23205495,loss_zero:0.00056348
# epoch 3 loss_pde:0.19442905, loss_ic:0.00345013,loss_symetry:0.00117090,loss:0.22904103,loss_zero:0.00011068
# epoch 3 loss_pde:0.19290714, loss_ic:0.00353240,loss_symetry:0.00114482,loss:0.22847292,loss_zero:0.00024174
# epoch 3 loss_pde:0.19126680, loss_ic:0.00366117,loss_symetry:0.00111466,loss:0.22810647,loss_zero:0.00022800
# epoch 3 loss_pde:0.18979281, loss_ic:0.00376518,loss_symetry:0.00109083,loss:0.22763725,loss_zero:0.00019263
# epoch 3 loss_pde:0.18763335, loss_ic:0.00388023,loss_symetry:0.00121664,loss:0.22669356,loss_zero:0.00025795
# epoch 3 loss_pde:0.18620202, loss_ic:0.00385672,loss_symetry:0.00140782,loss:0.22514297,loss_zero:0.00037380
# epoch 3 loss_pde:0.18581757, loss_ic:0.00370714,loss_symetry:0.00188920,loss:0.22350971,loss_zero:0.00062071
# epoch 3 loss_pde:0.18972443, loss_ic:0.00321432,loss_symetry:0.00186740,loss:0.22257009,loss_zero:0.00070248
# epoch 3 loss_pde:0.19199575, loss_ic:0.00291107,loss_symetry:0.00207523,loss:0.22188775,loss_zero:0.00078130
# epoch 3 loss_pde:0.19157167, loss_ic:0.00293420,loss_symetry:0.00189225,loss:0.22164787,loss_zero:0.00073418
# epoch 3: loss 0.288721
# epoch 4 loss_pde:0.19157167, loss_ic:0.00293420,loss_symetry:0.00189225,loss:0.22164787,loss_zero:0.00073418
# epoch 4 loss_pde:0.19022588, loss_ic:0.00301719,loss_symetry:0.00168997,loss:0.22109336,loss_zero:0.00069561
# epoch 4 loss_pde:0.18774271, loss_ic:0.00312077,loss_symetry:0.00148674,loss:0.21961620,loss_zero:0.00066576
# epoch 4 loss_pde:0.18453220, loss_ic:0.00310726,loss_symetry:0.00146228,loss:0.21626848,loss_zero:0.00066364
# epoch 4 loss_pde:0.18048108, loss_ic:0.00313383,loss_symetry:0.00185428,loss:0.21228836,loss_zero:0.00046900
# epoch 4 loss_pde:0.17610754, loss_ic:0.00328748,loss_symetry:0.00196853,loss:0.20943612,loss_zero:0.00045377
# epoch 4 loss_pde:0.17678195, loss_ic:0.00312436,loss_symetry:0.00326217,loss:0.20858780,loss_zero:0.00056222
# epoch 4 loss_pde:0.17752039, loss_ic:0.00285202,loss_symetry:0.00301622,loss:0.20660709,loss_zero:0.00056646
# epoch 4 loss_pde:0.17732067, loss_ic:0.00290730,loss_symetry:0.00368741,loss:0.20683832,loss_zero:0.00044469
# epoch 4 loss_pde:0.17728427, loss_ic:0.00285039,loss_symetry:0.00309434,loss:0.20624045,loss_zero:0.00045225
# epoch 4 loss_pde:0.17761141, loss_ic:0.00279634,loss_symetry:0.00336600,loss:0.20601059,loss_zero:0.00043580
# epoch 4 loss_pde:0.17758383, loss_ic:0.00277669,loss_symetry:0.00342237,loss:0.20580618,loss_zero:0.00045543
# epoch 4 loss_pde:0.17741770, loss_ic:0.00274319,loss_symetry:0.00358863,loss:0.20529188,loss_zero:0.00044234
# epoch 4 loss_pde:0.17664261, loss_ic:0.00262710,loss_symetry:0.00360334,loss:0.20332466,loss_zero:0.00041105
# epoch 4 loss_pde:0.17314087, loss_ic:0.00283443,loss_symetry:0.00339212,loss:0.20187737,loss_zero:0.00039217
# epoch 4 loss_pde:0.17385684, loss_ic:0.00268038,loss_symetry:0.00326712,loss:0.20101926,loss_zero:0.00035864
# epoch 4 loss_pde:0.17240423, loss_ic:0.00279092,loss_symetry:0.00310245,loss:0.20065536,loss_zero:0.00034189
# epoch 4 loss_pde:0.17158927, loss_ic:0.00285336,loss_symetry:0.00311575,loss:0.20047396,loss_zero:0.00035111
# epoch 4 loss_pde:0.17301559, loss_ic:0.00268947,loss_symetry:0.00304834,loss:0.20024785,loss_zero:0.00033754
# epoch 4 loss_pde:0.17332196, loss_ic:0.00263781,loss_symetry:0.00280528,loss:0.20001802,loss_zero:0.00031792
# epoch 4 loss_pde:0.17229553, loss_ic:0.00269776,loss_symetry:0.00234624,loss:0.19957840,loss_zero:0.00030527
# epoch 4 loss_pde:0.17165904, loss_ic:0.00273044,loss_symetry:0.00220805,loss:0.19928674,loss_zero:0.00032329
# epoch 4 loss_pde:0.17054515, loss_ic:0.00275620,loss_symetry:0.00202557,loss:0.19851050,loss_zero:0.00040334
# epoch 4 loss_pde:0.16846077, loss_ic:0.00284274,loss_symetry:0.00197255,loss:0.19735953,loss_zero:0.00047135
# epoch 4 loss_pde:0.16651274, loss_ic:0.00280967,loss_symetry:0.00181632,loss:0.19519357,loss_zero:0.00058417
# epoch 4 loss_pde:0.16267020, loss_ic:0.00296483,loss_symetry:0.00169040,loss:0.19277850,loss_zero:0.00045998
# epoch 4 loss_pde:0.16272293, loss_ic:0.00283589,loss_symetry:0.00178591,loss:0.19149093,loss_zero:0.00040905
# epoch 4 loss_pde:0.16410789, loss_ic:0.00264662,loss_symetry:0.00160306,loss:0.19071846,loss_zero:0.00014441
# epoch 4 loss_pde:0.16373803, loss_ic:0.00266528,loss_symetry:0.00157341,loss:0.19057898,loss_zero:0.00018819
# epoch 4 loss_pde:0.16395067, loss_ic:0.00262788,loss_symetry:0.00154586,loss:0.19043180,loss_zero:0.00020231
# epoch 4 loss_pde:0.16445096, loss_ic:0.00254071,loss_symetry:0.00144813,loss:0.19009636,loss_zero:0.00023825
# epoch 4 loss_pde:0.16374490, loss_ic:0.00254360,loss_symetry:0.00141597,loss:0.18953182,loss_zero:0.00035092
# epoch 4: loss 0.221648
# epoch 5 loss_pde:0.16374490, loss_ic:0.00254360,loss_symetry:0.00141597,loss:0.18953182,loss_zero:0.00035092
# epoch 5 loss_pde:0.16207543, loss_ic:0.00256275,loss_symetry:0.00122611,loss:0.18822563,loss_zero:0.00052273
# epoch 5 loss_pde:0.15930323, loss_ic:0.00262316,loss_symetry:0.00126841,loss:0.18639562,loss_zero:0.00086073
# epoch 5 loss_pde:0.16024791, loss_ic:0.00228694,loss_symetry:0.00136197,loss:0.18421422,loss_zero:0.00109696
# epoch 5 loss_pde:0.16014344, loss_ic:0.00213999,loss_symetry:0.00165840,loss:0.18312874,loss_zero:0.00158543
# epoch 5 loss_pde:0.16497825, loss_ic:0.00169981,loss_symetry:0.00186578,loss:0.18303591,loss_zero:0.00105955
# epoch 5 loss_pde:0.16227472, loss_ic:0.00190408,loss_symetry:0.00168378,loss:0.18260434,loss_zero:0.00128885
# epoch 5 loss_pde:0.16094518, loss_ic:0.00205357,loss_symetry:0.00158659,loss:0.18262053,loss_zero:0.00113968
# epoch 5 loss_pde:0.16155989, loss_ic:0.00196800,loss_symetry:0.00162372,loss:0.18245599,loss_zero:0.00121604
# epoch 5 loss_pde:0.16018057, loss_ic:0.00210066,loss_symetry:0.00161351,loss:0.18240030,loss_zero:0.00121318
# epoch 5 loss_pde:0.16043855, loss_ic:0.00207287,loss_symetry:0.00159708,loss:0.18235278,loss_zero:0.00118555
# epoch 5 loss_pde:0.16076048, loss_ic:0.00203320,loss_symetry:0.00156352,loss:0.18228655,loss_zero:0.00119401
# epoch 5 loss_pde:0.16078760, loss_ic:0.00202190,loss_symetry:0.00152119,loss:0.18219464,loss_zero:0.00118800
# epoch 5 loss_pde:0.16058160, loss_ic:0.00202374,loss_symetry:0.00146008,loss:0.18201269,loss_zero:0.00119367
# epoch 5 loss_pde:0.16017222, loss_ic:0.00202950,loss_symetry:0.00133546,loss:0.18164407,loss_zero:0.00117687
# epoch 5 loss_pde:0.15916614, loss_ic:0.00205969,loss_symetry:0.00115862,loss:0.18087344,loss_zero:0.00111039
# epoch 5 loss_pde:0.15735431, loss_ic:0.00212104,loss_symetry:0.00089181,loss:0.17944820,loss_zero:0.00088344
# epoch 5 loss_pde:0.15453225, loss_ic:0.00224513,loss_symetry:0.00066035,loss:0.17749634,loss_zero:0.00051283
# epoch 5 loss_pde:0.15323555, loss_ic:0.00230441,loss_symetry:0.00115799,loss:0.17678791,loss_zero:0.00050826
# epoch 5 loss_pde:0.15426834, loss_ic:0.00215555,loss_symetry:0.00085001,loss:0.17612514,loss_zero:0.00030132
# epoch 5 loss_pde:0.15492883, loss_ic:0.00203742,loss_symetry:0.00072601,loss:0.17569388,loss_zero:0.00039084
# epoch 5 loss_pde:0.15584667, loss_ic:0.00193564,loss_symetry:0.00099411,loss:0.17557494,loss_zero:0.00037191
# epoch 5 loss_pde:0.15337132, loss_ic:0.00212389,loss_symetry:0.00107042,loss:0.17504577,loss_zero:0.00043560
# epoch 5 loss_pde:0.15376885, loss_ic:0.00205943,loss_symetry:0.00103746,loss:0.17482546,loss_zero:0.00046229
# epoch 5 loss_pde:0.15343267, loss_ic:0.00206501,loss_symetry:0.00123005,loss:0.17456953,loss_zero:0.00048674
# epoch 5 loss_pde:0.15212452, loss_ic:0.00210965,loss_symetry:0.00159797,loss:0.17381957,loss_zero:0.00059854
# epoch 5 loss_pde:0.14493020, loss_ic:0.00255668,loss_symetry:0.00338394,loss:0.17222179,loss_zero:0.00172482
# epoch 5 loss_pde:0.15006818, loss_ic:0.00198584,loss_symetry:0.00315265,loss:0.17089529,loss_zero:0.00096866
# epoch 5 loss_pde:0.14475532, loss_ic:0.00219493,loss_symetry:0.00280521,loss:0.16875170,loss_zero:0.00204706
# epoch 5 loss_pde:0.13842832, loss_ic:0.00273286,loss_symetry:0.00566984,loss:0.17020582,loss_zero:0.00444887
# epoch 5 loss_pde:0.14123799, loss_ic:0.00235963,loss_symetry:0.00366056,loss:0.16753614,loss_zero:0.00270180
# epoch 5 loss_pde:0.14103164, loss_ic:0.00235232,loss_symetry:0.00365862,loss:0.16602764,loss_zero:0.00147278
# epoch 5 loss_pde:0.13985176, loss_ic:0.00213701,loss_symetry:0.00387172,loss:0.16308945,loss_zero:0.00186763
# epoch 5 loss_pde:0.12057819, loss_ic:0.00549148,loss_symetry:0.00917692,loss:0.18722011,loss_zero:0.01172714
# epoch 5 loss_pde:0.12545578, loss_ic:0.00286111,loss_symetry:0.00438022,loss:0.15793657,loss_zero:0.00386972
# epoch 5: loss 0.189532
# epoch 6 loss_pde:0.12545578, loss_ic:0.00286111,loss_symetry:0.00438022,loss:0.15793657,loss_zero:0.00386972
# epoch 6 loss_pde:0.12042220, loss_ic:0.00336647,loss_symetry:0.00604287,loss:0.16278845,loss_zero:0.00870160
# epoch 6 loss_pde:0.11940762, loss_ic:0.00277796,loss_symetry:0.00386559,loss:0.15163715,loss_zero:0.00444996
# epoch 6 loss_pde:0.13092610, loss_ic:0.00363522,loss_symetry:0.01030004,loss:0.17062099,loss_zero:0.00334266
# epoch 6 loss_pde:0.11444104, loss_ic:0.00290318,loss_symetry:0.00494447,loss:0.14753620,loss_zero:0.00406333
# epoch 6 loss_pde:0.11061350, loss_ic:0.00305936,loss_symetry:0.00515751,loss:0.14644931,loss_zero:0.00524223
# epoch 6 loss_pde:0.11115970, loss_ic:0.00269519,loss_symetry:0.00459011,loss:0.14215636,loss_zero:0.00404472
# epoch 6 loss_pde:0.10782681, loss_ic:0.00295655,loss_symetry:0.00281553,loss:0.13878176,loss_zero:0.00138941
# epoch 6 loss_pde:0.10078212, loss_ic:0.00339946,loss_symetry:0.00284534,loss:0.13651474,loss_zero:0.00173802
# epoch 6 loss_pde:0.10135467, loss_ic:0.00312115,loss_symetry:0.00389853,loss:0.13427806,loss_zero:0.00171192
# epoch 6 loss_pde:0.09546174, loss_ic:0.00337324,loss_symetry:0.00309652,loss:0.13070041,loss_zero:0.00150628
# epoch 6 loss_pde:0.09063991, loss_ic:0.00336317,loss_symetry:0.00300149,loss:0.12499211,loss_zero:0.00072052
# epoch 6 loss_pde:0.07676989, loss_ic:0.00362577,loss_symetry:0.00314506,loss:0.11401954,loss_zero:0.00099196
# epoch 6 loss_pde:0.07554716, loss_ic:0.00290731,loss_symetry:0.00730808,loss:0.10698559,loss_zero:0.00236529
# epoch 6 loss_pde:0.06750171, loss_ic:0.00290657,loss_symetry:0.00439069,loss:0.09824149,loss_zero:0.00167406
# epoch 6 loss_pde:0.05952789, loss_ic:0.00293046,loss_symetry:0.00434487,loss:0.09054232,loss_zero:0.00170986
# epoch 6 loss_pde:0.06438132, loss_ic:0.00216000,loss_symetry:0.00377070,loss:0.08747450,loss_zero:0.00149316
# epoch 6 loss_pde:0.05994394, loss_ic:0.00161798,loss_symetry:0.00269499,loss:0.07732955,loss_zero:0.00120576
# epoch 6 loss_pde:0.05696738, loss_ic:0.00192013,loss_symetry:0.00221265,loss:0.07759470,loss_zero:0.00142605
# epoch 6 loss_pde:0.05767161, loss_ic:0.00166425,loss_symetry:0.00205683,loss:0.07560863,loss_zero:0.00129448
# epoch 6 loss_pde:0.05972641, loss_ic:0.00137286,loss_symetry:0.00269145,loss:0.07505151,loss_zero:0.00159646
# epoch 6 loss_pde:0.05856549, loss_ic:0.00125983,loss_symetry:0.00244957,loss:0.07268852,loss_zero:0.00152470
# epoch 6 loss_pde:0.05689424, loss_ic:0.00133273,loss_symetry:0.00213007,loss:0.07150800,loss_zero:0.00128650
# epoch 6 loss_pde:0.05469748, loss_ic:0.00124035,loss_symetry:0.00182530,loss:0.06812786,loss_zero:0.00102690
# epoch 6 loss_pde:0.05017033, loss_ic:0.00146668,loss_symetry:0.00210985,loss:0.06584935,loss_zero:0.00101225
# epoch 6 loss_pde:0.04893083, loss_ic:0.00146822,loss_symetry:0.00221795,loss:0.06460551,loss_zero:0.00099250
# epoch 6 loss_pde:0.04854342, loss_ic:0.00144803,loss_symetry:0.00244390,loss:0.06410623,loss_zero:0.00108254
# epoch 6 loss_pde:0.04873209, loss_ic:0.00140100,loss_symetry:0.00242388,loss:0.06384972,loss_zero:0.00110767
# epoch 6 loss_pde:0.04881793, loss_ic:0.00134255,loss_symetry:0.00233215,loss:0.06341534,loss_zero:0.00117195
# epoch 6 loss_pde:0.04778996, loss_ic:0.00134333,loss_symetry:0.00244230,loss:0.06253180,loss_zero:0.00130851
# epoch 6 loss_pde:0.04695367, loss_ic:0.00127331,loss_symetry:0.00254997,loss:0.06129811,loss_zero:0.00161130
# epoch 6 loss_pde:0.04583587, loss_ic:0.00119766,loss_symetry:0.00243116,loss:0.05996337,loss_zero:0.00215093
# epoch 6 loss_pde:0.04479365, loss_ic:0.00115289,loss_symetry:0.00292553,loss:0.05868262,loss_zero:0.00236010
# epoch 6 loss_pde:0.04376596, loss_ic:0.00114868,loss_symetry:0.00291012,loss:0.05753201,loss_zero:0.00227920
# epoch 6 loss_pde:0.04326443, loss_ic:0.00112884,loss_symetry:0.00299663,loss:0.05655272,loss_zero:0.00199984
# epoch 6 loss_pde:0.04320817, loss_ic:0.00108270,loss_symetry:0.00300917,loss:0.05564887,loss_zero:0.00161375
# epoch 6: loss 0.157937
# epoch 7 loss_pde:0.04320817, loss_ic:0.00108270,loss_symetry:0.00300917,loss:0.05564887,loss_zero:0.00161375
# epoch 7 loss_pde:0.04330647, loss_ic:0.00100518,loss_symetry:0.00301467,loss:0.05487550,loss_zero:0.00151722
# epoch 7 loss_pde:0.04275109, loss_ic:0.00098016,loss_symetry:0.00306696,loss:0.05397506,loss_zero:0.00142234
# epoch 7 loss_pde:0.04271963, loss_ic:0.00091176,loss_symetry:0.00327386,loss:0.05327397,loss_zero:0.00143672
# epoch 7 loss_pde:0.04169443, loss_ic:0.00094058,loss_symetry:0.00339022,loss:0.05261332,loss_zero:0.00151311
# epoch 7 loss_pde:0.04076644, loss_ic:0.00095430,loss_symetry:0.00338255,loss:0.05189026,loss_zero:0.00158083
# epoch 7 loss_pde:0.04031657, loss_ic:0.00092166,loss_symetry:0.00324022,loss:0.05121416,loss_zero:0.00168104
# epoch 7 loss_pde:0.03909480, loss_ic:0.00092986,loss_symetry:0.00263617,loss:0.05002842,loss_zero:0.00163501
# epoch 7 loss_pde:0.03841343, loss_ic:0.00091595,loss_symetry:0.00244454,loss:0.04919462,loss_zero:0.00162171
# epoch 7 loss_pde:0.03781457, loss_ic:0.00085522,loss_symetry:0.00225660,loss:0.04796351,loss_zero:0.00159674
# epoch 7 loss_pde:0.03661468, loss_ic:0.00090743,loss_symetry:0.00221351,loss:0.04727818,loss_zero:0.00158920
# epoch 7 loss_pde:0.03676793, loss_ic:0.00082171,loss_symetry:0.00223693,loss:0.04658149,loss_zero:0.00159642
# epoch 7 loss_pde:0.03594562, loss_ic:0.00085343,loss_symetry:0.00241223,loss:0.04611502,loss_zero:0.00163514
# epoch 7 loss_pde:0.03513595, loss_ic:0.00090913,loss_symetry:0.00266822,loss:0.04586697,loss_zero:0.00163971
# epoch 7 loss_pde:0.03466072, loss_ic:0.00094171,loss_symetry:0.00247977,loss:0.04569731,loss_zero:0.00161953
# epoch 7 loss_pde:0.03473936, loss_ic:0.00091729,loss_symetry:0.00259766,loss:0.04556194,loss_zero:0.00164967
# epoch 7 loss_pde:0.03446874, loss_ic:0.00091110,loss_symetry:0.00259034,loss:0.04523661,loss_zero:0.00165686
# epoch 7 loss_pde:0.03354233, loss_ic:0.00093788,loss_symetry:0.00265395,loss:0.04461468,loss_zero:0.00169351
# epoch 7 loss_pde:0.03173180, loss_ic:0.00092500,loss_symetry:0.00307135,loss:0.04284149,loss_zero:0.00185974
# epoch 7 loss_pde:0.02963183, loss_ic:0.00091482,loss_symetry:0.00371484,loss:0.04094969,loss_zero:0.00216966
# epoch 7 loss_pde:0.02930970, loss_ic:0.00075090,loss_symetry:0.00467046,loss:0.03886654,loss_zero:0.00204789
# epoch 7 loss_pde:0.02882493, loss_ic:0.00065324,loss_symetry:0.00494714,loss:0.03751997,loss_zero:0.00216261
# epoch 7 loss_pde:0.02900679, loss_ic:0.00057771,loss_symetry:0.00460410,loss:0.03647901,loss_zero:0.00169509
# epoch 7 loss_pde:0.02899916, loss_ic:0.00054788,loss_symetry:0.00459023,loss:0.03609120,loss_zero:0.00161328
# epoch 7 loss_pde:0.02887270, loss_ic:0.00052130,loss_symetry:0.00433961,loss:0.03566350,loss_zero:0.00157780
# epoch 7 loss_pde:0.02841705, loss_ic:0.00049540,loss_symetry:0.00409412,loss:0.03482189,loss_zero:0.00145081
# epoch 7 loss_pde:0.02671809, loss_ic:0.00050749,loss_symetry:0.00343773,loss:0.03281295,loss_zero:0.00101998
# epoch 7 loss_pde:0.02548375, loss_ic:0.00056095,loss_symetry:0.00294415,loss:0.03184407,loss_zero:0.00075078
# epoch 7 loss_pde:0.02594740, loss_ic:0.00047428,loss_symetry:0.00284122,loss:0.03129896,loss_zero:0.00060872
# epoch 7 loss_pde:0.02509866, loss_ic:0.00050996,loss_symetry:0.00286397,loss:0.03077517,loss_zero:0.00057695
# epoch 7 loss_pde:0.02517138, loss_ic:0.00046438,loss_symetry:0.00286742,loss:0.03037377,loss_zero:0.00055859
# epoch 7: loss 0.055649
# epoch 8 loss_pde:0.02517138, loss_ic:0.00046438,loss_symetry:0.00286742,loss:0.03037377,loss_zero:0.00055859
# epoch 8 loss_pde:0.02501527, loss_ic:0.00043785,loss_symetry:0.00297888,loss:0.02995322,loss_zero:0.00055940
# epoch 8 loss_pde:0.02482962, loss_ic:0.00042408,loss_symetry:0.00309680,loss:0.02961295,loss_zero:0.00054257
# epoch 8 loss_pde:0.02431726, loss_ic:0.00042890,loss_symetry:0.00299243,loss:0.02915478,loss_zero:0.00054853
# epoch 8 loss_pde:0.02373139, loss_ic:0.00044901,loss_symetry:0.00273379,loss:0.02864114,loss_zero:0.00041968
# epoch 8 loss_pde:0.02348984, loss_ic:0.00045130,loss_symetry:0.00246697,loss:0.02836135,loss_zero:0.00035849
# epoch 8 loss_pde:0.02347305, loss_ic:0.00044817,loss_symetry:0.00239382,loss:0.02828529,loss_zero:0.00033057
# epoch 8 loss_pde:0.02363322, loss_ic:0.00042845,loss_symetry:0.00233750,loss:0.02822798,loss_zero:0.00031022
# epoch 8 loss_pde:0.02359976, loss_ic:0.00042372,loss_symetry:0.00232818,loss:0.02814041,loss_zero:0.00030344
# epoch 8 loss_pde:0.02376412, loss_ic:0.00039220,loss_symetry:0.00227264,loss:0.02797565,loss_zero:0.00028954
# epoch 8 loss_pde:0.02365030, loss_ic:0.00037970,loss_symetry:0.00222478,loss:0.02774020,loss_zero:0.00029288
# epoch 8 loss_pde:0.02334764, loss_ic:0.00038851,loss_symetry:0.00218208,loss:0.02753291,loss_zero:0.00030013
# epoch 8 loss_pde:0.02295655, loss_ic:0.00040371,loss_symetry:0.00211709,loss:0.02728252,loss_zero:0.00028890
# epoch 8 loss_pde:0.02254747, loss_ic:0.00041176,loss_symetry:0.00198605,loss:0.02690848,loss_zero:0.00024338
# epoch 8 loss_pde:0.02226795, loss_ic:0.00038754,loss_symetry:0.00177735,loss:0.02629696,loss_zero:0.00015360
# epoch 8 loss_pde:0.02191602, loss_ic:0.00036204,loss_symetry:0.00135538,loss:0.02560855,loss_zero:0.00007214
# epoch 8 loss_pde:0.02136289, loss_ic:0.00038264,loss_symetry:0.00120297,loss:0.02526642,loss_zero:0.00007715
# epoch 8 loss_pde:0.02216103, loss_ic:0.00025944,loss_symetry:0.00106187,loss:0.02481004,loss_zero:0.00005464
# epoch 8 loss_pde:0.02096964, loss_ic:0.00035347,loss_symetry:0.00115845,loss:0.02458667,loss_zero:0.00008232
# epoch 8 loss_pde:0.02103355, loss_ic:0.00031460,loss_symetry:0.00108092,loss:0.02425897,loss_zero:0.00007946
# epoch 8 loss_pde:0.02110846, loss_ic:0.00028019,loss_symetry:0.00112691,loss:0.02399140,loss_zero:0.00008101
# epoch 8 loss_pde:0.02107562, loss_ic:0.00025641,loss_symetry:0.00126436,loss:0.02371755,loss_zero:0.00007779
# epoch 8 loss_pde:0.02087945, loss_ic:0.00025009,loss_symetry:0.00158950,loss:0.02346472,loss_zero:0.00008439
# epoch 8 loss_pde:0.02073668, loss_ic:0.00024913,loss_symetry:0.00168579,loss:0.02329273,loss_zero:0.00006479
# epoch 8 loss_pde:0.02050107, loss_ic:0.00024936,loss_symetry:0.00174407,loss:0.02307207,loss_zero:0.00007736
# epoch 8 loss_pde:0.02037841, loss_ic:0.00025150,loss_symetry:0.00161855,loss:0.02296062,loss_zero:0.00006718
# epoch 8 loss_pde:0.02043873, loss_ic:0.00023707,loss_symetry:0.00150082,loss:0.02287845,loss_zero:0.00006897
# epoch 8 loss_pde:0.02042099, loss_ic:0.00023010,loss_symetry:0.00141266,loss:0.02278736,loss_zero:0.00006539
# epoch 8 loss_pde:0.02031844, loss_ic:0.00022186,loss_symetry:0.00132191,loss:0.02260434,loss_zero:0.00006731
# epoch 8 loss_pde:0.02000882, loss_ic:0.00022829,loss_symetry:0.00123075,loss:0.02234372,loss_zero:0.00005196
# epoch 8 loss_pde:0.01950852, loss_ic:0.00024407,loss_symetry:0.00134311,loss:0.02201989,loss_zero:0.00007064
# epoch 8: loss 0.030374
# epoch 9 loss_pde:0.01950852, loss_ic:0.00024407,loss_symetry:0.00134311,loss:0.02201989,loss_zero:0.00007064
# epoch 9 loss_pde:0.01896019, loss_ic:0.00027501,loss_symetry:0.00127162,loss:0.02173346,loss_zero:0.00002313
# epoch 9 loss_pde:0.01844969, loss_ic:0.00030485,loss_symetry:0.00138187,loss:0.02152202,loss_zero:0.00002387
# epoch 9 loss_pde:0.01822631, loss_ic:0.00031297,loss_symetry:0.00156687,loss:0.02138112,loss_zero:0.00002510
# epoch 9 loss_pde:0.01789106, loss_ic:0.00033514,loss_symetry:0.00152801,loss:0.02126334,loss_zero:0.00002084
# epoch 9 loss_pde:0.01793285, loss_ic:0.00031368,loss_symetry:0.00157224,loss:0.02109080,loss_zero:0.00002115
# epoch 9 loss_pde:0.01778797, loss_ic:0.00029422,loss_symetry:0.00161427,loss:0.02075615,loss_zero:0.00002599
# epoch 9 loss_pde:0.01745012, loss_ic:0.00029676,loss_symetry:0.00164128,loss:0.02045671,loss_zero:0.00003902
# epoch 9 loss_pde:0.01688812, loss_ic:0.00031898,loss_symetry:0.00180282,loss:0.02013238,loss_zero:0.00005450
# epoch 9 loss_pde:0.01654058, loss_ic:0.00033559,loss_symetry:0.00192429,loss:0.01996375,loss_zero:0.00006725
# epoch 9 loss_pde:0.01654786, loss_ic:0.00032993,loss_symetry:0.00212399,loss:0.01990782,loss_zero:0.00006062
# epoch 9 loss_pde:0.01663069, loss_ic:0.00031691,loss_symetry:0.00208225,loss:0.01985946,loss_zero:0.00005963
# epoch 9 loss_pde:0.01672172, loss_ic:0.00030522,loss_symetry:0.00206515,loss:0.01983161,loss_zero:0.00005765
# epoch 9 loss_pde:0.01683764, loss_ic:0.00028956,loss_symetry:0.00206235,loss:0.01979129,loss_zero:0.00005805
# epoch 9 loss_pde:0.01692658, loss_ic:0.00027481,loss_symetry:0.00201504,loss:0.01973278,loss_zero:0.00005808
# epoch 9 loss_pde:0.01698395, loss_ic:0.00026136,loss_symetry:0.00197342,loss:0.01966091,loss_zero:0.00006337
# epoch 9 loss_pde:0.01697903, loss_ic:0.00024954,loss_symetry:0.00187128,loss:0.01954437,loss_zero:0.00006992
# epoch 9 loss_pde:0.01681798, loss_ic:0.00024566,loss_symetry:0.00179909,loss:0.01935029,loss_zero:0.00007575
# epoch 9 loss_pde:0.01660157, loss_ic:0.00023230,loss_symetry:0.00157145,loss:0.01902041,loss_zero:0.00009583
# epoch 9 loss_pde:0.01608459, loss_ic:0.00023699,loss_symetry:0.00128106,loss:0.01853671,loss_zero:0.00008218
# epoch 9 loss_pde:0.01588558, loss_ic:0.00021175,loss_symetry:0.00112543,loss:0.01805744,loss_zero:0.00005440
# epoch 9 loss_pde:0.01549076, loss_ic:0.00020196,loss_symetry:0.00107461,loss:0.01755026,loss_zero:0.00003987
# epoch 9 loss_pde:0.01553678, loss_ic:0.00018233,loss_symetry:0.00106890,loss:0.01746599,loss_zero:0.00010593
# epoch 9 loss_pde:0.01543195, loss_ic:0.00018561,loss_symetry:0.00106183,loss:0.01735487,loss_zero:0.00006680
# epoch 9 loss_pde:0.01527290, loss_ic:0.00018455,loss_symetry:0.00102156,loss:0.01717494,loss_zero:0.00005652
# epoch 9 loss_pde:0.01500544, loss_ic:0.00020111,loss_symetry:0.00098547,loss:0.01709062,loss_zero:0.00007406
# epoch 9 loss_pde:0.01497574, loss_ic:0.00019689,loss_symetry:0.00091159,loss:0.01703108,loss_zero:0.00008646
# epoch 9 loss_pde:0.01492637, loss_ic:0.00019766,loss_symetry:0.00091177,loss:0.01699648,loss_zero:0.00009346
# epoch 9 loss_pde:0.01506735, loss_ic:0.00018006,loss_symetry:0.00084261,loss:0.01696363,loss_zero:0.00009571
# epoch 9 loss_pde:0.01512759, loss_ic:0.00017037,loss_symetry:0.00081924,loss:0.01692514,loss_zero:0.00009384
# epoch 9 loss_pde:0.01511757, loss_ic:0.00016527,loss_symetry:0.00078650,loss:0.01687641,loss_zero:0.00010616
# epoch 9 loss_pde:0.01507373, loss_ic:0.00016592,loss_symetry:0.00073775,loss:0.01683918,loss_zero:0.00010626
# epoch 9: loss 0.022020
# epoch 10 loss_pde:0.01507373, loss_ic:0.00016592,loss_symetry:0.00073775,loss:0.01683918,loss_zero:0.00010626
# epoch 10 loss_pde:0.01497950, loss_ic:0.00016935,loss_symetry:0.00071956,loss:0.01679738,loss_zero:0.00012442
# epoch 10 loss_pde:0.01483299, loss_ic:0.00017454,loss_symetry:0.00069804,loss:0.01672236,loss_zero:0.00014396
# epoch 10 loss_pde:0.01460986, loss_ic:0.00018177,loss_symetry:0.00071693,loss:0.01658682,loss_zero:0.00015925
# epoch 10 loss_pde:0.01440999, loss_ic:0.00017594,loss_symetry:0.00072089,loss:0.01635532,loss_zero:0.00018592
# epoch 10 loss_pde:0.01400656, loss_ic:0.00017656,loss_symetry:0.00090506,loss:0.01596586,loss_zero:0.00019367
# epoch 10 loss_pde:0.01396483, loss_ic:0.00013437,loss_symetry:0.00094458,loss:0.01558434,loss_zero:0.00027578
# epoch 10 loss_pde:0.01627950, loss_ic:0.00018470,loss_symetry:0.00151130,loss:0.01857585,loss_zero:0.00044934
# epoch 10 loss_pde:0.01402488, loss_ic:0.00011592,loss_symetry:0.00093687,loss:0.01539591,loss_zero:0.00021182
# epoch 10 loss_pde:0.01374691, loss_ic:0.00009137,loss_symetry:0.00089389,loss:0.01486365,loss_zero:0.00020305
# epoch 10 loss_pde:0.01410212, loss_ic:0.00009282,loss_symetry:0.00103942,loss:0.01525250,loss_zero:0.00022213
# epoch 10 loss_pde:0.01352313, loss_ic:0.00008485,loss_symetry:0.00094799,loss:0.01458274,loss_zero:0.00021108
# epoch 10 loss_pde:0.01291393, loss_ic:0.00010147,loss_symetry:0.00084916,loss:0.01429403,loss_zero:0.00036540
# epoch 10 loss_pde:0.01253043, loss_ic:0.00013143,loss_symetry:0.00097601,loss:0.01416437,loss_zero:0.00031962
# epoch 10 loss_pde:0.01245041, loss_ic:0.00011757,loss_symetry:0.00097748,loss:0.01397977,loss_zero:0.00035366
# epoch 10 loss_pde:0.01266877, loss_ic:0.00009103,loss_symetry:0.00087122,loss:0.01388879,loss_zero:0.00030977
# epoch 10 loss_pde:0.01247733, loss_ic:0.00009616,loss_symetry:0.00089595,loss:0.01378896,loss_zero:0.00035007
# epoch 10 loss_pde:0.01231422, loss_ic:0.00009943,loss_symetry:0.00092916,loss:0.01367142,loss_zero:0.00036286
# epoch 10 loss_pde:0.01207005, loss_ic:0.00010529,loss_symetry:0.00085510,loss:0.01352093,loss_zero:0.00039797
# epoch 10 loss_pde:0.01199399, loss_ic:0.00009509,loss_symetry:0.00075874,loss:0.01335953,loss_zero:0.00041461
# epoch 10 loss_pde:0.01190097, loss_ic:0.00009470,loss_symetry:0.00065204,loss:0.01323306,loss_zero:0.00038512
# epoch 10 loss_pde:0.01175880, loss_ic:0.00009666,loss_symetry:0.00060189,loss:0.01313994,loss_zero:0.00041451
# epoch 10 loss_pde:0.01168267, loss_ic:0.00010042,loss_symetry:0.00059973,loss:0.01307465,loss_zero:0.00038776
# epoch 10 loss_pde:0.01164760, loss_ic:0.00009608,loss_symetry:0.00060667,loss:0.01301305,loss_zero:0.00040466
# epoch 10 loss_pde:0.01157405, loss_ic:0.00009533,loss_symetry:0.00061397,loss:0.01297317,loss_zero:0.00044581
# epoch 10 loss_pde:0.01147458, loss_ic:0.00009558,loss_symetry:0.00065682,loss:0.01293333,loss_zero:0.00050293
# epoch 10 loss_pde:0.01139444, loss_ic:0.00009462,loss_symetry:0.00068896,loss:0.01289547,loss_zero:0.00055484
# epoch 10 loss_pde:0.01137559, loss_ic:0.00009330,loss_symetry:0.00067769,loss:0.01287326,loss_zero:0.00056471
# epoch 10 loss_pde:0.01134848, loss_ic:0.00009466,loss_symetry:0.00068220,loss:0.01286139,loss_zero:0.00056634
# epoch 10 loss_pde:0.01129925, loss_ic:0.00009469,loss_symetry:0.00070369,loss:0.01281938,loss_zero:0.00057319
# epoch 10 loss_pde:0.01129588, loss_ic:0.00009225,loss_symetry:0.00071490,loss:0.01276135,loss_zero:0.00054298
# epoch 10 loss_pde:0.01104134, loss_ic:0.00011177,loss_symetry:0.00070568,loss:0.01269518,loss_zero:0.00053616
# epoch 10 loss_pde:0.01102585, loss_ic:0.00010744,loss_symetry:0.00072086,loss:0.01260080,loss_zero:0.00050060
# epoch 10: loss 0.016839
# epoch 11 loss_pde:0.01102585, loss_ic:0.00010744,loss_symetry:0.00072086,loss:0.01260080,loss_zero:0.00050060
# epoch 11 loss_pde:0.01089582, loss_ic:0.00010360,loss_symetry:0.00076626,loss:0.01234338,loss_zero:0.00041154
# epoch 11 loss_pde:0.01067174, loss_ic:0.00010721,loss_symetry:0.00078948,loss:0.01210179,loss_zero:0.00035793
# epoch 11 loss_pde:0.01035635, loss_ic:0.00011398,loss_symetry:0.00076483,loss:0.01178162,loss_zero:0.00028550
# epoch 11 loss_pde:0.00998031, loss_ic:0.00012420,loss_symetry:0.00070312,loss:0.01154664,loss_zero:0.00032430
# epoch 11 loss_pde:0.00977019, loss_ic:0.00011757,loss_symetry:0.00062847,loss:0.01128260,loss_zero:0.00033675
# epoch 11 loss_pde:0.00961241, loss_ic:0.00011986,loss_symetry:0.00058390,loss:0.01117870,loss_zero:0.00036770
# epoch 11 loss_pde:0.00958624, loss_ic:0.00011493,loss_symetry:0.00059548,loss:0.01130242,loss_zero:0.00056689
# epoch 11 loss_pde:0.00952424, loss_ic:0.00011476,loss_symetry:0.00057193,loss:0.01109160,loss_zero:0.00041976
# epoch 11 loss_pde:0.00947703, loss_ic:0.00011021,loss_symetry:0.00058177,loss:0.01101516,loss_zero:0.00043605
# epoch 11 loss_pde:0.00947063, loss_ic:0.00010831,loss_symetry:0.00059222,loss:0.01097635,loss_zero:0.00042257
# epoch 11 loss_pde:0.00954715, loss_ic:0.00009773,loss_symetry:0.00060011,loss:0.01095324,loss_zero:0.00042882
# epoch 11 loss_pde:0.00953310, loss_ic:0.00009708,loss_symetry:0.00060523,loss:0.01093449,loss_zero:0.00043055
# epoch 11 loss_pde:0.00954355, loss_ic:0.00009214,loss_symetry:0.00062176,loss:0.01090515,loss_zero:0.00044016
# epoch 11 loss_pde:0.00953069, loss_ic:0.00008953,loss_symetry:0.00063644,loss:0.01088625,loss_zero:0.00046026
# epoch 11 loss_pde:0.00950886, loss_ic:0.00008824,loss_symetry:0.00065391,loss:0.01085441,loss_zero:0.00046311
# epoch 11 loss_pde:0.00945125, loss_ic:0.00008811,loss_symetry:0.00067358,loss:0.01080289,loss_zero:0.00047049
# epoch 11 loss_pde:0.00940873, loss_ic:0.00009006,loss_symetry:0.00068251,loss:0.01076908,loss_zero:0.00045979
# epoch 11 loss_pde:0.00936946, loss_ic:0.00009070,loss_symetry:0.00068926,loss:0.01072928,loss_zero:0.00045286
# epoch 11 loss_pde:0.00933996, loss_ic:0.00008929,loss_symetry:0.00071389,loss:0.01066593,loss_zero:0.00043309
# epoch 11 loss_pde:0.00929162, loss_ic:0.00008530,loss_symetry:0.00075378,loss:0.01058041,loss_zero:0.00043581
# epoch 11 loss_pde:0.00935551, loss_ic:0.00007806,loss_symetry:0.00084762,loss:0.01051125,loss_zero:0.00037510
# epoch 11 loss_pde:0.00923638, loss_ic:0.00007790,loss_symetry:0.00087988,loss:0.01041020,loss_zero:0.00039478
# epoch 11 loss_pde:0.00907479, loss_ic:0.00008547,loss_symetry:0.00090248,loss:0.01033126,loss_zero:0.00040175
# epoch 11 loss_pde:0.00904004, loss_ic:0.00007792,loss_symetry:0.00092573,loss:0.01022994,loss_zero:0.00041067
# epoch 11 loss_pde:0.00875093, loss_ic:0.00009864,loss_symetry:0.00093734,loss:0.01009236,loss_zero:0.00035504
# epoch 11 loss_pde:0.00841034, loss_ic:0.00011447,loss_symetry:0.00099904,loss:0.00992925,loss_zero:0.00037425
# epoch 11 loss_pde:0.00838678, loss_ic:0.00010409,loss_symetry:0.00091745,loss:0.00966943,loss_zero:0.00024170
# epoch 11 loss_pde:0.00839476, loss_ic:0.00008857,loss_symetry:0.00090157,loss:0.00954639,loss_zero:0.00026596
# epoch 11 loss_pde:0.00815141, loss_ic:0.00010628,loss_symetry:0.00089202,loss:0.00948455,loss_zero:0.00027036
# epoch 11 loss_pde:0.00814954, loss_ic:0.00010387,loss_symetry:0.00088939,loss:0.00945650,loss_zero:0.00026830
# epoch 11 loss_pde:0.00811523, loss_ic:0.00010622,loss_symetry:0.00086491,loss:0.00937664,loss_zero:0.00019921
# epoch 11: loss 0.012601
# epoch 12 loss_pde:0.00811523, loss_ic:0.00010622,loss_symetry:0.00086491,loss:0.00937664,loss_zero:0.00019921
# epoch 12 loss_pde:0.00809904, loss_ic:0.00010329,loss_symetry:0.00082158,loss:0.00931651,loss_zero:0.00018462
# epoch 12 loss_pde:0.00816036, loss_ic:0.00008965,loss_symetry:0.00072196,loss:0.00920741,loss_zero:0.00015051
# epoch 12 loss_pde:0.00817783, loss_ic:0.00008439,loss_symetry:0.00070084,loss:0.00915849,loss_zero:0.00013681
# epoch 12 loss_pde:0.00822609, loss_ic:0.00007429,loss_symetry:0.00070856,loss:0.00909147,loss_zero:0.00012245
# epoch 12 loss_pde:0.00823925, loss_ic:0.00006830,loss_symetry:0.00070147,loss:0.00901754,loss_zero:0.00009527
# epoch 12 loss_pde:0.00818235, loss_ic:0.00007042,loss_symetry:0.00068672,loss:0.00895758,loss_zero:0.00007101
# epoch 12 loss_pde:0.00816279, loss_ic:0.00006927,loss_symetry:0.00065585,loss:0.00892609,loss_zero:0.00007062
# epoch 12 loss_pde:0.00813014, loss_ic:0.00006872,loss_symetry:0.00062754,loss:0.00888720,loss_zero:0.00006983
# epoch 12 loss_pde:0.00809926, loss_ic:0.00006939,loss_symetry:0.00062694,loss:0.00886791,loss_zero:0.00007479
# epoch 12 loss_pde:0.00811075, loss_ic:0.00006615,loss_symetry:0.00063683,loss:0.00884689,loss_zero:0.00007469
# epoch 12 loss_pde:0.00810688, loss_ic:0.00006417,loss_symetry:0.00064997,loss:0.00881949,loss_zero:0.00007087
# epoch 12 loss_pde:0.00809004, loss_ic:0.00006266,loss_symetry:0.00066647,loss:0.00877644,loss_zero:0.00005978
# epoch 12 loss_pde:0.00803037, loss_ic:0.00006387,loss_symetry:0.00067540,loss:0.00871140,loss_zero:0.00004233
# epoch 12 loss_pde:0.00793405, loss_ic:0.00006672,loss_symetry:0.00069201,loss:0.00863487,loss_zero:0.00003361
# epoch 12 loss_pde:0.00775121, loss_ic:0.00007822,loss_symetry:0.00066486,loss:0.00855657,loss_zero:0.00002319
# epoch 12 loss_pde:0.00769133, loss_ic:0.00008322,loss_symetry:0.00067678,loss:0.00856713,loss_zero:0.00004361
# epoch 12 loss_pde:0.00767586, loss_ic:0.00007784,loss_symetry:0.00065396,loss:0.00847550,loss_zero:0.00002127
# epoch 12 loss_pde:0.00763273, loss_ic:0.00007157,loss_symetry:0.00064096,loss:0.00836742,loss_zero:0.00001900
# epoch 12 loss_pde:0.00755089, loss_ic:0.00006087,loss_symetry:0.00072808,loss:0.00817932,loss_zero:0.00001976
# epoch 12 loss_pde:0.00751261, loss_ic:0.00005349,loss_symetry:0.00079189,loss:0.00805583,loss_zero:0.00000828
# epoch 12 loss_pde:0.00741945, loss_ic:0.00005326,loss_symetry:0.00095157,loss:0.00798170,loss_zero:0.00002965
# epoch 12 loss_pde:0.00742367, loss_ic:0.00005012,loss_symetry:0.00088663,loss:0.00794124,loss_zero:0.00001635
# epoch 12 loss_pde:0.00733031, loss_ic:0.00004815,loss_symetry:0.00091876,loss:0.00782254,loss_zero:0.00001069
# epoch 12 loss_pde:0.00722883, loss_ic:0.00004843,loss_symetry:0.00090925,loss:0.00773210,loss_zero:0.00001893
# epoch 12 loss_pde:0.00714042, loss_ic:0.00004863,loss_symetry:0.00095168,loss:0.00764019,loss_zero:0.00001347
# epoch 12 loss_pde:0.00702790, loss_ic:0.00005935,loss_symetry:0.00105690,loss:0.00764020,loss_zero:0.00001884
# epoch 12 loss_pde:0.00705222, loss_ic:0.00005062,loss_symetry:0.00099175,loss:0.00756886,loss_zero:0.00001047
# epoch 12 loss_pde:0.00694257, loss_ic:0.00004825,loss_symetry:0.00102445,loss:0.00743480,loss_zero:0.00000972
# epoch 12 loss_pde:0.00688326, loss_ic:0.00006160,loss_symetry:0.00078645,loss:0.00756889,loss_zero:0.00006965
# epoch 12 loss_pde:0.00682288, loss_ic:0.00004427,loss_symetry:0.00089141,loss:0.00728694,loss_zero:0.00002140
# epoch 12 loss_pde:0.00676327, loss_ic:0.00003406,loss_symetry:0.00077977,loss:0.00714148,loss_zero:0.00003758
# epoch 12 loss_pde:0.00632765, loss_ic:0.00005427,loss_symetry:0.00078914,loss:0.00687733,loss_zero:0.00000703
# epoch 12 loss_pde:0.00627240, loss_ic:0.00004740,loss_symetry:0.00092335,loss:0.00675951,loss_zero:0.00001308
# epoch 12 loss_pde:0.00617616, loss_ic:0.00003966,loss_symetry:0.00073876,loss:0.00659634,loss_zero:0.00002362
# epoch 12: loss 0.009377
# epoch 13 loss_pde:0.00617616, loss_ic:0.00003966,loss_symetry:0.00073876,loss:0.00659634,loss_zero:0.00002362
# epoch 13 loss_pde:0.00622662, loss_ic:0.00004472,loss_symetry:0.00077595,loss:0.00668890,loss_zero:0.00001511
# epoch 13 loss_pde:0.00615684, loss_ic:0.00003851,loss_symetry:0.00073285,loss:0.00655775,loss_zero:0.00001579
# epoch 13 loss_pde:0.00592276, loss_ic:0.00005655,loss_symetry:0.00081716,loss:0.00651652,loss_zero:0.00002830
# epoch 13 loss_pde:0.00598028, loss_ic:0.00004662,loss_symetry:0.00080895,loss:0.00646539,loss_zero:0.00001891
# epoch 13 loss_pde:0.00597785, loss_ic:0.00004291,loss_symetry:0.00073824,loss:0.00643008,loss_zero:0.00002313
# epoch 13 loss_pde:0.00590511, loss_ic:0.00004719,loss_symetry:0.00073879,loss:0.00640097,loss_zero:0.00002400
# epoch 13 loss_pde:0.00581882, loss_ic:0.00005206,loss_symetry:0.00075049,loss:0.00636024,loss_zero:0.00002083
# epoch 13 loss_pde:0.00577541, loss_ic:0.00005050,loss_symetry:0.00072403,loss:0.00630088,loss_zero:0.00002046
# epoch 13 loss_pde:0.00579593, loss_ic:0.00004189,loss_symetry:0.00072769,loss:0.00623045,loss_zero:0.00001565
# epoch 13 loss_pde:0.00574527, loss_ic:0.00004394,loss_symetry:0.00061893,loss:0.00620162,loss_zero:0.00001695
# epoch 13 loss_pde:0.00578130, loss_ic:0.00003639,loss_symetry:0.00067534,loss:0.00616758,loss_zero:0.00002242
# epoch 13 loss_pde:0.00578261, loss_ic:0.00003552,loss_symetry:0.00066946,loss:0.00615225,loss_zero:0.00001444
# epoch 13 loss_pde:0.00576252, loss_ic:0.00003615,loss_symetry:0.00066109,loss:0.00614094,loss_zero:0.00001697
# epoch 13 loss_pde:0.00574620, loss_ic:0.00003603,loss_symetry:0.00064250,loss:0.00612896,loss_zero:0.00002249
# epoch 13 loss_pde:0.00572727, loss_ic:0.00003678,loss_symetry:0.00065107,loss:0.00612026,loss_zero:0.00002523
# epoch 13 loss_pde:0.00572044, loss_ic:0.00003615,loss_symetry:0.00064818,loss:0.00611195,loss_zero:0.00003002
# epoch 13 loss_pde:0.00568740, loss_ic:0.00003828,loss_symetry:0.00064873,loss:0.00610087,loss_zero:0.00003070
# epoch 13 loss_pde:0.00563473, loss_ic:0.00004136,loss_symetry:0.00063738,loss:0.00608077,loss_zero:0.00003249
# epoch 13 loss_pde:0.00556304, loss_ic:0.00004510,loss_symetry:0.00061426,loss:0.00604828,loss_zero:0.00003422
# epoch 13 loss_pde:0.00542184, loss_ic:0.00005180,loss_symetry:0.00055307,loss:0.00597798,loss_zero:0.00003809
# epoch 13 loss_pde:0.00532461, loss_ic:0.00005537,loss_symetry:0.00047537,loss:0.00592062,loss_zero:0.00004233
# epoch 13 loss_pde:0.00521718, loss_ic:0.00005213,loss_symetry:0.00046692,loss:0.00576950,loss_zero:0.00003101
# epoch 13 loss_pde:0.00515354, loss_ic:0.00003875,loss_symetry:0.00046574,loss:0.00556887,loss_zero:0.00002780
# epoch 13 loss_pde:0.00509297, loss_ic:0.00003679,loss_symetry:0.00044575,loss:0.00548239,loss_zero:0.00002155
# epoch 13 loss_pde:0.00508879, loss_ic:0.00003127,loss_symetry:0.00044728,loss:0.00542791,loss_zero:0.00002644
# epoch 13 loss_pde:0.00504299, loss_ic:0.00003104,loss_symetry:0.00045550,loss:0.00537600,loss_zero:0.00002259
# epoch 13 loss_pde:0.00495815, loss_ic:0.00003155,loss_symetry:0.00045866,loss:0.00529492,loss_zero:0.00002124
# epoch 13 loss_pde:0.00485591, loss_ic:0.00002924,loss_symetry:0.00046153,loss:0.00517018,loss_zero:0.00002191
# epoch 13 loss_pde:0.00473412, loss_ic:0.00002815,loss_symetry:0.00045628,loss:0.00505925,loss_zero:0.00004365
# epoch 13 loss_pde:0.00472806, loss_ic:0.00002717,loss_symetry:0.00045158,loss:0.00503703,loss_zero:0.00003724
# epoch 13 loss_pde:0.00460910, loss_ic:0.00003170,loss_symetry:0.00047075,loss:0.00498389,loss_zero:0.00005782
# epoch 13: loss 0.006596
# epoch 14 loss_pde:0.00460910, loss_ic:0.00003170,loss_symetry:0.00047075,loss:0.00498389,loss_zero:0.00005782
# epoch 14 loss_pde:0.00469997, loss_ic:0.00002519,loss_symetry:0.00048393,loss:0.00499816,loss_zero:0.00004634
# epoch 14 loss_pde:0.00463945, loss_ic:0.00002749,loss_symetry:0.00047539,loss:0.00496642,loss_zero:0.00005205
# ...
# epoch 40 loss_pde:0.00012626, loss_ic:0.00000040,loss_symetry:0.00049719,loss:0.00013440,loss_zero:0.00000411
# epoch 40 loss_pde:0.00012625, loss_ic:0.00000040,loss_symetry:0.00049806,loss:0.00013436,loss_zero:0.00000408
# epoch 40 loss_pde:0.00012627, loss_ic:0.00000040,loss_symetry:0.00049944,loss:0.00013430,loss_zero:0.00000407
# epoch 40 loss_pde:0.00012627, loss_ic:0.00000039,loss_symetry:0.00050034,loss:0.00013424,loss_zero:0.00000407
# epoch 40 loss_pde:0.00012632, loss_ic:0.00000038,loss_symetry:0.00050059,loss:0.00013419,loss_zero:0.00000409
# epoch 40 loss_pde:0.00012631, loss_ic:0.00000037,loss_symetry:0.00050028,loss:0.00013415,loss_zero:0.00000410
# epoch 40 loss_pde:0.00012632, loss_ic:0.00000037,loss_symetry:0.00049962,loss:0.00013408,loss_zero:0.00000408
# epoch 40 loss_pde:0.00012627, loss_ic:0.00000037,loss_symetry:0.00049849,loss:0.00013396,loss_zero:0.00000403
# epoch 40 loss_pde:0.00012625, loss_ic:0.00000036,loss_symetry:0.00049653,loss:0.00013376,loss_zero:0.00000394
# epoch 40 loss_pde:0.00012603, loss_ic:0.00000038,loss_symetry:0.00049275,loss:0.00013343,loss_zero:0.00000364
# epoch 40 loss_pde:0.00012575, loss_ic:0.00000037,loss_symetry:0.00049053,loss:0.00013305,loss_zero:0.00000360
# epoch 40 loss_pde:0.00012534, loss_ic:0.00000035,loss_symetry:0.00048632,loss:0.00013226,loss_zero:0.00000345
# epoch 40 loss_pde:0.00012488, loss_ic:0.00000032,loss_symetry:0.00048172,loss:0.00013153,loss_zero:0.00000342
# epoch 40 loss_pde:0.00012396, loss_ic:0.00000032,loss_symetry:0.00047676,loss:0.00013059,loss_zero:0.00000345
# epoch 40 loss_pde:0.00012338, loss_ic:0.00000031,loss_symetry:0.00047027,loss:0.00012996,loss_zero:0.00000352
# epoch 40: loss 0.000137
# epoch 41 loss_pde:0.00012338, loss_ic:0.00000031,loss_symetry:0.00047027,loss:0.00012996,loss_zero:0.00000352
# epoch 41 loss_pde:0.00012233, loss_ic:0.00000026,loss_symetry:0.00047205,loss:0.00012870,loss_zero:0.00000379
# epoch 41 loss_pde:0.00012154, loss_ic:0.00000033,loss_symetry:0.00047110,loss:0.00012820,loss_zero:0.00000340
# epoch 41 loss_pde:0.00012092, loss_ic:0.00000028,loss_symetry:0.00047204,loss:0.00012711,loss_zero:0.00000342
# epoch 41 loss_pde:0.00012069, loss_ic:0.00000027,loss_symetry:0.00046687,loss:0.00012686,loss_zero:0.00000344
# epoch 41 loss_pde:0.00012033, loss_ic:0.00000025,loss_symetry:0.00046767,loss:0.00012619,loss_zero:0.00000331
# epoch 41 loss_pde:0.00011991, loss_ic:0.00000026,loss_symetry:0.00046453,loss:0.00012577,loss_zero:0.00000324
# epoch 41 loss_pde:0.00011964, loss_ic:0.00000026,loss_symetry:0.00046309,loss:0.00012535,loss_zero:0.00000314
# epoch 41 loss_pde:0.00011932, loss_ic:0.00000025,loss_symetry:0.00046004,loss:0.00012497,loss_zero:0.00000316
# epoch 41 loss_pde:0.00011916, loss_ic:0.00000025,loss_symetry:0.00045939,loss:0.00012480,loss_zero:0.00000316
# epoch 41 loss_pde:0.00011908, loss_ic:0.00000025,loss_symetry:0.00046025,loss:0.00012467,loss_zero:0.00000310
# epoch 41 loss_pde:0.00011891, loss_ic:0.00000026,loss_symetry:0.00046193,loss:0.00012463,loss_zero:0.00000313
# epoch 41 loss_pde:0.00011892, loss_ic:0.00000026,loss_symetry:0.00046097,loss:0.00012458,loss_zero:0.00000308
# epoch 41 loss_pde:0.00011904, loss_ic:0.00000025,loss_symetry:0.00046103,loss:0.00012455,loss_zero:0.00000305
# epoch 41 loss_pde:0.00011902, loss_ic:0.00000025,loss_symetry:0.00046062,loss:0.00012451,loss_zero:0.00000304
# epoch 41 loss_pde:0.00011900, loss_ic:0.00000024,loss_symetry:0.00046003,loss:0.00012447,loss_zero:0.00000303
# epoch 41 loss_pde:0.00011903, loss_ic:0.00000024,loss_symetry:0.00045932,loss:0.00012442,loss_zero:0.00000302
# epoch 41 loss_pde:0.00011894, loss_ic:0.00000024,loss_symetry:0.00045905,loss:0.00012437,loss_zero:0.00000304
# epoch 41 loss_pde:0.00011929, loss_ic:0.00000025,loss_symetry:0.00045437,loss:0.00012479,loss_zero:0.00000298
# epoch 41 loss_pde:0.00011891, loss_ic:0.00000024,loss_symetry:0.00045814,loss:0.00012434,loss_zero:0.00000302
# epoch 41 loss_pde:0.00011899, loss_ic:0.00000023,loss_symetry:0.00045680,loss:0.00012430,loss_zero:0.00000298
# epoch 41 loss_pde:0.00011897, loss_ic:0.00000023,loss_symetry:0.00045716,loss:0.00012425,loss_zero:0.00000295
# epoch 41 loss_pde:0.00011902, loss_ic:0.00000023,loss_symetry:0.00045789,loss:0.00012419,loss_zero:0.00000289
# epoch 41 loss_pde:0.00011905, loss_ic:0.00000022,loss_symetry:0.00045987,loss:0.00012412,loss_zero:0.00000288
# epoch 41 loss_pde:0.00011907, loss_ic:0.00000021,loss_symetry:0.00046119,loss:0.00012405,loss_zero:0.00000284
# epoch 41 loss_pde:0.00011907, loss_ic:0.00000021,loss_symetry:0.00046297,loss:0.00012395,loss_zero:0.00000280
# epoch 41 loss_pde:0.00011884, loss_ic:0.00000022,loss_symetry:0.00046295,loss:0.00012382,loss_zero:0.00000275
# epoch 41 loss_pde:0.00011879, loss_ic:0.00000022,loss_symetry:0.00046331,loss:0.00012368,loss_zero:0.00000268
# epoch 41 loss_pde:0.00011864, loss_ic:0.00000023,loss_symetry:0.00046161,loss:0.00012357,loss_zero:0.00000259
# epoch 41 loss_pde:0.00011825, loss_ic:0.00000026,loss_symetry:0.00046174,loss:0.00012346,loss_zero:0.00000258
# epoch 41 loss_pde:0.00011818, loss_ic:0.00000026,loss_symetry:0.00046098,loss:0.00012333,loss_zero:0.00000252
# epoch 41 loss_pde:0.00011813, loss_ic:0.00000027,loss_symetry:0.00045988,loss:0.00012322,loss_zero:0.00000244
# epoch 41: loss 0.000130
# epoch 42 loss_pde:0.00011813, loss_ic:0.00000027,loss_symetry:0.00045988,loss:0.00012322,loss_zero:0.00000244
# epoch 42 loss_pde:0.00011807, loss_ic:0.00000027,loss_symetry:0.00046013,loss:0.00012310,loss_zero:0.00000235
# epoch 42 loss_pde:0.00011786, loss_ic:0.00000028,loss_symetry:0.00045964,loss:0.00012291,loss_zero:0.00000227
# epoch 42 loss_pde:0.00011747, loss_ic:0.00000029,loss_symetry:0.00045929,loss:0.00012255,loss_zero:0.00000213
# epoch 42 loss_pde:0.00011682, loss_ic:0.00000032,loss_symetry:0.00046014,loss:0.00012209,loss_zero:0.00000206
# epoch 42 loss_pde:0.00011602, loss_ic:0.00000036,loss_symetry:0.00045938,loss:0.00012153,loss_zero:0.00000192
# epoch 42 loss_pde:0.00011561, loss_ic:0.00000035,loss_symetry:0.00045856,loss:0.00012104,loss_zero:0.00000189
# epoch 42 loss_pde:0.00011487, loss_ic:0.00000032,loss_symetry:0.00046062,loss:0.00012046,loss_zero:0.00000234
# epoch 42 loss_pde:0.00011433, loss_ic:0.00000032,loss_symetry:0.00045761,loss:0.00011964,loss_zero:0.00000215
# epoch 42 loss_pde:0.00011417, loss_ic:0.00000031,loss_symetry:0.00045600,loss:0.00011925,loss_zero:0.00000199
# epoch 42 loss_pde:0.00011374, loss_ic:0.00000031,loss_symetry:0.00045345,loss:0.00011890,loss_zero:0.00000204
# epoch 42 loss_pde:0.00011300, loss_ic:0.00000033,loss_symetry:0.00044998,loss:0.00011840,loss_zero:0.00000212
# epoch 42 loss_pde:0.00011251, loss_ic:0.00000033,loss_symetry:0.00044851,loss:0.00011800,loss_zero:0.00000217
# epoch 42 loss_pde:0.00011206, loss_ic:0.00000034,loss_symetry:0.00044485,loss:0.00011760,loss_zero:0.00000211
# epoch 42 loss_pde:0.00011184, loss_ic:0.00000033,loss_symetry:0.00044765,loss:0.00011726,loss_zero:0.00000210
# epoch 42 loss_pde:0.00011183, loss_ic:0.00000031,loss_symetry:0.00044949,loss:0.00011701,loss_zero:0.00000205
# epoch 42 loss_pde:0.00011171, loss_ic:0.00000029,loss_symetry:0.00045365,loss:0.00011665,loss_zero:0.00000206
# epoch 42 loss_pde:0.00011142, loss_ic:0.00000027,loss_symetry:0.00045401,loss:0.00011617,loss_zero:0.00000210
# epoch 42 loss_pde:0.00011106, loss_ic:0.00000022,loss_symetry:0.00045474,loss:0.00011543,loss_zero:0.00000213
# epoch 42 loss_pde:0.00011077, loss_ic:0.00000018,loss_symetry:0.00045891,loss:0.00011456,loss_zero:0.00000203
# epoch 42 loss_pde:0.00010990, loss_ic:0.00000016,loss_symetry:0.00046148,loss:0.00011351,loss_zero:0.00000200
# epoch 42 loss_pde:0.00010920, loss_ic:0.00000019,loss_symetry:0.00046283,loss:0.00011277,loss_zero:0.00000168
# epoch 42 loss_pde:0.00010829, loss_ic:0.00000019,loss_symetry:0.00046161,loss:0.00011185,loss_zero:0.00000161
# epoch 42 loss_pde:0.00010705, loss_ic:0.00000027,loss_symetry:0.00046766,loss:0.00011122,loss_zero:0.00000152
# epoch 42 loss_pde:0.00010597, loss_ic:0.00000027,loss_symetry:0.00046988,loss:0.00011023,loss_zero:0.00000152
# epoch 42 loss_pde:0.00010502, loss_ic:0.00000030,loss_symetry:0.00047469,loss:0.00010948,loss_zero:0.00000147
# epoch 42 loss_pde:0.00010422, loss_ic:0.00000032,loss_symetry:0.00048057,loss:0.00010891,loss_zero:0.00000146
# epoch 42 loss_pde:0.00010359, loss_ic:0.00000033,loss_symetry:0.00048649,loss:0.00010828,loss_zero:0.00000135
# epoch 42 loss_pde:0.00010318, loss_ic:0.00000032,loss_symetry:0.00048883,loss:0.00010792,loss_zero:0.00000152
# epoch 42 loss_pde:0.00010325, loss_ic:0.00000031,loss_symetry:0.00048978,loss:0.00010768,loss_zero:0.00000132
# epoch 42 loss_pde:0.00010346, loss_ic:0.00000029,loss_symetry:0.00048931,loss:0.00010754,loss_zero:0.00000122
# epoch 42: loss 0.000123
# epoch 43 loss_pde:0.00010346, loss_ic:0.00000029,loss_symetry:0.00048931,loss:0.00010754,loss_zero:0.00000122
# epoch 43 loss_pde:0.00010324, loss_ic:0.00000029,loss_symetry:0.00048868,loss:0.00010742,loss_zero:0.00000129
# epoch 43 loss_pde:0.00010300, loss_ic:0.00000029,loss_symetry:0.00048973,loss:0.00010730,loss_zero:0.00000136
# epoch 43 loss_pde:0.00010289, loss_ic:0.00000028,loss_symetry:0.00049022,loss:0.00010716,loss_zero:0.00000142
# epoch 43 loss_pde:0.00010268, loss_ic:0.00000028,loss_symetry:0.00049132,loss:0.00010698,loss_zero:0.00000145
# epoch 43 loss_pde:0.00010240, loss_ic:0.00000029,loss_symetry:0.00049365,loss:0.00010672,loss_zero:0.00000148
# epoch 43 loss_pde:0.00010229, loss_ic:0.00000029,loss_symetry:0.00049322,loss:0.00010660,loss_zero:0.00000146
# epoch 43 loss_pde:0.00010195, loss_ic:0.00000030,loss_symetry:0.00049323,loss:0.00010646,loss_zero:0.00000151
# epoch 43 loss_pde:0.00010183, loss_ic:0.00000030,loss_symetry:0.00049372,loss:0.00010638,loss_zero:0.00000152
# epoch 43 loss_pde:0.00010160, loss_ic:0.00000031,loss_symetry:0.00049346,loss:0.00010629,loss_zero:0.00000155
# epoch 43 loss_pde:0.00010159, loss_ic:0.00000031,loss_symetry:0.00049320,loss:0.00010625,loss_zero:0.00000156
# epoch 43 loss_pde:0.00010152, loss_ic:0.00000031,loss_symetry:0.00049363,loss:0.00010612,loss_zero:0.00000153
# epoch 43 loss_pde:0.00010142, loss_ic:0.00000031,loss_symetry:0.00049420,loss:0.00010594,loss_zero:0.00000147
# epoch 43 loss_pde:0.00010143, loss_ic:0.00000030,loss_symetry:0.00049357,loss:0.00010577,loss_zero:0.00000136
# epoch 43 loss_pde:0.00010128, loss_ic:0.00000031,loss_symetry:0.00049284,loss:0.00010564,loss_zero:0.00000130
# epoch 43 loss_pde:0.00010100, loss_ic:0.00000032,loss_symetry:0.00049206,loss:0.00010552,loss_zero:0.00000130
# epoch 43 loss_pde:0.00010085, loss_ic:0.00000033,loss_symetry:0.00049061,loss:0.00010543,loss_zero:0.00000127
# epoch 43 loss_pde:0.00010066, loss_ic:0.00000034,loss_symetry:0.00049027,loss:0.00010532,loss_zero:0.00000128
# epoch 43 loss_pde:0.00010047, loss_ic:0.00000034,loss_symetry:0.00048923,loss:0.00010517,loss_zero:0.00000126
# epoch 43 loss_pde:0.00010039, loss_ic:0.00000034,loss_symetry:0.00048946,loss:0.00010506,loss_zero:0.00000125
# epoch 43 loss_pde:0.00010043, loss_ic:0.00000033,loss_symetry:0.00049010,loss:0.00010495,loss_zero:0.00000124
# epoch 43 loss_pde:0.00010057, loss_ic:0.00000031,loss_symetry:0.00048978,loss:0.00010486,loss_zero:0.00000121
# epoch 43 loss_pde:0.00010066, loss_ic:0.00000029,loss_symetry:0.00049027,loss:0.00010480,loss_zero:0.00000123
# epoch 43 loss_pde:0.00010071, loss_ic:0.00000028,loss_symetry:0.00048893,loss:0.00010475,loss_zero:0.00000121
# epoch 43 loss_pde:0.00010073, loss_ic:0.00000028,loss_symetry:0.00048791,loss:0.00010470,loss_zero:0.00000121
# epoch 43 loss_pde:0.00010077, loss_ic:0.00000027,loss_symetry:0.00048723,loss:0.00010466,loss_zero:0.00000122
# epoch 43 loss_pde:0.00010082, loss_ic:0.00000026,loss_symetry:0.00048668,loss:0.00010458,loss_zero:0.00000119
# epoch 43 loss_pde:0.00010082, loss_ic:0.00000025,loss_symetry:0.00048570,loss:0.00010446,loss_zero:0.00000113
# epoch 43 loss_pde:0.00010089, loss_ic:0.00000023,loss_symetry:0.00048483,loss:0.00010424,loss_zero:0.00000107
# epoch 43 loss_pde:0.00010066, loss_ic:0.00000023,loss_symetry:0.00048394,loss:0.00010398,loss_zero:0.00000102
# epoch 43 loss_pde:0.00010019, loss_ic:0.00000024,loss_symetry:0.00048347,loss:0.00010365,loss_zero:0.00000103
# epoch 43: loss 0.000108
# epoch 44 loss_pde:0.00010019, loss_ic:0.00000024,loss_symetry:0.00048347,loss:0.00010365,loss_zero:0.00000103
# epoch 44 loss_pde:0.00010010, loss_ic:0.00000023,loss_symetry:0.00047977,loss:0.00010341,loss_zero:0.00000100
# epoch 44 loss_pde:0.00009963, loss_ic:0.00000024,loss_symetry:0.00047852,loss:0.00010313,loss_zero:0.00000107
# epoch 44 loss_pde:0.00009966, loss_ic:0.00000022,loss_symetry:0.00047625,loss:0.00010291,loss_zero:0.00000103
# epoch 44 loss_pde:0.00009990, loss_ic:0.00000019,loss_symetry:0.00047394,loss:0.00010276,loss_zero:0.00000095
# epoch 44 loss_pde:0.00009989, loss_ic:0.00000018,loss_symetry:0.00047293,loss:0.00010259,loss_zero:0.00000089
# epoch 44 loss_pde:0.00009961, loss_ic:0.00000019,loss_symetry:0.00047363,loss:0.00010237,loss_zero:0.00000086
# epoch 44 loss_pde:0.00009926, loss_ic:0.00000020,loss_symetry:0.00047248,loss:0.00010203,loss_zero:0.00000079
# epoch 44 loss_pde:0.00009925, loss_ic:0.00000018,loss_symetry:0.00047298,loss:0.00010178,loss_zero:0.00000073
# epoch 44 loss_pde:0.00009909, loss_ic:0.00000017,loss_symetry:0.00047174,loss:0.00010157,loss_zero:0.00000073
# epoch 44 loss_pde:0.00009898, loss_ic:0.00000017,loss_symetry:0.00046874,loss:0.00010134,loss_zero:0.00000070
# epoch 44 loss_pde:0.00009875, loss_ic:0.00000017,loss_symetry:0.00046955,loss:0.00010122,loss_zero:0.00000078
# epoch 44 loss_pde:0.00009869, loss_ic:0.00000016,loss_symetry:0.00046867,loss:0.00010108,loss_zero:0.00000075
# epoch 44 loss_pde:0.00009842, loss_ic:0.00000018,loss_symetry:0.00046799,loss:0.00010094,loss_zero:0.00000070
# epoch 44 loss_pde:0.00009814, loss_ic:0.00000020,loss_symetry:0.00046767,loss:0.00010079,loss_zero:0.00000069
# epoch 44 loss_pde:0.00009777, loss_ic:0.00000022,loss_symetry:0.00046745,loss:0.00010065,loss_zero:0.00000069
# epoch 44 loss_pde:0.00009760, loss_ic:0.00000023,loss_symetry:0.00046760,loss:0.00010057,loss_zero:0.00000068
# epoch 44 loss_pde:0.00009750, loss_ic:0.00000023,loss_symetry:0.00046607,loss:0.00010048,loss_zero:0.00000069
# epoch 44 loss_pde:0.00009745, loss_ic:0.00000022,loss_symetry:0.00046543,loss:0.00010036,loss_zero:0.00000068
# epoch 44 loss_pde:0.00009733, loss_ic:0.00000022,loss_symetry:0.00046402,loss:0.00010020,loss_zero:0.00000065
# epoch 44 loss_pde:0.00009725, loss_ic:0.00000022,loss_symetry:0.00046360,loss:0.00010006,loss_zero:0.00000064
# epoch 44 loss_pde:0.00009680, loss_ic:0.00000027,loss_symetry:0.00046222,loss:0.00010017,loss_zero:0.00000064
# epoch 44 loss_pde:0.00009701, loss_ic:0.00000024,loss_symetry:0.00046312,loss:0.00010000,loss_zero:0.00000063
# epoch 44 loss_pde:0.00009689, loss_ic:0.00000024,loss_symetry:0.00046333,loss:0.00009986,loss_zero:0.00000062
# epoch 44 loss_pde:0.00009674, loss_ic:0.00000023,loss_symetry:0.00046526,loss:0.00009968,loss_zero:0.00000060
# epoch 44 loss_pde:0.00009663, loss_ic:0.00000023,loss_symetry:0.00046619,loss:0.00009950,loss_zero:0.00000057
# epoch 44 loss_pde:0.00009652, loss_ic:0.00000022,loss_symetry:0.00046750,loss:0.00009932,loss_zero:0.00000058
# epoch 44 loss_pde:0.00009622, loss_ic:0.00000023,loss_symetry:0.00046860,loss:0.00009913,loss_zero:0.00000059
# epoch 44 loss_pde:0.00009616, loss_ic:0.00000023,loss_symetry:0.00046544,loss:0.00009897,loss_zero:0.00000056
# epoch 44 loss_pde:0.00009589, loss_ic:0.00000024,loss_symetry:0.00046361,loss:0.00009883,loss_zero:0.00000055
# epoch 44 loss_pde:0.00009551, loss_ic:0.00000026,loss_symetry:0.00045994,loss:0.00009865,loss_zero:0.00000055
# epoch 44 loss_pde:0.00009509, loss_ic:0.00000028,loss_symetry:0.00045669,loss:0.00009848,loss_zero:0.00000055
# epoch 44: loss 0.000104
# epoch 45 loss_pde:0.00009509, loss_ic:0.00000028,loss_symetry:0.00045669,loss:0.00009848,loss_zero:0.00000055
# epoch 45 loss_pde:0.00009492, loss_ic:0.00000029,loss_symetry:0.00045170,loss:0.00009840,loss_zero:0.00000056
# epoch 45 loss_pde:0.00009464, loss_ic:0.00000030,loss_symetry:0.00045253,loss:0.00009827,loss_zero:0.00000061

# %%
###***************PINNs-Original***************###

L2_var_o = np.zeros((Mesh_num,3))
Linf_var_o = np.zeros((Mesh_num ,3))
L2_shock_var_o = np.zeros((Mesh_num,3))
L2_smooth_var_o = np.zeros((Mesh_num,3))
Loss_var_o = np.zeros((Mesh_num,3))
Mesh_i = 0
#f= open("result.dat", "w+") 
for nnode in Mesh:
#for nnode in [25,51]:
  f.write('###########nnode: %d ########### \n' % nnode)
#nnode = 25 
L2_smooth_ave = [] 
L2_shock_ave = [] 
L2_ave = []
L2_max_ave = []
loss_ave = []
starttime = time.time()
for i in range(num_seed):  
    seed = i 
    setup_seed(seed)
 #   f.write('****seed: %d ***** \n' % seed)
    #How to count the computing time


    def train(epoch):
        model.it = epoch
        def closure():
            optimizer.zero_grad()                                              
            loss_pde = model.loss_pde(x_int)                                   
            loss_ic = model.loss_ic(x_ic, u_ic)  
            loss_symetry = model.loss_symetry(x_int,x_int_mirror)  
            loss_zero = model.loss_zero(x_zero)
            loss = loss_pde + 10*loss_ic + loss_zero                                      

            print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f},loss_symetry:{loss_symetry:.8f},loss:{loss:.8f},loss_zero:{loss_zero:.8f}')
            #model.it = model.it + 1
            #outputfile = open('loss_history_burgers.dat','a+')
            #print(f'{model.it}  {loss_pde:.6f}  {loss_ic:.6f}  {loss:.6f}',file=outputfile)
            #outputfile.close() 
            loss.backward()
            return loss

        loss = optimizer.step(closure)
        loss_value = loss.item()
        print(f'epoch {epoch}: loss {loss_value:.6f}')
        return loss

    def gradients(outputs, inputs):
        return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

    def to_numpy(input):
        if isinstance(input, torch.Tensor):
            return input.detach().cpu().numpy()
        elif isinstance(input, np.ndarray):
            return input
        else:
            raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                            'np.ndarray, but got {}'.format(type(input)))

    def IC(x):
        N = len(x)
        u_init = np.zeros((x.shape[0]))                                                
        for i in range(N):
            u_init[i] = -np.sin(np.pi*(x[i,1]-1))
        return u_init

    class DNN(nn.Module):
        def __init__(self):
            super(DNN, self).__init__()
            self.net = nn.Sequential()                                                  
            self.net.add_module('Linear_layer_1', nn.Linear(2, 30))                     
            self.net.add_module('Tanh_layer_1', nn.Tanh())                              

            for num in range(2, 4):                                                     
                self.net.add_module('Linear_layer_%d' % (num), nn.Linear(30, 30))       
                self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 
            self.net.add_module('Linear_layer_final', nn.Linear(30, 1))                 

        def forward(self, x):
            return self.net(x)
        def loss_symetry(self, x,x_mirror):
            y = self.net(x)                                                
            y_mirror = self.net(x_mirror)                                                
            f = (((y + y_mirror))**2).mean() 
            return f

        def loss_zero(self, x_zero):
            y = self.net(x_zero)                                                
            f = ((y)**2).mean() 
            return f
        def loss_pde(self, x):
            y = self.net(x)                                                
            u = y[:, 0:1]

            U = u**2/2

            dU_g = gradients(U, x)[0]                                  
            U_x = dU_g[:, 1:]
            du_g = gradients(u, x)[0]                                 
            u_t,u_x = du_g[:, :1],du_g[:,1:]
            #d = 0.1*(abs(u_x)-u_x) + 1
            d = 1

            f = (((u_t + U_x)/d)**2).mean() 

            return f
        def res_pde(self,x):
            y = self.net(x)
            Res = np.zeros((x.shape[0]))                                  

            u = y[:, 0:1]
            U = u**2/2
            dU_g = gradients(U, x)[0]                                 
            U_x = dU_g[:, 1:]
            du_g = gradients(u, x)[0]                                  
            u_t,u_x = du_g[:, :1],du_g[:,1:]
            Res = (u_t + U_x)**2 
            return Res 

        def lambda_pde(self,x):
            y = self.net(x)
            Res = np.zeros((x.shape[0]))                                  

            u = y[:, 0:1]
            du_g = gradients(u, x)[0]                                  
            u_t,u_x = du_g[:, :1],du_g[:,1:]
            d = 0.1*(abs(u_x)-u_x) + 1
            return  d


        def loss_ic(self, x_ic, u_ic):
            y_ic = self.net(x_ic)                                                      
            u_ic_nn = y_ic[:, 0]
            loss_ics = ((u_ic_nn - u_ic) ** 2).mean()
            return loss_ics

    device = torch.device('cuda')                                      
    #device = torch.device('cpu')                                      
    num_x = nnode                                                        
    num_t =  nnode                                                       
    num_i_train = nnode                                          
    num_f_train =  nnode*nnode                                         
    x = np.linspace(0, 2, num_x)                                   
    t = np.linspace(0, 1, num_t)                                   
    t_grid, x_grid = np.meshgrid(t, x)                             
    T = t_grid.flatten()[:, None]                                  
    X = x_grid.flatten()[:, None]                                  

    x_zero = np.zeros((num_t, 2))
    x_zero[:,0] = t
    x_zero[:,1] = 1

    id_ic = np.random.choice(num_x, num_i_train, replace=False)    
    id_f = np.random.choice(num_x*num_t, num_f_train, replace=False)

    x_ic = x_grid[id_ic, 0][:, None]                               
    t_ic = t_grid[id_ic, 0][:, None]                               
    x_ic_train = np.hstack((t_ic, x_ic))                               
    u_ic_train = IC(x_ic_train)                 

    x_int = X[:, 0][id_f, None]                                        
    t_int = T[:, 0][id_f, None]                                        
    x_int_train = np.hstack((t_int, x_int))                            
    x_int_mirror = np.hstack((t_int, 2-x_int))                            

    u_ic_train = IC(x_ic_train)                 

    x_ic = torch.tensor(x_ic_train, dtype=torch.float32).to(device)
    x_int = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)
    x_int_mirror = torch.tensor(x_int_mirror, requires_grad=True, dtype=torch.float32).to(device)
    x_zero = torch.tensor(x_zero, requires_grad=True, dtype=torch.float32).to(device)
    u_ic = torch.tensor(u_ic_train, dtype=torch.float32).to(device)

    model = DNN().to(device)

    #lr = 0.001

    optimizer = torch.optim.LBFGS(model.parameters(), lr=lr, 
                                  max_iter = 30, 
                                  max_eval = None, 
                                  tolerance_grad = 1e-06, 
                                  tolerance_change = 1e-09, 
                                  history_size = 100, 
                                  line_search_fn = 'strong_wolfe')
    epochs = epochN
    tic = time.time()
    
    loss_test = 100.0
    num_epoch = 0
    for epoch in range(1, epochs+1):
      #if int(epoch/10) > num_epoch:
      #  loss_test = loss
      #  abs(loss - loss_test)
      loss=train(epoch)


    x = np.linspace(0.0, 2.0, nnode)                                  
    t = np.linspace(1.0, 1.0, 1)                                        
    t_grid, x_grid = np.meshgrid(t, x)                              
    T = t_grid.flatten()[:, None]                                   
    X = x_grid.flatten()[:, None]                                   
    x_test = np.hstack((T, X))                                      
    x_test = torch.tensor(x_test, requires_grad=True, dtype=torch.float32).to(device)
    u_pred = to_numpy(model(x_test))
    res = to_numpy(model.res_pde(x_test))
    d   = to_numpy(model.lambda_pde(x_test))


    y_e = Exact_burgers.Exact_Burgers(x)
    L2_error = np.sqrt(np.sum((u_pred[:,0]-y_e)**2)/nnode)
    #f.write('L2 error: %e\n' % L2_error)
    num = 0
    num_shock = 0
    sum = 0.0
    sum_shock = 0
    for i in range(nnode):
        if abs(x[i]-1)> 0.05:
            sum = sum +  np.sum((u_pred[i,0]-y_e[i])**2)
            num = num + 1
        #np.sqrt(np.sum((u_pred[:,0]-y_e)**2)/100)
        else:
            sum_shock = sum_shock +  np.sum((u_pred[i,0]-y_e[i])**2)
            num_shock = num_shock + 1
    sum = sum/num
    sum_shock = sum_shock/num_shock
    L2_error_smooth = np.sqrt(sum)
    L2_error_shock = np.sqrt(sum_shock)
    #f.write('L2_smooth error: %e\n' % L2_error_smooth)
    #f.write('L2_shock  error: %e\n' % L2_error_shock)
    L2_Max =  (np.max(np.abs(u_pred[:,0]-y_e)))
    #f.write('Max error: %e\n' % L2_Max )
    #f.write('Loss: %e\n' % loss)
    L2_max_ave.append(L2_Max)
    L2_ave.append(L2_error)
    L2_smooth_ave.append(L2_error_smooth)
    L2_shock_ave.append(L2_error_shock)
    loss_ave.append(to_numpy(loss))
    #loss_ave = loss_ave + loss

#  f.write('Linf ave, top, bottom %e %e %e\n' %(np.mean(L2_max_ave),np.max(L2_max_ave),np.min(L2_max_ave)))
#  f.write('L2 ave, top, bottom: %e %e %e \n' %(np.mean(L2_ave), np.max(L2_ave), np.min(L2_ave)))
#  f.write('L2_smooth ave, top, bottom: %e %e %e \n' % (np.mean(L2_smooth_ave), np.max(L2_smooth_ave), np.min(L2_smooth_ave)))
#  f.write('L2_shoc _ave, top, bottom: %e %e %e \n' % (np.mean(L2_shock_ave),np.max(L2_shock_ave),np.min(L2_shock_ave)))
#  f.write('loss ave, top, bottom: %e %e %e \n' % (np.mean(loss_ave),np.max(loss_ave),np.min(loss_ave)))

    Linf_var_o[Mesh_i,0] = np.mean(L2_max_ave)
    Linf_var_o[Mesh_i,1] = np.max(L2_max_ave)
    Linf_var_o[Mesh_i,2] = np.min(L2_max_ave)
  
    L2_var_o[Mesh_i,0] = np.mean(L2_ave)
    L2_var_o[Mesh_i,1] = np.max(L2_ave)
    L2_var_o[Mesh_i,2] = np.min(L2_ave)
  
    L2_smooth_var_o[Mesh_i,0] = np.mean(L2_smooth_ave)
    L2_smooth_var_o[Mesh_i,1] = np.max(L2_smooth_ave)
    L2_smooth_var_o[Mesh_i,2] = np.min(L2_smooth_ave)
  
    L2_shock_var_o[Mesh_i,0] = np.mean(L2_shock_ave)
    L2_shock_var_o[Mesh_i,1] = np.max(L2_shock_ave)
    L2_shock_var_o[Mesh_i,2] = np.min(L2_shock_ave)

    Loss_var_o[Mesh_i,0] = np.mean(loss_ave) 
    Loss_var_o[Mesh_i,1] = np.max(loss_ave)
    Loss_var_o[Mesh_i,2] = np.min(loss_ave)

    #f.write('L2_max_ave_array: \n')
    #f.write(str(L2_max_ave))
    #f.write('\n L2_ave_array: \n')
    #f.write(str(L2_ave))
    #f.write('\n loss_ave_array: \n')
    #f.write(str(loss_ave))
    #L2_ave = L2_ave.mean()
    #L2_max_ave = L2_max_ave/num_seed  
    #loss_ave = loss_ave/num_seed
    endtime = time.time()
    train_time = (endtime - starttime)/num_seed
    f.write('\n train_time: %e\n' % (train_time/num_seed))
    Mesh_i = Mesh_i + 1

# %%
###***************WENO-Data Read***************###
Linf_var_W = np.zeros(len(Mesh))
L2_var_W = np.zeros(len(Mesh))
L2_smooth_var_W = np.zeros(len(Mesh))
L2_shock_var_W = np.zeros(len(Mesh))
Mesh_i = 0
for j in Mesh:
    file = 'WENO_'+str(j)+'.dat'
    #file = 'WENO_100.dat'
    u_W = np.loadtxt(file)
    u_W[:,0]
    y_e = Exact_burgers.Exact_Burgers(u_W[:,0])
    N = np.size(y_e)
    L2_error = np.sqrt(np.sum((u_W[:,1]-y_e)**2)/N)
        #f.write('L2 error: %e\n' % L2_error)
    num = 0
    num_shock = 0
    sum = 0.0
    sum_shock = 0
    for i in range(N):
        if abs(u_W[i,0]-1)> 0.05:
            sum = sum +  np.sum((u_W[i,1]-y_e[i])**2)
            num = num + 1
        #np.sqrt(np.sum((u_pred[:,0]-y_e)**2)/100)
        else:
            sum_shock = sum_shock +  np.sum((u_W[i,1]-y_e[i])**2)
            num_shock = num_shock + 1
    sum = sum/num
    sum_shock = sum_shock/num_shock
    L2_error_smooth = np.sqrt(sum)
    L2_error_shock = np.sqrt(sum_shock)
    L2_Max =  (np.max(np.abs(u_W[:,1]-y_e)))
    
    Linf_var_W[Mesh_i] = L2_Max
    L2_var_W[Mesh_i] = L2_error
    L2_smooth_var_W[Mesh_i] = L2_error_smooth
    L2_shock_var_W[Mesh_i] = L2_error_shock
    
    Mesh_i = Mesh_i +1

# %%
Mesh
# Out:
# [11, 21, 41, 81, 161, 321]

# %%
MeshC = np.zeros(len(Mesh))
for i in range(len(Mesh)):
    MeshC[i] = Mesh[i] -1 #  - [1,1,1,1,1,1]

###***** Figure Plot ****###

x = Mesh
fig, ax = plt.subplots(5)

##*** Loss ***##
ax[0].plot(MeshC, Loss_var_o[:,0],label= 'PINNs',color='blue',marker='*')
ax[0].plot(MeshC, Loss_var[:,0],label= 'PINNs-WE',color='red',marker='o')
y = Loss_var[:,0]
yd = Loss_var[:,1]
yu = Loss_var[:,2]
for i in range(len(x)):
    ax[0].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)
y = Loss_var_o[:,0]
yd = Loss_var_o[:,1]
yu = Loss_var_o[:,2]
for i in range(len(x)):
    ax[0].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)
# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[0].set_xscale('log', base=2)
ax[0].set_yscale('log')
ax[0].set_xticks(xticks)
ax[0].xaxis.set_major_locator(FixedLocator(xticks))
ax[0].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[0].legend(loc='lower right')
ax[0].set_title('Loss')

##*** Linf ***##
ax[1].plot(MeshC, Linf_var_o[:,0],label='PINNs',color='blue',marker='*')
ax[1].plot(MeshC, Linf_var_W[:],label='WENO-Z',color='green',marker='X')
ax[1].plot(MeshC, Linf_var[:,0],label='PINNs-WE',color='red',marker='o')
y = Linf_var_o[:,0]
yd = Linf_var_o[:,1]
yu = Linf_var_o[:,2]
for i in range(len(x)):
    ax[1].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)

y = Linf_var[:,0]
yd = Linf_var[:,1]
yu = Linf_var[:,2]
for i in range(len(x)):
    ax[1].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)
# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[1].set_xscale('log', base=2)
ax[1].set_yscale('log')
ax[1].set_xticks(xticks)
ax[1].xaxis.set_major_locator(FixedLocator(xticks))
ax[1].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[1].legend(loc='lower right')
ax[1].set_title(r'$L_{infity}$')

##*** L2 ***##
ax[2].plot(MeshC, L2_var_o[:,0],label='PINNs',color='blue',marker='*')
ax[2].plot(MeshC, L2_var_W[:],label='WENO-Z',color='green',marker='X')
ax[2].plot(MeshC, L2_var[:,0],label='PINNs-WE',color='red',marker='o')
y = Linf_var_o[:,0]
yd = Linf_var_o[:,1]
yu = Linf_var_o[:,2]
for i in range(len(x)):
    ax[2].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)

y = Linf_var[:,0]
yd = Linf_var[:,1]
yu = Linf_var[:,2]
for i in range(len(x)):
    ax[2].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)
# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[2].set_xscale('log', base=2)
ax[2].set_yscale('log')
ax[2].set_xticks(xticks)
ax[2].xaxis.set_major_locator(FixedLocator(xticks))
ax[2].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[2].legend(loc='lower right')
ax[2].set_title('L2')

##*** L2_smooth ***##
ax[3].plot(MeshC, L2_smooth_var_o[:,0],label='PINNs',color='blue',marker='*')
ax[3].plot(MeshC, L2_smooth_var_W[:],label='WENO-Z',color='green',marker='X')
ax[3].plot(MeshC, L2_smooth_var[:,0],label='PINNs-WE',color='red',marker='o')
y = L2_smooth_var_o[:,0]
yd = L2_smooth_var_o[:,1]
yu = L2_smooth_var_o[:,2]
for i in range(len(x)):
    ax[3].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)
y = L2_smooth_var[:,0]
yd = L2_smooth_var[:,1]
yu = L2_smooth_var[:,2]
for i in range(len(x)):
    ax[3].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)
# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[3].set_xscale('log', base=2)
ax[3].set_yscale('log')
ax[3].set_xticks(xticks)
ax[3].xaxis.set_major_locator(FixedLocator(xticks))
ax[3].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[3].legend(loc='lower right')
ax[3].set_title(r'$L_2^{\rm smooth}$')

##*** L2_shock ***##
ax[4].plot(MeshC, L2_shock_var_o[:,0],label='PINNs',color='blue',marker='*')
ax[4].plot(MeshC, L2_smooth_var_W[:],label='WENO-Z',color='green',marker='X')
ax[4].plot(MeshC, L2_shock_var[:,0],label='PINNs-WE',color='red',marker='o')
y  = L2_shock_var_o[:,0]
yd = L2_shock_var_o[:,1]
yu = L2_shock_var_o[:,2]
for i in range(len(x)):
    ax[4].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)
y = L2_shock_var[:,0]
yd = L2_shock_var[:,1]
yu = L2_shock_var[:,2]
for i in range(len(x)):
    ax[4].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)

# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[4].set_xscale('log', base=2)
ax[4].set_yscale('log')
ax[4].set_xticks(xticks)
ax[4].xaxis.set_major_locator(FixedLocator(xticks))
ax[4].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[4].legend(loc='lower right')
ax[4].set_title(r'$L_2^{\rm shock}$')
#ax[4].xlabel('Number of cells (or points-1)')
plt.xlabel('xxxx')
#plt.ylabel('Loss')

plt.savefig("1.png") 
plt.show()

# %%
for i in range(len(Mesh)):
    Mesh[i] = Mesh[i] -1 #  - [1,1,1,1,1,1]

###***** Figure Plot ****###

x = Mesh
fig, ax = plt.subplots()

##*** Loss ***##
ax[0].plot(Mesh, Loss_var_o[:,0],label= 'PINNs',color='blue',marker='*')
ax[0].plot(Mesh, Loss_var[:,0],label= 'PINNs-WE',color='red',marker='o')
y = Loss_var[:,0]
yd = Loss_var[:,1]
yu = Loss_var[:,2]
for i in range(len(x)):
    ax[0].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)
y = Loss_var_o[:,0]
yd = Loss_var_o[:,1]
yu = Loss_var_o[:,2]
for i in range(len(x)):
    ax[0].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)
# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[0].set_xscale('log', base=2)
ax[0].set_yscale('log')
ax[0].set_xticks(xticks)
ax[0].xaxis.set_major_locator(FixedLocator(xticks))
ax[0].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[0].legend(loc='lower right')
ax[0].set_title('Loss')

##*** Linf ***##
ax[1].plot(Mesh, Linf_var_o[:,0],label='PINNs',color='blue',marker='*')
ax[2].plot(Mesh, Linf_var_W[:],label='WENO-Z',color='green',marker='X')
ax[1].plot(Mesh, Linf_var[:,0],label='PINNs-WE',color='red',marker='o')
y = Linf_var_o[:,0]
yd = Linf_var_o[:,1]
yu = Linf_var_o[:,2]
for i in range(len(x)):
    ax[1].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)

y = Linf_var[:,0]
yd = Linf_var[:,1]
yu = Linf_var[:,2]
for i in range(len(x)):
    ax[1].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)
# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[1].set_xscale('log', base=2)
ax[1].set_yscale('log')
ax[1].set_xticks(xticks)
ax[1].xaxis.set_major_locator(FixedLocator(xticks))
ax[1].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[1].legend(loc='lower right')
ax[1].set_title(r'$L_{infity}$')

##*** L2 ***##
ax[2].plot(Mesh, L2_var_o[:,0],label='PINNs',color='blue',marker='*')
ax[2].plot(Mesh, L2_var_W[:],label='WENO-Z',color='green',marker='X')
ax[2].plot(Mesh, L2_var[:,0],label='PINNs-WE',color='red',marker='o')
y = Linf_var_o[:,0]
yd = Linf_var_o[:,1]
yu = Linf_var_o[:,2]
for i in range(len(x)):
    ax[2].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)

y = Linf_var[:,0]
yd = Linf_var[:,1]
yu = Linf_var[:,2]
for i in range(len(x)):
    ax[2].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)
# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[2].set_xscale('log', base=2)
ax[2].set_yscale('log')
ax[2].set_xticks(xticks)
ax[2].xaxis.set_major_locator(FixedLocator(xticks))
ax[2].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[2].legend(loc='lower right')
ax[2].set_title('L2')

##*** L2_smooth ***##
ax[3].plot(Mesh, L2_smooth_var_o[:,0],label='PINNs',color='blue',marker='*')
ax[3].plot(Mesh, L2_smooth_var_W[:],label='WENO-Z',color='green',marker='X')
ax[3].plot(Mesh, L2_smooth_var[:,0],label='PINNs-WE',color='red',marker='o')
y = L2_smooth_var_o[:,0]
yd = L2_smooth_var_o[:,1]
yu = L2_smooth_var_o[:,2]
for i in range(len(x)):
    ax[3].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)
y = L2_smooth_var[:,0]
yd = L2_smooth_var[:,1]
yu = L2_smooth_var[:,2]
for i in range(len(x)):
    ax[3].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)
# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[3].set_xscale('log', base=2)
ax[3].set_yscale('log')
ax[3].set_xticks(xticks)
ax[3].xaxis.set_major_locator(FixedLocator(xticks))
ax[3].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[3].legend(loc='lower right')
ax[3].set_title(r'$L_2^{\rm smooth}$')

##*** L2_shock ***##
ax[4].plot(Mesh, L2_shock_var_o[:,0],label='PINNs',color='blue',marker='*')
ax[4].plot(Mesh, L2_smooth_var_W[:],label='WENO-Z',color='green',marker='X')
ax[4].plot(Mesh, L2_shock_var[:,0],label='PINNs-WE',color='red',marker='o')
y  = L2_shock_var_o[:,0]
yd = L2_shock_var_o[:,1]
yu = L2_shock_var_o[:,2]
for i in range(len(x)):
    ax[4].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='blue', alpha=0.2)
y = L2_shock_var[:,0]
yd = L2_shock_var[:,1]
yu = L2_shock_var[:,2]
for i in range(len(x)):
    ax[4].fill_between([x[i]-0.01*x[i], x[i]+0.01*x[i]], [yd[i], yd[i]], [yu[i], yu[i]], color='red', alpha=0.2)

# 设置 x 轴的刻度位置和标签
xticks = Mesh
ax[4].set_xscale('log', base=2)
ax[4].set_yscale('log')
ax[4].set_xticks(xticks)
ax[4].xaxis.set_major_locator(FixedLocator(xticks))
ax[4].xaxis.set_major_formatter(FixedFormatter(xticks))
ax[4].legend(loc='lower right')
ax[4].set_title(r'$L_2^{\rm shock}$')
#ax[4].xlabel('Number of cells (or points-1)')
#plt.xlabel('xxxx')
#plt.ylabel('Loss')

plt.show()
