# %%
using DelimitedFiles

# %%
A = readdlm("burgers_u_we_11500.dat")
# Out:
# 101×2 Matrix{Float64}:
#  0.0    0.00529865
#  0.02   0.0197384
#  0.04   0.0342397
#  0.06   0.0488066
#  0.08   0.0634437
#  0.1    0.0781546
#  0.12   0.0929419
#  0.14   0.107807
#  0.16   0.122752
#  0.18   0.137776
#  0.2    0.152877
#  0.22   0.168053
#  0.24   0.183299
#  ⋮
#  1.78  -0.165368
#  1.8   -0.150383
#  1.82  -0.135484
#  1.84  -0.120683
#  1.86  -0.105991
#  1.88  -0.0914183
#  1.9   -0.0769747
#  1.92  -0.0626689
#  1.94  -0.0485092
#  1.96  -0.0345035
#  1.98  -0.0206592
#  2.0   -0.00698163

# %%
B = readdlm("result.dat",' ',Float64)
# Out:
# 10001×2 Matrix{Float64}:
#  0.0     -6.45873e-18
#  0.0002   0.000151709
#  0.0004   0.000303419
#  0.0006   0.000455128
#  0.0008   0.000606838
#  0.001    0.000758547
#  0.0012   0.000910256
#  0.0014   0.00106197
#  0.0016   0.00121368
#  0.0018   0.00136538
#  0.002    0.00151709
#  0.0022   0.0016688
#  0.0024   0.00182051
#  ⋮
#  1.9978  -0.0016688
#  1.998   -0.00151709
#  1.9982  -0.00136538
#  1.9984  -0.00121368
#  1.9986  -0.00106197
#  1.9988  -0.000910256
#  1.999   -0.000758547
#  1.9992  -0.000606838
#  1.9994  -0.000455128
#  1.9996  -0.000303419
#  1.9998  -0.000151709
#  2.0     -6.45873e-18

# %%
B[201,:]
# Out:
# 2-element Vector{Float64}:
#  0.04
#  0.03034075527

# %%
B[102,:]
# Out:
# 2-element Vector{Float64}:
#  0.0202
#  0.01532250448

# %%
B[101*99+1,:]
# Out:
# 2-element Vector{Float64}:
#   1.9998
#  -0.0001517093985

# %%
err = 0
for i in 0:100
    err = err + (B[i*100+1,2]-A[i+1,2])^2
end

# %%
B[99*101+1,1]
# Out:
# 2.0

# %%
A[100,1]
# Out:
# 2.0

# %%
using Plots

# %%
plot(A[:,1],A[:,2])
plot!(B[:,1],B[:,2])

# %%
err
# Out:
# 0.43861790149987956

# %%
err/100
# Out:
# 0.004569392021449272

# %%
err/100
# Out:
# 0.006020574172989263

# %%
err/100
# Out:
# 0.053460614128771546

# %%
err/100
# Out:
# 0.07137304646029934
