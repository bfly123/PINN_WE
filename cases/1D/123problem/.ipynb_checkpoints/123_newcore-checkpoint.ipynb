# %% [markdown]
# # Solving Sod Problem with PINN-WE
#
#
# * This code is modified from the code https://github.com/alexpapados/Physics-Informed-Deep-Learning-Solid-and-Fluid-Mechanics
#
# * The paper about this code can be reffed to https://www.researchgate.net/publication/359480166_Discontinuity_Computing_with_Physics-Informed_Neural_Network
#
# * For strong shock waves, PINN-WE can let you get a discontinuous result quickly and sharply. But it can not guarantee the result must be physical. You can try to change the random seed or learning rate to get a different result. In the paper, we show the best result of some tests to demonstrate that PINN-WE has the potential ability to handle a non-linear discontinuous problem.
#
# * So physics constraints are needed near shock waves. They are conservation laws, Rankine-Hugoniot relations and entropy condition. We develop a physics screen method here to determinate the problem.

# %%
from PINNs import *
import torch
import numpy as np
import matplotlib.pyplot as plt
from smt.sampling_methods import LHS
dtype=torch.float64
setup_seed(2)
Ts = 0
Te = 0.1
Xs = 0
Xe = 1
Nx = 100
Nt = 100

# %%
setup_seed(5)
def train(epoch):
    def closure():
        optimizer.zero_grad()                                                     
        loss_pde = model.loss_pde(x_int)                                    
        loss_ic = model.loss_ic(x_ic, rho_ic,u_ic,p_ic)   
        #loss_bc = model.loss_ic(x_bc, rho_bc,u_bc,p_bc)   
        
        #loss_rh1 = model.loss_rh(x_screen2,x_screen2_L,x_screen2_R) # RH relation
        #loss_s0 = model.loss_character(x_screen2,x_screen2_R) # Entropy condition
        #loss_con3 = model.loss_con(x_screen3 ,x_ic,T3) #Conservation laws
        #loss_con1 = model.loss_con(x_screen1 ,x_ic,T1) #Conservation laws
        loss = loss_pde + 10*(loss_ic)# +loss_bc) +  10*(loss_rh1)  +10* loss_s0 +10*loss_con3   +10* loss_s0  
        #print(f'epoch {epoch} loss_pde:{loss_pde:.8f},loss_rh1:{loss_rh1:.8f},loss_con:{loss_con1:.8f}, loss_s:{loss_s0:.8f}, loss_ic:{loss_ic:.8f}')
        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f}')
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    return loss

x_ic,x_bc,x_int =  Mesh_Data(Nx,Nt,Ts,Te,Xs,Xe)

xlimits = np.array([[0.,0],[0, Xe]])  #interal
sampling = LHS(xlimits=xlimits)
x_ic= sampling(500)
rho_ic, u_ic, p_ic= IC_123(x_ic)                    
xlimits = np.array([[0.,Te],[0, Xe]])  #interal
sampling = LHS(xlimits=xlimits)
x_int= sampling(2000)
#xlimits = np.array([[0.,Te],[0.4, 0.6]])  #interal
#sampling = LHS(xlimits=xlimits)
#x_int_add= sampling(1000)
#x_int = np.append(x_int,x_int_add,axis=0)
#xlimits = np.array([[0.,Te],[0.45, 0.55]])  #interal
#sampling = LHS(xlimits=xlimits)
#x_int_add= sampling(1000)
#x_int = np.append(x_int,x_int_add,axis=0)
x_ic = torch.tensor(x_ic,requires_grad=True, dtype=dtype).to(cuda)
x_int = torch.tensor(x_int, requires_grad=True, dtype=dtype).to(cuda)

rho_ic = torch.tensor(rho_ic, dtype=dtype).to(cuda)
u_ic = torch.tensor(u_ic, dtype=dtype).to(cuda)
p_ic = torch.tensor(p_ic, dtype=dtype).to(cuda)

# %%
x_int
# Out:
# tensor([[0.0135, 0.3902],
#         [0.0226, 0.4463],
#         [0.0503, 0.2913],
#         ...,
#         [0.0174, 0.2638],
#         [0.0051, 0.9992],
#         [0.0973, 0.9657]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<ToCopyBackward0>)

# %%
model = PINNs_Euler_1D(Nl=6,Nn=60).to(cuda).double()
print('Start training...')
epoch = 0
epochi = epoch
lr = 0.001                                                           # Learning rate
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
epochs = 100000
loss_history=[]
tic = time.time()
for epoch in range(1+epochi, epochs+epochi):
    loss = train(epoch)
    print(f'loss_tot:{loss:.8f}')
    loss_history.append(to_numpy(loss))
    if loss < 0.05:
        break
toc = time.time()
print(f'Total training time: {toc - tic}')

optimizer = torch.optim.LBFGS(model.parameters(),lr=0.1,max_iter=20)

epochi = 0

epochs = 5000
tic = time.time()
for epoch in range(epochi, epochs+epochi):
    loss = train(epoch)
    print(f'loss_tot:{loss:.8f}')
    #loss_history.append(to_numpy(loss))
    #if loss < 0.01:
    #    break
toc = time.time()

print(f'Total training time: {toc - tic}')
# Out:
# Start training...
# epoch 1 loss_pde:1.46322613, loss_ic:4.71024890
# loss_tot:48.56571510
# epoch 2 loss_pde:1.15878214, loss_ic:4.65868876
# loss_tot:47.74566971
# epoch 3 loss_pde:0.70259579, loss_ic:4.58830442
# loss_tot:46.58564001
# epoch 4 loss_pde:0.23921650, loss_ic:4.51821827
# loss_tot:45.42139917
# epoch 5 loss_pde:0.07401326, loss_ic:4.44837664
# loss_tot:44.55777967
# epoch 6 loss_pde:0.03689878, loss_ic:4.37857034
# loss_tot:43.82260221
# epoch 7 loss_pde:0.03682262, loss_ic:4.30899246
# loss_tot:43.12674719
# epoch 8 loss_pde:0.04024157, loss_ic:4.24018002
# loss_tot:42.44204178
# epoch 9 loss_pde:0.03814803, loss_ic:4.17295842
# loss_tot:41.76773227
# epoch 10 loss_pde:0.03113496, loss_ic:4.10841418
# loss_tot:41.11527675
# epoch 11 loss_pde:0.02348083, loss_ic:4.04785845
# loss_tot:40.50206534
# epoch 12 loss_pde:0.02127663, loss_ic:3.99275048
# loss_tot:39.94878141
# epoch 13 loss_pde:0.03300490, loss_ic:3.94456505
# loss_tot:39.47865545
# epoch 14 loss_pde:0.07356447, loss_ic:3.90461514
# loss_tot:39.11971590
# epoch 15 loss_pde:0.17888350, loss_ic:3.87397084
# loss_tot:38.91859191
# epoch 16 loss_pde:0.39215140, loss_ic:3.85461793
# loss_tot:38.93833070
# epoch 17 loss_pde:0.03265656, loss_ic:3.85718632
# loss_tot:38.60451973
# epoch 18 loss_pde:0.00926806, loss_ic:3.86064785
# loss_tot:38.61574654
# epoch 19 loss_pde:0.04540452, loss_ic:3.86014466
# loss_tot:38.64685115
# epoch 20 loss_pde:0.09676247, loss_ic:3.85310204
# loss_tot:38.62778285
# epoch 21 loss_pde:0.14594302, loss_ic:3.83888056
# loss_tot:38.53474863
# epoch 22 loss_pde:0.16782920, loss_ic:3.81860310
# loss_tot:38.35386024
# epoch 23 loss_pde:0.15525668, loss_ic:3.79377207
# loss_tot:38.09297737
# epoch 24 loss_pde:0.14809730, loss_ic:3.76450412
# loss_tot:37.79313853
# epoch 25 loss_pde:0.18253588, loss_ic:3.73016244
# loss_tot:37.48416029
# epoch 26 loss_pde:0.27646310, loss_ic:3.69070056
# loss_tot:37.18346872
# epoch 27 loss_pde:0.46276064, loss_ic:3.64825799
# loss_tot:36.94534055
# epoch 28 loss_pde:0.56808595, loss_ic:3.61897254
# loss_tot:36.75781137
# epoch 29 loss_pde:0.77417260, loss_ic:3.58404162
# loss_tot:36.61458879
# epoch 30 loss_pde:27.83967805, loss_ic:3.54513059
# loss_tot:63.29098400
# epoch 31 loss_pde:0.67865393, loss_ic:3.64067516
# loss_tot:37.08540551
# epoch 32 loss_pde:0.48259264, loss_ic:3.73842127
# loss_tot:37.86680537
# epoch 33 loss_pde:0.33863369, loss_ic:3.83513027
# loss_tot:38.68993637
# epoch 34 loss_pde:0.23454741, loss_ic:3.92866861
# loss_tot:39.52123354
# epoch 35 loss_pde:0.16074887, loss_ic:4.01770202
# loss_tot:40.33776909
# epoch 36 loss_pde:0.10991526, loss_ic:4.10146310
# loss_tot:41.12454622
# epoch 37 loss_pde:0.07639926, loss_ic:4.17957911
# loss_tot:41.87219036
# epoch 38 loss_pde:0.05582831, loss_ic:4.25194675
# loss_tot:42.57529579
# epoch 39 loss_pde:0.04482027, loss_ic:4.31864237
# loss_tot:43.23124397
# epoch 40 loss_pde:0.04076898, loss_ic:4.37985852
# loss_tot:43.83935420
# epoch 41 loss_pde:0.04167684, loss_ic:4.43585949
# loss_tot:44.40027177
# epoch 42 loss_pde:0.04602231, loss_ic:4.48695053
# loss_tot:44.91552760
# epoch 43 loss_pde:0.05265483, loss_ic:4.53345671
# loss_tot:45.38722193
# epoch 44 loss_pde:0.06071170, loss_ic:4.57570861
# loss_tot:45.81779776
# epoch 45 loss_pde:0.06955267, loss_ic:4.61403269
# loss_tot:46.20987956
# epoch 46 loss_pde:0.07870857, loss_ic:4.64874503
# loss_tot:46.56615886
# epoch 47 loss_pde:0.08784133, loss_ic:4.68014728
# loss_tot:46.88931417
# epoch 48 loss_pde:0.09671279, loss_ic:4.70852427
# loss_tot:47.18195553
# epoch 49 loss_pde:0.10516055, loss_ic:4.73414267
# loss_tot:47.44658725
# epoch 50 loss_pde:0.11307926, loss_ic:4.75725043
# loss_tot:47.68558360
# epoch 51 loss_pde:0.12040629, loss_ic:4.77807680
# loss_tot:47.90117434
# epoch 52 loss_pde:0.12711053, loss_ic:4.79683266
# loss_tot:48.09543711
# epoch 53 loss_pde:0.13318396, loss_ic:4.81371112
# loss_tot:48.27029513
# epoch 54 loss_pde:0.13863509, loss_ic:4.82888835
# loss_tot:48.42751858
# epoch 55 loss_pde:0.14348401, loss_ic:4.84252448
# loss_tot:48.56872882
# epoch 56 loss_pde:0.14775859, loss_ic:4.85476460
# loss_tot:48.69540458
# epoch 57 loss_pde:0.15149166, loss_ic:4.86573979
# loss_tot:48.80888954
# epoch 58 loss_pde:0.15471885, loss_ic:4.87556820
# loss_tot:48.91040084
# epoch 59 loss_pde:0.15747702, loss_ic:4.88435613
# loss_tot:49.00103828
# epoch 60 loss_pde:0.15980305, loss_ic:4.89219906
# loss_tot:49.08179368
# epoch 61 loss_pde:0.16173305, loss_ic:4.89918274
# loss_tot:49.15356041
# epoch 62 loss_pde:0.16330177, loss_ic:4.90538409
# loss_tot:49.21714268
# epoch 63 loss_pde:0.16454215, loss_ic:4.91087225
# loss_tot:49.27326465
# epoch 64 loss_pde:0.16548513, loss_ic:4.91570938
# loss_tot:49.32257895
# epoch 65 loss_pde:0.16615947, loss_ic:4.91995152
# loss_tot:49.36567471
# epoch 66 loss_pde:0.16659173, loss_ic:4.92364933
# loss_tot:49.40308499
# epoch 67 loss_pde:0.16680623, loss_ic:4.92684872
# loss_tot:49.43529342
# epoch 68 loss_pde:0.16682513, loss_ic:4.92959150
# loss_tot:49.46274017
# epoch 69 loss_pde:0.16666852, loss_ic:4.93191586
# loss_tot:49.48582714
# epoch 70 loss_pde:0.16635453, loss_ic:4.93385680
# loss_tot:49.50492249
# epoch 71 loss_pde:0.16589941, loss_ic:4.93544650
# loss_tot:49.52036442
# epoch 72 loss_pde:0.16531772, loss_ic:4.93671466
# loss_tot:49.53246437
# epoch 73 loss_pde:0.16462245, loss_ic:4.93768872
# loss_tot:49.54150966
# epoch 74 loss_pde:0.16382512, loss_ic:4.93839405
# loss_tot:49.54776563
# epoch 75 loss_pde:0.16293597, loss_ic:4.93885414
# loss_tot:49.55147740
# epoch 76 loss_pde:0.16196405, loss_ic:4.93909072
# loss_tot:49.55287128
# epoch 77 loss_pde:0.16091739, loss_ic:4.93912386
# loss_tot:49.55215595
# epoch 78 loss_pde:0.15980306, loss_ic:4.93897204
# loss_tot:49.54952348
# epoch 79 loss_pde:0.15862735, loss_ic:4.93865228
# loss_tot:49.54515017
# epoch 80 loss_pde:0.15739581, loss_ic:4.93818016
# loss_tot:49.53919740
# epoch 81 loss_pde:0.15611340, loss_ic:4.93756990
# loss_tot:49.53181236
# epoch 82 loss_pde:0.15478454, loss_ic:4.93683443
# loss_tot:49.52312882
# epoch 83 loss_pde:0.15341323, loss_ic:4.93598547
# loss_tot:49.51326794
# epoch 84 loss_pde:0.15200308, loss_ic:4.93503360
# loss_tot:49.50233903
# epoch 85 loss_pde:0.15055739, loss_ic:4.93398830
# loss_tot:49.49044039
# epoch 86 loss_pde:0.14907921, loss_ic:4.93285809
# loss_tot:49.47766014
# epoch 87 loss_pde:0.14757140, loss_ic:4.93165057
# loss_tot:49.46407710
# epoch 88 loss_pde:0.14603665, loss_ic:4.93037249
# loss_tot:49.44976159
# epoch 89 loss_pde:0.14447750, loss_ic:4.92902989
# loss_tot:49.43477636
# epoch 90 loss_pde:0.14289642, loss_ic:4.92762809
# loss_tot:49.41917729
# epoch 91 loss_pde:0.14129577, loss_ic:4.92617185
# loss_tot:49.40301428
# epoch 92 loss_pde:0.13967787, loss_ic:4.92466540
# loss_tot:49.38633190
# epoch 93 loss_pde:0.13804498, loss_ic:4.92311251
# loss_tot:49.36917007
# epoch 94 loss_pde:0.13639928, loss_ic:4.92151654
# loss_tot:49.35156472
# epoch 95 loss_pde:0.13474295, loss_ic:4.91988053
# loss_tot:49.33354824
# epoch 96 loss_pde:0.13307810, loss_ic:4.91820719
# loss_tot:49.31515002
# epoch 97 loss_pde:0.13140680, loss_ic:4.91649900
# loss_tot:49.29639681
# epoch 98 loss_pde:0.12973105, loss_ic:4.91475820
# loss_tot:49.27731306
# epoch 99 loss_pde:0.12805283, loss_ic:4.91298684
# loss_tot:49.25792119
# epoch 100 loss_pde:0.12637401, loss_ic:4.91118678
# loss_tot:49.23824184
# epoch 101 loss_pde:0.12469643, loss_ic:4.90935976
# loss_tot:49.21829402
# epoch 102 loss_pde:0.12302181, loss_ic:4.90750734
# loss_tot:49.19809524
# epoch 103 loss_pde:0.12135182, loss_ic:4.90563098
# loss_tot:49.17766167
# epoch 104 loss_pde:0.11968802, loss_ic:4.90373201
# loss_tot:49.15700817
# epoch 105 loss_pde:0.11803189, loss_ic:4.90181165
# loss_tot:49.13614840
# epoch 106 loss_pde:0.11638480, loss_ic:4.89987101
# loss_tot:49.11509487
# epoch 107 loss_pde:0.11474802, loss_ic:4.89791110
# loss_tot:49.09385901
# epoch 108 loss_pde:0.11312271, loss_ic:4.89593285
# loss_tot:49.07245118
# epoch 109 loss_pde:0.11150993, loss_ic:4.89393709
# loss_tot:49.05088081
# epoch 110 loss_pde:0.10991065, loss_ic:4.89192457
# loss_tot:49.02915635
# epoch 111 loss_pde:0.10832573, loss_ic:4.88989597
# loss_tot:49.00728543
# epoch 112 loss_pde:0.10675592, loss_ic:4.88785189
# loss_tot:48.98527485
# epoch 113 loss_pde:0.10520189, loss_ic:4.88579288
# loss_tot:48.96313071
# epoch 114 loss_pde:0.10366421, loss_ic:4.88371942
# loss_tot:48.94085840
# epoch 115 loss_pde:0.10214336, loss_ic:4.88163194
# loss_tot:48.91846273
# epoch 116 loss_pde:0.10063975, loss_ic:4.87953082
# loss_tot:48.89594798
# epoch 117 loss_pde:0.09915371, loss_ic:4.87741642
# loss_tot:48.87331795
# epoch 118 loss_pde:0.09768549, loss_ic:4.87528905
# loss_tot:48.85057602
# epoch 119 loss_pde:0.09623530, loss_ic:4.87314899
# loss_tot:48.82772521
# epoch 120 loss_pde:0.09480327, loss_ic:4.87099650
# loss_tot:48.80476825
# epoch 121 loss_pde:0.09338949, loss_ic:4.86883181
# loss_tot:48.78170758
# epoch 122 loss_pde:0.09199401, loss_ic:4.86665514
# loss_tot:48.75854542
# epoch 123 loss_pde:0.09061682, loss_ic:4.86446670
# loss_tot:48.73528381
# epoch 124 loss_pde:0.08925790, loss_ic:4.86226667
# loss_tot:48.71192460
# epoch 125 loss_pde:0.08791719, loss_ic:4.86005523
# loss_tot:48.68846950
# epoch 126 loss_pde:0.08659461, loss_ic:4.85783255
# loss_tot:48.66492009
# epoch 127 loss_pde:0.08529006, loss_ic:4.85559878
# loss_tot:48.64127785
# epoch 128 loss_pde:0.08400343, loss_ic:4.85335407
# loss_tot:48.61754413
# epoch 129 loss_pde:0.08273459, loss_ic:4.85109856
# loss_tot:48.59372021
# epoch 130 loss_pde:0.08148342, loss_ic:4.84883238
# loss_tot:48.56980725
# epoch 131 loss_pde:0.08024979, loss_ic:4.84655566
# loss_tot:48.54580635
# epoch 132 loss_pde:0.07903355, loss_ic:4.84426850
# loss_tot:48.52171853
# epoch 133 loss_pde:0.07783457, loss_ic:4.84197101
# loss_tot:48.49754472
# epoch 134 loss_pde:0.07665272, loss_ic:4.83966331
# loss_tot:48.47328578
# epoch 135 loss_pde:0.07548788, loss_ic:4.83734547
# loss_tot:48.44894253
# epoch 136 loss_pde:0.07433991, loss_ic:4.83501758
# loss_tot:48.42451571
# epoch 137 loss_pde:0.07320871, loss_ic:4.83267973
# loss_tot:48.40000599
# epoch 138 loss_pde:0.07209416, loss_ic:4.83033199
# loss_tot:48.37541402
# epoch 139 loss_pde:0.07099615, loss_ic:4.82797442
# loss_tot:48.35074040
# epoch 140 loss_pde:0.06991460, loss_ic:4.82560711
# loss_tot:48.32598567
# epoch 141 loss_pde:0.06884939, loss_ic:4.82323010
# loss_tot:48.30115035
# epoch 142 loss_pde:0.06780046, loss_ic:4.82084345
# loss_tot:48.27623495
# epoch 143 loss_pde:0.06676772, loss_ic:4.81844722
# loss_tot:48.25123993
# epoch 144 loss_pde:0.06575108, loss_ic:4.81604147
# loss_tot:48.22616575
# epoch 145 loss_pde:0.06475049, loss_ic:4.81362624
# loss_tot:48.20101285
# epoch 146 loss_pde:0.06376586, loss_ic:4.81120158
# loss_tot:48.17578165
# epoch 147 loss_pde:0.06279713, loss_ic:4.80876755
# loss_tot:48.15047260
# epoch 148 loss_pde:0.06184423, loss_ic:4.80632419
# loss_tot:48.12508610
# epoch 149 loss_pde:0.06090710, loss_ic:4.80387155
# loss_tot:48.09962258
# epoch 150 loss_pde:0.05998567, loss_ic:4.80140968
# loss_tot:48.07408246
# epoch 151 loss_pde:0.05907987, loss_ic:4.79893863
# loss_tot:48.04846617
# epoch 152 loss_pde:0.05818963, loss_ic:4.79645845
# loss_tot:48.02277412
# epoch 153 loss_pde:0.05731489, loss_ic:4.79396919
# loss_tot:47.99700675
# epoch 154 loss_pde:0.05645556, loss_ic:4.79147089
# loss_tot:47.97116449
# epoch 155 loss_pde:0.05561158, loss_ic:4.78896362
# loss_tot:47.94524778
# epoch 156 loss_pde:0.05478285, loss_ic:4.78644742
# loss_tot:47.91925706
# epoch 157 loss_pde:0.05396930, loss_ic:4.78392235
# loss_tot:47.89319277
# epoch 158 loss_pde:0.05317084, loss_ic:4.78138845
# loss_tot:47.86705536
# epoch 159 loss_pde:0.05238737, loss_ic:4.77884579
# loss_tot:47.84084530
# epoch 160 loss_pde:0.05161879, loss_ic:4.77629443
# loss_tot:47.81456304
# epoch 161 loss_pde:0.05086500, loss_ic:4.77373441
# loss_tot:47.78820905
# epoch 162 loss_pde:0.05012590, loss_ic:4.77116579
# loss_tot:47.76178380
# epoch 163 loss_pde:0.04940136, loss_ic:4.76858864
# loss_tot:47.73528776
# epoch 164 loss_pde:0.04869129, loss_ic:4.76600301
# loss_tot:47.70872141
# epoch 165 loss_pde:0.04799555, loss_ic:4.76340897
# loss_tot:47.68208524
# epoch 166 loss_pde:0.04731401, loss_ic:4.76080657
# loss_tot:47.65537974
# epoch 167 loss_pde:0.04664656, loss_ic:4.75819588
# loss_tot:47.62860541
# epoch 168 loss_pde:0.04599306, loss_ic:4.75557697
# loss_tot:47.60176275
# epoch 169 loss_pde:0.04535337, loss_ic:4.75294989
# loss_tot:47.57485226
# epoch 170 loss_pde:0.04472735, loss_ic:4.75031471
# loss_tot:47.54787446
# epoch 171 loss_pde:0.04411486, loss_ic:4.74767150
# loss_tot:47.52082986
# epoch 172 loss_pde:0.04351576, loss_ic:4.74502032
# loss_tot:47.49371899
# epoch 173 loss_pde:0.04292989, loss_ic:4.74236125
# loss_tot:47.46654236
# epoch 174 loss_pde:0.04235712, loss_ic:4.73969434
# loss_tot:47.43930051
# epoch 175 loss_pde:0.04179729, loss_ic:4.73701967
# loss_tot:47.41199397
# epoch 176 loss_pde:0.04125023, loss_ic:4.73433730
# loss_tot:47.38462327
# epoch 177 loss_pde:0.04071581, loss_ic:4.73164731
# loss_tot:47.35718896
# epoch 178 loss_pde:0.04019387, loss_ic:4.72894977
# loss_tot:47.32969156
# epoch 179 loss_pde:0.03968424, loss_ic:4.72624474
# loss_tot:47.30213163
# epoch 180 loss_pde:0.03918677, loss_ic:4.72353229
# loss_tot:47.27450970
# epoch 181 loss_pde:0.03870131, loss_ic:4.72081250
# loss_tot:47.24682632
# epoch 182 loss_pde:0.03822769, loss_ic:4.71808543
# loss_tot:47.21908202
# epoch 183 loss_pde:0.03776576, loss_ic:4.71535116
# loss_tot:47.19127736
# epoch 184 loss_pde:0.03731535, loss_ic:4.71260975
# loss_tot:47.16341286
# epoch 185 loss_pde:0.03687632, loss_ic:4.70986128
# loss_tot:47.13548908
# epoch 186 loss_pde:0.03644849, loss_ic:4.70710581
# loss_tot:47.10750654
# epoch 187 loss_pde:0.03603171, loss_ic:4.70434341
# loss_tot:47.07946578
# epoch 188 loss_pde:0.03562583, loss_ic:4.70157415
# loss_tot:47.05136733
# epoch 189 loss_pde:0.03523069, loss_ic:4.69879810
# loss_tot:47.02321172
# epoch 190 loss_pde:0.03484613, loss_ic:4.69601533
# loss_tot:46.99499947
# epoch 191 loss_pde:0.03447200, loss_ic:4.69322591
# loss_tot:46.96673110
# epoch 192 loss_pde:0.03410813, loss_ic:4.69042990
# loss_tot:46.93840712
# epoch 193 loss_pde:0.03375439, loss_ic:4.68762736
# loss_tot:46.91002803
# epoch 194 loss_pde:0.03341061, loss_ic:4.68481837
# loss_tot:46.88159435
# epoch 195 loss_pde:0.03307664, loss_ic:4.68200299
# loss_tot:46.85310656
# epoch 196 loss_pde:0.03275234, loss_ic:4.67918128
# loss_tot:46.82456515
# epoch 197 loss_pde:0.03243755, loss_ic:4.67635330
# loss_tot:46.79597060
# epoch 198 loss_pde:0.03213214, loss_ic:4.67351912
# loss_tot:46.76732338
# epoch 199 loss_pde:0.03183595, loss_ic:4.67067880
# loss_tot:46.73862396
# epoch 200 loss_pde:0.03154884, loss_ic:4.66783239
# loss_tot:46.70987279
# epoch 201 loss_pde:0.03127068, loss_ic:4.66497996
# loss_tot:46.68107031
# epoch 202 loss_pde:0.03100132, loss_ic:4.66212156
# loss_tot:46.65221696
# epoch 203 loss_pde:0.03074062, loss_ic:4.65925726
# loss_tot:46.62331317
# epoch 204 loss_pde:0.03048845, loss_ic:4.65638709
# loss_tot:46.59435936
# epoch 205 loss_pde:0.03024468, loss_ic:4.65351112
# loss_tot:46.56535592
# epoch 206 loss_pde:0.03000919, loss_ic:4.65062941
# loss_tot:46.53630325
# epoch 207 loss_pde:0.02978183, loss_ic:4.64774199
# loss_tot:46.50720173
# epoch 208 loss_pde:0.02956250, loss_ic:4.64484892
# loss_tot:46.47805174
# epoch 209 loss_pde:0.02935106, loss_ic:4.64195026
# loss_tot:46.44885364
# epoch 210 loss_pde:0.02914740, loss_ic:4.63904604
# loss_tot:46.41960776
# epoch 211 loss_pde:0.02895141, loss_ic:4.63613630
# loss_tot:46.39031445
# epoch 212 loss_pde:0.02876296, loss_ic:4.63322111
# loss_tot:46.36097403
# epoch 213 loss_pde:0.02858197, loss_ic:4.63030048
# loss_tot:46.33158681
# epoch 214 loss_pde:0.02840831, loss_ic:4.62737448
# loss_tot:46.30215309
# epoch 215 loss_pde:0.02824189, loss_ic:4.62444313
# loss_tot:46.27267315
# epoch 216 loss_pde:0.02808262, loss_ic:4.62150646
# loss_tot:46.24314727
# epoch 217 loss_pde:0.02793039, loss_ic:4.61856453
# loss_tot:46.21357570
# epoch 218 loss_pde:0.02778511, loss_ic:4.61561736
# loss_tot:46.18395868
# epoch 219 loss_pde:0.02764671, loss_ic:4.61266498
# loss_tot:46.15429647
# epoch 220 loss_pde:0.02751509, loss_ic:4.60970742
# loss_tot:46.12458926
# epoch 221 loss_pde:0.02739018, loss_ic:4.60674471
# loss_tot:46.09483728
# epoch 222 loss_pde:0.02727191, loss_ic:4.60377688
# loss_tot:46.06504072
# epoch 223 loss_pde:0.02716020, loss_ic:4.60080396
# loss_tot:46.03519975
# epoch 224 loss_pde:0.02705498, loss_ic:4.59782596
# loss_tot:46.00531455
# epoch 225 loss_pde:0.02695621, loss_ic:4.59484291
# loss_tot:45.97538527
# epoch 226 loss_pde:0.02686381, loss_ic:4.59185482
# loss_tot:45.94541206
# epoch 227 loss_pde:0.02677773, loss_ic:4.58886173
# loss_tot:45.91539504
# epoch 228 loss_pde:0.02669793, loss_ic:4.58586364
# loss_tot:45.88533435
# epoch 229 loss_pde:0.02662435, loss_ic:4.58286057
# loss_tot:45.85523008
# epoch 230 loss_pde:0.02655697, loss_ic:4.57985254
# loss_tot:45.82508234
# epoch 231 loss_pde:0.02649573, loss_ic:4.57683955
# loss_tot:45.79489120
# epoch 232 loss_pde:0.02644062, loss_ic:4.57382161
# loss_tot:45.76465674
# epoch 233 loss_pde:0.02639159, loss_ic:4.57079874
# loss_tot:45.73437902
# epoch 234 loss_pde:0.02634863, loss_ic:4.56777095
# loss_tot:45.70405809
# epoch 235 loss_pde:0.02631171, loss_ic:4.56473823
# loss_tot:45.67369399
# epoch 236 loss_pde:0.02628082, loss_ic:4.56170059
# loss_tot:45.64328676
# epoch 237 loss_pde:0.02625596, loss_ic:4.55865805
# loss_tot:45.61283642
# epoch 238 loss_pde:0.02623710, loss_ic:4.55561059
# loss_tot:45.58234296
# epoch 239 loss_pde:0.02622425, loss_ic:4.55255822
# loss_tot:45.55180641
# epoch 240 loss_pde:0.02621740, loss_ic:4.54950093
# loss_tot:45.52122675
# epoch 241 loss_pde:0.02621657, loss_ic:4.54643874
# loss_tot:45.49060396
# epoch 242 loss_pde:0.02622176, loss_ic:4.54337163
# loss_tot:45.45993803
# epoch 243 loss_pde:0.02623298, loss_ic:4.54029959
# loss_tot:45.42922892
# epoch 244 loss_pde:0.02625025, loss_ic:4.53722263
# loss_tot:45.39847659
# epoch 245 loss_pde:0.02627359, loss_ic:4.53414074
# loss_tot:45.36768101
# epoch 246 loss_pde:0.02630302, loss_ic:4.53105391
# loss_tot:45.33684211
# epoch 247 loss_pde:0.02633858, loss_ic:4.52796213
# loss_tot:45.30595984
# epoch 248 loss_pde:0.02638028, loss_ic:4.52486539
# loss_tot:45.27503414
# epoch 249 loss_pde:0.02642817, loss_ic:4.52176368
# loss_tot:45.24406494
# epoch 250 loss_pde:0.02648228, loss_ic:4.51865699
# loss_tot:45.21305217
# epoch 251 loss_pde:0.02654266, loss_ic:4.51554531
# loss_tot:45.18199574
# epoch 252 loss_pde:0.02660935, loss_ic:4.51242862
# loss_tot:45.15089559
# epoch 253 loss_pde:0.02668239, loss_ic:4.50930692
# loss_tot:45.11975162
# epoch 254 loss_pde:0.02676185, loss_ic:4.50618019
# loss_tot:45.08856375
# epoch 255 loss_pde:0.02684777, loss_ic:4.50304841
# loss_tot:45.05733189
# epoch 256 loss_pde:0.02694022, loss_ic:4.49991157
# loss_tot:45.02605595
# epoch 257 loss_pde:0.02703925, loss_ic:4.49676966
# loss_tot:44.99473583
# epoch 258 loss_pde:0.02714492, loss_ic:4.49362265
# loss_tot:44.96337145
# epoch 259 loss_pde:0.02725731, loss_ic:4.49047054
# loss_tot:44.93196270
# epoch 260 loss_pde:0.02737648, loss_ic:4.48731330
# loss_tot:44.90050949
# epoch 261 loss_pde:0.02750251, loss_ic:4.48415092
# loss_tot:44.86901172
# epoch 262 loss_pde:0.02763547, loss_ic:4.48098338
# loss_tot:44.83746931
# epoch 263 loss_pde:0.02777543, loss_ic:4.47781067
# loss_tot:44.80588216
# epoch 264 loss_pde:0.02792248, loss_ic:4.47463277
# loss_tot:44.77425018
# epoch 265 loss_pde:0.02807671, loss_ic:4.47144966
# loss_tot:44.74257328
# epoch 266 loss_pde:0.02823818, loss_ic:4.46826132
# loss_tot:44.71085138
# epoch 267 loss_pde:0.02840700, loss_ic:4.46506774
# loss_tot:44.67908438
# epoch 268 loss_pde:0.02858324, loss_ic:4.46186890
# loss_tot:44.64727222
# epoch 269 loss_pde:0.02876701, loss_ic:4.45866478
# loss_tot:44.61541481
# epoch 270 loss_pde:0.02895838, loss_ic:4.45545537
# loss_tot:44.58351209
# epoch 271 loss_pde:0.02915747, loss_ic:4.45224065
# loss_tot:44.55156398
# epoch 272 loss_pde:0.02936435, loss_ic:4.44902061
# loss_tot:44.51957043
# epoch 273 loss_pde:0.02957914, loss_ic:4.44579522
# loss_tot:44.48753137
# epoch 274 loss_pde:0.02980193, loss_ic:4.44256448
# loss_tot:44.45544677
# epoch 275 loss_pde:0.03003283, loss_ic:4.43932837
# loss_tot:44.42331656
# epoch 276 loss_pde:0.03027192, loss_ic:4.43608688
# loss_tot:44.39114072
# epoch 277 loss_pde:0.03051933, loss_ic:4.43283999
# loss_tot:44.35891922
# epoch 278 loss_pde:0.03077514, loss_ic:4.42958769
# loss_tot:44.32665202
# epoch 279 loss_pde:0.03103948, loss_ic:4.42632996
# loss_tot:44.29433912
# epoch 280 loss_pde:0.03131244, loss_ic:4.42306681
# loss_tot:44.26198051
# epoch 281 loss_pde:0.03159414, loss_ic:4.41979820
# loss_tot:44.22957618
# epoch 282 loss_pde:0.03188468, loss_ic:4.41652415
# loss_tot:44.19712616
# epoch 283 loss_pde:0.03218417, loss_ic:4.41324463
# loss_tot:44.16463044
# epoch 284 loss_pde:0.03249272, loss_ic:4.40995963
# loss_tot:44.13208907
# epoch 285 loss_pde:0.03281045, loss_ic:4.40666916
# loss_tot:44.09950207
# epoch 286 loss_pde:0.03313746, loss_ic:4.40337320
# loss_tot:44.06686950
# epoch 287 loss_pde:0.03347386, loss_ic:4.40007176
# loss_tot:44.03419142
# epoch 288 loss_pde:0.03381977, loss_ic:4.39676481
# loss_tot:44.00146788
# epoch 289 loss_pde:0.03417529, loss_ic:4.39345237
# loss_tot:43.96869896
# epoch 290 loss_pde:0.03454054, loss_ic:4.39013442
# loss_tot:43.93588477
# epoch 291 loss_pde:0.03491563, loss_ic:4.38681098
# loss_tot:43.90302538
# epoch 292 loss_pde:0.03530067, loss_ic:4.38348202
# loss_tot:43.87012092
# epoch 293 loss_pde:0.03569577, loss_ic:4.38014757
# loss_tot:43.83717150
# epoch 294 loss_pde:0.03610104, loss_ic:4.37680762
# loss_tot:43.80417726
# epoch 295 loss_pde:0.03651659, loss_ic:4.37346218
# loss_tot:43.77113834
# epoch 296 loss_pde:0.03694253, loss_ic:4.37011124
# loss_tot:43.73805490
# epoch 297 loss_pde:0.03737897, loss_ic:4.36675481
# loss_tot:43.70492711
# epoch 298 loss_pde:0.03782601, loss_ic:4.36339291
# loss_tot:43.67175514
# epoch 299 loss_pde:0.03828376, loss_ic:4.36002554
# loss_tot:43.63853918
# epoch 300 loss_pde:0.03875232, loss_ic:4.35665271
# loss_tot:43.60527945
# epoch 301 loss_pde:0.03923181, loss_ic:4.35327443
# loss_tot:43.57197615
# epoch 302 loss_pde:0.03972231, loss_ic:4.34989072
# loss_tot:43.53862952
# epoch 303 loss_pde:0.04022394, loss_ic:4.34650158
# loss_tot:43.50523978
# epoch 304 loss_pde:0.04073679, loss_ic:4.34310704
# loss_tot:43.47180721
# epoch 305 loss_pde:0.04126096, loss_ic:4.33970711
# loss_tot:43.43833205
# epoch 306 loss_pde:0.04179654, loss_ic:4.33630180
# loss_tot:43.40481459
# epoch 307 loss_pde:0.04234364, loss_ic:4.33289115
# loss_tot:43.37125511
# epoch 308 loss_pde:0.04290233, loss_ic:4.32947516
# loss_tot:43.33765391
# epoch 309 loss_pde:0.04347272, loss_ic:4.32605386
# loss_tot:43.30401130
# epoch 310 loss_pde:0.04405488, loss_ic:4.32262727
# loss_tot:43.27032761
# epoch 311 loss_pde:0.04464892, loss_ic:4.31919543
# loss_tot:43.23660317
# epoch 312 loss_pde:0.04525489, loss_ic:4.31575834
# loss_tot:43.20283833
# epoch 313 loss_pde:0.04587290, loss_ic:4.31231605
# loss_tot:43.16903345
# epoch 314 loss_pde:0.04650302, loss_ic:4.30886859
# loss_tot:43.13518888
# epoch 315 loss_pde:0.04714531, loss_ic:4.30541597
# loss_tot:43.10130501
# epoch 316 loss_pde:0.04779986, loss_ic:4.30195824
# loss_tot:43.06738224
# epoch 317 loss_pde:0.04846673, loss_ic:4.29849542
# loss_tot:43.03342095
# epoch 318 loss_pde:0.04914599, loss_ic:4.29502756
# loss_tot:42.99942156
# epoch 319 loss_pde:0.04983770, loss_ic:4.29155468
# loss_tot:42.96538449
# epoch 320 loss_pde:0.05054193, loss_ic:4.28807682
# loss_tot:42.93131017
# epoch 321 loss_pde:0.05125872, loss_ic:4.28459403
# loss_tot:42.89719903
# epoch 322 loss_pde:0.05198814, loss_ic:4.28110634
# loss_tot:42.86305152
# epoch 323 loss_pde:0.05273022, loss_ic:4.27761379
# loss_tot:42.82886809
# epoch 324 loss_pde:0.05348502, loss_ic:4.27411642
# loss_tot:42.79464922
# epoch 325 loss_pde:0.05425258, loss_ic:4.27061428
# loss_tot:42.76039536
# epoch 326 loss_pde:0.05503294, loss_ic:4.26710741
# loss_tot:42.72610700
# epoch 327 loss_pde:0.05582613, loss_ic:4.26359585
# loss_tot:42.69178462
# epoch 328 loss_pde:0.05663218, loss_ic:4.26007965
# loss_tot:42.65742870
# epoch 329 loss_pde:0.05745113, loss_ic:4.25655886
# loss_tot:42.62303976
# epoch 330 loss_pde:0.05828298, loss_ic:4.25303353
# loss_tot:42.58861828
# epoch 331 loss_pde:0.05912776, loss_ic:4.24950370
# loss_tot:42.55416478
# epoch 332 loss_pde:0.05998549, loss_ic:4.24596943
# loss_tot:42.51967976
# epoch 333 loss_pde:0.06085616, loss_ic:4.24243076
# loss_tot:42.48516374
# epoch 334 loss_pde:0.06173980, loss_ic:4.23888774
# loss_tot:42.45061723
# epoch 335 loss_pde:0.06263640, loss_ic:4.23534044
# loss_tot:42.41604077
# epoch 336 loss_pde:0.06354595, loss_ic:4.23178889
# loss_tot:42.38143485
# epoch 337 loss_pde:0.06446845, loss_ic:4.22823316
# loss_tot:42.34680002
# epoch 338 loss_pde:0.06540389, loss_ic:4.22467329
# loss_tot:42.31213680
# epoch 339 loss_pde:0.06635224, loss_ic:4.22110935
# loss_tot:42.27744570
# epoch 340 loss_pde:0.06731349, loss_ic:4.21754138
# loss_tot:42.24272725
# epoch 341 loss_pde:0.06828761, loss_ic:4.21396944
# loss_tot:42.20798197
# epoch 342 loss_pde:0.06927457, loss_ic:4.21039358
# loss_tot:42.17321039
# epoch 343 loss_pde:0.07027433, loss_ic:4.20681387
# loss_tot:42.13841301
# epoch 344 loss_pde:0.07128685, loss_ic:4.20323035
# loss_tot:42.10359036
# epoch 345 loss_pde:0.07231209, loss_ic:4.19964309
# loss_tot:42.06874295
# epoch 346 loss_pde:0.07334999, loss_ic:4.19605213
# loss_tot:42.03387127
# epoch 347 loss_pde:0.07440050, loss_ic:4.19245753
# loss_tot:41.99897583
# epoch 348 loss_pde:0.07546356, loss_ic:4.18885936
# loss_tot:41.96405712
# epoch 349 loss_pde:0.07653911, loss_ic:4.18525765
# loss_tot:41.92911563
# epoch 350 loss_pde:0.07762708, loss_ic:4.18165248
# loss_tot:41.89415184
# epoch 351 loss_pde:0.07872738, loss_ic:4.17804388
# loss_tot:41.85916621
# epoch 352 loss_pde:0.07983995, loss_ic:4.17443193
# loss_tot:41.82415921
# epoch 353 loss_pde:0.08096470, loss_ic:4.17081666
# loss_tot:41.78913129
# epoch 354 loss_pde:0.08210154, loss_ic:4.16719813
# loss_tot:41.75408289
# epoch 355 loss_pde:0.08325038, loss_ic:4.16357640
# loss_tot:41.71901443
# epoch 356 loss_pde:0.08441112, loss_ic:4.15995152
# loss_tot:41.68392633
# epoch 357 loss_pde:0.08558365, loss_ic:4.15632354
# loss_tot:41.64881900
# epoch 358 loss_pde:0.08676787, loss_ic:4.15269250
# loss_tot:41.61369283
# epoch 359 loss_pde:0.08796367, loss_ic:4.14905845
# loss_tot:41.57854818
# epoch 360 loss_pde:0.08917093, loss_ic:4.14542145
# loss_tot:41.54338542
# epoch 361 loss_pde:0.09038953, loss_ic:4.14178154
# loss_tot:41.50820490
# epoch 362 loss_pde:0.09161934, loss_ic:4.13813876
# loss_tot:41.47300693
# epoch 363 loss_pde:0.09286024, loss_ic:4.13449316
# loss_tot:41.43779182
# epoch 364 loss_pde:0.09411209, loss_ic:4.13084478
# loss_tot:41.40255987
# epoch 365 loss_pde:0.09537476, loss_ic:4.12719366
# loss_tot:41.36731135
# epoch 366 loss_pde:0.09664809, loss_ic:4.12353984
# loss_tot:41.33204650
# epoch 367 loss_pde:0.09793195, loss_ic:4.11988336
# loss_tot:41.29676557
# epoch 368 loss_pde:0.09922618, loss_ic:4.11622426
# loss_tot:41.26146876
# epoch 369 loss_pde:0.10053063, loss_ic:4.11256256
# loss_tot:41.22615626
# epoch 370 loss_pde:0.10184513, loss_ic:4.10889831
# loss_tot:41.19082823
# epoch 371 loss_pde:0.10316954, loss_ic:4.10523153
# loss_tot:41.15548482
# epoch 372 loss_pde:0.10450367, loss_ic:4.10156225
# loss_tot:41.12012616
# epoch 373 loss_pde:0.10584737, loss_ic:4.09789050
# loss_tot:41.08475233
# epoch 374 loss_pde:0.10720045, loss_ic:4.09421630
# loss_tot:41.04936342
# epoch 375 loss_pde:0.10856274, loss_ic:4.09053967
# loss_tot:41.01395946
# epoch 376 loss_pde:0.10993407, loss_ic:4.08686064
# loss_tot:40.97854049
# epoch 377 loss_pde:0.11131424, loss_ic:4.08317923
# loss_tot:40.94310650
# epoch 378 loss_pde:0.11270307, loss_ic:4.07949544
# loss_tot:40.90765746
# epoch 379 loss_pde:0.11410037, loss_ic:4.07580929
# loss_tot:40.87219332
# epoch 380 loss_pde:0.11550596, loss_ic:4.07212080
# loss_tot:40.83671399
# epoch 381 loss_pde:0.11691962, loss_ic:4.06842998
# loss_tot:40.80121938
# epoch 382 loss_pde:0.11834118, loss_ic:4.06473682
# loss_tot:40.76570934
# epoch 383 loss_pde:0.11977042, loss_ic:4.06104133
# loss_tot:40.73018372
# epoch 384 loss_pde:0.12120715, loss_ic:4.05734352
# loss_tot:40.69464232
# epoch 385 loss_pde:0.12265115, loss_ic:4.05364338
# loss_tot:40.65908495
# epoch 386 loss_pde:0.12410224, loss_ic:4.04994091
# loss_tot:40.62351134
# epoch 387 loss_pde:0.12556019, loss_ic:4.04623611
# loss_tot:40.58792124
# epoch 388 loss_pde:0.12702480, loss_ic:4.04252896
# loss_tot:40.55231436
# epoch 389 loss_pde:0.12849586, loss_ic:4.03881945
# loss_tot:40.51669037
# epoch 390 loss_pde:0.12997315, loss_ic:4.03510758
# loss_tot:40.48104893
# epoch 391 loss_pde:0.13145647, loss_ic:4.03139332
# loss_tot:40.44538967
# epoch 392 loss_pde:0.13294561, loss_ic:4.02767666
# loss_tot:40.40971218
# epoch 393 loss_pde:0.13444035, loss_ic:4.02395757
# loss_tot:40.37401606
# epoch 394 loss_pde:0.13594047, loss_ic:4.02023604
# loss_tot:40.33830086
# epoch 395 loss_pde:0.13744578, loss_ic:4.01651203
# loss_tot:40.30256611
# epoch 396 loss_pde:0.13895605, loss_ic:4.01278553
# loss_tot:40.26681133
# epoch 397 loss_pde:0.14047107, loss_ic:4.00905649
# loss_tot:40.23103599
# epoch 398 loss_pde:0.14199065, loss_ic:4.00532489
# loss_tot:40.19523958
# epoch 399 loss_pde:0.14351457, loss_ic:4.00159070
# loss_tot:40.15942154
# epoch 400 loss_pde:0.14504263, loss_ic:3.99785387
# loss_tot:40.12358130
# epoch 401 loss_pde:0.14657463, loss_ic:3.99411437
# loss_tot:40.08771828
# epoch 402 loss_pde:0.14811037, loss_ic:3.99037215
# loss_tot:40.05183188
# epoch 403 loss_pde:0.14964966, loss_ic:3.98662718
# loss_tot:40.01592148
# epoch 404 loss_pde:0.15119232, loss_ic:3.98287941
# loss_tot:39.97998644
# epoch 405 loss_pde:0.15273815, loss_ic:3.97912880
# loss_tot:39.94402614
# epoch 406 loss_pde:0.15428699, loss_ic:3.97537529
# loss_tot:39.90803991
# epoch 407 loss_pde:0.15583865, loss_ic:3.97161884
# loss_tot:39.87202710
# epoch 408 loss_pde:0.15739299, loss_ic:3.96785941
# loss_tot:39.83598704
# epoch 409 loss_pde:0.15894983, loss_ic:3.96409692
# loss_tot:39.79991906
# epoch 410 loss_pde:0.16050905, loss_ic:3.96033134
# loss_tot:39.76382249
# epoch 411 loss_pde:0.16207049, loss_ic:3.95656262
# loss_tot:39.72769664
# epoch 412 loss_pde:0.16363404, loss_ic:3.95279068
# loss_tot:39.69154085
# epoch 413 loss_pde:0.16519957, loss_ic:3.94901549
# loss_tot:39.65535444
# epoch 414 loss_pde:0.16676699, loss_ic:3.94523698
# loss_tot:39.61913674
# epoch 415 loss_pde:0.16833621, loss_ic:3.94145509
# loss_tot:39.58288710
# epoch 416 loss_pde:0.16990716, loss_ic:3.93766977
# loss_tot:39.54660486
# epoch 417 loss_pde:0.17147976, loss_ic:3.93388096
# loss_tot:39.51028938
# epoch 418 loss_pde:0.17305399, loss_ic:3.93008861
# loss_tot:39.47394004
# epoch 419 loss_pde:0.17462982, loss_ic:3.92629264
# loss_tot:39.43755624
# epoch 420 loss_pde:0.17620725, loss_ic:3.92249301
# loss_tot:39.40113737
# epoch 421 loss_pde:0.17778628, loss_ic:3.91868966
# loss_tot:39.36468286
# epoch 422 loss_pde:0.17936697, loss_ic:3.91488252
# loss_tot:39.32819219
# epoch 423 loss_pde:0.18094936, loss_ic:3.91107154
# loss_tot:39.29166481
# epoch 424 loss_pde:0.18253355, loss_ic:3.90725667
# loss_tot:39.25510025
# epoch 425 loss_pde:0.18411965, loss_ic:3.90343784
# loss_tot:39.21849803
# epoch 426 loss_pde:0.18570780, loss_ic:3.89961499
# loss_tot:39.18185774
# epoch 427 loss_pde:0.18729816, loss_ic:3.89578808
# loss_tot:39.14517897
# epoch 428 loss_pde:0.18889095, loss_ic:3.89195704
# loss_tot:39.10846138
# epoch 429 loss_pde:0.19048638, loss_ic:3.88812183
# loss_tot:39.07170465
# epoch 430 loss_pde:0.19208473, loss_ic:3.88428238
# loss_tot:39.03490851
# epoch 431 loss_pde:0.19368630, loss_ic:3.88043864
# loss_tot:38.99807272
# epoch 432 loss_pde:0.19529144, loss_ic:3.87659057
# loss_tot:38.96119711
# epoch 433 loss_pde:0.19690053, loss_ic:3.87273810
# loss_tot:38.92428155
# epoch 434 loss_pde:0.19851398, loss_ic:3.86888120
# loss_tot:38.88732596
# epoch 435 loss_pde:0.20013227, loss_ic:3.86501980
# loss_tot:38.85033031
# epoch 436 loss_pde:0.20175591, loss_ic:3.86115387
# loss_tot:38.81329463
# epoch 437 loss_pde:0.20338546, loss_ic:3.85728336
# loss_tot:38.77621902
# epoch 438 loss_pde:0.20502153, loss_ic:3.85340821
# loss_tot:38.73910361
# epoch 439 loss_pde:0.20666478, loss_ic:3.84952838
# loss_tot:38.70194861
# epoch 440 loss_pde:0.20831593, loss_ic:3.84564384
# loss_tot:38.66475430
# epoch 441 loss_pde:0.20997575, loss_ic:3.84175453
# loss_tot:38.62752101
# epoch 442 loss_pde:0.21164508, loss_ic:3.83786041
# loss_tot:38.59024916
# epoch 443 loss_pde:0.21332481, loss_ic:3.83396144
# loss_tot:38.55293920
# epoch 444 loss_pde:0.21501588, loss_ic:3.83005758
# loss_tot:38.51559169
# epoch 445 loss_pde:0.21671934, loss_ic:3.82614879
# loss_tot:38.47820724
# epoch 446 loss_pde:0.21843626, loss_ic:3.82223503
# loss_tot:38.44078654
# epoch 447 loss_pde:0.22016780, loss_ic:3.81831626
# loss_tot:38.40333036
# epoch 448 loss_pde:0.22191520, loss_ic:3.81439243
# loss_tot:38.36583954
# epoch 449 loss_pde:0.22367977, loss_ic:3.81046352
# loss_tot:38.32831500
# epoch 450 loss_pde:0.22546290, loss_ic:3.80652948
# loss_tot:38.29075774
# epoch 451 loss_pde:0.22726606, loss_ic:3.80259028
# loss_tot:38.25316886
# epoch 452 loss_pde:0.22909081, loss_ic:3.79864587
# loss_tot:38.21554953
# epoch 453 loss_pde:0.23093878, loss_ic:3.79469622
# loss_tot:38.17790101
# epoch 454 loss_pde:0.23281170, loss_ic:3.79074129
# loss_tot:38.14022464
# epoch 455 loss_pde:0.23471142, loss_ic:3.78678104
# loss_tot:38.10252187
# epoch 456 loss_pde:0.23663984, loss_ic:3.78281544
# loss_tot:38.06479423
# epoch 457 loss_pde:0.23859900, loss_ic:3.77884444
# loss_tot:38.02704337
# epoch 458 loss_pde:0.24059102, loss_ic:3.77486800
# loss_tot:37.98927102
# epoch 459 loss_pde:0.24261814, loss_ic:3.77088609
# loss_tot:37.95147902
# epoch 460 loss_pde:0.24468270, loss_ic:3.76689866
# loss_tot:37.91366932
# epoch 461 loss_pde:0.24678717, loss_ic:3.76290568
# loss_tot:37.87584399
# epoch 462 loss_pde:0.24893413, loss_ic:3.75890711
# loss_tot:37.83800520
# epoch 463 loss_pde:0.25112628, loss_ic:3.75490290
# loss_tot:37.80015526
# epoch 464 loss_pde:0.25336647, loss_ic:3.75089301
# loss_tot:37.76229660
# epoch 465 loss_pde:0.25565764, loss_ic:3.74687741
# loss_tot:37.72443179
# epoch 466 loss_pde:0.25800292, loss_ic:3.74285606
# loss_tot:37.68656353
# epoch 467 loss_pde:0.26040554, loss_ic:3.73882891
# loss_tot:37.64869467
# epoch 468 loss_pde:0.26286889, loss_ic:3.73479593
# loss_tot:37.61082823
# epoch 469 loss_pde:0.26539653, loss_ic:3.73075708
# loss_tot:37.57296737
# epoch 470 loss_pde:0.26799215, loss_ic:3.72671233
# loss_tot:37.53511544
# epoch 471 loss_pde:0.27065961, loss_ic:3.72266164
# loss_tot:37.49727597
# epoch 472 loss_pde:0.27340296, loss_ic:3.71860497
# loss_tot:37.45945268
# epoch 473 loss_pde:0.27622639, loss_ic:3.71454231
# loss_tot:37.42164948
# epoch 474 loss_pde:0.27913430, loss_ic:3.71047362
# loss_tot:37.38387051
# epoch 475 loss_pde:0.28213126, loss_ic:3.70639889
# loss_tot:37.34612015
# epoch 476 loss_pde:0.28522202, loss_ic:3.70231810
# loss_tot:37.30840298
# epoch 477 loss_pde:0.28841155, loss_ic:3.69823123
# loss_tot:37.27072388
# epoch 478 loss_pde:0.29170500, loss_ic:3.69413830
# loss_tot:37.23308796
# epoch 479 loss_pde:0.29510774, loss_ic:3.69003929
# loss_tot:37.19550064
# epoch 480 loss_pde:0.29862533, loss_ic:3.68593423
# loss_tot:37.15796763
# epoch 481 loss_pde:0.30226357, loss_ic:3.68182314
# loss_tot:37.12049495
# epoch 482 loss_pde:0.30602846, loss_ic:3.67770605
# loss_tot:37.08308896
# epoch 483 loss_pde:0.30992622, loss_ic:3.67358302
# loss_tot:37.04575637
# epoch 484 loss_pde:0.31396328, loss_ic:3.66945410
# loss_tot:37.00850426
# epoch 485 loss_pde:0.31814633, loss_ic:3.66531937
# loss_tot:36.97134007
# epoch 486 loss_pde:0.32248222, loss_ic:3.66117895
# loss_tot:36.93427168
# epoch 487 loss_pde:0.32697805, loss_ic:3.65703293
# loss_tot:36.89730735
# epoch 488 loss_pde:0.33164111, loss_ic:3.65288147
# loss_tot:36.86045579
# epoch 489 loss_pde:0.33647891, loss_ic:3.64872472
# loss_tot:36.82372616
# epoch 490 loss_pde:0.34149913, loss_ic:3.64456290
# loss_tot:36.78712808
# epoch 491 loss_pde:0.34670959, loss_ic:3.64039620
# loss_tot:36.75067164
# epoch 492 loss_pde:0.35211831, loss_ic:3.63622491
# loss_tot:36.71436741
# epoch 493 loss_pde:0.35773340, loss_ic:3.63204931
# loss_tot:36.67822645
# epoch 494 loss_pde:0.36356305, loss_ic:3.62786973
# loss_tot:36.64226032
# epoch 495 loss_pde:0.36961552, loss_ic:3.62368655
# loss_tot:36.60648104
# epoch 496 loss_pde:0.37589906, loss_ic:3.61950021
# loss_tot:36.57090113
# epoch 497 loss_pde:0.38242187, loss_ic:3.61531117
# loss_tot:36.53553357
# epoch 498 loss_pde:0.38919201, loss_ic:3.61111998
# loss_tot:36.50039178
# epoch 499 loss_pde:0.39621738, loss_ic:3.60692722
# loss_tot:36.46548960
# epoch 500 loss_pde:0.40350554, loss_ic:3.60273357
# loss_tot:36.43084121
# epoch 501 loss_pde:0.41106369, loss_ic:3.59853974
# loss_tot:36.39646114
# epoch 502 loss_pde:0.41889851, loss_ic:3.59434656
# loss_tot:36.36236414
# epoch 503 loss_pde:0.42701600, loss_ic:3.59015491
# loss_tot:36.32856513
# epoch 504 loss_pde:0.43542139, loss_ic:3.58596577
# loss_tot:36.29507911
# epoch 505 loss_pde:0.44411891, loss_ic:3.58178021
# loss_tot:36.26192102
# epoch 506 loss_pde:0.45311161, loss_ic:3.57759940
# loss_tot:36.22910561
# epoch 507 loss_pde:0.46240118, loss_ic:3.57342461
# loss_tot:36.19664729
# epoch 508 loss_pde:0.47198765, loss_ic:3.56925723
# loss_tot:36.16455994
# epoch 509 loss_pde:0.48186923, loss_ic:3.56509875
# loss_tot:36.13285674
# epoch 510 loss_pde:0.49204196, loss_ic:3.56095080
# loss_tot:36.10154991
# epoch 511 loss_pde:0.50249948, loss_ic:3.55681510
# loss_tot:36.07065048
# epoch 512 loss_pde:0.51323273, loss_ic:3.55269353
# loss_tot:36.04016806
# epoch 513 loss_pde:0.52422969, loss_ic:3.54858808
# loss_tot:36.01011054
# epoch 514 loss_pde:0.53547506, loss_ic:3.54450088
# loss_tot:35.98048382
# epoch 515 loss_pde:0.54695002, loss_ic:3.54043415
# loss_tot:35.95129155
# epoch 516 loss_pde:0.55863204, loss_ic:3.53639028
# loss_tot:35.92253486
# epoch 517 loss_pde:0.57049467, loss_ic:3.53237174
# loss_tot:35.89421210
# epoch 518 loss_pde:0.58250744, loss_ic:3.52838112
# loss_tot:35.86631867
# epoch 519 loss_pde:0.59463585, loss_ic:3.52442110
# loss_tot:35.83884683
# epoch 520 loss_pde:0.60684146, loss_ic:3.52049442
# loss_tot:35.81178566
# epoch 521 loss_pde:0.61908209, loss_ic:3.51660389
# loss_tot:35.78512099
# epoch 522 loss_pde:0.63131217, loss_ic:3.51275234
# loss_tot:35.75883559
# epoch 523 loss_pde:0.64348326, loss_ic:3.50894260
# loss_tot:35.73290928
# epoch 524 loss_pde:0.65554466, loss_ic:3.50517746
# loss_tot:35.70731930
# epoch 525 loss_pde:0.66744429, loss_ic:3.50145964
# loss_tot:35.68204073
# epoch 526 loss_pde:0.67912959, loss_ic:3.49779174
# loss_tot:35.65704700
# epoch 527 loss_pde:0.69054857, loss_ic:3.49417620
# loss_tot:35.63231052
# epoch 528 loss_pde:0.70165096, loss_ic:3.49061524
# loss_tot:35.60780337
# epoch 529 loss_pde:0.71238935, loss_ic:3.48711086
# loss_tot:35.58349795
# epoch 530 loss_pde:0.72272028, loss_ic:3.48366474
# loss_tot:35.55936767
# epoch 531 loss_pde:0.73260525, loss_ic:3.48027823
# loss_tot:35.53538756
# epoch 532 loss_pde:0.74201158, loss_ic:3.47695231
# loss_tot:35.51153472
# epoch 533 loss_pde:0.75091303, loss_ic:3.47368757
# loss_tot:35.48778871
# epoch 534 loss_pde:0.75929016, loss_ic:3.47048415
# loss_tot:35.46413165
# epoch 535 loss_pde:0.76713047, loss_ic:3.46734178
# loss_tot:35.44054829
# epoch 536 loss_pde:0.77442821, loss_ic:3.46425976
# loss_tot:35.41702577
# epoch 537 loss_pde:0.78118397, loss_ic:3.46123693
# loss_tot:35.39355331
# epoch 538 loss_pde:0.78740405, loss_ic:3.45827177
# loss_tot:35.37012178
# epoch 539 loss_pde:0.79309969, loss_ic:3.45536235
# loss_tot:35.34672318
# epoch 540 loss_pde:0.79828619, loss_ic:3.45250640
# loss_tot:35.32335018
# epoch 541 loss_pde:0.80298201, loss_ic:3.44970136
# loss_tot:35.29999558
# epoch 542 loss_pde:0.80720791, loss_ic:3.44694441
# loss_tot:35.27665199
# epoch 543 loss_pde:0.81098616, loss_ic:3.44423253
# loss_tot:35.25331150
# epoch 544 loss_pde:0.81433987, loss_ic:3.44156257
# loss_tot:35.22996555
# epoch 545 loss_pde:0.81729242, loss_ic:3.43893124
# loss_tot:35.20660487
# epoch 546 loss_pde:0.81986704, loss_ic:3.43633525
# loss_tot:35.18321957
# epoch 547 loss_pde:0.82208652, loss_ic:3.43377128
# loss_tot:35.15979927
# epoch 548 loss_pde:0.82397302, loss_ic:3.43123603
# loss_tot:35.13633336
# epoch 549 loss_pde:0.82554794, loss_ic:3.42872633
# loss_tot:35.11281119
# epoch 550 loss_pde:0.82683184, loss_ic:3.42623905
# loss_tot:35.08922238
# epoch 551 loss_pde:0.82784446, loss_ic:3.42377125
# loss_tot:35.06555699
# epoch 552 loss_pde:0.82860465, loss_ic:3.42132011
# loss_tot:35.04180576
# epoch 553 loss_pde:0.82913038, loss_ic:3.41888298
# loss_tot:35.01796020
# epoch 554 loss_pde:0.82943871, loss_ic:3.41645740
# loss_tot:34.99401268
# epoch 555 loss_pde:0.82954573, loss_ic:3.41404107
# loss_tot:34.96995642
# epoch 556 loss_pde:0.82946650, loss_ic:3.41163190
# loss_tot:34.94578548
# epoch 557 loss_pde:0.82921502, loss_ic:3.40922796
# loss_tot:34.92149466
# epoch 558 loss_pde:0.82880412, loss_ic:3.40682752
# loss_tot:34.89707934
# epoch 559 loss_pde:0.82824545, loss_ic:3.40442900
# loss_tot:34.87253540
# epoch 560 loss_pde:0.82754941, loss_ic:3.40203096
# loss_tot:34.84785903
# epoch 561 loss_pde:0.82672519, loss_ic:3.39963214
# loss_tot:34.82304660
# epoch 562 loss_pde:0.82578077, loss_ic:3.39723138
# loss_tot:34.79809453
# epoch 563 loss_pde:0.82472301, loss_ic:3.39482762
# loss_tot:34.77299922
# epoch 564 loss_pde:0.82355777, loss_ic:3.39241992
# loss_tot:34.74775694
# epoch 565 loss_pde:0.82229007, loss_ic:3.39000738
# loss_tot:34.72236384
# epoch 566 loss_pde:0.82092427, loss_ic:3.38758917
# loss_tot:34.69681593
# epoch 567 loss_pde:0.81946427, loss_ic:3.38516448
# loss_tot:34.67110909
# epoch 568 loss_pde:0.81791378, loss_ic:3.38273254
# loss_tot:34.64523916
# epoch 569 loss_pde:0.81627649, loss_ic:3.38029255
# loss_tot:34.61920198
# epoch 570 loss_pde:0.81455630, loss_ic:3.37784372
# loss_tot:34.59299346
# epoch 571 loss_pde:0.81275747, loss_ic:3.37538522
# loss_tot:34.56660966
# epoch 572 loss_pde:0.81088479, loss_ic:3.37291621
# loss_tot:34.54004686
# epoch 573 loss_pde:0.80894359, loss_ic:3.37043580
# loss_tot:34.51330158
# epoch 574 loss_pde:0.80693985, loss_ic:3.36794308
# loss_tot:34.48637063
# epoch 575 loss_pde:0.80488008, loss_ic:3.36543710
# loss_tot:34.45925111
# epoch 576 loss_pde:0.80277128, loss_ic:3.36291691
# loss_tot:34.43194041
# epoch 577 loss_pde:0.80062078, loss_ic:3.36038154
# loss_tot:34.40443621
# epoch 578 loss_pde:0.79843608, loss_ic:3.35783004
# loss_tot:34.37673643
# epoch 579 loss_pde:0.79622465, loss_ic:3.35526146
# loss_tot:34.34883925
# epoch 580 loss_pde:0.79399368, loss_ic:3.35267494
# loss_tot:34.32074304
# epoch 581 loss_pde:0.79174992, loss_ic:3.35006965
# loss_tot:34.29244643
# epoch 582 loss_pde:0.78949945, loss_ic:3.34744489
# loss_tot:34.26394831
# epoch 583 loss_pde:0.78724749, loss_ic:3.34480003
# loss_tot:34.23524783
# epoch 584 loss_pde:0.78499827, loss_ic:3.34213463
# loss_tot:34.20634454
# epoch 585 loss_pde:0.78275489, loss_ic:3.33944835
# loss_tot:34.17723841
# epoch 586 loss_pde:0.78051926, loss_ic:3.33674107
# loss_tot:34.14792995
# epoch 587 loss_pde:0.77829201, loss_ic:3.33401283
# loss_tot:34.11842036
# epoch 588 loss_pde:0.77607256, loss_ic:3.33126391
# loss_tot:34.08871166
# epoch 589 loss_pde:0.77385907, loss_ic:3.32849478
# loss_tot:34.05880685
# epoch 590 loss_pde:0.77164858, loss_ic:3.32570615
# loss_tot:34.02871011
# epoch 591 loss_pde:0.76943714, loss_ic:3.32289900
# loss_tot:33.99842712
# epoch 592 loss_pde:0.76722008, loss_ic:3.32007453
# loss_tot:33.96796539
# epoch 593 loss_pde:0.76499231, loss_ic:3.31723426
# loss_tot:33.93733489
# epoch 594 loss_pde:0.76274890, loss_ic:3.31438000
# loss_tot:33.90654889
# epoch 595 loss_pde:0.76048591, loss_ic:3.31151395
# loss_tot:33.87562546
# epoch 596 loss_pde:0.75820168, loss_ic:3.30863881
# loss_tot:33.84458976
# epoch 597 loss_pde:0.75589885, loss_ic:3.30575793
# loss_tot:33.81347813
# epoch 598 loss_pde:0.75358772, loss_ic:3.30287573
# loss_tot:33.78234502
# epoch 599 loss_pde:0.75129180, loss_ic:3.29999837
# loss_tot:33.75127547
# epoch 600 loss_pde:0.74905724, loss_ic:3.29713507
# loss_tot:33.72040798
# epoch 601 loss_pde:0.74696758, loss_ic:3.29430091
# loss_tot:33.68997669
# epoch 602 loss_pde:0.74515670, loss_ic:3.29152258
# loss_tot:33.66038254
# epoch 603 loss_pde:0.74374315, loss_ic:3.28885106
# loss_tot:33.63225376
# epoch 604 loss_pde:0.74225414, loss_ic:3.28638556
# loss_tot:33.60610970
# epoch 605 loss_pde:0.73837100, loss_ic:3.28427671
# loss_tot:33.58113812
# epoch 606 loss_pde:0.73286310, loss_ic:3.28250574
# loss_tot:33.55792049
# epoch 607 loss_pde:0.72880101, loss_ic:3.28078330
# loss_tot:33.53663403
# epoch 608 loss_pde:0.72376247, loss_ic:3.27897256
# loss_tot:33.51348808
# epoch 609 loss_pde:0.71771077, loss_ic:3.27712372
# loss_tot:33.48894795
# epoch 610 loss_pde:0.70591326, loss_ic:3.27574505
# loss_tot:33.46336379
# epoch 611 loss_pde:0.69140501, loss_ic:3.27466147
# loss_tot:33.43801974
# epoch 612 loss_pde:0.67938421, loss_ic:3.27345675
# loss_tot:33.41395172
# epoch 613 loss_pde:0.67034889, loss_ic:3.27206820
# loss_tot:33.39103085
# epoch 614 loss_pde:0.66426117, loss_ic:3.27055941
# loss_tot:33.36985527
# epoch 615 loss_pde:0.65937828, loss_ic:3.26903690
# loss_tot:33.34974724
# epoch 616 loss_pde:0.65456390, loss_ic:3.26752158
# loss_tot:33.32977966
# epoch 617 loss_pde:0.65068820, loss_ic:3.26592591
# loss_tot:33.30994729
# epoch 618 loss_pde:0.64853009, loss_ic:3.26416054
# loss_tot:33.29013548
# epoch 619 loss_pde:0.64824835, loss_ic:3.26218466
# loss_tot:33.27009494
# epoch 620 loss_pde:0.64975300, loss_ic:3.26000751
# loss_tot:33.24982812
# epoch 621 loss_pde:0.65283614, loss_ic:3.25768622
# loss_tot:33.22969832
# epoch 622 loss_pde:0.65685204, loss_ic:3.25533080
# loss_tot:33.21016004
# epoch 623 loss_pde:0.66025670, loss_ic:3.25308332
# loss_tot:33.19108985
# epoch 624 loss_pde:0.66300673, loss_ic:3.25096742
# loss_tot:33.17268090
# epoch 625 loss_pde:0.66680581, loss_ic:3.24884126
# loss_tot:33.15521837
# epoch 626 loss_pde:0.67158112, loss_ic:3.24663599
# loss_tot:33.13794099
# epoch 627 loss_pde:0.67671175, loss_ic:3.24445886
# loss_tot:33.12130032
# epoch 628 loss_pde:0.67742684, loss_ic:3.24269864
# loss_tot:33.10441321
# epoch 629 loss_pde:0.67903490, loss_ic:3.24085171
# loss_tot:33.08755197
# epoch 630 loss_pde:0.68150125, loss_ic:3.23894896
# loss_tot:33.07099080
# epoch 631 loss_pde:0.67963203, loss_ic:3.23746669
# loss_tot:33.05429896
# epoch 632 loss_pde:0.67937672, loss_ic:3.23587591
# loss_tot:33.03813580
# epoch 633 loss_pde:0.68056364, loss_ic:3.23415953
# loss_tot:33.02215896
# epoch 634 loss_pde:0.68159083, loss_ic:3.23252083
# loss_tot:33.00679908
# epoch 635 loss_pde:0.68089441, loss_ic:3.23105373
# loss_tot:32.99143176
# epoch 636 loss_pde:0.68125138, loss_ic:3.22952320
# loss_tot:32.97648340
# epoch 637 loss_pde:0.68300316, loss_ic:3.22784449
# loss_tot:32.96144808
# epoch 638 loss_pde:0.68580139, loss_ic:3.22607773
# loss_tot:32.94657871
# epoch 639 loss_pde:0.68791881, loss_ic:3.22438738
# loss_tot:32.93179261
# epoch 640 loss_pde:0.68918256, loss_ic:3.22279042
# loss_tot:32.91708677
# epoch 641 loss_pde:0.69158879, loss_ic:3.22110511
# loss_tot:32.90263985
# epoch 642 loss_pde:0.69527110, loss_ic:3.21929890
# loss_tot:32.88826009
# epoch 643 loss_pde:0.69840035, loss_ic:3.21757945
# loss_tot:32.87419486
# epoch 644 loss_pde:0.70034200, loss_ic:3.21602469
# loss_tot:32.86058895
# epoch 645 loss_pde:0.70470879, loss_ic:3.21421171
# loss_tot:32.84682590
# epoch 646 loss_pde:0.70734564, loss_ic:3.21327536
# loss_tot:32.84009920
# epoch 647 loss_pde:0.70687502, loss_ic:3.21200656
# loss_tot:32.82694059
# epoch 648 loss_pde:0.70454368, loss_ic:3.21035636
# loss_tot:32.80810730
# epoch 649 loss_pde:0.81505645, loss_ic:3.20832103
# loss_tot:32.89826673
# epoch 650 loss_pde:1.21918280, loss_ic:3.15744818
# loss_tot:32.79366455
# epoch 651 loss_pde:24.74327013, loss_ic:3.17957795
# loss_tot:56.53904959
# epoch 652 loss_pde:0.70392031, loss_ic:3.72670686
# loss_tot:37.97098887
# epoch 653 loss_pde:1.77244977, loss_ic:4.34573037
# loss_tot:45.22975346
# epoch 654 loss_pde:3.41085804, loss_ic:4.91804423
# loss_tot:52.59130039
# epoch 655 loss_pde:4.85893816, loss_ic:5.38894599
# loss_tot:58.74839809
# epoch 656 loss_pde:5.69119565, loss_ic:5.74757091
# loss_tot:63.16690473
# epoch 657 loss_pde:5.86233717, loss_ic:6.00584994
# loss_tot:65.92083654
# epoch 658 loss_pde:5.56064562, loss_ic:6.18402304
# loss_tot:67.40087605
# epoch 659 loss_pde:5.02585088, loss_ic:6.30274367
# loss_tot:68.05328758
# epoch 660 loss_pde:4.43706976, loss_ic:6.37960002
# loss_tot:68.23306996
# epoch 661 loss_pde:3.88983492, loss_ic:6.42810988
# loss_tot:68.17093371
# epoch 662 loss_pde:3.41933797, loss_ic:6.45792868
# loss_tot:67.99862475
# epoch 663 loss_pde:3.02909282, loss_ic:6.47553778
# loss_tot:67.78447065
# epoch 664 loss_pde:2.70991974, loss_ic:6.48502848
# loss_tot:67.56020459
# epoch 665 loss_pde:2.44947604, loss_ic:6.48881076
# loss_tot:67.33758363
# epoch 666 loss_pde:2.23613899, loss_ic:6.48819021
# loss_tot:67.11804105
# epoch 667 loss_pde:2.06018897, loss_ic:6.48380781
# loss_tot:66.89826709
# epoch 668 loss_pde:1.91389409, loss_ic:6.47595650
# loss_tot:66.67345905
# epoch 669 loss_pde:1.79123029, loss_ic:6.46479423
# loss_tot:66.43917262
# epoch 670 loss_pde:1.68753358, loss_ic:6.45047465
# loss_tot:66.19228010
# epoch 671 loss_pde:1.59918761, loss_ic:6.43321537
# loss_tot:65.93134128
# epoch 672 loss_pde:1.52337213, loss_ic:6.41332234
# loss_tot:65.65659549
# epoch 673 loss_pde:1.45786953, loss_ic:6.39118587
# loss_tot:65.36972821
# epoch 674 loss_pde:1.40091925, loss_ic:6.36726051
# loss_tot:65.07352434
# epoch 675 loss_pde:1.35110893, loss_ic:6.34203783
# loss_tot:64.77148725
# epoch 676 loss_pde:1.30729319, loss_ic:6.31601814
# loss_tot:64.46747462
# epoch 677 loss_pde:1.26853279, loss_ic:6.28968482
# loss_tot:64.16538102
# ...
# loss_tot:42.16592890
# epoch 5616 loss_pde:0.11837133, loss_ic:4.20389123
# loss_tot:42.15728360
# epoch 5617 loss_pde:0.11799731, loss_ic:4.20306574
# loss_tot:42.14865474
# epoch 5618 loss_pde:0.11762708, loss_ic:4.20224153
# loss_tot:42.14004233
# epoch 5619 loss_pde:0.11726065, loss_ic:4.20141857
# loss_tot:42.13144638
# epoch 5620 loss_pde:0.11689804, loss_ic:4.20059689
# loss_tot:42.12286689
# epoch 5621 loss_pde:0.11653927, loss_ic:4.19977646
# loss_tot:42.11430389
# epoch 5622 loss_pde:0.11618435, loss_ic:4.19895730
# loss_tot:42.10575737
# epoch 5623 loss_pde:0.11583330, loss_ic:4.19813941
# loss_tot:42.09722735
# epoch 5624 loss_pde:0.11548614, loss_ic:4.19732277
# loss_tot:42.08871384
# epoch 5625 loss_pde:0.11514288, loss_ic:4.19650740
# loss_tot:42.08021685
# epoch 5626 loss_pde:0.11480354, loss_ic:4.19569328
# loss_tot:42.07173639
# epoch 5627 loss_pde:0.11446814, loss_ic:4.19488043
# loss_tot:42.06327248
# epoch 5628 loss_pde:0.11413669, loss_ic:4.19406884
# loss_tot:42.05482511
# epoch 5629 loss_pde:0.11380921, loss_ic:4.19325851
# loss_tot:42.04639431
# epoch 5630 loss_pde:0.11348572, loss_ic:4.19244944
# loss_tot:42.03798008
# epoch 5631 loss_pde:0.11316622, loss_ic:4.19164162
# loss_tot:42.02958243
# epoch 5632 loss_pde:0.11285074, loss_ic:4.19083506
# loss_tot:42.02120138
# epoch 5633 loss_pde:0.11253929, loss_ic:4.19002976
# loss_tot:42.01283693
# epoch 5634 loss_pde:0.11223188, loss_ic:4.18922572
# loss_tot:42.00448910
# epoch 5635 loss_pde:0.11192854, loss_ic:4.18842294
# loss_tot:41.99615789
# epoch 5636 loss_pde:0.11162928, loss_ic:4.18762140
# loss_tot:41.98784333
# epoch 5637 loss_pde:0.11133410, loss_ic:4.18682113
# loss_tot:41.97954541
# epoch 5638 loss_pde:0.11104304, loss_ic:4.18602211
# loss_tot:41.97126415
# epoch 5639 loss_pde:0.11075609, loss_ic:4.18522435
# loss_tot:41.96299955
# epoch 5640 loss_pde:0.11047329, loss_ic:4.18442784
# loss_tot:41.95475164
# epoch 5641 loss_pde:0.11019463, loss_ic:4.18363258
# loss_tot:41.94652042
# epoch 5642 loss_pde:0.10992014, loss_ic:4.18283858
# loss_tot:41.93830590
# epoch 5643 loss_pde:0.10964982, loss_ic:4.18204583
# loss_tot:41.93010809
# epoch 5644 loss_pde:0.10938370, loss_ic:4.18125433
# loss_tot:41.92192701
# epoch 5645 loss_pde:0.10912179, loss_ic:4.18046409
# loss_tot:41.91376265
# epoch 5646 loss_pde:0.10886410, loss_ic:4.17967509
# loss_tot:41.90561504
# epoch 5647 loss_pde:0.10861065, loss_ic:4.17888735
# loss_tot:41.89748419
# epoch 5648 loss_pde:0.10836144, loss_ic:4.17810087
# loss_tot:41.88937010
# epoch 5649 loss_pde:0.10811649, loss_ic:4.17731563
# loss_tot:41.88127278
# epoch 5650 loss_pde:0.10787582, loss_ic:4.17653164
# loss_tot:41.87319225
# epoch 5651 loss_pde:0.10763943, loss_ic:4.17574891
# loss_tot:41.86512852
# epoch 5652 loss_pde:0.10740734, loss_ic:4.17496742
# loss_tot:41.85708159
# epoch 5653 loss_pde:0.10717957, loss_ic:4.17418719
# loss_tot:41.84905148
# epoch 5654 loss_pde:0.10695612, loss_ic:4.17340821
# loss_tot:41.84103819
# epoch 5655 loss_pde:0.10673701, loss_ic:4.17263047
# loss_tot:41.83304174
# epoch 5656 loss_pde:0.10652224, loss_ic:4.17185399
# loss_tot:41.82506213
# epoch 5657 loss_pde:0.10631184, loss_ic:4.17107875
# loss_tot:41.81709938
# epoch 5658 loss_pde:0.10610581, loss_ic:4.17030477
# loss_tot:41.80915350
# epoch 5659 loss_pde:0.10590416, loss_ic:4.16953203
# loss_tot:41.80122449
# epoch 5660 loss_pde:0.10570690, loss_ic:4.16876055
# loss_tot:41.79331237
# epoch 5661 loss_pde:0.10551405, loss_ic:4.16799031
# loss_tot:41.78541714
# epoch 5662 loss_pde:0.10532562, loss_ic:4.16722132
# loss_tot:41.77753881
# epoch 5663 loss_pde:0.10514161, loss_ic:4.16645358
# loss_tot:41.76967740
# epoch 5664 loss_pde:0.10496204, loss_ic:4.16568709
# loss_tot:41.76183291
# epoch 5665 loss_pde:0.10478692, loss_ic:4.16492184
# loss_tot:41.75400534
# epoch 5666 loss_pde:0.10461625, loss_ic:4.16415785
# loss_tot:41.74619472
# epoch 5667 loss_pde:0.10445005, loss_ic:4.16339510
# loss_tot:41.73840105
# epoch 5668 loss_pde:0.10428833, loss_ic:4.16263360
# loss_tot:41.73062433
# epoch 5669 loss_pde:0.10413108, loss_ic:4.16187335
# loss_tot:41.72286458
# epoch 5670 loss_pde:0.10397834, loss_ic:4.16111435
# loss_tot:41.71512180
# epoch 5671 loss_pde:0.10383009, loss_ic:4.16035659
# loss_tot:41.70739600
# epoch 5672 loss_pde:0.10368635, loss_ic:4.15960008
# loss_tot:41.69968719
# epoch 5673 loss_pde:0.10354713, loss_ic:4.15884482
# loss_tot:41.69199538
# epoch 5674 loss_pde:0.10341244, loss_ic:4.15809081
# loss_tot:41.68432057
# epoch 5675 loss_pde:0.10328228, loss_ic:4.15733805
# loss_tot:41.67666278
# epoch 5676 loss_pde:0.10315666, loss_ic:4.15658653
# loss_tot:41.66902200
# epoch 5677 loss_pde:0.10303559, loss_ic:4.15583627
# loss_tot:41.66139825
# epoch 5678 loss_pde:0.10291907, loss_ic:4.15508725
# loss_tot:41.65379153
# epoch 5679 loss_pde:0.10280711, loss_ic:4.15433947
# loss_tot:41.64620185
# epoch 5680 loss_pde:0.10269972, loss_ic:4.15359295
# loss_tot:41.63862922
# epoch 5681 loss_pde:0.10259691, loss_ic:4.15284767
# loss_tot:41.63107364
# epoch 5682 loss_pde:0.10249866, loss_ic:4.15210364
# loss_tot:41.62353511
# epoch 5683 loss_pde:0.10240501, loss_ic:4.15136086
# loss_tot:41.61601365
# epoch 5684 loss_pde:0.10231594, loss_ic:4.15061933
# loss_tot:41.60850925
# epoch 5685 loss_pde:0.10223146, loss_ic:4.14987905
# loss_tot:41.60102193
# epoch 5686 loss_pde:0.10215158, loss_ic:4.14914001
# loss_tot:41.59355169
# epoch 5687 loss_pde:0.10207630, loss_ic:4.14840222
# loss_tot:41.58609853
# epoch 5688 loss_pde:0.10200562, loss_ic:4.14766568
# loss_tot:41.57866246
# epoch 5689 loss_pde:0.10193955, loss_ic:4.14693039
# loss_tot:41.57124348
# epoch 5690 loss_pde:0.10187809, loss_ic:4.14619635
# loss_tot:41.56384160
# epoch 5691 loss_pde:0.10182125, loss_ic:4.14546356
# loss_tot:41.55645682
# epoch 5692 loss_pde:0.10176902, loss_ic:4.14473201
# loss_tot:41.54908913
# epoch 5693 loss_pde:0.10172140, loss_ic:4.14400172
# loss_tot:41.54173856
# epoch 5694 loss_pde:0.10167841, loss_ic:4.14327267
# loss_tot:41.53440509
# epoch 5695 loss_pde:0.10164003, loss_ic:4.14254487
# loss_tot:41.52708873
# epoch 5696 loss_pde:0.10160628, loss_ic:4.14181832
# loss_tot:41.51978948
# epoch 5697 loss_pde:0.10157714, loss_ic:4.14109302
# loss_tot:41.51250734
# epoch 5698 loss_pde:0.10155263, loss_ic:4.14036897
# loss_tot:41.50524232
# epoch 5699 loss_pde:0.10153273, loss_ic:4.13964617
# loss_tot:41.49799442
# epoch 5700 loss_pde:0.10151746, loss_ic:4.13892462
# loss_tot:41.49076363
# epoch 5701 loss_pde:0.10150680, loss_ic:4.13820432
# loss_tot:41.48354996
# epoch 5702 loss_pde:0.10150077, loss_ic:4.13748526
# loss_tot:41.47635341
# epoch 5703 loss_pde:0.10149935, loss_ic:4.13676746
# loss_tot:41.46917397
# epoch 5704 loss_pde:0.10150254, loss_ic:4.13605091
# loss_tot:41.46201165
# epoch 5705 loss_pde:0.10151034, loss_ic:4.13533561
# loss_tot:41.45486644
# epoch 5706 loss_pde:0.10152275, loss_ic:4.13462156
# loss_tot:41.44773835
# epoch 5707 loss_pde:0.10153976, loss_ic:4.13390876
# loss_tot:41.44062737
# epoch 5708 loss_pde:0.10156137, loss_ic:4.13319721
# loss_tot:41.43353349
# epoch 5709 loss_pde:0.10158758, loss_ic:4.13248691
# loss_tot:41.42645672
# epoch 5710 loss_pde:0.10161838, loss_ic:4.13177787
# loss_tot:41.41939705
# epoch 5711 loss_pde:0.10165376, loss_ic:4.13107007
# loss_tot:41.41235448
# epoch 5712 loss_pde:0.10169373, loss_ic:4.13036353
# loss_tot:41.40532901
# epoch 5713 loss_pde:0.10173826, loss_ic:4.12965824
# loss_tot:41.39832062
# epoch 5714 loss_pde:0.10178737, loss_ic:4.12895419
# loss_tot:41.39132932
# epoch 5715 loss_pde:0.10184103, loss_ic:4.12825141
# loss_tot:41.38435510
# epoch 5716 loss_pde:0.10189925, loss_ic:4.12754987
# loss_tot:41.37739795
# epoch 5717 loss_pde:0.10196201, loss_ic:4.12684958
# loss_tot:41.37045786
# epoch 5718 loss_pde:0.10202931, loss_ic:4.12615055
# loss_tot:41.36353484
# epoch 5719 loss_pde:0.10210114, loss_ic:4.12545277
# loss_tot:41.35662887
# epoch 5720 loss_pde:0.10217748, loss_ic:4.12475625
# loss_tot:41.34973994
# epoch 5721 loss_pde:0.10225834, loss_ic:4.12406097
# loss_tot:41.34286805
# epoch 5722 loss_pde:0.10234369, loss_ic:4.12336695
# loss_tot:41.33601319
# epoch 5723 loss_pde:0.10243353, loss_ic:4.12267418
# loss_tot:41.32917535
# epoch 5724 loss_pde:0.10252784, loss_ic:4.12198267
# loss_tot:41.32235451
# epoch 5725 loss_pde:0.10262662, loss_ic:4.12129240
# loss_tot:41.31555067
# epoch 5726 loss_pde:0.10272985, loss_ic:4.12060340
# loss_tot:41.30876381
# epoch 5727 loss_pde:0.10283753, loss_ic:4.11991564
# loss_tot:41.30199393
# epoch 5728 loss_pde:0.10294962, loss_ic:4.11922914
# loss_tot:41.29524102
# epoch 5729 loss_pde:0.10306613, loss_ic:4.11854389
# loss_tot:41.28850505
# epoch 5730 loss_pde:0.10318704, loss_ic:4.11785990
# loss_tot:41.28178602
# epoch 5731 loss_pde:0.10331233, loss_ic:4.11717716
# loss_tot:41.27508391
# epoch 5732 loss_pde:0.10344199, loss_ic:4.11649567
# loss_tot:41.26839871
# epoch 5733 loss_pde:0.10357600, loss_ic:4.11581544
# loss_tot:41.26173040
# epoch 5734 loss_pde:0.10371434, loss_ic:4.11513646
# loss_tot:41.25507897
# epoch 5735 loss_pde:0.10385701, loss_ic:4.11445874
# loss_tot:41.24844440
# epoch 5736 loss_pde:0.10400397, loss_ic:4.11378227
# loss_tot:41.24182667
# epoch 5737 loss_pde:0.10415522, loss_ic:4.11310706
# loss_tot:41.23522577
# epoch 5738 loss_pde:0.10431073, loss_ic:4.11243309
# loss_tot:41.22864168
# epoch 5739 loss_pde:0.10447049, loss_ic:4.11176039
# loss_tot:41.22207438
# epoch 5740 loss_pde:0.10463448, loss_ic:4.11108894
# loss_tot:41.21552385
# epoch 5741 loss_pde:0.10480267, loss_ic:4.11041874
# loss_tot:41.20899006
# epoch 5742 loss_pde:0.10497504, loss_ic:4.10974980
# loss_tot:41.20247301
# epoch 5743 loss_pde:0.10515158, loss_ic:4.10908211
# loss_tot:41.19597266
# epoch 5744 loss_pde:0.10533226, loss_ic:4.10841567
# loss_tot:41.18948900
# epoch 5745 loss_pde:0.10551705, loss_ic:4.10775050
# loss_tot:41.18302201
# epoch 5746 loss_pde:0.10570595, loss_ic:4.10708657
# loss_tot:41.17657165
# epoch 5747 loss_pde:0.10589891, loss_ic:4.10642390
# loss_tot:41.17013790
# epoch 5748 loss_pde:0.10609593, loss_ic:4.10576248
# loss_tot:41.16372075
# epoch 5749 loss_pde:0.10629696, loss_ic:4.10510232
# loss_tot:41.15732016
# epoch 5750 loss_pde:0.10650200, loss_ic:4.10444341
# loss_tot:41.15093611
# epoch 5751 loss_pde:0.10671100, loss_ic:4.10378576
# loss_tot:41.14456857
# epoch 5752 loss_pde:0.10692395, loss_ic:4.10312936
# loss_tot:41.13821751
# epoch 5753 loss_pde:0.10714082, loss_ic:4.10247421
# loss_tot:41.13188291
# epoch 5754 loss_pde:0.10736158, loss_ic:4.10182031
# loss_tot:41.12556473
# epoch 5755 loss_pde:0.10758620, loss_ic:4.10116767
# loss_tot:41.11926295
# epoch 5756 loss_pde:0.10781466, loss_ic:4.10051629
# loss_tot:41.11297753
# epoch 5757 loss_pde:0.10804691, loss_ic:4.09986615
# loss_tot:41.10670844
# epoch 5758 loss_pde:0.10828294, loss_ic:4.09921727
# loss_tot:41.10045566
# epoch 5759 loss_pde:0.10852272, loss_ic:4.09856964
# loss_tot:41.09421914
# epoch 5760 loss_pde:0.10876620, loss_ic:4.09792327
# loss_tot:41.08799885
# epoch 5761 loss_pde:0.10901337, loss_ic:4.09727814
# loss_tot:41.08179477
# epoch 5762 loss_pde:0.10926418, loss_ic:4.09663427
# loss_tot:41.07560685
# epoch 5763 loss_pde:0.10951860, loss_ic:4.09599165
# loss_tot:41.06943505
# epoch 5764 loss_pde:0.10977660, loss_ic:4.09535027
# loss_tot:41.06327935
# epoch 5765 loss_pde:0.11003815, loss_ic:4.09471015
# loss_tot:41.05713969
# epoch 5766 loss_pde:0.11030321, loss_ic:4.09407128
# loss_tot:41.05101605
# epoch 5767 loss_pde:0.11057175, loss_ic:4.09343366
# loss_tot:41.04490838
# epoch 5768 loss_pde:0.11084372, loss_ic:4.09279729
# loss_tot:41.03881665
# epoch 5769 loss_pde:0.11111909, loss_ic:4.09216217
# loss_tot:41.03274081
# epoch 5770 loss_pde:0.11139783, loss_ic:4.09152830
# loss_tot:41.02668082
# epoch 5771 loss_pde:0.11167989, loss_ic:4.09089567
# loss_tot:41.02063663
# epoch 5772 loss_pde:0.11196525, loss_ic:4.09026430
# loss_tot:41.01460821
# epoch 5773 loss_pde:0.11225385, loss_ic:4.08963417
# loss_tot:41.00859551
# epoch 5774 loss_pde:0.11254565, loss_ic:4.08900528
# loss_tot:41.00259848
# epoch 5775 loss_pde:0.11284063, loss_ic:4.08837764
# loss_tot:40.99661708
# epoch 5776 loss_pde:0.11313873, loss_ic:4.08775125
# loss_tot:40.99065126
# epoch 5777 loss_pde:0.11343992, loss_ic:4.08712610
# loss_tot:40.98470097
# epoch 5778 loss_pde:0.11374415, loss_ic:4.08650220
# loss_tot:40.97876616
# epoch 5779 loss_pde:0.11405138, loss_ic:4.08587954
# loss_tot:40.97284678
# epoch 5780 loss_pde:0.11436156, loss_ic:4.08525812
# loss_tot:40.96694279
# epoch 5781 loss_pde:0.11467466, loss_ic:4.08463795
# loss_tot:40.96105413
# epoch 5782 loss_pde:0.11499062, loss_ic:4.08401901
# loss_tot:40.95518075
# epoch 5783 loss_pde:0.11530941, loss_ic:4.08340132
# loss_tot:40.94932259
# epoch 5784 loss_pde:0.11563097, loss_ic:4.08278486
# loss_tot:40.94347961
# epoch 5785 loss_pde:0.11595526, loss_ic:4.08216965
# loss_tot:40.93765174
# epoch 5786 loss_pde:0.11628224, loss_ic:4.08155567
# loss_tot:40.93183893
# epoch 5787 loss_pde:0.11661184, loss_ic:4.08094293
# loss_tot:40.92604112
# epoch 5788 loss_pde:0.11694404, loss_ic:4.08033142
# loss_tot:40.92025826
# epoch 5789 loss_pde:0.11727877, loss_ic:4.07972115
# loss_tot:40.91449029
# epoch 5790 loss_pde:0.11761599, loss_ic:4.07911212
# loss_tot:40.90873714
# epoch 5791 loss_pde:0.11795565, loss_ic:4.07850431
# loss_tot:40.90299877
# epoch 5792 loss_pde:0.11829769, loss_ic:4.07789774
# loss_tot:40.89727509
# epoch 5793 loss_pde:0.11864207, loss_ic:4.07729240
# loss_tot:40.89156606
# epoch 5794 loss_pde:0.11898874, loss_ic:4.07668829
# loss_tot:40.88587161
# epoch 5795 loss_pde:0.11933763, loss_ic:4.07608540
# loss_tot:40.88019168
# epoch 5796 loss_pde:0.11968871, loss_ic:4.07548375
# loss_tot:40.87452620
# epoch 5797 loss_pde:0.12004191, loss_ic:4.07488332
# loss_tot:40.86887510
# epoch 5798 loss_pde:0.12039719, loss_ic:4.07428411
# loss_tot:40.86323832
# epoch 5799 loss_pde:0.12075448, loss_ic:4.07368613
# loss_tot:40.85761579
# epoch 5800 loss_pde:0.12111373, loss_ic:4.07308937
# loss_tot:40.85200745
# epoch 5801 loss_pde:0.12147489, loss_ic:4.07249383
# loss_tot:40.84641322
# epoch 5802 loss_pde:0.12183790, loss_ic:4.07189951
# loss_tot:40.84083303
# epoch 5803 loss_pde:0.12220271, loss_ic:4.07130641
# loss_tot:40.83526681
# epoch 5804 loss_pde:0.12256925, loss_ic:4.07071452
# loss_tot:40.82971449
# epoch 5805 loss_pde:0.12293748, loss_ic:4.07012385
# loss_tot:40.82417600
# epoch 5806 loss_pde:0.12330732, loss_ic:4.06953439
# loss_tot:40.81865126
# epoch 5807 loss_pde:0.12367873, loss_ic:4.06894615
# loss_tot:40.81314020
# epoch 5808 loss_pde:0.12405164, loss_ic:4.06835911
# loss_tot:40.80764274
# epoch 5809 loss_pde:0.12442599, loss_ic:4.06777328
# loss_tot:40.80215881
# epoch 5810 loss_pde:0.12480173, loss_ic:4.06718866
# loss_tot:40.79668832
# epoch 5811 loss_pde:0.12517880, loss_ic:4.06660524
# loss_tot:40.79123121
# epoch 5812 loss_pde:0.12555713, loss_ic:4.06602303
# loss_tot:40.78578738
# epoch 5813 loss_pde:0.12593665, loss_ic:4.06544201
# loss_tot:40.78035677
# epoch 5814 loss_pde:0.12631732, loss_ic:4.06486220
# loss_tot:40.77493929
# epoch 5815 loss_pde:0.12669907, loss_ic:4.06428358
# loss_tot:40.76953485
# epoch 5816 loss_pde:0.12708183, loss_ic:4.06370615
# loss_tot:40.76414338
# epoch 5817 loss_pde:0.12746555, loss_ic:4.06312992
# loss_tot:40.75876480
# epoch 5818 loss_pde:0.12785015, loss_ic:4.06255489
# loss_tot:40.75339901
# epoch 5819 loss_pde:0.12823558, loss_ic:4.06198104
# loss_tot:40.74804593
# epoch 5820 loss_pde:0.12862177, loss_ic:4.06140837
# loss_tot:40.74270548
# epoch 5821 loss_pde:0.12900865, loss_ic:4.06083689
# loss_tot:40.73737757
# epoch 5822 loss_pde:0.12939617, loss_ic:4.06026659
# loss_tot:40.73206212
# epoch 5823 loss_pde:0.12978426, loss_ic:4.05969748
# loss_tot:40.72675903
# epoch 5824 loss_pde:0.13017284, loss_ic:4.05912954
# loss_tot:40.72146821
# epoch 5825 loss_pde:0.13056186, loss_ic:4.05856277
# loss_tot:40.71618958
# epoch 5826 loss_pde:0.13095125, loss_ic:4.05799718
# loss_tot:40.71092305
# epoch 5827 loss_pde:0.13134094, loss_ic:4.05743276
# loss_tot:40.70566852
# epoch 5828 loss_pde:0.13173086, loss_ic:4.05686950
# loss_tot:40.70042590
# epoch 5829 loss_pde:0.13212096, loss_ic:4.05630741
# loss_tot:40.69519510
# epoch 5830 loss_pde:0.13251115, loss_ic:4.05574649
# loss_tot:40.68997602
# epoch 5831 loss_pde:0.13290138, loss_ic:4.05518672
# loss_tot:40.68476857
# epoch 5832 loss_pde:0.13329158, loss_ic:4.05462811
# loss_tot:40.67957266
# epoch 5833 loss_pde:0.13368167, loss_ic:4.05407065
# loss_tot:40.67438819
# epoch 5834 loss_pde:0.13407159, loss_ic:4.05351435
# loss_tot:40.66921505
# epoch 5835 loss_pde:0.13446127, loss_ic:4.05295919
# loss_tot:40.66405317
# epoch 5836 loss_pde:0.13485064, loss_ic:4.05240518
# loss_tot:40.65890243
# epoch 5837 loss_pde:0.13523964, loss_ic:4.05185231

# %%
np.shape(x_ic)

# %%
#model.load_state_dict(torch.load(PATH))
torch.save(model.to(cpu),'123.pth')
#model = torch.save('backcorner.pt')

# %%
model_path = '123.pth'
model = torch.load(model_path, map_location=cpu)
model = model.to(cuda)

# %%
plt.plot(loss_history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2856175/352708666.py in <module>
# ----> 1 plt.plot(loss_history)
#
# NameError: name 'loss_history' is not defined

# %%
optimizer = torch.optim.LBFGS(model.parameters(),lr=0.01,max_iter=30)
epochi = 0
epochs = 2000
tic = time.time()
for epoch in range(epochi, epochs+epochi):
    loss = train(epoch)
    print(f'loss_tot:{loss:.8f}')
    #loss_history.append(to_numpy(loss))
    #if loss < 0.01:
    #    break
toc = time.time()

print(f'Total training time: {toc - tic}')
# Out:
# epoch 0 loss_pde:49952.82284870, loss_ic:0.00027415
# epoch 0 loss_pde:41940.36313368, loss_ic:0.00034212
# epoch 0 loss_pde:41784.04477223, loss_ic:0.00034541
# epoch 0 loss_pde:41603.43063653, loss_ic:0.00034928
# epoch 0 loss_pde:41411.58654280, loss_ic:0.00035346
# epoch 0 loss_pde:41208.93835521, loss_ic:0.00035797
# epoch 0 loss_pde:40995.97334680, loss_ic:0.00036281
# epoch 0 loss_pde:40773.20533735, loss_ic:0.00036798
# epoch 0 loss_pde:40541.17379196, loss_ic:0.00037349
# epoch 0 loss_pde:40300.44219251, loss_ic:0.00037933
# epoch 0 loss_pde:40051.59577056, loss_ic:0.00038550
# epoch 0 loss_pde:39795.23860149, loss_ic:0.00039201
# epoch 0 loss_pde:39531.99007977, loss_ic:0.00039885
# epoch 0 loss_pde:39262.48081780, loss_ic:0.00040601
# epoch 0 loss_pde:38987.34803302, loss_ic:0.00041350
# epoch 0 loss_pde:38707.23051125, loss_ic:0.00042131
# epoch 0 loss_pde:38422.76325509, loss_ic:0.00042943
# epoch 0 loss_pde:38134.57194547, loss_ic:0.00043785
# epoch 0 loss_pde:37843.26735977, loss_ic:0.00044657
# epoch 0 loss_pde:37549.43990138, loss_ic:0.00045557
# epoch 0 loss_pde:37253.65440140, loss_ic:0.00046486
# epoch 0 loss_pde:36956.44535299, loss_ic:0.00047441
# epoch 0 loss_pde:36658.31273248, loss_ic:0.00048423
# epoch 0 loss_pde:36359.71854625, loss_ic:0.00049431
# epoch 0 loss_pde:36061.08422078, loss_ic:0.00050463
# epoch 0 loss_pde:35762.78892196, loss_ic:0.00051519
# epoch 0 loss_pde:35465.16885219, loss_ic:0.00052599
# epoch 0 loss_pde:35168.51752874, loss_ic:0.00053702
# epoch 0 loss_pde:34873.08699949, loss_ic:0.00054828
# epoch 0 loss_pde:34579.08990387, loss_ic:0.00055976
# loss_tot:49952.82559017
# epoch 1 loss_pde:34286.70224442, loss_ic:0.00057146
# epoch 1 loss_pde:33996.06670102, loss_ic:0.00058339
# epoch 1 loss_pde:33707.29630036, loss_ic:0.00059553
# epoch 1 loss_pde:33420.47824995, loss_ic:0.00060790
# epoch 1 loss_pde:33135.67775805, loss_ic:0.00062050
# epoch 1 loss_pde:32852.94168710, loss_ic:0.00063331
# epoch 1 loss_pde:32572.30192297, loss_ic:0.00064636
# epoch 1 loss_pde:32293.77838161, loss_ic:0.00065963
# epoch 1 loss_pde:32017.38161251, loss_ic:0.00067314
# epoch 1 loss_pde:31743.11499119, loss_ic:0.00068688
# epoch 1 loss_pde:31470.97651894, loss_ic:0.00070086
# epoch 1 loss_pde:31200.96026513, loss_ic:0.00071508
# epoch 1 loss_pde:30933.05749739, loss_ic:0.00072954
# epoch 1 loss_pde:30667.25754863, loss_ic:0.00074425
# epoch 1 loss_pde:30403.54846853, loss_ic:0.00075920
# epoch 1 loss_pde:30141.91750320, loss_ic:0.00077440
# epoch 1 loss_pde:29882.35144100, loss_ic:0.00078986
# epoch 1 loss_pde:29624.83685624, loss_ic:0.00080557
# epoch 1 loss_pde:29369.36027660, loss_ic:0.00082153
# epoch 1 loss_pde:29115.90829437, loss_ic:0.00083776
# epoch 1 loss_pde:28864.46763738, loss_ic:0.00085424
# epoch 1 loss_pde:28615.02521128, loss_ic:0.00087099
# epoch 1 loss_pde:28367.56812188, loss_ic:0.00088800
# epoch 1 loss_pde:28122.08368409, loss_ic:0.00090527
# epoch 1 loss_pde:27878.55942184, loss_ic:0.00092281
# epoch 1 loss_pde:27636.98306234, loss_ic:0.00094062
# epoch 1 loss_pde:27397.34252676, loss_ic:0.00095870
# epoch 1 loss_pde:27159.62591896, loss_ic:0.00097705
# epoch 1 loss_pde:26923.82151319, loss_ic:0.00099567
# epoch 1 loss_pde:26689.91774143, loss_ic:0.00101457
# loss_tot:34286.70795904
# epoch 2 loss_pde:26457.90318076, loss_ic:0.00103374
# epoch 2 loss_pde:26227.76654094, loss_ic:0.00105319
# epoch 2 loss_pde:25999.49665246, loss_ic:0.00107292
# epoch 2 loss_pde:25773.08245489, loss_ic:0.00109292
# epoch 2 loss_pde:25548.51298579, loss_ic:0.00111321
# epoch 2 loss_pde:25325.77736989, loss_ic:0.00113378
# epoch 2 loss_pde:25104.86480882, loss_ic:0.00115463
# epoch 2 loss_pde:24885.76457102, loss_ic:0.00117576
# epoch 2 loss_pde:24668.46598217, loss_ic:0.00119718
# epoch 2 loss_pde:24452.95841573, loss_ic:0.00121888
# epoch 2 loss_pde:24239.23128390, loss_ic:0.00124087
# epoch 2 loss_pde:24027.27402877, loss_ic:0.00126315
# epoch 2 loss_pde:23817.07611377, loss_ic:0.00128572
# epoch 2 loss_pde:23608.62701533, loss_ic:0.00130857
# epoch 2 loss_pde:23401.91621485, loss_ic:0.00133172
# epoch 2 loss_pde:23196.93319090, loss_ic:0.00135516
# epoch 2 loss_pde:22993.66741173, loss_ic:0.00137889
# epoch 2 loss_pde:22792.10832803, loss_ic:0.00140291
# epoch 2 loss_pde:22592.24536606, loss_ic:0.00142723
# epoch 2 loss_pde:22394.06792109, loss_ic:0.00145184
# epoch 2 loss_pde:22197.56535120, loss_ic:0.00147675
# epoch 2 loss_pde:22002.72697145, loss_ic:0.00150195
# epoch 2 loss_pde:21809.54204850, loss_ic:0.00152745
# epoch 2 loss_pde:21617.99979561, loss_ic:0.00155325
# epoch 2 loss_pde:21428.08936812, loss_ic:0.00157934
# epoch 2 loss_pde:21239.79985943, loss_ic:0.00160574
# epoch 2 loss_pde:21053.12029740, loss_ic:0.00163243
# epoch 2 loss_pde:20868.03964138, loss_ic:0.00165943
# epoch 2 loss_pde:20684.54677964, loss_ic:0.00168672
# epoch 2 loss_pde:20502.63052748, loss_ic:0.00171432
# loss_tot:26457.91351819
# epoch 3 loss_pde:20322.27962576, loss_ic:0.00174222
# epoch 3 loss_pde:20143.48274013, loss_ic:0.00177043
# epoch 3 loss_pde:19966.22846069, loss_ic:0.00179893
# epoch 3 loss_pde:19790.50530233, loss_ic:0.00182775
# epoch 3 loss_pde:19616.30170557, loss_ic:0.00185686
# epoch 3 loss_pde:19443.60603800, loss_ic:0.00188629
# epoch 3 loss_pde:19272.40659620, loss_ic:0.00191602
# epoch 3 loss_pde:19102.69160826, loss_ic:0.00194605
# epoch 3 loss_pde:18934.44923682, loss_ic:0.00197640
# epoch 3 loss_pde:18767.66758252, loss_ic:0.00200705
# epoch 3 loss_pde:18602.33468805, loss_ic:0.00203802
# epoch 3 loss_pde:18438.43854253, loss_ic:0.00206929
# epoch 3 loss_pde:18275.96696006, loss_ic:0.00210088
# epoch 3 loss_pde:18114.90754913, loss_ic:0.00213278
# epoch 3 loss_pde:17955.24787944, loss_ic:0.00216500
# epoch 3 loss_pde:17796.97566213, loss_ic:0.00219755
# epoch 3 loss_pde:17640.07883605, loss_ic:0.00223042
# epoch 3 loss_pde:17484.54552305, loss_ic:0.00226361
# epoch 3 loss_pde:17330.36388846, loss_ic:0.00229713
# epoch 3 loss_pde:17177.52201387, loss_ic:0.00233097
# epoch 3 loss_pde:17026.00785519, loss_ic:0.00236514
# epoch 3 loss_pde:16875.80927313, loss_ic:0.00239963
# epoch 3 loss_pde:16726.91408398, loss_ic:0.00243445
# epoch 3 loss_pde:16579.31009811, loss_ic:0.00246959
# epoch 3 loss_pde:16432.98514207, loss_ic:0.00250505
# epoch 3 loss_pde:16287.92707194, loss_ic:0.00254085
# epoch 3 loss_pde:16144.12378333, loss_ic:0.00257697
# epoch 3 loss_pde:16001.56322018, loss_ic:0.00261342
# epoch 3 loss_pde:15860.23338261, loss_ic:0.00265019
# epoch 3 loss_pde:15720.12233438, loss_ic:0.00268730
# loss_tot:20322.29704798
# epoch 4 loss_pde:15581.21820973, loss_ic:0.00272475
# epoch 4 loss_pde:15443.50922011, loss_ic:0.00276252
# epoch 4 loss_pde:15306.98366038, loss_ic:0.00280063
# epoch 4 loss_pde:15171.62991483, loss_ic:0.00283907
# epoch 4 loss_pde:15037.43646288, loss_ic:0.00287786
# epoch 4 loss_pde:14904.39188445, loss_ic:0.00291698
# epoch 4 loss_pde:14772.48486503, loss_ic:0.00295644
# epoch 4 loss_pde:14641.70420055, loss_ic:0.00299624
# epoch 4 loss_pde:14512.03880172, loss_ic:0.00303638
# epoch 4 loss_pde:14383.47769837, loss_ic:0.00307687
# epoch 4 loss_pde:14256.01004305, loss_ic:0.00311770
# epoch 4 loss_pde:14129.62511501, loss_ic:0.00315888
# epoch 4 loss_pde:14004.31232258, loss_ic:0.00320041
# epoch 4 loss_pde:13880.06120789, loss_ic:0.00324228
# epoch 4 loss_pde:13756.86144532, loss_ic:0.00328451
# epoch 4 loss_pde:13634.70285338, loss_ic:0.00332709
# epoch 4 loss_pde:13513.57537417, loss_ic:0.00337002
# epoch 4 loss_pde:13393.46912808, loss_ic:0.00341330
# epoch 4 loss_pde:13274.37428598, loss_ic:0.00345695
# epoch 4 loss_pde:13156.28137329, loss_ic:0.00350093
# epoch 4 loss_pde:13039.18045869, loss_ic:0.00354531
# epoch 4 loss_pde:12923.06273195, loss_ic:0.00358997
# epoch 4 loss_pde:12807.91374944, loss_ic:0.00363519
# epoch 4 loss_pde:12693.71267683, loss_ic:0.00368029
# epoch 4 loss_pde:12580.30881543, loss_ic:0.00372714
# epoch 4 loss_pde:12467.10097999, loss_ic:0.00377176
# epoch 4 loss_pde:12348.27400339, loss_ic:0.00382942
# epoch 4 loss_pde:12231.41195989, loss_ic:0.00387730
# epoch 4 loss_pde:12119.17482865, loss_ic:0.00392937
# epoch 4 loss_pde:12008.35380839, loss_ic:0.00397658
# loss_tot:15581.24545719
# epoch 5 loss_pde:11899.23172096, loss_ic:0.00402773
# epoch 5 loss_pde:11791.45509904, loss_ic:0.00407556
# epoch 5 loss_pde:11684.98293393, loss_ic:0.00412624
# epoch 5 loss_pde:11579.63564513, loss_ic:0.00417488
# epoch 5 loss_pde:11475.33169704, loss_ic:0.00422559
# epoch 5 loss_pde:11372.01443048, loss_ic:0.00427511
# epoch 5 loss_pde:11269.62107355, loss_ic:0.00432617
# epoch 5 loss_pde:11168.13665190, loss_ic:0.00437658
# epoch 5 loss_pde:11067.51961429, loss_ic:0.00442813
# epoch 5 loss_pde:10967.76677322, loss_ic:0.00447942
# epoch 5 loss_pde:10868.85123461, loss_ic:0.00453157
# epoch 5 loss_pde:10770.77181664, loss_ic:0.00458369
# epoch 5 loss_pde:10673.51055676, loss_ic:0.00463651
# epoch 5 loss_pde:10577.06551528, loss_ic:0.00468945
# epoch 5 loss_pde:10481.42393353, loss_ic:0.00474296
# epoch 5 loss_pde:10386.58266456, loss_ic:0.00479669
# epoch 5 loss_pde:10292.53194228, loss_ic:0.00485092
# epoch 5 loss_pde:10199.26762896, loss_ic:0.00490544
# epoch 5 loss_pde:10106.78168488, loss_ic:0.00496040
# epoch 5 loss_pde:10015.06930772, loss_ic:0.00501569
# epoch 5 loss_pde:9924.12346625, loss_ic:0.00507140
# epoch 5 loss_pde:9833.93896448, loss_ic:0.00512745
# epoch 5 loss_pde:9744.50937154, loss_ic:0.00518390
# epoch 5 loss_pde:9655.82928479, loss_ic:0.00524071
# epoch 5 loss_pde:9567.89263968, loss_ic:0.00529791
# epoch 5 loss_pde:9480.69394321, loss_ic:0.00535548
# epoch 5 loss_pde:9394.22736158, loss_ic:0.00541343
# epoch 5 loss_pde:9308.48737819, loss_ic:0.00547174
# epoch 5 loss_pde:9223.46831062, loss_ic:0.00553044
# epoch 5 loss_pde:9139.16465407, loss_ic:0.00558951
# loss_tot:11899.27199827
# epoch 6 loss_pde:9055.57083055, loss_ic:0.00564896
# epoch 6 loss_pde:8972.68136422, loss_ic:0.00570877
# epoch 6 loss_pde:8890.49075355, loss_ic:0.00576896
# epoch 6 loss_pde:8808.99355889, loss_ic:0.00582953
# epoch 6 loss_pde:8728.18433857, loss_ic:0.00589046
# epoch 6 loss_pde:8648.05769163, loss_ic:0.00595177
# epoch 6 loss_pde:8568.60822657, loss_ic:0.00601345
# epoch 6 loss_pde:8489.83058175, loss_ic:0.00607550
# epoch 6 loss_pde:8411.71941057, loss_ic:0.00613792
# epoch 6 loss_pde:8334.26939103, loss_ic:0.00620071
# epoch 6 loss_pde:8257.47521903, loss_ic:0.00626387
# epoch 6 loss_pde:8181.33161291, loss_ic:0.00632740
# epoch 6 loss_pde:8105.83331064, loss_ic:0.00639129
# epoch 6 loss_pde:8030.97507219, loss_ic:0.00645556
# epoch 6 loss_pde:7956.75167854, loss_ic:0.00652020
# epoch 6 loss_pde:7883.15793313, loss_ic:0.00658520
# epoch 6 loss_pde:7810.18866181, loss_ic:0.00665057
# epoch 6 loss_pde:7737.83871383, loss_ic:0.00671631
# epoch 6 loss_pde:7666.10296223, loss_ic:0.00678241
# epoch 6 loss_pde:7594.97630471, loss_ic:0.00684889
# epoch 6 loss_pde:7524.45366417, loss_ic:0.00691573
# epoch 6 loss_pde:7454.52998946, loss_ic:0.00698294
# epoch 6 loss_pde:7385.20025580, loss_ic:0.00705051
# epoch 6 loss_pde:7316.45946484, loss_ic:0.00711845
# epoch 6 loss_pde:7248.30264519, loss_ic:0.00718676
# epoch 6 loss_pde:7180.72485316, loss_ic:0.00725543
# epoch 6 loss_pde:7113.72117385, loss_ic:0.00732447
# epoch 6 loss_pde:7047.28672230, loss_ic:0.00739388
# epoch 6 loss_pde:6981.41664458, loss_ic:0.00746366
# epoch 6 loss_pde:6916.10611857, loss_ic:0.00753380
# loss_tot:9055.62732012
# epoch 7 loss_pde:6851.35035434, loss_ic:0.00760430
# epoch 7 loss_pde:6787.14459421, loss_ic:0.00767518
# epoch 7 loss_pde:6723.48411281, loss_ic:0.00774642
# epoch 7 loss_pde:6660.36421710, loss_ic:0.00781803
# epoch 7 loss_pde:6597.78024655, loss_ic:0.00789000
# epoch 7 loss_pde:6535.72757328, loss_ic:0.00796234
# epoch 7 loss_pde:6474.20160225, loss_ic:0.00803505
# epoch 7 loss_pde:6413.19777138, loss_ic:0.00810813
# epoch 7 loss_pde:6352.71155170, loss_ic:0.00818157
# epoch 7 loss_pde:6292.73844749, loss_ic:0.00825538
# epoch 7 loss_pde:6233.27399638, loss_ic:0.00832956
# epoch 7 loss_pde:6174.31376942, loss_ic:0.00840410
# epoch 7 loss_pde:6115.85337116, loss_ic:0.00847901
# epoch 7 loss_pde:6057.88843972, loss_ic:0.00855429
# epoch 7 loss_pde:6000.41464683, loss_ic:0.00862994
# epoch 7 loss_pde:5943.42769784, loss_ic:0.00870596
# epoch 7 loss_pde:5886.92333176, loss_ic:0.00878234
# epoch 7 loss_pde:5830.89732127, loss_ic:0.00885909
# epoch 7 loss_pde:5775.34547268, loss_ic:0.00893621
# epoch 7 loss_pde:5720.26362594, loss_ic:0.00901369
# epoch 7 loss_pde:5665.64765464, loss_ic:0.00909155
# epoch 7 loss_pde:5611.49346590, loss_ic:0.00916977
# epoch 7 loss_pde:5557.79700040, loss_ic:0.00924836
# epoch 7 loss_pde:5504.55423231, loss_ic:0.00932731
# epoch 7 loss_pde:5451.76116916, loss_ic:0.00940664
# epoch 7 loss_pde:5399.41385193, loss_ic:0.00948633
# epoch 7 loss_pde:5347.50835470, loss_ic:0.00956638
# epoch 7 loss_pde:5296.04078505, loss_ic:0.00964681
# epoch 7 loss_pde:5245.00728295, loss_ic:0.00972760
# epoch 7 loss_pde:5194.40402314, loss_ic:0.00980876
# loss_tot:6851.42639737
# epoch 8 loss_pde:5144.22720865, loss_ic:0.00989028
# epoch 8 loss_pde:5094.47308705, loss_ic:0.00997217
# epoch 8 loss_pde:5045.13790814, loss_ic:0.01005442
# epoch 8 loss_pde:4996.21803066, loss_ic:0.01013704
# epoch 8 loss_pde:4947.70963780, loss_ic:0.01022002
# epoch 8 loss_pde:4899.60940293, loss_ic:0.01030338
# epoch 8 loss_pde:4851.91256789, loss_ic:0.01038708
# epoch 8 loss_pde:4804.61559614, loss_ic:0.01047133
# epoch 8 loss_pde:4757.71732134, loss_ic:0.01055566
# epoch 8 loss_pde:4711.20929447, loss_ic:0.01064098
# epoch 8 loss_pde:4665.07683735, loss_ic:0.01072553
# epoch 8 loss_pde:4619.22614848, loss_ic:0.01081366
# epoch 8 loss_pde:4573.33777075, loss_ic:0.01089738
# epoch 8 loss_pde:4524.95784677, loss_ic:0.01100487
# epoch 8 loss_pde:4478.77882374, loss_ic:0.01109305
# epoch 8 loss_pde:4434.28848306, loss_ic:0.01118370
# epoch 8 loss_pde:4390.14072202, loss_ic:0.01127001
# epoch 8 loss_pde:4346.34123711, loss_ic:0.01136166
# epoch 8 loss_pde:4302.93593159, loss_ic:0.01144879
# epoch 8 loss_pde:4259.93907831, loss_ic:0.01154060
# epoch 8 loss_pde:4217.35364897, loss_ic:0.01162857
# epoch 8 loss_pde:4175.18159457, loss_ic:0.01172018
# epoch 8 loss_pde:4133.40151300, loss_ic:0.01180909
# epoch 8 loss_pde:4091.99914681, loss_ic:0.01190051
# epoch 8 loss_pde:4050.93744160, loss_ic:0.01199064
# epoch 8 loss_pde:4010.17387070, loss_ic:0.01208201
# epoch 8 loss_pde:3969.60815081, loss_ic:0.01217410
# epoch 8 loss_pde:3929.13352920, loss_ic:0.01226593
# epoch 8 loss_pde:3888.55093709, loss_ic:0.01236159
# epoch 8 loss_pde:3848.01942886, loss_ic:0.01245496
# loss_tot:5144.32611144
# epoch 9 loss_pde:3807.73845266, loss_ic:0.01255286
# epoch 9 loss_pde:3768.14169400, loss_ic:0.01264659
# epoch 9 loss_pde:3729.26237235, loss_ic:0.01274289
# epoch 9 loss_pde:3690.98437795, loss_ic:0.01283628
# epoch 9 loss_pde:3653.22198270, loss_ic:0.01293149
# epoch 9 loss_pde:3615.87863163, loss_ic:0.01302521
# epoch 9 loss_pde:3578.91627926, loss_ic:0.01312025
# epoch 9 loss_pde:3542.29670547, loss_ic:0.01321460
# epoch 9 loss_pde:3506.00631950, loss_ic:0.01330989
# epoch 9 loss_pde:3470.02921273, loss_ic:0.01340492
# epoch 9 loss_pde:3434.35999569, loss_ic:0.01350063
# epoch 9 loss_pde:3398.99049547, loss_ic:0.01359633
# epoch 9 loss_pde:3363.91782777, loss_ic:0.01369255
# epoch 9 loss_pde:3329.13669067, loss_ic:0.01378888
# epoch 9 loss_pde:3294.64490798, loss_ic:0.01388564
# epoch 9 loss_pde:3260.43837819, loss_ic:0.01398257
# epoch 9 loss_pde:3226.51509445, loss_ic:0.01407989
# epoch 9 loss_pde:3192.87152987, loss_ic:0.01417740
# epoch 9 loss_pde:3159.50570224, loss_ic:0.01427527
# epoch 9 loss_pde:3126.41439623, loss_ic:0.01437334
# epoch 9 loss_pde:3093.59562916, loss_ic:0.01447176
# epoch 9 loss_pde:3061.04637103, loss_ic:0.01457038
# epoch 9 loss_pde:3028.76464715, loss_ic:0.01466933
# epoch 9 loss_pde:2996.74754273, loss_ic:0.01476849
# epoch 9 loss_pde:2964.99310701, loss_ic:0.01486796
# epoch 9 loss_pde:2933.49849400, loss_ic:0.01496763
# epoch 9 loss_pde:2902.26179315, loss_ic:0.01506762
# epoch 9 loss_pde:2871.28018849, loss_ic:0.01516780
# epoch 9 loss_pde:2840.55182438, loss_ic:0.01526828
# epoch 9 loss_pde:2810.07387226, loss_ic:0.01536895
# loss_tot:3807.86398126
# epoch 10 loss_pde:2779.84454233, loss_ic:0.01546993
# epoch 10 loss_pde:2749.86093286, loss_ic:0.01557106
# epoch 10 loss_pde:2720.12132041, loss_ic:0.01567252
# epoch 10 loss_pde:2690.62262577, loss_ic:0.01577410
# epoch 10 loss_pde:2661.36316116, loss_ic:0.01587603
# epoch 10 loss_pde:2632.33946483, loss_ic:0.01597805
# epoch 10 loss_pde:2603.54976434, loss_ic:0.01608046
# epoch 10 loss_pde:2574.98977397, loss_ic:0.01618289
# epoch 10 loss_pde:2546.65727479, loss_ic:0.01628579
# epoch 10 loss_pde:2518.54616674, loss_ic:0.01638863
# epoch 10 loss_pde:2490.65285988, loss_ic:0.01649206
# epoch 10 loss_pde:2462.96735391, loss_ic:0.01659533
# epoch 10 loss_pde:2435.48302809, loss_ic:0.01669940
# epoch 10 loss_pde:2408.18312342, loss_ic:0.01680318
# epoch 10 loss_pde:2381.05870735, loss_ic:0.01690808
# epoch 10 loss_pde:2354.09023156, loss_ic:0.01701253
# epoch 10 loss_pde:2327.28259919, loss_ic:0.01711840
# epoch 10 loss_pde:2300.63832772, loss_ic:0.01722358
# epoch 10 loss_pde:2274.19591276, loss_ic:0.01733016
# epoch 10 loss_pde:2247.98099181, loss_ic:0.01743573
# epoch 10 loss_pde:2222.02549146, loss_ic:0.01754237
# epoch 10 loss_pde:2196.33475089, loss_ic:0.01764797
# epoch 10 loss_pde:2170.90984558, loss_ic:0.01775438
# epoch 10 loss_pde:2145.73766180, loss_ic:0.01785995
# epoch 10 loss_pde:2120.80972531, loss_ic:0.01796619
# epoch 10 loss_pde:2096.11161043, loss_ic:0.01807183
# epoch 10 loss_pde:2071.63675434, loss_ic:0.01817803
# epoch 10 loss_pde:2047.37441732, loss_ic:0.01828381
# epoch 10 loss_pde:2023.32092062, loss_ic:0.01839006
# epoch 10 loss_pde:1999.46875473, loss_ic:0.01849601
# loss_tot:2779.99924159
# epoch 11 loss_pde:1975.81600105, loss_ic:0.01860236
# epoch 11 loss_pde:1952.35721746, loss_ic:0.01870849
# epoch 11 loss_pde:1929.09136342, loss_ic:0.01881495
# epoch 11 loss_pde:1906.01423262, loss_ic:0.01892124
# epoch 11 loss_pde:1883.12519341, loss_ic:0.01902782
# epoch 11 loss_pde:1860.42078156, loss_ic:0.01913425
# epoch 11 loss_pde:1837.90055825, loss_ic:0.01924094
# epoch 11 loss_pde:1815.56151763, loss_ic:0.01934749
# epoch 11 loss_pde:1793.40332577, loss_ic:0.01945426
# epoch 11 loss_pde:1771.42326740, loss_ic:0.01956091
# epoch 11 loss_pde:1749.62108664, loss_ic:0.01966775
# epoch 11 loss_pde:1727.99425224, loss_ic:0.01977446
# epoch 11 loss_pde:1706.54258845, loss_ic:0.01988135
# epoch 11 loss_pde:1685.26367198, loss_ic:0.01998809
# epoch 11 loss_pde:1664.15742432, loss_ic:0.02009499
# epoch 11 loss_pde:1643.22146372, loss_ic:0.02020173
# epoch 11 loss_pde:1622.45583602, loss_ic:0.02030863
# epoch 11 loss_pde:1601.85809760, loss_ic:0.02041534
# epoch 11 loss_pde:1581.42846834, loss_ic:0.02052220
# epoch 11 loss_pde:1561.16432426, loss_ic:0.02062884
# epoch 11 loss_pde:1541.06623253, loss_ic:0.02073563
# epoch 11 loss_pde:1521.13073947, loss_ic:0.02084217
# epoch 11 loss_pde:1501.35959136, loss_ic:0.02094887
# epoch 11 loss_pde:1481.74465198, loss_ic:0.02105534
# epoch 11 loss_pde:1462.29165709, loss_ic:0.02116205
# epoch 11 loss_pde:1443.00306746, loss_ic:0.02126858
# epoch 11 loss_pde:1423.87751687, loss_ic:0.02137470
# epoch 11 loss_pde:1404.89943680, loss_ic:0.02148152
# epoch 11 loss_pde:1386.05420910, loss_ic:0.02158698
# epoch 11 loss_pde:1367.28606028, loss_ic:0.02169530
# loss_tot:1976.00202464
# epoch 12 loss_pde:1348.57357667, loss_ic:0.02180068
# epoch 12 loss_pde:1329.82911736, loss_ic:0.02191226
# epoch 12 loss_pde:1311.25921309, loss_ic:0.02201852
# epoch 12 loss_pde:1292.98394086, loss_ic:0.02212844
# epoch 12 loss_pde:1274.96853810, loss_ic:0.02223347
# epoch 12 loss_pde:1257.25508662, loss_ic:0.02234066
# epoch 12 loss_pde:1239.75444317, loss_ic:0.02244453
# epoch 12 loss_pde:1222.48118941, loss_ic:0.02254980
# epoch 12 loss_pde:1205.38095181, loss_ic:0.02265311
# epoch 12 loss_pde:1188.45086057, loss_ic:0.02275686
# epoch 12 loss_pde:1171.63323995, loss_ic:0.02286052
# epoch 12 loss_pde:1154.85487904, loss_ic:0.02296339
# epoch 12 loss_pde:1137.96011117, loss_ic:0.02307049
# epoch 12 loss_pde:1120.99619649, loss_ic:0.02317500
# epoch 12 loss_pde:1104.24289476, loss_ic:0.02328334
# epoch 12 loss_pde:1087.91372060, loss_ic:0.02338618
# epoch 12 loss_pde:1071.98123428, loss_ic:0.02349022
# epoch 12 loss_pde:1056.34227202, loss_ic:0.02359051
# epoch 12 loss_pde:1040.96315686, loss_ic:0.02369175
# epoch 12 loss_pde:1025.79100808, loss_ic:0.02379049
# epoch 12 loss_pde:1010.82032860, loss_ic:0.02388977
# epoch 12 loss_pde:996.02454503, loss_ic:0.02398728
# epoch 12 loss_pde:981.40571910, loss_ic:0.02408495
# epoch 12 loss_pde:966.94968734, loss_ic:0.02418128
# epoch 12 loss_pde:952.65966573, loss_ic:0.02427748
# epoch 12 loss_pde:938.52777350, loss_ic:0.02437258
# epoch 12 loss_pde:924.55676012, loss_ic:0.02446734
# epoch 12 loss_pde:910.74205865, loss_ic:0.02456113
# epoch 12 loss_pde:897.08572627, loss_ic:0.02465444
# epoch 12 loss_pde:883.58499447, loss_ic:0.02474685
# loss_tot:1348.79158344
# epoch 13 loss_pde:870.24135628, loss_ic:0.02483867
# epoch 13 loss_pde:857.05305069, loss_ic:0.02492961
# epoch 13 loss_pde:844.02117236, loss_ic:0.02501988
# epoch 13 loss_pde:831.14454614, loss_ic:0.02510927
# epoch 13 loss_pde:818.42399574, loss_ic:0.02519793
# epoch 13 loss_pde:805.85869867, loss_ic:0.02528570
# epoch 13 loss_pde:793.44929298, loss_ic:0.02537268
# epoch 13 loss_pde:781.19517217, loss_ic:0.02545875
# epoch 13 loss_pde:769.09684288, loss_ic:0.02554398
# epoch 13 loss_pde:757.15382834, loss_ic:0.02562827
# epoch 13 loss_pde:745.36653725, loss_ic:0.02571169
# epoch 13 loss_pde:733.73456334, loss_ic:0.02579413
# epoch 13 loss_pde:722.25823767, loss_ic:0.02587566
# epoch 13 loss_pde:710.93717975, loss_ic:0.02595619
# epoch 13 loss_pde:699.77165542, loss_ic:0.02603577
# epoch 13 loss_pde:688.76127261, loss_ic:0.02611431
# epoch 13 loss_pde:677.90624040, loss_ic:0.02619187
# epoch 13 loss_pde:667.20611998, loss_ic:0.02626836
# epoch 13 loss_pde:656.66107143, loss_ic:0.02634384
# epoch 13 loss_pde:646.27057097, loss_ic:0.02641823
# epoch 13 loss_pde:636.03473937, loss_ic:0.02649158
# epoch 13 loss_pde:625.95291796, loss_ic:0.02656380
# epoch 13 loss_pde:616.02520056, loss_ic:0.02663497
# epoch 13 loss_pde:606.25071125, loss_ic:0.02670497
# epoch 13 loss_pde:596.62952111, loss_ic:0.02677393
# epoch 13 loss_pde:587.16035171, loss_ic:0.02684167
# epoch 13 loss_pde:577.84316185, loss_ic:0.02690839
# epoch 13 loss_pde:568.67563996, loss_ic:0.02697382
# epoch 13 loss_pde:559.65681610, loss_ic:0.02703834
# epoch 13 loss_pde:550.78013792, loss_ic:0.02710144
# loss_tot:870.48974297
# epoch 14 loss_pde:542.03779086, loss_ic:0.02716400
# epoch 14 loss_pde:533.40265125, loss_ic:0.02722499
# epoch 14 loss_pde:524.84697374, loss_ic:0.02728646
# epoch 14 loss_pde:516.34973542, loss_ic:0.02734629
# epoch 14 loss_pde:507.99769930, loss_ic:0.02740660
# epoch 14 loss_pde:499.85088799, loss_ic:0.02746430
# epoch 14 loss_pde:491.92700441, loss_ic:0.02752151
# epoch 14 loss_pde:484.20531518, loss_ic:0.02757634
# epoch 14 loss_pde:476.67023818, loss_ic:0.02763053
# epoch 14 loss_pde:469.30369811, loss_ic:0.02768275
# epoch 14 loss_pde:462.09783565, loss_ic:0.02773426
# epoch 14 loss_pde:455.04174831, loss_ic:0.02778408
# epoch 14 loss_pde:448.13160148, loss_ic:0.02783313
# epoch 14 loss_pde:441.36042666, loss_ic:0.02788069
# epoch 14 loss_pde:434.72597383, loss_ic:0.02792745
# epoch 14 loss_pde:428.22334339, loss_ic:0.02797286
# epoch 14 loss_pde:421.85085062, loss_ic:0.02801745
# epoch 14 loss_pde:415.60470451, loss_ic:0.02806081
# epoch 14 loss_pde:409.48336462, loss_ic:0.02810336
# epoch 14 loss_pde:403.48364043, loss_ic:0.02814478
# epoch 14 loss_pde:397.60396473, loss_ic:0.02818541
# epoch 14 loss_pde:391.84147099, loss_ic:0.02822501
# epoch 14 loss_pde:386.19450304, loss_ic:0.02826384
# epoch 14 loss_pde:380.66036610, loss_ic:0.02830172
# epoch 14 loss_pde:375.23730197, loss_ic:0.02833889
# epoch 14 loss_pde:369.92270491, loss_ic:0.02837518
# epoch 14 loss_pde:364.71472415, loss_ic:0.02841082
# epoch 14 loss_pde:359.61080015, loss_ic:0.02844565
# epoch 14 loss_pde:354.60900931, loss_ic:0.02847988
# epoch 14 loss_pde:349.70681862, loss_ic:0.02851338
# loss_tot:542.30943082
# epoch 15 loss_pde:344.90225546, loss_ic:0.02854634
# epoch 15 loss_pde:340.19280466, loss_ic:0.02857865
# epoch 15 loss_pde:335.57646873, loss_ic:0.02861048
# epoch 15 loss_pde:331.05073535, loss_ic:0.02864173
# epoch 15 loss_pde:326.61359466, loss_ic:0.02867256
# epoch 15 loss_pde:322.26257675, loss_ic:0.02870288
# epoch 15 loss_pde:317.99570096, loss_ic:0.02873284
# epoch 15 loss_pde:313.81048936, loss_ic:0.02876235
# epoch 15 loss_pde:309.70493388, loss_ic:0.02879157
# epoch 15 loss_pde:305.67649093, loss_ic:0.02882039
# epoch 15 loss_pde:301.72283578, loss_ic:0.02884898
# epoch 15 loss_pde:297.84108995, loss_ic:0.02887722
# epoch 15 loss_pde:294.02731027, loss_ic:0.02890533
# epoch 15 loss_pde:290.27645247, loss_ic:0.02893311
# epoch 15 loss_pde:286.58152475, loss_ic:0.02896099
# epoch 15 loss_pde:282.93500012, loss_ic:0.02898854
# epoch 15 loss_pde:279.33949056, loss_ic:0.02901642
# epoch 15 loss_pde:275.80553313, loss_ic:0.02904381
# epoch 15 loss_pde:272.34633092, loss_ic:0.02907140
# epoch 15 loss_pde:268.96514526, loss_ic:0.02909840
# epoch 15 loss_pde:265.65649971, loss_ic:0.02912554
# epoch 15 loss_pde:262.41551264, loss_ic:0.02915219
# epoch 15 loss_pde:259.23255436, loss_ic:0.02917908
# epoch 15 loss_pde:256.09673995, loss_ic:0.02920552
# epoch 15 loss_pde:252.99206011, loss_ic:0.02923261
# epoch 15 loss_pde:249.90361968, loss_ic:0.02925927
# epoch 15 loss_pde:246.85812023, loss_ic:0.02928676
# epoch 15 loss_pde:243.88547572, loss_ic:0.02931335
# epoch 15 loss_pde:240.98997401, loss_ic:0.02934040
# epoch 15 loss_pde:238.16636801, loss_ic:0.02936676
# loss_tot:345.18771890
# epoch 16 loss_pde:235.40334321, loss_ic:0.02939357
# epoch 16 loss_pde:232.69569176, loss_ic:0.02941996
# epoch 16 loss_pde:230.03686196, loss_ic:0.02944680
# epoch 16 loss_pde:227.42353272, loss_ic:0.02947339
# epoch 16 loss_pde:224.85148970, loss_ic:0.02950042
# epoch 16 loss_pde:222.31826342, loss_ic:0.02952729
# epoch 16 loss_pde:219.82037289, loss_ic:0.02955461
# epoch 16 loss_pde:217.35512169, loss_ic:0.02958186
# epoch 16 loss_pde:214.91806251, loss_ic:0.02960959
# epoch 16 loss_pde:212.50463984, loss_ic:0.02963738
# epoch 16 loss_pde:210.10846763, loss_ic:0.02966574
# epoch 16 loss_pde:207.72786558, loss_ic:0.02969429
# epoch 16 loss_pde:205.36832041, loss_ic:0.02972330
# epoch 16 loss_pde:203.04706050, loss_ic:0.02975232
# epoch 16 loss_pde:200.77163737, loss_ic:0.02978135
# epoch 16 loss_pde:198.54304602, loss_ic:0.02981036
# epoch 16 loss_pde:196.35429252, loss_ic:0.02983933
# epoch 16 loss_pde:194.20084148, loss_ic:0.02986845
# epoch 16 loss_pde:192.07849150, loss_ic:0.02989758
# epoch 16 loss_pde:189.98520609, loss_ic:0.02992693
# epoch 16 loss_pde:187.91910873, loss_ic:0.02995630
# epoch 16 loss_pde:185.87935989, loss_ic:0.02998591
# epoch 16 loss_pde:183.86493591, loss_ic:0.03001554
# epoch 16 loss_pde:181.87542989, loss_ic:0.03004542
# epoch 16 loss_pde:179.91013697, loss_ic:0.03007529
# epoch 16 loss_pde:177.96882798, loss_ic:0.03010541
# epoch 16 loss_pde:176.05093348, loss_ic:0.03013549
# epoch 16 loss_pde:174.15631830, loss_ic:0.03016584
# epoch 16 loss_pde:172.28448200, loss_ic:0.03019611
# epoch 16 loss_pde:170.43535582, loss_ic:0.03022665
# loss_tot:235.69727891
# epoch 17 loss_pde:168.60848769, loss_ic:0.03025708
# epoch 17 loss_pde:166.80386513, loss_ic:0.03028780
# epoch 17 loss_pde:165.02108391, loss_ic:0.03031836
# epoch 17 loss_pde:163.26017361, loss_ic:0.03034924
# epoch 17 loss_pde:161.52078056, loss_ic:0.03037990
# epoch 17 loss_pde:159.80294038, loss_ic:0.03041091
# epoch 17 loss_pde:158.10634424, loss_ic:0.03044164
# epoch 17 loss_pde:156.43096724, loss_ic:0.03047278
# epoch 17 loss_pde:154.77653097, loss_ic:0.03050356
# epoch 17 loss_pde:153.14284116, loss_ic:0.03053481
# epoch 17 loss_pde:151.52960765, loss_ic:0.03056563
# epoch 17 loss_pde:149.93620843, loss_ic:0.03059705
# epoch 17 loss_pde:148.36202877, loss_ic:0.03062792
# epoch 17 loss_pde:146.80538701, loss_ic:0.03065960
# epoch 17 loss_pde:145.26420615, loss_ic:0.03069062
# epoch 17 loss_pde:143.73664147, loss_ic:0.03072269
# epoch 17 loss_pde:142.22218467, loss_ic:0.03075415
# epoch 17 loss_pde:140.72533942, loss_ic:0.03078641
# epoch 17 loss_pde:139.24952412, loss_ic:0.03081819
# epoch 17 loss_pde:137.79772117, loss_ic:0.03085035
# epoch 17 loss_pde:136.36944141, loss_ic:0.03088212
# epoch 17 loss_pde:134.96505876, loss_ic:0.03091413
# epoch 17 loss_pde:133.58278157, loss_ic:0.03094583
# epoch 17 loss_pde:132.22266753, loss_ic:0.03097775
# epoch 17 loss_pde:130.88281377, loss_ic:0.03100937
# epoch 17 loss_pde:129.56321815, loss_ic:0.03104128
# epoch 17 loss_pde:128.26211474, loss_ic:0.03107284
# epoch 17 loss_pde:126.97922565, loss_ic:0.03110485
# epoch 17 loss_pde:125.71275245, loss_ic:0.03113634
# epoch 17 loss_pde:124.46132540, loss_ic:0.03116871
# loss_tot:168.91105850
# epoch 18 loss_pde:123.22206674, loss_ic:0.03120008
# epoch 18 loss_pde:121.98984773, loss_ic:0.03123345
# epoch 18 loss_pde:120.75895700, loss_ic:0.03126475
# epoch 18 loss_pde:119.52670299, loss_ic:0.03129996
# epoch 18 loss_pde:118.31313690, loss_ic:0.03133143
# epoch 18 loss_pde:117.13357843, loss_ic:0.03136584
# epoch 18 loss_pde:115.98885084, loss_ic:0.03139710
# epoch 18 loss_pde:114.86498535, loss_ic:0.03143060
# epoch 18 loss_pde:113.75893650, loss_ic:0.03146182
# epoch 18 loss_pde:112.66274407, loss_ic:0.03149585
# epoch 18 loss_pde:111.56975152, loss_ic:0.03152690
# epoch 18 loss_pde:110.46520384, loss_ic:0.03156333
# epoch 18 loss_pde:109.35235238, loss_ic:0.03159545
# epoch 18 loss_pde:108.28724755, loss_ic:0.03163045
# epoch 18 loss_pde:107.26329223, loss_ic:0.03166311
# epoch 18 loss_pde:106.25954325, loss_ic:0.03169672
# epoch 18 loss_pde:105.27140684, loss_ic:0.03172973
# epoch 18 loss_pde:104.29714999, loss_ic:0.03176343
# epoch 18 loss_pde:103.33549599, loss_ic:0.03179684
# epoch 18 loss_pde:102.38648268, loss_ic:0.03183088
# epoch 18 loss_pde:101.44917665, loss_ic:0.03186471
# epoch 18 loss_pde:100.52388466, loss_ic:0.03189916
# epoch 18 loss_pde:99.60971390, loss_ic:0.03193346
# epoch 18 loss_pde:98.70698069, loss_ic:0.03196839
# epoch 18 loss_pde:97.81469329, loss_ic:0.03200324
# epoch 18 loss_pde:96.93304648, loss_ic:0.03203874
# epoch 18 loss_pde:96.06071655, loss_ic:0.03207425
# epoch 18 loss_pde:95.19795244, loss_ic:0.03211035
# epoch 18 loss_pde:94.34356282, loss_ic:0.03214662
# epoch 18 loss_pde:93.49900044, loss_ic:0.03218328
# loss_tot:123.53406754
# epoch 19 loss_pde:92.66383313, loss_ic:0.03222019
# epoch 19 loss_pde:91.83977210, loss_ic:0.03225732
# epoch 19 loss_pde:91.02576382, loss_ic:0.03229474
# epoch 19 loss_pde:90.22280238, loss_ic:0.03233234
# epoch 19 loss_pde:89.42911252, loss_ic:0.03237035
# epoch 19 loss_pde:88.64504843, loss_ic:0.03240858
# epoch 19 loss_pde:87.86803369, loss_ic:0.03244734
# epoch 19 loss_pde:87.09907112, loss_ic:0.03248637
# epoch 19 loss_pde:86.33741870, loss_ic:0.03252583
# epoch 19 loss_pde:85.58568354, loss_ic:0.03256546
# epoch 19 loss_pde:84.84329262, loss_ic:0.03260537
# epoch 19 loss_pde:84.11179877, loss_ic:0.03264540
# epoch 19 loss_pde:83.39006972, loss_ic:0.03268568
# epoch 19 loss_pde:82.67901723, loss_ic:0.03272608
# epoch 19 loss_pde:81.97732124, loss_ic:0.03276678
# epoch 19 loss_pde:81.28563059, loss_ic:0.03280763
# epoch 19 loss_pde:80.60262342, loss_ic:0.03284884
# epoch 19 loss_pde:79.92882175, loss_ic:0.03289026
# epoch 19 loss_pde:79.26295090, loss_ic:0.03293212
# epoch 19 loss_pde:78.60541466, loss_ic:0.03297424
# epoch 19 loss_pde:77.95494945, loss_ic:0.03301692
# epoch 19 loss_pde:77.31173042, loss_ic:0.03305993
# epoch 19 loss_pde:76.67427990, loss_ic:0.03310368
# epoch 19 loss_pde:76.04175190, loss_ic:0.03314786
# epoch 19 loss_pde:75.41055168, loss_ic:0.03319324
# epoch 19 loss_pde:74.77504752, loss_ic:0.03323960
# epoch 19 loss_pde:74.13348293, loss_ic:0.03328777
# epoch 19 loss_pde:73.50632572, loss_ic:0.03333548
# epoch 19 loss_pde:72.90345256, loss_ic:0.03338226
# epoch 19 loss_pde:72.31376838, loss_ic:0.03342878
# loss_tot:92.98603504
# epoch 20 loss_pde:71.73381394, loss_ic:0.03347532
# epoch 20 loss_pde:71.16091576, loss_ic:0.03352226
# epoch 20 loss_pde:70.59490822, loss_ic:0.03356939
# epoch 20 loss_pde:70.03474413, loss_ic:0.03361710
# epoch 20 loss_pde:69.48069425, loss_ic:0.03366499
# epoch 20 loss_pde:68.93201301, loss_ic:0.03371358
# epoch 20 loss_pde:68.38904950, loss_ic:0.03376231
# epoch 20 loss_pde:67.85115000, loss_ic:0.03381186
# epoch 20 loss_pde:67.31866983, loss_ic:0.03386143
# epoch 20 loss_pde:66.79097393, loss_ic:0.03391200
# epoch 20 loss_pde:66.26838675, loss_ic:0.03396244
# epoch 20 loss_pde:65.75020380, loss_ic:0.03401414
# epoch 20 loss_pde:65.23663367, loss_ic:0.03406543
# epoch 20 loss_pde:64.72666411, loss_ic:0.03411850
# epoch 20 loss_pde:64.22010207, loss_ic:0.03417074
# epoch 20 loss_pde:63.71478618, loss_ic:0.03422582
# epoch 20 loss_pde:63.20912230, loss_ic:0.03427946
# epoch 20 loss_pde:62.69679757, loss_ic:0.03433847
# epoch 20 loss_pde:62.17710230, loss_ic:0.03439518
# epoch 20 loss_pde:61.66193047, loss_ic:0.03445653
# epoch 20 loss_pde:61.17378341, loss_ic:0.03451324
# epoch 20 loss_pde:60.70010214, loss_ic:0.03456960
# epoch 20 loss_pde:60.23140213, loss_ic:0.03462620
# epoch 20 loss_pde:59.76756149, loss_ic:0.03468313
# epoch 20 loss_pde:59.30755695, loss_ic:0.03474064
# epoch 20 loss_pde:58.85157754, loss_ic:0.03479849
# epoch 20 loss_pde:58.39908306, loss_ic:0.03485688
# epoch 20 loss_pde:57.95042485, loss_ic:0.03491574
# epoch 20 loss_pde:57.50552731, loss_ic:0.03497497
# epoch 20 loss_pde:57.06508791, loss_ic:0.03503466
# loss_tot:72.06856718
# epoch 21 loss_pde:56.62886228, loss_ic:0.03509458
# epoch 21 loss_pde:56.19722563, loss_ic:0.03515497
# epoch 21 loss_pde:55.76971787, loss_ic:0.03521555
# epoch 21 loss_pde:55.34661978, loss_ic:0.03527664
# epoch 21 loss_pde:54.92746881, loss_ic:0.03533790
# epoch 21 loss_pde:54.51255066, loss_ic:0.03539971
# epoch 21 loss_pde:54.10142838, loss_ic:0.03546167
# epoch 21 loss_pde:53.69437455, loss_ic:0.03552422
# epoch 21 loss_pde:53.29095728, loss_ic:0.03558689
# epoch 21 loss_pde:52.89138641, loss_ic:0.03565021
# epoch 21 loss_pde:52.49520442, loss_ic:0.03571361
# epoch 21 loss_pde:52.10247919, loss_ic:0.03577775
# epoch 21 loss_pde:51.71268739, loss_ic:0.03584192
# epoch 21 loss_pde:51.32572452, loss_ic:0.03590698
# epoch 21 loss_pde:50.94089431, loss_ic:0.03597223
# epoch 21 loss_pde:50.55737460, loss_ic:0.03603875
# epoch 21 loss_pde:50.17219038, loss_ic:0.03610629
# epoch 21 loss_pde:49.78303121, loss_ic:0.03617626
# epoch 21 loss_pde:49.39722071, loss_ic:0.03624623
# epoch 21 loss_pde:49.02477742, loss_ic:0.03631527
# epoch 21 loss_pde:48.66328686, loss_ic:0.03638305
# epoch 21 loss_pde:48.30703282, loss_ic:0.03645111
# epoch 21 loss_pde:47.95491480, loss_ic:0.03651927
# epoch 21 loss_pde:47.60644364, loss_ic:0.03658780
# epoch 21 loss_pde:47.26110142, loss_ic:0.03665685
# epoch 21 loss_pde:46.91862912, loss_ic:0.03672630
# epoch 21 loss_pde:46.57875166, loss_ic:0.03679632
# epoch 21 loss_pde:46.24118103, loss_ic:0.03686683
# epoch 21 loss_pde:45.90603888, loss_ic:0.03693790
# epoch 21 loss_pde:45.57329361, loss_ic:0.03700944
# loss_tot:56.97980807
# epoch 22 loss_pde:45.24326275, loss_ic:0.03708147
# epoch 22 loss_pde:44.91595925, loss_ic:0.03715389
# epoch 22 loss_pde:44.59153182, loss_ic:0.03722679
# epoch 22 loss_pde:44.26993227, loss_ic:0.03730002
# epoch 22 loss_pde:43.95119227, loss_ic:0.03737376
# epoch 22 loss_pde:43.63522385, loss_ic:0.03744782
# epoch 22 loss_pde:43.32204251, loss_ic:0.03752242
# epoch 22 loss_pde:43.01152087, loss_ic:0.03759733
# epoch 22 loss_pde:42.70367514, loss_ic:0.03767281
# epoch 22 loss_pde:42.39822509, loss_ic:0.03774862
# epoch 22 loss_pde:42.09504204, loss_ic:0.03782512
# epoch 22 loss_pde:41.79360572, loss_ic:0.03790200
# epoch 22 loss_pde:41.49395451, loss_ic:0.03797975
# epoch 22 loss_pde:41.19602977, loss_ic:0.03805776
# epoch 22 loss_pde:40.90035035, loss_ic:0.03813660
# epoch 22 loss_pde:40.60688394, loss_ic:0.03821550
# epoch 22 loss_pde:40.31602746, loss_ic:0.03829514
# epoch 22 loss_pde:40.02751330, loss_ic:0.03837479
# epoch 22 loss_pde:39.74169364, loss_ic:0.03845516
# epoch 22 loss_pde:39.45824154, loss_ic:0.03853548
# epoch 22 loss_pde:39.17746947, loss_ic:0.03861652
# epoch 22 loss_pde:38.89898691, loss_ic:0.03869751
# epoch 22 loss_pde:38.62305135, loss_ic:0.03877924
# epoch 22 loss_pde:38.34927569, loss_ic:0.03886094
# epoch 22 loss_pde:38.07791525, loss_ic:0.03894339
# epoch 22 loss_pde:37.80862581, loss_ic:0.03902581
# epoch 22 loss_pde:37.54166509, loss_ic:0.03910901
# epoch 22 loss_pde:37.27672916, loss_ic:0.03919217
# epoch 22 loss_pde:37.01405690, loss_ic:0.03927611
# epoch 22 loss_pde:36.75337229, loss_ic:0.03936001
# loss_tot:45.61407748
# epoch 23 loss_pde:36.49487397, loss_ic:0.03944470
# epoch 23 loss_pde:36.23830356, loss_ic:0.03952936
# epoch 23 loss_pde:35.98379893, loss_ic:0.03961484
# epoch 23 loss_pde:35.73110113, loss_ic:0.03970034
# epoch 23 loss_pde:35.48024034, loss_ic:0.03978672
# epoch 23 loss_pde:35.23089723, loss_ic:0.03987324
# epoch 23 loss_pde:34.98291005, loss_ic:0.03996082
# epoch 23 loss_pde:34.73592746, loss_ic:0.04004878
# epoch 23 loss_pde:34.48904348, loss_ic:0.04013811
# epoch 23 loss_pde:34.24027160, loss_ic:0.04022908
# epoch 23 loss_pde:33.98705869, loss_ic:0.04032286
# epoch 23 loss_pde:33.73367931, loss_ic:0.04041827
# epoch 23 loss_pde:33.49162395, loss_ic:0.04051002
# epoch 23 loss_pde:33.25745814, loss_ic:0.04060031
# epoch 23 loss_pde:33.02607706, loss_ic:0.04069015
# epoch 23 loss_pde:32.79728705, loss_ic:0.04078046
# epoch 23 loss_pde:32.57006878, loss_ic:0.04087085
# epoch 23 loss_pde:32.34467437, loss_ic:0.04096196
# epoch 23 loss_pde:32.12076523, loss_ic:0.04105324
# epoch 23 loss_pde:31.89843011, loss_ic:0.04114530
# epoch 23 loss_pde:31.67753011, loss_ic:0.04123758
# epoch 23 loss_pde:31.45808079, loss_ic:0.04133062
# epoch 23 loss_pde:31.23997139, loss_ic:0.04142399
# epoch 23 loss_pde:31.02321538, loss_ic:0.04151805
# epoch 23 loss_pde:30.80761855, loss_ic:0.04161264
# epoch 23 loss_pde:30.59317612, loss_ic:0.04170786
# epoch 23 loss_pde:30.37944097, loss_ic:0.04180405
# epoch 23 loss_pde:30.16624584, loss_ic:0.04190092
# epoch 23 loss_pde:29.95266723, loss_ic:0.04199977
# epoch 23 loss_pde:29.73883601, loss_ic:0.04209930
# loss_tot:36.88932095
# epoch 24 loss_pde:29.52372955, loss_ic:0.04220173
# epoch 24 loss_pde:29.29512393, loss_ic:0.04230970
# epoch 24 loss_pde:29.04331210, loss_ic:0.04243351
# epoch 24 loss_pde:28.83172240, loss_ic:0.04253677
# epoch 24 loss_pde:28.62940906, loss_ic:0.04263708
# epoch 24 loss_pde:28.42795738, loss_ic:0.04273777
# epoch 24 loss_pde:28.22817747, loss_ic:0.04283888
# epoch 24 loss_pde:28.02897718, loss_ic:0.04294079
# epoch 24 loss_pde:27.83080608, loss_ic:0.04304340
# epoch 24 loss_pde:27.63356803, loss_ic:0.04314669
# epoch 24 loss_pde:27.43700515, loss_ic:0.04325083
# epoch 24 loss_pde:27.24145994, loss_ic:0.04335557
# epoch 24 loss_pde:27.04669280, loss_ic:0.04346109
# epoch 24 loss_pde:26.85296659, loss_ic:0.04356718
# epoch 24 loss_pde:26.66020405, loss_ic:0.04367394
# epoch 24 loss_pde:26.46848760, loss_ic:0.04378128
# epoch 24 loss_pde:26.27781423, loss_ic:0.04388922
# epoch 24 loss_pde:26.08817241, loss_ic:0.04399776
# epoch 24 loss_pde:25.89955082, loss_ic:0.04410691
# epoch 24 loss_pde:25.71192301, loss_ic:0.04421669
# epoch 24 loss_pde:25.52523187, loss_ic:0.04432710
# epoch 24 loss_pde:25.33946569, loss_ic:0.04443821
# epoch 24 loss_pde:25.15449790, loss_ic:0.04455001
# epoch 24 loss_pde:24.97033063, loss_ic:0.04466261
# epoch 24 loss_pde:24.78673183, loss_ic:0.04477602
# epoch 24 loss_pde:24.60367553, loss_ic:0.04489042
# epoch 24 loss_pde:24.42074051, loss_ic:0.04500592
# epoch 24 loss_pde:24.23769401, loss_ic:0.04512286
# epoch 24 loss_pde:24.05379893, loss_ic:0.04524161
# epoch 24 loss_pde:23.86845853, loss_ic:0.04536268
# loss_tot:29.94574688
# epoch 25 loss_pde:23.68088721, loss_ic:0.04548656
# epoch 25 loss_pde:23.49268491, loss_ic:0.04561219
# epoch 25 loss_pde:23.30868600, loss_ic:0.04573652
# epoch 25 loss_pde:23.13106677, loss_ic:0.04585768
# epoch 25 loss_pde:22.95620610, loss_ic:0.04597847
# epoch 25 loss_pde:22.78311510, loss_ic:0.04609910
# epoch 25 loss_pde:22.61094703, loss_ic:0.04622065
# epoch 25 loss_pde:22.43965280, loss_ic:0.04634260
# epoch 25 loss_pde:22.26915919, loss_ic:0.04646562
# epoch 25 loss_pde:22.09940642, loss_ic:0.04658905
# epoch 25 loss_pde:21.93046344, loss_ic:0.04671359
# epoch 25 loss_pde:21.76225163, loss_ic:0.04683849
# epoch 25 loss_pde:21.59485146, loss_ic:0.04696453
# epoch 25 loss_pde:21.42820029, loss_ic:0.04709090
# epoch 25 loss_pde:21.26235198, loss_ic:0.04721839
# epoch 25 loss_pde:21.09722691, loss_ic:0.04734627
# epoch 25 loss_pde:20.93284280, loss_ic:0.04747524
# epoch 25 loss_pde:20.76910281, loss_ic:0.04760474
# epoch 25 loss_pde:20.60607194, loss_ic:0.04773529
# epoch 25 loss_pde:20.44371385, loss_ic:0.04786641
# epoch 25 loss_pde:20.28217605, loss_ic:0.04799845
# epoch 25 loss_pde:20.12144417, loss_ic:0.04813097
# epoch 25 loss_pde:19.96163427, loss_ic:0.04826433
# epoch 25 loss_pde:19.80269071, loss_ic:0.04839809
# epoch 25 loss_pde:19.64464573, loss_ic:0.04853275
# epoch 25 loss_pde:19.48741198, loss_ic:0.04866778
# epoch 25 loss_pde:19.33091674, loss_ic:0.04880395
# epoch 25 loss_pde:19.17500947, loss_ic:0.04894055
# epoch 25 loss_pde:19.01952144, loss_ic:0.04907874
# epoch 25 loss_pde:18.86454360, loss_ic:0.04921732
# loss_tot:24.13575281
# epoch 26 loss_pde:18.71009562, loss_ic:0.04935749
# epoch 26 loss_pde:18.55656595, loss_ic:0.04949771
# epoch 26 loss_pde:18.40383131, loss_ic:0.04963926
# epoch 26 loss_pde:18.25218958, loss_ic:0.04978073
# epoch 26 loss_pde:18.10150523, loss_ic:0.04992331
# epoch 26 loss_pde:17.95187730, loss_ic:0.05006590
# epoch 26 loss_pde:17.80331309, loss_ic:0.05020942
# epoch 26 loss_pde:17.65574069, loss_ic:0.05035304
# epoch 26 loss_pde:17.50924735, loss_ic:0.05049751
# epoch 26 loss_pde:17.36375485, loss_ic:0.05064212
# epoch 26 loss_pde:17.21926895, loss_ic:0.05078757
# epoch 26 loss_pde:17.07583147, loss_ic:0.05093318
# epoch 26 loss_pde:16.93332649, loss_ic:0.05107963
# epoch 26 loss_pde:16.79186503, loss_ic:0.05122629
# epoch 26 loss_pde:16.65133379, loss_ic:0.05137373
# epoch 26 loss_pde:16.51176514, loss_ic:0.05152151
# epoch 26 loss_pde:16.37313228, loss_ic:0.05166999
# epoch 26 loss_pde:16.23535899, loss_ic:0.05181895
# epoch 26 loss_pde:16.09840561, loss_ic:0.05196872
# epoch 26 loss_pde:15.96217275, loss_ic:0.05211915
# epoch 26 loss_pde:15.82632591, loss_ic:0.05227089
# epoch 26 loss_pde:15.69094487, loss_ic:0.05242358
# epoch 26 loss_pde:15.55563810, loss_ic:0.05257797
# epoch 26 loss_pde:15.42007049, loss_ic:0.05273420
# epoch 26 loss_pde:15.28358388, loss_ic:0.05289329
# epoch 26 loss_pde:15.14647489, loss_ic:0.05305478
# epoch 26 loss_pde:15.01145019, loss_ic:0.05321559
# epoch 26 loss_pde:14.88166652, loss_ic:0.05337176
# epoch 26 loss_pde:14.75515982, loss_ic:0.05352568
# epoch 26 loss_pde:14.63026137, loss_ic:0.05367905
# loss_tot:19.20367054
# epoch 27 loss_pde:14.50651658, loss_ic:0.05383276
# epoch 27 loss_pde:14.38387686, loss_ic:0.05398641
# epoch 27 loss_pde:14.26211037, loss_ic:0.05414080
# epoch 27 loss_pde:14.14145478, loss_ic:0.05429500
# epoch 27 loss_pde:14.02162358, loss_ic:0.05445008
# epoch 27 loss_pde:13.90289598, loss_ic:0.05460488
# epoch 27 loss_pde:13.78501857, loss_ic:0.05476055
# epoch 27 loss_pde:13.66823791, loss_ic:0.05491588
# epoch 27 loss_pde:13.55232955, loss_ic:0.05507201
# epoch 27 loss_pde:13.43748752, loss_ic:0.05522789
# epoch 27 loss_pde:13.32348751, loss_ic:0.05538444
# epoch 27 loss_pde:13.21016734, loss_ic:0.05554157
# epoch 27 loss_pde:13.09717187, loss_ic:0.05569967
# epoch 27 loss_pde:12.98449340, loss_ic:0.05585945
# epoch 27 loss_pde:12.86910194, loss_ic:0.05602366
# epoch 27 loss_pde:12.74966941, loss_ic:0.05619688
# epoch 27 loss_pde:12.62224966, loss_ic:0.05638126
# epoch 27 loss_pde:12.50745217, loss_ic:0.05655105
# epoch 27 loss_pde:12.40213888, loss_ic:0.05670754
# epoch 27 loss_pde:12.29837187, loss_ic:0.05686372
# epoch 27 loss_pde:12.19593620, loss_ic:0.05701896
# epoch 27 loss_pde:12.09396288, loss_ic:0.05717545
# epoch 27 loss_pde:11.99321572, loss_ic:0.05733117
# epoch 27 loss_pde:11.89296758, loss_ic:0.05748819
# epoch 27 loss_pde:11.79389455, loss_ic:0.05764444
# epoch 27 loss_pde:11.69550213, loss_ic:0.05780175
# epoch 27 loss_pde:11.59812321, loss_ic:0.05795840
# epoch 27 loss_pde:11.50166775, loss_ic:0.05811572
# epoch 27 loss_pde:11.40596260, loss_ic:0.05827259
# epoch 27 loss_pde:11.31129303, loss_ic:0.05843003
# loss_tot:15.04484420
# epoch 28 loss_pde:11.21733442, loss_ic:0.05858688
# epoch 28 loss_pde:11.12441359, loss_ic:0.05874441
# epoch 28 loss_pde:11.03250865, loss_ic:0.05890074
# epoch 28 loss_pde:10.94147281, loss_ic:0.05905812
# epoch 28 loss_pde:10.85172131, loss_ic:0.05921382
# epoch 28 loss_pde:10.76270338, loss_ic:0.05937083
# epoch 28 loss_pde:10.67495964, loss_ic:0.05952613
# epoch 28 loss_pde:10.58798080, loss_ic:0.05968265
# epoch 28 loss_pde:10.50196007, loss_ic:0.05983789
# epoch 28 loss_pde:10.41654128, loss_ic:0.05999470
# epoch 28 loss_pde:10.33146821, loss_ic:0.06015120
# epoch 28 loss_pde:10.24624441, loss_ic:0.06031082
# epoch 28 loss_pde:10.16040856, loss_ic:0.06047198
# epoch 28 loss_pde:10.07351685, loss_ic:0.06063787
# epoch 28 loss_pde:9.98772359, loss_ic:0.06080286
# epoch 28 loss_pde:9.90604969, loss_ic:0.06096149
# epoch 28 loss_pde:9.82714949, loss_ic:0.06111681
# epoch 28 loss_pde:9.74997889, loss_ic:0.06126965
# epoch 28 loss_pde:9.67365819, loss_ic:0.06142303
# epoch 28 loss_pde:9.59822421, loss_ic:0.06157540
# epoch 28 loss_pde:9.52362025, loss_ic:0.06172833
# epoch 28 loss_pde:9.44967362, loss_ic:0.06188065
# epoch 28 loss_pde:9.37658406, loss_ic:0.06203344
# epoch 28 loss_pde:9.30440589, loss_ic:0.06218509
# epoch 28 loss_pde:9.23280098, loss_ic:0.06233781
# epoch 28 loss_pde:9.16241949, loss_ic:0.06248874
# epoch 28 loss_pde:9.09260928, loss_ic:0.06264070
# epoch 28 loss_pde:9.02394965, loss_ic:0.06279094
# epoch 28 loss_pde:8.95618129, loss_ic:0.06294142
# epoch 28 loss_pde:8.88930783, loss_ic:0.06309062
# loss_tot:11.80320324
# epoch 29 loss_pde:8.82336463, loss_ic:0.06323989
# epoch 29 loss_pde:8.75832008, loss_ic:0.06338779
# epoch 29 loss_pde:8.69398376, loss_ic:0.06353624
# epoch 29 loss_pde:8.63054060, loss_ic:0.06368324
# epoch 29 loss_pde:8.56766236, loss_ic:0.06383113
# epoch 29 loss_pde:8.50556960, loss_ic:0.06397772
# epoch 29 loss_pde:8.44409413, loss_ic:0.06412501
# epoch 29 loss_pde:8.38335340, loss_ic:0.06427110
# epoch 29 loss_pde:8.32330052, loss_ic:0.06441756
# epoch 29 loss_pde:8.26400110, loss_ic:0.06456287
# epoch 29 loss_pde:8.20529362, loss_ic:0.06470851
# epoch 29 loss_pde:8.14716548, loss_ic:0.06485365
# epoch 29 loss_pde:8.08928217, loss_ic:0.06499969
# epoch 29 loss_pde:8.03156637, loss_ic:0.06514664
# epoch 29 loss_pde:7.97406852, loss_ic:0.06529435
# epoch 29 loss_pde:7.91709141, loss_ic:0.06544237
# epoch 29 loss_pde:7.86073301, loss_ic:0.06558988
# epoch 29 loss_pde:7.80510622, loss_ic:0.06573733
# epoch 29 loss_pde:7.75020192, loss_ic:0.06588374
# epoch 29 loss_pde:7.69604683, loss_ic:0.06603017
# epoch 29 loss_pde:7.64263309, loss_ic:0.06617527
# epoch 29 loss_pde:7.58993759, loss_ic:0.06632054
# epoch 29 loss_pde:7.53795014, loss_ic:0.06646438
# epoch 29 loss_pde:7.48664460, loss_ic:0.06660851
# epoch 29 loss_pde:7.43597720, loss_ic:0.06675126
# epoch 29 loss_pde:7.38596132, loss_ic:0.06689439
# epoch 29 loss_pde:7.33649895, loss_ic:0.06703625
# epoch 29 loss_pde:7.28765260, loss_ic:0.06717858
# epoch 29 loss_pde:7.23929802, loss_ic:0.06731974
# epoch 29 loss_pde:7.19149824, loss_ic:0.06746158
# loss_tot:9.45576357
# epoch 30 loss_pde:7.14416782, loss_ic:0.06760224
# epoch 30 loss_pde:7.09729088, loss_ic:0.06774398
# epoch 30 loss_pde:7.05089375, loss_ic:0.06788448
# epoch 30 loss_pde:7.00485698, loss_ic:0.06802637
# epoch 30 loss_pde:6.95928154, loss_ic:0.06816712
# epoch 30 loss_pde:6.91401301, loss_ic:0.06830932
# epoch 30 loss_pde:6.86920147, loss_ic:0.06845057
# epoch 30 loss_pde:6.82475887, loss_ic:0.06859269
# epoch 30 loss_pde:6.78072069, loss_ic:0.06873429
# epoch 30 loss_pde:6.73702225, loss_ic:0.06887641
# epoch 30 loss_pde:6.69364844, loss_ic:0.06901873
# epoch 30 loss_pde:6.65015923, loss_ic:0.06916197
# epoch 30 loss_pde:6.60613196, loss_ic:0.06931032
# epoch 30 loss_pde:6.56422973, loss_ic:0.06945104
# epoch 30 loss_pde:6.52371052, loss_ic:0.06958988
# epoch 30 loss_pde:6.48348878, loss_ic:0.06972738
# epoch 30 loss_pde:6.44387334, loss_ic:0.06986552
# epoch 30 loss_pde:6.40479278, loss_ic:0.07000171
# epoch 30 loss_pde:6.36599889, loss_ic:0.07013958
# epoch 30 loss_pde:6.32783173, loss_ic:0.07027530
# epoch 30 loss_pde:6.28996817, loss_ic:0.07041245
# epoch 30 loss_pde:6.25265534, loss_ic:0.07054774
# epoch 30 loss_pde:6.21575029, loss_ic:0.07068394
# epoch 30 loss_pde:6.17932999, loss_ic:0.07081847
# epoch 30 loss_pde:6.14331666, loss_ic:0.07095388
# epoch 30 loss_pde:6.10766854, loss_ic:0.07108789
# epoch 30 loss_pde:6.07215236, loss_ic:0.07122404
# epoch 30 loss_pde:6.03696608, loss_ic:0.07135878
# epoch 30 loss_pde:6.00155502, loss_ic:0.07149702
# epoch 30 loss_pde:5.96568751, loss_ic:0.07163685
# loss_tot:7.82019027
# epoch 31 loss_pde:5.92886778, loss_ic:0.07178309
# ...
# epoch 248 loss_pde:0.10111542, loss_ic:0.04924146
# epoch 248 loss_pde:0.10113320, loss_ic:0.04923553
# epoch 248 loss_pde:0.10114953, loss_ic:0.04922968
# epoch 248 loss_pde:0.10120041, loss_ic:0.04921944
# epoch 248 loss_pde:0.10121681, loss_ic:0.04921379
# epoch 248 loss_pde:0.10123401, loss_ic:0.04920771
# epoch 248 loss_pde:0.10127469, loss_ic:0.04919507
# epoch 248 loss_pde:0.10129304, loss_ic:0.04918907
# epoch 248 loss_pde:0.10131852, loss_ic:0.04918200
# epoch 248 loss_pde:0.10133905, loss_ic:0.04917553
# epoch 248 loss_pde:0.10135526, loss_ic:0.04916849
# epoch 248 loss_pde:0.10137281, loss_ic:0.04916212
# epoch 248 loss_pde:0.10140542, loss_ic:0.04915354
# epoch 248 loss_pde:0.10142573, loss_ic:0.04914683
# epoch 248 loss_pde:0.10145484, loss_ic:0.04913871
# epoch 248 loss_pde:0.10147613, loss_ic:0.04913186
# loss_tot:0.59416476
# epoch 249 loss_pde:0.10149481, loss_ic:0.04912507
# epoch 249 loss_pde:0.10153711, loss_ic:0.04911556
# epoch 249 loss_pde:0.10155739, loss_ic:0.04910771
# epoch 249 loss_pde:0.10158729, loss_ic:0.04909947
# epoch 249 loss_pde:0.10156594, loss_ic:0.04909520
# epoch 249 loss_pde:0.10158567, loss_ic:0.04908823
# epoch 249 loss_pde:0.10165558, loss_ic:0.04907457
# epoch 249 loss_pde:0.10168086, loss_ic:0.04906707
# epoch 249 loss_pde:0.10171617, loss_ic:0.04905764
# epoch 249 loss_pde:0.10174467, loss_ic:0.04904945
# epoch 249 loss_pde:0.10177221, loss_ic:0.04904129
# epoch 249 loss_pde:0.10180057, loss_ic:0.04903264
# epoch 249 loss_pde:0.10182553, loss_ic:0.04902447
# epoch 249 loss_pde:0.10185386, loss_ic:0.04901568
# epoch 249 loss_pde:0.10188458, loss_ic:0.04900564
# epoch 249 loss_pde:0.10191096, loss_ic:0.04899712
# epoch 249 loss_pde:0.10194050, loss_ic:0.04898802
# epoch 249 loss_pde:0.10196941, loss_ic:0.04897872
# epoch 249 loss_pde:0.10200218, loss_ic:0.04896867
# epoch 249 loss_pde:0.10203812, loss_ic:0.04895778
# epoch 249 loss_pde:0.10207224, loss_ic:0.04894755
# epoch 249 loss_pde:0.10210804, loss_ic:0.04893723
# epoch 249 loss_pde:0.10214149, loss_ic:0.04892685
# epoch 249 loss_pde:0.10218578, loss_ic:0.04891480
# epoch 249 loss_pde:0.10222341, loss_ic:0.04890353
# epoch 249 loss_pde:0.10226953, loss_ic:0.04889123
# epoch 249 loss_pde:0.10230698, loss_ic:0.04888045
# epoch 249 loss_pde:0.10234708, loss_ic:0.04886917
# epoch 249 loss_pde:0.10238648, loss_ic:0.04885778
# epoch 249 loss_pde:0.10244321, loss_ic:0.04884336
# loss_tot:0.59274555
# epoch 250 loss_pde:0.10248287, loss_ic:0.04883206
# epoch 250 loss_pde:0.10252237, loss_ic:0.04882063
# epoch 250 loss_pde:0.10256352, loss_ic:0.04880876
# epoch 250 loss_pde:0.10260549, loss_ic:0.04879653
# epoch 250 loss_pde:0.10264770, loss_ic:0.04878438
# epoch 250 loss_pde:0.10267462, loss_ic:0.04877280
# epoch 250 loss_pde:0.10271887, loss_ic:0.04875999
# epoch 250 loss_pde:0.10271940, loss_ic:0.04875072
# epoch 250 loss_pde:0.10276162, loss_ic:0.04873838
# epoch 250 loss_pde:0.10280372, loss_ic:0.04872591
# epoch 250 loss_pde:0.10278334, loss_ic:0.04872016
# epoch 250 loss_pde:0.10282604, loss_ic:0.04870772
# epoch 250 loss_pde:0.10286410, loss_ic:0.04869575
# epoch 250 loss_pde:0.10290783, loss_ic:0.04868305
# epoch 250 loss_pde:0.10294068, loss_ic:0.04867117
# epoch 250 loss_pde:0.10298442, loss_ic:0.04865821
# epoch 250 loss_pde:0.10302526, loss_ic:0.04864537
# epoch 250 loss_pde:0.10307173, loss_ic:0.04863180
# epoch 250 loss_pde:0.10310828, loss_ic:0.04861899
# epoch 250 loss_pde:0.10315482, loss_ic:0.04860517
# epoch 250 loss_pde:0.10319239, loss_ic:0.04859206
# epoch 250 loss_pde:0.10323478, loss_ic:0.04857832
# epoch 250 loss_pde:0.10346133, loss_ic:0.04853611
# epoch 250 loss_pde:0.10350052, loss_ic:0.04852263
# epoch 250 loss_pde:0.10354668, loss_ic:0.04850866
# epoch 250 loss_pde:0.10359244, loss_ic:0.04849511
# epoch 250 loss_pde:0.10366936, loss_ic:0.04847631
# epoch 250 loss_pde:0.10371840, loss_ic:0.04846248
# epoch 250 loss_pde:0.10375755, loss_ic:0.04844948
# epoch 250 loss_pde:0.10381464, loss_ic:0.04843367
# loss_tot:0.59080349
# epoch 251 loss_pde:0.10386520, loss_ic:0.04841920
# epoch 251 loss_pde:0.10392349, loss_ic:0.04840312
# epoch 251 loss_pde:0.10397271, loss_ic:0.04838928
# epoch 251 loss_pde:0.10402444, loss_ic:0.04837460
# epoch 251 loss_pde:0.10407396, loss_ic:0.04836081
# epoch 251 loss_pde:0.10412190, loss_ic:0.04834710
# epoch 251 loss_pde:0.10417488, loss_ic:0.04833277
# epoch 251 loss_pde:0.10421449, loss_ic:0.04831784
# epoch 251 loss_pde:0.10426346, loss_ic:0.04830424
# epoch 251 loss_pde:0.10432464, loss_ic:0.04828894
# epoch 251 loss_pde:0.10437588, loss_ic:0.04827492
# epoch 251 loss_pde:0.10442819, loss_ic:0.04826070
# epoch 251 loss_pde:0.10448002, loss_ic:0.04824650
# epoch 251 loss_pde:0.10464963, loss_ic:0.04821939
# epoch 251 loss_pde:0.10470265, loss_ic:0.04820550
# epoch 251 loss_pde:0.10475337, loss_ic:0.04819142
# epoch 251 loss_pde:0.10480581, loss_ic:0.04817692
# epoch 251 loss_pde:0.10486110, loss_ic:0.04816190
# epoch 251 loss_pde:0.10491299, loss_ic:0.04814722
# epoch 251 loss_pde:0.10496842, loss_ic:0.04813225
# epoch 251 loss_pde:0.10501995, loss_ic:0.04811735
# epoch 251 loss_pde:0.10507813, loss_ic:0.04810183
# epoch 251 loss_pde:0.10512683, loss_ic:0.04808710
# epoch 251 loss_pde:0.10518095, loss_ic:0.04807234
# epoch 251 loss_pde:0.10523041, loss_ic:0.04805780
# epoch 251 loss_pde:0.10527739, loss_ic:0.04804321
# epoch 251 loss_pde:0.10535716, loss_ic:0.04802485
# epoch 251 loss_pde:0.10540737, loss_ic:0.04801085
# epoch 251 loss_pde:0.10547901, loss_ic:0.04799484
# epoch 251 loss_pde:0.10552994, loss_ic:0.04798052
# loss_tot:0.58805720
# epoch 252 loss_pde:0.10558405, loss_ic:0.04796665
# epoch 252 loss_pde:0.10563675, loss_ic:0.04795210
# epoch 252 loss_pde:0.10569310, loss_ic:0.04793809
# epoch 252 loss_pde:0.10574297, loss_ic:0.04792492
# epoch 252 loss_pde:0.10579588, loss_ic:0.04791126
# epoch 252 loss_pde:0.10585288, loss_ic:0.04789671
# epoch 252 loss_pde:0.10590585, loss_ic:0.04788317
# epoch 252 loss_pde:0.10597194, loss_ic:0.04786754
# epoch 252 loss_pde:0.10602420, loss_ic:0.04785477
# epoch 252 loss_pde:0.10607798, loss_ic:0.04784149
# epoch 252 loss_pde:0.10613245, loss_ic:0.04782824
# epoch 252 loss_pde:0.10617796, loss_ic:0.04781579
# epoch 252 loss_pde:0.10624184, loss_ic:0.04780034
# epoch 252 loss_pde:0.10629063, loss_ic:0.04778661
# epoch 252 loss_pde:0.10633903, loss_ic:0.04777355
# epoch 252 loss_pde:0.10640233, loss_ic:0.04775921
# epoch 252 loss_pde:0.10643778, loss_ic:0.04774583
# epoch 252 loss_pde:0.10648119, loss_ic:0.04773320
# epoch 252 loss_pde:0.10652705, loss_ic:0.04772080
# epoch 252 loss_pde:0.10656862, loss_ic:0.04770956
# epoch 252 loss_pde:0.10661586, loss_ic:0.04769755
# epoch 252 loss_pde:0.10666249, loss_ic:0.04768545
# epoch 252 loss_pde:0.10671196, loss_ic:0.04767326
# epoch 252 loss_pde:0.10675741, loss_ic:0.04766142
# epoch 252 loss_pde:0.10680411, loss_ic:0.04764982
# epoch 252 loss_pde:0.10684575, loss_ic:0.04763825
# epoch 252 loss_pde:0.10688981, loss_ic:0.04762736
# epoch 252 loss_pde:0.10693457, loss_ic:0.04761629
# epoch 252 loss_pde:0.10697801, loss_ic:0.04760500
# epoch 252 loss_pde:0.10702322, loss_ic:0.04759391
# loss_tot:0.58525056
# epoch 253 loss_pde:0.10706415, loss_ic:0.04758333
# epoch 253 loss_pde:0.10710848, loss_ic:0.04757238
# epoch 253 loss_pde:0.10714847, loss_ic:0.04756195
# epoch 253 loss_pde:0.10719121, loss_ic:0.04755132
# epoch 253 loss_pde:0.10722995, loss_ic:0.04754111
# epoch 253 loss_pde:0.10727112, loss_ic:0.04753078
# epoch 253 loss_pde:0.10730837, loss_ic:0.04752091
# epoch 253 loss_pde:0.10734827, loss_ic:0.04751085
# epoch 253 loss_pde:0.10738478, loss_ic:0.04750119
# epoch 253 loss_pde:0.10742393, loss_ic:0.04749132
# epoch 253 loss_pde:0.10746394, loss_ic:0.04748134
# epoch 253 loss_pde:0.10751104, loss_ic:0.04747043
# epoch 253 loss_pde:0.10755062, loss_ic:0.04746077
# epoch 253 loss_pde:0.10758914, loss_ic:0.04745104
# epoch 253 loss_pde:0.10763360, loss_ic:0.04744037
# epoch 253 loss_pde:0.10767272, loss_ic:0.04743068
# epoch 253 loss_pde:0.10771584, loss_ic:0.04742070
# epoch 253 loss_pde:0.10775496, loss_ic:0.04741130
# epoch 253 loss_pde:0.10778008, loss_ic:0.04740325
# epoch 253 loss_pde:0.10781721, loss_ic:0.04739462
# epoch 253 loss_pde:0.10785679, loss_ic:0.04738559
# epoch 253 loss_pde:0.10789283, loss_ic:0.04737686
# epoch 253 loss_pde:0.10793927, loss_ic:0.04736678
# epoch 253 loss_pde:0.10797823, loss_ic:0.04735775
# epoch 253 loss_pde:0.10802407, loss_ic:0.04734779
# epoch 253 loss_pde:0.10806271, loss_ic:0.04733888
# epoch 253 loss_pde:0.10810442, loss_ic:0.04732981
# epoch 253 loss_pde:0.10814196, loss_ic:0.04732130
# epoch 253 loss_pde:0.10818226, loss_ic:0.04731256
# epoch 253 loss_pde:0.10821891, loss_ic:0.04730430
# loss_tot:0.58289745
# epoch 254 loss_pde:0.10825892, loss_ic:0.04729576
# epoch 254 loss_pde:0.10829467, loss_ic:0.04728775
# epoch 254 loss_pde:0.10833424, loss_ic:0.04727939
# epoch 254 loss_pde:0.10837049, loss_ic:0.04727140
# epoch 254 loss_pde:0.10840237, loss_ic:0.04726379
# epoch 254 loss_pde:0.10843169, loss_ic:0.04725682
# epoch 254 loss_pde:0.10846640, loss_ic:0.04724925
# epoch 254 loss_pde:0.10849226, loss_ic:0.04724232
# epoch 254 loss_pde:0.10852527, loss_ic:0.04723490
# epoch 254 loss_pde:0.10855269, loss_ic:0.04722819
# epoch 254 loss_pde:0.10859330, loss_ic:0.04721988
# epoch 254 loss_pde:0.10862554, loss_ic:0.04721262
# epoch 254 loss_pde:0.10866848, loss_ic:0.04720422
# epoch 254 loss_pde:0.10870211, loss_ic:0.04719700
# epoch 254 loss_pde:0.10873939, loss_ic:0.04718953
# epoch 254 loss_pde:0.10877260, loss_ic:0.04718231
# epoch 254 loss_pde:0.10880616, loss_ic:0.04717526
# epoch 254 loss_pde:0.10883845, loss_ic:0.04716833
# epoch 254 loss_pde:0.10886619, loss_ic:0.04716192
# epoch 254 loss_pde:0.10890247, loss_ic:0.04715450
# epoch 254 loss_pde:0.10893154, loss_ic:0.04714806
# epoch 254 loss_pde:0.10897080, loss_ic:0.04714046
# epoch 254 loss_pde:0.10900184, loss_ic:0.04713397
# epoch 254 loss_pde:0.10904251, loss_ic:0.04712644
# epoch 254 loss_pde:0.10907986, loss_ic:0.04711944
# epoch 254 loss_pde:0.10908082, loss_ic:0.04711324
# epoch 254 loss_pde:0.10911196, loss_ic:0.04710713
# epoch 254 loss_pde:0.10914269, loss_ic:0.04710104
# epoch 254 loss_pde:0.10918487, loss_ic:0.04709312
# epoch 254 loss_pde:0.10921865, loss_ic:0.04708652
# loss_tot:0.58121652
# epoch 255 loss_pde:0.10925017, loss_ic:0.04708027
# epoch 255 loss_pde:0.10928346, loss_ic:0.04707389
# epoch 255 loss_pde:0.10931283, loss_ic:0.04706792
# epoch 255 loss_pde:0.10934560, loss_ic:0.04706163
# epoch 255 loss_pde:0.10937627, loss_ic:0.04705559
# epoch 255 loss_pde:0.10940693, loss_ic:0.04704953
# epoch 255 loss_pde:0.10944612, loss_ic:0.04704245
# epoch 255 loss_pde:0.10947847, loss_ic:0.04703612
# epoch 255 loss_pde:0.10951351, loss_ic:0.04702937
# epoch 255 loss_pde:0.10954696, loss_ic:0.04702313
# epoch 255 loss_pde:0.10957198, loss_ic:0.04701772
# epoch 255 loss_pde:0.10960375, loss_ic:0.04701178
# epoch 255 loss_pde:0.10963300, loss_ic:0.04700618
# epoch 255 loss_pde:0.10968142, loss_ic:0.04699815
# epoch 255 loss_pde:0.10971291, loss_ic:0.04699237
# epoch 255 loss_pde:0.10974258, loss_ic:0.04698680
# epoch 255 loss_pde:0.10978282, loss_ic:0.04697990
# epoch 255 loss_pde:0.10981429, loss_ic:0.04697410
# epoch 255 loss_pde:0.10984607, loss_ic:0.04696829
# epoch 255 loss_pde:0.10989355, loss_ic:0.04695946
# epoch 255 loss_pde:0.10992540, loss_ic:0.04695352
# epoch 255 loss_pde:0.10995841, loss_ic:0.04694753
# epoch 255 loss_pde:0.10998945, loss_ic:0.04694177
# epoch 255 loss_pde:0.11002227, loss_ic:0.04693588
# epoch 255 loss_pde:0.11005301, loss_ic:0.04693006
# epoch 255 loss_pde:0.11008745, loss_ic:0.04692387
# epoch 255 loss_pde:0.11012440, loss_ic:0.04691745
# epoch 255 loss_pde:0.11015496, loss_ic:0.04691179
# epoch 255 loss_pde:0.11019239, loss_ic:0.04690543
# epoch 255 loss_pde:0.11022469, loss_ic:0.04689959
# loss_tot:0.58005284
# epoch 256 loss_pde:0.11025714, loss_ic:0.04689381
# epoch 256 loss_pde:0.11028909, loss_ic:0.04688815
# epoch 256 loss_pde:0.11032038, loss_ic:0.04688260
# epoch 256 loss_pde:0.11035265, loss_ic:0.04687694
# epoch 256 loss_pde:0.11038352, loss_ic:0.04687148
# epoch 256 loss_pde:0.11041565, loss_ic:0.04686589
# epoch 256 loss_pde:0.11044583, loss_ic:0.04686050
# epoch 256 loss_pde:0.11047832, loss_ic:0.04685494
# epoch 256 loss_pde:0.11050763, loss_ic:0.04684977
# epoch 256 loss_pde:0.11054071, loss_ic:0.04684420
# epoch 256 loss_pde:0.11056973, loss_ic:0.04683911
# epoch 256 loss_pde:0.11060239, loss_ic:0.04683365
# epoch 256 loss_pde:0.11063084, loss_ic:0.04682866
# epoch 256 loss_pde:0.11066165, loss_ic:0.04682347
# epoch 256 loss_pde:0.11068931, loss_ic:0.04681857
# epoch 256 loss_pde:0.11071979, loss_ic:0.04681342
# epoch 256 loss_pde:0.11074690, loss_ic:0.04680858
# epoch 256 loss_pde:0.11077719, loss_ic:0.04680346
# epoch 256 loss_pde:0.11080388, loss_ic:0.04679868
# epoch 256 loss_pde:0.11083396, loss_ic:0.04679359
# epoch 256 loss_pde:0.11086059, loss_ic:0.04678886
# epoch 256 loss_pde:0.11089051, loss_ic:0.04678380
# epoch 256 loss_pde:0.11091717, loss_ic:0.04677913
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4159635/4183524978.py in <module>
#       4 tic = time.time()
#       5 for epoch in range(epochi, epochs+epochi):
# ----> 6     loss = train(epoch)
#       7     print(f'loss_tot:{loss:.8f}')
#       8     #loss_history.append(to_numpy(loss))
#
# /tmp/ipykernel_4159635/2479335744.py in train(epoch)
#      16         loss.backward()
#      17         return loss
# ---> 18     loss = optimizer.step(closure)
#      19     return loss
#      20
#
# ~/.local/lib/python3.10/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     278                                                f"but got {result}.")
#     279
# --> 280                 out = func(*args, **kwargs)
#     281                 self._optimizer_step_code()
#     282
#
# ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# ~/.local/lib/python3.10/site-packages/torch/optim/lbfgs.py in step(self, closure)
#     436                     # no use to re-evaluate that function here
#     437                     with torch.enable_grad():
# --> 438                         loss = float(closure())
#     439                     flat_grad = self._gather_flat_grad()
#     440                     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /tmp/ipykernel_4159635/2479335744.py in closure()
#       3     def closure():
#       4         optimizer.zero_grad()
# ----> 5         loss_pde = model.loss_pde(x_int)
#       6         loss_ic = model.loss_ic(x_ic, rho_ic,u_ic,p_ic)
#       7         #loss_bc = model.loss_ic(x_bc, rho_bc,u_bc,p_bc)
#
# ~/BflySrc/PySrc/PINNsrc/PINNs.py in loss_pde(self, x)
#      80         dU2_g = gradients(U2, x)[0]
#      81         U2_t,U2_x = dU2_g[:,:1], dU2_g[:,1:]
# ---> 82         dU3_g = gradients(U3, x)[0]
#      83         U3_t,U3_x = dU3_g[:,:1], dU3_g[:,1:]
#      84         dF2_g = gradients(F2, x)[0]
#
# ~/BflySrc/PySrc/PINNsrc/PINNs.py in gradients(outputs, inputs)
#      16 cpu = torch.device('cuda')
#      17 def gradients(outputs, inputs):
# ---> 18     return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)
#      19
#      20 # Convert torch tensor into np.array
#
# ~/.local/lib/python3.10/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     301         return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     302     else:
# --> 303         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     304             t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     305             allow_unused, accumulate_grad=False)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
x = np.linspace(0.0, 1.0, 100)                                   
t = np.linspace(0.1,  0.1, 1)                                     
t_grid, x_grid = np.meshgrid(t, x)                               
T = t_grid.flatten()[:, None]                                    
X = x_grid.flatten()[:, None]                                    
x_test = np.hstack((T, X))                                       
x_test = torch.tensor(x_test, requires_grad=True, dtype=dtype).to(cuda)
u_pred = model(x_test)
rho, p,u = u_pred[:, 0], u_pred[:, 1], u_pred[:, 2]          
U2 = rho*u
U3 = 0.5*rho*u**2 + p/0.4

#F1 = U2
F2 = rho*u**2+p
F3 = u*(U3 + p)

gamma = 1.4                                                    

# Gradients and partial derivatives
drho_g = gradients(rho, x_test)[0]                                  
rho_t, rho_x = drho_g[:, :1], drho_g[:, 1:]             


du_g = gradients(u, x_test)[0]                                      
u_t, u_x = du_g[:, :1], du_g[:, 1:]                            

dp_g = gradients(p, x_test)[0]                                      
p_t, p_x = dp_g[:, :1], dp_g[:, 1:]                            

dp_g = gradients(p, x_test)[0]                                     
p_t, p_x = dp_g[:, :1], dp_g[:, 1:]                           

dU2_g = gradients(U2, x_test)[0]
U2_t,U2_x = dU2_g[:,:1], dU2_g[:,1:]
dU3_g = gradients(U3, x_test)[0]
U3_t,U3_x = dU3_g[:,:1], dU3_g[:,1:]
dF2_g = gradients(F2, x_test)[0]
F2_t,F2_x = dF2_g[:,:1], dF2_g[:,1:]
dF3_g = gradients(F3, x_test)[0]
F3_t,F3_x = dF3_g[:,:1], dF3_g[:,1:]

d = 0.1*(abs(u_x)-(u_x))  + 1

#d = 0.1*(abs(uR-uL)-(uR-uL))/Dx + 1
#d = torch.exp(-10*u_x)+1
#d1 = torch.clamp(d/5,min=1)

f = ((rho_t + U2_x)/d)**2 + \
    ((U2_t  + F2_x)/d)**2 + \
    ((U3_t  + F3_x)/d)**2 #+\
#d = 1/(0.1*(torch.clamp((abs(u_x)-u_x))
d = 1/(0.1*(abs(u_x)-u_x)+1)
d = to_numpy(d)
f = to_numpy(f)
#d3 = to_numpy(d3)
u_pred = to_numpy(u_pred)
np.size(u_pred[:,0])
# Out:
# 100

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
#ax.scatter(x[:],u_pred[:,0])
#ax.scatter(x[:],u_pred[:,1])
#ax.scatter(x[:],u_pred[:,2])
ax.scatter(x[:],u_pred[:,1]/u_pred[:,0]/0.4)
#ax.scatter(x[:],d)
#ax.scatter(x[:],f)
#ax.plot(Exact[:,0],Exact[:,1],color='black')
#ax.plot(Exact[:,0],Exact[:,2],color='black')
#ax.plot(Exact[:,0],Exact[:,3],color='black')
ax.plot(Exact[:,0],Exact[:,4]/0.4,color='black')
ax.set_xlim(0.0, 1.0)
#ax.set_ylim(-1.0, 1.0)
plt.savefig('1.eps', format='eps')
#ax.set_ylim(0.0, 1.2)
plt.show()

# %%
np.min(Exact[:,3])

# %%
u_pred_i[:,:,k] = u_pred
k = k+1

# %%
u_pred_i = np.zeros((100,3,10))
k = 0

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.scatter(x[:],u_pred[:,0])
ax.scatter(x[:],u_pred[:,1])
ax.scatter(x[:],u_pred[:,2])
ax.plot(Exact[:,0],Exact[:,1])
ax.plot(Exact[:,0],Exact[:,2])
ax.plot(Exact[:,0],Exact[:,3])
ax.set_xlim(0.0, 1.0)
#ax.set_ylim(0.2, 1.2)
plt.show()

# %%
Exact = np.loadtxt('123e.dat')
Exact[:,0]
# Out:
# array([-0.0496663 , -0.04829213, -0.04691796, ...,  1.0455438 ,
#         1.04691796,  1.04829213])

# %%
fig,ax = plt.subplots()
x = np.linspace(0,1,100)
#ax.plot(x,np.max([0.1-x,np.zeros_like(x)],axis=0))
#ax.plot(x,np.exp(100*(0.1-x))/ np.exp(100*(0.1)))
#ax.plot(x,np.exp(100*(-x)))
ax.plot(x,np.exp(100*(x-0.1)))
plt.show()

# %%
np.max([0.1-x,np.zeros_like(x)],axis=0)

# %%
xp= x.flatten()[:,None]
rhop= u_pred[:,0].flatten()[:,None]
up= u_pred[:,1].flatten()[:,None]
pp= u_pred[:,2].flatten()[:,None]
uxy= np.hstack((xp,rhop,up,pp))    
np.savetxt('shockCrho.dat', uxy)

# %%
# first 15000step conservation
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x[:],u_pred[:,0])
plt.scatter(x[:],u_pred[:,1])
plt.scatter(x[:],u_pred[:,2])
plt.show()

# %%
# first 15000step non-conservation
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x[:],u_pred[:,0])
plt.scatter(x[:],u_pred[:,1])
plt.scatter(x[:],u_pred[:,2])
plt.show()
