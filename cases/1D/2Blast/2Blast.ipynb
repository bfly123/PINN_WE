# %%
from PINNs import *
import torch
import numpy as np
import matplotlib.pyplot as plt
from smt.sampling_methods import LHS
dtype=torch.float64
setup_seed(4)
Ts = 0
Te = 0.32
#Te = 0.1
Xs = 0
Xe = 1
Nx = 100
Nt = 100
dt = 0.002
dx = 0.01

crhoL =1.0
cuL = 0.0
cpL = 0.01

crhoR = 1.0
cuR = 0
cpR = 0.01
setup_seed(7)
def train(epoch):
    def closure():
        optimizer.zero_grad()                                                     
        loss_pde = model.loss_pde(x_int)                                    
        loss_ic = model.loss_ic(x_ic, rho_ic,u_ic,p_ic)   
        loss_bc = model.loss_ic(x_bc, rho_bc,u_bc,p_bc)   
        
        loss_rh = model.loss_rh(xrh,xrhL) # RH relation
        loss_con = model.loss_con(x_en,x_ic,crhoL,cuL,cpL,crhoR,cuR,cpR,Te-Ts) #Conservation laws
        loss_con1 = model.loss_con(x_en1,x_ic,crhoL,cuL,cpL,crhoR,cuR,cpR,Te/2) #Conservation laws
        loss_con2 = model.loss_con(x_en2,x_ic,crhoL,cuL,cpL,crhoR,cuR,cpR,Te/10) #Conservation laws
        loss = loss_pde + 10*(loss_ic+loss_bc) + 10*(loss_rh) +10*(loss_con +loss_con1+loss_con2)
        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f}, loss_rh:{loss_rh:.8f},loss_con:{loss_con:.8f}')
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    return loss

#x_ic,x_bc,x_int =  Mesh_Data(Nx,Nt,Ts,Te,Xs,Xe)

xlimits = np.array([[0.,0],[0, Xe]])  #interal
sampling = LHS(xlimits=xlimits)
x_ic= sampling(1000)

xlimits = np.array([[0.1,Te],[0, 0]])  #interal
sampling = LHS(xlimits=xlimits)
x_bcL= sampling(100)
xlimits = np.array([[0.,Te],[Xe, Xe]])  #interal
sampling = LHS(xlimits=xlimits)
x_bcR= sampling(100)
x_bc = np.vstack((x_bcL,x_bcR))

rho_ic, u_ic, p_ic= IC_Blast(x_ic)                    
rho_bc, u_bc, p_bc= IC_Riemann_1D(x_bc,crhoL,cuL,cpL,crhoR,cuR,cpR)                    
xlimits = np.array([[0.0,Te],[0, Xe]])  #interal
sampling = LHS(xlimits=xlimits)
x_int= sampling(10000)

xrh,xrhL,xrhR,xrhP,xrhPL,xrhPR = Pertur_1D(x_int,0,dt,dx)

x_en = Move_Time_1D(x_ic,Te)
x_en1 = Move_Time_1D(x_ic,Te/2)
x_en2 = Move_Time_1D(x_ic,Te/10)

x_ic = torch.tensor(x_ic,dtype=dtype).to(cuda)
x_bc = torch.tensor(x_bc,dtype=dtype).to(cuda)
x_int = torch.tensor(x_int,requires_grad=True, dtype=dtype).to(cuda)
x_en = torch.tensor(x_en,  dtype=dtype).to(cuda)
x_en1 = torch.tensor(x_en1,  dtype=dtype).to(cuda)
x_en2 = torch.tensor(x_en2,  dtype=dtype).to(cuda)
xrh = torch.tensor(xrh,  dtype=dtype).to(cuda)
xrhL = torch.tensor(xrhL,  dtype=dtype).to(cuda)

rho_ic = torch.tensor(rho_ic, dtype=dtype).to(cuda)
u_ic = torch.tensor(u_ic, dtype=dtype).to(cuda)
p_ic = torch.tensor(p_ic, dtype=dtype).to(cuda)

rho_bc = torch.tensor(rho_bc, dtype=dtype).to(cuda)
u_bc = torch.tensor(u_bc, dtype=dtype).to(cuda)
p_bc = torch.tensor(p_bc, dtype=dtype).to(cuda)

# %%
e = 16e6
p = 0.4*e
rhoL = 1
uL = 0
pL =  100 
rhoR =1
uR = 0
pR = 1
t = 0.038

rhoLn,uLn,pLn,rhoRn,uRn,pRn, tn,rhoref,uref,pref =Unit_var(rhoL,uL,pL,rhoR,uR,pR,t)

# %%
tn
# Out:
# 0.38

# %%
#model = PINNs_WE_Euler_1D(Nl=6,Nn=60).to(cuda).double()
print('Start training...')
epoch = 0
epochi = epoch
lr = 0.002                                                           # Learning rate
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
epochs = 15000
loss_history=[]
tic = time.time()
for epoch in range(1+epochi, epochs+epochi):
    loss = train(epoch)
    print(f'loss_tot:{loss:.8f}')
    loss_history.append(to_numpy(loss))
    if loss < 0.04:
        break
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# Start training...
# epoch 1 loss_pde:0.05875115, loss_ic:0.00626074, loss_rh:0.00003320,loss_con:0.00011835
# loss_tot:0.12353141
# epoch 2 loss_pde:52.46346137, loss_ic:0.04336987, loss_rh:0.00017224,loss_con:0.03931826
# loss_tot:53.82848127
# epoch 3 loss_pde:2.97363643, loss_ic:0.01823277, loss_rh:0.00007766,loss_con:0.00064748
# loss_tot:3.36457389
# epoch 4 loss_pde:6.31876298, loss_ic:0.01585539, loss_rh:0.00005098,loss_con:0.00811066
# loss_tot:6.70087546
# epoch 5 loss_pde:12.68830505, loss_ic:0.03485714, loss_rh:0.00010624,loss_con:0.01725766
# loss_tot:13.58045234
# epoch 6 loss_pde:8.62751325, loss_ic:0.05478286, loss_rh:0.00011349,loss_con:0.01962603
# loss_tot:9.99514955
# epoch 7 loss_pde:5.15595477, loss_ic:0.07551174, loss_rh:0.00008067,loss_con:0.01749648
# loss_tot:6.96250503
# epoch 8 loss_pde:3.93236324, loss_ic:0.09383507, loss_rh:0.00006499,loss_con:0.01279191
# loss_tot:6.11336960
# epoch 9 loss_pde:3.62137644, loss_ic:0.10354707, loss_rh:0.00007765,loss_con:0.00644612
# loss_tot:6.00208834
# epoch 10 loss_pde:3.36801643, loss_ic:0.10169471, loss_rh:0.00009695,loss_con:0.00188943
# loss_tot:5.71926972
# epoch 11 loss_pde:3.22606183, loss_ic:0.09184857, loss_rh:0.00010041,loss_con:0.00099277
# loss_tot:5.36227130
# epoch 12 loss_pde:3.30389062, loss_ic:0.07942036, loss_rh:0.00009060,loss_con:0.00146014
# loss_tot:5.12229816
# epoch 13 loss_pde:3.38123333, loss_ic:0.06907794, loss_rh:0.00007232,loss_con:0.00067277
# loss_tot:4.88114783
# epoch 14 loss_pde:3.19970545, loss_ic:0.06233409, loss_rh:0.00005391,loss_con:0.00020648
# loss_tot:4.46956108
# epoch 15 loss_pde:2.75597941, loss_ic:0.05794706, loss_rh:0.00003902,loss_con:0.00469839
# loss_tot:3.92904716
# epoch 16 loss_pde:2.25801969, loss_ic:0.05385933, loss_rh:0.00002991,loss_con:0.01679231
# loss_tot:3.44931543
# epoch 17 loss_pde:1.89027718, loss_ic:0.04931034, loss_rh:0.00002177,loss_con:0.03372546
# loss_tot:3.15160863
# epoch 18 loss_pde:1.64580796, loss_ic:0.04544279, loss_rh:0.00001513,loss_con:0.04867998
# loss_tot:2.96274527
# epoch 19 loss_pde:1.46609857, loss_ic:0.04420091, loss_rh:0.00001021,loss_con:0.05555485
# loss_tot:2.79134775
# epoch 20 loss_pde:1.31551717, loss_ic:0.04630331, loss_rh:0.00000672,loss_con:0.05276502
# loss_tot:2.60096222
# epoch 21 loss_pde:1.20838020, loss_ic:0.05026561, loss_rh:0.00000475,loss_con:0.04332813
# loss_tot:2.41289357
# epoch 22 loss_pde:1.16913222, loss_ic:0.05380474, loss_rh:0.00000319,loss_con:0.03213694
# loss_tot:2.26046304
# epoch 23 loss_pde:1.18337409, loss_ic:0.05548138, loss_rh:0.00000194,loss_con:0.02282550
# loss_tot:2.14475519
# epoch 24 loss_pde:1.20200408, loss_ic:0.05572839, loss_rh:0.00000112,loss_con:0.01655414
# loss_tot:2.04762539
# epoch 25 loss_pde:1.18912761, loss_ic:0.05619008, loss_rh:0.00000066,loss_con:0.01281613
# loss_tot:1.96898887
# epoch 26 loss_pde:1.16786190, loss_ic:0.05744035, loss_rh:0.00000039,loss_con:0.01068664
# loss_tot:1.93793763
# epoch 27 loss_pde:1.14811311, loss_ic:0.05883168, loss_rh:0.00000030,loss_con:0.00949124
# loss_tot:1.93567085
# epoch 28 loss_pde:1.13000909, loss_ic:0.05913065, loss_rh:0.00000022,loss_con:0.00883745
# loss_tot:1.92051768
# epoch 29 loss_pde:1.10120177, loss_ic:0.05784521, loss_rh:0.00000021,loss_con:0.00846087
# loss_tot:1.86131594
# epoch 30 loss_pde:1.05329764, loss_ic:0.05582899, loss_rh:0.00000021,loss_con:0.00815091
# loss_tot:1.76711986
# epoch 31 loss_pde:0.99413731, loss_ic:0.05431858, loss_rh:0.00000023,loss_con:0.00778553
# loss_tot:1.67569119
# epoch 32 loss_pde:0.94082792, loss_ic:0.05372908, loss_rh:0.00000029,loss_con:0.00741733
# loss_tot:1.61568353
# epoch 33 loss_pde:0.90217394, loss_ic:0.05341568, loss_rh:0.00000036,loss_con:0.00722725
# loss_tot:1.58081596
# epoch 34 loss_pde:0.86868086, loss_ic:0.05243938, loss_rh:0.00000046,loss_con:0.00734616
# loss_tot:1.53854654
# epoch 35 loss_pde:0.82872723, loss_ic:0.05055520, loss_rh:0.00000062,loss_con:0.00775237
# loss_tot:1.47142193
# epoch 36 loss_pde:0.78842487, loss_ic:0.04845810, loss_rh:0.00000085,loss_con:0.00828546
# loss_tot:1.40142958
# epoch 37 loss_pde:0.75944037, loss_ic:0.04698622, loss_rh:0.00000108,loss_con:0.00867954
# loss_tot:1.35722747
# epoch 38 loss_pde:0.74317812, loss_ic:0.04631954, loss_rh:0.00000143,loss_con:0.00865118
# loss_tot:1.33928490
# epoch 39 loss_pde:0.73028531, loss_ic:0.04608364, loss_rh:0.00000176,loss_con:0.00811307
# loss_tot:1.32452558
# epoch 40 loss_pde:0.71029903, loss_ic:0.04592028, loss_rh:0.00000206,loss_con:0.00727336
# loss_tot:1.29389284
# epoch 41 loss_pde:0.69116130, loss_ic:0.04557273, loss_rh:0.00000235,loss_con:0.00644387
# loss_tot:1.25726367
# epoch 42 loss_pde:0.67931890, loss_ic:0.04533409, loss_rh:0.00000269,loss_con:0.00586319
# loss_tot:1.23232531
# epoch 43 loss_pde:0.66895563, loss_ic:0.04519450, loss_rh:0.00000353,loss_con:0.00559357
# loss_tot:1.21660063
# epoch 44 loss_pde:0.65268400, loss_ic:0.04479772, loss_rh:0.00000447,loss_con:0.00562994
# loss_tot:1.19684291
# epoch 45 loss_pde:0.63170798, loss_ic:0.04380306, loss_rh:0.00000513,loss_con:0.00597534
# loss_tot:1.16772163
# epoch 46 loss_pde:0.61851749, loss_ic:0.04212634, loss_rh:0.00000494,loss_con:0.00656294
# loss_tot:1.14005239
# epoch 47 loss_pde:0.61263118, loss_ic:0.04022056, loss_rh:0.00000453,loss_con:0.00720949
# loss_tot:1.11812246
# epoch 48 loss_pde:0.61739651, loss_ic:0.03840727, loss_rh:0.00000404,loss_con:0.00765680
# loss_tot:1.10711362
# epoch 49 loss_pde:0.60021655, loss_ic:0.03718396, loss_rh:0.00000379,loss_con:0.00777935
# loss_tot:1.07728698
# epoch 50 loss_pde:0.57616766, loss_ic:0.03651499, loss_rh:0.00000373,loss_con:0.00765071
# loss_tot:1.04314027
# epoch 51 loss_pde:0.56645337, loss_ic:0.03611095, loss_rh:0.00000374,loss_con:0.00747588
# loss_tot:1.02529065
# epoch 52 loss_pde:0.55921067, loss_ic:0.03591323, loss_rh:0.00000365,loss_con:0.00744315
# loss_tot:1.01403474
# epoch 53 loss_pde:0.55263956, loss_ic:0.03573352, loss_rh:0.00000364,loss_con:0.00761076
# loss_tot:1.00666887
# epoch 54 loss_pde:0.54280386, loss_ic:0.03543718, loss_rh:0.00000366,loss_con:0.00794474
# loss_tot:0.99723254
# epoch 55 loss_pde:0.53260434, loss_ic:0.03500973, loss_rh:0.00000360,loss_con:0.00836192
# loss_tot:0.98717780
# epoch 56 loss_pde:0.52344624, loss_ic:0.03452424, loss_rh:0.00000344,loss_con:0.00873479
# loss_tot:0.97711908
# epoch 57 loss_pde:0.51275342, loss_ic:0.03408150, loss_rh:0.00000339,loss_con:0.00892653
# loss_tot:0.96402351
# epoch 58 loss_pde:0.49935452, loss_ic:0.03374345, loss_rh:0.00000333,loss_con:0.00886494
# loss_tot:0.94652893
# epoch 59 loss_pde:0.48725083, loss_ic:0.03351744, loss_rh:0.00000320,loss_con:0.00858851
# loss_tot:0.92903492
# epoch 60 loss_pde:0.48080244, loss_ic:0.03337712, loss_rh:0.00000308,loss_con:0.00821633
# loss_tot:0.91682950
# epoch 61 loss_pde:0.47886360, loss_ic:0.03324944, loss_rh:0.00000303,loss_con:0.00787009
# loss_tot:0.90927314
# epoch 62 loss_pde:0.47532235, loss_ic:0.03310406, loss_rh:0.00000308,loss_con:0.00762184
# loss_tot:0.90074617
# epoch 63 loss_pde:0.46744266, loss_ic:0.03293976, loss_rh:0.00000323,loss_con:0.00747776
# loss_tot:0.88875810
# epoch 64 loss_pde:0.45884702, loss_ic:0.03276973, loss_rh:0.00000342,loss_con:0.00738500
# loss_tot:0.87676206
# epoch 65 loss_pde:0.45324654, loss_ic:0.03260261, loss_rh:0.00000363,loss_con:0.00725199
# loss_tot:0.86766701
# epoch 66 loss_pde:0.44994564, loss_ic:0.03245951, loss_rh:0.00000382,loss_con:0.00700065
# loss_tot:0.86000021
# epoch 67 loss_pde:0.44705468, loss_ic:0.03233261, loss_rh:0.00000393,loss_con:0.00662083
# loss_tot:0.85148976
# epoch 68 loss_pde:0.44441515, loss_ic:0.03220469, loss_rh:0.00000393,loss_con:0.00618004
# loss_tot:0.84248857
# epoch 69 loss_pde:0.44220628, loss_ic:0.03206439, loss_rh:0.00000383,loss_con:0.00577478
# loss_tot:0.83418356
# epoch 70 loss_pde:0.43913637, loss_ic:0.03190446, loss_rh:0.00000368,loss_con:0.00547646
# loss_tot:0.82605323
# epoch 71 loss_pde:0.43362326, loss_ic:0.03172701, loss_rh:0.00000352,loss_con:0.00531278
# loss_tot:0.81682460
# epoch 72 loss_pde:0.42620958, loss_ic:0.03154809, loss_rh:0.00000342,loss_con:0.00526927
# loss_tot:0.80695339
# epoch 73 loss_pde:0.41894048, loss_ic:0.03139058, loss_rh:0.00000335,loss_con:0.00528930
# loss_tot:0.79799271
# epoch 74 loss_pde:0.41291013, loss_ic:0.03126824, loss_rh:0.00000337,loss_con:0.00528952
# loss_tot:0.79026808
# epoch 75 loss_pde:0.40750419, loss_ic:0.03119364, loss_rh:0.00000341,loss_con:0.00520388
# loss_tot:0.78273408
# epoch 76 loss_pde:0.40219138, loss_ic:0.03114829, loss_rh:0.00000341,loss_con:0.00502385
# loss_tot:0.77476341
# epoch 77 loss_pde:0.39760648, loss_ic:0.03107965, loss_rh:0.00000338,loss_con:0.00479855
# loss_tot:0.76701116
# epoch 78 loss_pde:0.39394699, loss_ic:0.03093328, loss_rh:0.00000338,loss_con:0.00459544
# loss_tot:0.75973256
# epoch 79 loss_pde:0.39038740, loss_ic:0.03069293, loss_rh:0.00000341,loss_con:0.00445996
# loss_tot:0.75237338
# epoch 80 loss_pde:0.38640860, loss_ic:0.03039971, loss_rh:0.00000345,loss_con:0.00440301
# loss_tot:0.74501136
# epoch 81 loss_pde:0.38227698, loss_ic:0.03010290, loss_rh:0.00000351,loss_con:0.00440384
# loss_tot:0.73816503
# epoch 82 loss_pde:0.37813248, loss_ic:0.02984237, loss_rh:0.00000360,loss_con:0.00442450
# loss_tot:0.73176740
# epoch 83 loss_pde:0.37377130, loss_ic:0.02963059, loss_rh:0.00000371,loss_con:0.00442942
# loss_tot:0.72519095
# epoch 84 loss_pde:0.36906912, loss_ic:0.02947778, loss_rh:0.00000384,loss_con:0.00440599
# loss_tot:0.71836338
# epoch 85 loss_pde:0.36423040, loss_ic:0.02937755, loss_rh:0.00000400,loss_con:0.00436516
# loss_tot:0.71176836
# epoch 86 loss_pde:0.35941329, loss_ic:0.02930422, loss_rh:0.00000411,loss_con:0.00432543
# loss_tot:0.70560320
# epoch 87 loss_pde:0.35457148, loss_ic:0.02922529, loss_rh:0.00000416,loss_con:0.00429533
# loss_tot:0.69952251
# epoch 88 loss_pde:0.34980022, loss_ic:0.02912486, loss_rh:0.00000417,loss_con:0.00426714
# loss_tot:0.69333428
# epoch 89 loss_pde:0.34544173, loss_ic:0.02900979, loss_rh:0.00000414,loss_con:0.00422151
# loss_tot:0.68729609
# epoch 90 loss_pde:0.34166738, loss_ic:0.02889512, loss_rh:0.00000413,loss_con:0.00413988
# loss_tot:0.68156385
# epoch 91 loss_pde:0.33830318, loss_ic:0.02878862, loss_rh:0.00000415,loss_con:0.00401935
# loss_tot:0.67593943
# epoch 92 loss_pde:0.33513038, loss_ic:0.02868974, loss_rh:0.00000420,loss_con:0.00387868
# loss_tot:0.67031292
# epoch 93 loss_pde:0.33202569, loss_ic:0.02859473, loss_rh:0.00000429,loss_con:0.00374830
# loss_tot:0.66484110
# epoch 94 loss_pde:0.32877802, loss_ic:0.02849896, loss_rh:0.00000439,loss_con:0.00365277
# loss_tot:0.65956630
# epoch 95 loss_pde:0.32513451, loss_ic:0.02839823, loss_rh:0.00000448,loss_con:0.00360147
# loss_tot:0.65430449
# epoch 96 loss_pde:0.32109391, loss_ic:0.02829319, loss_rh:0.00000455,loss_con:0.00358971
# loss_tot:0.64899948
# epoch 97 loss_pde:0.31691025, loss_ic:0.02819086, loss_rh:0.00000457,loss_con:0.00360137
# loss_tot:0.64380746
# epoch 98 loss_pde:0.31282098, loss_ic:0.02809966, loss_rh:0.00000456,loss_con:0.00361179
# loss_tot:0.63880280
# epoch 99 loss_pde:0.30896098, loss_ic:0.02802367, loss_rh:0.00000454,loss_con:0.00359702
# loss_tot:0.63390963
# epoch 100 loss_pde:0.30544471, loss_ic:0.02795931, loss_rh:0.00000454,loss_con:0.00354628
# loss_tot:0.62908518
# epoch 101 loss_pde:0.30229265, loss_ic:0.02789782, loss_rh:0.00000459,loss_con:0.00346632
# loss_tot:0.62433354
# epoch 102 loss_pde:0.29936302, loss_ic:0.02783036, loss_rh:0.00000468,loss_con:0.00337417
# loss_tot:0.61961416
# epoch 103 loss_pde:0.29650862, loss_ic:0.02775360, loss_rh:0.00000481,loss_con:0.00328548
# loss_tot:0.61492368
# epoch 104 loss_pde:0.29368528, loss_ic:0.02767165, loss_rh:0.00000496,loss_con:0.00320743
# loss_tot:0.61034229
# epoch 105 loss_pde:0.29084623, loss_ic:0.02759353, loss_rh:0.00000509,loss_con:0.00313862
# loss_tot:0.60589822
# epoch 106 loss_pde:0.28789152, loss_ic:0.02752693, loss_rh:0.00000518,loss_con:0.00307415
# loss_tot:0.60150963
# epoch 107 loss_pde:0.28478689, loss_ic:0.02747354, loss_rh:0.00000524,loss_con:0.00301208
# loss_tot:0.59713113
# epoch 108 loss_pde:0.28160726, loss_ic:0.02742797, loss_rh:0.00000528,loss_con:0.00295580
# loss_tot:0.59281870
# epoch 109 loss_pde:0.27842051, loss_ic:0.02738110, loss_rh:0.00000532,loss_con:0.00291020
# loss_tot:0.58860489
# epoch 110 loss_pde:0.27526559, loss_ic:0.02732521, loss_rh:0.00000538,loss_con:0.00287562
# loss_tot:0.58446065
# epoch 111 loss_pde:0.27223716, loss_ic:0.02725792, loss_rh:0.00000546,loss_con:0.00284470
# loss_tot:0.58038172
# epoch 112 loss_pde:0.26947850, loss_ic:0.02717898, loss_rh:0.00000557,loss_con:0.00280531
# loss_tot:0.57637709
# epoch 113 loss_pde:0.26703397, loss_ic:0.02709349, loss_rh:0.00000568,loss_con:0.00274858
# loss_tot:0.57244115
# epoch 114 loss_pde:0.26480412, loss_ic:0.02700803, loss_rh:0.00000579,loss_con:0.00267543
# loss_tot:0.56854504
# epoch 115 loss_pde:0.26265405, loss_ic:0.02692652, loss_rh:0.00000587,loss_con:0.00259632
# loss_tot:0.56470390
# epoch 116 loss_pde:0.26044831, loss_ic:0.02684983, loss_rh:0.00000593,loss_con:0.00252445
# loss_tot:0.56093501
# epoch 117 loss_pde:0.25808874, loss_ic:0.02677716, loss_rh:0.00000596,loss_con:0.00246836
# loss_tot:0.55722354
# epoch 118 loss_pde:0.25557258, loss_ic:0.02670758, loss_rh:0.00000600,loss_con:0.00242896
# loss_tot:0.55356170
# epoch 119 loss_pde:0.25297874, loss_ic:0.02664043, loss_rh:0.00000605,loss_con:0.00240121
# loss_tot:0.54996186
# epoch 120 loss_pde:0.25038835, loss_ic:0.02657513, loss_rh:0.00000612,loss_con:0.00237802
# loss_tot:0.54642357
# epoch 121 loss_pde:0.24785495, loss_ic:0.02651036, loss_rh:0.00000619,loss_con:0.00235414
# loss_tot:0.54293982
# epoch 122 loss_pde:0.24541580, loss_ic:0.02644437, loss_rh:0.00000625,loss_con:0.00232794
# loss_tot:0.53952125
# epoch 123 loss_pde:0.24307949, loss_ic:0.02637562, loss_rh:0.00000631,loss_con:0.00230035
# loss_tot:0.53617233
# epoch 124 loss_pde:0.24081444, loss_ic:0.02630493, loss_rh:0.00000637,loss_con:0.00227245
# loss_tot:0.53287715
# epoch 125 loss_pde:0.23859188, loss_ic:0.02623519, loss_rh:0.00000641,loss_con:0.00224400
# loss_tot:0.52963230
# epoch 126 loss_pde:0.23640436, loss_ic:0.02617011, loss_rh:0.00000643,loss_con:0.00221339
# loss_tot:0.52644902
# epoch 127 loss_pde:0.23425347, loss_ic:0.02611138, loss_rh:0.00000644,loss_con:0.00217918
# loss_tot:0.52332624
# epoch 128 loss_pde:0.23214450, loss_ic:0.02605768, loss_rh:0.00000646,loss_con:0.00214177
# loss_tot:0.52025652
# epoch 129 loss_pde:0.23008436, loss_ic:0.02600547, loss_rh:0.00000648,loss_con:0.00210385
# loss_tot:0.51724268
# epoch 130 loss_pde:0.22806903, loss_ic:0.02595072, loss_rh:0.00000650,loss_con:0.00206915
# loss_tot:0.51428439
# epoch 131 loss_pde:0.22608518, loss_ic:0.02589094, loss_rh:0.00000652,loss_con:0.00204014
# loss_tot:0.51137269
# epoch 132 loss_pde:0.22413062, loss_ic:0.02582661, loss_rh:0.00000653,loss_con:0.00201652
# loss_tot:0.50850629
# epoch 133 loss_pde:0.22221560, loss_ic:0.02576050, loss_rh:0.00000655,loss_con:0.00199523
# loss_tot:0.50568944
# epoch 134 loss_pde:0.22034690, loss_ic:0.02569561, loss_rh:0.00000656,loss_con:0.00197256
# loss_tot:0.50291661
# epoch 135 loss_pde:0.21853368, loss_ic:0.02563312, loss_rh:0.00000658,loss_con:0.00194662
# loss_tot:0.50018606
# epoch 136 loss_pde:0.21677588, loss_ic:0.02557213, loss_rh:0.00000660,loss_con:0.00191840
# loss_tot:0.49749861
# epoch 137 loss_pde:0.21506495, loss_ic:0.02551047, loss_rh:0.00000662,loss_con:0.00189044
# loss_tot:0.49485261
# epoch 138 loss_pde:0.21339952, loss_ic:0.02544613, loss_rh:0.00000664,loss_con:0.00186436
# loss_tot:0.49224678
# epoch 139 loss_pde:0.21178930, loss_ic:0.02537865, loss_rh:0.00000666,loss_con:0.00183966
# loss_tot:0.48968178
# epoch 140 loss_pde:0.21024180, loss_ic:0.02530906, loss_rh:0.00000668,loss_con:0.00181453
# loss_tot:0.48715551
# epoch 141 loss_pde:0.20875165, loss_ic:0.02523885, loss_rh:0.00000670,loss_con:0.00178792
# loss_tot:0.48466501
# epoch 142 loss_pde:0.20729754, loss_ic:0.02516930, loss_rh:0.00000671,loss_con:0.00176068
# loss_tot:0.48221025
# epoch 143 loss_pde:0.20585222, loss_ic:0.02510085, loss_rh:0.00000671,loss_con:0.00173493
# loss_tot:0.47979128
# epoch 144 loss_pde:0.20439482, loss_ic:0.02503427, loss_rh:0.00000672,loss_con:0.00171192
# loss_tot:0.47740724
# epoch 145 loss_pde:0.20292161, loss_ic:0.02497036, loss_rh:0.00000673,loss_con:0.00169110
# loss_tot:0.47505581
# epoch 146 loss_pde:0.20146073, loss_ic:0.02490823, loss_rh:0.00000673,loss_con:0.00167062
# loss_tot:0.47273648
# epoch 147 loss_pde:0.20002627, loss_ic:0.02484805, loss_rh:0.00000674,loss_con:0.00164897
# loss_tot:0.47044971
# epoch 148 loss_pde:0.19862456, loss_ic:0.02478905, loss_rh:0.00000675,loss_con:0.00162606
# loss_tot:0.46819428
# epoch 149 loss_pde:0.19725282, loss_ic:0.02472992, loss_rh:0.00000675,loss_con:0.00160311
# loss_tot:0.46596797
# epoch 150 loss_pde:0.19591088, loss_ic:0.02466889, loss_rh:0.00000675,loss_con:0.00158159
# loss_tot:0.46376976
# epoch 151 loss_pde:0.19459709, loss_ic:0.02460611, loss_rh:0.00000675,loss_con:0.00156169
# loss_tot:0.46160013
# epoch 152 loss_pde:0.19326950, loss_ic:0.02454284, loss_rh:0.00000675,loss_con:0.00154260
# loss_tot:0.45941994
# epoch 153 loss_pde:0.19211071, loss_ic:0.02437672, loss_rh:0.00000683,loss_con:0.00152158
# loss_tot:0.45633662
# epoch 154 loss_pde:0.19167678, loss_ic:0.02414825, loss_rh:0.00000683,loss_con:0.00149901
# loss_tot:0.45333043
# epoch 155 loss_pde:0.19198845, loss_ic:0.02391389, loss_rh:0.00000671,loss_con:0.00147504
# loss_tot:0.45100357
# epoch 156 loss_pde:0.19264936, loss_ic:0.02368119, loss_rh:0.00000671,loss_con:0.00145041
# loss_tot:0.44904307
# epoch 157 loss_pde:0.19305622, loss_ic:0.02352163, loss_rh:0.00000676,loss_con:0.00143055
# loss_tot:0.44763238
# epoch 158 loss_pde:0.19239024, loss_ic:0.02340340, loss_rh:0.00000677,loss_con:0.00141862
# loss_tot:0.44565963
# epoch 159 loss_pde:0.19124093, loss_ic:0.02331085, loss_rh:0.00000679,loss_con:0.00141378
# loss_tot:0.44354718
# epoch 160 loss_pde:0.18941629, loss_ic:0.02326619, loss_rh:0.00000678,loss_con:0.00140941
# loss_tot:0.44125447
# epoch 161 loss_pde:0.18778300, loss_ic:0.02319038, loss_rh:0.00000687,loss_con:0.00139685
# loss_tot:0.43873950
# epoch 162 loss_pde:0.18674969, loss_ic:0.02304186, loss_rh:0.00000713,loss_con:0.00137494
# loss_tot:0.43597366
# epoch 163 loss_pde:0.18633749, loss_ic:0.02284032, loss_rh:0.00000747,loss_con:0.00135038
# loss_tot:0.43326222
# epoch 164 loss_pde:0.18636406, loss_ic:0.02260237, loss_rh:0.00000789,loss_con:0.00132927
# loss_tot:0.43066731
# epoch 165 loss_pde:0.18672669, loss_ic:0.02234800, loss_rh:0.00000814,loss_con:0.00131127
# loss_tot:0.42827670
# epoch 166 loss_pde:0.18662409, loss_ic:0.02207759, loss_rh:0.00000820,loss_con:0.00129101
# loss_tot:0.42521646
# epoch 167 loss_pde:0.18616535, loss_ic:0.02176013, loss_rh:0.00000802,loss_con:0.00126604
# loss_tot:0.42125161
# epoch 168 loss_pde:0.18544561, loss_ic:0.02139468, loss_rh:0.00000741,loss_con:0.00123941
# loss_tot:0.41651989
# epoch 169 loss_pde:0.18527439, loss_ic:0.02098134, loss_rh:0.00000605,loss_con:0.00121377
# loss_tot:0.41187395
# epoch 170 loss_pde:0.18455829, loss_ic:0.02051886, loss_rh:0.00000525,loss_con:0.00118751
# loss_tot:0.40619994
# epoch 171 loss_pde:0.18584248, loss_ic:0.02005193, loss_rh:0.00000489,loss_con:0.00116219
# loss_tot:0.40251523
# epoch 172 loss_pde:0.18304951, loss_ic:0.01955255, loss_rh:0.00000540,loss_con:0.00113539
# loss_tot:0.39442272
# epoch 173 loss_pde:0.18193717, loss_ic:0.01907348, loss_rh:0.00000658,loss_con:0.00111670
# loss_tot:0.38834011
# epoch 174 loss_pde:0.18082251, loss_ic:0.01865600, loss_rh:0.00000732,loss_con:0.00110135
# loss_tot:0.38292513
# epoch 175 loss_pde:0.18116491, loss_ic:0.01836379, loss_rh:0.00000741,loss_con:0.00107711
# loss_tot:0.38011905
# epoch 176 loss_pde:0.17936718, loss_ic:0.01822899, loss_rh:0.00000723,loss_con:0.00103860
# loss_tot:0.37657483
# epoch 177 loss_pde:0.17801055, loss_ic:0.01822375, loss_rh:0.00000715,loss_con:0.00099809
# loss_tot:0.37474304
# epoch 178 loss_pde:0.17763262, loss_ic:0.01826255, loss_rh:0.00000737,loss_con:0.00096288
# loss_tot:0.37440469
# epoch 179 loss_pde:0.17776926, loss_ic:0.01824229, loss_rh:0.00000732,loss_con:0.00092797
# loss_tot:0.37400043
# epoch 180 loss_pde:0.17713712, loss_ic:0.01810424, loss_rh:0.00000739,loss_con:0.00089003
# loss_tot:0.37161955
# epoch 181 loss_pde:0.17557095, loss_ic:0.01786633, loss_rh:0.00000767,loss_con:0.00085970
# loss_tot:0.36739499
# epoch 182 loss_pde:0.17408658, loss_ic:0.01760026, loss_rh:0.00000798,loss_con:0.00085086
# loss_tot:0.36320636
# epoch 183 loss_pde:0.17318500, loss_ic:0.01737398, loss_rh:0.00000827,loss_con:0.00086260
# loss_tot:0.36020757
# epoch 184 loss_pde:0.17262509, loss_ic:0.01721850, loss_rh:0.00000885,loss_con:0.00087845
# loss_tot:0.35827683
# epoch 185 loss_pde:0.17235554, loss_ic:0.01712098, loss_rh:0.00000949,loss_con:0.00088266
# loss_tot:0.35705660
# epoch 186 loss_pde:0.17200937, loss_ic:0.01704585, loss_rh:0.00001003,loss_con:0.00087596
# loss_tot:0.35583148
# epoch 187 loss_pde:0.17107322, loss_ic:0.01696230, loss_rh:0.00001042,loss_con:0.00086945
# loss_tot:0.35390138
# epoch 188 loss_pde:0.16945572, loss_ic:0.01686813, loss_rh:0.00001065,loss_con:0.00086715
# loss_tot:0.35121106
# epoch 189 loss_pde:0.16761702, loss_ic:0.01678516, loss_rh:0.00001068,loss_con:0.00086081
# loss_tot:0.34837922
# epoch 190 loss_pde:0.16610423, loss_ic:0.01673501, loss_rh:0.00001066,loss_con:0.00084146
# loss_tot:0.34608610
# epoch 191 loss_pde:0.16506465, loss_ic:0.01671612, loss_rh:0.00001064,loss_con:0.00081379
# loss_tot:0.34451602
# epoch 192 loss_pde:0.16432171, loss_ic:0.01670524, loss_rh:0.00001066,loss_con:0.00078941
# loss_tot:0.34338697
# epoch 193 loss_pde:0.16348525, loss_ic:0.01667763, loss_rh:0.00001066,loss_con:0.00077182
# loss_tot:0.34209310
# epoch 194 loss_pde:0.16238821, loss_ic:0.01662464, loss_rh:0.00001079,loss_con:0.00075570
# loss_tot:0.34030724
# epoch 195 loss_pde:0.16115390, loss_ic:0.01655551, loss_rh:0.00001102,loss_con:0.00073793
# loss_tot:0.33819882
# epoch 196 loss_pde:0.16001931, loss_ic:0.01648770, loss_rh:0.00001124,loss_con:0.00072248
# loss_tot:0.33621959
# epoch 197 loss_pde:0.15912950, loss_ic:0.01643440, loss_rh:0.00001153,loss_con:0.00071392
# loss_tot:0.33469404
# epoch 198 loss_pde:0.15843443, loss_ic:0.01639614, loss_rh:0.00001183,loss_con:0.00071155
# loss_tot:0.33355928
# epoch 199 loss_pde:0.15769665, loss_ic:0.01636250, loss_rh:0.00001210,loss_con:0.00071124
# loss_tot:0.33242036
# epoch 200 loss_pde:0.15671330, loss_ic:0.01632258, loss_rh:0.00001233,loss_con:0.00071127
# loss_tot:0.33095400
# epoch 201 loss_pde:0.15555217, loss_ic:0.01627508, loss_rh:0.00001249,loss_con:0.00071354
# loss_tot:0.32925425
# epoch 202 loss_pde:0.15446108, loss_ic:0.01622699, loss_rh:0.00001252,loss_con:0.00071877
# loss_tot:0.32766251
# epoch 203 loss_pde:0.15359838, loss_ic:0.01618411, loss_rh:0.00001247,loss_con:0.00072332
# loss_tot:0.32636320
# epoch 204 loss_pde:0.15290877, loss_ic:0.01614474, loss_rh:0.00001245,loss_con:0.00072286
# loss_tot:0.32524036
# epoch 205 loss_pde:0.15222326, loss_ic:0.01610201, loss_rh:0.00001241,loss_con:0.00071792
# loss_tot:0.32406507
# epoch 206 loss_pde:0.15142520, loss_ic:0.01605143, loss_rh:0.00001239,loss_con:0.00071228
# loss_tot:0.32271827
# epoch 207 loss_pde:0.15055220, loss_ic:0.01599600, loss_rh:0.00001240,loss_con:0.00070683
# loss_tot:0.32126933
# epoch 208 loss_pde:0.14973476, loss_ic:0.01594352, loss_rh:0.00001241,loss_con:0.00069916
# loss_tot:0.31988472
# epoch 209 loss_pde:0.14903987, loss_ic:0.01589941, loss_rh:0.00001248,loss_con:0.00068868
# loss_tot:0.31866343
# epoch 210 loss_pde:0.14839736, loss_ic:0.01586291, loss_rh:0.00001258,loss_con:0.00067862
# loss_tot:0.31755139
# epoch 211 loss_pde:0.14768436, loss_ic:0.01583030, loss_rh:0.00001264,loss_con:0.00067153
# loss_tot:0.31640971
# epoch 212 loss_pde:0.14686689, loss_ic:0.01580030, loss_rh:0.00001265,loss_con:0.00066575
# loss_tot:0.31517064
# epoch 213 loss_pde:0.14602009, loss_ic:0.01577476, loss_rh:0.00001263,loss_con:0.00065804
# loss_tot:0.31389627
# epoch 214 loss_pde:0.14521543, loss_ic:0.01575483, loss_rh:0.00001264,loss_con:0.00064846
# loss_tot:0.31268474
# epoch 215 loss_pde:0.14444677, loss_ic:0.01573806, loss_rh:0.00001265,loss_con:0.00064050
# loss_tot:0.31156379
# epoch 216 loss_pde:0.14366811, loss_ic:0.01572017, loss_rh:0.00001265,loss_con:0.00063618
# loss_tot:0.31048312
# epoch 217 loss_pde:0.14286471, loss_ic:0.01569847, loss_rh:0.00001265,loss_con:0.00063324
# loss_tot:0.30938169
# epoch 218 loss_pde:0.14206071, loss_ic:0.01567285, loss_rh:0.00001267,loss_con:0.00062839
# loss_tot:0.30824388
# epoch 219 loss_pde:0.14128056, loss_ic:0.01564449, loss_rh:0.00001273,loss_con:0.00062179
# loss_tot:0.30710305
# epoch 220 loss_pde:0.14052917, loss_ic:0.01561446, loss_rh:0.00001279,loss_con:0.00061594
# loss_tot:0.30599870
# epoch 221 loss_pde:0.13980567, loss_ic:0.01558338, loss_rh:0.00001286,loss_con:0.00061142
# loss_tot:0.30493718
# epoch 222 loss_pde:0.13910858, loss_ic:0.01555143, loss_rh:0.00001292,loss_con:0.00060621
# loss_tot:0.30388976
# epoch 223 loss_pde:0.13843057, loss_ic:0.01551835, loss_rh:0.00001295,loss_con:0.00059936
# loss_tot:0.30283001
# epoch 224 loss_pde:0.13776233, loss_ic:0.01548383, loss_rh:0.00001294,loss_con:0.00059273
# loss_tot:0.30176284
# epoch 225 loss_pde:0.13710400, loss_ic:0.01544812, loss_rh:0.00001292,loss_con:0.00058846
# loss_tot:0.30071321
# epoch 226 loss_pde:0.13646858, loss_ic:0.01541200, loss_rh:0.00001289,loss_con:0.00058626
# loss_tot:0.29969592
# epoch 227 loss_pde:0.13586414, loss_ic:0.01537591, loss_rh:0.00001288,loss_con:0.00058422
# loss_tot:0.29870071
# epoch 228 loss_pde:0.13527909, loss_ic:0.01533955, loss_rh:0.00001290,loss_con:0.00058163
# loss_tot:0.29770669
# epoch 229 loss_pde:0.13469470, loss_ic:0.01530250, loss_rh:0.00001296,loss_con:0.00057946
# loss_tot:0.29670614
# epoch 230 loss_pde:0.13410930, loss_ic:0.01526515, loss_rh:0.00001304,loss_con:0.00057800
# loss_tot:0.29570939
# epoch 231 loss_pde:0.13354059, loss_ic:0.01522871, loss_rh:0.00001312,loss_con:0.00057578
# loss_tot:0.29473280
# epoch 232 loss_pde:0.13299771, loss_ic:0.01519403, loss_rh:0.00001320,loss_con:0.00057142
# loss_tot:0.29378036
# epoch 233 loss_pde:0.13246534, loss_ic:0.01516092, loss_rh:0.00001326,loss_con:0.00056542
# loss_tot:0.29284211
# epoch 234 loss_pde:0.13192249, loss_ic:0.01512872, loss_rh:0.00001330,loss_con:0.00055917
# loss_tot:0.29190626
# epoch 235 loss_pde:0.13136878, loss_ic:0.01509705, loss_rh:0.00001331,loss_con:0.00055318
# loss_tot:0.29097245
# epoch 236 loss_pde:0.13081744, loss_ic:0.01506583, loss_rh:0.00001332,loss_con:0.00054723
# loss_tot:0.29004835
# epoch 237 loss_pde:0.13026911, loss_ic:0.01503494, loss_rh:0.00001332,loss_con:0.00054182
# loss_tot:0.28913873
# epoch 238 loss_pde:0.12972447, loss_ic:0.01500364, loss_rh:0.00001332,loss_con:0.00053788
# loss_tot:0.28824584
# epoch 239 loss_pde:0.12918173, loss_ic:0.01497143, loss_rh:0.00001333,loss_con:0.00053552
# loss_tot:0.28736236
# epoch 240 loss_pde:0.12864504, loss_ic:0.01493857, loss_rh:0.00001336,loss_con:0.00053378
# loss_tot:0.28648204
# epoch 241 loss_pde:0.12812816, loss_ic:0.01490542, loss_rh:0.00001340,loss_con:0.00053168
# loss_tot:0.28561028
# epoch 242 loss_pde:0.12763181, loss_ic:0.01487246, loss_rh:0.00001344,loss_con:0.00052917
# loss_tot:0.28475221
# epoch 243 loss_pde:0.12715084, loss_ic:0.01484009, loss_rh:0.00001348,loss_con:0.00052645
# loss_tot:0.28391033
# epoch 244 loss_pde:0.12668225, loss_ic:0.01480869, loss_rh:0.00001351,loss_con:0.00052318
# loss_tot:0.28308253
# epoch 245 loss_pde:0.12622369, loss_ic:0.01477843, loss_rh:0.00001353,loss_con:0.00051903
# loss_tot:0.28226482
# epoch 246 loss_pde:0.12576930, loss_ic:0.01474917, loss_rh:0.00001354,loss_con:0.00051446
# loss_tot:0.28145585
# epoch 247 loss_pde:0.12531494, loss_ic:0.01472051, loss_rh:0.00001355,loss_con:0.00051028
# loss_tot:0.28065785
# epoch 248 loss_pde:0.12486424, loss_ic:0.01469215, loss_rh:0.00001356,loss_con:0.00050656
# loss_tot:0.27987255
# epoch 249 loss_pde:0.12442564, loss_ic:0.01466377, loss_rh:0.00001357,loss_con:0.00050275
# loss_tot:0.27909951
# epoch 250 loss_pde:0.12400225, loss_ic:0.01463506, loss_rh:0.00001359,loss_con:0.00049870
# loss_tot:0.27833684
# epoch 251 loss_pde:0.12358989, loss_ic:0.01460581, loss_rh:0.00001360,loss_con:0.00049486
# loss_tot:0.27758356
# epoch 252 loss_pde:0.12318557, loss_ic:0.01457615, loss_rh:0.00001361,loss_con:0.00049148
# loss_tot:0.27684069
# epoch 253 loss_pde:0.12279138, loss_ic:0.01454661, loss_rh:0.00001362,loss_con:0.00048813
# loss_tot:0.27610978
# epoch 254 loss_pde:0.12240714, loss_ic:0.01451769, loss_rh:0.00001363,loss_con:0.00048451
# loss_tot:0.27539086
# epoch 255 loss_pde:0.12202586, loss_ic:0.01448952, loss_rh:0.00001365,loss_con:0.00048102
# loss_tot:0.27468259
# epoch 256 loss_pde:0.12164037, loss_ic:0.01446199, loss_rh:0.00001366,loss_con:0.00047821
# loss_tot:0.27398297
# epoch 257 loss_pde:0.12125220, loss_ic:0.01443492, loss_rh:0.00001367,loss_con:0.00047602
# loss_tot:0.27329199
# epoch 258 loss_pde:0.12086751, loss_ic:0.01440817, loss_rh:0.00001368,loss_con:0.00047400
# loss_tot:0.27261012
# epoch 259 loss_pde:0.12048988, loss_ic:0.01438152, loss_rh:0.00001368,loss_con:0.00047199
# loss_tot:0.27193789
# epoch 260 loss_pde:0.12011744, loss_ic:0.01435481, loss_rh:0.00001369,loss_con:0.00047024
# loss_tot:0.27127488
# epoch 261 loss_pde:0.11974907, loss_ic:0.01432809, loss_rh:0.00001369,loss_con:0.00046870
# loss_tot:0.27061993
# epoch 262 loss_pde:0.11938608, loss_ic:0.01430174, loss_rh:0.00001369,loss_con:0.00046691
# loss_tot:0.26997227
# epoch 263 loss_pde:0.11902453, loss_ic:0.01427658, loss_rh:0.00001369,loss_con:0.00046459
# loss_tot:0.26933233
# epoch 264 loss_pde:0.11866438, loss_ic:0.01425261, loss_rh:0.00001369,loss_con:0.00046183
# loss_tot:0.26870037
# epoch 265 loss_pde:0.11830023, loss_ic:0.01422973, loss_rh:0.00001370,loss_con:0.00045896
# loss_tot:0.26807450
# epoch 266 loss_pde:0.11793733, loss_ic:0.01420760, loss_rh:0.00001370,loss_con:0.00045603
# loss_tot:0.26745655
# epoch 267 loss_pde:0.11758071, loss_ic:0.01418594, loss_rh:0.00001370,loss_con:0.00045289
# loss_tot:0.26684630
# epoch 268 loss_pde:0.11723233, loss_ic:0.01416450, loss_rh:0.00001371,loss_con:0.00044960
# loss_tot:0.26624344
# epoch 269 loss_pde:0.11689024, loss_ic:0.01414309, loss_rh:0.00001371,loss_con:0.00044650
# loss_tot:0.26564746
# epoch 270 loss_pde:0.11655200, loss_ic:0.01412167, loss_rh:0.00001373,loss_con:0.00044379
# loss_tot:0.26505801
# epoch 271 loss_pde:0.11621680, loss_ic:0.01410033, loss_rh:0.00001374,loss_con:0.00044141
# loss_tot:0.26447477
# epoch 272 loss_pde:0.11588434, loss_ic:0.01407919, loss_rh:0.00001376,loss_con:0.00043922
# loss_tot:0.26389764
# epoch 273 loss_pde:0.11555331, loss_ic:0.01405837, loss_rh:0.00001378,loss_con:0.00043716
# loss_tot:0.26332653
# epoch 274 loss_pde:0.11522333, loss_ic:0.01403792, loss_rh:0.00001380,loss_con:0.00043514
# loss_tot:0.26276131
# epoch 275 loss_pde:0.11489612, loss_ic:0.01401786, loss_rh:0.00001382,loss_con:0.00043291
# loss_tot:0.26220188
# epoch 276 loss_pde:0.11457361, loss_ic:0.01399815, loss_rh:0.00001383,loss_con:0.00043032
# loss_tot:0.26164814
# epoch 277 loss_pde:0.11425583, loss_ic:0.01397869, loss_rh:0.00001384,loss_con:0.00042743
# loss_tot:0.26109997
# epoch 278 loss_pde:0.11394153, loss_ic:0.01395939, loss_rh:0.00001384,loss_con:0.00042445
# loss_tot:0.26055726
# epoch 279 loss_pde:0.11362971, loss_ic:0.01394022, loss_rh:0.00001385,loss_con:0.00042154
# loss_tot:0.26001975
# epoch 280 loss_pde:0.11332003, loss_ic:0.01392120, loss_rh:0.00001386,loss_con:0.00041877
# loss_tot:0.25948729
# epoch 281 loss_pde:0.11301117, loss_ic:0.01390239, loss_rh:0.00001387,loss_con:0.00041624
# loss_tot:0.25895977
# epoch 282 loss_pde:0.11270059, loss_ic:0.01388394, loss_rh:0.00001388,loss_con:0.00041403
# loss_tot:0.25843689
# epoch 283 loss_pde:0.11238863, loss_ic:0.01386585, loss_rh:0.00001390,loss_con:0.00041204
# loss_tot:0.25791827
# epoch 284 loss_pde:0.11207645, loss_ic:0.01384812, loss_rh:0.00001391,loss_con:0.00041017
# loss_tot:0.25740400
# epoch 285 loss_pde:0.11176531, loss_ic:0.01383066, loss_rh:0.00001392,loss_con:0.00040836
# loss_tot:0.25689431
# epoch 286 loss_pde:0.11145541, loss_ic:0.01381346, loss_rh:0.00001393,loss_con:0.00040658
# loss_tot:0.25638913
# epoch 287 loss_pde:0.11114755, loss_ic:0.01379653, loss_rh:0.00001394,loss_con:0.00040474
# loss_tot:0.25588837
# epoch 288 loss_pde:0.11084285, loss_ic:0.01377990, loss_rh:0.00001395,loss_con:0.00040275
# loss_tot:0.25539193
# epoch 289 loss_pde:0.11054169, loss_ic:0.01376352, loss_rh:0.00001396,loss_con:0.00040058
# loss_tot:0.25489973
# epoch 290 loss_pde:0.11024358, loss_ic:0.01374732, loss_rh:0.00001397,loss_con:0.00039835
# loss_tot:0.25441167
# epoch 291 loss_pde:0.10994879, loss_ic:0.01373118, loss_rh:0.00001399,loss_con:0.00039609
# loss_tot:0.25392763
# epoch 292 loss_pde:0.10965607, loss_ic:0.01371511, loss_rh:0.00001401,loss_con:0.00039377
# loss_tot:0.25344646
# epoch 293 loss_pde:0.10935978, loss_ic:0.01369956, loss_rh:0.00001402,loss_con:0.00039147
# loss_tot:0.25296791
# epoch 294 loss_pde:0.10906571, loss_ic:0.01368420, loss_rh:0.00001403,loss_con:0.00038914
# loss_tot:0.25249345
# epoch 295 loss_pde:0.10877788, loss_ic:0.01366854, loss_rh:0.00001405,loss_con:0.00038687
# loss_tot:0.25202370
# epoch 296 loss_pde:0.10849763, loss_ic:0.01365226, loss_rh:0.00001406,loss_con:0.00038480
# loss_tot:0.25155785
# epoch 297 loss_pde:0.10822575, loss_ic:0.01363528, loss_rh:0.00001408,loss_con:0.00038285
# loss_tot:0.25109496
# epoch 298 loss_pde:0.10796147, loss_ic:0.01361787, loss_rh:0.00001410,loss_con:0.00038091
# loss_tot:0.25063506
# epoch 299 loss_pde:0.10770143, loss_ic:0.01360043, loss_rh:0.00001413,loss_con:0.00037906
# loss_tot:0.25017900
# epoch 300 loss_pde:0.10744079, loss_ic:0.01358337, loss_rh:0.00001415,loss_con:0.00037738
# loss_tot:0.24972708
# epoch 301 loss_pde:0.10717677, loss_ic:0.01356697, loss_rh:0.00001418,loss_con:0.00037577
# loss_tot:0.24927864
# epoch 302 loss_pde:0.10690937, loss_ic:0.01355132, loss_rh:0.00001420,loss_con:0.00037411
# loss_tot:0.24883307
# epoch 303 loss_pde:0.10663947, loss_ic:0.01353621, loss_rh:0.00001422,loss_con:0.00037243
# loss_tot:0.24839045
# epoch 304 loss_pde:0.10636914, loss_ic:0.01352133, loss_rh:0.00001424,loss_con:0.00037084
# loss_tot:0.24795124
# epoch 305 loss_pde:0.10610219, loss_ic:0.01350639, loss_rh:0.00001425,loss_con:0.00036927
# loss_tot:0.24751556
# epoch 306 loss_pde:0.10584177, loss_ic:0.01349118, loss_rh:0.00001427,loss_con:0.00036761
# loss_tot:0.24708301
# epoch 307 loss_pde:0.10558807, loss_ic:0.01347565, loss_rh:0.00001428,loss_con:0.00036589
# loss_tot:0.24665321
# epoch 308 loss_pde:0.10533940, loss_ic:0.01345986, loss_rh:0.00001431,loss_con:0.00036422
# loss_tot:0.24622620
# epoch 309 loss_pde:0.10509371, loss_ic:0.01344401, loss_rh:0.00001433,loss_con:0.00036258
# loss_tot:0.24580151
# epoch 310 loss_pde:0.10484809, loss_ic:0.01342841, loss_rh:0.00001435,loss_con:0.00036091
# loss_tot:0.24537951
# epoch 311 loss_pde:0.10460175, loss_ic:0.01341313, loss_rh:0.00001437,loss_con:0.00035922
# loss_tot:0.24495999
# epoch 312 loss_pde:0.10435407, loss_ic:0.01339815, loss_rh:0.00001438,loss_con:0.00035755
# loss_tot:0.24454296
# epoch 313 loss_pde:0.10410618, loss_ic:0.01338338, loss_rh:0.00001440,loss_con:0.00035591
# loss_tot:0.24412854
# epoch 314 loss_pde:0.10386057, loss_ic:0.01336868, loss_rh:0.00001441,loss_con:0.00035421
# loss_tot:0.24371677
# epoch 315 loss_pde:0.10361900, loss_ic:0.01335388, loss_rh:0.00001443,loss_con:0.00035247
# loss_tot:0.24330758
# epoch 316 loss_pde:0.10338089, loss_ic:0.01333887, loss_rh:0.00001444,loss_con:0.00035083
# loss_tot:0.24290071
# epoch 317 loss_pde:0.10314565, loss_ic:0.01332366, loss_rh:0.00001446,loss_con:0.00034934
# loss_tot:0.24249602
# epoch 318 loss_pde:0.10291357, loss_ic:0.01330836, loss_rh:0.00001448,loss_con:0.00034785
# loss_tot:0.24209350
# epoch 319 loss_pde:0.10268445, loss_ic:0.01329310, loss_rh:0.00001450,loss_con:0.00034627
# loss_tot:0.24169319
# epoch 320 loss_pde:0.10245643, loss_ic:0.01327792, loss_rh:0.00001452,loss_con:0.00034467
# loss_tot:0.24129498
# epoch 321 loss_pde:0.10222837, loss_ic:0.01326286, loss_rh:0.00001454,loss_con:0.00034309
# loss_tot:0.24089872
# epoch 322 loss_pde:0.10200096, loss_ic:0.01324792, loss_rh:0.00001456,loss_con:0.00034149
# loss_tot:0.24050439
# epoch 323 loss_pde:0.10177518, loss_ic:0.01323305, loss_rh:0.00001457,loss_con:0.00033983
# loss_tot:0.24011203
# epoch 324 loss_pde:0.10155103, loss_ic:0.01321815, loss_rh:0.00001459,loss_con:0.00033823
# loss_tot:0.23972161
# epoch 325 loss_pde:0.10132871, loss_ic:0.01320312, loss_rh:0.00001460,loss_con:0.00033675
# loss_tot:0.23933299
# epoch 326 loss_pde:0.10110893, loss_ic:0.01318795, loss_rh:0.00001462,loss_con:0.00033536
# loss_tot:0.23894611
# epoch 327 loss_pde:0.10089195, loss_ic:0.01317264, loss_rh:0.00001463,loss_con:0.00033398
# loss_tot:0.23856088
# epoch 328 loss_pde:0.10067704, loss_ic:0.01315723, loss_rh:0.00001465,loss_con:0.00033265
# loss_tot:0.23817730
# epoch 329 loss_pde:0.10046270, loss_ic:0.01314181, loss_rh:0.00001466,loss_con:0.00033141
# loss_tot:0.23779534
# epoch 330 loss_pde:0.10024814, loss_ic:0.01312646, loss_rh:0.00001467,loss_con:0.00033023
# loss_tot:0.23741496
# epoch 331 loss_pde:0.10003331, loss_ic:0.01311127, loss_rh:0.00001468,loss_con:0.00032907
# loss_tot:0.23703605
# epoch 332 loss_pde:0.09981658, loss_ic:0.01309635, loss_rh:0.00001468,loss_con:0.00032795
# loss_tot:0.23665835
# epoch 333 loss_pde:0.09959622, loss_ic:0.01308178, loss_rh:0.00001469,loss_con:0.00032688
# loss_tot:0.23628119
# epoch 334 loss_pde:0.09937538, loss_ic:0.01306732, loss_rh:0.00001469,loss_con:0.00032585
# loss_tot:0.23590531
# epoch 335 loss_pde:0.09915863, loss_ic:0.01305263, loss_rh:0.00001469,loss_con:0.00032479
# loss_tot:0.23553101
# epoch 336 loss_pde:0.09894710, loss_ic:0.01303752, loss_rh:0.00001470,loss_con:0.00032372
# loss_tot:0.23515793
# epoch 337 loss_pde:0.09874060, loss_ic:0.01302204, loss_rh:0.00001470,loss_con:0.00032262
# loss_tot:0.23478608
# epoch 338 loss_pde:0.09853819, loss_ic:0.01300645, loss_rh:0.00001470,loss_con:0.00032141
# loss_tot:0.23441571
# epoch 339 loss_pde:0.09833734, loss_ic:0.01299100, loss_rh:0.00001470,loss_con:0.00032014
# loss_tot:0.23404693
# epoch 340 loss_pde:0.09813459, loss_ic:0.01297584, loss_rh:0.00001470,loss_con:0.00031897
# loss_tot:0.23367959
# epoch 341 loss_pde:0.09792910, loss_ic:0.01296101, loss_rh:0.00001470,loss_con:0.00031789
# loss_tot:0.23331344
# epoch 342 loss_pde:0.09772324, loss_ic:0.01294638, loss_rh:0.00001469,loss_con:0.00031681
# loss_tot:0.23294855
# epoch 343 loss_pde:0.09751926, loss_ic:0.01293169, loss_rh:0.00001469,loss_con:0.00031571
# loss_tot:0.23258509
# epoch 344 loss_pde:0.09731817, loss_ic:0.01291672, loss_rh:0.00001468,loss_con:0.00031470
# loss_tot:0.23222302
# epoch 345 loss_pde:0.09712103, loss_ic:0.01290136, loss_rh:0.00001468,loss_con:0.00031376
# loss_tot:0.23186214
# epoch 346 loss_pde:0.09692850, loss_ic:0.01288567, loss_rh:0.00001467,loss_con:0.00031276
# loss_tot:0.23150240
# epoch 347 loss_pde:0.09673893, loss_ic:0.01286983, loss_rh:0.00001467,loss_con:0.00031174
# loss_tot:0.23114389
# epoch 348 loss_pde:0.09654951, loss_ic:0.01285401, loss_rh:0.00001467,loss_con:0.00031081
# loss_tot:0.23078662
# epoch 349 loss_pde:0.09635893, loss_ic:0.01283837, loss_rh:0.00001466,loss_con:0.00030994
# loss_tot:0.23043047
# epoch 350 loss_pde:0.09616726, loss_ic:0.01282297, loss_rh:0.00001466,loss_con:0.00030903
# loss_tot:0.23007511
# epoch 351 loss_pde:0.09597453, loss_ic:0.01280778, loss_rh:0.00001466,loss_con:0.00030810
# loss_tot:0.22972059
# epoch 352 loss_pde:0.09578114, loss_ic:0.01279265, loss_rh:0.00001465,loss_con:0.00030723
# loss_tot:0.22936701
# epoch 353 loss_pde:0.09558807, loss_ic:0.01277749, loss_rh:0.00001464,loss_con:0.00030644
# loss_tot:0.22901432
# epoch 354 loss_pde:0.09539625, loss_ic:0.01276225, loss_rh:0.00001463,loss_con:0.00030569
# loss_tot:0.22866244
# epoch 355 loss_pde:0.09520550, loss_ic:0.01274696, loss_rh:0.00001462,loss_con:0.00030497
# loss_tot:0.22831132
# epoch 356 loss_pde:0.09501496, loss_ic:0.01273170, loss_rh:0.00001462,loss_con:0.00030430
# loss_tot:0.22796095
# epoch 357 loss_pde:0.09482412, loss_ic:0.01271655, loss_rh:0.00001462,loss_con:0.00030364
# loss_tot:0.22761135
# epoch 358 loss_pde:0.09463282, loss_ic:0.01270159, loss_rh:0.00001461,loss_con:0.00030293
# loss_tot:0.22726248
# epoch 359 loss_pde:0.09444091, loss_ic:0.01268683, loss_rh:0.00001461,loss_con:0.00030214
# loss_tot:0.22691430
# epoch 360 loss_pde:0.09424849, loss_ic:0.01267222, loss_rh:0.00001460,loss_con:0.00030130
# loss_tot:0.22656686
# epoch 361 loss_pde:0.09405593, loss_ic:0.01265768, loss_rh:0.00001459,loss_con:0.00030047
# loss_tot:0.22622001
# epoch 362 loss_pde:0.09386402, loss_ic:0.01264312, loss_rh:0.00001458,loss_con:0.00029965
# loss_tot:0.22587395
# epoch 363 loss_pde:0.09367365, loss_ic:0.01262849, loss_rh:0.00001458,loss_con:0.00029886
# loss_tot:0.22552875
# epoch 364 loss_pde:0.09348506, loss_ic:0.01261377, loss_rh:0.00001457,loss_con:0.00029810
# loss_tot:0.22518445
# epoch 365 loss_pde:0.09329803, loss_ic:0.01259895, loss_rh:0.00001456,loss_con:0.00029738
# loss_tot:0.22484115
# epoch 366 loss_pde:0.09311239, loss_ic:0.01258410, loss_rh:0.00001455,loss_con:0.00029667
# loss_tot:0.22449894
# epoch 367 loss_pde:0.09292775, loss_ic:0.01256927, loss_rh:0.00001454,loss_con:0.00029595
# loss_tot:0.22415786
# epoch 368 loss_pde:0.09274264, loss_ic:0.01255450, loss_rh:0.00001454,loss_con:0.00029524
# loss_tot:0.22381710
# epoch 369 loss_pde:0.09255517, loss_ic:0.01253996, loss_rh:0.00001453,loss_con:0.00029459
# loss_tot:0.22347744
# epoch 370 loss_pde:0.09236701, loss_ic:0.01252558, loss_rh:0.00001452,loss_con:0.00029400
# loss_tot:0.22313920
# epoch 371 loss_pde:0.09217982, loss_ic:0.01251123, loss_rh:0.00001451,loss_con:0.00029344
# loss_tot:0.22280262
# epoch 372 loss_pde:0.09199523, loss_ic:0.01249682, loss_rh:0.00001450,loss_con:0.00029286
# loss_tot:0.22246783
# epoch 373 loss_pde:0.09181452, loss_ic:0.01248234, loss_rh:0.00001449,loss_con:0.00029222
# loss_tot:0.22213498
# epoch 374 loss_pde:0.09163712, loss_ic:0.01246782, loss_rh:0.00001449,loss_con:0.00029154
# loss_tot:0.22180421
# epoch 375 loss_pde:0.09146129, loss_ic:0.01245335, loss_rh:0.00001449,loss_con:0.00029093
# loss_tot:0.22147556
# epoch 376 loss_pde:0.09128646, loss_ic:0.01243899, loss_rh:0.00001449,loss_con:0.00029034
# loss_tot:0.22114906
# epoch 377 loss_pde:0.09111293, loss_ic:0.01242478, loss_rh:0.00001448,loss_con:0.00028972
# loss_tot:0.22082474
# epoch 378 loss_pde:0.09094059, loss_ic:0.01241068, loss_rh:0.00001448,loss_con:0.00028912
# loss_tot:0.22050270
# epoch 379 loss_pde:0.09076965, loss_ic:0.01239661, loss_rh:0.00001447,loss_con:0.00028857
# loss_tot:0.22018307
# epoch 380 loss_pde:0.09060159, loss_ic:0.01238252, loss_rh:0.00001446,loss_con:0.00028799
# loss_tot:0.21986597
# epoch 381 loss_pde:0.09043737, loss_ic:0.01236843, loss_rh:0.00001446,loss_con:0.00028728
# loss_tot:0.21955147
# epoch 382 loss_pde:0.09027582, loss_ic:0.01235436, loss_rh:0.00001445,loss_con:0.00028655
# loss_tot:0.21923966
# epoch 383 loss_pde:0.09011553, loss_ic:0.01234036, loss_rh:0.00001445,loss_con:0.00028589
# loss_tot:0.21893061
# epoch 384 loss_pde:0.08995611, loss_ic:0.01232653, loss_rh:0.00001444,loss_con:0.00028524
# loss_tot:0.21862408
# epoch 385 loss_pde:0.08979727, loss_ic:0.01231291, loss_rh:0.00001443,loss_con:0.00028459
# loss_tot:0.21832023
# epoch 386 loss_pde:0.08963710, loss_ic:0.01229961, loss_rh:0.00001442,loss_con:0.00028403
# loss_tot:0.21801907
# epoch 387 loss_pde:0.08947569, loss_ic:0.01228654, loss_rh:0.00001441,loss_con:0.00028356
# loss_tot:0.21771987
# epoch 388 loss_pde:0.08931482, loss_ic:0.01227364, loss_rh:0.00001440,loss_con:0.00028313
# loss_tot:0.21742332
# epoch 389 loss_pde:0.08915654, loss_ic:0.01226087, loss_rh:0.00001439,loss_con:0.00028264
# loss_tot:0.21712950
# epoch 390 loss_pde:0.08900005, loss_ic:0.01224821, loss_rh:0.00001438,loss_con:0.00028216
# loss_tot:0.21683844
# epoch 391 loss_pde:0.08884467, loss_ic:0.01223574, loss_rh:0.00001438,loss_con:0.00028170
# loss_tot:0.21655017
# epoch 392 loss_pde:0.08869088, loss_ic:0.01222357, loss_rh:0.00001438,loss_con:0.00028113
# loss_tot:0.21626467
# epoch 393 loss_pde:0.08853729, loss_ic:0.01221173, loss_rh:0.00001438,loss_con:0.00028047
# loss_tot:0.21598145
# epoch 394 loss_pde:0.08838873, loss_ic:0.01219957, loss_rh:0.00001438,loss_con:0.00027983
# loss_tot:0.21570066
# epoch 395 loss_pde:0.08824383, loss_ic:0.01218746, loss_rh:0.00001438,loss_con:0.00027909
# loss_tot:0.21542281
# epoch 396 loss_pde:0.08809849, loss_ic:0.01217583, loss_rh:0.00001438,loss_con:0.00027825
# loss_tot:0.21514774
# epoch 397 loss_pde:0.08794888, loss_ic:0.01216483, loss_rh:0.00001439,loss_con:0.00027746
# loss_tot:0.21487507
# epoch 398 loss_pde:0.08779630, loss_ic:0.01215435, loss_rh:0.00001439,loss_con:0.00027672
# loss_tot:0.21460490
# epoch 399 loss_pde:0.08764387, loss_ic:0.01214409, loss_rh:0.00001439,loss_con:0.00027602
# loss_tot:0.21433743
# epoch 400 loss_pde:0.08749343, loss_ic:0.01213377, loss_rh:0.00001439,loss_con:0.00027540
# loss_tot:0.21407259
# epoch 401 loss_pde:0.08734670, loss_ic:0.01212330, loss_rh:0.00001440,loss_con:0.00027475
# loss_tot:0.21381005
# epoch 402 loss_pde:0.08720426, loss_ic:0.01211280, loss_rh:0.00001440,loss_con:0.00027393
# loss_tot:0.21354965
# epoch 403 loss_pde:0.08706400, loss_ic:0.01210241, loss_rh:0.00001441,loss_con:0.00027305
# loss_tot:0.21329176
# epoch 404 loss_pde:0.08692187, loss_ic:0.01209229, loss_rh:0.00001442,loss_con:0.00027233
# loss_tot:0.21303638
# epoch 405 loss_pde:0.08677729, loss_ic:0.01208256, loss_rh:0.00001442,loss_con:0.00027169
# loss_tot:0.21278338
# epoch 406 loss_pde:0.08663207, loss_ic:0.01207321, loss_rh:0.00001443,loss_con:0.00027101
# loss_tot:0.21253264
# epoch 407 loss_pde:0.08648675, loss_ic:0.01206411, loss_rh:0.00001443,loss_con:0.00027034
# loss_tot:0.21228422
# epoch 408 loss_pde:0.08634264, loss_ic:0.01205506, loss_rh:0.00001443,loss_con:0.00026970
# loss_tot:0.21203813
# epoch 409 loss_pde:0.08620218, loss_ic:0.01204599, loss_rh:0.00001444,loss_con:0.00026895
# loss_tot:0.21179423
# epoch 410 loss_pde:0.08606502, loss_ic:0.01203689, loss_rh:0.00001444,loss_con:0.00026811
# loss_tot:0.21155247
# epoch 411 loss_pde:0.08592793, loss_ic:0.01202787, loss_rh:0.00001445,loss_con:0.00026742
# loss_tot:0.21131283
# epoch 412 loss_pde:0.08578971, loss_ic:0.01201909, loss_rh:0.00001445,loss_con:0.00026684
# loss_tot:0.21107530
# epoch 413 loss_pde:0.08565168, loss_ic:0.01201066, loss_rh:0.00001445,loss_con:0.00026616
# loss_tot:0.21083976
# epoch 414 loss_pde:0.08551419, loss_ic:0.01200248, loss_rh:0.00001446,loss_con:0.00026537
# loss_tot:0.21060615
# epoch 415 loss_pde:0.08537708, loss_ic:0.01199440, loss_rh:0.00001446,loss_con:0.00026458
# loss_tot:0.21037442
# epoch 416 loss_pde:0.08524112, loss_ic:0.01198632, loss_rh:0.00001446,loss_con:0.00026377
# loss_tot:0.21014418
# epoch 417 loss_pde:0.08510832, loss_ic:0.01197818, loss_rh:0.00001446,loss_con:0.00026290
# loss_tot:0.20991574
# epoch 418 loss_pde:0.08497711, loss_ic:0.01196998, loss_rh:0.00001446,loss_con:0.00026212
# loss_tot:0.20968903
# epoch 419 loss_pde:0.08484643, loss_ic:0.01196177, loss_rh:0.00001446,loss_con:0.00026150
# loss_tot:0.20946402
# epoch 420 loss_pde:0.08471756, loss_ic:0.01195360, loss_rh:0.00001446,loss_con:0.00026084
# loss_tot:0.20924058
# epoch 421 loss_pde:0.08458996, loss_ic:0.01194547, loss_rh:0.00001446,loss_con:0.00026011
# loss_tot:0.20901829
# epoch 422 loss_pde:0.08446301, loss_ic:0.01193737, loss_rh:0.00001446,loss_con:0.00025938
# loss_tot:0.20879749
# epoch 423 loss_pde:0.08433644, loss_ic:0.01192935, loss_rh:0.00001445,loss_con:0.00025865
# loss_tot:0.20857817
# epoch 424 loss_pde:0.08421044, loss_ic:0.01192142, loss_rh:0.00001445,loss_con:0.00025792
# loss_tot:0.20836036
# epoch 425 loss_pde:0.08408492, loss_ic:0.01191359, loss_rh:0.00001445,loss_con:0.00025721
# loss_tot:0.20814401
# epoch 426 loss_pde:0.08395982, loss_ic:0.01190582, loss_rh:0.00001445,loss_con:0.00025656
# loss_tot:0.20792907
# epoch 427 loss_pde:0.08383565, loss_ic:0.01189810, loss_rh:0.00001445,loss_con:0.00025591
# loss_tot:0.20771553
# epoch 428 loss_pde:0.08371281, loss_ic:0.01189045, loss_rh:0.00001444,loss_con:0.00025520
# loss_tot:0.20750335
# epoch 429 loss_pde:0.08359093, loss_ic:0.01188287, loss_rh:0.00001444,loss_con:0.00025444
# loss_tot:0.20729249
# epoch 430 loss_pde:0.08346943, loss_ic:0.01187535, loss_rh:0.00001444,loss_con:0.00025369
# loss_tot:0.20708291
# epoch 431 loss_pde:0.08334833, loss_ic:0.01186787, loss_rh:0.00001444,loss_con:0.00025298
# loss_tot:0.20687459
# epoch 432 loss_pde:0.08322819, loss_ic:0.01186038, loss_rh:0.00001443,loss_con:0.00025231
# loss_tot:0.20666752
# epoch 433 loss_pde:0.08310960, loss_ic:0.01185283, loss_rh:0.00001443,loss_con:0.00025167
# loss_tot:0.20646168
# epoch 434 loss_pde:0.08299279, loss_ic:0.01184521, loss_rh:0.00001443,loss_con:0.00025103
# loss_tot:0.20625704
# epoch 435 loss_pde:0.08287758, loss_ic:0.01183756, loss_rh:0.00001443,loss_con:0.00025037
# loss_tot:0.20605329
# epoch 436 loss_pde:0.08276345, loss_ic:0.01182988, loss_rh:0.00001443,loss_con:0.00024969
# loss_tot:0.20585032
# epoch 437 loss_pde:0.08265082, loss_ic:0.01182222, loss_rh:0.00001442,loss_con:0.00024896
# loss_tot:0.20564839
# ...
# loss_tot:0.09020621
# epoch 3839 loss_pde:0.04360554, loss_ic:0.00404852, loss_rh:0.00008038,loss_con:0.00006641
# loss_tot:0.08769432
# epoch 3840 loss_pde:0.04320990, loss_ic:0.00401662, loss_rh:0.00008193,loss_con:0.00009286
# loss_tot:0.08710388
# epoch 3841 loss_pde:0.04343104, loss_ic:0.00405194, loss_rh:0.00008013,loss_con:0.00012282
# loss_tot:0.08839337
# epoch 3842 loss_pde:0.04480158, loss_ic:0.00406372, loss_rh:0.00008021,loss_con:0.00005017
# loss_tot:0.08929138
# epoch 3843 loss_pde:0.04348416, loss_ic:0.00402588, loss_rh:0.00008126,loss_con:0.00015369
# loss_tot:0.08862659
# epoch 3844 loss_pde:0.04408243, loss_ic:0.00404070, loss_rh:0.00007908,loss_con:0.00004544
# loss_tot:0.08757136
# epoch 3845 loss_pde:0.04270740, loss_ic:0.00400199, loss_rh:0.00008187,loss_con:0.00014026
# loss_tot:0.08727426
# epoch 3846 loss_pde:0.04320276, loss_ic:0.00405383, loss_rh:0.00008025,loss_con:0.00006302
# loss_tot:0.08755145
# epoch 3847 loss_pde:0.04282175, loss_ic:0.00402892, loss_rh:0.00007931,loss_con:0.00011403
# loss_tot:0.08762761
# epoch 3848 loss_pde:0.04375338, loss_ic:0.00400664, loss_rh:0.00008223,loss_con:0.00007352
# loss_tot:0.08736713
# epoch 3849 loss_pde:0.04307925, loss_ic:0.00401891, loss_rh:0.00007883,loss_con:0.00009053
# loss_tot:0.08694961
# epoch 3850 loss_pde:0.04295661, loss_ic:0.00399162, loss_rh:0.00008057,loss_con:0.00009491
# loss_tot:0.08664462
# epoch 3851 loss_pde:0.04274453, loss_ic:0.00400138, loss_rh:0.00008052,loss_con:0.00007760
# loss_tot:0.08649217
# epoch 3852 loss_pde:0.04247836, loss_ic:0.00399871, loss_rh:0.00007901,loss_con:0.00010518
# loss_tot:0.08646297
# epoch 3853 loss_pde:0.04334111, loss_ic:0.00398677, loss_rh:0.00008140,loss_con:0.00006342
# loss_tot:0.08656006
# epoch 3854 loss_pde:0.04298279, loss_ic:0.00397408, loss_rh:0.00007942,loss_con:0.00011138
# loss_tot:0.08672265
# epoch 3855 loss_pde:0.04358201, loss_ic:0.00398587, loss_rh:0.00007961,loss_con:0.00006455
# loss_tot:0.08678430
# epoch 3856 loss_pde:0.04306564, loss_ic:0.00396344, loss_rh:0.00008086,loss_con:0.00010128
# loss_tot:0.08658817
# epoch 3857 loss_pde:0.04295116, loss_ic:0.00398194, loss_rh:0.00007904,loss_con:0.00007073
# loss_tot:0.08620864
# epoch 3858 loss_pde:0.04262217, loss_ic:0.00395325, loss_rh:0.00008004,loss_con:0.00009080
# loss_tot:0.08588935
# epoch 3859 loss_pde:0.04247427, loss_ic:0.00396507, loss_rh:0.00007972,loss_con:0.00008007
# loss_tot:0.08578470
# epoch 3860 loss_pde:0.04266836, loss_ic:0.00395750, loss_rh:0.00007935,loss_con:0.00008037
# loss_tot:0.08583994
# epoch 3861 loss_pde:0.04266249, loss_ic:0.00394758, loss_rh:0.00008037,loss_con:0.00008655
# loss_tot:0.08587687
# epoch 3862 loss_pde:0.04293711, loss_ic:0.00394820, loss_rh:0.00007938,loss_con:0.00007461
# loss_tot:0.08587455
# epoch 3863 loss_pde:0.04254356, loss_ic:0.00394785, loss_rh:0.00007966,loss_con:0.00009435
# loss_tot:0.08588514
# epoch 3864 loss_pde:0.04311351, loss_ic:0.00394317, loss_rh:0.00008056,loss_con:0.00006385
# loss_tot:0.08591749
# epoch 3865 loss_pde:0.04241026, loss_ic:0.00395169, loss_rh:0.00007895,loss_con:0.00009940
# loss_tot:0.08588319
# epoch 3866 loss_pde:0.04320132, loss_ic:0.00393303, loss_rh:0.00008096,loss_con:0.00006036
# loss_tot:0.08577650
# epoch 3867 loss_pde:0.04226762, loss_ic:0.00394194, loss_rh:0.00007947,loss_con:0.00010580
# loss_tot:0.08566489
# epoch 3868 loss_pde:0.04320106, loss_ic:0.00392460, loss_rh:0.00008039,loss_con:0.00005785
# loss_tot:0.08564587
# epoch 3869 loss_pde:0.04236605, loss_ic:0.00393043, loss_rh:0.00008046,loss_con:0.00010683
# loss_tot:0.08570970
# epoch 3870 loss_pde:0.04340923, loss_ic:0.00392414, loss_rh:0.00007978,loss_con:0.00005947
# loss_tot:0.08583200
# epoch 3871 loss_pde:0.04267488, loss_ic:0.00392986, loss_rh:0.00008029,loss_con:0.00010646
# loss_tot:0.08601797
# epoch 3872 loss_pde:0.04422959, loss_ic:0.00390510, loss_rh:0.00008050,loss_con:0.00005670
# loss_tot:0.08641075
# epoch 3873 loss_pde:0.04358367, loss_ic:0.00393614, loss_rh:0.00007948,loss_con:0.00011090
# loss_tot:0.08710514
# epoch 3874 loss_pde:0.04631987, loss_ic:0.00388832, loss_rh:0.00008139,loss_con:0.00005963
# loss_tot:0.08831928
# epoch 3875 loss_pde:0.04623325, loss_ic:0.00394790, loss_rh:0.00007904,loss_con:0.00012608
# loss_tot:0.09019478
# epoch 3876 loss_pde:0.05170416, loss_ic:0.00387575, loss_rh:0.00008168,loss_con:0.00006422
# loss_tot:0.09359613
# epoch 3877 loss_pde:0.05381102, loss_ic:0.00397637, loss_rh:0.00007931,loss_con:0.00016499
# loss_tot:0.09888622
# epoch 3878 loss_pde:0.06647123, loss_ic:0.00387124, loss_rh:0.00008198,loss_con:0.00009756
# loss_tot:0.10879839
# epoch 3879 loss_pde:0.07490343, loss_ic:0.00404091, loss_rh:0.00007905,loss_con:0.00026903
# loss_tot:0.12266506
# epoch 3880 loss_pde:0.10501500, loss_ic:0.00387912, loss_rh:0.00008370,loss_con:0.00018739
# loss_tot:0.14892430
# epoch 3881 loss_pde:0.12204016, loss_ic:0.00416013, loss_rh:0.00007826,loss_con:0.00050345
# loss_tot:0.17519502
# epoch 3882 loss_pde:0.17105594, loss_ic:0.00392527, loss_rh:0.00008556,loss_con:0.00038441
# loss_tot:0.21870363
# epoch 3883 loss_pde:0.16917752, loss_ic:0.00429130, loss_rh:0.00007781,loss_con:0.00086539
# loss_tot:0.22968692
# epoch 3884 loss_pde:0.18246491, loss_ic:0.00399720, loss_rh:0.00008541,loss_con:0.00049081
# loss_tot:0.23261197
# epoch 3885 loss_pde:0.11796542, loss_ic:0.00423204, loss_rh:0.00007839,loss_con:0.00104917
# loss_tot:0.17980132
# epoch 3886 loss_pde:0.08712995, loss_ic:0.00401465, loss_rh:0.00008124,loss_con:0.00025746
# loss_tot:0.13317731
# epoch 3887 loss_pde:0.06110682, loss_ic:0.00398127, loss_rh:0.00007797,loss_con:0.00094855
# loss_tot:0.11657917
# epoch 3888 loss_pde:0.08351482, loss_ic:0.00425486, loss_rh:0.00007648,loss_con:0.00015985
# loss_tot:0.13148647
# epoch 3889 loss_pde:0.09520844, loss_ic:0.00416120, loss_rh:0.00007862,loss_con:0.00070137
# loss_tot:0.15148532
# epoch 3890 loss_pde:0.08037262, loss_ic:0.00450165, loss_rh:0.00007620,loss_con:0.00019923
# loss_tot:0.13554996
# epoch 3891 loss_pde:0.05645138, loss_ic:0.00423759, loss_rh:0.00007702,loss_con:0.00019177
# loss_tot:0.10745857
# epoch 3892 loss_pde:0.04621234, loss_ic:0.00409159, loss_rh:0.00007799,loss_con:0.00020575
# loss_tot:0.09330267
# epoch 3893 loss_pde:0.06032049, loss_ic:0.00412100, loss_rh:0.00007893,loss_con:0.00002350
# loss_tot:0.10454215
# epoch 3894 loss_pde:0.06716876, loss_ic:0.00420980, loss_rh:0.00007884,loss_con:0.00047729
# loss_tot:0.12214847
# epoch 3895 loss_pde:0.06561242, loss_ic:0.00460225, loss_rh:0.00008068,loss_con:0.00006230
# loss_tot:0.12211951
# epoch 3896 loss_pde:0.04917485, loss_ic:0.00435000, loss_rh:0.00007703,loss_con:0.00036803
# loss_tot:0.10612102
# epoch 3897 loss_pde:0.04721584, loss_ic:0.00412703, loss_rh:0.00008032,loss_con:0.00001589
# loss_tot:0.09246444
# epoch 3898 loss_pde:0.04806450, loss_ic:0.00406995, loss_rh:0.00007946,loss_con:0.00017978
# loss_tot:0.09421147
# epoch 3899 loss_pde:0.05439732, loss_ic:0.00410570, loss_rh:0.00008173,loss_con:0.00019395
# loss_tot:0.10323935
# epoch 3900 loss_pde:0.05124086, loss_ic:0.00436154, loss_rh:0.00008113,loss_con:0.00006288
# loss_tot:0.10286890
# epoch 3901 loss_pde:0.04505919, loss_ic:0.00410285, loss_rh:0.00007933,loss_con:0.00021165
# loss_tot:0.09397650
# epoch 3902 loss_pde:0.04593798, loss_ic:0.00400837, loss_rh:0.00008183,loss_con:0.00000887
# loss_tot:0.08852969
# epoch 3903 loss_pde:0.04546606, loss_ic:0.00406384, loss_rh:0.00007991,loss_con:0.00024209
# loss_tot:0.09288106
# epoch 3904 loss_pde:0.05187708, loss_ic:0.00408393, loss_rh:0.00008056,loss_con:0.00011899
# loss_tot:0.09878637
# epoch 3905 loss_pde:0.04775017, loss_ic:0.00413924, loss_rh:0.00008270,loss_con:0.00017777
# loss_tot:0.09644038
# epoch 3906 loss_pde:0.04566057, loss_ic:0.00399176, loss_rh:0.00008037,loss_con:0.00006607
# loss_tot:0.08923396
# epoch 3907 loss_pde:0.04254007, loss_ic:0.00394864, loss_rh:0.00008389,loss_con:0.00008264
# loss_tot:0.08579457
# epoch 3908 loss_pde:0.04319156, loss_ic:0.00403850, loss_rh:0.00008209,loss_con:0.00010463
# loss_tot:0.08876649
# epoch 3909 loss_pde:0.04702957, loss_ic:0.00402009, loss_rh:0.00008118,loss_con:0.00009570
# loss_tot:0.09223806
# epoch 3910 loss_pde:0.04604268, loss_ic:0.00403644, loss_rh:0.00008396,loss_con:0.00014326
# loss_tot:0.09173980
# epoch 3911 loss_pde:0.04651700, loss_ic:0.00395773, loss_rh:0.00008059,loss_con:0.00004079
# loss_tot:0.08890399
# epoch 3912 loss_pde:0.04269862, loss_ic:0.00395462, loss_rh:0.00008253,loss_con:0.00015642
# loss_tot:0.08727317
# epoch 3913 loss_pde:0.04463747, loss_ic:0.00400389, loss_rh:0.00008313,loss_con:0.00002752
# loss_tot:0.08811918
# epoch 3914 loss_pde:0.04515641, loss_ic:0.00392661, loss_rh:0.00008227,loss_con:0.00018106
# loss_tot:0.08965229
# epoch 3915 loss_pde:0.04742319, loss_ic:0.00395297, loss_rh:0.00008415,loss_con:0.00004483
# loss_tot:0.09021374
# epoch 3916 loss_pde:0.04731356, loss_ic:0.00390342, loss_rh:0.00008385,loss_con:0.00012826
# loss_tot:0.09052133
# epoch 3917 loss_pde:0.04765124, loss_ic:0.00397077, loss_rh:0.00008223,loss_con:0.00008011
# loss_tot:0.09161714
# epoch 3918 loss_pde:0.05303229, loss_ic:0.00393779, loss_rh:0.00008613,loss_con:0.00006521
# loss_tot:0.09627103
# epoch 3919 loss_pde:0.06091544, loss_ic:0.00397839, loss_rh:0.00008096,loss_con:0.00011922
# loss_tot:0.10550253
# epoch 3920 loss_pde:0.07854835, loss_ic:0.00393139, loss_rh:0.00008766,loss_con:0.00008070
# loss_tot:0.12179132
# epoch 3921 loss_pde:0.10176690, loss_ic:0.00399763, loss_rh:0.00008083,loss_con:0.00011010
# loss_tot:0.14670703
# epoch 3922 loss_pde:0.14564156, loss_ic:0.00396444, loss_rh:0.00008869,loss_con:0.00020500
# loss_tot:0.19163738
# epoch 3923 loss_pde:0.19158512, loss_ic:0.00421145, loss_rh:0.00008144,loss_con:0.00011487
# loss_tot:0.24125497
# epoch 3924 loss_pde:0.25087636, loss_ic:0.00415063, loss_rh:0.00009300,loss_con:0.00048544
# loss_tot:0.30532309
# epoch 3925 loss_pde:0.21903041, loss_ic:0.00445478, loss_rh:0.00007961,loss_con:0.00013388
# loss_tot:0.27419000
# epoch 3926 loss_pde:0.13640181, loss_ic:0.00413291, loss_rh:0.00009528,loss_con:0.00044528
# loss_tot:0.18962123
# epoch 3927 loss_pde:0.05519862, loss_ic:0.00415046, loss_rh:0.00008383,loss_con:0.00002910
# loss_tot:0.10068567
# epoch 3928 loss_pde:0.07435788, loss_ic:0.00410510, loss_rh:0.00008966,loss_con:0.00020410
# loss_tot:0.12154521
# epoch 3929 loss_pde:0.13117143, loss_ic:0.00414662, loss_rh:0.00008999,loss_con:0.00035319
# loss_tot:0.18209090
# epoch 3930 loss_pde:0.09234122, loss_ic:0.00433749, loss_rh:0.00008262,loss_con:0.00013775
# loss_tot:0.14457838
# epoch 3931 loss_pde:0.04806800, loss_ic:0.00413771, loss_rh:0.00009245,loss_con:0.00015236
# loss_tot:0.09659925
# epoch 3932 loss_pde:0.07293690, loss_ic:0.00417694, loss_rh:0.00008480,loss_con:0.00023504
# loss_tot:0.12060458
# epoch 3933 loss_pde:0.09053958, loss_ic:0.00424311, loss_rh:0.00009130,loss_con:0.00019004
# loss_tot:0.13978477
# epoch 3934 loss_pde:0.06093066, loss_ic:0.00420880, loss_rh:0.00009026,loss_con:0.00015211
# loss_tot:0.11106612
# epoch 3935 loss_pde:0.04875383, loss_ic:0.00417132, loss_rh:0.00008604,loss_con:0.00017994
# loss_tot:0.09792846
# epoch 3936 loss_pde:0.07586552, loss_ic:0.00421590, loss_rh:0.00009365,loss_con:0.00009797
# loss_tot:0.12232530
# epoch 3937 loss_pde:0.06911590, loss_ic:0.00427979, loss_rh:0.00008809,loss_con:0.00028670
# loss_tot:0.11895602
# epoch 3938 loss_pde:0.04721803, loss_ic:0.00420574, loss_rh:0.00008993,loss_con:0.00007181
# loss_tot:0.09565645
# epoch 3939 loss_pde:0.05869212, loss_ic:0.00423394, loss_rh:0.00009612,loss_con:0.00013766
# loss_tot:0.10659014
# epoch 3940 loss_pde:0.06779465, loss_ic:0.00431948, loss_rh:0.00008617,loss_con:0.00028206
# loss_tot:0.11719470
# epoch 3941 loss_pde:0.05096656, loss_ic:0.00424705, loss_rh:0.00009250,loss_con:0.00006024
# loss_tot:0.09789777
# epoch 3942 loss_pde:0.04836888, loss_ic:0.00418472, loss_rh:0.00009257,loss_con:0.00015107
# loss_tot:0.09639142
# epoch 3943 loss_pde:0.06236252, loss_ic:0.00426916, loss_rh:0.00008429,loss_con:0.00012747
# loss_tot:0.11011876
# epoch 3944 loss_pde:0.05880122, loss_ic:0.00431783, loss_rh:0.00009704,loss_con:0.00010495
# loss_tot:0.10621802
# epoch 3945 loss_pde:0.04347048, loss_ic:0.00415837, loss_rh:0.00009046,loss_con:0.00011951
# loss_tot:0.09013378
# epoch 3946 loss_pde:0.05480790, loss_ic:0.00423353, loss_rh:0.00008072,loss_con:0.00013930
# loss_tot:0.10316702
# epoch 3947 loss_pde:0.07421682, loss_ic:0.00508200, loss_rh:0.00009979,loss_con:0.00009030
# loss_tot:0.12936730
# epoch 3948 loss_pde:0.06279903, loss_ic:0.00777878, loss_rh:0.00008863,loss_con:0.00010565
# loss_tot:0.14390263
# epoch 3949 loss_pde:0.06437201, loss_ic:0.01018375, loss_rh:0.00006142,loss_con:0.00019764
# loss_tot:0.17091582
# epoch 3950 loss_pde:0.06568422, loss_ic:0.01124914, loss_rh:0.00005411,loss_con:0.00014435
# loss_tot:0.18233270
# epoch 3951 loss_pde:0.06547323, loss_ic:0.01117992, loss_rh:0.00005966,loss_con:0.00037157
# loss_tot:0.18426243
# epoch 3952 loss_pde:0.06750631, loss_ic:0.01032671, loss_rh:0.00006626,loss_con:0.00005461
# loss_tot:0.17318311
# epoch 3953 loss_pde:0.05841297, loss_ic:0.00891696, loss_rh:0.00007609,loss_con:0.00018047
# loss_tot:0.15267929
# epoch 3954 loss_pde:0.06690814, loss_ic:0.00680772, loss_rh:0.00009529,loss_con:0.00005903
# loss_tot:0.13881338
# epoch 3955 loss_pde:0.05092719, loss_ic:0.00478935, loss_rh:0.00007882,loss_con:0.00020411
# loss_tot:0.10447068
# epoch 3956 loss_pde:0.06572429, loss_ic:0.00624833, loss_rh:0.00005877,loss_con:0.00023477
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_692655/224219749.py in <module>
#       9 tic = time.time()
#      10 for epoch in range(1+epochi, epochs+epochi):
# ---> 11     loss = train(epoch)
#      12     print(f'loss_tot:{loss:.8f}')
#      13     loss_history.append(to_numpy(loss))
#
# /tmp/ipykernel_692655/2381275098.py in train(epoch)
#      39         loss.backward()
#      40         return loss
# ---> 41     loss = optimizer.step(closure)
#      42     return loss
#      43
#
# ~/.local/lib/python3.10/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     278                                                f"but got {result}.")
#     279
# --> 280                 out = func(*args, **kwargs)
#     281                 self._optimizer_step_code()
#     282
#
# ~/.local/lib/python3.10/site-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      31         try:
#      32             torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33             ret = func(self, *args, **kwargs)
#      34         finally:
#      35             torch.set_grad_enabled(prev_grad)
#
# ~/.local/lib/python3.10/site-packages/torch/optim/adam.py in step(self, closure)
#     119         if closure is not None:
#     120             with torch.enable_grad():
# --> 121                 loss = closure()
#     122
#     123         for group in self.param_groups:
#
# /tmp/ipykernel_692655/2381275098.py in closure()
#      37         loss = loss_pde + 10*(loss_ic+loss_bc) + 10*(loss_rh) +10*(loss_con +loss_con1+loss_con2)
#      38         print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f}, loss_rh:{loss_rh:.8f},loss_con:{loss_con:.8f}')
# ---> 39         loss.backward()
#      40         return loss
#      41     loss = optimizer.step(closure)
#
# ~/.local/lib/python3.10/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# ~/.local/lib/python3.10/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     198     # some Python versions print out the first line of a multi-line function
#     199     # calls in the traceback and some print out the last line
# --> 200     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
#model = PINNs_WE_Euler_1D(Nl=6,Nn=60).to(cuda).double()
optimizer = torch.optim.LBFGS(model.parameters(),lr=0.1,max_iter=30)

epochi = 0

epochs = 5000
tic = time.time()
for epoch in range(epochi, epochs+epochi):
    loss = train(epoch)
    print(f'loss_tot:{loss:.8f}')
    loss_history.append(to_numpy(loss))
  #  if loss < 0.005:
   #     break
toc = time.time()

print(f'Total training time: {toc - tic}')
# Out:
# epoch 0 loss_pde:0.00291910, loss_ic:0.00007867, loss_rh:0.00017039,loss_con:0.00000508
# epoch 0 loss_pde:0.46123978, loss_ic:0.00060731, loss_rh:0.00018005,loss_con:0.00002827
# epoch 0 loss_pde:0.40218857, loss_ic:0.00050008, loss_rh:0.00017882,loss_con:0.00002449
# epoch 0 loss_pde:0.27921478, loss_ic:0.00033472, loss_rh:0.00017614,loss_con:0.00001803
# epoch 0 loss_pde:0.11491856, loss_ic:0.00017649, loss_rh:0.00017313,loss_con:0.00001147
# epoch 0 loss_pde:0.07681980, loss_ic:0.00014223, loss_rh:0.00017220,loss_con:0.00001001
# epoch 0 loss_pde:0.06300174, loss_ic:0.00012980, loss_rh:0.00017168,loss_con:0.00000943
# epoch 0 loss_pde:0.05265495, loss_ic:0.00012045, loss_rh:0.00017118,loss_con:0.00000896
# epoch 0 loss_pde:0.04455913, loss_ic:0.00011321, loss_rh:0.00017071,loss_con:0.00000855
# epoch 0 loss_pde:0.03769322, loss_ic:0.00010733, loss_rh:0.00017027,loss_con:0.00000820
# epoch 0 loss_pde:0.02914561, loss_ic:0.00010147, loss_rh:0.00016978,loss_con:0.00000783
# epoch 0 loss_pde:0.02646314, loss_ic:0.00009940, loss_rh:0.00016960,loss_con:0.00000768
# epoch 0 loss_pde:0.02378040, loss_ic:0.00009718, loss_rh:0.00016939,loss_con:0.00000750
# epoch 0 loss_pde:0.02132134, loss_ic:0.00009505, loss_rh:0.00016919,loss_con:0.00000732
# epoch 0 loss_pde:0.01909547, loss_ic:0.00009305, loss_rh:0.00016900,loss_con:0.00000713
# epoch 0 loss_pde:0.01710555, loss_ic:0.00009123, loss_rh:0.00016882,loss_con:0.00000694
# epoch 0 loss_pde:0.01534253, loss_ic:0.00008961, loss_rh:0.00016866,loss_con:0.00000676
# epoch 0 loss_pde:0.01378898, loss_ic:0.00008819, loss_rh:0.00016852,loss_con:0.00000659
# epoch 0 loss_pde:0.01242310, loss_ic:0.00008695, loss_rh:0.00016840,loss_con:0.00000644
# epoch 0 loss_pde:0.01122565, loss_ic:0.00008588, loss_rh:0.00016835,loss_con:0.00000630
# epoch 0 loss_pde:0.01017324, loss_ic:0.00008497, loss_rh:0.00016832,loss_con:0.00000617
# epoch 0 loss_pde:0.00924930, loss_ic:0.00008418, loss_rh:0.00016831,loss_con:0.00000606
# epoch 0 loss_pde:0.00843849, loss_ic:0.00008351, loss_rh:0.00016831,loss_con:0.00000596
# epoch 0 loss_pde:0.00772769, loss_ic:0.00008293, loss_rh:0.00016833,loss_con:0.00000587
# epoch 0 loss_pde:0.00710523, loss_ic:0.00008244, loss_rh:0.00016836,loss_con:0.00000579
# epoch 0 loss_pde:0.00656079, loss_ic:0.00008201, loss_rh:0.00016844,loss_con:0.00000573
# epoch 0 loss_pde:0.00608878, loss_ic:0.00008166, loss_rh:0.00016853,loss_con:0.00000567
# epoch 0 loss_pde:0.00567328, loss_ic:0.00008134, loss_rh:0.00016862,loss_con:0.00000563
# epoch 0 loss_pde:0.00531212, loss_ic:0.00008107, loss_rh:0.00016872,loss_con:0.00000559
# epoch 0 loss_pde:0.00499822, loss_ic:0.00008084, loss_rh:0.00016883,loss_con:0.00000555
# loss_tot:0.00565178
# epoch 1 loss_pde:0.00472733, loss_ic:0.00008063, loss_rh:0.00016894,loss_con:0.00000553
# epoch 1 loss_pde:0.00449124, loss_ic:0.00008045, loss_rh:0.00016905,loss_con:0.00000551
# epoch 1 loss_pde:0.00428735, loss_ic:0.00008029, loss_rh:0.00016916,loss_con:0.00000549
# epoch 1 loss_pde:0.00411145, loss_ic:0.00008014, loss_rh:0.00016926,loss_con:0.00000547
# epoch 1 loss_pde:0.00396013, loss_ic:0.00008001, loss_rh:0.00016935,loss_con:0.00000546
# epoch 1 loss_pde:0.00383006, loss_ic:0.00007989, loss_rh:0.00016944,loss_con:0.00000545
# epoch 1 loss_pde:0.00371833, loss_ic:0.00007979, loss_rh:0.00016952,loss_con:0.00000544
# epoch 1 loss_pde:0.00362235, loss_ic:0.00007969, loss_rh:0.00016960,loss_con:0.00000544
# epoch 1 loss_pde:0.00353984, loss_ic:0.00007960, loss_rh:0.00016968,loss_con:0.00000543
# epoch 1 loss_pde:0.00346886, loss_ic:0.00007952, loss_rh:0.00016975,loss_con:0.00000542
# epoch 1 loss_pde:0.00340755, loss_ic:0.00007945, loss_rh:0.00016981,loss_con:0.00000541
# epoch 1 loss_pde:0.00335448, loss_ic:0.00007938, loss_rh:0.00016987,loss_con:0.00000541
# epoch 1 loss_pde:0.00330839, loss_ic:0.00007932, loss_rh:0.00016993,loss_con:0.00000540
# epoch 1 loss_pde:0.00326809, loss_ic:0.00007927, loss_rh:0.00016998,loss_con:0.00000539
# epoch 1 loss_pde:0.00323032, loss_ic:0.00007922, loss_rh:0.00017003,loss_con:0.00000539
# epoch 1 loss_pde:0.00320004, loss_ic:0.00007917, loss_rh:0.00017008,loss_con:0.00000538
# epoch 1 loss_pde:0.00317259, loss_ic:0.00007914, loss_rh:0.00017011,loss_con:0.00000537
# epoch 1 loss_pde:0.00314712, loss_ic:0.00007910, loss_rh:0.00017017,loss_con:0.00000536
# epoch 1 loss_pde:0.00312562, loss_ic:0.00007907, loss_rh:0.00017019,loss_con:0.00000535
# epoch 1 loss_pde:0.00310663, loss_ic:0.00007905, loss_rh:0.00017022,loss_con:0.00000534
# epoch 1 loss_pde:0.00308923, loss_ic:0.00007903, loss_rh:0.00017025,loss_con:0.00000533
# epoch 1 loss_pde:0.00307326, loss_ic:0.00007901, loss_rh:0.00017027,loss_con:0.00000531
# epoch 1 loss_pde:0.00305857, loss_ic:0.00007900, loss_rh:0.00017029,loss_con:0.00000530
# epoch 1 loss_pde:0.00304503, loss_ic:0.00007898, loss_rh:0.00017031,loss_con:0.00000528
# epoch 1 loss_pde:0.00303251, loss_ic:0.00007898, loss_rh:0.00017033,loss_con:0.00000527
# epoch 1 loss_pde:0.00302093, loss_ic:0.00007897, loss_rh:0.00017034,loss_con:0.00000525
# epoch 1 loss_pde:0.00301021, loss_ic:0.00007897, loss_rh:0.00017035,loss_con:0.00000523
# epoch 1 loss_pde:0.00300029, loss_ic:0.00007898, loss_rh:0.00017035,loss_con:0.00000521
# epoch 1 loss_pde:0.00299108, loss_ic:0.00007898, loss_rh:0.00017035,loss_con:0.00000518
# epoch 1 loss_pde:0.00298256, loss_ic:0.00007900, loss_rh:0.00017034,loss_con:0.00000516
# loss_tot:0.00747306
# epoch 2 loss_pde:0.00297473, loss_ic:0.00007901, loss_rh:0.00017032,loss_con:0.00000514
# epoch 2 loss_pde:0.00296763, loss_ic:0.00007903, loss_rh:0.00017031,loss_con:0.00000511
# epoch 2 loss_pde:0.00295391, loss_ic:0.00007904, loss_rh:0.00017038,loss_con:0.00000505
# epoch 2 loss_pde:0.00295025, loss_ic:0.00007905, loss_rh:0.00017036,loss_con:0.00000504
# epoch 2 loss_pde:0.00294627, loss_ic:0.00007907, loss_rh:0.00017033,loss_con:0.00000502
# epoch 2 loss_pde:0.00294333, loss_ic:0.00007909, loss_rh:0.00017030,loss_con:0.00000500
# epoch 2 loss_pde:0.00294099, loss_ic:0.00007911, loss_rh:0.00017027,loss_con:0.00000499
# epoch 2 loss_pde:0.00293887, loss_ic:0.00007913, loss_rh:0.00017025,loss_con:0.00000498
# epoch 2 loss_pde:0.00293683, loss_ic:0.00007915, loss_rh:0.00017022,loss_con:0.00000497
# epoch 2 loss_pde:0.00293507, loss_ic:0.00007916, loss_rh:0.00017019,loss_con:0.00000496
# epoch 2 loss_pde:0.00293313, loss_ic:0.00007918, loss_rh:0.00017016,loss_con:0.00000495
# epoch 2 loss_pde:0.00293172, loss_ic:0.00007919, loss_rh:0.00017014,loss_con:0.00000495
# epoch 2 loss_pde:0.00293018, loss_ic:0.00007920, loss_rh:0.00017013,loss_con:0.00000494
# epoch 2 loss_pde:0.00292920, loss_ic:0.00007921, loss_rh:0.00017012,loss_con:0.00000494
# epoch 2 loss_pde:0.00292767, loss_ic:0.00007923, loss_rh:0.00017010,loss_con:0.00000494
# epoch 2 loss_pde:0.00292703, loss_ic:0.00007924, loss_rh:0.00017009,loss_con:0.00000493
# epoch 2 loss_pde:0.00292634, loss_ic:0.00007924, loss_rh:0.00017008,loss_con:0.00000494
# epoch 2 loss_pde:0.00292568, loss_ic:0.00007924, loss_rh:0.00017007,loss_con:0.00000494
# epoch 2 loss_pde:0.00292498, loss_ic:0.00007924, loss_rh:0.00017006,loss_con:0.00000494
# epoch 2 loss_pde:0.00292433, loss_ic:0.00007924, loss_rh:0.00017006,loss_con:0.00000495
# epoch 2 loss_pde:0.00292360, loss_ic:0.00007923, loss_rh:0.00017006,loss_con:0.00000496
# epoch 2 loss_pde:0.00292298, loss_ic:0.00007921, loss_rh:0.00017006,loss_con:0.00000497
# epoch 2 loss_pde:0.00292237, loss_ic:0.00007920, loss_rh:0.00017006,loss_con:0.00000499
# epoch 2 loss_pde:0.00292188, loss_ic:0.00007918, loss_rh:0.00017007,loss_con:0.00000500
# epoch 2 loss_pde:0.00292140, loss_ic:0.00007916, loss_rh:0.00017007,loss_con:0.00000501
# epoch 2 loss_pde:0.00292100, loss_ic:0.00007914, loss_rh:0.00017008,loss_con:0.00000503
# epoch 2 loss_pde:0.00292066, loss_ic:0.00007912, loss_rh:0.00017009,loss_con:0.00000504
# epoch 2 loss_pde:0.00292041, loss_ic:0.00007910, loss_rh:0.00017009,loss_con:0.00000505
# epoch 2 loss_pde:0.00292018, loss_ic:0.00007908, loss_rh:0.00017010,loss_con:0.00000507
# epoch 2 loss_pde:0.00291991, loss_ic:0.00007905, loss_rh:0.00017011,loss_con:0.00000508
# loss_tot:0.00571219
# epoch 3 loss_pde:0.00291972, loss_ic:0.00007903, loss_rh:0.00017013,loss_con:0.00000509
# epoch 3 loss_pde:0.00291954, loss_ic:0.00007901, loss_rh:0.00017014,loss_con:0.00000511
# epoch 3 loss_pde:0.00291940, loss_ic:0.00007899, loss_rh:0.00017015,loss_con:0.00000512
# epoch 3 loss_pde:0.00291928, loss_ic:0.00007897, loss_rh:0.00017016,loss_con:0.00000513
# epoch 3 loss_pde:0.00291918, loss_ic:0.00007895, loss_rh:0.00017017,loss_con:0.00000514
# epoch 3 loss_pde:0.00291906, loss_ic:0.00007892, loss_rh:0.00017018,loss_con:0.00000515
# epoch 3 loss_pde:0.00291900, loss_ic:0.00007890, loss_rh:0.00017019,loss_con:0.00000516
# epoch 3 loss_pde:0.00291894, loss_ic:0.00007889, loss_rh:0.00017020,loss_con:0.00000516
# epoch 3 loss_pde:0.00291887, loss_ic:0.00007887, loss_rh:0.00017021,loss_con:0.00000517
# epoch 3 loss_pde:0.00291882, loss_ic:0.00007885, loss_rh:0.00017022,loss_con:0.00000518
# epoch 3 loss_pde:0.00291877, loss_ic:0.00007883, loss_rh:0.00017023,loss_con:0.00000518
# epoch 3 loss_pde:0.00291871, loss_ic:0.00007881, loss_rh:0.00017024,loss_con:0.00000519
# epoch 3 loss_pde:0.00291867, loss_ic:0.00007880, loss_rh:0.00017025,loss_con:0.00000519
# epoch 3 loss_pde:0.00291860, loss_ic:0.00007878, loss_rh:0.00017026,loss_con:0.00000520
# epoch 3 loss_pde:0.00291853, loss_ic:0.00007876, loss_rh:0.00017028,loss_con:0.00000520
# epoch 3 loss_pde:0.00291850, loss_ic:0.00007874, loss_rh:0.00017029,loss_con:0.00000521
# epoch 3 loss_pde:0.00291854, loss_ic:0.00007873, loss_rh:0.00017030,loss_con:0.00000520
# epoch 3 loss_pde:0.00291850, loss_ic:0.00007871, loss_rh:0.00017031,loss_con:0.00000520
# epoch 3 loss_pde:0.00291847, loss_ic:0.00007869, loss_rh:0.00017032,loss_con:0.00000520
# epoch 3 loss_pde:0.00291844, loss_ic:0.00007868, loss_rh:0.00017033,loss_con:0.00000520
# epoch 3 loss_pde:0.00291837, loss_ic:0.00007867, loss_rh:0.00017034,loss_con:0.00000521
# epoch 3 loss_pde:0.00291834, loss_ic:0.00007865, loss_rh:0.00017035,loss_con:0.00000521
# epoch 3 loss_pde:0.00291830, loss_ic:0.00007864, loss_rh:0.00017036,loss_con:0.00000521
# epoch 3 loss_pde:0.00291828, loss_ic:0.00007862, loss_rh:0.00017037,loss_con:0.00000521
# epoch 3 loss_pde:0.00291810, loss_ic:0.00007861, loss_rh:0.00017038,loss_con:0.00000522
# epoch 3 loss_pde:0.00291808, loss_ic:0.00007860, loss_rh:0.00017039,loss_con:0.00000522
# epoch 3 loss_pde:0.00291797, loss_ic:0.00007859, loss_rh:0.00017040,loss_con:0.00000523
# epoch 3 loss_pde:0.00291793, loss_ic:0.00007858, loss_rh:0.00017041,loss_con:0.00000523
# epoch 3 loss_pde:0.00291792, loss_ic:0.00007856, loss_rh:0.00017042,loss_con:0.00000523
# epoch 3 loss_pde:0.00291789, loss_ic:0.00007855, loss_rh:0.00017044,loss_con:0.00000522
# loss_tot:0.00565330
# epoch 4 loss_pde:0.00291786, loss_ic:0.00007853, loss_rh:0.00017045,loss_con:0.00000522
# epoch 4 loss_pde:0.00291785, loss_ic:0.00007852, loss_rh:0.00017046,loss_con:0.00000522
# epoch 4 loss_pde:0.00291783, loss_ic:0.00007851, loss_rh:0.00017047,loss_con:0.00000522
# epoch 4 loss_pde:0.00291777, loss_ic:0.00007850, loss_rh:0.00017048,loss_con:0.00000522
# epoch 4 loss_pde:0.00291773, loss_ic:0.00007849, loss_rh:0.00017049,loss_con:0.00000522
# epoch 4 loss_pde:0.00291769, loss_ic:0.00007848, loss_rh:0.00017050,loss_con:0.00000521
# epoch 4 loss_pde:0.00291765, loss_ic:0.00007847, loss_rh:0.00017050,loss_con:0.00000521
# epoch 4 loss_pde:0.00291761, loss_ic:0.00007847, loss_rh:0.00017051,loss_con:0.00000521
# epoch 4 loss_pde:0.00291757, loss_ic:0.00007846, loss_rh:0.00017052,loss_con:0.00000521
# epoch 4 loss_pde:0.00291754, loss_ic:0.00007846, loss_rh:0.00017052,loss_con:0.00000521
# epoch 4 loss_pde:0.00291781, loss_ic:0.00007845, loss_rh:0.00017053,loss_con:0.00000517
# epoch 4 loss_pde:0.00291780, loss_ic:0.00007845, loss_rh:0.00017054,loss_con:0.00000517
# epoch 4 loss_pde:0.00291777, loss_ic:0.00007844, loss_rh:0.00017054,loss_con:0.00000517
# epoch 4 loss_pde:0.00291773, loss_ic:0.00007844, loss_rh:0.00017054,loss_con:0.00000517
# epoch 4 loss_pde:0.00291770, loss_ic:0.00007844, loss_rh:0.00017055,loss_con:0.00000517
# epoch 4 loss_pde:0.00291766, loss_ic:0.00007844, loss_rh:0.00017055,loss_con:0.00000518
# epoch 4 loss_pde:0.00291762, loss_ic:0.00007844, loss_rh:0.00017055,loss_con:0.00000518
# epoch 4 loss_pde:0.00291759, loss_ic:0.00007844, loss_rh:0.00017055,loss_con:0.00000518
# epoch 4 loss_pde:0.00291755, loss_ic:0.00007844, loss_rh:0.00017055,loss_con:0.00000518
# epoch 4 loss_pde:0.00291753, loss_ic:0.00007844, loss_rh:0.00017056,loss_con:0.00000519
# epoch 4 loss_pde:0.00291760, loss_ic:0.00007844, loss_rh:0.00017055,loss_con:0.00000517
# epoch 4 loss_pde:0.00291762, loss_ic:0.00007844, loss_rh:0.00017055,loss_con:0.00000517
# epoch 4 loss_pde:0.00291757, loss_ic:0.00007845, loss_rh:0.00017055,loss_con:0.00000518
# epoch 4 loss_pde:0.00291756, loss_ic:0.00007845, loss_rh:0.00017055,loss_con:0.00000518
# epoch 4 loss_pde:0.00291753, loss_ic:0.00007845, loss_rh:0.00017054,loss_con:0.00000518
# epoch 4 loss_pde:0.00291751, loss_ic:0.00007846, loss_rh:0.00017054,loss_con:0.00000518
# epoch 4 loss_pde:0.00291749, loss_ic:0.00007846, loss_rh:0.00017054,loss_con:0.00000519
# epoch 4 loss_pde:0.00291747, loss_ic:0.00007846, loss_rh:0.00017053,loss_con:0.00000519
# epoch 4 loss_pde:0.00291745, loss_ic:0.00007847, loss_rh:0.00017053,loss_con:0.00000520
# epoch 4 loss_pde:0.00291743, loss_ic:0.00007847, loss_rh:0.00017052,loss_con:0.00000520
# loss_tot:0.00565053
# epoch 5 loss_pde:0.00291742, loss_ic:0.00007848, loss_rh:0.00017052,loss_con:0.00000520
# epoch 5 loss_pde:0.00291741, loss_ic:0.00007848, loss_rh:0.00017051,loss_con:0.00000520
# epoch 5 loss_pde:0.00291740, loss_ic:0.00007849, loss_rh:0.00017051,loss_con:0.00000521
# epoch 5 loss_pde:0.00291737, loss_ic:0.00007849, loss_rh:0.00017050,loss_con:0.00000521
# epoch 5 loss_pde:0.00291735, loss_ic:0.00007850, loss_rh:0.00017050,loss_con:0.00000522
# epoch 5 loss_pde:0.00291732, loss_ic:0.00007850, loss_rh:0.00017049,loss_con:0.00000522
# epoch 5 loss_pde:0.00291730, loss_ic:0.00007850, loss_rh:0.00017049,loss_con:0.00000523
# epoch 5 loss_pde:0.00291729, loss_ic:0.00007851, loss_rh:0.00017048,loss_con:0.00000523
# epoch 5 loss_pde:0.00291727, loss_ic:0.00007851, loss_rh:0.00017048,loss_con:0.00000524
# epoch 5 loss_pde:0.00291726, loss_ic:0.00007851, loss_rh:0.00017047,loss_con:0.00000524
# epoch 5 loss_pde:0.00291725, loss_ic:0.00007851, loss_rh:0.00017047,loss_con:0.00000524
# epoch 5 loss_pde:0.00291716, loss_ic:0.00007852, loss_rh:0.00017046,loss_con:0.00000525
# epoch 5 loss_pde:0.00291712, loss_ic:0.00007852, loss_rh:0.00017046,loss_con:0.00000526
# epoch 5 loss_pde:0.00291709, loss_ic:0.00007852, loss_rh:0.00017045,loss_con:0.00000527
# epoch 5 loss_pde:0.00291705, loss_ic:0.00007852, loss_rh:0.00017045,loss_con:0.00000527
# epoch 5 loss_pde:0.00291700, loss_ic:0.00007852, loss_rh:0.00017044,loss_con:0.00000528
# epoch 5 loss_pde:0.00291697, loss_ic:0.00007852, loss_rh:0.00017044,loss_con:0.00000528
# epoch 5 loss_pde:0.00291692, loss_ic:0.00007852, loss_rh:0.00017043,loss_con:0.00000529
# epoch 5 loss_pde:0.00291702, loss_ic:0.00007852, loss_rh:0.00017043,loss_con:0.00000528
# epoch 5 loss_pde:0.00291698, loss_ic:0.00007852, loss_rh:0.00017042,loss_con:0.00000529
# epoch 5 loss_pde:0.00291686, loss_ic:0.00007852, loss_rh:0.00017042,loss_con:0.00000530
# epoch 5 loss_pde:0.00291682, loss_ic:0.00007851, loss_rh:0.00017042,loss_con:0.00000531
# epoch 5 loss_pde:0.00291675, loss_ic:0.00007851, loss_rh:0.00017042,loss_con:0.00000531
# epoch 5 loss_pde:0.00291671, loss_ic:0.00007850, loss_rh:0.00017042,loss_con:0.00000532
# epoch 5 loss_pde:0.00291665, loss_ic:0.00007850, loss_rh:0.00017042,loss_con:0.00000532
# epoch 5 loss_pde:0.00291661, loss_ic:0.00007849, loss_rh:0.00017042,loss_con:0.00000533
# epoch 5 loss_pde:0.00291656, loss_ic:0.00007849, loss_rh:0.00017042,loss_con:0.00000533
# epoch 5 loss_pde:0.00291651, loss_ic:0.00007848, loss_rh:0.00017042,loss_con:0.00000533
# epoch 5 loss_pde:0.00291646, loss_ic:0.00007848, loss_rh:0.00017042,loss_con:0.00000533
# epoch 5 loss_pde:0.00291641, loss_ic:0.00007847, loss_rh:0.00017043,loss_con:0.00000533
# loss_tot:0.00564892
# epoch 6 loss_pde:0.00291637, loss_ic:0.00007847, loss_rh:0.00017043,loss_con:0.00000533
# epoch 6 loss_pde:0.00291626, loss_ic:0.00007847, loss_rh:0.00017043,loss_con:0.00000534
# epoch 6 loss_pde:0.00291623, loss_ic:0.00007846, loss_rh:0.00017043,loss_con:0.00000534
# epoch 6 loss_pde:0.00291620, loss_ic:0.00007846, loss_rh:0.00017043,loss_con:0.00000534
# epoch 6 loss_pde:0.00291616, loss_ic:0.00007846, loss_rh:0.00017043,loss_con:0.00000533
# epoch 6 loss_pde:0.00291612, loss_ic:0.00007845, loss_rh:0.00017044,loss_con:0.00000533
# epoch 6 loss_pde:0.00291608, loss_ic:0.00007845, loss_rh:0.00017044,loss_con:0.00000533
# epoch 6 loss_pde:0.00291603, loss_ic:0.00007845, loss_rh:0.00017044,loss_con:0.00000532
# epoch 6 loss_pde:0.00291599, loss_ic:0.00007845, loss_rh:0.00017044,loss_con:0.00000532
# epoch 6 loss_pde:0.00291594, loss_ic:0.00007845, loss_rh:0.00017044,loss_con:0.00000531
# epoch 6 loss_pde:0.00291588, loss_ic:0.00007845, loss_rh:0.00017044,loss_con:0.00000531
# epoch 6 loss_pde:0.00291587, loss_ic:0.00007845, loss_rh:0.00017044,loss_con:0.00000530
# epoch 6 loss_pde:0.00291581, loss_ic:0.00007845, loss_rh:0.00017044,loss_con:0.00000529
# epoch 6 loss_pde:0.00291577, loss_ic:0.00007846, loss_rh:0.00017044,loss_con:0.00000528
# epoch 6 loss_pde:0.00291572, loss_ic:0.00007846, loss_rh:0.00017044,loss_con:0.00000527
# epoch 6 loss_pde:0.00291566, loss_ic:0.00007847, loss_rh:0.00017044,loss_con:0.00000527
# epoch 6 loss_pde:0.00291562, loss_ic:0.00007847, loss_rh:0.00017044,loss_con:0.00000526
# epoch 6 loss_pde:0.00291558, loss_ic:0.00007847, loss_rh:0.00017044,loss_con:0.00000525
# epoch 6 loss_pde:0.00291552, loss_ic:0.00007848, loss_rh:0.00017043,loss_con:0.00000525
# epoch 6 loss_pde:0.00291549, loss_ic:0.00007848, loss_rh:0.00017043,loss_con:0.00000524
# epoch 6 loss_pde:0.00291542, loss_ic:0.00007849, loss_rh:0.00017043,loss_con:0.00000523
# epoch 6 loss_pde:0.00291538, loss_ic:0.00007850, loss_rh:0.00017042,loss_con:0.00000522
# epoch 6 loss_pde:0.00291532, loss_ic:0.00007850, loss_rh:0.00017042,loss_con:0.00000522
# epoch 6 loss_pde:0.00291528, loss_ic:0.00007851, loss_rh:0.00017042,loss_con:0.00000521
# epoch 6 loss_pde:0.00291521, loss_ic:0.00007852, loss_rh:0.00017040,loss_con:0.00000521
# epoch 6 loss_pde:0.00291519, loss_ic:0.00007853, loss_rh:0.00017040,loss_con:0.00000521
# epoch 6 loss_pde:0.00291516, loss_ic:0.00007853, loss_rh:0.00017040,loss_con:0.00000520
# epoch 6 loss_pde:0.00291514, loss_ic:0.00007854, loss_rh:0.00017039,loss_con:0.00000519
# epoch 6 loss_pde:0.00291512, loss_ic:0.00007854, loss_rh:0.00017039,loss_con:0.00000519
# epoch 6 loss_pde:0.00291511, loss_ic:0.00007855, loss_rh:0.00017038,loss_con:0.00000518
# loss_tot:0.00564698
# epoch 7 loss_pde:0.00291509, loss_ic:0.00007855, loss_rh:0.00017038,loss_con:0.00000518
# epoch 7 loss_pde:0.00291507, loss_ic:0.00007855, loss_rh:0.00017038,loss_con:0.00000518
# epoch 7 loss_pde:0.00291505, loss_ic:0.00007856, loss_rh:0.00017037,loss_con:0.00000518
# epoch 7 loss_pde:0.00291517, loss_ic:0.00007855, loss_rh:0.00017037,loss_con:0.00000516
# epoch 7 loss_pde:0.00291515, loss_ic:0.00007855, loss_rh:0.00017037,loss_con:0.00000516
# epoch 7 loss_pde:0.00291510, loss_ic:0.00007855, loss_rh:0.00017037,loss_con:0.00000517
# epoch 7 loss_pde:0.00291515, loss_ic:0.00007855, loss_rh:0.00017037,loss_con:0.00000516
# epoch 7 loss_pde:0.00291513, loss_ic:0.00007855, loss_rh:0.00017036,loss_con:0.00000516
# epoch 7 loss_pde:0.00291512, loss_ic:0.00007854, loss_rh:0.00017036,loss_con:0.00000517
# epoch 7 loss_pde:0.00291529, loss_ic:0.00007853, loss_rh:0.00017037,loss_con:0.00000516
# epoch 7 loss_pde:0.00291527, loss_ic:0.00007852, loss_rh:0.00017037,loss_con:0.00000516
# epoch 7 loss_pde:0.00291524, loss_ic:0.00007852, loss_rh:0.00017037,loss_con:0.00000517
# epoch 7 loss_pde:0.00291522, loss_ic:0.00007851, loss_rh:0.00017037,loss_con:0.00000518
# epoch 7 loss_pde:0.00291520, loss_ic:0.00007851, loss_rh:0.00017037,loss_con:0.00000518
# epoch 7 loss_pde:0.00291519, loss_ic:0.00007850, loss_rh:0.00017037,loss_con:0.00000519
# epoch 7 loss_pde:0.00291515, loss_ic:0.00007849, loss_rh:0.00017038,loss_con:0.00000519
# epoch 7 loss_pde:0.00291514, loss_ic:0.00007849, loss_rh:0.00017038,loss_con:0.00000520
# epoch 7 loss_pde:0.00291510, loss_ic:0.00007846, loss_rh:0.00017039,loss_con:0.00000521
# epoch 7 loss_pde:0.00291507, loss_ic:0.00007845, loss_rh:0.00017039,loss_con:0.00000522
# epoch 7 loss_pde:0.00291507, loss_ic:0.00007844, loss_rh:0.00017040,loss_con:0.00000523
# epoch 7 loss_pde:0.00291502, loss_ic:0.00007843, loss_rh:0.00017041,loss_con:0.00000524
# epoch 7 loss_pde:0.00291535, loss_ic:0.00007841, loss_rh:0.00017042,loss_con:0.00000521
# epoch 7 loss_pde:0.00291527, loss_ic:0.00007839, loss_rh:0.00017042,loss_con:0.00000522
# epoch 7 loss_pde:0.00291520, loss_ic:0.00007838, loss_rh:0.00017043,loss_con:0.00000523
# epoch 7 loss_pde:0.00291513, loss_ic:0.00007837, loss_rh:0.00017044,loss_con:0.00000524
# epoch 7 loss_pde:0.00291506, loss_ic:0.00007836, loss_rh:0.00017044,loss_con:0.00000525
# epoch 7 loss_pde:0.00291498, loss_ic:0.00007835, loss_rh:0.00017045,loss_con:0.00000526
# epoch 7 loss_pde:0.00291489, loss_ic:0.00007834, loss_rh:0.00017046,loss_con:0.00000527
# epoch 7 loss_pde:0.00291481, loss_ic:0.00007832, loss_rh:0.00017047,loss_con:0.00000528
# epoch 7 loss_pde:0.00291472, loss_ic:0.00007831, loss_rh:0.00017047,loss_con:0.00000529
# loss_tot:0.00564528
# epoch 8 loss_pde:0.00291463, loss_ic:0.00007830, loss_rh:0.00017048,loss_con:0.00000530
# epoch 8 loss_pde:0.00291455, loss_ic:0.00007829, loss_rh:0.00017049,loss_con:0.00000531
# epoch 8 loss_pde:0.00291438, loss_ic:0.00007828, loss_rh:0.00017050,loss_con:0.00000532
# epoch 8 loss_pde:0.00291429, loss_ic:0.00007826, loss_rh:0.00017052,loss_con:0.00000532
# epoch 8 loss_pde:0.00291423, loss_ic:0.00007825, loss_rh:0.00017052,loss_con:0.00000533
# epoch 8 loss_pde:0.00291416, loss_ic:0.00007824, loss_rh:0.00017053,loss_con:0.00000533
# epoch 8 loss_pde:0.00291412, loss_ic:0.00007824, loss_rh:0.00017053,loss_con:0.00000534
# epoch 8 loss_pde:0.00291410, loss_ic:0.00007824, loss_rh:0.00017054,loss_con:0.00000533
# epoch 8 loss_pde:0.00291406, loss_ic:0.00007823, loss_rh:0.00017054,loss_con:0.00000533
# epoch 8 loss_pde:0.00291395, loss_ic:0.00007823, loss_rh:0.00017054,loss_con:0.00000533
# epoch 8 loss_pde:0.00291388, loss_ic:0.00007823, loss_rh:0.00017054,loss_con:0.00000533
# epoch 8 loss_pde:0.00291381, loss_ic:0.00007823, loss_rh:0.00017054,loss_con:0.00000533
# epoch 8 loss_pde:0.00291375, loss_ic:0.00007824, loss_rh:0.00017054,loss_con:0.00000532
# epoch 8 loss_pde:0.00291370, loss_ic:0.00007824, loss_rh:0.00017054,loss_con:0.00000532
# epoch 8 loss_pde:0.00291364, loss_ic:0.00007825, loss_rh:0.00017054,loss_con:0.00000532
# epoch 8 loss_pde:0.00291359, loss_ic:0.00007826, loss_rh:0.00017053,loss_con:0.00000531
# epoch 8 loss_pde:0.00291351, loss_ic:0.00007827, loss_rh:0.00017053,loss_con:0.00000531
# epoch 8 loss_pde:0.00291344, loss_ic:0.00007828, loss_rh:0.00017052,loss_con:0.00000530
# epoch 8 loss_pde:0.00291336, loss_ic:0.00007829, loss_rh:0.00017051,loss_con:0.00000530
# epoch 8 loss_pde:0.00291330, loss_ic:0.00007830, loss_rh:0.00017051,loss_con:0.00000529
# epoch 8 loss_pde:0.00291326, loss_ic:0.00007832, loss_rh:0.00017050,loss_con:0.00000529
# epoch 8 loss_pde:0.00291321, loss_ic:0.00007833, loss_rh:0.00017049,loss_con:0.00000528
# epoch 8 loss_pde:0.00291312, loss_ic:0.00007834, loss_rh:0.00017048,loss_con:0.00000528
# epoch 8 loss_pde:0.00291307, loss_ic:0.00007835, loss_rh:0.00017048,loss_con:0.00000527
# epoch 8 loss_pde:0.00291301, loss_ic:0.00007836, loss_rh:0.00017047,loss_con:0.00000527
# epoch 8 loss_pde:0.00291298, loss_ic:0.00007837, loss_rh:0.00017046,loss_con:0.00000526
# epoch 8 loss_pde:0.00291296, loss_ic:0.00007839, loss_rh:0.00017045,loss_con:0.00000525
# epoch 8 loss_pde:0.00291293, loss_ic:0.00007840, loss_rh:0.00017044,loss_con:0.00000524
# epoch 8 loss_pde:0.00291286, loss_ic:0.00007843, loss_rh:0.00017043,loss_con:0.00000523
# epoch 8 loss_pde:0.00291282, loss_ic:0.00007844, loss_rh:0.00017042,loss_con:0.00000523
# loss_tot:0.00564375
# epoch 9 loss_pde:0.00291277, loss_ic:0.00007845, loss_rh:0.00017041,loss_con:0.00000522
# epoch 9 loss_pde:0.00291271, loss_ic:0.00007847, loss_rh:0.00017041,loss_con:0.00000521
# epoch 9 loss_pde:0.00291266, loss_ic:0.00007848, loss_rh:0.00017040,loss_con:0.00000520
# epoch 9 loss_pde:0.00291263, loss_ic:0.00007849, loss_rh:0.00017039,loss_con:0.00000520
# epoch 9 loss_pde:0.00291250, loss_ic:0.00007850, loss_rh:0.00017039,loss_con:0.00000520
# epoch 9 loss_pde:0.00291245, loss_ic:0.00007851, loss_rh:0.00017038,loss_con:0.00000519
# epoch 9 loss_pde:0.00291237, loss_ic:0.00007852, loss_rh:0.00017038,loss_con:0.00000518
# epoch 9 loss_pde:0.00291230, loss_ic:0.00007853, loss_rh:0.00017037,loss_con:0.00000517
# epoch 9 loss_pde:0.00291226, loss_ic:0.00007854, loss_rh:0.00017037,loss_con:0.00000517
# epoch 9 loss_pde:0.00291221, loss_ic:0.00007854, loss_rh:0.00017037,loss_con:0.00000516
# epoch 9 loss_pde:0.00291202, loss_ic:0.00007854, loss_rh:0.00017037,loss_con:0.00000517
# epoch 9 loss_pde:0.00291195, loss_ic:0.00007854, loss_rh:0.00017037,loss_con:0.00000516
# epoch 9 loss_pde:0.00291191, loss_ic:0.00007855, loss_rh:0.00017037,loss_con:0.00000516
# epoch 9 loss_pde:0.00291185, loss_ic:0.00007856, loss_rh:0.00017037,loss_con:0.00000516
# epoch 9 loss_pde:0.00291181, loss_ic:0.00007855, loss_rh:0.00017037,loss_con:0.00000515
# epoch 9 loss_pde:0.00291176, loss_ic:0.00007855, loss_rh:0.00017038,loss_con:0.00000515
# epoch 9 loss_pde:0.00291170, loss_ic:0.00007854, loss_rh:0.00017038,loss_con:0.00000515
# epoch 9 loss_pde:0.00291166, loss_ic:0.00007854, loss_rh:0.00017039,loss_con:0.00000515
# epoch 9 loss_pde:0.00291158, loss_ic:0.00007853, loss_rh:0.00017039,loss_con:0.00000515
# epoch 9 loss_pde:0.00291155, loss_ic:0.00007852, loss_rh:0.00017040,loss_con:0.00000515
# epoch 9 loss_pde:0.00291146, loss_ic:0.00007851, loss_rh:0.00017041,loss_con:0.00000515
# epoch 9 loss_pde:0.00291142, loss_ic:0.00007850, loss_rh:0.00017042,loss_con:0.00000516
# epoch 9 loss_pde:0.00291139, loss_ic:0.00007848, loss_rh:0.00017043,loss_con:0.00000516
# epoch 9 loss_pde:0.00291136, loss_ic:0.00007847, loss_rh:0.00017044,loss_con:0.00000516
# epoch 9 loss_pde:0.00291134, loss_ic:0.00007846, loss_rh:0.00017045,loss_con:0.00000516
# epoch 9 loss_pde:0.00291132, loss_ic:0.00007845, loss_rh:0.00017046,loss_con:0.00000516
# epoch 9 loss_pde:0.00291130, loss_ic:0.00007844, loss_rh:0.00017046,loss_con:0.00000516
# epoch 9 loss_pde:0.00291128, loss_ic:0.00007843, loss_rh:0.00017047,loss_con:0.00000517
# epoch 9 loss_pde:0.00291127, loss_ic:0.00007842, loss_rh:0.00017048,loss_con:0.00000517
# epoch 9 loss_pde:0.00291125, loss_ic:0.00007841, loss_rh:0.00017048,loss_con:0.00000517
# loss_tot:0.00564224
# epoch 10 loss_pde:0.00291123, loss_ic:0.00007840, loss_rh:0.00017049,loss_con:0.00000517
# epoch 10 loss_pde:0.00291121, loss_ic:0.00007839, loss_rh:0.00017050,loss_con:0.00000518
# epoch 10 loss_pde:0.00291120, loss_ic:0.00007838, loss_rh:0.00017050,loss_con:0.00000518
# epoch 10 loss_pde:0.00291116, loss_ic:0.00007837, loss_rh:0.00017051,loss_con:0.00000518
# epoch 10 loss_pde:0.00291114, loss_ic:0.00007836, loss_rh:0.00017052,loss_con:0.00000518
# epoch 10 loss_pde:0.00291111, loss_ic:0.00007835, loss_rh:0.00017052,loss_con:0.00000519
# epoch 10 loss_pde:0.00291108, loss_ic:0.00007835, loss_rh:0.00017053,loss_con:0.00000519
# epoch 10 loss_pde:0.00291101, loss_ic:0.00007834, loss_rh:0.00017054,loss_con:0.00000519
# epoch 10 loss_pde:0.00291100, loss_ic:0.00007833, loss_rh:0.00017054,loss_con:0.00000519
# epoch 10 loss_pde:0.00291095, loss_ic:0.00007833, loss_rh:0.00017054,loss_con:0.00000520
# epoch 10 loss_pde:0.00291092, loss_ic:0.00007832, loss_rh:0.00017055,loss_con:0.00000519
# epoch 10 loss_pde:0.00291084, loss_ic:0.00007832, loss_rh:0.00017055,loss_con:0.00000520
# epoch 10 loss_pde:0.00291078, loss_ic:0.00007832, loss_rh:0.00017055,loss_con:0.00000520
# epoch 10 loss_pde:0.00291073, loss_ic:0.00007832, loss_rh:0.00017056,loss_con:0.00000520
# epoch 10 loss_pde:0.00291120, loss_ic:0.00007829, loss_rh:0.00017058,loss_con:0.00000517
# epoch 10 loss_pde:0.00291109, loss_ic:0.00007829, loss_rh:0.00017057,loss_con:0.00000518
# epoch 10 loss_pde:0.00291097, loss_ic:0.00007830, loss_rh:0.00017057,loss_con:0.00000518
# epoch 10 loss_pde:0.00291083, loss_ic:0.00007831, loss_rh:0.00017057,loss_con:0.00000518
# epoch 10 loss_pde:0.00291071, loss_ic:0.00007832, loss_rh:0.00017056,loss_con:0.00000519
# epoch 10 loss_pde:0.00291055, loss_ic:0.00007833, loss_rh:0.00017056,loss_con:0.00000519
# epoch 10 loss_pde:0.00291043, loss_ic:0.00007834, loss_rh:0.00017055,loss_con:0.00000520
# epoch 10 loss_pde:0.00291033, loss_ic:0.00007835, loss_rh:0.00017055,loss_con:0.00000520
# epoch 10 loss_pde:0.00291015, loss_ic:0.00007836, loss_rh:0.00017054,loss_con:0.00000521
# epoch 10 loss_pde:0.00291006, loss_ic:0.00007837, loss_rh:0.00017054,loss_con:0.00000521
# epoch 10 loss_pde:0.00290996, loss_ic:0.00007838, loss_rh:0.00017053,loss_con:0.00000521
# epoch 10 loss_pde:0.00290991, loss_ic:0.00007840, loss_rh:0.00017053,loss_con:0.00000521
# epoch 10 loss_pde:0.00290977, loss_ic:0.00007841, loss_rh:0.00017052,loss_con:0.00000521
# epoch 10 loss_pde:0.00290968, loss_ic:0.00007843, loss_rh:0.00017051,loss_con:0.00000521
# epoch 10 loss_pde:0.00290960, loss_ic:0.00007844, loss_rh:0.00017051,loss_con:0.00000521
# epoch 10 loss_pde:0.00290954, loss_ic:0.00007844, loss_rh:0.00017050,loss_con:0.00000521
# loss_tot:0.00564035
# epoch 11 loss_pde:0.00290946, loss_ic:0.00007846, loss_rh:0.00017049,loss_con:0.00000522
# epoch 11 loss_pde:0.00290938, loss_ic:0.00007846, loss_rh:0.00017049,loss_con:0.00000522
# epoch 11 loss_pde:0.00290939, loss_ic:0.00007847, loss_rh:0.00017048,loss_con:0.00000521
# epoch 11 loss_pde:0.00290931, loss_ic:0.00007848, loss_rh:0.00017048,loss_con:0.00000521
# epoch 11 loss_pde:0.00290925, loss_ic:0.00007849, loss_rh:0.00017048,loss_con:0.00000522
# epoch 11 loss_pde:0.00290919, loss_ic:0.00007850, loss_rh:0.00017047,loss_con:0.00000522
# epoch 11 loss_pde:0.00290901, loss_ic:0.00007851, loss_rh:0.00017047,loss_con:0.00000523
# epoch 11 loss_pde:0.00290894, loss_ic:0.00007851, loss_rh:0.00017046,loss_con:0.00000523
# epoch 11 loss_pde:0.00290892, loss_ic:0.00007852, loss_rh:0.00017046,loss_con:0.00000523
# epoch 11 loss_pde:0.00290885, loss_ic:0.00007852, loss_rh:0.00017046,loss_con:0.00000524
# epoch 11 loss_pde:0.00290876, loss_ic:0.00007852, loss_rh:0.00017046,loss_con:0.00000524
# epoch 11 loss_pde:0.00290870, loss_ic:0.00007852, loss_rh:0.00017046,loss_con:0.00000525
# epoch 11 loss_pde:0.00290863, loss_ic:0.00007852, loss_rh:0.00017046,loss_con:0.00000525
# epoch 11 loss_pde:0.00290858, loss_ic:0.00007851, loss_rh:0.00017046,loss_con:0.00000526
# epoch 11 loss_pde:0.00290878, loss_ic:0.00007853, loss_rh:0.00017046,loss_con:0.00000522
# epoch 11 loss_pde:0.00290873, loss_ic:0.00007853, loss_rh:0.00017046,loss_con:0.00000523
# epoch 11 loss_pde:0.00290863, loss_ic:0.00007852, loss_rh:0.00017047,loss_con:0.00000524
# epoch 11 loss_pde:0.00290881, loss_ic:0.00007850, loss_rh:0.00017047,loss_con:0.00000522
# epoch 11 loss_pde:0.00290873, loss_ic:0.00007849, loss_rh:0.00017048,loss_con:0.00000524
# epoch 11 loss_pde:0.00290870, loss_ic:0.00007848, loss_rh:0.00017048,loss_con:0.00000524
# epoch 11 loss_pde:0.00290869, loss_ic:0.00007847, loss_rh:0.00017048,loss_con:0.00000524
# epoch 11 loss_pde:0.00290867, loss_ic:0.00007847, loss_rh:0.00017049,loss_con:0.00000525
# epoch 11 loss_pde:0.00290866, loss_ic:0.00007846, loss_rh:0.00017049,loss_con:0.00000525
# epoch 11 loss_pde:0.00290865, loss_ic:0.00007845, loss_rh:0.00017050,loss_con:0.00000525
# epoch 11 loss_pde:0.00290865, loss_ic:0.00007845, loss_rh:0.00017050,loss_con:0.00000526
# epoch 11 loss_pde:0.00290865, loss_ic:0.00007844, loss_rh:0.00017050,loss_con:0.00000526
# epoch 11 loss_pde:0.00290864, loss_ic:0.00007843, loss_rh:0.00017051,loss_con:0.00000526
# epoch 11 loss_pde:0.00290868, loss_ic:0.00007841, loss_rh:0.00017052,loss_con:0.00000526
# epoch 11 loss_pde:0.00290868, loss_ic:0.00007840, loss_rh:0.00017052,loss_con:0.00000526
# epoch 11 loss_pde:0.00290867, loss_ic:0.00007840, loss_rh:0.00017053,loss_con:0.00000526
# loss_tot:0.00563894
# epoch 12 loss_pde:0.00290869, loss_ic:0.00007840, loss_rh:0.00017053,loss_con:0.00000526
# epoch 12 loss_pde:0.00290867, loss_ic:0.00007839, loss_rh:0.00017053,loss_con:0.00000526
# epoch 12 loss_pde:0.00290867, loss_ic:0.00007839, loss_rh:0.00017053,loss_con:0.00000527
# epoch 12 loss_pde:0.00290867, loss_ic:0.00007839, loss_rh:0.00017053,loss_con:0.00000526
# epoch 12 loss_pde:0.00290866, loss_ic:0.00007839, loss_rh:0.00017053,loss_con:0.00000526
# epoch 12 loss_pde:0.00290863, loss_ic:0.00007839, loss_rh:0.00017053,loss_con:0.00000526
# epoch 12 loss_pde:0.00290861, loss_ic:0.00007839, loss_rh:0.00017053,loss_con:0.00000526
# epoch 12 loss_pde:0.00290861, loss_ic:0.00007839, loss_rh:0.00017053,loss_con:0.00000526
# epoch 12 loss_pde:0.00290854, loss_ic:0.00007840, loss_rh:0.00017053,loss_con:0.00000526
# epoch 12 loss_pde:0.00290851, loss_ic:0.00007840, loss_rh:0.00017053,loss_con:0.00000526
# epoch 12 loss_pde:0.00290843, loss_ic:0.00007841, loss_rh:0.00017052,loss_con:0.00000526
# epoch 12 loss_pde:0.00290837, loss_ic:0.00007842, loss_rh:0.00017052,loss_con:0.00000525
# epoch 12 loss_pde:0.00290827, loss_ic:0.00007842, loss_rh:0.00017051,loss_con:0.00000525
# epoch 12 loss_pde:0.00290819, loss_ic:0.00007844, loss_rh:0.00017051,loss_con:0.00000525
# epoch 12 loss_pde:0.00290805, loss_ic:0.00007845, loss_rh:0.00017050,loss_con:0.00000525
# epoch 12 loss_pde:0.00290805, loss_ic:0.00007847, loss_rh:0.00017048,loss_con:0.00000523
# epoch 12 loss_pde:0.00290796, loss_ic:0.00007849, loss_rh:0.00017048,loss_con:0.00000523
# epoch 12 loss_pde:0.00290769, loss_ic:0.00007849, loss_rh:0.00017048,loss_con:0.00000524
# epoch 12 loss_pde:0.00290757, loss_ic:0.00007850, loss_rh:0.00017047,loss_con:0.00000524
# epoch 12 loss_pde:0.00290747, loss_ic:0.00007852, loss_rh:0.00017046,loss_con:0.00000523
# epoch 12 loss_pde:0.00290730, loss_ic:0.00007853, loss_rh:0.00017046,loss_con:0.00000523
# epoch 12 loss_pde:0.00290709, loss_ic:0.00007855, loss_rh:0.00017044,loss_con:0.00000524
# epoch 12 loss_pde:0.00290696, loss_ic:0.00007857, loss_rh:0.00017043,loss_con:0.00000524
# epoch 12 loss_pde:0.00290683, loss_ic:0.00007859, loss_rh:0.00017042,loss_con:0.00000524
# epoch 12 loss_pde:0.00290675, loss_ic:0.00007861, loss_rh:0.00017041,loss_con:0.00000523
# epoch 12 loss_pde:0.00290662, loss_ic:0.00007862, loss_rh:0.00017040,loss_con:0.00000523
# epoch 12 loss_pde:0.00290650, loss_ic:0.00007864, loss_rh:0.00017040,loss_con:0.00000522
# epoch 12 loss_pde:0.00290639, loss_ic:0.00007865, loss_rh:0.00017039,loss_con:0.00000522
# epoch 12 loss_pde:0.00290627, loss_ic:0.00007867, loss_rh:0.00017038,loss_con:0.00000522
# epoch 12 loss_pde:0.00290618, loss_ic:0.00007868, loss_rh:0.00017037,loss_con:0.00000522
# loss_tot:0.00563758
# epoch 13 loss_pde:0.00290607, loss_ic:0.00007869, loss_rh:0.00017037,loss_con:0.00000522
# epoch 13 loss_pde:0.00290599, loss_ic:0.00007870, loss_rh:0.00017036,loss_con:0.00000521
# epoch 13 loss_pde:0.00290589, loss_ic:0.00007870, loss_rh:0.00017036,loss_con:0.00000521
# epoch 13 loss_pde:0.00290583, loss_ic:0.00007871, loss_rh:0.00017035,loss_con:0.00000521
# epoch 13 loss_pde:0.00290574, loss_ic:0.00007872, loss_rh:0.00017035,loss_con:0.00000521
# epoch 13 loss_pde:0.00290568, loss_ic:0.00007872, loss_rh:0.00017034,loss_con:0.00000521
# epoch 13 loss_pde:0.00290561, loss_ic:0.00007873, loss_rh:0.00017034,loss_con:0.00000520
# epoch 13 loss_pde:0.00290555, loss_ic:0.00007873, loss_rh:0.00017034,loss_con:0.00000520
# epoch 13 loss_pde:0.00290549, loss_ic:0.00007873, loss_rh:0.00017033,loss_con:0.00000520
# epoch 13 loss_pde:0.00290544, loss_ic:0.00007873, loss_rh:0.00017033,loss_con:0.00000520
# epoch 13 loss_pde:0.00290540, loss_ic:0.00007873, loss_rh:0.00017033,loss_con:0.00000520
# epoch 13 loss_pde:0.00290532, loss_ic:0.00007874, loss_rh:0.00017033,loss_con:0.00000520
# epoch 13 loss_pde:0.00290529, loss_ic:0.00007874, loss_rh:0.00017032,loss_con:0.00000520
# epoch 13 loss_pde:0.00290524, loss_ic:0.00007874, loss_rh:0.00017032,loss_con:0.00000520
# epoch 13 loss_pde:0.00290522, loss_ic:0.00007874, loss_rh:0.00017032,loss_con:0.00000519
# epoch 13 loss_pde:0.00290520, loss_ic:0.00007874, loss_rh:0.00017031,loss_con:0.00000519
# epoch 13 loss_pde:0.00290518, loss_ic:0.00007874, loss_rh:0.00017031,loss_con:0.00000519
# epoch 13 loss_pde:0.00290516, loss_ic:0.00007874, loss_rh:0.00017031,loss_con:0.00000519
# epoch 13 loss_pde:0.00290515, loss_ic:0.00007873, loss_rh:0.00017030,loss_con:0.00000519
# epoch 13 loss_pde:0.00290507, loss_ic:0.00007873, loss_rh:0.00017030,loss_con:0.00000520
# epoch 13 loss_pde:0.00290506, loss_ic:0.00007873, loss_rh:0.00017029,loss_con:0.00000520
# epoch 13 loss_pde:0.00290506, loss_ic:0.00007873, loss_rh:0.00017029,loss_con:0.00000520
# epoch 13 loss_pde:0.00290504, loss_ic:0.00007873, loss_rh:0.00017029,loss_con:0.00000520
# epoch 13 loss_pde:0.00290562, loss_ic:0.00007869, loss_rh:0.00017030,loss_con:0.00000521
# epoch 13 loss_pde:0.00290554, loss_ic:0.00007869, loss_rh:0.00017030,loss_con:0.00000521
# epoch 13 loss_pde:0.00290547, loss_ic:0.00007869, loss_rh:0.00017029,loss_con:0.00000521
# epoch 13 loss_pde:0.00290536, loss_ic:0.00007869, loss_rh:0.00017029,loss_con:0.00000521
# epoch 13 loss_pde:0.00290538, loss_ic:0.00007869, loss_rh:0.00017029,loss_con:0.00000520
# epoch 13 loss_pde:0.00290527, loss_ic:0.00007870, loss_rh:0.00017028,loss_con:0.00000520
# epoch 13 loss_pde:0.00290522, loss_ic:0.00007870, loss_rh:0.00017027,loss_con:0.00000520
# loss_tot:0.00563560
# epoch 14 loss_pde:0.00290521, loss_ic:0.00007870, loss_rh:0.00017027,loss_con:0.00000520
# epoch 14 loss_pde:0.00290518, loss_ic:0.00007871, loss_rh:0.00017027,loss_con:0.00000520
# epoch 14 loss_pde:0.00290517, loss_ic:0.00007871, loss_rh:0.00017026,loss_con:0.00000520
# epoch 14 loss_pde:0.00290520, loss_ic:0.00007871, loss_rh:0.00017026,loss_con:0.00000520
# epoch 14 loss_pde:0.00290517, loss_ic:0.00007871, loss_rh:0.00017025,loss_con:0.00000520
# epoch 14 loss_pde:0.00290516, loss_ic:0.00007872, loss_rh:0.00017025,loss_con:0.00000520
# epoch 14 loss_pde:0.00290515, loss_ic:0.00007872, loss_rh:0.00017025,loss_con:0.00000520
# epoch 14 loss_pde:0.00290514, loss_ic:0.00007872, loss_rh:0.00017024,loss_con:0.00000520
# epoch 14 loss_pde:0.00290512, loss_ic:0.00007872, loss_rh:0.00017024,loss_con:0.00000520
# epoch 14 loss_pde:0.00290508, loss_ic:0.00007873, loss_rh:0.00017023,loss_con:0.00000520
# epoch 14 loss_pde:0.00290507, loss_ic:0.00007873, loss_rh:0.00017023,loss_con:0.00000520
# epoch 14 loss_pde:0.00290508, loss_ic:0.00007873, loss_rh:0.00017023,loss_con:0.00000520
# epoch 14 loss_pde:0.00290501, loss_ic:0.00007874, loss_rh:0.00017022,loss_con:0.00000521
# epoch 14 loss_pde:0.00290500, loss_ic:0.00007875, loss_rh:0.00017022,loss_con:0.00000521
# epoch 14 loss_pde:0.00290499, loss_ic:0.00007875, loss_rh:0.00017022,loss_con:0.00000521
# epoch 14 loss_pde:0.00290499, loss_ic:0.00007876, loss_rh:0.00017021,loss_con:0.00000521
# epoch 14 loss_pde:0.00290443, loss_ic:0.00007879, loss_rh:0.00017019,loss_con:0.00000528
# epoch 14 loss_pde:0.00290446, loss_ic:0.00007880, loss_rh:0.00017019,loss_con:0.00000528
# epoch 14 loss_pde:0.00290449, loss_ic:0.00007880, loss_rh:0.00017019,loss_con:0.00000527
# epoch 14 loss_pde:0.00290451, loss_ic:0.00007880, loss_rh:0.00017018,loss_con:0.00000527
# epoch 14 loss_pde:0.00290453, loss_ic:0.00007881, loss_rh:0.00017018,loss_con:0.00000526
# epoch 14 loss_pde:0.00290458, loss_ic:0.00007881, loss_rh:0.00017018,loss_con:0.00000525
# epoch 14 loss_pde:0.00290461, loss_ic:0.00007882, loss_rh:0.00017017,loss_con:0.00000524
# epoch 14 loss_pde:0.00290464, loss_ic:0.00007882, loss_rh:0.00017017,loss_con:0.00000524
# epoch 14 loss_pde:0.00290466, loss_ic:0.00007883, loss_rh:0.00017016,loss_con:0.00000524
# epoch 14 loss_pde:0.00290468, loss_ic:0.00007883, loss_rh:0.00017016,loss_con:0.00000523
# epoch 14 loss_pde:0.00290469, loss_ic:0.00007884, loss_rh:0.00017016,loss_con:0.00000523
# epoch 14 loss_pde:0.00290469, loss_ic:0.00007884, loss_rh:0.00017015,loss_con:0.00000523
# epoch 14 loss_pde:0.00290470, loss_ic:0.00007885, loss_rh:0.00017015,loss_con:0.00000522
# epoch 14 loss_pde:0.00290469, loss_ic:0.00007886, loss_rh:0.00017014,loss_con:0.00000522
# loss_tot:0.00563366
# epoch 15 loss_pde:0.00290469, loss_ic:0.00007887, loss_rh:0.00017014,loss_con:0.00000522
# epoch 15 loss_pde:0.00290468, loss_ic:0.00007888, loss_rh:0.00017013,loss_con:0.00000522
# epoch 15 loss_pde:0.00290467, loss_ic:0.00007889, loss_rh:0.00017012,loss_con:0.00000522
# epoch 15 loss_pde:0.00290464, loss_ic:0.00007890, loss_rh:0.00017012,loss_con:0.00000522
# epoch 15 loss_pde:0.00290466, loss_ic:0.00007890, loss_rh:0.00017011,loss_con:0.00000521
# epoch 15 loss_pde:0.00290462, loss_ic:0.00007892, loss_rh:0.00017010,loss_con:0.00000522
# epoch 15 loss_pde:0.00290463, loss_ic:0.00007893, loss_rh:0.00017009,loss_con:0.00000521
# epoch 15 loss_pde:0.00290460, loss_ic:0.00007894, loss_rh:0.00017009,loss_con:0.00000521
# epoch 15 loss_pde:0.00290459, loss_ic:0.00007895, loss_rh:0.00017008,loss_con:0.00000521
# epoch 15 loss_pde:0.00290435, loss_ic:0.00007899, loss_rh:0.00017005,loss_con:0.00000524
# epoch 15 loss_pde:0.00290435, loss_ic:0.00007900, loss_rh:0.00017005,loss_con:0.00000524
# epoch 15 loss_pde:0.00290434, loss_ic:0.00007900, loss_rh:0.00017004,loss_con:0.00000524
# epoch 15 loss_pde:0.00290432, loss_ic:0.00007901, loss_rh:0.00017004,loss_con:0.00000523
# epoch 15 loss_pde:0.00290430, loss_ic:0.00007901, loss_rh:0.00017004,loss_con:0.00000523
# epoch 15 loss_pde:0.00290427, loss_ic:0.00007902, loss_rh:0.00017003,loss_con:0.00000523
# epoch 15 loss_pde:0.00290424, loss_ic:0.00007903, loss_rh:0.00017003,loss_con:0.00000523
# epoch 15 loss_pde:0.00290421, loss_ic:0.00007903, loss_rh:0.00017003,loss_con:0.00000523
# epoch 15 loss_pde:0.00290415, loss_ic:0.00007904, loss_rh:0.00017002,loss_con:0.00000523
# epoch 15 loss_pde:0.00290412, loss_ic:0.00007904, loss_rh:0.00017002,loss_con:0.00000524
# epoch 15 loss_pde:0.00290409, loss_ic:0.00007905, loss_rh:0.00017002,loss_con:0.00000524
# epoch 15 loss_pde:0.00290406, loss_ic:0.00007905, loss_rh:0.00017002,loss_con:0.00000524
# epoch 15 loss_pde:0.00290402, loss_ic:0.00007905, loss_rh:0.00017002,loss_con:0.00000524
# epoch 15 loss_pde:0.00290398, loss_ic:0.00007906, loss_rh:0.00017002,loss_con:0.00000524
# epoch 15 loss_pde:0.00290393, loss_ic:0.00007906, loss_rh:0.00017001,loss_con:0.00000524
# epoch 15 loss_pde:0.00290390, loss_ic:0.00007906, loss_rh:0.00017002,loss_con:0.00000525
# epoch 15 loss_pde:0.00290385, loss_ic:0.00007906, loss_rh:0.00017002,loss_con:0.00000525
# epoch 15 loss_pde:0.00290381, loss_ic:0.00007906, loss_rh:0.00017002,loss_con:0.00000525
# epoch 15 loss_pde:0.00290376, loss_ic:0.00007906, loss_rh:0.00017002,loss_con:0.00000525
# epoch 15 loss_pde:0.00290378, loss_ic:0.00007907, loss_rh:0.00017002,loss_con:0.00000524
# epoch 15 loss_pde:0.00290373, loss_ic:0.00007906, loss_rh:0.00017002,loss_con:0.00000525
# loss_tot:0.00563286
# epoch 16 loss_pde:0.00290369, loss_ic:0.00007906, loss_rh:0.00017002,loss_con:0.00000525
# epoch 16 loss_pde:0.00290365, loss_ic:0.00007906, loss_rh:0.00017003,loss_con:0.00000525
# epoch 16 loss_pde:0.00290360, loss_ic:0.00007906, loss_rh:0.00017003,loss_con:0.00000525
# epoch 16 loss_pde:0.00290357, loss_ic:0.00007906, loss_rh:0.00017003,loss_con:0.00000526
# epoch 16 loss_pde:0.00290352, loss_ic:0.00007906, loss_rh:0.00017004,loss_con:0.00000526
# epoch 16 loss_pde:0.00290346, loss_ic:0.00007905, loss_rh:0.00017004,loss_con:0.00000526
# epoch 16 loss_pde:0.00290343, loss_ic:0.00007905, loss_rh:0.00017005,loss_con:0.00000526
# epoch 16 loss_pde:0.00290341, loss_ic:0.00007905, loss_rh:0.00017005,loss_con:0.00000526
# epoch 16 loss_pde:0.00290336, loss_ic:0.00007904, loss_rh:0.00017006,loss_con:0.00000526
# epoch 16 loss_pde:0.00290334, loss_ic:0.00007904, loss_rh:0.00017006,loss_con:0.00000526
# epoch 16 loss_pde:0.00290329, loss_ic:0.00007904, loss_rh:0.00017007,loss_con:0.00000526
# epoch 16 loss_pde:0.00290325, loss_ic:0.00007904, loss_rh:0.00017007,loss_con:0.00000526
# epoch 16 loss_pde:0.00290323, loss_ic:0.00007904, loss_rh:0.00017008,loss_con:0.00000525
# epoch 16 loss_pde:0.00290319, loss_ic:0.00007903, loss_rh:0.00017008,loss_con:0.00000525
# epoch 16 loss_pde:0.00290316, loss_ic:0.00007903, loss_rh:0.00017009,loss_con:0.00000525
# epoch 16 loss_pde:0.00290312, loss_ic:0.00007903, loss_rh:0.00017009,loss_con:0.00000524
# epoch 16 loss_pde:0.00290310, loss_ic:0.00007903, loss_rh:0.00017010,loss_con:0.00000524
# epoch 16 loss_pde:0.00290307, loss_ic:0.00007903, loss_rh:0.00017010,loss_con:0.00000524
# epoch 16 loss_pde:0.00290302, loss_ic:0.00007903, loss_rh:0.00017011,loss_con:0.00000523
# epoch 16 loss_pde:0.00290299, loss_ic:0.00007903, loss_rh:0.00017011,loss_con:0.00000523
# epoch 16 loss_pde:0.00290295, loss_ic:0.00007903, loss_rh:0.00017011,loss_con:0.00000522
# epoch 16 loss_pde:0.00290292, loss_ic:0.00007904, loss_rh:0.00017012,loss_con:0.00000521
# epoch 16 loss_pde:0.00290287, loss_ic:0.00007904, loss_rh:0.00017012,loss_con:0.00000521
# epoch 16 loss_pde:0.00290284, loss_ic:0.00007904, loss_rh:0.00017012,loss_con:0.00000520
# epoch 16 loss_pde:0.00290278, loss_ic:0.00007904, loss_rh:0.00017013,loss_con:0.00000520
# epoch 16 loss_pde:0.00290273, loss_ic:0.00007904, loss_rh:0.00017013,loss_con:0.00000519
# epoch 16 loss_pde:0.00290271, loss_ic:0.00007904, loss_rh:0.00017013,loss_con:0.00000519
# epoch 16 loss_pde:0.00290266, loss_ic:0.00007905, loss_rh:0.00017013,loss_con:0.00000518
# epoch 16 loss_pde:0.00290261, loss_ic:0.00007905, loss_rh:0.00017014,loss_con:0.00000518
# epoch 16 loss_pde:0.00290254, loss_ic:0.00007905, loss_rh:0.00017014,loss_con:0.00000518
# loss_tot:0.00563201
# epoch 17 loss_pde:0.00290245, loss_ic:0.00007905, loss_rh:0.00017014,loss_con:0.00000518
# epoch 17 loss_pde:0.00290239, loss_ic:0.00007905, loss_rh:0.00017014,loss_con:0.00000518
# epoch 17 loss_pde:0.00290233, loss_ic:0.00007905, loss_rh:0.00017014,loss_con:0.00000518
# epoch 17 loss_pde:0.00290223, loss_ic:0.00007904, loss_rh:0.00017015,loss_con:0.00000518
# epoch 17 loss_pde:0.00290219, loss_ic:0.00007904, loss_rh:0.00017015,loss_con:0.00000518
# epoch 17 loss_pde:0.00290211, loss_ic:0.00007904, loss_rh:0.00017016,loss_con:0.00000518
# epoch 17 loss_pde:0.00290208, loss_ic:0.00007902, loss_rh:0.00017016,loss_con:0.00000518
# epoch 17 loss_pde:0.00290201, loss_ic:0.00007902, loss_rh:0.00017016,loss_con:0.00000518
# epoch 17 loss_pde:0.00290197, loss_ic:0.00007902, loss_rh:0.00017017,loss_con:0.00000518
# epoch 17 loss_pde:0.00290186, loss_ic:0.00007901, loss_rh:0.00017017,loss_con:0.00000519
# epoch 17 loss_pde:0.00290184, loss_ic:0.00007900, loss_rh:0.00017017,loss_con:0.00000518
# epoch 17 loss_pde:0.00290169, loss_ic:0.00007900, loss_rh:0.00017018,loss_con:0.00000519
# epoch 17 loss_pde:0.00290163, loss_ic:0.00007899, loss_rh:0.00017018,loss_con:0.00000519
# epoch 17 loss_pde:0.00290156, loss_ic:0.00007898, loss_rh:0.00017019,loss_con:0.00000520
# epoch 17 loss_pde:0.00290148, loss_ic:0.00007898, loss_rh:0.00017019,loss_con:0.00000519
# epoch 17 loss_pde:0.00290138, loss_ic:0.00007897, loss_rh:0.00017019,loss_con:0.00000520
# epoch 17 loss_pde:0.00290130, loss_ic:0.00007896, loss_rh:0.00017020,loss_con:0.00000520
# epoch 17 loss_pde:0.00290115, loss_ic:0.00007895, loss_rh:0.00017020,loss_con:0.00000521
# epoch 17 loss_pde:0.00290107, loss_ic:0.00007894, loss_rh:0.00017021,loss_con:0.00000521
# epoch 17 loss_pde:0.00290081, loss_ic:0.00007894, loss_rh:0.00017021,loss_con:0.00000524
# epoch 17 loss_pde:0.00290073, loss_ic:0.00007893, loss_rh:0.00017022,loss_con:0.00000524
# epoch 17 loss_pde:0.00290064, loss_ic:0.00007891, loss_rh:0.00017022,loss_con:0.00000525
# epoch 17 loss_pde:0.00290056, loss_ic:0.00007890, loss_rh:0.00017022,loss_con:0.00000525
# epoch 17 loss_pde:0.00290049, loss_ic:0.00007890, loss_rh:0.00017023,loss_con:0.00000525
# epoch 17 loss_pde:0.00290030, loss_ic:0.00007890, loss_rh:0.00017023,loss_con:0.00000526
# epoch 17 loss_pde:0.00290023, loss_ic:0.00007889, loss_rh:0.00017023,loss_con:0.00000526
# epoch 17 loss_pde:0.00290004, loss_ic:0.00007890, loss_rh:0.00017023,loss_con:0.00000527
# epoch 17 loss_pde:0.00289999, loss_ic:0.00007889, loss_rh:0.00017023,loss_con:0.00000526
# ...
# epoch 374 loss_pde:0.00223686, loss_ic:0.00006958, loss_rh:0.00015446,loss_con:0.00000604
# epoch 374 loss_pde:0.00223685, loss_ic:0.00006958, loss_rh:0.00015446,loss_con:0.00000604
# epoch 374 loss_pde:0.00223679, loss_ic:0.00006957, loss_rh:0.00015446,loss_con:0.00000604
# epoch 374 loss_pde:0.00223682, loss_ic:0.00006956, loss_rh:0.00015446,loss_con:0.00000604
# epoch 374 loss_pde:0.00223675, loss_ic:0.00006955, loss_rh:0.00015447,loss_con:0.00000604
# epoch 374 loss_pde:0.00223675, loss_ic:0.00006954, loss_rh:0.00015448,loss_con:0.00000604
# epoch 374 loss_pde:0.00223672, loss_ic:0.00006952, loss_rh:0.00015448,loss_con:0.00000605
# epoch 374 loss_pde:0.00223672, loss_ic:0.00006950, loss_rh:0.00015449,loss_con:0.00000605
# epoch 374 loss_pde:0.00223672, loss_ic:0.00006948, loss_rh:0.00015450,loss_con:0.00000606
# epoch 374 loss_pde:0.00223672, loss_ic:0.00006946, loss_rh:0.00015452,loss_con:0.00000607
# epoch 374 loss_pde:0.00223673, loss_ic:0.00006943, loss_rh:0.00015453,loss_con:0.00000608
# loss_tot:0.00469914
# epoch 375 loss_pde:0.00223676, loss_ic:0.00006941, loss_rh:0.00015454,loss_con:0.00000608
# epoch 375 loss_pde:0.00223678, loss_ic:0.00006939, loss_rh:0.00015455,loss_con:0.00000609
# epoch 375 loss_pde:0.00223680, loss_ic:0.00006936, loss_rh:0.00015456,loss_con:0.00000610
# epoch 375 loss_pde:0.00223668, loss_ic:0.00006933, loss_rh:0.00015458,loss_con:0.00000613
# epoch 375 loss_pde:0.00223670, loss_ic:0.00006930, loss_rh:0.00015459,loss_con:0.00000613
# epoch 375 loss_pde:0.00223671, loss_ic:0.00006928, loss_rh:0.00015460,loss_con:0.00000614
# epoch 375 loss_pde:0.00223675, loss_ic:0.00006925, loss_rh:0.00015461,loss_con:0.00000615
# epoch 375 loss_pde:0.00223675, loss_ic:0.00006922, loss_rh:0.00015463,loss_con:0.00000617
# epoch 375 loss_pde:0.00223678, loss_ic:0.00006919, loss_rh:0.00015464,loss_con:0.00000617
# epoch 375 loss_pde:0.00223679, loss_ic:0.00006917, loss_rh:0.00015465,loss_con:0.00000619
# epoch 375 loss_pde:0.00223681, loss_ic:0.00006914, loss_rh:0.00015466,loss_con:0.00000619
# epoch 375 loss_pde:0.00223681, loss_ic:0.00006911, loss_rh:0.00015467,loss_con:0.00000621
# epoch 375 loss_pde:0.00223681, loss_ic:0.00006909, loss_rh:0.00015468,loss_con:0.00000622
# epoch 375 loss_pde:0.00223682, loss_ic:0.00006907, loss_rh:0.00015469,loss_con:0.00000623
# epoch 375 loss_pde:0.00223682, loss_ic:0.00006905, loss_rh:0.00015469,loss_con:0.00000623
# epoch 375 loss_pde:0.00223682, loss_ic:0.00006903, loss_rh:0.00015470,loss_con:0.00000624
# epoch 375 loss_pde:0.00223681, loss_ic:0.00006901, loss_rh:0.00015470,loss_con:0.00000625
# epoch 375 loss_pde:0.00223679, loss_ic:0.00006900, loss_rh:0.00015471,loss_con:0.00000625
# epoch 375 loss_pde:0.00223676, loss_ic:0.00006899, loss_rh:0.00015471,loss_con:0.00000626
# epoch 375 loss_pde:0.00223666, loss_ic:0.00006897, loss_rh:0.00015472,loss_con:0.00000628
# epoch 375 loss_pde:0.00223663, loss_ic:0.00006896, loss_rh:0.00015472,loss_con:0.00000629
# epoch 375 loss_pde:0.00223686, loss_ic:0.00006896, loss_rh:0.00015472,loss_con:0.00000626
# epoch 375 loss_pde:0.00223682, loss_ic:0.00006895, loss_rh:0.00015473,loss_con:0.00000626
# epoch 375 loss_pde:0.00223676, loss_ic:0.00006895, loss_rh:0.00015473,loss_con:0.00000627
# epoch 375 loss_pde:0.00223670, loss_ic:0.00006895, loss_rh:0.00015472,loss_con:0.00000627
# epoch 375 loss_pde:0.00223668, loss_ic:0.00006895, loss_rh:0.00015472,loss_con:0.00000627
# epoch 375 loss_pde:0.00223664, loss_ic:0.00006895, loss_rh:0.00015472,loss_con:0.00000626
# epoch 375 loss_pde:0.00223656, loss_ic:0.00006896, loss_rh:0.00015471,loss_con:0.00000626
# epoch 375 loss_pde:0.00223648, loss_ic:0.00006897, loss_rh:0.00015471,loss_con:0.00000626
# epoch 375 loss_pde:0.00223640, loss_ic:0.00006898, loss_rh:0.00015470,loss_con:0.00000626
# loss_tot:0.00469674
# epoch 376 loss_pde:0.00223633, loss_ic:0.00006899, loss_rh:0.00015469,loss_con:0.00000625
# epoch 376 loss_pde:0.00223625, loss_ic:0.00006901, loss_rh:0.00015469,loss_con:0.00000625
# epoch 376 loss_pde:0.00223618, loss_ic:0.00006903, loss_rh:0.00015468,loss_con:0.00000624
# epoch 376 loss_pde:0.00223611, loss_ic:0.00006904, loss_rh:0.00015467,loss_con:0.00000623
# epoch 376 loss_pde:0.00223605, loss_ic:0.00006906, loss_rh:0.00015466,loss_con:0.00000623
# epoch 376 loss_pde:0.00223571, loss_ic:0.00006911, loss_rh:0.00015463,loss_con:0.00000623
# epoch 376 loss_pde:0.00223568, loss_ic:0.00006913, loss_rh:0.00015462,loss_con:0.00000622
# epoch 376 loss_pde:0.00223564, loss_ic:0.00006914, loss_rh:0.00015461,loss_con:0.00000622
# epoch 376 loss_pde:0.00223560, loss_ic:0.00006916, loss_rh:0.00015461,loss_con:0.00000621
# epoch 376 loss_pde:0.00223554, loss_ic:0.00006917, loss_rh:0.00015460,loss_con:0.00000621
# epoch 376 loss_pde:0.00223551, loss_ic:0.00006919, loss_rh:0.00015459,loss_con:0.00000619
# epoch 376 loss_pde:0.00223536, loss_ic:0.00006923, loss_rh:0.00015456,loss_con:0.00000618
# epoch 376 loss_pde:0.00223535, loss_ic:0.00006924, loss_rh:0.00015455,loss_con:0.00000617
# epoch 376 loss_pde:0.00223533, loss_ic:0.00006926, loss_rh:0.00015454,loss_con:0.00000616
# epoch 376 loss_pde:0.00223531, loss_ic:0.00006927, loss_rh:0.00015453,loss_con:0.00000616
# epoch 376 loss_pde:0.00223526, loss_ic:0.00006929, loss_rh:0.00015452,loss_con:0.00000615
# epoch 376 loss_pde:0.00223524, loss_ic:0.00006931, loss_rh:0.00015451,loss_con:0.00000614
# epoch 376 loss_pde:0.00223522, loss_ic:0.00006933, loss_rh:0.00015450,loss_con:0.00000613
# epoch 376 loss_pde:0.00223521, loss_ic:0.00006934, loss_rh:0.00015448,loss_con:0.00000612
# epoch 376 loss_pde:0.00223517, loss_ic:0.00006936, loss_rh:0.00015447,loss_con:0.00000612
# epoch 376 loss_pde:0.00223515, loss_ic:0.00006937, loss_rh:0.00015446,loss_con:0.00000611
# epoch 376 loss_pde:0.00223520, loss_ic:0.00006939, loss_rh:0.00015445,loss_con:0.00000610
# epoch 376 loss_pde:0.00223519, loss_ic:0.00006940, loss_rh:0.00015445,loss_con:0.00000609
# epoch 376 loss_pde:0.00223516, loss_ic:0.00006940, loss_rh:0.00015444,loss_con:0.00000609
# epoch 376 loss_pde:0.00223514, loss_ic:0.00006941, loss_rh:0.00015443,loss_con:0.00000609
# epoch 376 loss_pde:0.00223511, loss_ic:0.00006942, loss_rh:0.00015441,loss_con:0.00000609
# epoch 376 loss_pde:0.00223510, loss_ic:0.00006943, loss_rh:0.00015441,loss_con:0.00000609
# epoch 376 loss_pde:0.00223504, loss_ic:0.00006944, loss_rh:0.00015439,loss_con:0.00000610
# epoch 376 loss_pde:0.00223508, loss_ic:0.00006943, loss_rh:0.00015439,loss_con:0.00000609
# epoch 376 loss_pde:0.00223505, loss_ic:0.00006944, loss_rh:0.00015438,loss_con:0.00000610
# loss_tot:0.00469516
# epoch 377 loss_pde:0.00223500, loss_ic:0.00006944, loss_rh:0.00015437,loss_con:0.00000611
# epoch 377 loss_pde:0.00223488, loss_ic:0.00006944, loss_rh:0.00015437,loss_con:0.00000612
# epoch 377 loss_pde:0.00223489, loss_ic:0.00006944, loss_rh:0.00015436,loss_con:0.00000613
# epoch 377 loss_pde:0.00223470, loss_ic:0.00006943, loss_rh:0.00015436,loss_con:0.00000615
# epoch 377 loss_pde:0.00223466, loss_ic:0.00006943, loss_rh:0.00015436,loss_con:0.00000616
# epoch 377 loss_pde:0.00223458, loss_ic:0.00006943, loss_rh:0.00015435,loss_con:0.00000618
# epoch 377 loss_pde:0.00223447, loss_ic:0.00006941, loss_rh:0.00015435,loss_con:0.00000620
# epoch 377 loss_pde:0.00223455, loss_ic:0.00006941, loss_rh:0.00015435,loss_con:0.00000621
# epoch 377 loss_pde:0.00223440, loss_ic:0.00006939, loss_rh:0.00015435,loss_con:0.00000624
# epoch 377 loss_pde:0.00223440, loss_ic:0.00006938, loss_rh:0.00015435,loss_con:0.00000625
# epoch 377 loss_pde:0.00223433, loss_ic:0.00006937, loss_rh:0.00015436,loss_con:0.00000627
# epoch 377 loss_pde:0.00223412, loss_ic:0.00006937, loss_rh:0.00015435,loss_con:0.00000629
# epoch 377 loss_pde:0.00223403, loss_ic:0.00006936, loss_rh:0.00015435,loss_con:0.00000631
# epoch 377 loss_pde:0.00223395, loss_ic:0.00006935, loss_rh:0.00015436,loss_con:0.00000633
# epoch 377 loss_pde:0.00223383, loss_ic:0.00006933, loss_rh:0.00015437,loss_con:0.00000634
# epoch 377 loss_pde:0.00223371, loss_ic:0.00006932, loss_rh:0.00015437,loss_con:0.00000636
# epoch 377 loss_pde:0.00223359, loss_ic:0.00006930, loss_rh:0.00015438,loss_con:0.00000638
# epoch 377 loss_pde:0.00223346, loss_ic:0.00006929, loss_rh:0.00015439,loss_con:0.00000640
# epoch 377 loss_pde:0.00223334, loss_ic:0.00006928, loss_rh:0.00015440,loss_con:0.00000641
# epoch 377 loss_pde:0.00223318, loss_ic:0.00006926, loss_rh:0.00015441,loss_con:0.00000643
# epoch 377 loss_pde:0.00223303, loss_ic:0.00006925, loss_rh:0.00015442,loss_con:0.00000644
# epoch 377 loss_pde:0.00223287, loss_ic:0.00006924, loss_rh:0.00015443,loss_con:0.00000646
# epoch 377 loss_pde:0.00223271, loss_ic:0.00006923, loss_rh:0.00015444,loss_con:0.00000647
# epoch 377 loss_pde:0.00223258, loss_ic:0.00006922, loss_rh:0.00015445,loss_con:0.00000648
# epoch 377 loss_pde:0.00223243, loss_ic:0.00006921, loss_rh:0.00015445,loss_con:0.00000649
# epoch 377 loss_pde:0.00223225, loss_ic:0.00006921, loss_rh:0.00015446,loss_con:0.00000650
# epoch 377 loss_pde:0.00223207, loss_ic:0.00006920, loss_rh:0.00015447,loss_con:0.00000650
# epoch 377 loss_pde:0.00223188, loss_ic:0.00006920, loss_rh:0.00015447,loss_con:0.00000651
# epoch 377 loss_pde:0.00223158, loss_ic:0.00006920, loss_rh:0.00015448,loss_con:0.00000652
# epoch 377 loss_pde:0.00223139, loss_ic:0.00006920, loss_rh:0.00015448,loss_con:0.00000653
# loss_tot:0.00469363
# epoch 378 loss_pde:0.00223115, loss_ic:0.00006920, loss_rh:0.00015448,loss_con:0.00000653
# epoch 378 loss_pde:0.00223096, loss_ic:0.00006920, loss_rh:0.00015448,loss_con:0.00000653
# epoch 378 loss_pde:0.00223075, loss_ic:0.00006921, loss_rh:0.00015448,loss_con:0.00000653
# epoch 378 loss_pde:0.00223057, loss_ic:0.00006922, loss_rh:0.00015448,loss_con:0.00000653
# epoch 378 loss_pde:0.00223041, loss_ic:0.00006923, loss_rh:0.00015448,loss_con:0.00000652
# epoch 378 loss_pde:0.00223018, loss_ic:0.00006924, loss_rh:0.00015447,loss_con:0.00000652
# epoch 378 loss_pde:0.00222999, loss_ic:0.00006925, loss_rh:0.00015447,loss_con:0.00000651
# epoch 378 loss_pde:0.00222960, loss_ic:0.00006927, loss_rh:0.00015446,loss_con:0.00000652
# epoch 378 loss_pde:0.00222944, loss_ic:0.00006928, loss_rh:0.00015446,loss_con:0.00000651
# epoch 378 loss_pde:0.00222915, loss_ic:0.00006929, loss_rh:0.00015445,loss_con:0.00000652
# epoch 378 loss_pde:0.00222895, loss_ic:0.00006931, loss_rh:0.00015444,loss_con:0.00000650
# epoch 378 loss_pde:0.00222883, loss_ic:0.00006932, loss_rh:0.00015444,loss_con:0.00000648
# epoch 378 loss_pde:0.00222863, loss_ic:0.00006934, loss_rh:0.00015443,loss_con:0.00000646
# epoch 378 loss_pde:0.00222852, loss_ic:0.00006936, loss_rh:0.00015442,loss_con:0.00000645
# epoch 378 loss_pde:0.00222842, loss_ic:0.00006937, loss_rh:0.00015442,loss_con:0.00000643
# epoch 378 loss_pde:0.00222788, loss_ic:0.00006934, loss_rh:0.00015443,loss_con:0.00000649
# epoch 378 loss_pde:0.00222782, loss_ic:0.00006935, loss_rh:0.00015442,loss_con:0.00000647
# epoch 378 loss_pde:0.00222777, loss_ic:0.00006937, loss_rh:0.00015442,loss_con:0.00000644
# epoch 378 loss_pde:0.00222773, loss_ic:0.00006938, loss_rh:0.00015441,loss_con:0.00000642
# epoch 378 loss_pde:0.00222770, loss_ic:0.00006940, loss_rh:0.00015440,loss_con:0.00000640
# epoch 378 loss_pde:0.00222767, loss_ic:0.00006941, loss_rh:0.00015439,loss_con:0.00000638
# epoch 378 loss_pde:0.00222765, loss_ic:0.00006942, loss_rh:0.00015438,loss_con:0.00000636
# epoch 378 loss_pde:0.00222764, loss_ic:0.00006944, loss_rh:0.00015437,loss_con:0.00000635
# epoch 378 loss_pde:0.00222763, loss_ic:0.00006944, loss_rh:0.00015437,loss_con:0.00000633
# epoch 378 loss_pde:0.00222763, loss_ic:0.00006946, loss_rh:0.00015436,loss_con:0.00000631
# epoch 378 loss_pde:0.00222761, loss_ic:0.00006947, loss_rh:0.00015435,loss_con:0.00000630
# epoch 378 loss_pde:0.00222760, loss_ic:0.00006948, loss_rh:0.00015434,loss_con:0.00000628
# epoch 378 loss_pde:0.00222761, loss_ic:0.00006949, loss_rh:0.00015434,loss_con:0.00000627
# epoch 378 loss_pde:0.00222760, loss_ic:0.00006949, loss_rh:0.00015433,loss_con:0.00000626
# epoch 378 loss_pde:0.00222765, loss_ic:0.00006949, loss_rh:0.00015432,loss_con:0.00000625
# loss_tot:0.00469096
# epoch 379 loss_pde:0.00222764, loss_ic:0.00006949, loss_rh:0.00015432,loss_con:0.00000625
# epoch 379 loss_pde:0.00222775, loss_ic:0.00006949, loss_rh:0.00015432,loss_con:0.00000623
# epoch 379 loss_pde:0.00222777, loss_ic:0.00006950, loss_rh:0.00015431,loss_con:0.00000622
# epoch 379 loss_pde:0.00222780, loss_ic:0.00006948, loss_rh:0.00015431,loss_con:0.00000623
# epoch 379 loss_pde:0.00222783, loss_ic:0.00006948, loss_rh:0.00015431,loss_con:0.00000622
# epoch 379 loss_pde:0.00222784, loss_ic:0.00006948, loss_rh:0.00015431,loss_con:0.00000622
# epoch 379 loss_pde:0.00222785, loss_ic:0.00006947, loss_rh:0.00015431,loss_con:0.00000622
# epoch 379 loss_pde:0.00222788, loss_ic:0.00006946, loss_rh:0.00015431,loss_con:0.00000623
# epoch 379 loss_pde:0.00222788, loss_ic:0.00006945, loss_rh:0.00015431,loss_con:0.00000623
# epoch 379 loss_pde:0.00222788, loss_ic:0.00006944, loss_rh:0.00015431,loss_con:0.00000624
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_692655/1980690088.py in <module>
#       7 tic = time.time()
#       8 for epoch in range(epochi, epochs+epochi):
# ----> 9     loss = train(epoch)
#      10     print(f'loss_tot:{loss:.8f}')
#      11     loss_history.append(to_numpy(loss))
#
# /tmp/ipykernel_692655/2381275098.py in train(epoch)
#      39         loss.backward()
#      40         return loss
# ---> 41     loss = optimizer.step(closure)
#      42     return loss
#      43
#
# ~/.local/lib/python3.10/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     278                                                f"but got {result}.")
#     279
# --> 280                 out = func(*args, **kwargs)
#     281                 self._optimizer_step_code()
#     282
#
# ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# ~/.local/lib/python3.10/site-packages/torch/optim/lbfgs.py in step(self, closure)
#     436                     # no use to re-evaluate that function here
#     437                     with torch.enable_grad():
# --> 438                         loss = float(closure())
#     439                     flat_grad = self._gather_flat_grad()
#     440                     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /tmp/ipykernel_692655/2381275098.py in closure()
#      37         loss = loss_pde + 10*(loss_ic+loss_bc) + 10*(loss_rh) +10*(loss_con +loss_con1+loss_con2)
#      38         print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ic:{loss_ic:.8f}, loss_rh:{loss_rh:.8f},loss_con:{loss_con:.8f}')
# ---> 39         loss.backward()
#      40         return loss
#      41     loss = optimizer.step(closure)
#
# ~/.local/lib/python3.10/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# ~/.local/lib/python3.10/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     198     # some Python versions print out the first line of a multi-line function
#     199     # calls in the traceback and some print out the last line
# --> 200     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
torch.save(model,'2blast.pt')

# %%
model = torch.load("2blast.pt")

# %%
x = np.linspace(0.0, 1.0, 100)                                   
t = np.linspace(Te, Te, 1)                                     
t_grid, x_grid = np.meshgrid(t, x)                               
T = t_grid.flatten()[:, None]                                    
X = x_grid.flatten()[:, None]                                    
x_test = np.hstack((T, X))                                       
x_test = torch.tensor(x_test, dtype=dtype).to(cpu)
u_pred = to_numpy(model(x_test))

import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.scatter(x[:],u_pred[:,0])
ax.scatter(x[:],u_pred[:,1])
ax.scatter(x[:],u_pred[:,2])
#ax.plot(Exact[:,0],Exact[:,1])
#ax.plot(Exact[:,0],Exact[:,2])
#ax.plot(Exact[:,0],Exact[:,3])
ax.set_xlim(0.0, 1.0)
#ax.set_ylim(0.2, 1.2)
plt.show()

# %%
Exact = np.loadtxt('sode.dat')
Exact[:,0]
# Out:
# array([0.02671362, 0.02789683, 0.02908005, ..., 1.19560583, 1.19735798,
#        1.19911014])

# %%
device = cpu

x = np.linspace(0.0, 1.0, 100)                                   
t = np.linspace(Te,  Te, 1)                                     
t_grid, x_grid = np.meshgrid(t, x)                               
T = t_grid.flatten()[:, None]                                    
X = x_grid.flatten()[:, None]                                    
x_test = np.hstack((T, X))                                       
x_1,xL,xR,xP,xPL,xPR = Pertur_1D(x_test,0.00,0.01,0.01)
x_test = torch.tensor(x_test, requires_grad=True, dtype=dtype).to(device)
xR = torch.tensor(xR, dtype=dtype).to(device)
xL = torch.tensor(xL, dtype=dtype).to(device)
u_pred = model(x_test)
uL_pred = model(xL)
uR_pred = model(xR)
rho, p,u = u_pred[:, 0], u_pred[:, 1], u_pred[:, 2]          
rhoL, pL,uL = uL_pred[:, :1], uL_pred[:, 1:2], uL_pred[:, 2:]          
rhoR, pR,uR = uR_pred[:, :1], uR_pred[:, 1:2], uR_pred[:, 2:]          
U2 = rho*u
U3 = 0.5*rho*u**2 + p/0.4

#F1 = U2
F2 = rho*u**2+p
F3 = u*(U3 + p)

gamma = 1.4                                                    

# Gradients and partial derivatives
drho_g = gradients(rho, x_test)[0]                                  
rho_t, rho_x = drho_g[:, :1], drho_g[:, 1:]             


du_g = gradients(u, x_test)[0]                                      
u_t, u_x = du_g[:, :1], du_g[:, 1:]                            

dp_g = gradients(p, x_test)[0]                                      
p_t, p_x = dp_g[:, :1], dp_g[:, 1:]                            

dp_g = gradients(p, x_test)[0]                                     
p_t, p_x = dp_g[:, :1], dp_g[:, 1:]                           

dU2_g = gradients(U2, x_test)[0]
U2_t,U2_x = dU2_g[:,:1], dU2_g[:,1:]
dU3_g = gradients(U3, x_test)[0]
U3_t,U3_x = dU3_g[:,:1], dU3_g[:,1:]
dF2_g = gradients(F2, x_test)[0]
F2_t,F2_x = dF2_g[:,:1], dF2_g[:,1:]
dF3_g = gradients(F3, x_test)[0]
F3_t,F3_x = dF3_g[:,:1], dF3_g[:,1:]

d = 0.2*(abs(u_x)-(u_x))  + 1

d = 0.1*(abs(uR-uL)-(uR-uL))/0.01 + 1
#d = torch.exp(-10*u_x)+1
#d1 = torch.clamp(d/5,min=1)

d = 1/(0.2*(abs(u_x)-u_x)+1)
d2 =1/(0.1*(abs(uR-uL)-(uR-uL))/0.02  + 1)
f = ((rho_t + U2_x))**2 + \
    ((U2_t  + F2_x))**2 + \
    ((U3_t  + F3_x))**2 #+\
#d = 1/(0.1*(torch.clamp((abs(u_x)-u_x))
d = to_numpy(d)
d2 = to_numpy(d2)
f = to_numpy(f)
#d3 = to_numpy(d3)
u_pred = to_numpy(u_pred)

np.size(u_pred[:,0])
# Out:
# 100

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
#ax.scatter(x[:],rhoref*u_pred[:,0])
#ax.scatter(x[:],pref*u_pred[:,1])
#ax.scatter(x[:],uref*u_pred[:,2])
ax.scatter(x[:],d)
#ax.scatter(x[:],d2)
#ax.scatter(x[:],f)
#ax.plot(Exact[:,0],Exact[:,1],color='black')
#ax.plot(Exact[:,0],Exact[:,2],color='black')
#ax.plot(Exact[:,0],Exact[:,3],color='black')
ax.set_xlim(0.0, 1.0)
#plt.savefig('1.eps', format='eps')
#ax.set_ylim(0.0, 1.2)
#ax.scatter(x[:],d)
plt.show()

# %%
xp= x.flatten()[:,None]
rhop= u_pred[:,0].flatten()[:,None]
up= u_pred[:,1].flatten()[:,None]
pp= u_pred[:,2].flatten()[:,None]
#ff= f.flatten()[:,None]
#dd= d.flatten()[:,None]
uxy= np.hstack((xp,rhop,up,pp))
np.savetxt('2Blast_1w.dat', uxy)

# %%
xp= x.flatten()[:,None]
rhop= u_pred[:,0].flatten()[:,None]
up= u_pred[:,1].flatten()[:,None]
pp= u_pred[:,2].flatten()[:,None]
uxy= np.hstack((xp,rhop,up,pp))    
np.savetxt('Sod.dat', uxy)
