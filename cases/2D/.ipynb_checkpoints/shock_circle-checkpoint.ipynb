# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
import matplotlib.pyplot as plt
from numpy import arange, meshgrid
#
from smt.sampling_methods import LHS
# Seeds
torch.manual_seed(123)
np.random.seed(123)
def train(epoch):
    model.train()
    def closure():
        optimizer.zero_grad()                                                     # Optimizer
        loss_pde = model.loss_pde(x_int_train)                                    # Loss function of PDE
        loss_ic = model.loss_ic(x_ic_train, rho_ic_train,u_ic_train,v_ic_train,p_ic_train)   # Loss function of IC
        loss_bdL = model.loss_bc(x_bcL_train, rho_bcL_train,u_bcL_train,v_bcL_train,p_bcL_train)   # Loss function of IC
        loss_bdR = model.loss_bc1(x_bcR_train,rho_bcR_train,u_bcR_train,v_bcR_train,p_bcR_train)   # Loss function of IC
        #loss_cut = model.loss_bc1(x_cut_train,rho_cut_train,u_cut_train,v_cut_train,p_cut_train) 
        loss_bdI = model.bd_B(x_bcI_train, sin_bcI_train,cos_bcI_train)  

        loss_ib = loss_ic  +  loss_bdI +loss_bdL
        loss = loss_pde + 10*loss_ib

        # Print iteration, loss of PDE and ICs
        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_ib:{loss_ib:.8f}')
        loss.backward()
        return loss

    # Optimize loss function
    loss = optimizer.step(closure)
    loss_value = loss.item() if not isinstance(loss, float) else loss
    # Print total loss
    print(f'epoch {epoch}: loss {loss_value:.6f}')
    
# Calculate gradients using torch.autograd.grad
def gradients(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

# Convert torch tensor into np.array
def to_numpy(input):
    if isinstance(input, torch.Tensor):
        return input.detach().cpu().numpy()
    elif isinstance(input, np.ndarray):
        return input
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                        'np.ndarray, but got {}'.format(type(input)))
def IC(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    rho1 = 2.112
    p1 =  3.011
    v1 = 0.0
    u1 = np.sqrt(1.4*p1/rho1)*0.728
    
    rho2 = 1.0
    p2 = 1.
    v2 = 0.0
    #u1 = ms*npsqrt(gamma)
    u2 = 0.0
    # rho, p - initial condition
    for i in range(N):
        if x[i,1] < 1.0:
            rho_init[i] = rho1
            u_init[i] =   u1
            v_init[i] =  v1
            p_init[i] =  p1
        else:
            rho_init[i] = rho2
            u_init[i] =   u2
            v_init[i] =  v2
            p_init[i] =  p2

    return rho_init, u_init, v_init,p_init

def BC_L(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    #u1 = ms*npsqrt(gamma)
    # rho, p - initial condition
    rho1 = 2.112
    p1 =  3.011
    v1 = 0.0
    u1 = np.sqrt(1.4*p1/rho1)*0.728
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] =  u1
        v_init[i] =  v1
        p_init[i] =  p1
    return rho_init, u_init, v_init,p_init
def BC_R(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    ms = 2.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] = u1
        v_init[i] = v1
        p_init[i] = p1

    return rho_init, u_init, v_init,p_init
def BC_Cut(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))
    u_init = np.zeros((x.shape[0]))
    v_init = np.zeros((x.shape[0]))
    p_init = np.zeros((x.shape[0]))
    
    gamma = 1.4
    ms = 2.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = 10.01
        u_init[i] =  0
        v_init[i] = 0
        p_init[i] = 10.01

    return rho_init, u_init, v_init,p_init
    
class DNN(nn.Module):

    def __init__(self):
        super(DNN, self).__init__()
        self.net = nn.Sequential()                                                  # Define neural network
        self.net.add_module('Linear_layer_1', nn.Linear(3, 60))                     # First linear layer
        self.net.add_module('Tanh_layer_1', nn.Tanh())                              # First activation Layer

        for num in range(2, 5):                                                     # Number of layers (2 through 7)
            self.net.add_module('Linear_layer_%d' % (num), nn.Linear(60, 60))       # Linear layer
            self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 # Activation Layer
        self.net.add_module('Linear_layer_final', nn.Linear(60, 4))                 # Output Layer

    # Forward Feed
    def forward(self, x):
        return self.net(x)

    def bd_B(self,x,sin,cos):
        yb = self.net(x)
        rhob,pb,ub,vb = yb[:, 0:1], yb[:, 1:2], yb[:, 2:3],yb[:,3:]
        drhob_g = gradients(rhob, x)[0]                                      # Gradient [u_t, u_x]
        rhob_x, rhob_y = drhob_g[:, 1:2], drhob_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dub_g = gradients(ub, x)[0]                                      # Gradient [u_t, u_x]
        ub_x, ub_y = dub_g[:, 1:2], dub_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dvb_g = gradients(vb, x)[0]                                      # Gradient [u_t, u_x]
        vb_x, vb_y = dvb_g[:, 1:2], dvb_g[:, 2:3]                            # Partial derivatives u_t, u_x
        dpb_g = gradients(pb, x)[0]                                      # Gradient [p_t, p_x]
        pb_x, pb_y = dpb_g[:, 1:2], dpb_g[:, 2:3]                            # Partial derivatives p_t, p_x
        
        #deltau = ub_x + vb_y
        #lam = 0.1*(abs(deltau) - deltau) + 1
        #lam = (deltau) - deltau) + 1
        
        fb = (((ub*cos + vb*sin))**2).mean() +\
            (((pb_x*cos + pb_y*sin))**2).mean() +\
            (((rhob_x*cos + rhob_y*sin))**2).mean()
        return fb
    def bd_OY(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        
        f = ((( u_y)/lam)**2).mean() +\
            ((( v_y)/lam)**2).mean() +\
            ((( p_y)/lam)**2).mean() +\
            ((( rho_y)/lam)**2).mean()
        return f
    
    def bd_OX(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        
        f = ((( u_x)/lam)**2).mean() +\
            ((( v_x)/lam)**2).mean() +\
            ((( p_x)/lam)**2).mean() +\
            ((( rho_x)/lam)**2).mean()
        return f
     
    # Loss function for PDE
    def loss_pde(self, x):
        
       # yL = self.net(x_intL_train)
       # yR = self.net(x_intR_train)
       # yU = self.net(x_intU_train)
       # yD = self.net(x_intD_train)
       # rhoL,pL,uL,vL = yL[:, 0:1], yL[:, 1:2], yL[:, 2:3],yL[:,3:]
       # rhoR,pR,uR,vR = yR[:, 0:1], yR[:, 1:2], yR[:, 2:3],yR[:,3:]
       # rhoU,pU,uU,vU = yU[:, 0:1], yU[:, 1:2], yU[:, 2:3],yU[:,3:]
       # rhoD,pD,uD,vD = yD[:, 0:1], yD[:, 1:2], yD[:, 2:3],yD[:,3:]
        y = self.net(x)
        gamma = 1.4                                                    # Heat Capacity Ratio
        epsilon = 1e-5
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        rhoE = p/(gamma - 1) +0.5*rho*(u**2+v**2)
        
        f1 = rho*u
        f2 = rho*u*u+p
        f3 = rho*u*v
        f4 = (rhoE+p)*u
        
        g1 = rho*v
        g2 = rho*v*u
        g3 = rho*v*v + p
        g4 = (rhoE+p)*v
        
        drho_g = gradients(rho,x)[0]
        U1_t = drho_g[:, :1]
        dU2_g = gradients(f1,x)[0]
        U2_t = dU2_g[:, :1]
        dU3_g = gradients(g1,x)[0]
        U3_t = dU3_g[:, :1]
        dU4_g = gradients(rhoE,x)[0]
        U4_t = dU4_g[:, :1]
        
        df1_g = gradients(f1, x)[0]                                  # Gradient [rho_t, rho_x]
        f1_x = df1_g[:, 1:2]
        df2_g = gradients(f2, x)[0]                                      # Gradient [u_t, u_x]
        f2_x = df2_g[:, 1:2]
        df3_g = gradients(f3, x)[0]                                      # Gradient [u_t, u_x]
        f3_x = df3_g[:, 1:2]
        df4_g = gradients(f4, x)[0]                                      # Gradient [u_t, u_x]
        f4_x = df4_g[:, 1:2]
        
        dg1_g = gradients(g1, x)[0]                                  # Gradient [rho_t, rho_x]
        g1_y = dg1_g[:, 2:3]
        dg2_g = gradients(g2, x)[0]                                      # Gradient [u_t, u_x]
        g2_y = dg2_g[:, 2:3]
        dg3_g = gradients(g3, x)[0]                                      # Gradient [u_t, u_x]
        g3_y = dg3_g[:, 2:3]
        dg4_g = gradients(g4, x)[0]                                      # Gradient [u_t, u_x]
        g4_y = dg4_g[:, 2:3]
        
        
        du_g = gradients(u, x)[0]                                
        u_x = du_g[:, 1:2]         
        dv_g = gradients(v, x)[0]                    
        v_y = dv_g[:, 2:3]         
        
      #  rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
      #  gamma = 1.4                                                    # Heat Capacity Ratio
      #  epsilon = 1e-5
      #  s = torch.log((abs(p)+epsilon)/(abs(rho)+epsilon)**1.4)
      #  eta = -rho*s
      #  phi1 = -rho*u*s
      #  phi2 = -rho*v*s
      #  
      #  drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
      #  rho_t, rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2],drho_g[:,2:]
      #  du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
      #  u_t, u_x, u_y = du_g[:, :1], du_g[:, 1:2], du_g[:,2:]                            # Partial derivatives u_t, u_x
      #  dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
      #  v_t, v_x, v_y = dv_g[:, :1], dv_g[:, 1:2], dv_g[:,2:]                            # Partial derivatives u_t, u_x
      #  
      #  E = p/0.4 + 0.5*rho*(u**2+v**2)
      #  EL = pL/0.4 + 0.5*rhoL*(uL**2+vL**2)
      #  ER = pR/0.4 + 0.5*rhoR*(uR**2+vR**2)
      #  EU = pU/0.4 + 0.5*rhoU*(uU**2+vU**2)
      #  ED = pD/0.4 + 0.5*rhoD*(uD**2+vD**2)
      #  dE_g = gradients(E, x)[0]                                      # Gradient [u_t, u_x]
      #  E_t = dE_g[:, :1]
      #  
      #  
      #  deta_g = gradients(eta, x)[0]                                      # Gradient [p_t, p_x]
      #  eta_t, eta_x,eta_y = deta_g[:, :1], deta_g[:, 1:2],deta_g[2:3]                            # Partial derivatives p_t, p_x
      #  dphi1_g = gradients(phi1, x)[0]                                      # Gradient [p_t, p_x]
      #  dphi2_g = gradients(phi2, x)[0]                                      # Gradient [p_t, p_x]
      #  phi1_t, phi1_x,phi1_y = dphi1_g[:, :1], dphi1_g[:, 1:2],dphi1_g[:,2:3]                           # Partial derivatives p_t, p_x
      #  phi2_t, phi2_x,phi2_y = dphi2_g[:, :1], dphi2_g[:, 1:2],dphi2_g[:,2:3]                           # Partial derivatives p_t, p_x
        
        d = np.random.rand()
        deltau = u_x + v_y
        nab = abs(deltau) - deltau
        
        #a = np.sqrt(1.4*p/rho)
       # q = 0.01*(rho*deltau**2)
        
        d = 1.0
        lam = d*(0.1*nab) + 1
        #lam = d + 1
       # lam = 1/lam
        
        f = (((U1_t + f1_x+g1_y )/lam)**2).mean() +\
            (((U2_t + f2_x+g2_y )/lam)**2).mean() +\
            (((U3_t + f3_x+g3_y )/lam)**2).mean() +\
            (((U4_t + f4_x+g4_y )/lam)**2).mean()

      #  p = p+q
        
      #  dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
      #  p_t, p_x, p_y = dp_g[:, :1], dp_g[:, 1:2], dp_g[:,2:]                            # Partial derivatives p_t, p_x
      #  
      #  s1 = rho_t + (rhoR*uR - rhoL*uL)/0.02 +  (rhoU*uU - rhoD*uD)/0.02 
      #  s2 = u*rho_t + u_t*rho + (rhoR*uR*uR +pR - rhoL*uL*uL-pL)/0.02 \
      #       +(rhoU*uU*vU - rhoD*uD*vD)/0.02 
      #  s3 = v*rho_t + v_t*rho + (rhoU*vU*vU +pU - rhoD*vD*vD-pD)/0.02 \
      #       +(rhoR*uR*vR - rhoL*uL*vL)/0.02 
      #  s4 = E_t + ((ER+pR)*uR - (EL+pL)*uL)/0.02 + ((EU+pU)*vU - (ED+pD)*vD)/0.02 
      #  
      #  du_gg = gradients(u_x, x)[0]                                      # Gradient [u_t, u_x]
      #  u_xx, u_xy = du_gg[:, :1], du_gg[:, 1:2]                            # Partial derivatives u_t, u_x
      #  
      #  dv_gg = gradients(v_y, x)[0]                                      # Gradient [u_t, u_x]
      #  v_yx, v_yy = dv_gg[:, :1], dv_gg[:, 1:2]                            # Partial derivatives u_t, u_x
      #  
      #  vis = -0.1*(u_xx + v_yy)
#
      #  f = (((rho_t+rho*deltau+u*rho_x + v*rho_y)/lam)**2).mean() +\
      #      (((rho*u_t+rho*u*u_x+rho*v*u_y+p_x +rho*vis)/lam)**2).mean() +\
      #      (((rho*v_t+rho*u*v_x+rho*v*v_y+p_y +rho*vis)/lam)**2).mean() +\
      #      (((p_t+u*p_x+v*p_y+1.4*p*deltau +rho*vis)/lam)**2).mean() + \
      #      ((abs(s1)+s1)**2).mean() +\
      #      ((abs(s3)+s3)**2).mean() +\
      #      ((abs(s2)+s2)**2).mean() +\
      #      ((abs(s4)+s4)**2).mean()
      #      #(((abs(eta_t+phi1_x + phi2_y)+eta_t+phi1_x+ phi2_y))**2).mean()
    #
      #      #((abs(rho-1) - (rho-1))**2).mean()   + \
      #      #((abs(p-0.7) - (p-0.7))**2).mean() +\
        return f

    # Loss function for initial condition
    def loss_ic(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean() + \
               ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() +\
               ((v_ic_nn - v_ic) ** 2).mean()

        return loss_ics

    def loss_bc(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean() + \
               ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() +\
               ((v_ic_nn - v_ic) ** 2).mean()

        return loss_ics
    def loss_bc1(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() 

        return loss_ics

def BD_circle(t,xc,yc,r,n):
    x = np.zeros((n,3)) 
    sin = np.zeros((n,1)) 
    cos = np.zeros((n,1)) 

    for i in range(n):
        the = np.random.rand()*np.pi
        xd = np.cos(the + np.pi/2)
        yd = np.sin(the + np.pi/2)
        x[i,0] = np.random.rand()*t
        x[i,1] = xc  + xd*r
        x[i,2] = yc  + yd*r
        cos[i,0] = xd 
        sin[i,0] = yd
        #cos[i,0] = 1
        #sin[i,0] = 0
    return x, sin,cos

def Pertur(x, dx):
    N =x.shape[0]
    xL = np.zeros((N,3))
    xR = np.zeros((N,3))
    xU = np.zeros((N,3))
    xD = np.zeros((N,3))
    
    for i in range(N):
        xL[i,0] = x[i,0]
        xR[i,0] = x[i,0]
        xU[i,0] = x[i,0]
        xD[i,0] = x[i,0]
        
        
        xL[i,1] = x[i,1] - dx
        xR[i,1] = x[i,1] + dx
        xU[i,1] = x[i,1]
        xD[i,1] = x[i,1]
        
        xL[i,2] = x[i,2] 
        xR[i,2] = x[i,2]
        xU[i,2] = x[i,2] + dx
        xD[i,2] = x[i,2] - dx
        
    return xL,xR,xU,xD
    
    
    
def BD_BackCorner(t,n):
    
    x = np.zeros((n,3)) 
    x2 = np.zeros((n,3)) 
    sin = np.zeros((n,1)) 
    sin2 = np.zeros((n,1)) 
    cos = np.zeros((n,1)) 
    cos2 = np.zeros((n,1)) 
    
    for i in range(n):
        x[i,0] = np.random.rand()*t
        x[i,1] = np.random.rand()*0.3 + 0.2
        x[i,2] = 1.5
        sin[i] = 1
        cos[i] = 0
    for i in range(n):
        x2[i,0] = np.random.rand()*t
        x2[i,1] = np.random.rand()*0.5
        x2[i,2] = 1.5
        sin2[i] = 1
        cos2[i] = 0
    x = np.vstack((x,x2))
    sin = np.vstack((sin,sin2))
    cos = np.vstack((cos,cos2))
    
    for i in range(n):
        x2[i,0] = np.random.rand()*t
        x2[i,1] = 0.5
        x2[i,2] = np.random.rand()*1.5
        sin2[i] = 0
        cos2[i] = 1
        
    x = np.vstack((x,x2))
    sin = np.vstack((sin,sin2))
    cos = np.vstack((cos,cos2))
    
    for i in range(n):
        x2[i,0] = np.random.rand()*t
        x2[i,1] = 0.5
        x2[i,2] = np.random.rand()*0.3 + 1.2
        sin2[i] = 0
        cos2[i] = 1
        
    x = np.vstack((x,x2))
    sin = np.vstack((sin,sin2))
    cos = np.vstack((cos,cos2))
        
    return x,sin,cos

# Solve Euler equations using PINNs
# def main():
  # Initialization
#device = torch.device('cuda')                                          # Run on CPU
device = torch.device('cuda')                                          # Run on CPU
lr = 0.001                                                           # Learning rate
num_ib = 9000                                                # Random sampled points from IC0
num_int = 50000                                                # Random sampled points in interior
Tend = 1.0
Lx = 3.0
Ly = 3.0
rx = 1.5
ry = 1.5
rd = 0.25


xlimits = np.array([[0.,Tend],[0.0, Lx], [0,Ly]])  #interal
sampling = LHS(xlimits=xlimits)
x_int_train = sampling(num_int)

#xlimits = np.array([[0.,Tend],[0.5, 2], [0.5,2]])  #interal
#sampling = LHS(xlimits=xlimits)
#x_int1_train = sampling(num_int)
#x_int_train =  np.vstack((x_int_train,x_int1_train))

A = []
for i in range(num_int):
    x = x_int_train[i,1]
    y = x_int_train[i,2]
    if ((x - 1.5)**2 +(y-1.5)**2< 0.25**2):
        A.append(i)
x_int_train = np.delete(x_int_train,A,axis=0)

#xlimits = np.array([[0.0, Tend], [1.0, 4.0], [0.2,1.0]])
#sampling = LHS(xlimits=xlimits)
#x_int_train_add = sampling(3*num_int)
#x_int_train = np.vstack((x_int_train,x_int_train_add))

#x_intL_train,x_intR_train,x_intU_train,x_intD_train = Pertur(x_int_train, 0.01)

xlimits = np.array([[0.,0.0],[0.0,Lx], [0.0,Ly]])  #interal
sampling = LHS(xlimits=xlimits)
x_ic_train = sampling(num_ib)
A = []
for i in range(num_ib):
    x = x_ic_train[i,1]
    y = x_ic_train[i,2]
    if ((x - 1.5)**2 +(y-1.5)**2< 0.25**2):
        A.append(i)
x_ic_train = np.delete(x_ic_train,A,axis=0)


#xlimits = np.array([[0.0, 0.0], [1.0, 4.0], [0.2,1.0]])
#sampling = LHS(xlimits=xlimits)
#x_ic_train_add = sampling(3*num_int)
#x_ic_train = np.vstack((x_ic_train,x_ic_train_add))


xlimits = np.array([[0.0,Tend],[0.0, 0.0], [1.5,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcL_train =  sampling(num_ib)

xlimits = np.array([[0.0,Tend], [Lx, Lx], [0.0,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcR_train =  sampling(num_ib)


xlimits = np.array([[0.0,Tend],[0.0, Lx], [Ly,Ly]])
sampling = LHS(xlimits=xlimits)
x_bcU_train =  sampling(num_ib)

xlimits = np.array([[0.0,Tend], [0.0, Lx], [0.0,0.0]])
sampling = LHS(xlimits=xlimits)
x_bcD_train =  sampling(num_ib)                                           # Vectorized whole domain

#xlimits = np.array([[0.0,0.0],[0.0, Lx], [0.0,Ly]])
#sampling = LHS(xlimits=xlimits)
#x_ic_train =  sampling(num_ib)
#A = []
#for i in range(num_ib):
#    x = x_ic_train[i,1]
#    y = x_ic_train[i,2]
#    if ((x-rx)**2 + (y-ry)**2 ) < rd**2:
#        A.append(i)
#x_ic_train = np.delete(x_ic_train,A,axis=0)


x_bcI_train,sin_bcI_train,cos_bcI_train = BD_circle(Tend,rx,ry,rd,num_ib)
#x_bcI_train,sin_bcI_train,cos_bcI_train = BD_BackCorner(Tend,num_ib)

rho_bcL_train, u_bcL_train,v_bcL_train, p_bcL_train = BC_L(x_bcL_train)  
rho_bcR_train, u_bcR_train,v_bcR_train, p_bcR_train = BC_L(x_bcR_train)  
#rho_cut_train, u_cut_train,v_cut_train, p_cut_train = BC_Cut(x_cut_train)  
rho_ic_train, u_ic_train,v_ic_train, p_ic_train = IC(x_ic_train)  


x_int_train = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)
#x_intL_train = torch.tensor(x_intL_train,dtype=torch.float32).to(device)
#x_intR_train = torch.tensor(x_intR_train,dtype=torch.float32).to(device)
#x_intU_train = torch.tensor(x_intU_train,dtype=torch.float32).to(device)
#x_intD_train = torch.tensor(x_intD_train,dtype=torch.float32).to(device)

rho_bcL_train = torch.tensor(rho_bcL_train, dtype=torch.float32).to(device)
u_bcL_train = torch.tensor(u_bcL_train, dtype=torch.float32).to(device)
v_bcL_train = torch.tensor(v_bcL_train, dtype=torch.float32).to(device)
p_bcL_train = torch.tensor(p_bcL_train, dtype=torch.float32).to(device)

rho_bcR_train = torch.tensor(rho_bcR_train, dtype=torch.float32).to(device)
u_bcR_train = torch.tensor(u_bcR_train, dtype=torch.float32).to(device)
v_bcR_train = torch.tensor(v_bcR_train, dtype=torch.float32).to(device)
p_bcR_train = torch.tensor(p_bcR_train, dtype=torch.float32).to(device)

x_bcD_train = torch.tensor(x_bcD_train,requires_grad=True, dtype=torch.float32).to(device)
x_bcU_train = torch.tensor(x_bcU_train, requires_grad=True, dtype=torch.float32).to(device)
x_bcR_train = torch.tensor(x_bcR_train, requires_grad=True, dtype=torch.float32).to(device)
x_bcL_train = torch.tensor(x_bcL_train, dtype=torch.float32).to(device)
x_bcI_train = torch.tensor(x_bcI_train, requires_grad=True, dtype=torch.float32).to(device)
sin_bcI_train = torch.tensor(sin_bcI_train, dtype=torch.float32).to(device)
cos_bcI_train = torch.tensor(cos_bcI_train, dtype=torch.float32).to(device)

#rho_cut_train = torch.tensor(rho_cut_train, dtype=torch.float32).to(device)
#u_cut_train = torch.tensor(u_cut_train, dtype=torch.float32).to(device)
#v_cut_train = torch.tensor(v_cut_train, dtype=torch.float32).to(device)
#p_cut_train = torch.tensor(p_cut_train, dtype=torch.float32).to(device)
#x_cut_train = torch.tensor(x_cut_train, dtype=torch.float32).to(device)

rho_ic_train = torch.tensor(rho_ic_train, dtype=torch.float32).to(device)
u_ic_train = torch.tensor(u_ic_train, dtype=torch.float32).to(device)
v_ic_train = torch.tensor(v_ic_train, dtype=torch.float32).to(device)
p_ic_train = torch.tensor(p_ic_train, dtype=torch.float32).to(device)
x_ic_train = torch.tensor(x_ic_train, dtype=torch.float32).to(device)


#model = DNN().to(device)

#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
#rho_ic_train.clone().detach().requires_grad_(True)
#u_ic_train.clone().detach().requires_grad_(True)
# Initialize neural network

print('Start training...')
# Out:
# Start training...

# %%
model = DNN().to(device)

# %%
lr = 0.001
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_Adam,gamma=0.995)
#optimizer = torch.optim.LBFGS(model.parameters(),lr=0.001,max_iter=10)
#optimizer_LBFGS = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=50000)

# %%
epochs = 10000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:0.00843426, loss_ib:18.17846870
# epoch 1: loss 181.793121
# epoch 2 loss_pde:0.00373270, loss_ib:16.81455612
# epoch 2: loss 168.149307
# epoch 3 loss_pde:0.00237246, loss_ib:15.57001019
# epoch 3: loss 155.702469
# epoch 4 loss_pde:0.00301423, loss_ib:14.40509224
# epoch 4: loss 144.053940
# epoch 5 loss_pde:0.00546248, loss_ib:13.29140568
# epoch 5: loss 132.919525
# epoch 6 loss_pde:0.01016407, loss_ib:12.20883369
# epoch 6: loss 122.098495
# epoch 7 loss_pde:0.01790964, loss_ib:11.14446068
# epoch 7: loss 111.462517
# epoch 8 loss_pde:0.02959279, loss_ib:10.09295559
# epoch 8: loss 100.959152
# epoch 9 loss_pde:0.04590871, loss_ib:9.05647850
# epoch 9: loss 90.610695
# epoch 10 loss_pde:0.06700589, loss_ib:8.04431343
# epoch 10: loss 80.510139
# epoch 11 loss_pde:0.09216373, loss_ib:7.07150936
# epoch 11: loss 70.807259
# epoch 12 loss_pde:0.11958955, loss_ib:6.15665531
# epoch 12: loss 61.686142
# epoch 13 loss_pde:0.14653060, loss_ib:5.31946564
# epoch 13: loss 53.341187
# epoch 14 loss_pde:0.16988537, loss_ib:4.57879019
# epoch 14: loss 45.957787
# epoch 15 loss_pde:0.18729284, loss_ib:3.95113659
# epoch 15: loss 39.698662
# epoch 16 loss_pde:0.19828488, loss_ib:3.44918299
# epoch 16: loss 34.690113
# epoch 17 loss_pde:0.20495534, loss_ib:3.07976246
# epoch 17: loss 31.002581
# epoch 18 loss_pde:0.21178752, loss_ib:2.84149694
# epoch 18: loss 28.626759
# epoch 19 loss_pde:0.22434583, loss_ib:2.72270727
# epoch 19: loss 27.451420
# epoch 20 loss_pde:0.24657384, loss_ib:2.70052934
# epoch 20: loss 27.251867
# epoch 21 loss_pde:0.27737185, loss_ib:2.74236870
# epoch 21: loss 27.701059
# epoch 22 loss_pde:0.31006825, loss_ib:2.81106663
# epoch 22: loss 28.420734
# epoch 23 loss_pde:0.33750555, loss_ib:2.87312603
# epoch 23: loss 29.068766
# epoch 24 loss_pde:0.35776144, loss_ib:2.90518737
# epoch 24: loss 29.409636
# epoch 25 loss_pde:0.37558317, loss_ib:2.89567757
# epoch 25: loss 29.332359
# epoch 26 loss_pde:0.40016720, loss_ib:2.84307194
# epoch 26: loss 28.830887
# epoch 27 loss_pde:0.44133452, loss_ib:2.75294542
# epoch 27: loss 27.970787
# epoch 28 loss_pde:0.50541222, loss_ib:2.63501430
# epoch 28: loss 26.855556
# epoch 29 loss_pde:0.59207284, loss_ib:2.50068665
# epoch 29: loss 25.598940
# epoch 30 loss_pde:0.69376588, loss_ib:2.36139226
# epoch 30: loss 24.307688
# epoch 31 loss_pde:0.79875576, loss_ib:2.22770452
# epoch 31: loss 23.075802
# epoch 32 loss_pde:0.89649987, loss_ib:2.10887051
# epoch 32: loss 21.985205
# epoch 33 loss_pde:0.98214632, loss_ib:2.01222563
# epoch 33: loss 21.104404
# epoch 34 loss_pde:1.05763543, loss_ib:1.94224763
# epoch 34: loss 20.480112
# epoch 35 loss_pde:1.12933576, loss_ib:1.89952767
# epoch 35: loss 20.124613
# epoch 36 loss_pde:1.20402718, loss_ib:1.88023317
# epoch 36: loss 20.006359
# epoch 37 loss_pde:1.28546739, loss_ib:1.87662601
# epoch 37: loss 20.051727
# epoch 38 loss_pde:1.37303567, loss_ib:1.87883306
# epoch 38: loss 20.161366
# epoch 39 loss_pde:1.46251845, loss_ib:1.87744272
# epoch 39: loss 20.236946
# epoch 40 loss_pde:1.54784870, loss_ib:1.86596847
# epoch 40: loss 20.207535
# epoch 41 loss_pde:1.62237072, loss_ib:1.84214509
# epoch 41: loss 20.043823
# epoch 42 loss_pde:1.67907584, loss_ib:1.80764890
# epoch 42: loss 19.755564
# epoch 43 loss_pde:1.71049190, loss_ib:1.76660013
# epoch 43: loss 19.376492
# epoch 44 loss_pde:1.70954001, loss_ib:1.72370982
# epoch 44: loss 18.946638
# epoch 45 loss_pde:1.67187035, loss_ib:1.68289447
# epoch 45: loss 18.500816
# epoch 46 loss_pde:1.59837544, loss_ib:1.64667523
# epoch 46: loss 18.065128
# epoch 47 loss_pde:1.49590695, loss_ib:1.61618173
# epoch 47: loss 17.657724
# epoch 48 loss_pde:1.37569141, loss_ib:1.59140170
# epoch 48: loss 17.289707
# epoch 49 loss_pde:1.25048769, loss_ib:1.57146573
# epoch 49: loss 16.965145
# epoch 50 loss_pde:1.13182366, loss_ib:1.55489433
# epoch 50: loss 16.680767
# epoch 51 loss_pde:1.02811730, loss_ib:1.53982639
# epoch 51: loss 16.426382
# epoch 52 loss_pde:0.94397211, loss_ib:1.52430606
# epoch 52: loss 16.187033
# epoch 53 loss_pde:0.88057745, loss_ib:1.50669050
# epoch 53: loss 15.947482
# epoch 54 loss_pde:0.83687013, loss_ib:1.48607159
# epoch 54: loss 15.697586
# epoch 55 loss_pde:0.81084365, loss_ib:1.46247149
# epoch 55: loss 15.435558
# epoch 56 loss_pde:0.80043185, loss_ib:1.43668783
# epoch 56: loss 15.167311
# epoch 57 loss_pde:0.80377287, loss_ib:1.40988350
# epoch 57: loss 14.902608
# epoch 58 loss_pde:0.81901979, loss_ib:1.38314199
# epoch 58: loss 14.650440
# epoch 59 loss_pde:0.84398627, loss_ib:1.35715199
# epoch 59: loss 14.415506
# epoch 60 loss_pde:0.87588626, loss_ib:1.33210409
# epoch 60: loss 14.196927
# epoch 61 loss_pde:0.91134733, loss_ib:1.30779207
# epoch 61: loss 13.989268
# epoch 62 loss_pde:0.94674706, loss_ib:1.28384185
# epoch 62: loss 13.785166
# epoch 63 loss_pde:0.97875768, loss_ib:1.25996327
# epoch 63: loss 13.578390
# epoch 64 loss_pde:1.00486636, loss_ib:1.23612618
# epoch 64: loss 13.366128
# epoch 65 loss_pde:1.02367353, loss_ib:1.21261835
# epoch 65: loss 13.149857
# epoch 66 loss_pde:1.03490889, loss_ib:1.18998265
# epoch 66: loss 12.934735
# epoch 67 loss_pde:1.03923416, loss_ib:1.16886091
# epoch 67: loss 12.727843
# epoch 68 loss_pde:1.03794897, loss_ib:1.14979196
# epoch 68: loss 12.535868
# epoch 69 loss_pde:1.03269672, loss_ib:1.13302183
# epoch 69: loss 12.362915
# epoch 70 loss_pde:1.02522218, loss_ib:1.11839020
# epoch 70: loss 12.209124
# epoch 71 loss_pde:1.01719272, loss_ib:1.10534632
# epoch 71: loss 12.070656
# epoch 72 loss_pde:1.01007307, loss_ib:1.09310400
# epoch 72: loss 11.941113
# epoch 73 loss_pde:1.00503707, loss_ib:1.08088470
# epoch 73: loss 11.813885
# epoch 74 loss_pde:1.00289845, loss_ib:1.06816590
# epoch 74: loss 11.684557
# epoch 75 loss_pde:1.00406086, loss_ib:1.05483615
# epoch 75: loss 11.552423
# epoch 76 loss_pde:1.00849247, loss_ib:1.04119706
# epoch 76: loss 11.420463
# epoch 77 loss_pde:1.01573932, loss_ib:1.02781367
# epoch 77: loss 11.293877
# epoch 78 loss_pde:1.02499032, loss_ib:1.01527297
# epoch 78: loss 11.177720
# epoch 79 loss_pde:1.03520238, loss_ib:1.00395691
# epoch 79: loss 11.074771
# epoch 80 loss_pde:1.04528260, loss_ib:0.99392581
# epoch 80: loss 10.984541
# epoch 81 loss_pde:1.05430233, loss_ib:0.98495448
# epoch 81: loss 10.903847
# epoch 82 loss_pde:1.06169295, loss_ib:0.97668433
# epoch 82: loss 10.828537
# epoch 83 loss_pde:1.06737173, loss_ib:0.96879596
# epoch 83: loss 10.755331
# epoch 84 loss_pde:1.07174921, loss_ib:0.96110982
# epoch 84: loss 10.682848
# epoch 85 loss_pde:1.07562053, loss_ib:0.95357883
# epoch 85: loss 10.611409
# epoch 86 loss_pde:1.07996440, loss_ib:0.94621497
# epoch 86: loss 10.542114
# epoch 87 loss_pde:1.08570230, loss_ib:0.93901730
# epoch 87: loss 10.475875
# epoch 88 loss_pde:1.09346867, loss_ib:0.93195003
# epoch 88: loss 10.412969
# epoch 89 loss_pde:1.10344160, loss_ib:0.92497009
# epoch 89: loss 10.353142
# epoch 90 loss_pde:1.11526763, loss_ib:0.91806567
# epoch 90: loss 10.295924
# epoch 91 loss_pde:1.12810838, loss_ib:0.91127443
# epoch 91: loss 10.240852
# epoch 92 loss_pde:1.14080346, loss_ib:0.90467191
# epoch 92: loss 10.187522
# epoch 93 loss_pde:1.15211594, loss_ib:0.89834499
# epoch 93: loss 10.135566
# epoch 94 loss_pde:1.16098070, loss_ib:0.89237088
# epoch 94: loss 10.084690
# epoch 95 loss_pde:1.16668665, loss_ib:0.88680398
# epoch 95: loss 10.034727
# epoch 96 loss_pde:1.16894460, loss_ib:0.88166547
# epoch 96: loss 9.985599
# epoch 97 loss_pde:1.16784728, loss_ib:0.87693721
# epoch 97: loss 9.937220
# epoch 98 loss_pde:1.16377926, loss_ib:0.87256044
# epoch 98: loss 9.889383
# epoch 99 loss_pde:1.15731752, loss_ib:0.86845291
# epoch 99: loss 9.841846
# epoch 100 loss_pde:1.14913821, loss_ib:0.86453891
# epoch 100: loss 9.794528
# epoch 101 loss_pde:1.13991582, loss_ib:0.86077529
# epoch 101: loss 9.747668
# epoch 102 loss_pde:1.13021576, loss_ib:0.85715544
# epoch 102: loss 9.701770
# epoch 103 loss_pde:1.12040770, loss_ib:0.85368991
# epoch 103: loss 9.657308
# epoch 104 loss_pde:1.11064804, loss_ib:0.85037893
# epoch 104: loss 9.614437
# epoch 105 loss_pde:1.10094583, loss_ib:0.84719896
# epoch 105: loss 9.572935
# epoch 106 loss_pde:1.09128296, loss_ib:0.84410793
# epoch 106: loss 9.532362
# epoch 107 loss_pde:1.08172035, loss_ib:0.84106159
# epoch 107: loss 9.492336
# epoch 108 loss_pde:1.07242787, loss_ib:0.83802968
# epoch 108: loss 9.452724
# epoch 109 loss_pde:1.06362569, loss_ib:0.83499908
# epoch 109: loss 9.413616
# epoch 110 loss_pde:1.05547321, loss_ib:0.83197337
# epoch 110: loss 9.375207
# epoch 111 loss_pde:1.04796481, loss_ib:0.82896864
# epoch 111: loss 9.337651
# epoch 112 loss_pde:1.04088521, loss_ib:0.82601392
# epoch 112: loss 9.301024
# epoch 113 loss_pde:1.03383875, loss_ib:0.82314748
# epoch 113: loss 9.265314
# epoch 114 loss_pde:1.02634311, loss_ib:0.82040972
# epoch 114: loss 9.230440
# epoch 115 loss_pde:1.01794922, loss_ib:0.81783283
# epoch 115: loss 9.196278
# epoch 116 loss_pde:1.00835228, loss_ib:0.81543368
# epoch 116: loss 9.162689
# epoch 117 loss_pde:0.99746418, loss_ib:0.81321096
# epoch 117: loss 9.129574
# epoch 118 loss_pde:0.98543161, loss_ib:0.81114638
# epoch 118: loss 9.096895
# epoch 119 loss_pde:0.97259533, loss_ib:0.80920810
# epoch 119: loss 9.064676
# epoch 120 loss_pde:0.95941031, loss_ib:0.80735326
# epoch 120: loss 9.032943
# epoch 121 loss_pde:0.94634682, loss_ib:0.80553418
# epoch 121: loss 9.001689
# epoch 122 loss_pde:0.93380314, loss_ib:0.80370694
# epoch 122: loss 8.970873
# epoch 123 loss_pde:0.92204738, loss_ib:0.80184072
# epoch 123: loss 8.940454
# epoch 124 loss_pde:0.91119552, loss_ib:0.79992354
# epoch 124: loss 8.910431
# epoch 125 loss_pde:0.90122628, loss_ib:0.79795951
# epoch 125: loss 8.880821
# epoch 126 loss_pde:0.89202046, loss_ib:0.79596138
# epoch 126: loss 8.851634
# epoch 127 loss_pde:0.88340974, loss_ib:0.79394364
# epoch 127: loss 8.822846
# epoch 128 loss_pde:0.87522620, loss_ib:0.79191840
# epoch 128: loss 8.794410
# epoch 129 loss_pde:0.86733812, loss_ib:0.78989410
# epoch 129: loss 8.766279
# epoch 130 loss_pde:0.85966504, loss_ib:0.78787673
# epoch 130: loss 8.738432
# epoch 131 loss_pde:0.85217571, loss_ib:0.78586996
# epoch 131: loss 8.710876
# epoch 132 loss_pde:0.84487134, loss_ib:0.78387576
# epoch 132: loss 8.683629
# epoch 133 loss_pde:0.83776438, loss_ib:0.78189456
# epoch 133: loss 8.656711
# epoch 134 loss_pde:0.83085692, loss_ib:0.77992719
# epoch 134: loss 8.630129
# epoch 135 loss_pde:0.82412803, loss_ib:0.77797520
# epoch 135: loss 8.603880
# epoch 136 loss_pde:0.81753063, loss_ib:0.77604139
# epoch 136: loss 8.577945
# epoch 137 loss_pde:0.81100106, loss_ib:0.77412897
# epoch 137: loss 8.552291
# epoch 138 loss_pde:0.80447257, loss_ib:0.77224219
# epoch 138: loss 8.526895
# epoch 139 loss_pde:0.79789203, loss_ib:0.77038491
# epoch 139: loss 8.501740
# epoch 140 loss_pde:0.79122829, loss_ib:0.76856041
# epoch 140: loss 8.476832
# epoch 141 loss_pde:0.78447443, loss_ib:0.76677001
# epoch 141: loss 8.452174
# epoch 142 loss_pde:0.77764243, loss_ib:0.76501268
# epoch 142: loss 8.427770
# epoch 143 loss_pde:0.77075684, loss_ib:0.76328528
# epoch 143: loss 8.403609
# epoch 144 loss_pde:0.76384974, loss_ib:0.76158297
# epoch 144: loss 8.379679
# epoch 145 loss_pde:0.75695574, loss_ib:0.75990152
# epoch 145: loss 8.355971
# epoch 146 loss_pde:0.75010973, loss_ib:0.75823641
# epoch 146: loss 8.332474
# epoch 147 loss_pde:0.74334347, loss_ib:0.75658411
# epoch 147: loss 8.309185
# epoch 148 loss_pde:0.73668551, loss_ib:0.75494045
# epoch 148: loss 8.286090
# epoch 149 loss_pde:0.73015904, loss_ib:0.75330228
# epoch 149: loss 8.263182
# epoch 150 loss_pde:0.72377825, loss_ib:0.75166708
# epoch 150: loss 8.240449
# epoch 151 loss_pde:0.71754283, loss_ib:0.75003415
# epoch 151: loss 8.217884
# epoch 152 loss_pde:0.71143144, loss_ib:0.74840528
# epoch 152: loss 8.195484
# epoch 153 loss_pde:0.70539832, loss_ib:0.74678433
# epoch 153: loss 8.173242
# epoch 154 loss_pde:0.69937587, loss_ib:0.74517745
# epoch 154: loss 8.151151
# epoch 155 loss_pde:0.69328529, loss_ib:0.74359179
# epoch 155: loss 8.129203
# epoch 156 loss_pde:0.68705225, loss_ib:0.74203360
# epoch 156: loss 8.107388
# epoch 157 loss_pde:0.68062288, loss_ib:0.74050689
# epoch 157: loss 8.085691
# epoch 158 loss_pde:0.67397654, loss_ib:0.73901331
# epoch 158: loss 8.064110
# epoch 159 loss_pde:0.66713166, loss_ib:0.73754960
# epoch 159: loss 8.042627
# epoch 160 loss_pde:0.66013926, loss_ib:0.73611075
# epoch 160: loss 8.021247
# epoch 161 loss_pde:0.65307188, loss_ib:0.73468900
# epoch 161: loss 7.999962
# epoch 162 loss_pde:0.64600652, loss_ib:0.73327637
# epoch 162: loss 7.978770
# epoch 163 loss_pde:0.63900942, loss_ib:0.73186523
# epoch 163: loss 7.957662
# epoch 164 loss_pde:0.63212562, loss_ib:0.73045063
# epoch 164: loss 7.936632
# epoch 165 loss_pde:0.62537408, loss_ib:0.72903019
# epoch 165: loss 7.915676
# epoch 166 loss_pde:0.61875236, loss_ib:0.72760397
# epoch 166: loss 7.894792
# epoch 167 loss_pde:0.61224395, loss_ib:0.72617328
# epoch 167: loss 7.873977
# epoch 168 loss_pde:0.60582787, loss_ib:0.72474021
# epoch 168: loss 7.853230
# epoch 169 loss_pde:0.59948754, loss_ib:0.72330636
# epoch 169: loss 7.832551
# epoch 170 loss_pde:0.59321553, loss_ib:0.72187221
# epoch 170: loss 7.811938
# epoch 171 loss_pde:0.58701491, loss_ib:0.72043777
# epoch 171: loss 7.791392
# epoch 172 loss_pde:0.58089662, loss_ib:0.71900165
# epoch 172: loss 7.770913
# epoch 173 loss_pde:0.57487547, loss_ib:0.71756274
# epoch 173: loss 7.750503
# epoch 174 loss_pde:0.56896561, loss_ib:0.71611953
# epoch 174: loss 7.730161
# epoch 175 loss_pde:0.56317794, loss_ib:0.71467102
# epoch 175: loss 7.709888
# epoch 176 loss_pde:0.55751890, loss_ib:0.71321690
# epoch 176: loss 7.689688
# epoch 177 loss_pde:0.55199194, loss_ib:0.71175718
# epoch 177: loss 7.669564
# epoch 178 loss_pde:0.54659873, loss_ib:0.71029150
# epoch 178: loss 7.649514
# epoch 179 loss_pde:0.54134095, loss_ib:0.70882046
# epoch 179: loss 7.629545
# epoch 180 loss_pde:0.53622061, loss_ib:0.70734394
# epoch 180: loss 7.609660
# epoch 181 loss_pde:0.53123969, loss_ib:0.70586216
# epoch 181: loss 7.589861
# epoch 182 loss_pde:0.52639967, loss_ib:0.70437527
# epoch 182: loss 7.570152
# epoch 183 loss_pde:0.52170151, loss_ib:0.70288354
# epoch 183: loss 7.550537
# epoch 184 loss_pde:0.51714593, loss_ib:0.70138729
# epoch 184: loss 7.531019
# epoch 185 loss_pde:0.51273382, loss_ib:0.69988692
# epoch 185: loss 7.511603
# epoch 186 loss_pde:0.50846738, loss_ib:0.69838262
# epoch 186: loss 7.492293
# epoch 187 loss_pde:0.50434893, loss_ib:0.69687480
# epoch 187: loss 7.473097
# epoch 188 loss_pde:0.50038135, loss_ib:0.69536328
# epoch 188: loss 7.454014
# epoch 189 loss_pde:0.49656549, loss_ib:0.69384873
# epoch 189: loss 7.435052
# epoch 190 loss_pde:0.49289984, loss_ib:0.69233167
# epoch 190: loss 7.416217
# epoch 191 loss_pde:0.48937932, loss_ib:0.69081295
# epoch 191: loss 7.397509
# epoch 192 loss_pde:0.48599577, loss_ib:0.68929398
# epoch 192: loss 7.378935
# epoch 193 loss_pde:0.48274064, loss_ib:0.68777603
# epoch 193: loss 7.360501
# epoch 194 loss_pde:0.47960672, loss_ib:0.68626010
# epoch 194: loss 7.342208
# epoch 195 loss_pde:0.47659057, loss_ib:0.68474734
# epoch 195: loss 7.324064
# epoch 196 loss_pde:0.47369367, loss_ib:0.68323779
# epoch 196: loss 7.306072
# epoch 197 loss_pde:0.47092164, loss_ib:0.68173134
# epoch 197: loss 7.288235
# epoch 198 loss_pde:0.46828192, loss_ib:0.68022770
# epoch 198: loss 7.270559
# epoch 199 loss_pde:0.46578142, loss_ib:0.67872643
# epoch 199: loss 7.253046
# epoch 200 loss_pde:0.46342325, loss_ib:0.67722774
# epoch 200: loss 7.235701
# epoch 201 loss_pde:0.46120626, loss_ib:0.67573208
# epoch 201: loss 7.218527
# epoch 202 loss_pde:0.45912474, loss_ib:0.67424029
# epoch 202: loss 7.201528
# epoch 203 loss_pde:0.45717061, loss_ib:0.67275345
# epoch 203: loss 7.184705
# epoch 204 loss_pde:0.45533553, loss_ib:0.67127287
# epoch 204: loss 7.168064
# epoch 205 loss_pde:0.45361334, loss_ib:0.66979921
# epoch 205: loss 7.151606
# epoch 206 loss_pde:0.45200074, loss_ib:0.66833293
# epoch 206: loss 7.135330
# epoch 207 loss_pde:0.45049724, loss_ib:0.66687447
# epoch 207: loss 7.119242
# epoch 208 loss_pde:0.44910383, loss_ib:0.66542363
# epoch 208: loss 7.103340
# epoch 209 loss_pde:0.44782132, loss_ib:0.66398066
# epoch 209: loss 7.087628
# epoch 210 loss_pde:0.44664904, loss_ib:0.66254550
# epoch 210: loss 7.072104
# epoch 211 loss_pde:0.44558439, loss_ib:0.66111839
# epoch 211: loss 7.056768
# epoch 212 loss_pde:0.44462264, loss_ib:0.65969968
# epoch 212: loss 7.041619
# epoch 213 loss_pde:0.44375807, loss_ib:0.65828991
# epoch 213: loss 7.026657
# epoch 214 loss_pde:0.44298464, loss_ib:0.65688956
# epoch 214: loss 7.011880
# epoch 215 loss_pde:0.44229615, loss_ib:0.65549898
# epoch 215: loss 6.997286
# epoch 216 loss_pde:0.44168636, loss_ib:0.65411848
# epoch 216: loss 6.982871
# epoch 217 loss_pde:0.44114912, loss_ib:0.65274841
# epoch 217: loss 6.968633
# epoch 218 loss_pde:0.44067788, loss_ib:0.65138900
# epoch 218: loss 6.954568
# epoch 219 loss_pde:0.44026583, loss_ib:0.65004063
# epoch 219: loss 6.940672
# epoch 220 loss_pde:0.43990692, loss_ib:0.64870334
# epoch 220: loss 6.926940
# epoch 221 loss_pde:0.43959567, loss_ib:0.64737737
# epoch 221: loss 6.913370
# epoch 222 loss_pde:0.43932816, loss_ib:0.64606231
# epoch 222: loss 6.899951
# epoch 223 loss_pde:0.43910134, loss_ib:0.64475816
# epoch 223: loss 6.886683
# epoch 224 loss_pde:0.43891269, loss_ib:0.64346421
# epoch 224: loss 6.873555
# epoch 225 loss_pde:0.43875968, loss_ib:0.64218050
# epoch 225: loss 6.860565
# epoch 226 loss_pde:0.43863916, loss_ib:0.64090639
# epoch 226: loss 6.847703
# epoch 227 loss_pde:0.43854678, loss_ib:0.63964176
# epoch 227: loss 6.834964
# epoch 228 loss_pde:0.43847799, loss_ib:0.63838649
# epoch 228: loss 6.822343
# epoch 229 loss_pde:0.43842849, loss_ib:0.63714015
# epoch 229: loss 6.809830
# epoch 230 loss_pde:0.43839455, loss_ib:0.63590252
# epoch 230: loss 6.797420
# epoch 231 loss_pde:0.43837327, loss_ib:0.63467306
# epoch 231: loss 6.785104
# epoch 232 loss_pde:0.43836284, loss_ib:0.63345128
# epoch 232: loss 6.772876
# epoch 233 loss_pde:0.43836126, loss_ib:0.63223684
# epoch 233: loss 6.760730
# epoch 234 loss_pde:0.43836695, loss_ib:0.63102901
# epoch 234: loss 6.748657
# epoch 235 loss_pde:0.43837798, loss_ib:0.62982750
# epoch 235: loss 6.736653
# epoch 236 loss_pde:0.43839267, loss_ib:0.62863177
# epoch 236: loss 6.724710
# epoch 237 loss_pde:0.43840972, loss_ib:0.62744129
# epoch 237: loss 6.712823
# epoch 238 loss_pde:0.43842915, loss_ib:0.62625533
# epoch 238: loss 6.700983
# epoch 239 loss_pde:0.43845177, loss_ib:0.62507331
# epoch 239: loss 6.689185
# epoch 240 loss_pde:0.43847889, loss_ib:0.62389469
# epoch 240: loss 6.677426
# epoch 241 loss_pde:0.43851185, loss_ib:0.62271875
# epoch 241: loss 6.665699
# epoch 242 loss_pde:0.43855149, loss_ib:0.62154472
# epoch 242: loss 6.653999
# epoch 243 loss_pde:0.43859774, loss_ib:0.62037230
# epoch 243: loss 6.642321
# epoch 244 loss_pde:0.43864995, loss_ib:0.61920106
# epoch 244: loss 6.630661
# epoch 245 loss_pde:0.43870714, loss_ib:0.61803061
# epoch 245: loss 6.619013
# epoch 246 loss_pde:0.43876830, loss_ib:0.61686075
# epoch 246: loss 6.607376
# epoch 247 loss_pde:0.43883339, loss_ib:0.61569118
# epoch 247: loss 6.595745
# epoch 248 loss_pde:0.43890271, loss_ib:0.61452127
# epoch 248: loss 6.584116
# epoch 249 loss_pde:0.43897685, loss_ib:0.61335087
# epoch 249: loss 6.572485
# epoch 250 loss_pde:0.43905649, loss_ib:0.61217958
# epoch 250: loss 6.560852
# epoch 251 loss_pde:0.43914223, loss_ib:0.61100703
# epoch 251: loss 6.549212
# epoch 252 loss_pde:0.43923438, loss_ib:0.60983300
# epoch 252: loss 6.537564
# epoch 253 loss_pde:0.43933323, loss_ib:0.60865712
# epoch 253: loss 6.525905
# epoch 254 loss_pde:0.43943900, loss_ib:0.60747939
# epoch 254: loss 6.514233
# epoch 255 loss_pde:0.43955255, loss_ib:0.60629934
# epoch 255: loss 6.502546
# epoch 256 loss_pde:0.43967405, loss_ib:0.60511667
# epoch 256: loss 6.490840
# epoch 257 loss_pde:0.43980372, loss_ib:0.60393167
# epoch 257: loss 6.479120
# epoch 258 loss_pde:0.43994173, loss_ib:0.60274363
# epoch 258: loss 6.467378
# epoch 259 loss_pde:0.44008780, loss_ib:0.60155290
# epoch 259: loss 6.455617
# epoch 260 loss_pde:0.44024163, loss_ib:0.60035920
# epoch 260: loss 6.443834
# epoch 261 loss_pde:0.44040340, loss_ib:0.59916258
# epoch 261: loss 6.432029
# epoch 262 loss_pde:0.44057333, loss_ib:0.59796262
# epoch 262: loss 6.420199
# epoch 263 loss_pde:0.44075164, loss_ib:0.59675962
# epoch 263: loss 6.408348
# epoch 264 loss_pde:0.44093883, loss_ib:0.59555310
# epoch 264: loss 6.396470
# epoch 265 loss_pde:0.44113526, loss_ib:0.59434342
# epoch 265: loss 6.384570
# epoch 266 loss_pde:0.44134128, loss_ib:0.59313023
# epoch 266: loss 6.372643
# epoch 267 loss_pde:0.44155723, loss_ib:0.59191346
# epoch 267: loss 6.360692
# epoch 268 loss_pde:0.44178298, loss_ib:0.59069341
# epoch 268: loss 6.348717
# epoch 269 loss_pde:0.44201940, loss_ib:0.58946979
# epoch 269: loss 6.336718
# epoch 270 loss_pde:0.44226685, loss_ib:0.58824265
# epoch 270: loss 6.324693
# epoch 271 loss_pde:0.44252667, loss_ib:0.58701199
# epoch 271: loss 6.312647
# epoch 272 loss_pde:0.44279957, loss_ib:0.58577770
# epoch 272: loss 6.300577
# epoch 273 loss_pde:0.44308653, loss_ib:0.58453977
# epoch 273: loss 6.288485
# epoch 274 loss_pde:0.44338813, loss_ib:0.58329833
# epoch 274: loss 6.276371
# epoch 275 loss_pde:0.44370499, loss_ib:0.58205324
# epoch 275: loss 6.264237
# epoch 276 loss_pde:0.44403791, loss_ib:0.58080488
# epoch 276: loss 6.252087
# epoch 277 loss_pde:0.44438791, loss_ib:0.57955301
# epoch 277: loss 6.239918
# epoch 278 loss_pde:0.44475609, loss_ib:0.57829773
# epoch 278: loss 6.227733
# epoch 279 loss_pde:0.44514376, loss_ib:0.57703888
# epoch 279: loss 6.215532
# epoch 280 loss_pde:0.44555217, loss_ib:0.57577688
# epoch 280: loss 6.203321
# epoch 281 loss_pde:0.44598240, loss_ib:0.57451165
# epoch 281: loss 6.191099
# epoch 282 loss_pde:0.44643557, loss_ib:0.57324308
# epoch 282: loss 6.178866
# epoch 283 loss_pde:0.44691283, loss_ib:0.57197148
# epoch 283: loss 6.166627
# epoch 284 loss_pde:0.44741511, loss_ib:0.57069683
# epoch 284: loss 6.154384
# epoch 285 loss_pde:0.44794333, loss_ib:0.56941932
# epoch 285: loss 6.142137
# epoch 286 loss_pde:0.44849855, loss_ib:0.56813908
# epoch 286: loss 6.129889
# epoch 287 loss_pde:0.44908208, loss_ib:0.56685603
# epoch 287: loss 6.117642
# epoch 288 loss_pde:0.44969434, loss_ib:0.56557047
# epoch 288: loss 6.105399
# epoch 289 loss_pde:0.45033601, loss_ib:0.56428254
# epoch 289: loss 6.093161
# epoch 290 loss_pde:0.45100754, loss_ib:0.56299245
# epoch 290: loss 6.080932
# epoch 291 loss_pde:0.45170942, loss_ib:0.56170022
# epoch 291: loss 6.068712
# epoch 292 loss_pde:0.45244181, loss_ib:0.56040621
# epoch 292: loss 6.056504
# epoch 293 loss_pde:0.45320517, loss_ib:0.55911034
# epoch 293: loss 6.044309
# epoch 294 loss_pde:0.45399961, loss_ib:0.55781299
# epoch 294: loss 6.032129
# epoch 295 loss_pde:0.45482492, loss_ib:0.55651438
# epoch 295: loss 6.019969
# epoch 296 loss_pde:0.45568091, loss_ib:0.55521470
# epoch 296: loss 6.007828
# epoch 297 loss_pde:0.45656732, loss_ib:0.55391413
# epoch 297: loss 5.995708
# epoch 298 loss_pde:0.45748359, loss_ib:0.55261278
# epoch 298: loss 5.983612
# epoch 299 loss_pde:0.45842934, loss_ib:0.55131108
# epoch 299: loss 5.971540
# epoch 300 loss_pde:0.45940357, loss_ib:0.55000907
# epoch 300: loss 5.959494
# epoch 301 loss_pde:0.46040565, loss_ib:0.54870713
# epoch 301: loss 5.947477
# epoch 302 loss_pde:0.46143496, loss_ib:0.54740542
# epoch 302: loss 5.935489
# epoch 303 loss_pde:0.46249020, loss_ib:0.54610407
# epoch 303: loss 5.923531
# epoch 304 loss_pde:0.46357036, loss_ib:0.54480356
# epoch 304: loss 5.911606
# epoch 305 loss_pde:0.46467456, loss_ib:0.54350382
# epoch 305: loss 5.899713
# epoch 306 loss_pde:0.46580154, loss_ib:0.54220510
# epoch 306: loss 5.887853
# epoch 307 loss_pde:0.46695036, loss_ib:0.54090768
# epoch 307: loss 5.876027
# epoch 308 loss_pde:0.46811995, loss_ib:0.53961176
# epoch 308: loss 5.864238
# epoch 309 loss_pde:0.46930924, loss_ib:0.53831744
# epoch 309: loss 5.852484
# epoch 310 loss_pde:0.47051689, loss_ib:0.53702486
# epoch 310: loss 5.840765
# epoch 311 loss_pde:0.47174177, loss_ib:0.53573436
# epoch 311: loss 5.829085
# epoch 312 loss_pde:0.47298300, loss_ib:0.53444570
# epoch 312: loss 5.817440
# epoch 313 loss_pde:0.47423917, loss_ib:0.53315943
# epoch 313: loss 5.805834
# epoch 314 loss_pde:0.47550973, loss_ib:0.53187531
# epoch 314: loss 5.794263
# epoch 315 loss_pde:0.47679353, loss_ib:0.53059369
# epoch 315: loss 5.782730
# epoch 316 loss_pde:0.47808996, loss_ib:0.52931434
# epoch 316: loss 5.771233
# epoch 317 loss_pde:0.47939789, loss_ib:0.52803767
# epoch 317: loss 5.759774
# epoch 318 loss_pde:0.48071688, loss_ib:0.52676344
# epoch 318: loss 5.748351
# epoch 319 loss_pde:0.48204625, loss_ib:0.52549165
# epoch 319: loss 5.736963
# epoch 320 loss_pde:0.48338506, loss_ib:0.52422249
# epoch 320: loss 5.725610
# epoch 321 loss_pde:0.48473281, loss_ib:0.52295589
# epoch 321: loss 5.714292
# epoch 322 loss_pde:0.48608911, loss_ib:0.52169180
# epoch 322: loss 5.703007
# epoch 323 loss_pde:0.48745355, loss_ib:0.52043015
# epoch 323: loss 5.691755
# epoch 324 loss_pde:0.48882544, loss_ib:0.51917100
# epoch 324: loss 5.680535
# epoch 325 loss_pde:0.49020439, loss_ib:0.51791412
# epoch 325: loss 5.669345
# epoch 326 loss_pde:0.49158978, loss_ib:0.51665974
# epoch 326: loss 5.658187
# epoch 327 loss_pde:0.49298137, loss_ib:0.51540744
# epoch 327: loss 5.647056
# epoch 328 loss_pde:0.49437851, loss_ib:0.51415741
# epoch 328: loss 5.635952
# epoch 329 loss_pde:0.49578080, loss_ib:0.51290947
# epoch 329: loss 5.624876
# epoch 330 loss_pde:0.49718776, loss_ib:0.51166368
# epoch 330: loss 5.613824
# epoch 331 loss_pde:0.49859887, loss_ib:0.51041967
# epoch 331: loss 5.602796
# epoch 332 loss_pde:0.50001353, loss_ib:0.50917745
# epoch 332: loss 5.591788
# epoch 333 loss_pde:0.50143093, loss_ib:0.50793713
# epoch 333: loss 5.580802
# epoch 334 loss_pde:0.50285065, loss_ib:0.50669849
# epoch 334: loss 5.569836
# epoch 335 loss_pde:0.50427186, loss_ib:0.50546128
# epoch 335: loss 5.558885
# epoch 336 loss_pde:0.50569367, loss_ib:0.50422561
# epoch 336: loss 5.547950
# epoch 337 loss_pde:0.50711536, loss_ib:0.50299138
# epoch 337: loss 5.537029
# epoch 338 loss_pde:0.50853598, loss_ib:0.50175840
# epoch 338: loss 5.526120
# epoch 339 loss_pde:0.50995457, loss_ib:0.50052673
# epoch 339: loss 5.515222
# epoch 340 loss_pde:0.51137000, loss_ib:0.49929613
# epoch 340: loss 5.504332
# epoch 341 loss_pde:0.51278174, loss_ib:0.49806648
# epoch 341: loss 5.493446
# epoch 342 loss_pde:0.51418841, loss_ib:0.49683788
# epoch 342: loss 5.482567
# epoch 343 loss_pde:0.51558924, loss_ib:0.49561000
# epoch 343: loss 5.471689
# epoch 344 loss_pde:0.51698327, loss_ib:0.49438301
# epoch 344: loss 5.460814
# epoch 345 loss_pde:0.51836932, loss_ib:0.49315655
# epoch 345: loss 5.449934
# epoch 346 loss_pde:0.51974648, loss_ib:0.49193072
# epoch 346: loss 5.439054
# epoch 347 loss_pde:0.52111393, loss_ib:0.49070525
# epoch 347: loss 5.428166
# epoch 348 loss_pde:0.52247083, loss_ib:0.48948005
# epoch 348: loss 5.417272
# epoch 349 loss_pde:0.52381647, loss_ib:0.48825496
# epoch 349: loss 5.406366
# epoch 350 loss_pde:0.52514982, loss_ib:0.48703003
# epoch 350: loss 5.395450
# epoch 351 loss_pde:0.52647024, loss_ib:0.48580486
# epoch 351: loss 5.384519
# epoch 352 loss_pde:0.52777719, loss_ib:0.48457947
# epoch 352: loss 5.373572
# epoch 353 loss_pde:0.52907014, loss_ib:0.48335373
# epoch 353: loss 5.362607
# epoch 354 loss_pde:0.53034878, loss_ib:0.48212725
# epoch 354: loss 5.351621
# epoch 355 loss_pde:0.53161252, loss_ib:0.48090017
# epoch 355: loss 5.340614
# epoch 356 loss_pde:0.53286117, loss_ib:0.47967210
# epoch 356: loss 5.329582
# epoch 357 loss_pde:0.53409445, loss_ib:0.47844279
# epoch 357: loss 5.318522
# epoch 358 loss_pde:0.53531194, loss_ib:0.47721231
# epoch 358: loss 5.307435
# epoch 359 loss_pde:0.53651392, loss_ib:0.47598028
# epoch 359: loss 5.296317
# epoch 360 loss_pde:0.53770006, loss_ib:0.47474656
# epoch 360: loss 5.285166
# epoch 361 loss_pde:0.53887039, loss_ib:0.47351092
# epoch 361: loss 5.273980
# epoch 362 loss_pde:0.54002500, loss_ib:0.47227317
# epoch 362: loss 5.262756
# epoch 363 loss_pde:0.54116404, loss_ib:0.47103310
# epoch 363: loss 5.251495
# epoch 364 loss_pde:0.54228759, loss_ib:0.46979052
# epoch 364: loss 5.240192
# epoch 365 loss_pde:0.54339582, loss_ib:0.46854520
# epoch 365: loss 5.228848
# epoch 366 loss_pde:0.54448867, loss_ib:0.46729699
# epoch 366: loss 5.217459
# epoch 367 loss_pde:0.54556644, loss_ib:0.46604565
# epoch 367: loss 5.206023
# epoch 368 loss_pde:0.54662937, loss_ib:0.46479100
# epoch 368: loss 5.194540
# epoch 369 loss_pde:0.54767787, loss_ib:0.46353281
# epoch 369: loss 5.183006
# epoch 370 loss_pde:0.54871202, loss_ib:0.46227092
# epoch 370: loss 5.171421
# epoch 371 loss_pde:0.54973215, loss_ib:0.46100515
# epoch 371: loss 5.159784
# epoch 372 loss_pde:0.55073869, loss_ib:0.45973524
# epoch 372: loss 5.148091
# epoch 373 loss_pde:0.55173188, loss_ib:0.45846108
# epoch 373: loss 5.136343
# epoch 374 loss_pde:0.55271220, loss_ib:0.45718235
# epoch 374: loss 5.124536
# epoch 375 loss_pde:0.55368012, loss_ib:0.45589903
# epoch 375: loss 5.112670
# epoch 376 loss_pde:0.55463612, loss_ib:0.45461085
# epoch 376: loss 5.100745
# epoch 377 loss_pde:0.55558038, loss_ib:0.45331773
# epoch 377: loss 5.088758
# epoch 378 loss_pde:0.55651379, loss_ib:0.45201942
# epoch 378: loss 5.076708
# epoch 379 loss_pde:0.55743694, loss_ib:0.45071572
# epoch 379: loss 5.064594
# epoch 380 loss_pde:0.55835021, loss_ib:0.44940653
# epoch 380: loss 5.052415
# epoch 381 loss_pde:0.55925441, loss_ib:0.44809157
# epoch 381: loss 5.040170
# epoch 382 loss_pde:0.56014979, loss_ib:0.44677091
# epoch 382: loss 5.027859
# epoch 383 loss_pde:0.56103712, loss_ib:0.44544423
# epoch 383: loss 5.015479
# epoch 384 loss_pde:0.56191701, loss_ib:0.44411150
# epoch 384: loss 5.003032
# epoch 385 loss_pde:0.56279004, loss_ib:0.44277257
# epoch 385: loss 4.990516
# epoch 386 loss_pde:0.56365705, loss_ib:0.44142726
# epoch 386: loss 4.977930
# epoch 387 loss_pde:0.56451851, loss_ib:0.44007552
# epoch 387: loss 4.965273
# epoch 388 loss_pde:0.56537509, loss_ib:0.43871731
# epoch 388: loss 4.952548
# epoch 389 loss_pde:0.56622726, loss_ib:0.43735239
# epoch 389: loss 4.939751
# epoch 390 loss_pde:0.56707561, loss_ib:0.43598083
# epoch 390: loss 4.926884
# epoch 391 loss_pde:0.56792033, loss_ib:0.43460268
# epoch 391: loss 4.913947
# epoch 392 loss_pde:0.56876248, loss_ib:0.43321767
# epoch 392: loss 4.900939
# epoch 393 loss_pde:0.56960225, loss_ib:0.43182588
# epoch 393: loss 4.887861
# epoch 394 loss_pde:0.57044017, loss_ib:0.43042731
# epoch 394: loss 4.874713
# epoch 395 loss_pde:0.57127643, loss_ib:0.42902192
# epoch 395: loss 4.861496
# epoch 396 loss_pde:0.57211161, loss_ib:0.42760983
# epoch 396: loss 4.848210
# epoch 397 loss_pde:0.57294595, loss_ib:0.42619100
# epoch 397: loss 4.834856
# epoch 398 loss_pde:0.57377988, loss_ib:0.42476556
# epoch 398: loss 4.821435
# epoch 399 loss_pde:0.57461393, loss_ib:0.42333344
# epoch 399: loss 4.807949
# epoch 400 loss_pde:0.57544810, loss_ib:0.42189482
# epoch 400: loss 4.794396
# epoch 401 loss_pde:0.57628280, loss_ib:0.42044973
# epoch 401: loss 4.780780
# epoch 402 loss_pde:0.57711792, loss_ib:0.41899839
# epoch 402: loss 4.767102
# epoch 403 loss_pde:0.57795393, loss_ib:0.41754091
# epoch 403: loss 4.753363
# epoch 404 loss_pde:0.57879084, loss_ib:0.41607732
# epoch 404: loss 4.739564
# epoch 405 loss_pde:0.57962894, loss_ib:0.41460794
# epoch 405: loss 4.725708
# epoch 406 loss_pde:0.58046806, loss_ib:0.41313288
# epoch 406: loss 4.711797
# epoch 407 loss_pde:0.58130813, loss_ib:0.41165239
# epoch 407: loss 4.697832
# epoch 408 loss_pde:0.58214903, loss_ib:0.41016671
# epoch 408: loss 4.683816
# epoch 409 loss_pde:0.58299077, loss_ib:0.40867594
# epoch 409: loss 4.669750
# epoch 410 loss_pde:0.58383286, loss_ib:0.40718055
# epoch 410: loss 4.655638
# epoch 411 loss_pde:0.58467501, loss_ib:0.40568075
# epoch 411: loss 4.641482
# epoch 412 loss_pde:0.58551681, loss_ib:0.40417683
# epoch 412: loss 4.627285
# epoch 413 loss_pde:0.58635777, loss_ib:0.40266913
# epoch 413: loss 4.613049
# epoch 414 loss_pde:0.58719707, loss_ib:0.40115798
# epoch 414: loss 4.598777
# epoch 415 loss_pde:0.58803427, loss_ib:0.39964363
# epoch 415: loss 4.584471
# epoch 416 loss_pde:0.58886820, loss_ib:0.39812672
# epoch 416: loss 4.570136
# epoch 417 loss_pde:0.58969796, loss_ib:0.39660740
# epoch 417: loss 4.555772
# epoch 418 loss_pde:0.59052265, loss_ib:0.39508626
# epoch 418: loss 4.541385
# epoch 419 loss_pde:0.59134126, loss_ib:0.39356357
# epoch 419: loss 4.526977
# epoch 420 loss_pde:0.59215212, loss_ib:0.39203995
# epoch 420: loss 4.512552
# epoch 421 loss_pde:0.59295446, loss_ib:0.39051563
# epoch 421: loss 4.498111
# epoch 422 loss_pde:0.59374660, loss_ib:0.38899118
# epoch 422: loss 4.483658
# epoch 423 loss_pde:0.59452713, loss_ib:0.38746709
# epoch 423: loss 4.469198
# epoch 424 loss_pde:0.59529430, loss_ib:0.38594377
# epoch 424: loss 4.454732
# epoch 425 loss_pde:0.59604657, loss_ib:0.38442174
# epoch 425: loss 4.440264
# epoch 426 loss_pde:0.59678221, loss_ib:0.38290149
# epoch 426: loss 4.425797
# epoch 427 loss_pde:0.59749937, loss_ib:0.38138339
# epoch 427: loss 4.411333
# epoch 428 loss_pde:0.59819603, loss_ib:0.37986809
# epoch 428: loss 4.396877
# epoch 429 loss_pde:0.59887052, loss_ib:0.37835589
# epoch 429: loss 4.382429
# epoch 430 loss_pde:0.59952092, loss_ib:0.37684736
# epoch 430: loss 4.367994
# epoch 431 loss_pde:0.60014516, loss_ib:0.37534285
# epoch 431: loss 4.353574
# epoch 432 loss_pde:0.60074109, loss_ib:0.37384301
# epoch 432: loss 4.339171
# epoch 433 loss_pde:0.60130668, loss_ib:0.37234801
# epoch 433: loss 4.324787
# epoch 434 loss_pde:0.60183984, loss_ib:0.37085855
# epoch 434: loss 4.310425
# epoch 435 loss_pde:0.60233873, loss_ib:0.36937478
# epoch 435: loss 4.296086
# epoch 436 loss_pde:0.60280126, loss_ib:0.36789715
# epoch 436: loss 4.281773
# epoch 437 loss_pde:0.60322565, loss_ib:0.36642605
# epoch 437: loss 4.267486
# epoch 438 loss_pde:0.60360968, loss_ib:0.36496180
# epoch 438: loss 4.253228
# epoch 439 loss_pde:0.60395169, loss_ib:0.36350471
# epoch 439: loss 4.238998
# epoch 440 loss_pde:0.60424972, loss_ib:0.36205503
# epoch 440: loss 4.224800
# epoch 441 loss_pde:0.60450196, loss_ib:0.36061311
# epoch 441: loss 4.210633
# epoch 442 loss_pde:0.60470724, loss_ib:0.35917896
# epoch 442: loss 4.196497
# epoch 443 loss_pde:0.60486388, loss_ib:0.35775286
# epoch 443: loss 4.182392
# epoch 444 loss_pde:0.60497069, loss_ib:0.35633487
# epoch 444: loss 4.168320
# epoch 445 loss_pde:0.60502589, loss_ib:0.35492527
# epoch 445: loss 4.154279
# epoch 446 loss_pde:0.60502875, loss_ib:0.35352397
# epoch 446: loss 4.140268
# epoch 447 loss_pde:0.60497802, loss_ib:0.35213113
# epoch 447: loss 4.126289
# epoch 448 loss_pde:0.60487312, loss_ib:0.35074660
# epoch 448: loss 4.112339
# epoch 449 loss_pde:0.60471368, loss_ib:0.34937036
# epoch 449: loss 4.098417
# epoch 450 loss_pde:0.60449862, loss_ib:0.34800237
# epoch 450: loss 4.084522
# epoch 451 loss_pde:0.60422790, loss_ib:0.34664249
# epoch 451: loss 4.070653
# epoch 452 loss_pde:0.60390127, loss_ib:0.34529060
# epoch 452: loss 4.056808
# epoch 453 loss_pde:0.60351861, loss_ib:0.34394652
# epoch 453: loss 4.042984
# epoch 454 loss_pde:0.60307997, loss_ib:0.34260997
# epoch 454: loss 4.029180
# epoch 455 loss_pde:0.60258597, loss_ib:0.34128067
# epoch 455: loss 4.015393
# epoch 456 loss_pde:0.60203707, loss_ib:0.33995831
# epoch 456: loss 4.001620
# epoch 457 loss_pde:0.60143363, loss_ib:0.33864263
# epoch 457: loss 3.987860
# epoch 458 loss_pde:0.60077655, loss_ib:0.33733323
# epoch 458: loss 3.974109
# epoch 459 loss_pde:0.60006654, loss_ib:0.33602986
# epoch 459: loss 3.960365
# epoch 460 loss_pde:0.59930474, loss_ib:0.33473200
# epoch 460: loss 3.946625
# epoch 461 loss_pde:0.59849203, loss_ib:0.33343935
# epoch 461: loss 3.932886
# epoch 462 loss_pde:0.59763026, loss_ib:0.33215135
# epoch 462: loss 3.919144
# epoch 463 loss_pde:0.59672070, loss_ib:0.33086771
# epoch 463: loss 3.905398
# epoch 464 loss_pde:0.59576470, loss_ib:0.32958776
# epoch 464: loss 3.891642
# epoch 465 loss_pde:0.59476411, loss_ib:0.32831129
# epoch 465: loss 3.877877
# epoch 466 loss_pde:0.59372044, loss_ib:0.32703757
# epoch 466: loss 3.864096
# epoch 467 loss_pde:0.59263539, loss_ib:0.32576632
# epoch 467: loss 3.850299
# epoch 468 loss_pde:0.59151101, loss_ib:0.32449704
# epoch 468: loss 3.836481
# epoch 469 loss_pde:0.59034956, loss_ib:0.32322913
# epoch 469: loss 3.822641
# epoch 470 loss_pde:0.58915269, loss_ib:0.32196227
# epoch 470: loss 3.808775
# epoch 471 loss_pde:0.58792287, loss_ib:0.32069582
# epoch 471: loss 3.794881
# epoch 472 loss_pde:0.58666211, loss_ib:0.31942934
# epoch 472: loss 3.780956
# epoch 473 loss_pde:0.58537287, loss_ib:0.31816250
# epoch 473: loss 3.766998
# epoch 474 loss_pde:0.58405739, loss_ib:0.31689474
# epoch 474: loss 3.753005
# epoch 475 loss_pde:0.58271807, loss_ib:0.31562558
# epoch 475: loss 3.738974
# epoch 476 loss_pde:0.58135736, loss_ib:0.31435460
# epoch 476: loss 3.724904
# epoch 477 loss_pde:0.57997763, loss_ib:0.31308144
# epoch 477: loss 3.710792
# epoch 478 loss_pde:0.57858109, loss_ib:0.31180567
# epoch 478: loss 3.696638
# epoch 479 loss_pde:0.57717037, loss_ib:0.31052688
# epoch 479: loss 3.682439
# epoch 480 loss_pde:0.57574797, loss_ib:0.30924469
# epoch 480: loss 3.668195
# epoch 481 loss_pde:0.57431626, loss_ib:0.30795878
# epoch 481: loss 3.653904
# epoch 482 loss_pde:0.57287776, loss_ib:0.30666876
# epoch 482: loss 3.639565
# epoch 483 loss_pde:0.57143474, loss_ib:0.30537435
# epoch 483: loss 3.625178
# epoch 484 loss_pde:0.56998932, loss_ib:0.30407530
# epoch 484: loss 3.610742
# epoch 485 loss_pde:0.56854391, loss_ib:0.30277127
# epoch 485: loss 3.596257
# epoch 486 loss_pde:0.56710064, loss_ib:0.30146205
# epoch 486: loss 3.581721
# epoch 487 loss_pde:0.56566167, loss_ib:0.30014753
# epoch 487: loss 3.567137
# epoch 488 loss_pde:0.56422901, loss_ib:0.29882729
# epoch 488: loss 3.552502
# epoch 489 loss_pde:0.56280446, loss_ib:0.29750142
# epoch 489: loss 3.537819
# epoch 490 loss_pde:0.56138968, loss_ib:0.29616961
# epoch 490: loss 3.523086
# epoch 491 loss_pde:0.55998659, loss_ib:0.29483178
# epoch 491: loss 3.508304
# epoch 492 loss_pde:0.55859637, loss_ib:0.29348785
# epoch 492: loss 3.493475
# epoch 493 loss_pde:0.55722034, loss_ib:0.29213789
# epoch 493: loss 3.478599
# epoch 494 loss_pde:0.55585992, loss_ib:0.29078171
# epoch 494: loss 3.463677
# epoch 495 loss_pde:0.55451608, loss_ib:0.28941944
# epoch 495: loss 3.448710
# epoch 496 loss_pde:0.55318964, loss_ib:0.28805104
# epoch 496: loss 3.433700
# epoch 497 loss_pde:0.55188143, loss_ib:0.28667659
# epoch 497: loss 3.418647
# epoch 498 loss_pde:0.55059183, loss_ib:0.28529614
# epoch 498: loss 3.403553
# epoch 499 loss_pde:0.54932159, loss_ib:0.28390980
# epoch 499: loss 3.388420
# epoch 500 loss_pde:0.54807067, loss_ib:0.28251776
# epoch 500: loss 3.373248
# epoch 501 loss_pde:0.54683912, loss_ib:0.28112012
# epoch 501: loss 3.358040
# epoch 502 loss_pde:0.54562676, loss_ib:0.27971709
# epoch 502: loss 3.342798
# epoch 503 loss_pde:0.54443324, loss_ib:0.27830893
# epoch 503: loss 3.327522
# epoch 504 loss_pde:0.54325837, loss_ib:0.27689570
# epoch 504: loss 3.312216
# epoch 505 loss_pde:0.54210138, loss_ib:0.27547777
# epoch 505: loss 3.296879
# epoch 506 loss_pde:0.54096150, loss_ib:0.27405533
# epoch 506: loss 3.281515
# epoch 507 loss_pde:0.53983796, loss_ib:0.27262869
# epoch 507: loss 3.266125
# epoch 508 loss_pde:0.53872937, loss_ib:0.27119812
# epoch 508: loss 3.250711
# epoch 509 loss_pde:0.53763461, loss_ib:0.26976392
# epoch 509: loss 3.235274
# epoch 510 loss_pde:0.53655231, loss_ib:0.26832646
# epoch 510: loss 3.219817
# epoch 511 loss_pde:0.53548110, loss_ib:0.26688597
# epoch 511: loss 3.204341
# epoch 512 loss_pde:0.53441942, loss_ib:0.26544285
# epoch 512: loss 3.188848
# epoch 513 loss_pde:0.53336555, loss_ib:0.26399747
# epoch 513: loss 3.173340
# epoch 514 loss_pde:0.53231782, loss_ib:0.26255003
# epoch 514: loss 3.157818
# epoch 515 loss_pde:0.53127432, loss_ib:0.26110101
# epoch 515: loss 3.142284
# epoch 516 loss_pde:0.53023314, loss_ib:0.25965074
# epoch 516: loss 3.126740
# epoch 517 loss_pde:0.52919245, loss_ib:0.25819957
# epoch 517: loss 3.111188
# epoch 518 loss_pde:0.52815032, loss_ib:0.25674778
# epoch 518: loss 3.095628
# epoch 519 loss_pde:0.52710479, loss_ib:0.25529581
# epoch 519: loss 3.080063
# epoch 520 loss_pde:0.52605402, loss_ib:0.25384393
# epoch 520: loss 3.064493
# epoch 521 loss_pde:0.52499592, loss_ib:0.25239253
# epoch 521: loss 3.048921
# epoch 522 loss_pde:0.52392888, loss_ib:0.25094187
# epoch 522: loss 3.033348
# epoch 523 loss_pde:0.52285087, loss_ib:0.24949232
# epoch 523: loss 3.017774
# epoch 524 loss_pde:0.52176034, loss_ib:0.24804416
# epoch 524: loss 3.002202
# epoch 525 loss_pde:0.52065557, loss_ib:0.24659768
# epoch 525: loss 2.986632
# epoch 526 loss_pde:0.51953506, loss_ib:0.24515323
# epoch 526: loss 2.971067
# epoch 527 loss_pde:0.51839721, loss_ib:0.24371098
# epoch 527: loss 2.955507
# epoch 528 loss_pde:0.51724076, loss_ib:0.24227127
# epoch 528: loss 2.939954
# epoch 529 loss_pde:0.51606447, loss_ib:0.24083428
# epoch 529: loss 2.924407
# epoch 530 loss_pde:0.51486719, loss_ib:0.23940033
# epoch 530: loss 2.908871
# epoch 531 loss_pde:0.51364797, loss_ib:0.23796959
# epoch 531: loss 2.893344
# epoch 532 loss_pde:0.51240611, loss_ib:0.23654225
# epoch 532: loss 2.877829
# epoch 533 loss_pde:0.51114082, loss_ib:0.23511858
# epoch 533: loss 2.862327
# epoch 534 loss_pde:0.50985187, loss_ib:0.23369871
# epoch 534: loss 2.846839
# epoch 535 loss_pde:0.50853884, loss_ib:0.23228279
# epoch 535: loss 2.831367
# epoch 536 loss_pde:0.50720179, loss_ib:0.23087099
# epoch 536: loss 2.815912
# epoch 537 loss_pde:0.50584060, loss_ib:0.22946346
# epoch 537: loss 2.800475
# epoch 538 loss_pde:0.50445580, loss_ib:0.22806031
# epoch 538: loss 2.785059
# epoch 539 loss_pde:0.50304753, loss_ib:0.22666170
# epoch 539: loss 2.769665
# epoch 540 loss_pde:0.50161648, loss_ib:0.22526768
# epoch 540: loss 2.754293
# epoch 541 loss_pde:0.50016344, loss_ib:0.22387841
# epoch 541: loss 2.738947
# epoch 542 loss_pde:0.49868941, loss_ib:0.22249401
# epoch 542: loss 2.723629
# epoch 543 loss_pde:0.49719530, loss_ib:0.22111447
# epoch 543: loss 2.708340
# epoch 544 loss_pde:0.49568230, loss_ib:0.21973997
# epoch 544: loss 2.693082
# epoch 545 loss_pde:0.49415177, loss_ib:0.21837054
# epoch 545: loss 2.677857
# epoch 546 loss_pde:0.49260536, loss_ib:0.21700628
# epoch 546: loss 2.662668
# epoch 547 loss_pde:0.49104446, loss_ib:0.21564731
# epoch 547: loss 2.647518
# epoch 548 loss_pde:0.48947084, loss_ib:0.21429360
# epoch 548: loss 2.632407
# epoch 549 loss_pde:0.48788634, loss_ib:0.21294528
# epoch 549: loss 2.617339
# epoch 550 loss_pde:0.48629260, loss_ib:0.21160237
# epoch 550: loss 2.602316
# epoch 551 loss_pde:0.48469135, loss_ib:0.21026509
# epoch 551: loss 2.587342
# epoch 552 loss_pde:0.48308432, loss_ib:0.20893341
# epoch 552: loss 2.572418
# epoch 553 loss_pde:0.48147354, loss_ib:0.20760754
# epoch 553: loss 2.557549
# epoch 554 loss_pde:0.47986120, loss_ib:0.20628735
# epoch 554: loss 2.542735
# epoch 555 loss_pde:0.47824937, loss_ib:0.20497312
# epoch 555: loss 2.527981
# epoch 556 loss_pde:0.47663969, loss_ib:0.20366487
# epoch 556: loss 2.513288
# epoch 557 loss_pde:0.47503453, loss_ib:0.20236266
# epoch 557: loss 2.498661
# epoch 558 loss_pde:0.47343597, loss_ib:0.20106667
# epoch 558: loss 2.484103
# epoch 559 loss_pde:0.47184598, loss_ib:0.19977692
# epoch 559: loss 2.469615
# epoch 560 loss_pde:0.47026652, loss_ib:0.19849358
# epoch 560: loss 2.455202
# epoch 561 loss_pde:0.46869910, loss_ib:0.19721681
# epoch 561: loss 2.440867
# epoch 562 loss_pde:0.46714547, loss_ib:0.19594669
# epoch 562: loss 2.426612
# epoch 563 loss_pde:0.46560755, loss_ib:0.19468340
# epoch 563: loss 2.412442
# epoch 564 loss_pde:0.46408743, loss_ib:0.19342703
# epoch 564: loss 2.398358
# epoch 565 loss_pde:0.46258688, loss_ib:0.19217771
# epoch 565: loss 2.384364
# epoch 566 loss_pde:0.46110624, loss_ib:0.19093567
# epoch 566: loss 2.370463
# epoch 567 loss_pde:0.45964575, loss_ib:0.18970110
# epoch 567: loss 2.356657
# epoch 568 loss_pde:0.45820573, loss_ib:0.18847430
# epoch 568: loss 2.342949
# epoch 569 loss_pde:0.45678747, loss_ib:0.18725538
# epoch 569: loss 2.329341
# epoch 570 loss_pde:0.45539176, loss_ib:0.18604457
# epoch 570: loss 2.315837
# epoch 571 loss_pde:0.45401970, loss_ib:0.18484190
# epoch 571: loss 2.302439
# epoch 572 loss_pde:0.45267159, loss_ib:0.18364760
# epoch 572: loss 2.289148
# epoch 573 loss_pde:0.45134735, loss_ib:0.18246186
# epoch 573: loss 2.275966
# epoch 574 loss_pde:0.45004675, loss_ib:0.18128490
# epoch 574: loss 2.262896
# epoch 575 loss_pde:0.44876999, loss_ib:0.18011683
# epoch 575: loss 2.249938
# epoch 576 loss_pde:0.44751704, loss_ib:0.17895789
# epoch 576: loss 2.237096
# epoch 577 loss_pde:0.44628757, loss_ib:0.17780817
# epoch 577: loss 2.224369
# epoch 578 loss_pde:0.44508132, loss_ib:0.17666784
# epoch 578: loss 2.211760
# epoch 579 loss_pde:0.44389671, loss_ib:0.17553712
# epoch 579: loss 2.199268
# epoch 580 loss_pde:0.44273254, loss_ib:0.17441624
# epoch 580: loss 2.186895
# epoch 581 loss_pde:0.44158849, loss_ib:0.17330527
# epoch 581: loss 2.174641
# epoch 582 loss_pde:0.44046521, loss_ib:0.17220426
# epoch 582: loss 2.162508
# epoch 583 loss_pde:0.43936300, loss_ib:0.17111318
# epoch 583: loss 2.150495
# epoch 584 loss_pde:0.43828148, loss_ib:0.17003207
# epoch 584: loss 2.138602
# epoch 585 loss_pde:0.43721947, loss_ib:0.16896108
# epoch 585: loss 2.126830
# epoch 586 loss_pde:0.43617511, loss_ib:0.16790035
# epoch 586: loss 2.115179
# epoch 587 loss_pde:0.43514633, loss_ib:0.16685000
# epoch 587: loss 2.103646
# epoch 588 loss_pde:0.43413323, loss_ib:0.16581011
# epoch 588: loss 2.092234
# epoch 589 loss_pde:0.43313622, loss_ib:0.16478056
# epoch 589: loss 2.080942
# epoch 590 loss_pde:0.43215486, loss_ib:0.16376129
# epoch 590: loss 2.069768
# epoch 591 loss_pde:0.43118805, loss_ib:0.16275239
# epoch 591: loss 2.058712
# epoch 592 loss_pde:0.43023452, loss_ib:0.16175395
# epoch 592: loss 2.047774
# epoch 593 loss_pde:0.42929456, loss_ib:0.16076583
# epoch 593: loss 2.036953
# epoch 594 loss_pde:0.42836720, loss_ib:0.15978800
# epoch 594: loss 2.026247
# epoch 595 loss_pde:0.42745227, loss_ib:0.15882048
# epoch 595: loss 2.015657
# epoch 596 loss_pde:0.42654872, loss_ib:0.15786320
# epoch 596: loss 2.005181
# epoch 597 loss_pde:0.42565596, loss_ib:0.15691616
# epoch 597: loss 1.994817
# epoch 598 loss_pde:0.42477271, loss_ib:0.15597934
# epoch 598: loss 1.984566
# epoch 599 loss_pde:0.42389911, loss_ib:0.15505271
# epoch 599: loss 1.974426
# epoch 600 loss_pde:0.42303491, loss_ib:0.15413612
# epoch 600: loss 1.964396
# epoch 601 loss_pde:0.42217958, loss_ib:0.15322956
# epoch 601: loss 1.954475
# epoch 602 loss_pde:0.42133361, loss_ib:0.15233293
# epoch 602: loss 1.944663
# epoch 603 loss_pde:0.42049694, loss_ib:0.15144607
# epoch 603: loss 1.934958
# epoch 604 loss_pde:0.41966742, loss_ib:0.15056908
# epoch 604: loss 1.925358
# epoch 605 loss_pde:0.41884369, loss_ib:0.14970198
# epoch 605: loss 1.915864
# epoch 606 loss_pde:0.41802508, loss_ib:0.14884475
# epoch 606: loss 1.906472
# epoch 607 loss_pde:0.41721219, loss_ib:0.14799729
# epoch 607: loss 1.897185
# epoch 608 loss_pde:0.41640699, loss_ib:0.14715928
# epoch 608: loss 1.888000
# epoch 609 loss_pde:0.41560799, loss_ib:0.14633077
# epoch 609: loss 1.878916
# epoch 610 loss_pde:0.41481474, loss_ib:0.14551169
# epoch 610: loss 1.869932
# epoch 611 loss_pde:0.41402638, loss_ib:0.14470214
# epoch 611: loss 1.861048
# epoch 612 loss_pde:0.41324389, loss_ib:0.14390184
# epoch 612: loss 1.852262
# epoch 613 loss_pde:0.41246733, loss_ib:0.14311081
# epoch 613: loss 1.843575
# epoch 614 loss_pde:0.41169560, loss_ib:0.14232898
# epoch 614: loss 1.834985
# epoch 615 loss_pde:0.41092610, loss_ib:0.14155656
# epoch 615: loss 1.826492
# epoch 616 loss_pde:0.41015881, loss_ib:0.14079349
# epoch 616: loss 1.818094
# epoch 617 loss_pde:0.40939358, loss_ib:0.14003970
# epoch 617: loss 1.809790
# epoch 618 loss_pde:0.40863168, loss_ib:0.13929503
# epoch 618: loss 1.801582
# epoch 619 loss_pde:0.40787444, loss_ib:0.13855931
# epoch 619: loss 1.793468
# epoch 620 loss_pde:0.40712315, loss_ib:0.13783237
# epoch 620: loss 1.785447
# epoch 621 loss_pde:0.40637684, loss_ib:0.13711421
# epoch 621: loss 1.777519
# epoch 622 loss_pde:0.40563393, loss_ib:0.13640496
# epoch 622: loss 1.769684
# epoch 623 loss_pde:0.40489453, loss_ib:0.13570456
# epoch 623: loss 1.761940
# epoch 624 loss_pde:0.40415955, loss_ib:0.13501285
# epoch 624: loss 1.754288
# epoch 625 loss_pde:0.40342912, loss_ib:0.13432983
# epoch 625: loss 1.746727
# epoch 626 loss_pde:0.40270266, loss_ib:0.13365540
# epoch 626: loss 1.739257
# epoch 627 loss_pde:0.40197712, loss_ib:0.13298982
# epoch 627: loss 1.731875
# epoch 628 loss_pde:0.40125489, loss_ib:0.13233292
# epoch 628: loss 1.724584
# epoch 629 loss_pde:0.40053862, loss_ib:0.13168433
# epoch 629: loss 1.717382
# epoch 630 loss_pde:0.39982903, loss_ib:0.13104396
# epoch 630: loss 1.710269
# epoch 631 loss_pde:0.39912719, loss_ib:0.13041171
# epoch 631: loss 1.703244
# epoch 632 loss_pde:0.39843231, loss_ib:0.12978753
# epoch 632: loss 1.696308
# epoch 633 loss_pde:0.39774311, loss_ib:0.12917152
# epoch 633: loss 1.689458
# epoch 634 loss_pde:0.39705804, loss_ib:0.12856384
# epoch 634: loss 1.682696
# epoch 635 loss_pde:0.39637816, loss_ib:0.12796426
# epoch 635: loss 1.676021
# epoch 636 loss_pde:0.39570385, loss_ib:0.12737274
# epoch 636: loss 1.669431
# epoch 637 loss_pde:0.39503753, loss_ib:0.12678899
# epoch 637: loss 1.662927
# epoch 638 loss_pde:0.39437807, loss_ib:0.12621300
# epoch 638: loss 1.656508
# epoch 639 loss_pde:0.39372656, loss_ib:0.12564468
# epoch 639: loss 1.650173
# epoch 640 loss_pde:0.39308321, loss_ib:0.12508386
# epoch 640: loss 1.643922
# epoch 641 loss_pde:0.39244732, loss_ib:0.12453055
# epoch 641: loss 1.637753
# ...
# epoch 9794 loss_pde:0.17221242, loss_ib:0.00774835
# epoch 9794: loss 0.249696
# epoch 9795 loss_pde:0.17216703, loss_ib:0.00774402
# epoch 9795: loss 0.249607
# epoch 9796 loss_pde:0.17212145, loss_ib:0.00773971
# epoch 9796: loss 0.249519
# epoch 9797 loss_pde:0.17207605, loss_ib:0.00773540
# epoch 9797: loss 0.249430
# epoch 9798 loss_pde:0.17203091, loss_ib:0.00773107
# epoch 9798: loss 0.249342
# epoch 9799 loss_pde:0.17198594, loss_ib:0.00772674
# epoch 9799: loss 0.249253
# epoch 9800 loss_pde:0.17194030, loss_ib:0.00772248
# epoch 9800: loss 0.249165
# epoch 9801 loss_pde:0.17189410, loss_ib:0.00771830
# epoch 9801: loss 0.249077
# epoch 9802 loss_pde:0.17184833, loss_ib:0.00771408
# epoch 9802: loss 0.248989
# epoch 9803 loss_pde:0.17180331, loss_ib:0.00770980
# epoch 9803: loss 0.248901
# epoch 9804 loss_pde:0.17175867, loss_ib:0.00770549
# epoch 9804: loss 0.248814
# epoch 9805 loss_pde:0.17171371, loss_ib:0.00770123
# epoch 9805: loss 0.248726
# epoch 9806 loss_pde:0.17166837, loss_ib:0.00769702
# epoch 9806: loss 0.248639
# epoch 9807 loss_pde:0.17162322, loss_ib:0.00769279
# epoch 9807: loss 0.248551
# epoch 9808 loss_pde:0.17157853, loss_ib:0.00768854
# epoch 9808: loss 0.248464
# epoch 9809 loss_pde:0.17153378, loss_ib:0.00768430
# epoch 9809: loss 0.248377
# epoch 9810 loss_pde:0.17148872, loss_ib:0.00768010
# epoch 9810: loss 0.248290
# epoch 9811 loss_pde:0.17144385, loss_ib:0.00767590
# epoch 9811: loss 0.248203
# epoch 9812 loss_pde:0.17139964, loss_ib:0.00767165
# epoch 9812: loss 0.248116
# epoch 9813 loss_pde:0.17135543, loss_ib:0.00766740
# epoch 9813: loss 0.248029
# epoch 9814 loss_pde:0.17131044, loss_ib:0.00766325
# epoch 9814: loss 0.247943
# epoch 9815 loss_pde:0.17126502, loss_ib:0.00765915
# epoch 9815: loss 0.247856
# epoch 9816 loss_pde:0.17122000, loss_ib:0.00765502
# epoch 9816: loss 0.247770
# epoch 9817 loss_pde:0.17117578, loss_ib:0.00765082
# epoch 9817: loss 0.247684
# epoch 9818 loss_pde:0.17113167, loss_ib:0.00764662
# epoch 9818: loss 0.247598
# epoch 9819 loss_pde:0.17108694, loss_ib:0.00764250
# epoch 9819: loss 0.247512
# epoch 9820 loss_pde:0.17104226, loss_ib:0.00763839
# epoch 9820: loss 0.247426
# epoch 9821 loss_pde:0.17099795, loss_ib:0.00763424
# epoch 9821: loss 0.247340
# epoch 9822 loss_pde:0.17095381, loss_ib:0.00763010
# epoch 9822: loss 0.247255
# epoch 9823 loss_pde:0.17090943, loss_ib:0.00762598
# epoch 9823: loss 0.247169
# epoch 9824 loss_pde:0.17086476, loss_ib:0.00762191
# epoch 9824: loss 0.247084
# epoch 9825 loss_pde:0.17082033, loss_ib:0.00761783
# epoch 9825: loss 0.246999
# epoch 9826 loss_pde:0.17077644, loss_ib:0.00761370
# epoch 9826: loss 0.246913
# epoch 9827 loss_pde:0.17073287, loss_ib:0.00760956
# epoch 9827: loss 0.246828
# epoch 9828 loss_pde:0.17068893, loss_ib:0.00760546
# epoch 9828: loss 0.246744
# epoch 9829 loss_pde:0.17064463, loss_ib:0.00760141
# epoch 9829: loss 0.246659
# epoch 9830 loss_pde:0.17060041, loss_ib:0.00759736
# epoch 9830: loss 0.246574
# epoch 9831 loss_pde:0.17055672, loss_ib:0.00759327
# epoch 9831: loss 0.246489
# epoch 9832 loss_pde:0.17051324, loss_ib:0.00758917
# epoch 9832: loss 0.246405
# epoch 9833 loss_pde:0.17046937, loss_ib:0.00758513
# epoch 9833: loss 0.246321
# epoch 9834 loss_pde:0.17042524, loss_ib:0.00758111
# epoch 9834: loss 0.246236
# epoch 9835 loss_pde:0.17038143, loss_ib:0.00757708
# epoch 9835: loss 0.246152
# epoch 9836 loss_pde:0.17033793, loss_ib:0.00757303
# epoch 9836: loss 0.246068
# epoch 9837 loss_pde:0.17029452, loss_ib:0.00756898
# epoch 9837: loss 0.245984
# epoch 9838 loss_pde:0.17025104, loss_ib:0.00756495
# epoch 9838: loss 0.245901
# epoch 9839 loss_pde:0.17020757, loss_ib:0.00756093
# epoch 9839: loss 0.245817
# epoch 9840 loss_pde:0.17016418, loss_ib:0.00755692
# epoch 9840: loss 0.245733
# epoch 9841 loss_pde:0.17012082, loss_ib:0.00755291
# epoch 9841: loss 0.245650
# epoch 9842 loss_pde:0.17007728, loss_ib:0.00754893
# epoch 9842: loss 0.245567
# epoch 9843 loss_pde:0.17003381, loss_ib:0.00754496
# epoch 9843: loss 0.245483
# epoch 9844 loss_pde:0.16999038, loss_ib:0.00754099
# epoch 9844: loss 0.245400
# epoch 9845 loss_pde:0.16994704, loss_ib:0.00753703
# epoch 9845: loss 0.245317
# epoch 9846 loss_pde:0.16990383, loss_ib:0.00753306
# epoch 9846: loss 0.245234
# epoch 9847 loss_pde:0.16986056, loss_ib:0.00752911
# epoch 9847: loss 0.245152
# epoch 9848 loss_pde:0.16981727, loss_ib:0.00752517
# epoch 9848: loss 0.245069
# epoch 9849 loss_pde:0.16977400, loss_ib:0.00752125
# epoch 9849: loss 0.244986
# epoch 9850 loss_pde:0.16973080, loss_ib:0.00751732
# epoch 9850: loss 0.244904
# epoch 9851 loss_pde:0.16968767, loss_ib:0.00751340
# epoch 9851: loss 0.244822
# epoch 9852 loss_pde:0.16964462, loss_ib:0.00750949
# epoch 9852: loss 0.244740
# epoch 9853 loss_pde:0.16960165, loss_ib:0.00750557
# epoch 9853: loss 0.244657
# epoch 9854 loss_pde:0.16955882, loss_ib:0.00750166
# epoch 9854: loss 0.244575
# epoch 9855 loss_pde:0.16951603, loss_ib:0.00749775
# epoch 9855: loss 0.244494
# epoch 9856 loss_pde:0.16947313, loss_ib:0.00749386
# epoch 9856: loss 0.244412
# epoch 9857 loss_pde:0.16943032, loss_ib:0.00748998
# epoch 9857: loss 0.244330
# epoch 9858 loss_pde:0.16938767, loss_ib:0.00748609
# epoch 9858: loss 0.244249
# epoch 9859 loss_pde:0.16934508, loss_ib:0.00748221
# epoch 9859: loss 0.244167
# epoch 9860 loss_pde:0.16930255, loss_ib:0.00747833
# epoch 9860: loss 0.244086
# epoch 9861 loss_pde:0.16925995, loss_ib:0.00747447
# epoch 9861: loss 0.244005
# epoch 9862 loss_pde:0.16921736, loss_ib:0.00747062
# epoch 9862: loss 0.243924
# epoch 9863 loss_pde:0.16917484, loss_ib:0.00746677
# epoch 9863: loss 0.243843
# epoch 9864 loss_pde:0.16913229, loss_ib:0.00746294
# epoch 9864: loss 0.243762
# epoch 9865 loss_pde:0.16908991, loss_ib:0.00745910
# epoch 9865: loss 0.243681
# epoch 9866 loss_pde:0.16904761, loss_ib:0.00745527
# epoch 9866: loss 0.243600
# epoch 9867 loss_pde:0.16900524, loss_ib:0.00745145
# epoch 9867: loss 0.243520
# epoch 9868 loss_pde:0.16896290, loss_ib:0.00744764
# epoch 9868: loss 0.243439
# epoch 9869 loss_pde:0.16892058, loss_ib:0.00744384
# epoch 9869: loss 0.243359
# epoch 9870 loss_pde:0.16887824, loss_ib:0.00744005
# epoch 9870: loss 0.243279
# epoch 9871 loss_pde:0.16883603, loss_ib:0.00743626
# epoch 9871: loss 0.243199
# epoch 9872 loss_pde:0.16879393, loss_ib:0.00743247
# epoch 9872: loss 0.243119
# epoch 9873 loss_pde:0.16875188, loss_ib:0.00742869
# epoch 9873: loss 0.243039
# epoch 9874 loss_pde:0.16870986, loss_ib:0.00742491
# epoch 9874: loss 0.242959
# epoch 9875 loss_pde:0.16866782, loss_ib:0.00742115
# epoch 9875: loss 0.242879
# epoch 9876 loss_pde:0.16862589, loss_ib:0.00741738
# epoch 9876: loss 0.242800
# epoch 9877 loss_pde:0.16858397, loss_ib:0.00741363
# epoch 9877: loss 0.242720
# epoch 9878 loss_pde:0.16854209, loss_ib:0.00740989
# epoch 9878: loss 0.242641
# epoch 9879 loss_pde:0.16850021, loss_ib:0.00740615
# epoch 9879: loss 0.242562
# epoch 9880 loss_pde:0.16845843, loss_ib:0.00740242
# epoch 9880: loss 0.242483
# epoch 9881 loss_pde:0.16841678, loss_ib:0.00739867
# epoch 9881: loss 0.242404
# epoch 9882 loss_pde:0.16837515, loss_ib:0.00739495
# epoch 9882: loss 0.242325
# epoch 9883 loss_pde:0.16833347, loss_ib:0.00739123
# epoch 9883: loss 0.242246
# epoch 9884 loss_pde:0.16829172, loss_ib:0.00738754
# epoch 9884: loss 0.242167
# epoch 9885 loss_pde:0.16825007, loss_ib:0.00738385
# epoch 9885: loss 0.242089
# epoch 9886 loss_pde:0.16820867, loss_ib:0.00738014
# epoch 9886: loss 0.242010
# epoch 9887 loss_pde:0.16816732, loss_ib:0.00737644
# epoch 9887: loss 0.241932
# epoch 9888 loss_pde:0.16812594, loss_ib:0.00737275
# epoch 9888: loss 0.241853
# epoch 9889 loss_pde:0.16808450, loss_ib:0.00736908
# epoch 9889: loss 0.241775
# epoch 9890 loss_pde:0.16804311, loss_ib:0.00736541
# epoch 9890: loss 0.241697
# epoch 9891 loss_pde:0.16800174, loss_ib:0.00736175
# epoch 9891: loss 0.241619
# epoch 9892 loss_pde:0.16796048, loss_ib:0.00735809
# epoch 9892: loss 0.241541
# epoch 9893 loss_pde:0.16791928, loss_ib:0.00735444
# epoch 9893: loss 0.241464
# epoch 9894 loss_pde:0.16787803, loss_ib:0.00735081
# epoch 9894: loss 0.241386
# epoch 9895 loss_pde:0.16783682, loss_ib:0.00734718
# epoch 9895: loss 0.241309
# epoch 9896 loss_pde:0.16779594, loss_ib:0.00734352
# epoch 9896: loss 0.241231
# epoch 9897 loss_pde:0.16775504, loss_ib:0.00733988
# epoch 9897: loss 0.241154
# epoch 9898 loss_pde:0.16771370, loss_ib:0.00733629
# epoch 9898: loss 0.241077
# epoch 9899 loss_pde:0.16767277, loss_ib:0.00733268
# epoch 9899: loss 0.241000
# epoch 9900 loss_pde:0.16763201, loss_ib:0.00732906
# epoch 9900: loss 0.240923
# epoch 9901 loss_pde:0.16759086, loss_ib:0.00732548
# epoch 9901: loss 0.240846
# epoch 9902 loss_pde:0.16754980, loss_ib:0.00732191
# epoch 9902: loss 0.240769
# epoch 9903 loss_pde:0.16750933, loss_ib:0.00731829
# epoch 9903: loss 0.240692
# epoch 9904 loss_pde:0.16746874, loss_ib:0.00731469
# epoch 9904: loss 0.240616
# epoch 9905 loss_pde:0.16742799, loss_ib:0.00731112
# epoch 9905: loss 0.240539
# epoch 9906 loss_pde:0.16738750, loss_ib:0.00730753
# epoch 9906: loss 0.240463
# epoch 9907 loss_pde:0.16734719, loss_ib:0.00730394
# epoch 9907: loss 0.240387
# epoch 9908 loss_pde:0.16730648, loss_ib:0.00730039
# epoch 9908: loss 0.240310
# epoch 9909 loss_pde:0.16726586, loss_ib:0.00729685
# epoch 9909: loss 0.240234
# epoch 9910 loss_pde:0.16722566, loss_ib:0.00729327
# epoch 9910: loss 0.240158
# epoch 9911 loss_pde:0.16718529, loss_ib:0.00728973
# epoch 9911: loss 0.240083
# epoch 9912 loss_pde:0.16714460, loss_ib:0.00728622
# epoch 9912: loss 0.240007
# epoch 9913 loss_pde:0.16710450, loss_ib:0.00728267
# epoch 9913: loss 0.239931
# epoch 9914 loss_pde:0.16706452, loss_ib:0.00727912
# epoch 9914: loss 0.239856
# epoch 9915 loss_pde:0.16702402, loss_ib:0.00727562
# epoch 9915: loss 0.239780
# epoch 9916 loss_pde:0.16698349, loss_ib:0.00727215
# epoch 9916: loss 0.239705
# epoch 9917 loss_pde:0.16694354, loss_ib:0.00726862
# epoch 9917: loss 0.239630
# epoch 9918 loss_pde:0.16690359, loss_ib:0.00726510
# epoch 9918: loss 0.239555
# epoch 9919 loss_pde:0.16686344, loss_ib:0.00726162
# epoch 9919: loss 0.239480
# epoch 9920 loss_pde:0.16682360, loss_ib:0.00725811
# epoch 9920: loss 0.239405
# epoch 9921 loss_pde:0.16678379, loss_ib:0.00725461
# epoch 9921: loss 0.239330
# epoch 9922 loss_pde:0.16674365, loss_ib:0.00725116
# epoch 9922: loss 0.239255
# epoch 9923 loss_pde:0.16670379, loss_ib:0.00724768
# epoch 9923: loss 0.239181
# epoch 9924 loss_pde:0.16666412, loss_ib:0.00724420
# epoch 9924: loss 0.239106
# epoch 9925 loss_pde:0.16662458, loss_ib:0.00724072
# epoch 9925: loss 0.239032
# epoch 9926 loss_pde:0.16658491, loss_ib:0.00723726
# epoch 9926: loss 0.238957
# epoch 9927 loss_pde:0.16654500, loss_ib:0.00723383
# epoch 9927: loss 0.238883
# epoch 9928 loss_pde:0.16650508, loss_ib:0.00723041
# epoch 9928: loss 0.238809
# epoch 9929 loss_pde:0.16646528, loss_ib:0.00722700
# epoch 9929: loss 0.238735
# epoch 9930 loss_pde:0.16642575, loss_ib:0.00722356
# epoch 9930: loss 0.238661
# epoch 9931 loss_pde:0.16638647, loss_ib:0.00722011
# epoch 9931: loss 0.238588
# epoch 9932 loss_pde:0.16634728, loss_ib:0.00721666
# epoch 9932: loss 0.238514
# epoch 9933 loss_pde:0.16630775, loss_ib:0.00721326
# epoch 9933: loss 0.238440
# epoch 9934 loss_pde:0.16626823, loss_ib:0.00720986
# epoch 9934: loss 0.238367
# epoch 9935 loss_pde:0.16622892, loss_ib:0.00720646
# epoch 9935: loss 0.238294
# epoch 9936 loss_pde:0.16618951, loss_ib:0.00720307
# epoch 9936: loss 0.238220
# epoch 9937 loss_pde:0.16614994, loss_ib:0.00719971
# epoch 9937: loss 0.238147
# epoch 9938 loss_pde:0.16611066, loss_ib:0.00719633
# epoch 9938: loss 0.238074
# epoch 9939 loss_pde:0.16607162, loss_ib:0.00719294
# epoch 9939: loss 0.238001
# epoch 9940 loss_pde:0.16603251, loss_ib:0.00718956
# epoch 9940: loss 0.237928
# epoch 9941 loss_pde:0.16599330, loss_ib:0.00718621
# epoch 9941: loss 0.237855
# epoch 9942 loss_pde:0.16595429, loss_ib:0.00718284
# epoch 9942: loss 0.237783
# epoch 9943 loss_pde:0.16591552, loss_ib:0.00717946
# epoch 9943: loss 0.237710
# epoch 9944 loss_pde:0.16587678, loss_ib:0.00717609
# epoch 9944: loss 0.237638
# epoch 9945 loss_pde:0.16583802, loss_ib:0.00717273
# epoch 9945: loss 0.237565
# epoch 9946 loss_pde:0.16579916, loss_ib:0.00716939
# epoch 9946: loss 0.237493
# epoch 9947 loss_pde:0.16576034, loss_ib:0.00716605
# epoch 9947: loss 0.237421
# epoch 9948 loss_pde:0.16572173, loss_ib:0.00716271
# epoch 9948: loss 0.237349
# epoch 9949 loss_pde:0.16568306, loss_ib:0.00715938
# epoch 9949: loss 0.237277
# epoch 9950 loss_pde:0.16564424, loss_ib:0.00715607
# epoch 9950: loss 0.237205
# epoch 9951 loss_pde:0.16560556, loss_ib:0.00715277
# epoch 9951: loss 0.237133
# epoch 9952 loss_pde:0.16556695, loss_ib:0.00714946
# epoch 9952: loss 0.237062
# epoch 9953 loss_pde:0.16552857, loss_ib:0.00714614
# epoch 9953: loss 0.236990
# epoch 9954 loss_pde:0.16548994, loss_ib:0.00714285
# epoch 9954: loss 0.236918
# epoch 9955 loss_pde:0.16545108, loss_ib:0.00713960
# epoch 9955: loss 0.236847
# epoch 9956 loss_pde:0.16541255, loss_ib:0.00713633
# epoch 9956: loss 0.236776
# epoch 9957 loss_pde:0.16537426, loss_ib:0.00713304
# epoch 9957: loss 0.236705
# epoch 9958 loss_pde:0.16533583, loss_ib:0.00712977
# epoch 9958: loss 0.236634
# epoch 9959 loss_pde:0.16529746, loss_ib:0.00712651
# epoch 9959: loss 0.236563
# epoch 9960 loss_pde:0.16525945, loss_ib:0.00712323
# epoch 9960: loss 0.236492
# epoch 9961 loss_pde:0.16522135, loss_ib:0.00711996
# epoch 9961: loss 0.236421
# epoch 9962 loss_pde:0.16518298, loss_ib:0.00711673
# epoch 9962: loss 0.236350
# epoch 9963 loss_pde:0.16514476, loss_ib:0.00711349
# epoch 9963: loss 0.236280
# epoch 9964 loss_pde:0.16510676, loss_ib:0.00711024
# epoch 9964: loss 0.236209
# epoch 9965 loss_pde:0.16506876, loss_ib:0.00710700
# epoch 9965: loss 0.236139
# epoch 9966 loss_pde:0.16503084, loss_ib:0.00710376
# epoch 9966: loss 0.236068
# epoch 9967 loss_pde:0.16499293, loss_ib:0.00710053
# epoch 9967: loss 0.235998
# epoch 9968 loss_pde:0.16495487, loss_ib:0.00709732
# epoch 9968: loss 0.235928
# epoch 9969 loss_pde:0.16491702, loss_ib:0.00709411
# epoch 9969: loss 0.235858
# epoch 9970 loss_pde:0.16487941, loss_ib:0.00709088
# epoch 9970: loss 0.235788
# epoch 9971 loss_pde:0.16484183, loss_ib:0.00708766
# epoch 9971: loss 0.235718
# epoch 9972 loss_pde:0.16480410, loss_ib:0.00708446
# epoch 9972: loss 0.235649
# epoch 9973 loss_pde:0.16476637, loss_ib:0.00708127
# epoch 9973: loss 0.235579
# epoch 9974 loss_pde:0.16472870, loss_ib:0.00707809
# epoch 9974: loss 0.235510
# epoch 9975 loss_pde:0.16469105, loss_ib:0.00707491
# epoch 9975: loss 0.235440
# epoch 9976 loss_pde:0.16465348, loss_ib:0.00707173
# epoch 9976: loss 0.235371
# epoch 9977 loss_pde:0.16461620, loss_ib:0.00706853
# epoch 9977: loss 0.235302
# epoch 9978 loss_pde:0.16457897, loss_ib:0.00706534
# epoch 9978: loss 0.235232
# epoch 9979 loss_pde:0.16454154, loss_ib:0.00706218
# epoch 9979: loss 0.235163
# epoch 9980 loss_pde:0.16450410, loss_ib:0.00705903
# epoch 9980: loss 0.235094
# epoch 9981 loss_pde:0.16446672, loss_ib:0.00705588
# epoch 9981: loss 0.235026
# epoch 9982 loss_pde:0.16442940, loss_ib:0.00705273
# epoch 9982: loss 0.234957
# epoch 9983 loss_pde:0.16439213, loss_ib:0.00704960
# epoch 9983: loss 0.234888
# epoch 9984 loss_pde:0.16435495, loss_ib:0.00704645
# epoch 9984: loss 0.234820
# epoch 9985 loss_pde:0.16431794, loss_ib:0.00704331
# epoch 9985: loss 0.234751
# epoch 9986 loss_pde:0.16428091, loss_ib:0.00704018
# epoch 9986: loss 0.234683
# epoch 9987 loss_pde:0.16424379, loss_ib:0.00703705
# epoch 9987: loss 0.234614
# epoch 9988 loss_pde:0.16420676, loss_ib:0.00703394
# epoch 9988: loss 0.234546
# epoch 9989 loss_pde:0.16416973, loss_ib:0.00703083
# epoch 9989: loss 0.234478
# epoch 9990 loss_pde:0.16413280, loss_ib:0.00702772
# epoch 9990: loss 0.234410
# epoch 9991 loss_pde:0.16409594, loss_ib:0.00702462
# epoch 9991: loss 0.234342
# epoch 9992 loss_pde:0.16405910, loss_ib:0.00702152
# epoch 9992: loss 0.234274
# epoch 9993 loss_pde:0.16402231, loss_ib:0.00701842
# epoch 9993: loss 0.234207
# epoch 9994 loss_pde:0.16398552, loss_ib:0.00701534
# epoch 9994: loss 0.234139
# epoch 9995 loss_pde:0.16394891, loss_ib:0.00701225
# epoch 9995: loss 0.234071
# epoch 9996 loss_pde:0.16391239, loss_ib:0.00700915
# epoch 9996: loss 0.234004
# epoch 9997 loss_pde:0.16387537, loss_ib:0.00700612
# epoch 9997: loss 0.233937
# epoch 9998 loss_pde:0.16383843, loss_ib:0.00700309
# epoch 9998: loss 0.233869
# epoch 9999 loss_pde:0.16380185, loss_ib:0.00700002
# epoch 9999: loss 0.233802
# epoch 10000 loss_pde:0.16376540, loss_ib:0.00699696
# epoch 10000: loss 0.233735
# Total training time: 1790.036376953125

# %%
lr = 0.0001
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_Adam,gamma=0.995)
#optimizer = torch.optim.LBFGS(model.parameters(),lr=0.1,max_iter=10)
#optimizer_LBFGS = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=50000)

# %%
epochs = 20000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:0.16372898, loss_ib:0.00699391
# epoch 1: loss 0.233668
# epoch 2 loss_pde:0.16326138, loss_ib:0.00705824
# epoch 2: loss 0.233844
# epoch 3 loss_pde:0.16639489, loss_ib:0.00849648
# epoch 3: loss 0.251360
# epoch 4 loss_pde:0.16443226, loss_ib:0.00720356
# epoch 4: loss 0.236468
# epoch 5 loss_pde:0.16364162, loss_ib:0.00779829
# epoch 5: loss 0.241625
# epoch 6 loss_pde:0.16282968, loss_ib:0.00785703
# epoch 6: loss 0.241400
# epoch 7 loss_pde:0.16255817, loss_ib:0.00752875
# epoch 7: loss 0.237846
# epoch 8 loss_pde:0.16383256, loss_ib:0.00729487
# epoch 8: loss 0.236781
# epoch 9 loss_pde:0.16522907, loss_ib:0.00719020
# epoch 9: loss 0.237131
# epoch 10 loss_pde:0.16534570, loss_ib:0.00716032
# epoch 10: loss 0.236949
# epoch 11 loss_pde:0.16458744, loss_ib:0.00715107
# epoch 11: loss 0.236098
# epoch 12 loss_pde:0.16372798, loss_ib:0.00717429
# epoch 12: loss 0.235471
# epoch 13 loss_pde:0.16297026, loss_ib:0.00724180
# epoch 13: loss 0.235388
# epoch 14 loss_pde:0.16251823, loss_ib:0.00729734
# epoch 14: loss 0.235492
# epoch 15 loss_pde:0.16272384, loss_ib:0.00723859
# epoch 15: loss 0.235110
# epoch 16 loss_pde:0.16344523, loss_ib:0.00709259
# epoch 16: loss 0.234371
# epoch 17 loss_pde:0.16398807, loss_ib:0.00700362
# epoch 17: loss 0.234024
# epoch 18 loss_pde:0.16394415, loss_ib:0.00703425
# epoch 18: loss 0.234287
# epoch 19 loss_pde:0.16356260, loss_ib:0.00709826
# epoch 19: loss 0.234545
# epoch 20 loss_pde:0.16322769, loss_ib:0.00710028
# epoch 20: loss 0.234231
# epoch 21 loss_pde:0.16308099, loss_ib:0.00705031
# epoch 21: loss 0.233584
# epoch 22 loss_pde:0.16315623, loss_ib:0.00701058
# epoch 22: loss 0.233262
# epoch 23 loss_pde:0.16344799, loss_ib:0.00700482
# epoch 23: loss 0.233496
# epoch 24 loss_pde:0.16376664, loss_ib:0.00700291
# epoch 24: loss 0.233796
# epoch 25 loss_pde:0.16387106, loss_ib:0.00697601
# epoch 25: loss 0.233631
# epoch 26 loss_pde:0.16371635, loss_ib:0.00694411
# epoch 26: loss 0.233157
# epoch 27 loss_pde:0.16340655, loss_ib:0.00695044
# epoch 27: loss 0.232911
# epoch 28 loss_pde:0.16304448, loss_ib:0.00699812
# epoch 28: loss 0.233026
# epoch 29 loss_pde:0.16277257, loss_ib:0.00703833
# epoch 29: loss 0.233156
# epoch 30 loss_pde:0.16276127, loss_ib:0.00703180
# epoch 30: loss 0.233079
# epoch 31 loss_pde:0.16298527, loss_ib:0.00699284
# epoch 31: loss 0.232914
# epoch 32 loss_pde:0.16317783, loss_ib:0.00696051
# epoch 32: loss 0.232783
# epoch 33 loss_pde:0.16316742, loss_ib:0.00695240
# epoch 33: loss 0.232691
# epoch 34 loss_pde:0.16307278, loss_ib:0.00695878
# epoch 34: loss 0.232661
# epoch 35 loss_pde:0.16308215, loss_ib:0.00696139
# epoch 35: loss 0.232696
# epoch 36 loss_pde:0.16320114, loss_ib:0.00694897
# epoch 36: loss 0.232691
# epoch 37 loss_pde:0.16331373, loss_ib:0.00692594
# epoch 37: loss 0.232573
# epoch 38 loss_pde:0.16335219, loss_ib:0.00690902
# epoch 38: loss 0.232442
# epoch 39 loss_pde:0.16329926, loss_ib:0.00691098
# epoch 39: loss 0.232409
# epoch 40 loss_pde:0.16313614, loss_ib:0.00692957
# epoch 40: loss 0.232432
# epoch 41 loss_pde:0.16288865, loss_ib:0.00695240
# epoch 41: loss 0.232413
# epoch 42 loss_pde:0.16266948, loss_ib:0.00696677
# epoch 42: loss 0.232337
# epoch 43 loss_pde:0.16260748, loss_ib:0.00696527
# epoch 43: loss 0.232260
# epoch 44 loss_pde:0.16273013, loss_ib:0.00694902
# epoch 44: loss 0.232220
# epoch 45 loss_pde:0.16293642, loss_ib:0.00692712
# epoch 45: loss 0.232208
# epoch 46 loss_pde:0.16308445, loss_ib:0.00690989
# epoch 46: loss 0.232183
# epoch 47 loss_pde:0.16309986, loss_ib:0.00690309
# epoch 47: loss 0.232131
# epoch 48 loss_pde:0.16300610, loss_ib:0.00690684
# epoch 48: loss 0.232075
# epoch 49 loss_pde:0.16287856, loss_ib:0.00691604
# epoch 49: loss 0.232039
# epoch 50 loss_pde:0.16278391, loss_ib:0.00692283
# epoch 50: loss 0.232012
# epoch 51 loss_pde:0.16275486, loss_ib:0.00692214
# epoch 51: loss 0.231976
# epoch 52 loss_pde:0.16278613, loss_ib:0.00691513
# epoch 52: loss 0.231937
# epoch 53 loss_pde:0.16283384, loss_ib:0.00690683
# epoch 53: loss 0.231902
# epoch 54 loss_pde:0.16283688, loss_ib:0.00690235
# epoch 54: loss 0.231860
# epoch 55 loss_pde:0.16277002, loss_ib:0.00690450
# epoch 55: loss 0.231815
# epoch 56 loss_pde:0.16267326, loss_ib:0.00691136
# epoch 56: loss 0.231787
# epoch 57 loss_pde:0.16260938, loss_ib:0.00691580
# epoch 57: loss 0.231767
# epoch 58 loss_pde:0.16260579, loss_ib:0.00691178
# epoch 58: loss 0.231724
# epoch 59 loss_pde:0.16265483, loss_ib:0.00690113
# epoch 59: loss 0.231666
# epoch 60 loss_pde:0.16272581, loss_ib:0.00689081
# epoch 60: loss 0.231634
# epoch 61 loss_pde:0.16276230, loss_ib:0.00688563
# epoch 61: loss 0.231619
# epoch 62 loss_pde:0.16272379, loss_ib:0.00688589
# epoch 62: loss 0.231583
# epoch 63 loss_pde:0.16263342, loss_ib:0.00688962
# epoch 63: loss 0.231530
# epoch 64 loss_pde:0.16255315, loss_ib:0.00689360
# epoch 64: loss 0.231489
# epoch 65 loss_pde:0.16252472, loss_ib:0.00689398
# epoch 65: loss 0.231464
# epoch 66 loss_pde:0.16254264, loss_ib:0.00688921
# epoch 66: loss 0.231435
# epoch 67 loss_pde:0.16256744, loss_ib:0.00688228
# epoch 67: loss 0.231390
# epoch 68 loss_pde:0.16256346, loss_ib:0.00687828
# epoch 68: loss 0.231346
# epoch 69 loss_pde:0.16252428, loss_ib:0.00687908
# epoch 69: loss 0.231315
# epoch 70 loss_pde:0.16246888, loss_ib:0.00688155
# epoch 70: loss 0.231284
# epoch 71 loss_pde:0.16242808, loss_ib:0.00688156
# epoch 71: loss 0.231244
# epoch 72 loss_pde:0.16242252, loss_ib:0.00687796
# epoch 72: loss 0.231202
# epoch 73 loss_pde:0.16244024, loss_ib:0.00687270
# epoch 73: loss 0.231167
# epoch 74 loss_pde:0.16244777, loss_ib:0.00686850
# epoch 74: loss 0.231133
# epoch 75 loss_pde:0.16242626, loss_ib:0.00686674
# epoch 75: loss 0.231094
# epoch 76 loss_pde:0.16238594, loss_ib:0.00686689
# epoch 76: loss 0.231055
# epoch 77 loss_pde:0.16234770, loss_ib:0.00686705
# epoch 77: loss 0.231018
# epoch 78 loss_pde:0.16232303, loss_ib:0.00686571
# epoch 78: loss 0.230980
# epoch 79 loss_pde:0.16230918, loss_ib:0.00686323
# epoch 79: loss 0.230941
# epoch 80 loss_pde:0.16229521, loss_ib:0.00686090
# epoch 80: loss 0.230904
# epoch 81 loss_pde:0.16227317, loss_ib:0.00685929
# epoch 81: loss 0.230866
# epoch 82 loss_pde:0.16224755, loss_ib:0.00685793
# epoch 82: loss 0.230827
# epoch 83 loss_pde:0.16223018, loss_ib:0.00685578
# epoch 83: loss 0.230788
# epoch 84 loss_pde:0.16222478, loss_ib:0.00685251
# epoch 84: loss 0.230750
# epoch 85 loss_pde:0.16222030, loss_ib:0.00684911
# epoch 85: loss 0.230711
# epoch 86 loss_pde:0.16220194, loss_ib:0.00684700
# epoch 86: loss 0.230672
# epoch 87 loss_pde:0.16216677, loss_ib:0.00684655
# epoch 87: loss 0.230632
# epoch 88 loss_pde:0.16212773, loss_ib:0.00684657
# epoch 88: loss 0.230593
# epoch 89 loss_pde:0.16210103, loss_ib:0.00684533
# epoch 89: loss 0.230554
# epoch 90 loss_pde:0.16209009, loss_ib:0.00684243
# epoch 90: loss 0.230514
# epoch 91 loss_pde:0.16208322, loss_ib:0.00683912
# epoch 91: loss 0.230474
# epoch 92 loss_pde:0.16206530, loss_ib:0.00683695
# epoch 92: loss 0.230435
# epoch 93 loss_pde:0.16203399, loss_ib:0.00683610
# epoch 93: loss 0.230395
# epoch 94 loss_pde:0.16200230, loss_ib:0.00683524
# epoch 94: loss 0.230355
# epoch 95 loss_pde:0.16198346, loss_ib:0.00683309
# epoch 95: loss 0.230314
# epoch 96 loss_pde:0.16197647, loss_ib:0.00682974
# epoch 96: loss 0.230274
# epoch 97 loss_pde:0.16196859, loss_ib:0.00682650
# epoch 97: loss 0.230234
# epoch 98 loss_pde:0.16194862, loss_ib:0.00682443
# epoch 98: loss 0.230193
# epoch 99 loss_pde:0.16191681, loss_ib:0.00682351
# epoch 99: loss 0.230152
# epoch 100 loss_pde:0.16188335, loss_ib:0.00682276
# epoch 100: loss 0.230111
# epoch 101 loss_pde:0.16185786, loss_ib:0.00682122
# epoch 101: loss 0.230070
# epoch 102 loss_pde:0.16184123, loss_ib:0.00681876
# epoch 102: loss 0.230029
# epoch 103 loss_pde:0.16182703, loss_ib:0.00681604
# epoch 103: loss 0.229987
# epoch 104 loss_pde:0.16180830, loss_ib:0.00681377
# epoch 104: loss 0.229946
# epoch 105 loss_pde:0.16178343, loss_ib:0.00681210
# epoch 105: loss 0.229904
# epoch 106 loss_pde:0.16175683, loss_ib:0.00681059
# epoch 106: loss 0.229863
# epoch 107 loss_pde:0.16173403, loss_ib:0.00680869
# epoch 107: loss 0.229821
# epoch 108 loss_pde:0.16171685, loss_ib:0.00680621
# epoch 108: loss 0.229779
# epoch 109 loss_pde:0.16170101, loss_ib:0.00680359
# epoch 109: loss 0.229737
# epoch 110 loss_pde:0.16168003, loss_ib:0.00680147
# epoch 110: loss 0.229695
# epoch 111 loss_pde:0.16165225, loss_ib:0.00680002
# epoch 111: loss 0.229652
# epoch 112 loss_pde:0.16162291, loss_ib:0.00679871
# epoch 112: loss 0.229610
# epoch 113 loss_pde:0.16159908, loss_ib:0.00679683
# epoch 113: loss 0.229567
# epoch 114 loss_pde:0.16158172, loss_ib:0.00679431
# epoch 114: loss 0.229525
# epoch 115 loss_pde:0.16156493, loss_ib:0.00679172
# epoch 115: loss 0.229482
# epoch 116 loss_pde:0.16154312, loss_ib:0.00678961
# epoch 116: loss 0.229439
# epoch 117 loss_pde:0.16151749, loss_ib:0.00678788
# epoch 117: loss 0.229396
# epoch 118 loss_pde:0.16149348, loss_ib:0.00678598
# epoch 118: loss 0.229353
# epoch 119 loss_pde:0.16147307, loss_ib:0.00678369
# epoch 119: loss 0.229310
# epoch 120 loss_pde:0.16145267, loss_ib:0.00678140
# epoch 120: loss 0.229267
# epoch 121 loss_pde:0.16142836, loss_ib:0.00677950
# epoch 121: loss 0.229223
# epoch 122 loss_pde:0.16140138, loss_ib:0.00677785
# epoch 122: loss 0.229180
# epoch 123 loss_pde:0.16137631, loss_ib:0.00677600
# epoch 123: loss 0.229136
# epoch 124 loss_pde:0.16135502, loss_ib:0.00677375
# epoch 124: loss 0.229093
# epoch 125 loss_pde:0.16133462, loss_ib:0.00677141
# epoch 125: loss 0.229049
# epoch 126 loss_pde:0.16131462, loss_ib:0.00676899
# epoch 126: loss 0.229005
# epoch 127 loss_pde:0.16129148, loss_ib:0.00676689
# epoch 127: loss 0.228960
# epoch 128 loss_pde:0.16126521, loss_ib:0.00676512
# epoch 128: loss 0.228916
# epoch 129 loss_pde:0.16123891, loss_ib:0.00676331
# epoch 129: loss 0.228872
# epoch 130 loss_pde:0.16121428, loss_ib:0.00676132
# epoch 130: loss 0.228827
# epoch 131 loss_pde:0.16119042, loss_ib:0.00675926
# epoch 131: loss 0.228783
# epoch 132 loss_pde:0.16116595, loss_ib:0.00675725
# epoch 132: loss 0.228738
# epoch 133 loss_pde:0.16114113, loss_ib:0.00675526
# epoch 133: loss 0.228694
# epoch 134 loss_pde:0.16111696, loss_ib:0.00675320
# epoch 134: loss 0.228649
# epoch 135 loss_pde:0.16109371, loss_ib:0.00675104
# epoch 135: loss 0.228604
# epoch 136 loss_pde:0.16107078, loss_ib:0.00674883
# epoch 136: loss 0.228559
# epoch 137 loss_pde:0.16104777, loss_ib:0.00674663
# epoch 137: loss 0.228514
# epoch 138 loss_pde:0.16102450, loss_ib:0.00674444
# epoch 138: loss 0.228469
# epoch 139 loss_pde:0.16100070, loss_ib:0.00674230
# epoch 139: loss 0.228424
# epoch 140 loss_pde:0.16097622, loss_ib:0.00674022
# epoch 140: loss 0.228378
# epoch 141 loss_pde:0.16095138, loss_ib:0.00673817
# epoch 141: loss 0.228333
# epoch 142 loss_pde:0.16092670, loss_ib:0.00673609
# epoch 142: loss 0.228288
# epoch 143 loss_pde:0.16090278, loss_ib:0.00673393
# epoch 143: loss 0.228242
# epoch 144 loss_pde:0.16087951, loss_ib:0.00673170
# epoch 144: loss 0.228196
# epoch 145 loss_pde:0.16085629, loss_ib:0.00672945
# epoch 145: loss 0.228151
# epoch 146 loss_pde:0.16083205, loss_ib:0.00672730
# epoch 146: loss 0.228105
# epoch 147 loss_pde:0.16080606, loss_ib:0.00672530
# epoch 147: loss 0.228059
# epoch 148 loss_pde:0.16077904, loss_ib:0.00672342
# epoch 148: loss 0.228013
# epoch 149 loss_pde:0.16075300, loss_ib:0.00672142
# epoch 149: loss 0.227967
# epoch 150 loss_pde:0.16072945, loss_ib:0.00671917
# epoch 150: loss 0.227921
# epoch 151 loss_pde:0.16070740, loss_ib:0.00671676
# epoch 151: loss 0.227875
# epoch 152 loss_pde:0.16068415, loss_ib:0.00671446
# epoch 152: loss 0.227829
# epoch 153 loss_pde:0.16065836, loss_ib:0.00671241
# epoch 153: loss 0.227782
# epoch 154 loss_pde:0.16063176, loss_ib:0.00671044
# epoch 154: loss 0.227736
# epoch 155 loss_pde:0.16060629, loss_ib:0.00670834
# epoch 155: loss 0.227690
# epoch 156 loss_pde:0.16058215, loss_ib:0.00670611
# epoch 156: loss 0.227643
# epoch 157 loss_pde:0.16055824, loss_ib:0.00670384
# epoch 157: loss 0.227597
# epoch 158 loss_pde:0.16053370, loss_ib:0.00670163
# epoch 158: loss 0.227550
# epoch 159 loss_pde:0.16050877, loss_ib:0.00669945
# epoch 159: loss 0.227503
# epoch 160 loss_pde:0.16048379, loss_ib:0.00669728
# epoch 160: loss 0.227457
# epoch 161 loss_pde:0.16045873, loss_ib:0.00669510
# epoch 161: loss 0.227410
# epoch 162 loss_pde:0.16043340, loss_ib:0.00669295
# epoch 162: loss 0.227363
# epoch 163 loss_pde:0.16040784, loss_ib:0.00669081
# epoch 163: loss 0.227316
# epoch 164 loss_pde:0.16038235, loss_ib:0.00668866
# epoch 164: loss 0.227269
# epoch 165 loss_pde:0.16035748, loss_ib:0.00668644
# epoch 165: loss 0.227222
# epoch 166 loss_pde:0.16033334, loss_ib:0.00668414
# epoch 166: loss 0.227175
# epoch 167 loss_pde:0.16030911, loss_ib:0.00668184
# epoch 167: loss 0.227127
# epoch 168 loss_pde:0.16028370, loss_ib:0.00667966
# epoch 168: loss 0.227080
# epoch 169 loss_pde:0.16025721, loss_ib:0.00667757
# epoch 169: loss 0.227033
# epoch 170 loss_pde:0.16023088, loss_ib:0.00667547
# epoch 170: loss 0.226986
# epoch 171 loss_pde:0.16020551, loss_ib:0.00667327
# epoch 171: loss 0.226938
# epoch 172 loss_pde:0.16018081, loss_ib:0.00667099
# epoch 172: loss 0.226891
# epoch 173 loss_pde:0.16015603, loss_ib:0.00666872
# epoch 173: loss 0.226843
# epoch 174 loss_pde:0.16013077, loss_ib:0.00666648
# epoch 174: loss 0.226796
# epoch 175 loss_pde:0.16010490, loss_ib:0.00666431
# epoch 175: loss 0.226748
# epoch 176 loss_pde:0.16007867, loss_ib:0.00666216
# epoch 176: loss 0.226700
# epoch 177 loss_pde:0.16005245, loss_ib:0.00666001
# epoch 177: loss 0.226653
# epoch 178 loss_pde:0.16002673, loss_ib:0.00665781
# epoch 178: loss 0.226605
# epoch 179 loss_pde:0.16000149, loss_ib:0.00665554
# epoch 179: loss 0.226557
# epoch 180 loss_pde:0.15997626, loss_ib:0.00665328
# epoch 180: loss 0.226509
# epoch 181 loss_pde:0.15995070, loss_ib:0.00665104
# epoch 181: loss 0.226461
# epoch 182 loss_pde:0.15992464, loss_ib:0.00664885
# epoch 182: loss 0.226413
# epoch 183 loss_pde:0.15989831, loss_ib:0.00664668
# epoch 183: loss 0.226365
# epoch 184 loss_pde:0.15987220, loss_ib:0.00664448
# epoch 184: loss 0.226317
# epoch 185 loss_pde:0.15984638, loss_ib:0.00664225
# epoch 185: loss 0.226269
# epoch 186 loss_pde:0.15982071, loss_ib:0.00664000
# epoch 186: loss 0.226221
# epoch 187 loss_pde:0.15979499, loss_ib:0.00663775
# epoch 187: loss 0.226173
# epoch 188 loss_pde:0.15976904, loss_ib:0.00663552
# epoch 188: loss 0.226124
# epoch 189 loss_pde:0.15974274, loss_ib:0.00663332
# epoch 189: loss 0.226076
# epoch 190 loss_pde:0.15971632, loss_ib:0.00663113
# epoch 190: loss 0.226028
# epoch 191 loss_pde:0.15968993, loss_ib:0.00662893
# epoch 191: loss 0.225979
# epoch 192 loss_pde:0.15966371, loss_ib:0.00662671
# epoch 192: loss 0.225931
# epoch 193 loss_pde:0.15963763, loss_ib:0.00662447
# epoch 193: loss 0.225882
# epoch 194 loss_pde:0.15961170, loss_ib:0.00662221
# epoch 194: loss 0.225834
# epoch 195 loss_pde:0.15958554, loss_ib:0.00661998
# epoch 195: loss 0.225785
# epoch 196 loss_pde:0.15955906, loss_ib:0.00661777
# epoch 196: loss 0.225737
# epoch 197 loss_pde:0.15953237, loss_ib:0.00661558
# epoch 197: loss 0.225688
# epoch 198 loss_pde:0.15950584, loss_ib:0.00661336
# epoch 198: loss 0.225639
# epoch 199 loss_pde:0.15947971, loss_ib:0.00661110
# epoch 199: loss 0.225591
# epoch 200 loss_pde:0.15945376, loss_ib:0.00660882
# epoch 200: loss 0.225542
# epoch 201 loss_pde:0.15942749, loss_ib:0.00660657
# epoch 201: loss 0.225493
# epoch 202 loss_pde:0.15940106, loss_ib:0.00660434
# epoch 202: loss 0.225444
# epoch 203 loss_pde:0.15937446, loss_ib:0.00660211
# epoch 203: loss 0.225396
# epoch 204 loss_pde:0.15934783, loss_ib:0.00659988
# epoch 204: loss 0.225347
# epoch 205 loss_pde:0.15932125, loss_ib:0.00659765
# epoch 205: loss 0.225298
# epoch 206 loss_pde:0.15929465, loss_ib:0.00659542
# epoch 206: loss 0.225249
# epoch 207 loss_pde:0.15926805, loss_ib:0.00659318
# epoch 207: loss 0.225200
# epoch 208 loss_pde:0.15924147, loss_ib:0.00659094
# epoch 208: loss 0.225151
# epoch 209 loss_pde:0.15921485, loss_ib:0.00658869
# epoch 209: loss 0.225102
# epoch 210 loss_pde:0.15918817, loss_ib:0.00658645
# epoch 210: loss 0.225053
# epoch 211 loss_pde:0.15916151, loss_ib:0.00658421
# epoch 211: loss 0.225004
# epoch 212 loss_pde:0.15913489, loss_ib:0.00658195
# epoch 212: loss 0.224954
# epoch 213 loss_pde:0.15910839, loss_ib:0.00657969
# epoch 213: loss 0.224905
# epoch 214 loss_pde:0.15908180, loss_ib:0.00657743
# epoch 214: loss 0.224856
# epoch 215 loss_pde:0.15905502, loss_ib:0.00657518
# epoch 215: loss 0.224807
# epoch 216 loss_pde:0.15902822, loss_ib:0.00657293
# epoch 216: loss 0.224758
# epoch 217 loss_pde:0.15900145, loss_ib:0.00657068
# epoch 217: loss 0.224708
# epoch 218 loss_pde:0.15897477, loss_ib:0.00656842
# epoch 218: loss 0.224659
# epoch 219 loss_pde:0.15894797, loss_ib:0.00656617
# epoch 219: loss 0.224610
# epoch 220 loss_pde:0.15892130, loss_ib:0.00656390
# epoch 220: loss 0.224560
# epoch 221 loss_pde:0.15889445, loss_ib:0.00656164
# epoch 221: loss 0.224511
# epoch 222 loss_pde:0.15886748, loss_ib:0.00655940
# epoch 222: loss 0.224461
# epoch 223 loss_pde:0.15884052, loss_ib:0.00655715
# epoch 223: loss 0.224412
# epoch 224 loss_pde:0.15881366, loss_ib:0.00655489
# epoch 224: loss 0.224363
# epoch 225 loss_pde:0.15878667, loss_ib:0.00655263
# epoch 225: loss 0.224313
# epoch 226 loss_pde:0.15875983, loss_ib:0.00655037
# epoch 226: loss 0.224264
# epoch 227 loss_pde:0.15873298, loss_ib:0.00654810
# epoch 227: loss 0.224214
# epoch 228 loss_pde:0.15870595, loss_ib:0.00654584
# epoch 228: loss 0.224164
# epoch 229 loss_pde:0.15867887, loss_ib:0.00654360
# epoch 229: loss 0.224115
# epoch 230 loss_pde:0.15865172, loss_ib:0.00654135
# epoch 230: loss 0.224065
# epoch 231 loss_pde:0.15862478, loss_ib:0.00653908
# epoch 231: loss 0.224016
# epoch 232 loss_pde:0.15859786, loss_ib:0.00653681
# epoch 232: loss 0.223966
# epoch 233 loss_pde:0.15857078, loss_ib:0.00653455
# epoch 233: loss 0.223916
# epoch 234 loss_pde:0.15854363, loss_ib:0.00653230
# epoch 234: loss 0.223867
# epoch 235 loss_pde:0.15851653, loss_ib:0.00653004
# epoch 235: loss 0.223817
# epoch 236 loss_pde:0.15848947, loss_ib:0.00652777
# epoch 236: loss 0.223767
# epoch 237 loss_pde:0.15846226, loss_ib:0.00652552
# epoch 237: loss 0.223717
# epoch 238 loss_pde:0.15843515, loss_ib:0.00652325
# epoch 238: loss 0.223668
# epoch 239 loss_pde:0.15840802, loss_ib:0.00652098
# epoch 239: loss 0.223618
# epoch 240 loss_pde:0.15838091, loss_ib:0.00651871
# epoch 240: loss 0.223568
# epoch 241 loss_pde:0.15835379, loss_ib:0.00651644
# epoch 241: loss 0.223518
# epoch 242 loss_pde:0.15832663, loss_ib:0.00651418
# epoch 242: loss 0.223468
# epoch 243 loss_pde:0.15829934, loss_ib:0.00651192
# epoch 243: loss 0.223419
# epoch 244 loss_pde:0.15827209, loss_ib:0.00650966
# epoch 244: loss 0.223369
# epoch 245 loss_pde:0.15824498, loss_ib:0.00650738
# epoch 245: loss 0.223319
# epoch 246 loss_pde:0.15821779, loss_ib:0.00650511
# epoch 246: loss 0.223269
# epoch 247 loss_pde:0.15819034, loss_ib:0.00650286
# epoch 247: loss 0.223219
# epoch 248 loss_pde:0.15816307, loss_ib:0.00650059
# epoch 248: loss 0.223169
# epoch 249 loss_pde:0.15813589, loss_ib:0.00649832
# epoch 249: loss 0.223119
# epoch 250 loss_pde:0.15810867, loss_ib:0.00649604
# epoch 250: loss 0.223069
# epoch 251 loss_pde:0.15808147, loss_ib:0.00649377
# epoch 251: loss 0.223019
# epoch 252 loss_pde:0.15805414, loss_ib:0.00649150
# epoch 252: loss 0.222969
# epoch 253 loss_pde:0.15802681, loss_ib:0.00648923
# epoch 253: loss 0.222919
# epoch 254 loss_pde:0.15799955, loss_ib:0.00648696
# epoch 254: loss 0.222869
# epoch 255 loss_pde:0.15797223, loss_ib:0.00648469
# epoch 255: loss 0.222819
# epoch 256 loss_pde:0.15794477, loss_ib:0.00648243
# epoch 256: loss 0.222769
# epoch 257 loss_pde:0.15791734, loss_ib:0.00648016
# epoch 257: loss 0.222719
# epoch 258 loss_pde:0.15788998, loss_ib:0.00647790
# epoch 258: loss 0.222669
# epoch 259 loss_pde:0.15786260, loss_ib:0.00647563
# epoch 259: loss 0.222619
# epoch 260 loss_pde:0.15783504, loss_ib:0.00647337
# epoch 260: loss 0.222569
# epoch 261 loss_pde:0.15780784, loss_ib:0.00647108
# epoch 261: loss 0.222519
# epoch 262 loss_pde:0.15778062, loss_ib:0.00646879
# epoch 262: loss 0.222469
# epoch 263 loss_pde:0.15775310, loss_ib:0.00646654
# epoch 263: loss 0.222418
# epoch 264 loss_pde:0.15772547, loss_ib:0.00646428
# epoch 264: loss 0.222368
# epoch 265 loss_pde:0.15769802, loss_ib:0.00646202
# epoch 265: loss 0.222318
# epoch 266 loss_pde:0.15767050, loss_ib:0.00645976
# epoch 266: loss 0.222268
# epoch 267 loss_pde:0.15764327, loss_ib:0.00645746
# epoch 267: loss 0.222218
# epoch 268 loss_pde:0.15761591, loss_ib:0.00645518
# epoch 268: loss 0.222168
# epoch 269 loss_pde:0.15758820, loss_ib:0.00645294
# epoch 269: loss 0.222118
# epoch 270 loss_pde:0.15756057, loss_ib:0.00645068
# epoch 270: loss 0.222067
# epoch 271 loss_pde:0.15753323, loss_ib:0.00644840
# epoch 271: loss 0.222017
# epoch 272 loss_pde:0.15750563, loss_ib:0.00644614
# epoch 272: loss 0.221967
# epoch 273 loss_pde:0.15747783, loss_ib:0.00644390
# epoch 273: loss 0.221917
# epoch 274 loss_pde:0.15745047, loss_ib:0.00644161
# epoch 274: loss 0.221867
# epoch 275 loss_pde:0.15742311, loss_ib:0.00643933
# epoch 275: loss 0.221816
# epoch 276 loss_pde:0.15739539, loss_ib:0.00643708
# epoch 276: loss 0.221766
# epoch 277 loss_pde:0.15736772, loss_ib:0.00643482
# epoch 277: loss 0.221716
# epoch 278 loss_pde:0.15734023, loss_ib:0.00643255
# epoch 278: loss 0.221666
# epoch 279 loss_pde:0.15731263, loss_ib:0.00643028
# epoch 279: loss 0.221615
# epoch 280 loss_pde:0.15728517, loss_ib:0.00642800
# epoch 280: loss 0.221565
# epoch 281 loss_pde:0.15725775, loss_ib:0.00642572
# epoch 281: loss 0.221515
# epoch 282 loss_pde:0.15723011, loss_ib:0.00642346
# epoch 282: loss 0.221465
# epoch 283 loss_pde:0.15720233, loss_ib:0.00642121
# epoch 283: loss 0.221414
# epoch 284 loss_pde:0.15717474, loss_ib:0.00641895
# epoch 284: loss 0.221364
# epoch 285 loss_pde:0.15714704, loss_ib:0.00641669
# epoch 285: loss 0.221314
# epoch 286 loss_pde:0.15711939, loss_ib:0.00641443
# epoch 286: loss 0.221264
# epoch 287 loss_pde:0.15709206, loss_ib:0.00641214
# epoch 287: loss 0.221213
# epoch 288 loss_pde:0.15706450, loss_ib:0.00640986
# epoch 288: loss 0.221163
# epoch 289 loss_pde:0.15703669, loss_ib:0.00640762
# epoch 289: loss 0.221113
# epoch 290 loss_pde:0.15700905, loss_ib:0.00640535
# epoch 290: loss 0.221063
# epoch 291 loss_pde:0.15698150, loss_ib:0.00640308
# epoch 291: loss 0.221012
# epoch 292 loss_pde:0.15695368, loss_ib:0.00640084
# epoch 292: loss 0.220962
# epoch 293 loss_pde:0.15692616, loss_ib:0.00639856
# epoch 293: loss 0.220912
# epoch 294 loss_pde:0.15689874, loss_ib:0.00639627
# epoch 294: loss 0.220861
# epoch 295 loss_pde:0.15687098, loss_ib:0.00639402
# epoch 295: loss 0.220811
# epoch 296 loss_pde:0.15684342, loss_ib:0.00639175
# epoch 296: loss 0.220761
# epoch 297 loss_pde:0.15681589, loss_ib:0.00638948
# epoch 297: loss 0.220711
# epoch 298 loss_pde:0.15678811, loss_ib:0.00638722
# epoch 298: loss 0.220660
# epoch 299 loss_pde:0.15676051, loss_ib:0.00638495
# epoch 299: loss 0.220610
# epoch 300 loss_pde:0.15673302, loss_ib:0.00638268
# epoch 300: loss 0.220560
# epoch 301 loss_pde:0.15670522, loss_ib:0.00638042
# epoch 301: loss 0.220509
# epoch 302 loss_pde:0.15667741, loss_ib:0.00637818
# epoch 302: loss 0.220459
# epoch 303 loss_pde:0.15664989, loss_ib:0.00637590
# epoch 303: loss 0.220409
# epoch 304 loss_pde:0.15662214, loss_ib:0.00637365
# epoch 304: loss 0.220359
# epoch 305 loss_pde:0.15659443, loss_ib:0.00637139
# epoch 305: loss 0.220308
# epoch 306 loss_pde:0.15656692, loss_ib:0.00636911
# epoch 306: loss 0.220258
# epoch 307 loss_pde:0.15653928, loss_ib:0.00636685
# epoch 307: loss 0.220208
# epoch 308 loss_pde:0.15651141, loss_ib:0.00636461
# epoch 308: loss 0.220158
# epoch 309 loss_pde:0.15648371, loss_ib:0.00636235
# epoch 309: loss 0.220107
# epoch 310 loss_pde:0.15645590, loss_ib:0.00636011
# epoch 310: loss 0.220057
# epoch 311 loss_pde:0.15642810, loss_ib:0.00635786
# epoch 311: loss 0.220007
# epoch 312 loss_pde:0.15640056, loss_ib:0.00635559
# epoch 312: loss 0.219956
# epoch 313 loss_pde:0.15637286, loss_ib:0.00635333
# epoch 313: loss 0.219906
# epoch 314 loss_pde:0.15634501, loss_ib:0.00635109
# epoch 314: loss 0.219856
# epoch 315 loss_pde:0.15631750, loss_ib:0.00634881
# epoch 315: loss 0.219806
# epoch 316 loss_pde:0.15628986, loss_ib:0.00634655
# epoch 316: loss 0.219755
# epoch 317 loss_pde:0.15626206, loss_ib:0.00634431
# epoch 317: loss 0.219705
# epoch 318 loss_pde:0.15623426, loss_ib:0.00634207
# epoch 318: loss 0.219655
# epoch 319 loss_pde:0.15620673, loss_ib:0.00633979
# epoch 319: loss 0.219605
# epoch 320 loss_pde:0.15617904, loss_ib:0.00633754
# epoch 320: loss 0.219554
# epoch 321 loss_pde:0.15615128, loss_ib:0.00633529
# epoch 321: loss 0.219504
# epoch 322 loss_pde:0.15612346, loss_ib:0.00633305
# epoch 322: loss 0.219454
# epoch 323 loss_pde:0.15609576, loss_ib:0.00633080
# epoch 323: loss 0.219404
# epoch 324 loss_pde:0.15606825, loss_ib:0.00632853
# epoch 324: loss 0.219354
# epoch 325 loss_pde:0.15604058, loss_ib:0.00632628
# epoch 325: loss 0.219303
# epoch 326 loss_pde:0.15601270, loss_ib:0.00632404
# epoch 326: loss 0.219253
# epoch 327 loss_pde:0.15598525, loss_ib:0.00632177
# epoch 327: loss 0.219203
# epoch 328 loss_pde:0.15595770, loss_ib:0.00631951
# epoch 328: loss 0.219153
# epoch 329 loss_pde:0.15592991, loss_ib:0.00631727
# epoch 329: loss 0.219103
# epoch 330 loss_pde:0.15590213, loss_ib:0.00631503
# epoch 330: loss 0.219052
# epoch 331 loss_pde:0.15587451, loss_ib:0.00631277
# epoch 331: loss 0.219002
# epoch 332 loss_pde:0.15584680, loss_ib:0.00631052
# epoch 332: loss 0.218952
# epoch 333 loss_pde:0.15581915, loss_ib:0.00630827
# epoch 333: loss 0.218902
# epoch 334 loss_pde:0.15579146, loss_ib:0.00630602
# epoch 334: loss 0.218852
# epoch 335 loss_pde:0.15576375, loss_ib:0.00630378
# epoch 335: loss 0.218802
# epoch 336 loss_pde:0.15573613, loss_ib:0.00630153
# epoch 336: loss 0.218751
# epoch 337 loss_pde:0.15570833, loss_ib:0.00629930
# epoch 337: loss 0.218701
# epoch 338 loss_pde:0.15568072, loss_ib:0.00629705
# epoch 338: loss 0.218651
# epoch 339 loss_pde:0.15565309, loss_ib:0.00629480
# epoch 339: loss 0.218601
# epoch 340 loss_pde:0.15562527, loss_ib:0.00629257
# epoch 340: loss 0.218551
# epoch 341 loss_pde:0.15559760, loss_ib:0.00629033
# epoch 341: loss 0.218501
# epoch 342 loss_pde:0.15556997, loss_ib:0.00628809
# epoch 342: loss 0.218451
# epoch 343 loss_pde:0.15554219, loss_ib:0.00628585
# epoch 343: loss 0.218401
# epoch 344 loss_pde:0.15551464, loss_ib:0.00628360
# epoch 344: loss 0.218351
# epoch 345 loss_pde:0.15548685, loss_ib:0.00628137
# epoch 345: loss 0.218301
# epoch 346 loss_pde:0.15545911, loss_ib:0.00627914
# epoch 346: loss 0.218251
# epoch 347 loss_pde:0.15543160, loss_ib:0.00627689
# epoch 347: loss 0.218201
# epoch 348 loss_pde:0.15540382, loss_ib:0.00627466
# epoch 348: loss 0.218150
# epoch 349 loss_pde:0.15537611, loss_ib:0.00627244
# epoch 349: loss 0.218100
# epoch 350 loss_pde:0.15534855, loss_ib:0.00627019
# epoch 350: loss 0.218050
# epoch 351 loss_pde:0.15532085, loss_ib:0.00626796
# epoch 351: loss 0.218000
# epoch 352 loss_pde:0.15529320, loss_ib:0.00626572
# epoch 352: loss 0.217950
# epoch 353 loss_pde:0.15526541, loss_ib:0.00626350
# epoch 353: loss 0.217900
# epoch 354 loss_pde:0.15523767, loss_ib:0.00626128
# epoch 354: loss 0.217850
# epoch 355 loss_pde:0.15521003, loss_ib:0.00625905
# epoch 355: loss 0.217800
# epoch 356 loss_pde:0.15518253, loss_ib:0.00625680
# epoch 356: loss 0.217751
# epoch 357 loss_pde:0.15515488, loss_ib:0.00625457
# epoch 357: loss 0.217701
# epoch 358 loss_pde:0.15512703, loss_ib:0.00625236
# epoch 358: loss 0.217651
# epoch 359 loss_pde:0.15509915, loss_ib:0.00625016
# epoch 359: loss 0.217601
# epoch 360 loss_pde:0.15507133, loss_ib:0.00624795
# epoch 360: loss 0.217551
# epoch 361 loss_pde:0.15504406, loss_ib:0.00624569
# epoch 361: loss 0.217501
# epoch 362 loss_pde:0.15501662, loss_ib:0.00624345
# epoch 362: loss 0.217451
# epoch 363 loss_pde:0.15498900, loss_ib:0.00624122
# epoch 363: loss 0.217401
# epoch 364 loss_pde:0.15496156, loss_ib:0.00623898
# epoch 364: loss 0.217351
# epoch 365 loss_pde:0.15493390, loss_ib:0.00623676
# epoch 365: loss 0.217302
# epoch 366 loss_pde:0.15490612, loss_ib:0.00623455
# epoch 366: loss 0.217252
# epoch 367 loss_pde:0.15487856, loss_ib:0.00623232
# epoch 367: loss 0.217202
# epoch 368 loss_pde:0.15485097, loss_ib:0.00623010
# epoch 368: loss 0.217152
# epoch 369 loss_pde:0.15482350, loss_ib:0.00622787
# epoch 369: loss 0.217102
# epoch 370 loss_pde:0.15479589, loss_ib:0.00622565
# epoch 370: loss 0.217052
# epoch 371 loss_pde:0.15476805, loss_ib:0.00622346
# epoch 371: loss 0.217003
# epoch 372 loss_pde:0.15474060, loss_ib:0.00622122
# epoch 372: loss 0.216953
# epoch 373 loss_pde:0.15471289, loss_ib:0.00621903
# epoch 373: loss 0.216903
# epoch 374 loss_pde:0.15468527, loss_ib:0.00621681
# epoch 374: loss 0.216853
# epoch 375 loss_pde:0.15465780, loss_ib:0.00621459
# epoch 375: loss 0.216804
# epoch 376 loss_pde:0.15463020, loss_ib:0.00621238
# epoch 376: loss 0.216754
# epoch 377 loss_pde:0.15460262, loss_ib:0.00621017
# epoch 377: loss 0.216704
# epoch 378 loss_pde:0.15457499, loss_ib:0.00620796
# epoch 378: loss 0.216655
# epoch 379 loss_pde:0.15454736, loss_ib:0.00620575
# epoch 379: loss 0.216605
# epoch 380 loss_pde:0.15451978, loss_ib:0.00620354
# epoch 380: loss 0.216555
# epoch 381 loss_pde:0.15449204, loss_ib:0.00620135
# epoch 381: loss 0.216506
# epoch 382 loss_pde:0.15446456, loss_ib:0.00619914
# epoch 382: loss 0.216456
# epoch 383 loss_pde:0.15443699, loss_ib:0.00619694
# epoch 383: loss 0.216406
# epoch 384 loss_pde:0.15440924, loss_ib:0.00619475
# epoch 384: loss 0.216357
# epoch 385 loss_pde:0.15438180, loss_ib:0.00619253
# epoch 385: loss 0.216307
# epoch 386 loss_pde:0.15435442, loss_ib:0.00619032
# epoch 386: loss 0.216258
# epoch 387 loss_pde:0.15432681, loss_ib:0.00618812
# epoch 387: loss 0.216208
# epoch 388 loss_pde:0.15429936, loss_ib:0.00618591
# epoch 388: loss 0.216158
# epoch 389 loss_pde:0.15427181, loss_ib:0.00618371
# epoch 389: loss 0.216109
# epoch 390 loss_pde:0.15424432, loss_ib:0.00618151
# epoch 390: loss 0.216059
# epoch 391 loss_pde:0.15421683, loss_ib:0.00617931
# epoch 391: loss 0.216010
# epoch 392 loss_pde:0.15418926, loss_ib:0.00617712
# epoch 392: loss 0.215960
# epoch 393 loss_pde:0.15416166, loss_ib:0.00617493
# epoch 393: loss 0.215911
# epoch 394 loss_pde:0.15413406, loss_ib:0.00617275
# epoch 394: loss 0.215862
# epoch 395 loss_pde:0.15410659, loss_ib:0.00617055
# epoch 395: loss 0.215812
# epoch 396 loss_pde:0.15407921, loss_ib:0.00616834
# epoch 396: loss 0.215763
# epoch 397 loss_pde:0.15405150, loss_ib:0.00616618
# epoch 397: loss 0.215713
# epoch 398 loss_pde:0.15402414, loss_ib:0.00616397
# epoch 398: loss 0.215664
# epoch 399 loss_pde:0.15399672, loss_ib:0.00616178
# epoch 399: loss 0.215615
# epoch 400 loss_pde:0.15396914, loss_ib:0.00615960
# epoch 400: loss 0.215565
# epoch 401 loss_pde:0.15394175, loss_ib:0.00615741
# epoch 401: loss 0.215516
# epoch 402 loss_pde:0.15391427, loss_ib:0.00615522
# epoch 402: loss 0.215466
# epoch 403 loss_pde:0.15388675, loss_ib:0.00615304
# epoch 403: loss 0.215417
# epoch 404 loss_pde:0.15385947, loss_ib:0.00615084
# epoch 404: loss 0.215368
# epoch 405 loss_pde:0.15383184, loss_ib:0.00614868
# epoch 405: loss 0.215319
# epoch 406 loss_pde:0.15380469, loss_ib:0.00614647
# epoch 406: loss 0.215269
# epoch 407 loss_pde:0.15377705, loss_ib:0.00614430
# epoch 407: loss 0.215220
# epoch 408 loss_pde:0.15374964, loss_ib:0.00614212
# epoch 408: loss 0.215171
# epoch 409 loss_pde:0.15372229, loss_ib:0.00613994
# epoch 409: loss 0.215122
# epoch 410 loss_pde:0.15369475, loss_ib:0.00613777
# epoch 410: loss 0.215072
# epoch 411 loss_pde:0.15366735, loss_ib:0.00613560
# epoch 411: loss 0.215023
# epoch 412 loss_pde:0.15363969, loss_ib:0.00613344
# epoch 412: loss 0.214974
# epoch 413 loss_pde:0.15361218, loss_ib:0.00613128
# epoch 413: loss 0.214925
# epoch 414 loss_pde:0.15358484, loss_ib:0.00612910
# epoch 414: loss 0.214876
# epoch 415 loss_pde:0.15355726, loss_ib:0.00612695
# epoch 415: loss 0.214827
# epoch 416 loss_pde:0.15353006, loss_ib:0.00612476
# epoch 416: loss 0.214778
# epoch 417 loss_pde:0.15350261, loss_ib:0.00612260
# epoch 417: loss 0.214729
# epoch 418 loss_pde:0.15347514, loss_ib:0.00612044
# epoch 418: loss 0.214680
# epoch 419 loss_pde:0.15344781, loss_ib:0.00611827
# epoch 419: loss 0.214631
# epoch 420 loss_pde:0.15342045, loss_ib:0.00611611
# epoch 420: loss 0.214582
# epoch 421 loss_pde:0.15339342, loss_ib:0.00611391
# epoch 421: loss 0.214533
# epoch 422 loss_pde:0.15336609, loss_ib:0.00611174
# epoch 422: loss 0.214484
# epoch 423 loss_pde:0.15333880, loss_ib:0.00610957
# epoch 423: loss 0.214435
# epoch 424 loss_pde:0.15331142, loss_ib:0.00610742
# epoch 424: loss 0.214386
# epoch 425 loss_pde:0.15328403, loss_ib:0.00610526
# epoch 425: loss 0.214337
# epoch 426 loss_pde:0.15325677, loss_ib:0.00610309
# epoch 426: loss 0.214288
# epoch 427 loss_pde:0.15322928, loss_ib:0.00610096
# epoch 427: loss 0.214239
# epoch 428 loss_pde:0.15320215, loss_ib:0.00609878
# epoch 428: loss 0.214190
# epoch 429 loss_pde:0.15317494, loss_ib:0.00609662
# epoch 429: loss 0.214141
# epoch 430 loss_pde:0.15314750, loss_ib:0.00609448
# epoch 430: loss 0.214092
# epoch 431 loss_pde:0.15312016, loss_ib:0.00609233
# epoch 431: loss 0.214043
# epoch 432 loss_pde:0.15309304, loss_ib:0.00609016
# epoch 432: loss 0.213995
# epoch 433 loss_pde:0.15306561, loss_ib:0.00608803
# epoch 433: loss 0.213946
# epoch 434 loss_pde:0.15303852, loss_ib:0.00608586
# epoch 434: loss 0.213897
# epoch 435 loss_pde:0.15301099, loss_ib:0.00608374
# epoch 435: loss 0.213848
# epoch 436 loss_pde:0.15298392, loss_ib:0.00608157
# epoch 436: loss 0.213800
# epoch 437 loss_pde:0.15295655, loss_ib:0.00607944
# epoch 437: loss 0.213751
# epoch 438 loss_pde:0.15292940, loss_ib:0.00607728
# epoch 438: loss 0.213702
# epoch 439 loss_pde:0.15290226, loss_ib:0.00607513
# epoch 439: loss 0.213654
# epoch 440 loss_pde:0.15287477, loss_ib:0.00607302
# epoch 440: loss 0.213605
# epoch 441 loss_pde:0.15284787, loss_ib:0.00607085
# epoch 441: loss 0.213556
# epoch 442 loss_pde:0.15282029, loss_ib:0.00606875
# epoch 442: loss 0.213508
# epoch 443 loss_pde:0.15279345, loss_ib:0.00606657
# epoch 443: loss 0.213459
# epoch 444 loss_pde:0.15276587, loss_ib:0.00606447
# epoch 444: loss 0.213411
# epoch 445 loss_pde:0.15273905, loss_ib:0.00606230
# epoch 445: loss 0.213362
# epoch 446 loss_pde:0.15271145, loss_ib:0.00606020
# epoch 446: loss 0.213313
# epoch 447 loss_pde:0.15268478, loss_ib:0.00605802
# epoch 447: loss 0.213265
# epoch 448 loss_pde:0.15265733, loss_ib:0.00605592
# epoch 448: loss 0.213216
# epoch 449 loss_pde:0.15263024, loss_ib:0.00605378
# epoch 449: loss 0.213168
# epoch 450 loss_pde:0.15260270, loss_ib:0.00605169
# epoch 450: loss 0.213120
# epoch 451 loss_pde:0.15257584, loss_ib:0.00604953
# epoch 451: loss 0.213071
# epoch 452 loss_pde:0.15254848, loss_ib:0.00604743
# epoch 452: loss 0.213023
# epoch 453 loss_pde:0.15252136, loss_ib:0.00604529
# epoch 453: loss 0.212974
# epoch 454 loss_pde:0.15249461, loss_ib:0.00604314
# epoch 454: loss 0.212926
# epoch 455 loss_pde:0.15246722, loss_ib:0.00604104
# epoch 455: loss 0.212878
# epoch 456 loss_pde:0.15244032, loss_ib:0.00603890
# epoch 456: loss 0.212829
# epoch 457 loss_pde:0.15241291, loss_ib:0.00603681
# epoch 457: loss 0.212781
# epoch 458 loss_pde:0.15238640, loss_ib:0.00603462
# epoch 458: loss 0.212733
# epoch 459 loss_pde:0.15235868, loss_ib:0.00603257
# epoch 459: loss 0.212684
# epoch 460 loss_pde:0.15233238, loss_ib:0.00603038
# epoch 460: loss 0.212636
# epoch 461 loss_pde:0.15230429, loss_ib:0.00602836
# epoch 461: loss 0.212588
# epoch 462 loss_pde:0.15227818, loss_ib:0.00602616
# epoch 462: loss 0.212540
# epoch 463 loss_pde:0.15225008, loss_ib:0.00602415
# epoch 463: loss 0.212492
# epoch 464 loss_pde:0.15222447, loss_ib:0.00602188
# epoch 464: loss 0.212443
# epoch 465 loss_pde:0.15219595, loss_ib:0.00601993
# epoch 465: loss 0.212395
# epoch 466 loss_pde:0.15217035, loss_ib:0.00601767
# epoch 466: loss 0.212347
# epoch 467 loss_pde:0.15214160, loss_ib:0.00601574
# epoch 467: loss 0.212299
# epoch 468 loss_pde:0.15211615, loss_ib:0.00601347
# epoch 468: loss 0.212251
# epoch 469 loss_pde:0.15208726, loss_ib:0.00601156
# epoch 469: loss 0.212203
# epoch 470 loss_pde:0.15206291, loss_ib:0.00600919
# epoch 470: loss 0.212155
# epoch 471 loss_pde:0.15203288, loss_ib:0.00600739
# epoch 471: loss 0.212107
# epoch 472 loss_pde:0.15200928, loss_ib:0.00600494
# epoch 472: loss 0.212059
# epoch 473 loss_pde:0.15197815, loss_ib:0.00600326
# epoch 473: loss 0.212011
# epoch 474 loss_pde:0.15195788, loss_ib:0.00600048
# epoch 474: loss 0.211963
# epoch 475 loss_pde:0.15192217, loss_ib:0.00599925
# epoch 475: loss 0.211915
# epoch 476 loss_pde:0.15190445, loss_ib:0.00599623
# epoch 476: loss 0.211867
# epoch 477 loss_pde:0.15186247, loss_ib:0.00599563
# epoch 477: loss 0.211819
# epoch 478 loss_pde:0.15185362, loss_ib:0.00599173
# epoch 478: loss 0.211771
# epoch 479 loss_pde:0.15180190, loss_ib:0.00599213
# epoch 479: loss 0.211723
# epoch 480 loss_pde:0.15181008, loss_ib:0.00598654
# epoch 480: loss 0.211676
# epoch 481 loss_pde:0.15173700, loss_ib:0.00598912
# epoch 481: loss 0.211628
# epoch 482 loss_pde:0.15177372, loss_ib:0.00598077
# epoch 482: loss 0.211581
# epoch 483 loss_pde:0.15165742, loss_ib:0.00598783
# epoch 483: loss 0.211536
# epoch 484 loss_pde:0.15175694, loss_ib:0.00597355
# epoch 484: loss 0.211492
# epoch 485 loss_pde:0.15155248, loss_ib:0.00599016
# epoch 485: loss 0.211454
# epoch 486 loss_pde:0.15178224, loss_ib:0.00596435
# epoch 486: loss 0.211426
# epoch 487 loss_pde:0.15139145, loss_ib:0.00600275
# epoch 487: loss 0.211419
# epoch 488 loss_pde:0.15189433, loss_ib:0.00595601
# epoch 488: loss 0.211454
# epoch 489 loss_pde:0.15113562, loss_ib:0.00604377
# epoch 489: loss 0.211573
# epoch 490 loss_pde:0.15214713, loss_ib:0.00596589
# epoch 490: loss 0.211806
# epoch 491 loss_pde:0.15084171, loss_ib:0.00613067
# epoch 491: loss 0.212148
# epoch 492 loss_pde:0.15230738, loss_ib:0.00600035
# epoch 492: loss 0.212311
# epoch 493 loss_pde:0.15087351, loss_ib:0.00611468
# epoch 493: loss 0.212020
# epoch 494 loss_pde:0.15174559, loss_ib:0.00595965
# epoch 494: loss 0.211342
# epoch 495 loss_pde:0.15139158, loss_ib:0.00596029
# epoch 495: loss 0.210994
# epoch 496 loss_pde:0.15101841, loss_ib:0.00602008
# epoch 496: loss 0.211219
# epoch 497 loss_pde:0.15183420, loss_ib:0.00596479
# epoch 497: loss 0.211482
# epoch 498 loss_pde:0.15092750, loss_ib:0.00603773
# epoch 498: loss 0.211305
# epoch 499 loss_pde:0.15149350, loss_ib:0.00594080
# epoch 499: loss 0.210901
# epoch 500 loss_pde:0.15138501, loss_ib:0.00594352
# epoch 500: loss 0.210820
# epoch 501 loss_pde:0.15087490, loss_ib:0.00601359
# epoch 501: loss 0.211011
# epoch 502 loss_pde:0.15160215, loss_ib:0.00594052
# epoch 502: loss 0.211007
# epoch 503 loss_pde:0.15101001, loss_ib:0.00597425
# epoch 503: loss 0.210752
# epoch 504 loss_pde:0.15109789, loss_ib:0.00595105
# epoch 504: loss 0.210608
# epoch 505 loss_pde:0.15139659, loss_ib:0.00592959
# epoch 505: loss 0.210692
# epoch 506 loss_pde:0.15085641, loss_ib:0.00598683
# epoch 506: loss 0.210725
# epoch 507 loss_pde:0.15128529, loss_ib:0.00592776
# epoch 507: loss 0.210563
# epoch 508 loss_pde:0.15107800, loss_ib:0.00593483
# epoch 508: loss 0.210426
# epoch 509 loss_pde:0.15085985, loss_ib:0.00595922
# epoch 509: loss 0.210452
# epoch 510 loss_pde:0.15124960, loss_ib:0.00592254
# epoch 510: loss 0.210475
# epoch 511 loss_pde:0.15083906, loss_ib:0.00595282
# epoch 511: loss 0.210367
# epoch 512 loss_pde:0.15099481, loss_ib:0.00592552
# epoch 512: loss 0.210250
# epoch 513 loss_pde:0.15107812, loss_ib:0.00591649
# epoch 513: loss 0.210243
# epoch 514 loss_pde:0.15072624, loss_ib:0.00595286
# epoch 514: loss 0.210255
# epoch 515 loss_pde:0.15105540, loss_ib:0.00591212
# epoch 515: loss 0.210177
# epoch 516 loss_pde:0.15085450, loss_ib:0.00592225
# epoch 516: loss 0.210077
# epoch 517 loss_pde:0.15073854, loss_ib:0.00593126
# epoch 517: loss 0.210051
# epoch 518 loss_pde:0.15098360, loss_ib:0.00590668
# epoch 518: loss 0.210050
# epoch 519 loss_pde:0.15069684, loss_ib:0.00592949
# epoch 519: loss 0.209992
# epoch 520 loss_pde:0.15081978, loss_ib:0.00590869
# epoch 520: loss 0.209907
# epoch 521 loss_pde:0.15081488, loss_ib:0.00590535
# epoch 521: loss 0.209868
# epoch 522 loss_pde:0.15061745, loss_ib:0.00592399
# epoch 522: loss 0.209857
# epoch 523 loss_pde:0.15082610, loss_ib:0.00589849
# epoch 523: loss 0.209811
# epoch 524 loss_pde:0.15062830, loss_ib:0.00591103
# epoch 524: loss 0.209739
# epoch 525 loss_pde:0.15062189, loss_ib:0.00590703
# epoch 525: loss 0.209692
# epoch 526 loss_pde:0.15073328, loss_ib:0.00589379
# epoch 526: loss 0.209671
# epoch 527 loss_pde:0.15051535, loss_ib:0.00591177
# epoch 527: loss 0.209633
# epoch 528 loss_pde:0.15064570, loss_ib:0.00589260
# epoch 528: loss 0.209572
# epoch 529 loss_pde:0.15057147, loss_ib:0.00589494
# epoch 529: loss 0.209521
# epoch 530 loss_pde:0.15046979, loss_ib:0.00590208
# epoch 530: loss 0.209491
# epoch 531 loss_pde:0.15059653, loss_ib:0.00588596
# epoch 531: loss 0.209456
# epoch 532 loss_pde:0.15043350, loss_ib:0.00589711
# epoch 532: loss 0.209405
# epoch 533 loss_pde:0.15047923, loss_ib:0.00588738
# epoch 533: loss 0.209353
# epoch 534 loss_pde:0.15047678, loss_ib:0.00588382
# epoch 534: loss 0.209315
# epoch 535 loss_pde:0.15036151, loss_ib:0.00589188
# epoch 535: loss 0.209280
# epoch 536 loss_pde:0.15045701, loss_ib:0.00587791
# epoch 536: loss 0.209236
# epoch 537 loss_pde:0.15033495, loss_ib:0.00588522
# epoch 537: loss 0.209187
# epoch 538 loss_pde:0.15033916, loss_ib:0.00588048
# epoch 538: loss 0.209144
# epoch 539 loss_pde:0.15036891, loss_ib:0.00587373
# epoch 539: loss 0.209106
# epoch 540 loss_pde:0.15024808, loss_ib:0.00588179
# epoch 540: loss 0.209066
# epoch 541 loss_pde:0.15031591, loss_ib:0.00587052
# epoch 541: loss 0.209021
# epoch 542 loss_pde:0.15024285, loss_ib:0.00587335
# epoch 542: loss 0.208976
# epoch 543 loss_pde:0.15021256, loss_ib:0.00587225
# epoch 543: loss 0.208935
# epoch 544 loss_pde:0.15023901, loss_ib:0.00586561
# epoch 544: loss 0.208895
# epoch 545 loss_pde:0.15014508, loss_ib:0.00587083
# epoch 545: loss 0.208853
# epoch 546 loss_pde:0.15018460, loss_ib:0.00586255
# epoch 546: loss 0.208810
# epoch 547 loss_pde:0.15012699, loss_ib:0.00586401
# epoch 547: loss 0.208767
# epoch 548 loss_pde:0.15009636, loss_ib:0.00586291
# epoch 548: loss 0.208725
# epoch 549 loss_pde:0.15011375, loss_ib:0.00585707
# epoch 549: loss 0.208684
# epoch 550 loss_pde:0.15003309, loss_ib:0.00586099
# epoch 550: loss 0.208643
# epoch 551 loss_pde:0.15005814, loss_ib:0.00585425
# epoch 551: loss 0.208601
# epoch 552 loss_pde:0.15001152, loss_ib:0.00585466
# epoch 552: loss 0.208558
# epoch 553 loss_pde:0.14998160, loss_ib:0.00585345
# epoch 553: loss 0.208516
# epoch 554 loss_pde:0.14998640, loss_ib:0.00584883
# epoch 554: loss 0.208475
# epoch 555 loss_pde:0.14992389, loss_ib:0.00585097
# epoch 555: loss 0.208434
# epoch 556 loss_pde:0.14993413, loss_ib:0.00584577
# epoch 556: loss 0.208392
# epoch 557 loss_pde:0.14988917, loss_ib:0.00584604
# epoch 557: loss 0.208350
# epoch 558 loss_pde:0.14987047, loss_ib:0.00584369
# epoch 558: loss 0.208307
# epoch 559 loss_pde:0.14985867, loss_ib:0.00584073
# epoch 559: loss 0.208266
# epoch 560 loss_pde:0.14981021, loss_ib:0.00584146
# epoch 560: loss 0.208225
# epoch 561 loss_pde:0.14981620, loss_ib:0.00583672
# epoch 561: loss 0.208183
# epoch 562 loss_pde:0.14976875, loss_ib:0.00583727
# epoch 562: loss 0.208141
# epoch 563 loss_pde:0.14975595, loss_ib:0.00583434
# epoch 563: loss 0.208099
# epoch 564 loss_pde:0.14973381, loss_ib:0.00583239
# epoch 564: loss 0.208058
# epoch 565 loss_pde:0.14969954, loss_ib:0.00583170
# epoch 565: loss 0.208016
# epoch 566 loss_pde:0.14969271, loss_ib:0.00582825
# epoch 566: loss 0.207975
# epoch 567 loss_pde:0.14964943, loss_ib:0.00582842
# epoch 567: loss 0.207934
# epoch 568 loss_pde:0.14964369, loss_ib:0.00582481
# epoch 568: loss 0.207892
# epoch 569 loss_pde:0.14960763, loss_ib:0.00582425
# epoch 569: loss 0.207850
# epoch 570 loss_pde:0.14958678, loss_ib:0.00582219
# epoch 570: loss 0.207809
# epoch 571 loss_pde:0.14956979, loss_ib:0.00581976
# epoch 571: loss 0.207767
# epoch 572 loss_pde:0.14953279, loss_ib:0.00581932
# epoch 572: loss 0.207726
# epoch 573 loss_pde:0.14952573, loss_ib:0.00581589
# epoch 573: loss 0.207685
# epoch 574 loss_pde:0.14948587, loss_ib:0.00581572
# epoch 574: loss 0.207643
# epoch 575 loss_pde:0.14947419, loss_ib:0.00581273
# epoch 575: loss 0.207602
# epoch 576 loss_pde:0.14944381, loss_ib:0.00581163
# epoch 576: loss 0.207560
# epoch 577 loss_pde:0.14942028, loss_ib:0.00580985
# epoch 577: loss 0.207519
# epoch 578 loss_pde:0.14940318, loss_ib:0.00580742
# epoch 578: loss 0.207477
# epoch 579 loss_pde:0.14936714, loss_ib:0.00580690
# epoch 579: loss 0.207436
# epoch 580 loss_pde:0.14935869, loss_ib:0.00580361
# epoch 580: loss 0.207395
# epoch 581 loss_pde:0.14932023, loss_ib:0.00580332
# epoch 581: loss 0.207353
# epoch 582 loss_pde:0.14930712, loss_ib:0.00580049
# epoch 582: loss 0.207312
# epoch 583 loss_pde:0.14927834, loss_ib:0.00579924
# epoch 583: loss 0.207271
# epoch 584 loss_pde:0.14925471, loss_ib:0.00579747
# epoch 584: loss 0.207229
# epoch 585 loss_pde:0.14923617, loss_ib:0.00579520
# epoch 585: loss 0.207188
# epoch 586 loss_pde:0.14920372, loss_ib:0.00579433
# epoch 586: loss 0.207147
# epoch 587 loss_pde:0.14919136, loss_ib:0.00579144
# epoch 587: loss 0.207106
# epoch 588 loss_pde:0.14915587, loss_ib:0.00579086
# epoch 588: loss 0.207064
# epoch 589 loss_pde:0.14914224, loss_ib:0.00578810
# epoch 589: loss 0.207023
# epoch 590 loss_pde:0.14911230, loss_ib:0.00578697
# epoch 590: loss 0.206982
# epoch 591 loss_pde:0.14909142, loss_ib:0.00578494
# epoch 591: loss 0.206941
# epoch 592 loss_pde:0.14906865, loss_ib:0.00578310
# epoch 592: loss 0.206900
# epoch 593 loss_pde:0.14904174, loss_ib:0.00578167
# epoch 593: loss 0.206858
# epoch 594 loss_pde:0.14902402, loss_ib:0.00577933
# epoch 594: loss 0.206817
# epoch 595 loss_pde:0.14899328, loss_ib:0.00577829
# epoch 595: loss 0.206776
# epoch 596 loss_pde:0.14897628, loss_ib:0.00577587
# epoch 596: loss 0.206735
# epoch 597 loss_pde:0.14894582, loss_ib:0.00577481
# epoch 597: loss 0.206694
# epoch 598 loss_pde:0.14892823, loss_ib:0.00577246
# epoch 598: loss 0.206653
# epoch 599 loss_pde:0.14889993, loss_ib:0.00577118
# epoch 599: loss 0.206612
# epoch 600 loss_pde:0.14888008, loss_ib:0.00576905
# epoch 600: loss 0.206571
# epoch 601 loss_pde:0.14885405, loss_ib:0.00576755
# epoch 601: loss 0.206530
# epoch 602 loss_pde:0.14883219, loss_ib:0.00576563
# epoch 602: loss 0.206488
# epoch 603 loss_pde:0.14880754, loss_ib:0.00576399
# epoch 603: loss 0.206447
# epoch 604 loss_pde:0.14878485, loss_ib:0.00576216
# epoch 604: loss 0.206406
# epoch 605 loss_pde:0.14876206, loss_ib:0.00576034
# epoch 605: loss 0.206365
# epoch 606 loss_pde:0.14873734, loss_ib:0.00575871
# epoch 606: loss 0.206324
# epoch 607 loss_pde:0.14871553, loss_ib:0.00575679
# epoch 607: loss 0.206283
# epoch 608 loss_pde:0.14868948, loss_ib:0.00575530
# epoch 608: loss 0.206243
# epoch 609 loss_pde:0.14866945, loss_ib:0.00575321
# epoch 609: loss 0.206202
# epoch 610 loss_pde:0.14864169, loss_ib:0.00575189
# epoch 610: loss 0.206161
# epoch 611 loss_pde:0.14862312, loss_ib:0.00574965
# epoch 611: loss 0.206120
# epoch 612 loss_pde:0.14859402, loss_ib:0.00574848
# epoch 612: loss 0.206079
# epoch 613 loss_pde:0.14857662, loss_ib:0.00574612
# epoch 613: loss 0.206038
# epoch 614 loss_pde:0.14854659, loss_ib:0.00574504
# epoch 614: loss 0.205997
# epoch 615 loss_pde:0.14853047, loss_ib:0.00574256
# epoch 615: loss 0.205956
# epoch 616 loss_pde:0.14849927, loss_ib:0.00574160
# epoch 616: loss 0.205915
# epoch 617 loss_pde:0.14848423, loss_ib:0.00573902
# epoch 617: loss 0.205874
# epoch 618 loss_pde:0.14845113, loss_ib:0.00573824
# epoch 618: loss 0.205834
# epoch 619 loss_pde:0.14843911, loss_ib:0.00573537
# epoch 619: loss 0.205793
# epoch 620 loss_pde:0.14840262, loss_ib:0.00573494
# epoch 620: loss 0.205752
# epoch 621 loss_pde:0.14839515, loss_ib:0.00573162
# epoch 621: loss 0.205711
# epoch 622 loss_pde:0.14835207, loss_ib:0.00573186
# epoch 622: loss 0.205671
# epoch 623 loss_pde:0.14835337, loss_ib:0.00572768
# epoch 623: loss 0.205630
# epoch 624 loss_pde:0.14829831, loss_ib:0.00572914
# epoch 624: loss 0.205590
# epoch 625 loss_pde:0.14831531, loss_ib:0.00572343
# epoch 625: loss 0.205550
# epoch 626 loss_pde:0.14823958, loss_ib:0.00572703
# epoch 626: loss 0.205510
# epoch 627 loss_pde:0.14828461, loss_ib:0.00571864
# epoch 627: loss 0.205471
# epoch 628 loss_pde:0.14817099, loss_ib:0.00572626
# epoch 628: loss 0.205434
# epoch 629 loss_pde:0.14826833, loss_ib:0.00571306
# epoch 629: loss 0.205399
# epoch 630 loss_pde:0.14808330, loss_ib:0.00572863
# epoch 630: loss 0.205370
# epoch 631 loss_pde:0.14827903, loss_ib:0.00570708
# epoch 631: loss 0.205350
# epoch 632 loss_pde:0.14795883, loss_ib:0.00573903
# epoch 632: loss 0.205349
# epoch 633 loss_pde:0.14834176, loss_ib:0.00570397
# epoch 633: loss 0.205381
# epoch 634 loss_pde:0.14777222, loss_ib:0.00577033
# epoch 634: loss 0.205476
# epoch 635 loss_pde:0.14848006, loss_ib:0.00571719
# epoch 635: loss 0.205652
# epoch 636 loss_pde:0.14752746, loss_ib:0.00584064
# epoch 636: loss 0.205934
# epoch 637 loss_pde:0.14861837, loss_ib:0.00575617
# epoch 637: loss 0.206180
# epoch 638 loss_pde:0.14739984, loss_ib:0.00588161
# epoch 638: loss 0.206216
# epoch 639 loss_pde:0.14844178, loss_ib:0.00573478
# epoch 639: loss 0.205790
# epoch 640 loss_pde:0.14765514, loss_ib:0.00575721
# epoch 640: loss 0.205227
# epoch 641 loss_pde:0.14795320, loss_ib:0.00570306
# epoch 641: loss 0.204984
# epoch 642 loss_pde:0.14806722, loss_ib:0.00570796
# epoch 642: loss 0.205147
# epoch 643 loss_pde:0.14756212, loss_ib:0.00577825
# ...
# epoch 19799 loss_pde:0.06727661, loss_ib:0.00194572
# epoch 19799: loss 0.086734
# epoch 19800 loss_pde:0.06726397, loss_ib:0.00194679
# epoch 19800: loss 0.086732
# epoch 19801 loss_pde:0.06727209, loss_ib:0.00194577
# epoch 19801: loss 0.086730
# epoch 19802 loss_pde:0.06726344, loss_ib:0.00194642
# epoch 19802: loss 0.086728
# epoch 19803 loss_pde:0.06726610, loss_ib:0.00194596
# epoch 19803: loss 0.086726
# epoch 19804 loss_pde:0.06726358, loss_ib:0.00194601
# epoch 19804: loss 0.086724
# epoch 19805 loss_pde:0.06726028, loss_ib:0.00194615
# epoch 19805: loss 0.086722
# epoch 19806 loss_pde:0.06726228, loss_ib:0.00194575
# epoch 19806: loss 0.086720
# epoch 19807 loss_pde:0.06725653, loss_ib:0.00194614
# epoch 19807: loss 0.086718
# epoch 19808 loss_pde:0.06725974, loss_ib:0.00194562
# epoch 19808: loss 0.086716
# epoch 19809 loss_pde:0.06725363, loss_ib:0.00194604
# epoch 19809: loss 0.086714
# epoch 19810 loss_pde:0.06725637, loss_ib:0.00194557
# epoch 19810: loss 0.086712
# epoch 19811 loss_pde:0.06725152, loss_ib:0.00194586
# epoch 19811: loss 0.086710
# epoch 19812 loss_pde:0.06725233, loss_ib:0.00194558
# epoch 19812: loss 0.086708
# epoch 19813 loss_pde:0.06724945, loss_ib:0.00194567
# epoch 19813: loss 0.086706
# epoch 19814 loss_pde:0.06724839, loss_ib:0.00194558
# epoch 19814: loss 0.086704
# epoch 19815 loss_pde:0.06724775, loss_ib:0.00194545
# epoch 19815: loss 0.086702
# epoch 19816 loss_pde:0.06724461, loss_ib:0.00194557
# epoch 19816: loss 0.086700
# epoch 19817 loss_pde:0.06724536, loss_ib:0.00194530
# epoch 19817: loss 0.086698
# epoch 19818 loss_pde:0.06724093, loss_ib:0.00194554
# epoch 19818: loss 0.086696
# epoch 19819 loss_pde:0.06724266, loss_ib:0.00194517
# epoch 19819: loss 0.086694
# epoch 19820 loss_pde:0.06723820, loss_ib:0.00194542
# epoch 19820: loss 0.086692
# epoch 19821 loss_pde:0.06723947, loss_ib:0.00194510
# epoch 19821: loss 0.086690
# epoch 19822 loss_pde:0.06723573, loss_ib:0.00194528
# epoch 19822: loss 0.086689
# epoch 19823 loss_pde:0.06723557, loss_ib:0.00194510
# epoch 19823: loss 0.086687
# epoch 19824 loss_pde:0.06723329, loss_ib:0.00194514
# epoch 19824: loss 0.086685
# epoch 19825 loss_pde:0.06723194, loss_ib:0.00194507
# epoch 19825: loss 0.086683
# epoch 19826 loss_pde:0.06723086, loss_ib:0.00194498
# epoch 19826: loss 0.086681
# epoch 19827 loss_pde:0.06722867, loss_ib:0.00194501
# epoch 19827: loss 0.086679
# epoch 19828 loss_pde:0.06722787, loss_ib:0.00194489
# epoch 19828: loss 0.086677
# epoch 19829 loss_pde:0.06722571, loss_ib:0.00194491
# epoch 19829: loss 0.086675
# epoch 19830 loss_pde:0.06722466, loss_ib:0.00194482
# epoch 19830: loss 0.086673
# epoch 19831 loss_pde:0.06722314, loss_ib:0.00194478
# epoch 19831: loss 0.086671
# epoch 19832 loss_pde:0.06722138, loss_ib:0.00194476
# epoch 19832: loss 0.086669
# epoch 19833 loss_pde:0.06722045, loss_ib:0.00194466
# epoch 19833: loss 0.086667
# epoch 19834 loss_pde:0.06721813, loss_ib:0.00194469
# epoch 19834: loss 0.086665
# epoch 19835 loss_pde:0.06721760, loss_ib:0.00194455
# epoch 19835: loss 0.086663
# epoch 19836 loss_pde:0.06721498, loss_ib:0.00194461
# epoch 19836: loss 0.086661
# epoch 19837 loss_pde:0.06721449, loss_ib:0.00194446
# epoch 19837: loss 0.086659
# epoch 19838 loss_pde:0.06721227, loss_ib:0.00194450
# epoch 19838: loss 0.086657
# epoch 19839 loss_pde:0.06721139, loss_ib:0.00194438
# epoch 19839: loss 0.086655
# epoch 19840 loss_pde:0.06720946, loss_ib:0.00194438
# epoch 19840: loss 0.086653
# epoch 19841 loss_pde:0.06720825, loss_ib:0.00194431
# epoch 19841: loss 0.086651
# epoch 19842 loss_pde:0.06720646, loss_ib:0.00194428
# epoch 19842: loss 0.086649
# epoch 19843 loss_pde:0.06720540, loss_ib:0.00194419
# epoch 19843: loss 0.086647
# epoch 19844 loss_pde:0.06720326, loss_ib:0.00194421
# epoch 19844: loss 0.086645
# epoch 19845 loss_pde:0.06720269, loss_ib:0.00194407
# epoch 19845: loss 0.086643
# epoch 19846 loss_pde:0.06719986, loss_ib:0.00194416
# epoch 19846: loss 0.086641
# epoch 19847 loss_pde:0.06720010, loss_ib:0.00194394
# epoch 19847: loss 0.086640
# epoch 19848 loss_pde:0.06719638, loss_ib:0.00194412
# epoch 19848: loss 0.086638
# epoch 19849 loss_pde:0.06719778, loss_ib:0.00194378
# epoch 19849: loss 0.086636
# epoch 19850 loss_pde:0.06719275, loss_ib:0.00194409
# epoch 19850: loss 0.086634
# epoch 19851 loss_pde:0.06719545, loss_ib:0.00194362
# epoch 19851: loss 0.086632
# epoch 19852 loss_pde:0.06718893, loss_ib:0.00194408
# epoch 19852: loss 0.086630
# epoch 19853 loss_pde:0.06719353, loss_ib:0.00194343
# epoch 19853: loss 0.086628
# epoch 19854 loss_pde:0.06718490, loss_ib:0.00194411
# epoch 19854: loss 0.086626
# epoch 19855 loss_pde:0.06719187, loss_ib:0.00194323
# epoch 19855: loss 0.086624
# epoch 19856 loss_pde:0.06718054, loss_ib:0.00194418
# epoch 19856: loss 0.086622
# epoch 19857 loss_pde:0.06719107, loss_ib:0.00194296
# epoch 19857: loss 0.086621
# epoch 19858 loss_pde:0.06717546, loss_ib:0.00194437
# epoch 19858: loss 0.086619
# epoch 19859 loss_pde:0.06719139, loss_ib:0.00194264
# epoch 19859: loss 0.086618
# epoch 19860 loss_pde:0.06716970, loss_ib:0.00194471
# epoch 19860: loss 0.086617
# epoch 19861 loss_pde:0.06719388, loss_ib:0.00194223
# epoch 19861: loss 0.086616
# epoch 19862 loss_pde:0.06716321, loss_ib:0.00194532
# epoch 19862: loss 0.086616
# epoch 19863 loss_pde:0.06720004, loss_ib:0.00194177
# epoch 19863: loss 0.086618
# epoch 19864 loss_pde:0.06715591, loss_ib:0.00194650
# epoch 19864: loss 0.086621
# epoch 19865 loss_pde:0.06721310, loss_ib:0.00194136
# epoch 19865: loss 0.086627
# epoch 19866 loss_pde:0.06714974, loss_ib:0.00194869
# epoch 19866: loss 0.086637
# epoch 19867 loss_pde:0.06723876, loss_ib:0.00194139
# epoch 19867: loss 0.086653
# epoch 19868 loss_pde:0.06714799, loss_ib:0.00195284
# epoch 19868: loss 0.086676
# epoch 19869 loss_pde:0.06728100, loss_ib:0.00194290
# epoch 19869: loss 0.086710
# epoch 19870 loss_pde:0.06715275, loss_ib:0.00195962
# epoch 19870: loss 0.086749
# epoch 19871 loss_pde:0.06732015, loss_ib:0.00194760
# epoch 19871: loss 0.086796
# epoch 19872 loss_pde:0.06716330, loss_ib:0.00196754
# epoch 19872: loss 0.086839
# epoch 19873 loss_pde:0.06732076, loss_ib:0.00195535
# epoch 19873: loss 0.086874
# epoch 19874 loss_pde:0.06718372, loss_ib:0.00197030
# epoch 19874: loss 0.086887
# epoch 19875 loss_pde:0.06726595, loss_ib:0.00196140
# epoch 19875: loss 0.086880
# epoch 19876 loss_pde:0.06723209, loss_ib:0.00196199
# epoch 19876: loss 0.086852
# epoch 19877 loss_pde:0.06719805, loss_ib:0.00196151
# epoch 19877: loss 0.086813
# epoch 19878 loss_pde:0.06727562, loss_ib:0.00194940
# epoch 19878: loss 0.086770
# epoch 19879 loss_pde:0.06714737, loss_ib:0.00195776
# epoch 19879: loss 0.086725
# epoch 19880 loss_pde:0.06724028, loss_ib:0.00194420
# epoch 19880: loss 0.086682
# epoch 19881 loss_pde:0.06713623, loss_ib:0.00195084
# epoch 19881: loss 0.086645
# epoch 19882 loss_pde:0.06716080, loss_ib:0.00194588
# epoch 19882: loss 0.086620
# epoch 19883 loss_pde:0.06717425, loss_ib:0.00194376
# epoch 19883: loss 0.086612
# epoch 19884 loss_pde:0.06711490, loss_ib:0.00195080
# epoch 19884: loss 0.086623
# epoch 19885 loss_pde:0.06721342, loss_ib:0.00194360
# epoch 19885: loss 0.086649
# epoch 19886 loss_pde:0.06711008, loss_ib:0.00195742
# epoch 19886: loss 0.086684
# epoch 19887 loss_pde:0.06722727, loss_ib:0.00194911
# epoch 19887: loss 0.086718
# epoch 19888 loss_pde:0.06710602, loss_ib:0.00196392
# epoch 19888: loss 0.086745
# epoch 19889 loss_pde:0.06722856, loss_ib:0.00195404
# epoch 19889: loss 0.086769
# epoch 19890 loss_pde:0.06707496, loss_ib:0.00197303
# epoch 19890: loss 0.086805
# epoch 19891 loss_pde:0.06723439, loss_ib:0.00196407
# epoch 19891: loss 0.086875
# epoch 19892 loss_pde:0.06703786, loss_ib:0.00199735
# epoch 19892: loss 0.087011
# epoch 19893 loss_pde:0.06726314, loss_ib:0.00199601
# epoch 19893: loss 0.087223
# epoch 19894 loss_pde:0.06701793, loss_ib:0.00205452
# epoch 19894: loss 0.087563
# epoch 19895 loss_pde:0.06731966, loss_ib:0.00206749
# epoch 19895: loss 0.087995
# epoch 19896 loss_pde:0.06699371, loss_ib:0.00216317
# epoch 19896: loss 0.088625
# epoch 19897 loss_pde:0.06740137, loss_ib:0.00218621
# epoch 19897: loss 0.089263
# epoch 19898 loss_pde:0.06694914, loss_ib:0.00231227
# epoch 19898: loss 0.090072
# epoch 19899 loss_pde:0.06748706, loss_ib:0.00229864
# epoch 19899: loss 0.090473
# epoch 19900 loss_pde:0.06692018, loss_ib:0.00237440
# epoch 19900: loss 0.090664
# epoch 19901 loss_pde:0.06749055, loss_ib:0.00224544
# epoch 19901: loss 0.089945
# epoch 19902 loss_pde:0.06695552, loss_ib:0.00218976
# epoch 19902: loss 0.088853
# epoch 19903 loss_pde:0.06732826, loss_ib:0.00202310
# epoch 19903: loss 0.087559
# epoch 19904 loss_pde:0.06706087, loss_ib:0.00196776
# epoch 19904: loss 0.086738
# epoch 19905 loss_pde:0.06710139, loss_ib:0.00195351
# epoch 19905: loss 0.086636
# epoch 19906 loss_pde:0.06722084, loss_ib:0.00198863
# epoch 19906: loss 0.087107
# epoch 19907 loss_pde:0.06698317, loss_ib:0.00207614
# epoch 19907: loss 0.087745
# epoch 19908 loss_pde:0.06735195, loss_ib:0.00207061
# epoch 19908: loss 0.088058
# epoch 19909 loss_pde:0.06696511, loss_ib:0.00209557
# epoch 19909: loss 0.087921
# epoch 19910 loss_pde:0.06729734, loss_ib:0.00200658
# epoch 19910: loss 0.087363
# epoch 19911 loss_pde:0.06700934, loss_ib:0.00197952
# epoch 19911: loss 0.086805
# epoch 19912 loss_pde:0.06711035, loss_ib:0.00194345
# epoch 19912: loss 0.086545
# epoch 19913 loss_pde:0.06716156, loss_ib:0.00195019
# epoch 19913: loss 0.086663
# epoch 19914 loss_pde:0.06699480, loss_ib:0.00199824
# epoch 19914: loss 0.086977
# epoch 19915 loss_pde:0.06729086, loss_ib:0.00199144
# epoch 19915: loss 0.087205
# epoch 19916 loss_pde:0.06697913, loss_ib:0.00202242
# epoch 19916: loss 0.087203
# epoch 19917 loss_pde:0.06723002, loss_ib:0.00197372
# epoch 19917: loss 0.086967
# epoch 19918 loss_pde:0.06705379, loss_ib:0.00196363
# epoch 19918: loss 0.086690
# epoch 19919 loss_pde:0.06708427, loss_ib:0.00194468
# epoch 19919: loss 0.086531
# epoch 19920 loss_pde:0.06717525, loss_ib:0.00193786
# epoch 19920: loss 0.086554
# epoch 19921 loss_pde:0.06700841, loss_ib:0.00196808
# epoch 19921: loss 0.086689
# epoch 19922 loss_pde:0.06720351, loss_ib:0.00196064
# epoch 19922: loss 0.086810
# epoch 19923 loss_pde:0.06701635, loss_ib:0.00198168
# epoch 19923: loss 0.086833
# epoch 19924 loss_pde:0.06713326, loss_ib:0.00196085
# epoch 19924: loss 0.086742
# epoch 19925 loss_pde:0.06707647, loss_ib:0.00195339
# epoch 19925: loss 0.086610
# epoch 19926 loss_pde:0.06706174, loss_ib:0.00194529
# epoch 19926: loss 0.086515
# epoch 19927 loss_pde:0.06711882, loss_ib:0.00193816
# epoch 19927: loss 0.086500
# epoch 19928 loss_pde:0.06703469, loss_ib:0.00195187
# epoch 19928: loss 0.086553
# epoch 19929 loss_pde:0.06711803, loss_ib:0.00195017
# epoch 19929: loss 0.086620
# epoch 19930 loss_pde:0.06704611, loss_ib:0.00196037
# epoch 19930: loss 0.086650
# epoch 19931 loss_pde:0.06709617, loss_ib:0.00195249
# epoch 19931: loss 0.086621
# epoch 19932 loss_pde:0.06706081, loss_ib:0.00194972
# epoch 19932: loss 0.086558
# epoch 19933 loss_pde:0.06707177, loss_ib:0.00194268
# epoch 19933: loss 0.086499
# epoch 19934 loss_pde:0.06706783, loss_ib:0.00194069
# epoch 19934: loss 0.086475
# epoch 19935 loss_pde:0.06706136, loss_ib:0.00194283
# epoch 19935: loss 0.086490
# epoch 19936 loss_pde:0.06707826, loss_ib:0.00194440
# epoch 19936: loss 0.086522
# epoch 19937 loss_pde:0.06705330, loss_ib:0.00194926
# epoch 19937: loss 0.086546
# epoch 19938 loss_pde:0.06708661, loss_ib:0.00194572
# epoch 19938: loss 0.086544
# epoch 19939 loss_pde:0.06703951, loss_ib:0.00194806
# epoch 19939: loss 0.086520
# epoch 19940 loss_pde:0.06708509, loss_ib:0.00194037
# epoch 19940: loss 0.086489
# epoch 19941 loss_pde:0.06703782, loss_ib:0.00194289
# epoch 19941: loss 0.086467
# epoch 19942 loss_pde:0.06706910, loss_ib:0.00193920
# epoch 19942: loss 0.086461
# epoch 19943 loss_pde:0.06705561, loss_ib:0.00194134
# epoch 19943: loss 0.086469
# epoch 19944 loss_pde:0.06704269, loss_ib:0.00194386
# epoch 19944: loss 0.086481
# epoch 19945 loss_pde:0.06707837, loss_ib:0.00194100
# epoch 19945: loss 0.086488
# epoch 19946 loss_pde:0.06702538, loss_ib:0.00194606
# epoch 19946: loss 0.086486
# epoch 19947 loss_pde:0.06708293, loss_ib:0.00193922
# epoch 19947: loss 0.086475
# epoch 19948 loss_pde:0.06702795, loss_ib:0.00194334
# epoch 19948: loss 0.086461
# epoch 19949 loss_pde:0.06706347, loss_ib:0.00193866
# epoch 19949: loss 0.086450
# epoch 19950 loss_pde:0.06704348, loss_ib:0.00194013
# epoch 19950: loss 0.086445
# epoch 19951 loss_pde:0.06703769, loss_ib:0.00194076
# epoch 19951: loss 0.086445
# epoch 19952 loss_pde:0.06705759, loss_ib:0.00193914
# epoch 19952: loss 0.086449
# epoch 19953 loss_pde:0.06702285, loss_ib:0.00194293
# epoch 19953: loss 0.086452
# epoch 19954 loss_pde:0.06706066, loss_ib:0.00193915
# epoch 19954: loss 0.086452
# epoch 19955 loss_pde:0.06702161, loss_ib:0.00194268
# epoch 19955: loss 0.086448
# epoch 19956 loss_pde:0.06705312, loss_ib:0.00193888
# epoch 19956: loss 0.086442
# epoch 19957 loss_pde:0.06702772, loss_ib:0.00194074
# epoch 19957: loss 0.086435
# epoch 19958 loss_pde:0.06704060, loss_ib:0.00193894
# epoch 19958: loss 0.086430
# epoch 19959 loss_pde:0.06703603, loss_ib:0.00193911
# epoch 19959: loss 0.086427
# epoch 19960 loss_pde:0.06702802, loss_ib:0.00193984
# epoch 19960: loss 0.086426
# epoch 19961 loss_pde:0.06704145, loss_ib:0.00193851
# epoch 19961: loss 0.086427
# epoch 19962 loss_pde:0.06701867, loss_ib:0.00194078
# epoch 19962: loss 0.086426
# epoch 19963 loss_pde:0.06704103, loss_ib:0.00193844
# epoch 19963: loss 0.086425
# epoch 19964 loss_pde:0.06701563, loss_ib:0.00194076
# epoch 19964: loss 0.086423
# epoch 19965 loss_pde:0.06703523, loss_ib:0.00193848
# epoch 19965: loss 0.086420
# epoch 19966 loss_pde:0.06701858, loss_ib:0.00193979
# epoch 19966: loss 0.086416
# epoch 19967 loss_pde:0.06702721, loss_ib:0.00193858
# epoch 19967: loss 0.086413
# epoch 19968 loss_pde:0.06702262, loss_ib:0.00193873
# epoch 19968: loss 0.086410
# epoch 19969 loss_pde:0.06701945, loss_ib:0.00193883
# epoch 19969: loss 0.086408
# epoch 19970 loss_pde:0.06702387, loss_ib:0.00193823
# epoch 19970: loss 0.086406
# epoch 19971 loss_pde:0.06701376, loss_ib:0.00193912
# epoch 19971: loss 0.086405
# epoch 19972 loss_pde:0.06702206, loss_ib:0.00193818
# epoch 19972: loss 0.086404
# epoch 19973 loss_pde:0.06701034, loss_ib:0.00193921
# epoch 19973: loss 0.086402
# epoch 19974 loss_pde:0.06701894, loss_ib:0.00193816
# epoch 19974: loss 0.086401
# epoch 19975 loss_pde:0.06700810, loss_ib:0.00193902
# epoch 19975: loss 0.086398
# epoch 19976 loss_pde:0.06701569, loss_ib:0.00193802
# epoch 19976: loss 0.086396
# epoch 19977 loss_pde:0.06700593, loss_ib:0.00193874
# epoch 19977: loss 0.086393
# epoch 19978 loss_pde:0.06701186, loss_ib:0.00193790
# epoch 19978: loss 0.086391
# epoch 19979 loss_pde:0.06700400, loss_ib:0.00193846
# epoch 19979: loss 0.086389
# epoch 19980 loss_pde:0.06700738, loss_ib:0.00193792
# epoch 19980: loss 0.086387
# epoch 19981 loss_pde:0.06700308, loss_ib:0.00193816
# epoch 19981: loss 0.086385
# epoch 19982 loss_pde:0.06700172, loss_ib:0.00193812
# epoch 19982: loss 0.086383
# epoch 19983 loss_pde:0.06700331, loss_ib:0.00193780
# epoch 19983: loss 0.086381
# epoch 19984 loss_pde:0.06699593, loss_ib:0.00193836
# epoch 19984: loss 0.086380
# epoch 19985 loss_pde:0.06700286, loss_ib:0.00193748
# epoch 19985: loss 0.086378
# epoch 19986 loss_pde:0.06699125, loss_ib:0.00193846
# epoch 19986: loss 0.086376
# epoch 19987 loss_pde:0.06700024, loss_ib:0.00193736
# epoch 19987: loss 0.086374
# epoch 19988 loss_pde:0.06698873, loss_ib:0.00193831
# epoch 19988: loss 0.086372
# epoch 19989 loss_pde:0.06699563, loss_ib:0.00193741
# epoch 19989: loss 0.086370
# epoch 19990 loss_pde:0.06698792, loss_ib:0.00193798
# epoch 19990: loss 0.086368
# epoch 19991 loss_pde:0.06699023, loss_ib:0.00193753
# epoch 19991: loss 0.086366
# epoch 19992 loss_pde:0.06698716, loss_ib:0.00193764
# epoch 19992: loss 0.086364
# epoch 19993 loss_pde:0.06698567, loss_ib:0.00193760
# epoch 19993: loss 0.086362
# epoch 19994 loss_pde:0.06698547, loss_ib:0.00193742
# epoch 19994: loss 0.086360
# epoch 19995 loss_pde:0.06698190, loss_ib:0.00193759
# epoch 19995: loss 0.086358
# epoch 19996 loss_pde:0.06698294, loss_ib:0.00193729
# epoch 19996: loss 0.086356
# epoch 19997 loss_pde:0.06697872, loss_ib:0.00193752
# epoch 19997: loss 0.086354
# epoch 19998 loss_pde:0.06698003, loss_ib:0.00193720
# epoch 19998: loss 0.086352
# epoch 19999 loss_pde:0.06697590, loss_ib:0.00193743
# epoch 19999: loss 0.086350
# epoch 20000 loss_pde:0.06697717, loss_ib:0.00193711
# epoch 20000: loss 0.086348
# Total training time: 4485.693644762039

# %%
lr = 0.0001
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=500)
#optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_Adam,gamma=0.995)
optimizer = torch.optim.LBFGS(model.parameters(),lr=1,max_iter=20)
#optimizer_LBFGS = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=50000)

# %%
epochs = 1000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:0.00248554, loss_ib:0.00005331
# epoch 1 loss_pde:0.00248548, loss_ib:0.00005331
# epoch 1 loss_pde:0.00248537, loss_ib:0.00005332
# epoch 1 loss_pde:0.00248535, loss_ib:0.00005332
# epoch 1 loss_pde:0.00248545, loss_ib:0.00005331
# epoch 1 loss_pde:0.00248559, loss_ib:0.00005329
# epoch 1 loss_pde:0.00248573, loss_ib:0.00005327
# epoch 1 loss_pde:0.00248572, loss_ib:0.00005327
# epoch 1 loss_pde:0.00248560, loss_ib:0.00005328
# epoch 1 loss_pde:0.00248544, loss_ib:0.00005329
# epoch 1 loss_pde:0.00248532, loss_ib:0.00005330
# epoch 1 loss_pde:0.00248524, loss_ib:0.00005330
# epoch 1 loss_pde:0.00248566, loss_ib:0.00005327
# epoch 1 loss_pde:0.00248537, loss_ib:0.00005328
# epoch 1 loss_pde:0.00248538, loss_ib:0.00005328
# epoch 1 loss_pde:0.00248547, loss_ib:0.00005326
# epoch 1 loss_pde:0.00248569, loss_ib:0.00005323
# epoch 1 loss_pde:0.00248574, loss_ib:0.00005323
# epoch 1 loss_pde:0.00248565, loss_ib:0.00005323
# epoch 1 loss_pde:0.00248547, loss_ib:0.00005325
# epoch 1: loss 0.003019
# epoch 2 loss_pde:0.00248530, loss_ib:0.00005326
# epoch 2 loss_pde:0.00248513, loss_ib:0.00005327
# epoch 2 loss_pde:0.00248505, loss_ib:0.00005328
# epoch 2 loss_pde:0.00248501, loss_ib:0.00005327
# epoch 2 loss_pde:0.00248506, loss_ib:0.00005326
# epoch 2 loss_pde:0.00248467, loss_ib:0.00005331
# epoch 2 loss_pde:0.00248491, loss_ib:0.00005326
# epoch 2 loss_pde:0.00248468, loss_ib:0.00005328
# epoch 2 loss_pde:0.00248458, loss_ib:0.00005328
# epoch 2 loss_pde:0.00248428, loss_ib:0.00005331
# epoch 2 loss_pde:0.00248418, loss_ib:0.00005331
# epoch 2 loss_pde:0.00248403, loss_ib:0.00005332
# epoch 2 loss_pde:0.00248404, loss_ib:0.00005332
# epoch 2 loss_pde:0.00248404, loss_ib:0.00005332
# epoch 2 loss_pde:0.00248408, loss_ib:0.00005331
# epoch 2 loss_pde:0.00248411, loss_ib:0.00005330
# epoch 2 loss_pde:0.00248404, loss_ib:0.00005330
# epoch 2 loss_pde:0.00248395, loss_ib:0.00005331
# epoch 2 loss_pde:0.00248387, loss_ib:0.00005331
# epoch 2 loss_pde:0.00248381, loss_ib:0.00005331
# epoch 2: loss 0.003018
# epoch 3 loss_pde:0.00248391, loss_ib:0.00005330
# epoch 3 loss_pde:0.00248404, loss_ib:0.00005328
# epoch 3 loss_pde:0.00248428, loss_ib:0.00005325
# epoch 3 loss_pde:0.00248401, loss_ib:0.00005327
# epoch 3 loss_pde:0.00248382, loss_ib:0.00005329
# epoch 3 loss_pde:0.00248375, loss_ib:0.00005329
# epoch 3 loss_pde:0.00248369, loss_ib:0.00005329
# epoch 3 loss_pde:0.00248360, loss_ib:0.00005330
# epoch 3 loss_pde:0.00248352, loss_ib:0.00005330
# epoch 3 loss_pde:0.00248334, loss_ib:0.00005331
# epoch 3 loss_pde:0.00248339, loss_ib:0.00005331
# epoch 3 loss_pde:0.00248338, loss_ib:0.00005330
# epoch 3 loss_pde:0.00248342, loss_ib:0.00005330
# epoch 3 loss_pde:0.00248349, loss_ib:0.00005328
# epoch 3 loss_pde:0.00248359, loss_ib:0.00005327
# epoch 3 loss_pde:0.00248364, loss_ib:0.00005325
# epoch 3 loss_pde:0.00248369, loss_ib:0.00005324
# epoch 3 loss_pde:0.00248356, loss_ib:0.00005325
# epoch 3 loss_pde:0.00248350, loss_ib:0.00005325
# epoch 3 loss_pde:0.00248340, loss_ib:0.00005326
# epoch 3: loss 0.003017
# epoch 4 loss_pde:0.00248330, loss_ib:0.00005326
# epoch 4 loss_pde:0.00248318, loss_ib:0.00005327
# epoch 4 loss_pde:0.00248285, loss_ib:0.00005329
# epoch 4 loss_pde:0.00248270, loss_ib:0.00005331
# epoch 4 loss_pde:0.00248267, loss_ib:0.00005330
# epoch 4 loss_pde:0.00248267, loss_ib:0.00005330
# epoch 4 loss_pde:0.00248276, loss_ib:0.00005329
# epoch 4 loss_pde:0.00248275, loss_ib:0.00005328
# epoch 4 loss_pde:0.00248277, loss_ib:0.00005328
# epoch 4 loss_pde:0.00248275, loss_ib:0.00005327
# epoch 4 loss_pde:0.00248279, loss_ib:0.00005326
# epoch 4 loss_pde:0.00248284, loss_ib:0.00005326
# epoch 4 loss_pde:0.00248281, loss_ib:0.00005325
# epoch 4 loss_pde:0.00248273, loss_ib:0.00005326
# epoch 4 loss_pde:0.00248266, loss_ib:0.00005326
# epoch 4 loss_pde:0.00248252, loss_ib:0.00005327
# epoch 4 loss_pde:0.00248254, loss_ib:0.00005326
# epoch 4 loss_pde:0.00248246, loss_ib:0.00005326
# epoch 4 loss_pde:0.00248232, loss_ib:0.00005326
# epoch 4 loss_pde:0.00248234, loss_ib:0.00005325
# epoch 4: loss 0.003016
# epoch 5 loss_pde:0.00248241, loss_ib:0.00005324
# epoch 5 loss_pde:0.00248247, loss_ib:0.00005323
# epoch 5 loss_pde:0.00248245, loss_ib:0.00005322
# epoch 5 loss_pde:0.00248238, loss_ib:0.00005323
# epoch 5 loss_pde:0.00248221, loss_ib:0.00005324
# epoch 5 loss_pde:0.00248218, loss_ib:0.00005324
# epoch 5 loss_pde:0.00248213, loss_ib:0.00005324
# epoch 5 loss_pde:0.00248215, loss_ib:0.00005324
# epoch 5 loss_pde:0.00248219, loss_ib:0.00005323
# epoch 5 loss_pde:0.00248212, loss_ib:0.00005323
# epoch 5 loss_pde:0.00248214, loss_ib:0.00005322
# epoch 5 loss_pde:0.00248218, loss_ib:0.00005322
# epoch 5 loss_pde:0.00248217, loss_ib:0.00005322
# epoch 5 loss_pde:0.00248204, loss_ib:0.00005323
# epoch 5 loss_pde:0.00248173, loss_ib:0.00005325
# epoch 5 loss_pde:0.00248156, loss_ib:0.00005326
# epoch 5 loss_pde:0.00248123, loss_ib:0.00005329
# epoch 5 loss_pde:0.00248108, loss_ib:0.00005330
# epoch 5 loss_pde:0.00248112, loss_ib:0.00005329
# epoch 5 loss_pde:0.00248147, loss_ib:0.00005324
# epoch 5: loss 0.003015
# epoch 6 loss_pde:0.00248139, loss_ib:0.00005325
# epoch 6 loss_pde:0.00248135, loss_ib:0.00005324
# epoch 6 loss_pde:0.00248131, loss_ib:0.00005325
# epoch 6 loss_pde:0.00248120, loss_ib:0.00005325
# epoch 6 loss_pde:0.00248106, loss_ib:0.00005326
# epoch 6 loss_pde:0.00248093, loss_ib:0.00005327
# epoch 6 loss_pde:0.00248059, loss_ib:0.00005330
# epoch 6 loss_pde:0.00248044, loss_ib:0.00005331
# epoch 6 loss_pde:0.00248020, loss_ib:0.00005333
# epoch 6 loss_pde:0.00248004, loss_ib:0.00005334
# epoch 6 loss_pde:0.00247999, loss_ib:0.00005335
# epoch 6 loss_pde:0.00247994, loss_ib:0.00005335
# epoch 6 loss_pde:0.00247996, loss_ib:0.00005334
# epoch 6 loss_pde:0.00247999, loss_ib:0.00005333
# epoch 6 loss_pde:0.00247997, loss_ib:0.00005333
# epoch 6 loss_pde:0.00247992, loss_ib:0.00005333
# epoch 6 loss_pde:0.00247990, loss_ib:0.00005333
# epoch 6 loss_pde:0.00247993, loss_ib:0.00005332
# epoch 6 loss_pde:0.00247997, loss_ib:0.00005331
# epoch 6 loss_pde:0.00248003, loss_ib:0.00005330
# epoch 6: loss 0.003014
# epoch 7 loss_pde:0.00248004, loss_ib:0.00005330
# epoch 7 loss_pde:0.00248006, loss_ib:0.00005329
# epoch 7 loss_pde:0.00247999, loss_ib:0.00005330
# epoch 7 loss_pde:0.00247993, loss_ib:0.00005330
# epoch 7 loss_pde:0.00247981, loss_ib:0.00005331
# epoch 7 loss_pde:0.00247969, loss_ib:0.00005332
# epoch 7 loss_pde:0.00247964, loss_ib:0.00005332
# epoch 7 loss_pde:0.00247960, loss_ib:0.00005332
# epoch 7 loss_pde:0.00247962, loss_ib:0.00005332
# epoch 7 loss_pde:0.00247968, loss_ib:0.00005331
# epoch 7 loss_pde:0.00247971, loss_ib:0.00005330
# epoch 7 loss_pde:0.00247974, loss_ib:0.00005329
# epoch 7 loss_pde:0.00247971, loss_ib:0.00005329
# epoch 7 loss_pde:0.00247974, loss_ib:0.00005328
# epoch 7 loss_pde:0.00247983, loss_ib:0.00005327
# epoch 7 loss_pde:0.00247990, loss_ib:0.00005326
# epoch 7 loss_pde:0.00247971, loss_ib:0.00005327
# epoch 7 loss_pde:0.00247970, loss_ib:0.00005327
# epoch 7 loss_pde:0.00247962, loss_ib:0.00005326
# epoch 7 loss_pde:0.00247947, loss_ib:0.00005327
# epoch 7: loss 0.003013
# epoch 8 loss_pde:0.00247924, loss_ib:0.00005329
# epoch 8 loss_pde:0.00247911, loss_ib:0.00005330
# epoch 8 loss_pde:0.00247907, loss_ib:0.00005330
# epoch 8 loss_pde:0.00247898, loss_ib:0.00005331
# epoch 8 loss_pde:0.00247908, loss_ib:0.00005329
# epoch 8 loss_pde:0.00247910, loss_ib:0.00005329
# epoch 8 loss_pde:0.00247907, loss_ib:0.00005328
# epoch 8 loss_pde:0.00247901, loss_ib:0.00005329
# epoch 8 loss_pde:0.00247890, loss_ib:0.00005330
# epoch 8 loss_pde:0.00247865, loss_ib:0.00005331
# epoch 8 loss_pde:0.00247850, loss_ib:0.00005332
# epoch 8 loss_pde:0.00247839, loss_ib:0.00005333
# epoch 8 loss_pde:0.00247841, loss_ib:0.00005333
# epoch 8 loss_pde:0.00247852, loss_ib:0.00005331
# epoch 8 loss_pde:0.00247860, loss_ib:0.00005330
# epoch 8 loss_pde:0.00247867, loss_ib:0.00005329
# epoch 8 loss_pde:0.00247859, loss_ib:0.00005328
# epoch 8 loss_pde:0.00247857, loss_ib:0.00005328
# epoch 8 loss_pde:0.00247842, loss_ib:0.00005329
# epoch 8 loss_pde:0.00247841, loss_ib:0.00005328
# epoch 8: loss 0.003012
# epoch 9 loss_pde:0.00247843, loss_ib:0.00005328
# epoch 9 loss_pde:0.00247850, loss_ib:0.00005326
# epoch 9 loss_pde:0.00247856, loss_ib:0.00005325
# epoch 9 loss_pde:0.00247852, loss_ib:0.00005325
# epoch 9 loss_pde:0.00247837, loss_ib:0.00005326
# epoch 9 loss_pde:0.00247824, loss_ib:0.00005327
# epoch 9 loss_pde:0.00247798, loss_ib:0.00005329
# epoch 9 loss_pde:0.00247789, loss_ib:0.00005329
# epoch 9 loss_pde:0.00247797, loss_ib:0.00005328
# epoch 9 loss_pde:0.00247814, loss_ib:0.00005326
# epoch 9 loss_pde:0.00247825, loss_ib:0.00005324
# epoch 9 loss_pde:0.00247839, loss_ib:0.00005322
# epoch 9 loss_pde:0.00247828, loss_ib:0.00005323
# epoch 9 loss_pde:0.00247818, loss_ib:0.00005323
# epoch 9 loss_pde:0.00247789, loss_ib:0.00005325
# epoch 9 loss_pde:0.00247776, loss_ib:0.00005326
# epoch 9 loss_pde:0.00247762, loss_ib:0.00005326
# epoch 9 loss_pde:0.00247760, loss_ib:0.00005326
# epoch 9 loss_pde:0.00247763, loss_ib:0.00005326
# epoch 9 loss_pde:0.00247753, loss_ib:0.00005326
# epoch 9: loss 0.003011
# epoch 10 loss_pde:0.00247748, loss_ib:0.00005326
# epoch 10 loss_pde:0.00247738, loss_ib:0.00005327
# epoch 10 loss_pde:0.00247733, loss_ib:0.00005327
# epoch 10 loss_pde:0.00247717, loss_ib:0.00005328
# epoch 10 loss_pde:0.00247714, loss_ib:0.00005328
# epoch 10 loss_pde:0.00247713, loss_ib:0.00005328
# epoch 10 loss_pde:0.00247714, loss_ib:0.00005328
# epoch 10 loss_pde:0.00247704, loss_ib:0.00005328
# epoch 10 loss_pde:0.00247705, loss_ib:0.00005327
# epoch 10 loss_pde:0.00247703, loss_ib:0.00005327
# epoch 10 loss_pde:0.00247717, loss_ib:0.00005326
# epoch 10 loss_pde:0.00247708, loss_ib:0.00005327
# epoch 10 loss_pde:0.00247725, loss_ib:0.00005324
# epoch 10 loss_pde:0.00247743, loss_ib:0.00005324
# epoch 10 loss_pde:0.00247718, loss_ib:0.00005323
# epoch 10 loss_pde:0.00247715, loss_ib:0.00005323
# epoch 10 loss_pde:0.00247701, loss_ib:0.00005324
# epoch 10 loss_pde:0.00247701, loss_ib:0.00005323
# epoch 10 loss_pde:0.00247710, loss_ib:0.00005322
# epoch 10 loss_pde:0.00247702, loss_ib:0.00005322
# epoch 10: loss 0.003010
# epoch 11 loss_pde:0.00247688, loss_ib:0.00005323
# epoch 11 loss_pde:0.00247688, loss_ib:0.00005323
# epoch 11 loss_pde:0.00247678, loss_ib:0.00005324
# epoch 11 loss_pde:0.00247671, loss_ib:0.00005324
# epoch 11 loss_pde:0.00247641, loss_ib:0.00005327
# epoch 11 loss_pde:0.00247648, loss_ib:0.00005325
# epoch 11 loss_pde:0.00247648, loss_ib:0.00005325
# epoch 11 loss_pde:0.00247650, loss_ib:0.00005324
# epoch 11 loss_pde:0.00247644, loss_ib:0.00005324
# epoch 11 loss_pde:0.00247649, loss_ib:0.00005323
# epoch 11 loss_pde:0.00247651, loss_ib:0.00005322
# epoch 11 loss_pde:0.00247645, loss_ib:0.00005322
# epoch 11 loss_pde:0.00247625, loss_ib:0.00005324
# epoch 11 loss_pde:0.00247655, loss_ib:0.00005321
# epoch 11 loss_pde:0.00247643, loss_ib:0.00005321
# epoch 11 loss_pde:0.00247649, loss_ib:0.00005320
# epoch 11 loss_pde:0.00247663, loss_ib:0.00005318
# epoch 11 loss_pde:0.00247674, loss_ib:0.00005316
# epoch 11 loss_pde:0.00247675, loss_ib:0.00005315
# epoch 11 loss_pde:0.00247670, loss_ib:0.00005315
# epoch 11: loss 0.003009
# epoch 12 loss_pde:0.00247649, loss_ib:0.00005317
# epoch 12 loss_pde:0.00247635, loss_ib:0.00005318
# epoch 12 loss_pde:0.00247577, loss_ib:0.00005323
# epoch 12 loss_pde:0.00247579, loss_ib:0.00005322
# epoch 12 loss_pde:0.00247584, loss_ib:0.00005321
# epoch 12 loss_pde:0.00247586, loss_ib:0.00005320
# epoch 12 loss_pde:0.00247583, loss_ib:0.00005320
# epoch 12 loss_pde:0.00247572, loss_ib:0.00005321
# epoch 12 loss_pde:0.00247558, loss_ib:0.00005322
# epoch 12 loss_pde:0.00247523, loss_ib:0.00005324
# epoch 12 loss_pde:0.00247498, loss_ib:0.00005329
# epoch 12 loss_pde:0.00247464, loss_ib:0.00005329
# epoch 12 loss_pde:0.00247483, loss_ib:0.00005333
# epoch 12 loss_pde:0.00247473, loss_ib:0.00005327
# epoch 12 loss_pde:0.00247454, loss_ib:0.00005328
# epoch 12 loss_pde:0.00247432, loss_ib:0.00005330
# epoch 12 loss_pde:0.00247423, loss_ib:0.00005330
# epoch 12 loss_pde:0.00247423, loss_ib:0.00005329
# epoch 12 loss_pde:0.00247431, loss_ib:0.00005328
# epoch 12 loss_pde:0.00247443, loss_ib:0.00005327
# epoch 12: loss 0.003008
# epoch 13 loss_pde:0.00247455, loss_ib:0.00005325
# epoch 13 loss_pde:0.00247460, loss_ib:0.00005324
# epoch 13 loss_pde:0.00247464, loss_ib:0.00005323
# epoch 13 loss_pde:0.00247461, loss_ib:0.00005323
# epoch 13 loss_pde:0.00247461, loss_ib:0.00005322
# epoch 13 loss_pde:0.00247452, loss_ib:0.00005322
# epoch 13 loss_pde:0.00247429, loss_ib:0.00005324
# epoch 13 loss_pde:0.00247422, loss_ib:0.00005324
# epoch 13 loss_pde:0.00247424, loss_ib:0.00005323
# epoch 13 loss_pde:0.00247419, loss_ib:0.00005322
# epoch 13 loss_pde:0.00247405, loss_ib:0.00005323
# epoch 13 loss_pde:0.00247404, loss_ib:0.00005322
# epoch 13 loss_pde:0.00247402, loss_ib:0.00005322
# epoch 13 loss_pde:0.00247410, loss_ib:0.00005321
# epoch 13 loss_pde:0.00247394, loss_ib:0.00005322
# epoch 13 loss_pde:0.00247384, loss_ib:0.00005322
# epoch 13 loss_pde:0.00247367, loss_ib:0.00005323
# epoch 13 loss_pde:0.00247345, loss_ib:0.00005325
# epoch 13 loss_pde:0.00247310, loss_ib:0.00005328
# epoch 13 loss_pde:0.00247299, loss_ib:0.00005328
# epoch 13: loss 0.003007
# epoch 14 loss_pde:0.00247291, loss_ib:0.00005327
# epoch 14 loss_pde:0.00247291, loss_ib:0.00005327
# epoch 14 loss_pde:0.00247292, loss_ib:0.00005326
# epoch 14 loss_pde:0.00247294, loss_ib:0.00005326
# epoch 14 loss_pde:0.00247302, loss_ib:0.00005324
# epoch 14 loss_pde:0.00247311, loss_ib:0.00005323
# epoch 14 loss_pde:0.00247312, loss_ib:0.00005322
# epoch 14 loss_pde:0.00247313, loss_ib:0.00005322
# epoch 14 loss_pde:0.00247305, loss_ib:0.00005322
# epoch 14 loss_pde:0.00247288, loss_ib:0.00005323
# epoch 14 loss_pde:0.00247276, loss_ib:0.00005324
# epoch 14 loss_pde:0.00247250, loss_ib:0.00005326
# epoch 14: loss 0.003006
# epoch 15 loss_pde:0.00247250, loss_ib:0.00005326
# epoch 15 loss_pde:0.00247258, loss_ib:0.00005325
# epoch 15 loss_pde:0.00247259, loss_ib:0.00005324
# epoch 15 loss_pde:0.00247254, loss_ib:0.00005324
# epoch 15 loss_pde:0.00247244, loss_ib:0.00005324
# epoch 15 loss_pde:0.00247235, loss_ib:0.00005325
# epoch 15 loss_pde:0.00247223, loss_ib:0.00005326
# epoch 15 loss_pde:0.00247201, loss_ib:0.00005328
# epoch 15 loss_pde:0.00247211, loss_ib:0.00005326
# epoch 15 loss_pde:0.00247209, loss_ib:0.00005326
# epoch 15 loss_pde:0.00247223, loss_ib:0.00005324
# epoch 15 loss_pde:0.00247221, loss_ib:0.00005323
# epoch 15 loss_pde:0.00247216, loss_ib:0.00005323
# epoch 15 loss_pde:0.00247199, loss_ib:0.00005323
# epoch 15 loss_pde:0.00247197, loss_ib:0.00005323
# epoch 15 loss_pde:0.00247190, loss_ib:0.00005323
# epoch 15 loss_pde:0.00247189, loss_ib:0.00005323
# epoch 15 loss_pde:0.00247178, loss_ib:0.00005323
# epoch 15 loss_pde:0.00247178, loss_ib:0.00005323
# epoch 15 loss_pde:0.00247179, loss_ib:0.00005322
# epoch 15: loss 0.003005
# epoch 16 loss_pde:0.00247181, loss_ib:0.00005322
# epoch 16 loss_pde:0.00247189, loss_ib:0.00005321
# epoch 16 loss_pde:0.00247194, loss_ib:0.00005320
# epoch 16 loss_pde:0.00247198, loss_ib:0.00005319
# epoch 16 loss_pde:0.00247208, loss_ib:0.00005318
# epoch 16 loss_pde:0.00247201, loss_ib:0.00005318
# epoch 16 loss_pde:0.00247187, loss_ib:0.00005319
# epoch 16 loss_pde:0.00247195, loss_ib:0.00005318
# epoch 16 loss_pde:0.00247207, loss_ib:0.00005316
# epoch 16 loss_pde:0.00247208, loss_ib:0.00005315
# epoch 16 loss_pde:0.00247206, loss_ib:0.00005315
# epoch 16 loss_pde:0.00247199, loss_ib:0.00005315
# epoch 16 loss_pde:0.00247188, loss_ib:0.00005316
# epoch 16 loss_pde:0.00247171, loss_ib:0.00005317
# epoch 16 loss_pde:0.00247156, loss_ib:0.00005318
# epoch 16 loss_pde:0.00247132, loss_ib:0.00005320
# epoch 16 loss_pde:0.00247115, loss_ib:0.00005321
# epoch 16 loss_pde:0.00247107, loss_ib:0.00005322
# epoch 16 loss_pde:0.00247070, loss_ib:0.00005325
# epoch 16 loss_pde:0.00247048, loss_ib:0.00005326
# epoch 16: loss 0.003004
# epoch 17 loss_pde:0.00247003, loss_ib:0.00005330
# epoch 17 loss_pde:0.00247007, loss_ib:0.00005329
# epoch 17 loss_pde:0.00247015, loss_ib:0.00005328
# epoch 17 loss_pde:0.00247006, loss_ib:0.00005328
# epoch 17 loss_pde:0.00247011, loss_ib:0.00005327
# epoch 17 loss_pde:0.00246998, loss_ib:0.00005328
# epoch 17 loss_pde:0.00246988, loss_ib:0.00005328
# epoch 17 loss_pde:0.00246989, loss_ib:0.00005328
# epoch 17 loss_pde:0.00246981, loss_ib:0.00005328
# epoch 17 loss_pde:0.00246989, loss_ib:0.00005327
# epoch 17 loss_pde:0.00247002, loss_ib:0.00005326
# epoch 17 loss_pde:0.00247011, loss_ib:0.00005324
# epoch 17 loss_pde:0.00247015, loss_ib:0.00005324
# epoch 17 loss_pde:0.00247014, loss_ib:0.00005323
# epoch 17 loss_pde:0.00247010, loss_ib:0.00005323
# epoch 17 loss_pde:0.00247009, loss_ib:0.00005323
# epoch 17 loss_pde:0.00247012, loss_ib:0.00005322
# epoch 17 loss_pde:0.00247017, loss_ib:0.00005321
# epoch 17 loss_pde:0.00247018, loss_ib:0.00005320
# epoch 17 loss_pde:0.00247014, loss_ib:0.00005320
# epoch 17: loss 0.003003
# epoch 18 loss_pde:0.00247005, loss_ib:0.00005321
# epoch 18 loss_pde:0.00246992, loss_ib:0.00005322
# epoch 18 loss_pde:0.00246966, loss_ib:0.00005323
# epoch 18 loss_pde:0.00246964, loss_ib:0.00005323
# epoch 18 loss_pde:0.00246966, loss_ib:0.00005323
# epoch 18 loss_pde:0.00246971, loss_ib:0.00005322
# epoch 18: loss 0.003002
# epoch 19 loss_pde:0.00246971, loss_ib:0.00005322
# epoch 19 loss_pde:0.00246968, loss_ib:0.00005322
# epoch 19 loss_pde:0.00246968, loss_ib:0.00005322
# epoch 19 loss_pde:0.00246972, loss_ib:0.00005322
# epoch 19 loss_pde:0.00246971, loss_ib:0.00005321
# epoch 19 loss_pde:0.00246962, loss_ib:0.00005321
# epoch 19 loss_pde:0.00246980, loss_ib:0.00005319
# epoch 19 loss_pde:0.00246952, loss_ib:0.00005321
# epoch 19 loss_pde:0.00246954, loss_ib:0.00005321
# epoch 19 loss_pde:0.00246954, loss_ib:0.00005320
# epoch 19 loss_pde:0.00246952, loss_ib:0.00005320
# epoch 19 loss_pde:0.00246939, loss_ib:0.00005321
# epoch 19 loss_pde:0.00246904, loss_ib:0.00005324
# epoch 19 loss_pde:0.00246887, loss_ib:0.00005325
# epoch 19 loss_pde:0.00246866, loss_ib:0.00005326
# epoch 19 loss_pde:0.00246853, loss_ib:0.00005327
# epoch 19 loss_pde:0.00246837, loss_ib:0.00005328
# epoch 19 loss_pde:0.00246831, loss_ib:0.00005328
# epoch 19 loss_pde:0.00246821, loss_ib:0.00005329
# epoch 19 loss_pde:0.00246807, loss_ib:0.00005330
# epoch 19: loss 0.003002
# epoch 20 loss_pde:0.00246790, loss_ib:0.00005331
# epoch 20 loss_pde:0.00246784, loss_ib:0.00005332
# epoch 20 loss_pde:0.00246785, loss_ib:0.00005331
# epoch 20 loss_pde:0.00246787, loss_ib:0.00005331
# epoch 20 loss_pde:0.00246790, loss_ib:0.00005330
# epoch 20 loss_pde:0.00246796, loss_ib:0.00005329
# epoch 20 loss_pde:0.00246791, loss_ib:0.00005329
# epoch 20 loss_pde:0.00246789, loss_ib:0.00005328
# epoch 20 loss_pde:0.00246781, loss_ib:0.00005328
# epoch 20 loss_pde:0.00246785, loss_ib:0.00005328
# epoch 20 loss_pde:0.00246792, loss_ib:0.00005327
# epoch 20 loss_pde:0.00246801, loss_ib:0.00005325
# epoch 20 loss_pde:0.00246801, loss_ib:0.00005325
# epoch 20 loss_pde:0.00246803, loss_ib:0.00005324
# epoch 20 loss_pde:0.00246800, loss_ib:0.00005324
# epoch 20 loss_pde:0.00246788, loss_ib:0.00005324
# epoch 20 loss_pde:0.00246768, loss_ib:0.00005325
# epoch 20 loss_pde:0.00246742, loss_ib:0.00005327
# epoch 20 loss_pde:0.00246745, loss_ib:0.00005326
# epoch 20 loss_pde:0.00246743, loss_ib:0.00005326
# epoch 20: loss 0.003001
# epoch 21 loss_pde:0.00246751, loss_ib:0.00005325
# epoch 21 loss_pde:0.00246752, loss_ib:0.00005324
# epoch 21 loss_pde:0.00246745, loss_ib:0.00005325
# epoch 21 loss_pde:0.00246741, loss_ib:0.00005325
# epoch 21 loss_pde:0.00246730, loss_ib:0.00005325
# epoch 21 loss_pde:0.00246731, loss_ib:0.00005325
# epoch 21 loss_pde:0.00246728, loss_ib:0.00005325
# epoch 21 loss_pde:0.00246732, loss_ib:0.00005324
# epoch 21 loss_pde:0.00246741, loss_ib:0.00005322
# epoch 21 loss_pde:0.00246749, loss_ib:0.00005321
# epoch 21 loss_pde:0.00246757, loss_ib:0.00005319
# epoch 21 loss_pde:0.00246754, loss_ib:0.00005319
# epoch 21 loss_pde:0.00246752, loss_ib:0.00005319
# epoch 21 loss_pde:0.00246740, loss_ib:0.00005320
# epoch 21 loss_pde:0.00246729, loss_ib:0.00005320
# epoch 21 loss_pde:0.00246718, loss_ib:0.00005321
# epoch 21 loss_pde:0.00246703, loss_ib:0.00005322
# epoch 21 loss_pde:0.00246687, loss_ib:0.00005323
# epoch 21 loss_pde:0.00246674, loss_ib:0.00005324
# epoch 21 loss_pde:0.00246658, loss_ib:0.00005325
# epoch 21: loss 0.003000
# epoch 22 loss_pde:0.00246634, loss_ib:0.00005326
# epoch 22 loss_pde:0.00246609, loss_ib:0.00005328
# epoch 22 loss_pde:0.00246583, loss_ib:0.00005330
# epoch 22 loss_pde:0.00246600, loss_ib:0.00005334
# epoch 22 loss_pde:0.00246571, loss_ib:0.00005331
# epoch 22 loss_pde:0.00246566, loss_ib:0.00005331
# epoch 22 loss_pde:0.00246559, loss_ib:0.00005331
# epoch 22 loss_pde:0.00246565, loss_ib:0.00005330
# epoch 22 loss_pde:0.00246560, loss_ib:0.00005330
# epoch 22 loss_pde:0.00246541, loss_ib:0.00005332
# epoch 22 loss_pde:0.00246539, loss_ib:0.00005331
# epoch 22 loss_pde:0.00246545, loss_ib:0.00005331
# epoch 22 loss_pde:0.00246553, loss_ib:0.00005329
# epoch 22 loss_pde:0.00246559, loss_ib:0.00005328
# epoch 22 loss_pde:0.00246559, loss_ib:0.00005327
# epoch 22 loss_pde:0.00246565, loss_ib:0.00005327
# epoch 22 loss_pde:0.00246562, loss_ib:0.00005327
# epoch 22 loss_pde:0.00246562, loss_ib:0.00005326
# epoch 22 loss_pde:0.00246564, loss_ib:0.00005326
# epoch 22 loss_pde:0.00246570, loss_ib:0.00005324
# epoch 22: loss 0.002999
# epoch 23 loss_pde:0.00246562, loss_ib:0.00005325
# epoch 23 loss_pde:0.00246543, loss_ib:0.00005326
# epoch 23 loss_pde:0.00246536, loss_ib:0.00005326
# epoch 23 loss_pde:0.00246524, loss_ib:0.00005327
# epoch 23 loss_pde:0.00246520, loss_ib:0.00005327
# epoch 23 loss_pde:0.00246512, loss_ib:0.00005327
# epoch 23 loss_pde:0.00246505, loss_ib:0.00005327
# epoch 23 loss_pde:0.00246526, loss_ib:0.00005324
# epoch 23 loss_pde:0.00246546, loss_ib:0.00005322
# epoch 23 loss_pde:0.00246526, loss_ib:0.00005323
# epoch 23 loss_pde:0.00246498, loss_ib:0.00005324
# epoch 23 loss_pde:0.00246463, loss_ib:0.00005327
# epoch 23 loss_pde:0.00246451, loss_ib:0.00005328
# epoch 23 loss_pde:0.00246432, loss_ib:0.00005329
# epoch 23 loss_pde:0.00246429, loss_ib:0.00005329
# epoch 23 loss_pde:0.00246423, loss_ib:0.00005329
# epoch 23 loss_pde:0.00246408, loss_ib:0.00005330
# epoch 23 loss_pde:0.00246363, loss_ib:0.00005333
# epoch 23 loss_pde:0.00246351, loss_ib:0.00005334
# epoch 23 loss_pde:0.00246352, loss_ib:0.00005333
# epoch 23: loss 0.002998
# epoch 24 loss_pde:0.00246350, loss_ib:0.00005333
# epoch 24 loss_pde:0.00246345, loss_ib:0.00005332
# epoch 24 loss_pde:0.00246342, loss_ib:0.00005332
# epoch 24 loss_pde:0.00246330, loss_ib:0.00005332
# epoch 24 loss_pde:0.00246398, loss_ib:0.00005326
# epoch 24 loss_pde:0.00246338, loss_ib:0.00005331
# epoch 24 loss_pde:0.00246332, loss_ib:0.00005331
# epoch 24 loss_pde:0.00246319, loss_ib:0.00005332
# epoch 24 loss_pde:0.00246316, loss_ib:0.00005332
# epoch 24 loss_pde:0.00246296, loss_ib:0.00005335
# epoch 24 loss_pde:0.00246302, loss_ib:0.00005332
# epoch 24 loss_pde:0.00246318, loss_ib:0.00005330
# epoch 24 loss_pde:0.00246310, loss_ib:0.00005330
# epoch 24 loss_pde:0.00246299, loss_ib:0.00005330
# epoch 24 loss_pde:0.00246281, loss_ib:0.00005331
# epoch 24 loss_pde:0.00246273, loss_ib:0.00005332
# epoch 24 loss_pde:0.00246271, loss_ib:0.00005332
# epoch 24 loss_pde:0.00246275, loss_ib:0.00005331
# epoch 24 loss_pde:0.00246291, loss_ib:0.00005329
# epoch 24 loss_pde:0.00246301, loss_ib:0.00005328
# epoch 24: loss 0.002997
# epoch 25 loss_pde:0.00246309, loss_ib:0.00005327
# epoch 25 loss_pde:0.00246308, loss_ib:0.00005326
# epoch 25 loss_pde:0.00246308, loss_ib:0.00005326
# epoch 25 loss_pde:0.00246306, loss_ib:0.00005326
# epoch 25 loss_pde:0.00246302, loss_ib:0.00005326
# epoch 25 loss_pde:0.00246305, loss_ib:0.00005326
# epoch 25 loss_pde:0.00246305, loss_ib:0.00005325
# epoch 25 loss_pde:0.00246301, loss_ib:0.00005325
# epoch 25 loss_pde:0.00246308, loss_ib:0.00005324
# epoch 25 loss_pde:0.00246306, loss_ib:0.00005324
# epoch 25 loss_pde:0.00246300, loss_ib:0.00005324
# epoch 25 loss_pde:0.00246297, loss_ib:0.00005324
# epoch 25 loss_pde:0.00246299, loss_ib:0.00005323
# epoch 25 loss_pde:0.00246296, loss_ib:0.00005323
# epoch 25 loss_pde:0.00246324, loss_ib:0.00005320
# epoch 25 loss_pde:0.00246299, loss_ib:0.00005322
# epoch 25 loss_pde:0.00246292, loss_ib:0.00005322
# epoch 25 loss_pde:0.00246283, loss_ib:0.00005322
# epoch 25 loss_pde:0.00246282, loss_ib:0.00005322
# epoch 25 loss_pde:0.00246284, loss_ib:0.00005321
# epoch 25: loss 0.002996
# epoch 26 loss_pde:0.00246288, loss_ib:0.00005320
# epoch 26 loss_pde:0.00246257, loss_ib:0.00005323
# epoch 26 loss_pde:0.00246267, loss_ib:0.00005321
# epoch 26 loss_pde:0.00246265, loss_ib:0.00005321
# epoch 26 loss_pde:0.00246247, loss_ib:0.00005322
# epoch 26 loss_pde:0.00246221, loss_ib:0.00005324
# epoch 26 loss_pde:0.00246201, loss_ib:0.00005325
# epoch 26 loss_pde:0.00246184, loss_ib:0.00005326
# epoch 26 loss_pde:0.00246178, loss_ib:0.00005326
# epoch 26 loss_pde:0.00246190, loss_ib:0.00005324
# epoch 26 loss_pde:0.00246201, loss_ib:0.00005322
# epoch 26 loss_pde:0.00246214, loss_ib:0.00005320
# epoch 26 loss_pde:0.00246213, loss_ib:0.00005320
# epoch 26 loss_pde:0.00246212, loss_ib:0.00005320
# epoch 26 loss_pde:0.00246211, loss_ib:0.00005319
# epoch 26 loss_pde:0.00246220, loss_ib:0.00005318
# epoch 26 loss_pde:0.00246238, loss_ib:0.00005316
# epoch 26 loss_pde:0.00246255, loss_ib:0.00005314
# epoch 26 loss_pde:0.00246272, loss_ib:0.00005312
# epoch 26 loss_pde:0.00246281, loss_ib:0.00005311
# epoch 26: loss 0.002995
# epoch 27 loss_pde:0.00246281, loss_ib:0.00005310
# epoch 27 loss_pde:0.00246271, loss_ib:0.00005310
# epoch 27 loss_pde:0.00246247, loss_ib:0.00005312
# epoch 27 loss_pde:0.00246240, loss_ib:0.00005313
# epoch 27 loss_pde:0.00246232, loss_ib:0.00005313
# epoch 27 loss_pde:0.00246240, loss_ib:0.00005312
# epoch 27 loss_pde:0.00246256, loss_ib:0.00005310
# epoch 27 loss_pde:0.00246251, loss_ib:0.00005311
# epoch 27 loss_pde:0.00246252, loss_ib:0.00005310
# epoch 27 loss_pde:0.00246235, loss_ib:0.00005311
# epoch 27 loss_pde:0.00246212, loss_ib:0.00005313
# epoch 27 loss_pde:0.00246185, loss_ib:0.00005315
# epoch 27 loss_pde:0.00246174, loss_ib:0.00005316
# epoch 27 loss_pde:0.00246139, loss_ib:0.00005319
# epoch 27 loss_pde:0.00246153, loss_ib:0.00005317
# epoch 27 loss_pde:0.00246185, loss_ib:0.00005313
# epoch 27 loss_pde:0.00246183, loss_ib:0.00005313
# epoch 27 loss_pde:0.00246188, loss_ib:0.00005312
# epoch 27 loss_pde:0.00246197, loss_ib:0.00005310
# epoch 27 loss_pde:0.00246195, loss_ib:0.00005310
# epoch 27: loss 0.002994
# epoch 28 loss_pde:0.00246201, loss_ib:0.00005309
# epoch 28 loss_pde:0.00246202, loss_ib:0.00005308
# epoch 28 loss_pde:0.00246223, loss_ib:0.00005305
# epoch 28 loss_pde:0.00246218, loss_ib:0.00005307
# epoch 28 loss_pde:0.00246216, loss_ib:0.00005305
# epoch 28 loss_pde:0.00246213, loss_ib:0.00005305
# epoch 28 loss_pde:0.00246206, loss_ib:0.00005305
# epoch 28 loss_pde:0.00246207, loss_ib:0.00005305
# epoch 28 loss_pde:0.00246212, loss_ib:0.00005304
# epoch 28 loss_pde:0.00246212, loss_ib:0.00005303
# epoch 28 loss_pde:0.00246209, loss_ib:0.00005303
# epoch 28 loss_pde:0.00246198, loss_ib:0.00005304
# epoch 28 loss_pde:0.00246163, loss_ib:0.00005307
# epoch 28 loss_pde:0.00246145, loss_ib:0.00005308
# epoch 28 loss_pde:0.00246119, loss_ib:0.00005310
# epoch 28 loss_pde:0.00246101, loss_ib:0.00005312
# epoch 28 loss_pde:0.00246086, loss_ib:0.00005313
# epoch 28 loss_pde:0.00246072, loss_ib:0.00005314
# epoch 28 loss_pde:0.00246055, loss_ib:0.00005315
# epoch 28 loss_pde:0.00246049, loss_ib:0.00005315
# epoch 28: loss 0.002993
# epoch 29 loss_pde:0.00246047, loss_ib:0.00005315
# epoch 29 loss_pde:0.00246049, loss_ib:0.00005314
# epoch 29 loss_pde:0.00246080, loss_ib:0.00005311
# epoch 29 loss_pde:0.00246060, loss_ib:0.00005312
# epoch 29 loss_pde:0.00246062, loss_ib:0.00005311
# epoch 29 loss_pde:0.00246063, loss_ib:0.00005311
# epoch 29 loss_pde:0.00246060, loss_ib:0.00005310
# epoch 29 loss_pde:0.00246054, loss_ib:0.00005310
# epoch 29 loss_pde:0.00246046, loss_ib:0.00005310
# epoch 29 loss_pde:0.00246036, loss_ib:0.00005311
# epoch 29 loss_pde:0.00246023, loss_ib:0.00005312
# epoch 29 loss_pde:0.00246016, loss_ib:0.00005312
# epoch 29 loss_pde:0.00246007, loss_ib:0.00005313
# epoch 29 loss_pde:0.00246012, loss_ib:0.00005312
# epoch 29 loss_pde:0.00246013, loss_ib:0.00005312
# epoch 29 loss_pde:0.00246006, loss_ib:0.00005312
# epoch 29 loss_pde:0.00246002, loss_ib:0.00005312
# epoch 29 loss_pde:0.00245996, loss_ib:0.00005312
# epoch 29 loss_pde:0.00245939, loss_ib:0.00005321
# epoch 29 loss_pde:0.00245972, loss_ib:0.00005313
# epoch 29: loss 0.002992
# epoch 30 loss_pde:0.00245971, loss_ib:0.00005313
# epoch 30 loss_pde:0.00245974, loss_ib:0.00005312
# epoch 30 loss_pde:0.00245972, loss_ib:0.00005312
# epoch 30 loss_pde:0.00245958, loss_ib:0.00005313
# epoch 30 loss_pde:0.00245949, loss_ib:0.00005313
# epoch 30 loss_pde:0.00245944, loss_ib:0.00005314
# epoch 30 loss_pde:0.00245954, loss_ib:0.00005312
# epoch 30 loss_pde:0.00245955, loss_ib:0.00005312
# epoch 30 loss_pde:0.00245948, loss_ib:0.00005312
# epoch 30 loss_pde:0.00245932, loss_ib:0.00005313
# epoch 30 loss_pde:0.00245904, loss_ib:0.00005315
# epoch 30 loss_pde:0.00245884, loss_ib:0.00005317
# epoch 30 loss_pde:0.00245858, loss_ib:0.00005319
# epoch 30 loss_pde:0.00245849, loss_ib:0.00005319
# epoch 30 loss_pde:0.00245844, loss_ib:0.00005319
# epoch 30 loss_pde:0.00245841, loss_ib:0.00005318
# epoch 30 loss_pde:0.00245841, loss_ib:0.00005318
# epoch 30 loss_pde:0.00245839, loss_ib:0.00005317
# epoch 30 loss_pde:0.00245845, loss_ib:0.00005317
# epoch 30 loss_pde:0.00245849, loss_ib:0.00005315
# epoch 30: loss 0.002991
# epoch 31 loss_pde:0.00245851, loss_ib:0.00005315
# epoch 31 loss_pde:0.00245870, loss_ib:0.00005311
# epoch 31 loss_pde:0.00245871, loss_ib:0.00005310
# epoch 31 loss_pde:0.00245890, loss_ib:0.00005307
# epoch 31 loss_pde:0.00245882, loss_ib:0.00005306
# epoch 31 loss_pde:0.00245880, loss_ib:0.00005306
# epoch 31 loss_pde:0.00245886, loss_ib:0.00005305
# epoch 31 loss_pde:0.00245909, loss_ib:0.00005302
# epoch 31 loss_pde:0.00245922, loss_ib:0.00005300
# epoch 31 loss_pde:0.00245943, loss_ib:0.00005297
# epoch 31 loss_pde:0.00245946, loss_ib:0.00005297
# epoch 31 loss_pde:0.00245937, loss_ib:0.00005297
# epoch 31 loss_pde:0.00245930, loss_ib:0.00005298
# epoch 31 loss_pde:0.00245902, loss_ib:0.00005300
# epoch 31 loss_pde:0.00245886, loss_ib:0.00005301
# epoch 31 loss_pde:0.00245871, loss_ib:0.00005303
# epoch 31 loss_pde:0.00245848, loss_ib:0.00005304
# epoch 31 loss_pde:0.00245843, loss_ib:0.00005304
# epoch 31 loss_pde:0.00245826, loss_ib:0.00005305
# epoch 31 loss_pde:0.00245824, loss_ib:0.00005305
# epoch 31: loss 0.002990
# epoch 32 loss_pde:0.00245804, loss_ib:0.00005306
# epoch 32 loss_pde:0.00245797, loss_ib:0.00005306
# epoch 32 loss_pde:0.00245767, loss_ib:0.00005309
# epoch 32 loss_pde:0.00245716, loss_ib:0.00005313
# epoch 32 loss_pde:0.00245702, loss_ib:0.00005344
# epoch 32 loss_pde:0.00245699, loss_ib:0.00005314
# epoch 32 loss_pde:0.00245702, loss_ib:0.00005313
# epoch 32 loss_pde:0.00245722, loss_ib:0.00005311
# epoch 32 loss_pde:0.00245705, loss_ib:0.00005312
# epoch 32 loss_pde:0.00245693, loss_ib:0.00005313
# epoch 32 loss_pde:0.00245690, loss_ib:0.00005313
# epoch 32 loss_pde:0.00245678, loss_ib:0.00005314
# epoch 32 loss_pde:0.00245669, loss_ib:0.00005314
# epoch 32 loss_pde:0.00245669, loss_ib:0.00005314
# epoch 32 loss_pde:0.00245672, loss_ib:0.00005313
# epoch 32 loss_pde:0.00245671, loss_ib:0.00005313
# epoch 32 loss_pde:0.00245677, loss_ib:0.00005312
# epoch 32 loss_pde:0.00245679, loss_ib:0.00005311
# epoch 32 loss_pde:0.00245696, loss_ib:0.00005309
# epoch 32 loss_pde:0.00245711, loss_ib:0.00005307
# epoch 32: loss 0.002989
# epoch 33 loss_pde:0.00245708, loss_ib:0.00005307
# epoch 33 loss_pde:0.00245690, loss_ib:0.00005308
# epoch 33 loss_pde:0.00245681, loss_ib:0.00005309
# epoch 33 loss_pde:0.00245645, loss_ib:0.00005311
# epoch 33 loss_pde:0.00245653, loss_ib:0.00005311
# epoch 33 loss_pde:0.00245652, loss_ib:0.00005311
# epoch 33 loss_pde:0.00245648, loss_ib:0.00005310
# epoch 33 loss_pde:0.00245650, loss_ib:0.00005310
# epoch 33 loss_pde:0.00245655, loss_ib:0.00005309
# epoch 33 loss_pde:0.00245667, loss_ib:0.00005307
# epoch 33 loss_pde:0.00245669, loss_ib:0.00005307
# epoch 33 loss_pde:0.00245667, loss_ib:0.00005306
# epoch 33 loss_pde:0.00245660, loss_ib:0.00005306
# epoch 33 loss_pde:0.00245670, loss_ib:0.00005307
# epoch 33 loss_pde:0.00245635, loss_ib:0.00005308
# epoch 33 loss_pde:0.00245658, loss_ib:0.00005305
# epoch 33 loss_pde:0.00245663, loss_ib:0.00005304
# epoch 33 loss_pde:0.00245683, loss_ib:0.00005301
# epoch 33 loss_pde:0.00245679, loss_ib:0.00005301
# epoch 33 loss_pde:0.00245675, loss_ib:0.00005301
# epoch 33: loss 0.002988
# epoch 34 loss_pde:0.00245670, loss_ib:0.00005301
# epoch 34 loss_pde:0.00245658, loss_ib:0.00005302
# epoch 34 loss_pde:0.00245644, loss_ib:0.00005303
# epoch 34 loss_pde:0.00245624, loss_ib:0.00005304
# epoch 34 loss_pde:0.00245618, loss_ib:0.00005305
# epoch 34 loss_pde:0.00245612, loss_ib:0.00005305
# epoch 34 loss_pde:0.00245610, loss_ib:0.00005305
# epoch 34 loss_pde:0.00245605, loss_ib:0.00005305
# epoch 34 loss_pde:0.00245605, loss_ib:0.00005305
# epoch 34 loss_pde:0.00245607, loss_ib:0.00005304
# epoch 34 loss_pde:0.00245630, loss_ib:0.00005304
# epoch 34 loss_pde:0.00245605, loss_ib:0.00005304
# epoch 34 loss_pde:0.00245601, loss_ib:0.00005304
# epoch 34 loss_pde:0.00245599, loss_ib:0.00005304
# epoch 34 loss_pde:0.00245590, loss_ib:0.00005304
# epoch 34 loss_pde:0.00245593, loss_ib:0.00005303
# epoch 34 loss_pde:0.00245596, loss_ib:0.00005302
# epoch 34 loss_pde:0.00245592, loss_ib:0.00005302
# epoch 34 loss_pde:0.00245584, loss_ib:0.00005303
# epoch 34 loss_pde:0.00245578, loss_ib:0.00005303
# epoch 34: loss 0.002987
# epoch 35 loss_pde:0.00245573, loss_ib:0.00005303
# epoch 35 loss_pde:0.00245561, loss_ib:0.00005304
# epoch 35 loss_pde:0.00245555, loss_ib:0.00005304
# epoch 35 loss_pde:0.00245557, loss_ib:0.00005304
# epoch 35 loss_pde:0.00245559, loss_ib:0.00005303
# epoch 35 loss_pde:0.00245577, loss_ib:0.00005300
# epoch 35 loss_pde:0.00245596, loss_ib:0.00005298
# epoch 35 loss_pde:0.00245606, loss_ib:0.00005296
# epoch 35 loss_pde:0.00245608, loss_ib:0.00005295
# epoch 35 loss_pde:0.00245591, loss_ib:0.00005297
# epoch 35 loss_pde:0.00245551, loss_ib:0.00005299
# epoch 35 loss_pde:0.00245524, loss_ib:0.00005301
# epoch 35 loss_pde:0.00245516, loss_ib:0.00005301
# epoch 35 loss_pde:0.00245517, loss_ib:0.00005301
# epoch 35 loss_pde:0.00245517, loss_ib:0.00005300
# epoch 35 loss_pde:0.00245514, loss_ib:0.00005300
# epoch 35 loss_pde:0.00245515, loss_ib:0.00005300
# epoch 35 loss_pde:0.00245495, loss_ib:0.00005301
# epoch 35 loss_pde:0.00245468, loss_ib:0.00005303
# epoch 35 loss_pde:0.00245455, loss_ib:0.00005304
# epoch 35: loss 0.002986
# epoch 36 loss_pde:0.00245452, loss_ib:0.00005303
# epoch 36 loss_pde:0.00245454, loss_ib:0.00005302
# epoch 36 loss_pde:0.00245466, loss_ib:0.00005302
# epoch 36 loss_pde:0.00245463, loss_ib:0.00005300
# epoch 36 loss_pde:0.00245454, loss_ib:0.00005300
# epoch 36 loss_pde:0.00245446, loss_ib:0.00005301
# epoch 36 loss_pde:0.00245444, loss_ib:0.00005301
# epoch 36 loss_pde:0.00245437, loss_ib:0.00005301
# epoch 36 loss_pde:0.00245456, loss_ib:0.00005299
# epoch 36 loss_pde:0.00245462, loss_ib:0.00005298
# epoch 36 loss_pde:0.00245478, loss_ib:0.00005296
# epoch 36 loss_pde:0.00245475, loss_ib:0.00005295
# epoch 36 loss_pde:0.00245457, loss_ib:0.00005296
# epoch 36 loss_pde:0.00245442, loss_ib:0.00005296
# epoch 36 loss_pde:0.00245426, loss_ib:0.00005297
# epoch 36 loss_pde:0.00245409, loss_ib:0.00005298
# epoch 36 loss_pde:0.00245387, loss_ib:0.00005300
# epoch 36 loss_pde:0.00245386, loss_ib:0.00005300
# epoch 36 loss_pde:0.00245415, loss_ib:0.00005296
# epoch 36 loss_pde:0.00245389, loss_ib:0.00005298
# epoch 36: loss 0.002985
# epoch 37 loss_pde:0.00245444, loss_ib:0.00005291
# epoch 37 loss_pde:0.00245415, loss_ib:0.00005293
# epoch 37 loss_pde:0.00245404, loss_ib:0.00005293
# epoch 37 loss_pde:0.00245414, loss_ib:0.00005291
# epoch 37 loss_pde:0.00245441, loss_ib:0.00005288
# epoch 37 loss_pde:0.00245454, loss_ib:0.00005286
# epoch 37 loss_pde:0.00245461, loss_ib:0.00005285
# epoch 37 loss_pde:0.00245459, loss_ib:0.00005285
# epoch 37 loss_pde:0.00245457, loss_ib:0.00005285
# epoch 37 loss_pde:0.00245446, loss_ib:0.00005285
# epoch 37 loss_pde:0.00245434, loss_ib:0.00005286
# epoch 37 loss_pde:0.00245397, loss_ib:0.00005289
# epoch 37 loss_pde:0.00245410, loss_ib:0.00005287
# epoch 37 loss_pde:0.00245416, loss_ib:0.00005286
# epoch 37 loss_pde:0.00245404, loss_ib:0.00005287
# epoch 37 loss_pde:0.00245400, loss_ib:0.00005287
# epoch 37 loss_pde:0.00245384, loss_ib:0.00005288
# epoch 37 loss_pde:0.00245366, loss_ib:0.00005289
# epoch 37 loss_pde:0.00245353, loss_ib:0.00005289
# epoch 37 loss_pde:0.00245375, loss_ib:0.00005287
# epoch 37: loss 0.002984
# epoch 38 loss_pde:0.00245372, loss_ib:0.00005287
# epoch 38 loss_pde:0.00245366, loss_ib:0.00005287
# epoch 38 loss_pde:0.00245363, loss_ib:0.00005286
# epoch 38 loss_pde:0.00245351, loss_ib:0.00005286
# epoch 38 loss_pde:0.00245349, loss_ib:0.00005286
# epoch 38 loss_pde:0.00245341, loss_ib:0.00005286
# epoch 38 loss_pde:0.00245336, loss_ib:0.00005286
# epoch 38 loss_pde:0.00245323, loss_ib:0.00005287
# epoch 38 loss_pde:0.00245317, loss_ib:0.00005287
# epoch 38 loss_pde:0.00245322, loss_ib:0.00005287
# epoch 38 loss_pde:0.00245326, loss_ib:0.00005286
# epoch 38 loss_pde:0.00245339, loss_ib:0.00005284
# epoch 38 loss_pde:0.00245339, loss_ib:0.00005284
# epoch 38 loss_pde:0.00245342, loss_ib:0.00005283
# epoch 38 loss_pde:0.00245347, loss_ib:0.00005282
# epoch 38 loss_pde:0.00245365, loss_ib:0.00005280
# epoch 38 loss_pde:0.00245347, loss_ib:0.00005281
# epoch 38 loss_pde:0.00245331, loss_ib:0.00005282
# epoch 38 loss_pde:0.00245329, loss_ib:0.00005282
# epoch 38 loss_pde:0.00245323, loss_ib:0.00005283
# epoch 38: loss 0.002982
# epoch 39 loss_pde:0.00245323, loss_ib:0.00005283
# epoch 39 loss_pde:0.00245319, loss_ib:0.00005282
# epoch 39 loss_pde:0.00245317, loss_ib:0.00005282
# epoch 39 loss_pde:0.00245311, loss_ib:0.00005283
# epoch 39 loss_pde:0.00245303, loss_ib:0.00005283
# epoch 39 loss_pde:0.00245296, loss_ib:0.00005283
# epoch 39 loss_pde:0.00245291, loss_ib:0.00005284
# epoch 39 loss_pde:0.00245292, loss_ib:0.00005284
# epoch 39 loss_pde:0.00245296, loss_ib:0.00005283
# epoch 39 loss_pde:0.00245302, loss_ib:0.00005282
# epoch 39 loss_pde:0.00245338, loss_ib:0.00005279
# epoch 39 loss_pde:0.00245306, loss_ib:0.00005280
# epoch 39 loss_pde:0.00245313, loss_ib:0.00005279
# epoch 39 loss_pde:0.00245309, loss_ib:0.00005279
# epoch 39 loss_pde:0.00245310, loss_ib:0.00005279
# epoch 39 loss_pde:0.00245310, loss_ib:0.00005278
# epoch 39 loss_pde:0.00245301, loss_ib:0.00005278
# epoch 39 loss_pde:0.00245292, loss_ib:0.00005278
# epoch 39 loss_pde:0.00245273, loss_ib:0.00005279
# epoch 39 loss_pde:0.00245263, loss_ib:0.00005278
# epoch 39: loss 0.002982
# epoch 40 loss_pde:0.00245262, loss_ib:0.00005278
# epoch 40 loss_pde:0.00245253, loss_ib:0.00005278
# epoch 40 loss_pde:0.00245246, loss_ib:0.00005278
# epoch 40 loss_pde:0.00245236, loss_ib:0.00005279
# epoch 40 loss_pde:0.00245226, loss_ib:0.00005279
# epoch 40 loss_pde:0.00245214, loss_ib:0.00005280
# epoch 40 loss_pde:0.00245204, loss_ib:0.00005281
# epoch 40 loss_pde:0.00245189, loss_ib:0.00005282
# epoch 40 loss_pde:0.00245166, loss_ib:0.00005283
# epoch 40 loss_pde:0.00245138, loss_ib:0.00005286
# epoch 40 loss_pde:0.00245118, loss_ib:0.00005287
# epoch 40 loss_pde:0.00245116, loss_ib:0.00005287
# epoch 40 loss_pde:0.00245117, loss_ib:0.00005286
# epoch 40 loss_pde:0.00245119, loss_ib:0.00005286
# epoch 40 loss_pde:0.00245117, loss_ib:0.00005285
# epoch 40 loss_pde:0.00245104, loss_ib:0.00005286
# epoch 40 loss_pde:0.00245099, loss_ib:0.00005286
# epoch 40 loss_pde:0.00245111, loss_ib:0.00005284
# epoch 40 loss_pde:0.00245133, loss_ib:0.00005282
# epoch 40 loss_pde:0.00245132, loss_ib:0.00005281
# epoch 40: loss 0.002980
# epoch 41 loss_pde:0.00245133, loss_ib:0.00005281
# epoch 41 loss_pde:0.00245133, loss_ib:0.00005280
# epoch 41 loss_pde:0.00245126, loss_ib:0.00005280
# epoch 41 loss_pde:0.00245120, loss_ib:0.00005280
# epoch 41 loss_pde:0.00245124, loss_ib:0.00005279
# epoch 41 loss_pde:0.00245111, loss_ib:0.00005281
# epoch 41 loss_pde:0.00245117, loss_ib:0.00005278
# epoch 41 loss_pde:0.00245104, loss_ib:0.00005280
# epoch 41 loss_pde:0.00245114, loss_ib:0.00005278
# epoch 41 loss_pde:0.00245117, loss_ib:0.00005277
# epoch 41 loss_pde:0.00245105, loss_ib:0.00005278
# epoch 41 loss_pde:0.00245082, loss_ib:0.00005280
# epoch 41 loss_pde:0.00245067, loss_ib:0.00005281
# epoch 41 loss_pde:0.00245055, loss_ib:0.00005282
# epoch 41 loss_pde:0.00245042, loss_ib:0.00005282
# epoch 41 loss_pde:0.00245047, loss_ib:0.00005281
# epoch 41 loss_pde:0.00245061, loss_ib:0.00005279
# epoch 41 loss_pde:0.00245067, loss_ib:0.00005278
# epoch 41 loss_pde:0.00245064, loss_ib:0.00005279
# epoch 41 loss_pde:0.00245048, loss_ib:0.00005279
# epoch 41: loss 0.002979
# epoch 42 loss_pde:0.00245053, loss_ib:0.00005278
# epoch 42 loss_pde:0.00245061, loss_ib:0.00005276
# epoch 42 loss_pde:0.00245061, loss_ib:0.00005276
# epoch 42 loss_pde:0.00245045, loss_ib:0.00005277
# epoch 42 loss_pde:0.00245030, loss_ib:0.00005278
# epoch 42 loss_pde:0.00245016, loss_ib:0.00005278
# epoch 42 loss_pde:0.00245012, loss_ib:0.00005278
# epoch 42 loss_pde:0.00245013, loss_ib:0.00005278
# epoch 42 loss_pde:0.00245003, loss_ib:0.00005278
# epoch 42 loss_pde:0.00245017, loss_ib:0.00005276
# epoch 42 loss_pde:0.00245023, loss_ib:0.00005275
# epoch 42 loss_pde:0.00245018, loss_ib:0.00005275
# epoch 42 loss_pde:0.00245007, loss_ib:0.00005276
# epoch 42 loss_pde:0.00244977, loss_ib:0.00005278
# epoch 42 loss_pde:0.00244952, loss_ib:0.00005280
# epoch 42 loss_pde:0.00244920, loss_ib:0.00005282
# epoch 42 loss_pde:0.00244900, loss_ib:0.00005284
# epoch 42 loss_pde:0.00244901, loss_ib:0.00005284
# epoch 42: loss 0.002978
# epoch 43 loss_pde:0.00244901, loss_ib:0.00005284
# epoch 43 loss_pde:0.00244904, loss_ib:0.00005283
# epoch 43 loss_pde:0.00244911, loss_ib:0.00005282
# epoch 43 loss_pde:0.00244915, loss_ib:0.00005281
# epoch 43 loss_pde:0.00244916, loss_ib:0.00005280
# epoch 43 loss_pde:0.00244934, loss_ib:0.00005285
# epoch 43 loss_pde:0.00244914, loss_ib:0.00005279
# epoch 43 loss_pde:0.00244891, loss_ib:0.00005280
# epoch 43 loss_pde:0.00244892, loss_ib:0.00005280
# epoch 43 loss_pde:0.00244895, loss_ib:0.00005279
# epoch 43 loss_pde:0.00244891, loss_ib:0.00005279
# epoch 43 loss_pde:0.00244884, loss_ib:0.00005279
# epoch 43 loss_pde:0.00244884, loss_ib:0.00005279
# epoch 43 loss_pde:0.00244880, loss_ib:0.00005278
# epoch 43 loss_pde:0.00244898, loss_ib:0.00005276
# epoch 43 loss_pde:0.00244890, loss_ib:0.00005277
# epoch 43 loss_pde:0.00244886, loss_ib:0.00005277
# epoch 43 loss_pde:0.00244887, loss_ib:0.00005276
# epoch 43 loss_pde:0.00244880, loss_ib:0.00005276
# epoch 43 loss_pde:0.00244873, loss_ib:0.00005276
# epoch 43: loss 0.002977
# epoch 44 loss_pde:0.00244875, loss_ib:0.00005276
# epoch 44 loss_pde:0.00244863, loss_ib:0.00005276
# epoch 44 loss_pde:0.00244855, loss_ib:0.00005276
# epoch 44 loss_pde:0.00244849, loss_ib:0.00005277
# epoch 44 loss_pde:0.00244831, loss_ib:0.00005278
# epoch 44 loss_pde:0.00244810, loss_ib:0.00005279
# epoch 44 loss_pde:0.00244800, loss_ib:0.00005279
# epoch 44 loss_pde:0.00244803, loss_ib:0.00005279
# epoch 44 loss_pde:0.00244810, loss_ib:0.00005278
# epoch 44 loss_pde:0.00244819, loss_ib:0.00005277
# epoch 44 loss_pde:0.00244827, loss_ib:0.00005276
# epoch 44 loss_pde:0.00244830, loss_ib:0.00005275
# epoch 44 loss_pde:0.00244846, loss_ib:0.00005274
# epoch 44 loss_pde:0.00244834, loss_ib:0.00005274
# epoch 44 loss_pde:0.00244815, loss_ib:0.00005276
# epoch 44 loss_pde:0.00244821, loss_ib:0.00005275
# epoch 44 loss_pde:0.00244834, loss_ib:0.00005273
# epoch 44 loss_pde:0.00244840, loss_ib:0.00005272
# epoch 44 loss_pde:0.00244851, loss_ib:0.00005273
# epoch 44 loss_pde:0.00244848, loss_ib:0.00005271
# epoch 44: loss 0.002976
# epoch 45 loss_pde:0.00244842, loss_ib:0.00005271
# epoch 45 loss_pde:0.00244836, loss_ib:0.00005271
# epoch 45 loss_pde:0.00244834, loss_ib:0.00005270
# epoch 45 loss_pde:0.00244833, loss_ib:0.00005270
# epoch 45 loss_pde:0.00244833, loss_ib:0.00005270
# epoch 45 loss_pde:0.00244833, loss_ib:0.00005270
# epoch 45 loss_pde:0.00244835, loss_ib:0.00005269
# epoch 45 loss_pde:0.00244853, loss_ib:0.00005268
# epoch 45 loss_pde:0.00244829, loss_ib:0.00005269
# epoch 45 loss_pde:0.00244814, loss_ib:0.00005270
# epoch 45 loss_pde:0.00244804, loss_ib:0.00005272
# epoch 45 loss_pde:0.00244787, loss_ib:0.00005272
# epoch 45 loss_pde:0.00244787, loss_ib:0.00005272
# epoch 45 loss_pde:0.00244787, loss_ib:0.00005271
# epoch 45 loss_pde:0.00244789, loss_ib:0.00005271
# epoch 45 loss_pde:0.00244791, loss_ib:0.00005270
# epoch 45 loss_pde:0.00244791, loss_ib:0.00005270
# epoch 45 loss_pde:0.00244791, loss_ib:0.00005269
# epoch 45 loss_pde:0.00244791, loss_ib:0.00005269
# epoch 45 loss_pde:0.00244797, loss_ib:0.00005268
# epoch 45: loss 0.002976
# epoch 46 loss_pde:0.00244787, loss_ib:0.00005273
# epoch 46 loss_pde:0.00244812, loss_ib:0.00005265
# epoch 46 loss_pde:0.00244766, loss_ib:0.00005270
# epoch 46 loss_pde:0.00244793, loss_ib:0.00005267
# epoch 46 loss_pde:0.00244801, loss_ib:0.00005265
# epoch 46 loss_pde:0.00244811, loss_ib:0.00005264
# epoch 46 loss_pde:0.00244804, loss_ib:0.00005264
# epoch 46 loss_pde:0.00244795, loss_ib:0.00005264
# epoch 46 loss_pde:0.00244786, loss_ib:0.00005265
# epoch 46 loss_pde:0.00244771, loss_ib:0.00005266
# epoch 46 loss_pde:0.00244750, loss_ib:0.00005267
# epoch 46 loss_pde:0.00244743, loss_ib:0.00005267
# epoch 46 loss_pde:0.00244736, loss_ib:0.00005267
# epoch 46 loss_pde:0.00244718, loss_ib:0.00005271
# epoch 46 loss_pde:0.00244727, loss_ib:0.00005267
# epoch 46 loss_pde:0.00244720, loss_ib:0.00005267
# epoch 46 loss_pde:0.00244690, loss_ib:0.00005270
# epoch 46 loss_pde:0.00244678, loss_ib:0.00005271
# epoch 46 loss_pde:0.00244578, loss_ib:0.00005287
# epoch 46 loss_pde:0.00244623, loss_ib:0.00005275
# epoch 46: loss 0.002975
# epoch 47 loss_pde:0.00244630, loss_ib:0.00005274
# epoch 47 loss_pde:0.00244622, loss_ib:0.00005274
# epoch 47 loss_pde:0.00244607, loss_ib:0.00005275
# epoch 47 loss_pde:0.00244606, loss_ib:0.00005275
# epoch 47 loss_pde:0.00244613, loss_ib:0.00005273
# epoch 47 loss_pde:0.00244622, loss_ib:0.00005272
# epoch 47 loss_pde:0.00244629, loss_ib:0.00005271
# epoch 47 loss_pde:0.00244632, loss_ib:0.00005270
# epoch 47 loss_pde:0.00244626, loss_ib:0.00005270
# epoch 47 loss_pde:0.00244608, loss_ib:0.00005271
# epoch 47 loss_pde:0.00244595, loss_ib:0.00005272
# epoch 47 loss_pde:0.00244592, loss_ib:0.00005272
# epoch 47 loss_pde:0.00244600, loss_ib:0.00005271
# epoch 47 loss_pde:0.00244604, loss_ib:0.00005270
# epoch 47 loss_pde:0.00244614, loss_ib:0.00005269
# epoch 47 loss_pde:0.00244610, loss_ib:0.00005268
# epoch 47 loss_pde:0.00244610, loss_ib:0.00005268
# epoch 47 loss_pde:0.00244602, loss_ib:0.00005268
# epoch 47 loss_pde:0.00244586, loss_ib:0.00005270
# epoch 47 loss_pde:0.00244582, loss_ib:0.00005270
# epoch 47: loss 0.002974
# epoch 48 loss_pde:0.00244578, loss_ib:0.00005270
# epoch 48 loss_pde:0.00244579, loss_ib:0.00005270
# epoch 48 loss_pde:0.00244572, loss_ib:0.00005270
# epoch 48 loss_pde:0.00244552, loss_ib:0.00005272
# epoch 48 loss_pde:0.00244550, loss_ib:0.00005272
# epoch 48 loss_pde:0.00244541, loss_ib:0.00005272
# epoch 48 loss_pde:0.00244518, loss_ib:0.00005274
# epoch 48 loss_pde:0.00244495, loss_ib:0.00005276
# epoch 48 loss_pde:0.00244452, loss_ib:0.00005280
# epoch 48 loss_pde:0.00244441, loss_ib:0.00005280
# epoch 48 loss_pde:0.00244430, loss_ib:0.00005280
# epoch 48 loss_pde:0.00244424, loss_ib:0.00005281
# epoch 48 loss_pde:0.00244416, loss_ib:0.00005281
# epoch 48 loss_pde:0.00244403, loss_ib:0.00005282
# epoch 48 loss_pde:0.00244407, loss_ib:0.00005281
# epoch 48 loss_pde:0.00244411, loss_ib:0.00005280
# epoch 48 loss_pde:0.00244420, loss_ib:0.00005279
# epoch 48 loss_pde:0.00244429, loss_ib:0.00005277
# epoch 48 loss_pde:0.00244432, loss_ib:0.00005277
# epoch 48 loss_pde:0.00244438, loss_ib:0.00005276
# epoch 48: loss 0.002973
# epoch 49 loss_pde:0.00244438, loss_ib:0.00005276
# epoch 49 loss_pde:0.00244443, loss_ib:0.00005275
# epoch 49 loss_pde:0.00244441, loss_ib:0.00005274
# epoch 49 loss_pde:0.00244440, loss_ib:0.00005274
# epoch 49 loss_pde:0.00244439, loss_ib:0.00005274
# epoch 49 loss_pde:0.00244434, loss_ib:0.00005274
# epoch 49 loss_pde:0.00244434, loss_ib:0.00005274
# epoch 49 loss_pde:0.00244432, loss_ib:0.00005274
# epoch 49 loss_pde:0.00244423, loss_ib:0.00005275
# epoch 49 loss_pde:0.00244423, loss_ib:0.00005275
# epoch 49 loss_pde:0.00244432, loss_ib:0.00005273
# epoch 49 loss_pde:0.00244437, loss_ib:0.00005272
# epoch 49 loss_pde:0.00244433, loss_ib:0.00005272
# epoch 49 loss_pde:0.00244435, loss_ib:0.00005272
# epoch 49 loss_pde:0.00244438, loss_ib:0.00005271
# epoch 49 loss_pde:0.00244431, loss_ib:0.00005271
# epoch 49 loss_pde:0.00244423, loss_ib:0.00005272
# epoch 49 loss_pde:0.00244432, loss_ib:0.00005270
# epoch 49 loss_pde:0.00244436, loss_ib:0.00005269
# epoch 49 loss_pde:0.00244417, loss_ib:0.00005271
# epoch 49: loss 0.002972
# epoch 50 loss_pde:0.00244438, loss_ib:0.00005268
# epoch 50 loss_pde:0.00244454, loss_ib:0.00005265
# epoch 50 loss_pde:0.00244470, loss_ib:0.00005263
# ...
# epoch 179 loss_pde:0.00235213, loss_ib:0.00005049
# epoch 179 loss_pde:0.00235191, loss_ib:0.00005050
# epoch 179 loss_pde:0.00235170, loss_ib:0.00005052
# epoch 179 loss_pde:0.00235156, loss_ib:0.00005053
# epoch 179 loss_pde:0.00235135, loss_ib:0.00005055
# epoch 179 loss_pde:0.00235123, loss_ib:0.00005056
# epoch 179 loss_pde:0.00235101, loss_ib:0.00005057
# epoch 179 loss_pde:0.00235092, loss_ib:0.00005058
# epoch 179 loss_pde:0.00235085, loss_ib:0.00005058
# epoch 179 loss_pde:0.00235075, loss_ib:0.00005059
# epoch 179 loss_pde:0.00235067, loss_ib:0.00005059
# epoch 179 loss_pde:0.00235228, loss_ib:0.00005062
# epoch 179 loss_pde:0.00235064, loss_ib:0.00005059
# epoch 179 loss_pde:0.00235118, loss_ib:0.00005057
# epoch 179 loss_pde:0.00235059, loss_ib:0.00005059
# epoch 179 loss_pde:0.00235057, loss_ib:0.00005058
# epoch 179 loss_pde:0.00235047, loss_ib:0.00005058
# epoch 179 loss_pde:0.00235046, loss_ib:0.00005058
# epoch 179 loss_pde:0.00235042, loss_ib:0.00005058
# epoch 179 loss_pde:0.00235041, loss_ib:0.00005057
# epoch 179: loss 0.002857
# epoch 180 loss_pde:0.00235041, loss_ib:0.00005057
# epoch 180 loss_pde:0.00235032, loss_ib:0.00005057
# epoch 180 loss_pde:0.00235033, loss_ib:0.00005056
# epoch 180 loss_pde:0.00235091, loss_ib:0.00005059
# epoch 180 loss_pde:0.00235028, loss_ib:0.00005056
# epoch 180 loss_pde:0.00235034, loss_ib:0.00005055
# epoch 180 loss_pde:0.00235022, loss_ib:0.00005056
# epoch 180 loss_pde:0.00235009, loss_ib:0.00005056
# epoch 180 loss_pde:0.00234985, loss_ib:0.00005058
# epoch 180 loss_pde:0.00234983, loss_ib:0.00005057
# epoch 180 loss_pde:0.00234910, loss_ib:0.00005066
# epoch 180 loss_pde:0.00234957, loss_ib:0.00005059
# epoch 180 loss_pde:0.00234954, loss_ib:0.00005059
# epoch 180 loss_pde:0.00234925, loss_ib:0.00005061
# epoch 180 loss_pde:0.00234903, loss_ib:0.00005063
# epoch 180 loss_pde:0.00234877, loss_ib:0.00005065
# epoch 180 loss_pde:0.00234859, loss_ib:0.00005066
# epoch 180 loss_pde:0.00234846, loss_ib:0.00005067
# epoch 180 loss_pde:0.00234835, loss_ib:0.00005068
# epoch 180 loss_pde:0.00234829, loss_ib:0.00005068
# epoch 180: loss 0.002856
# epoch 181 loss_pde:0.00234818, loss_ib:0.00005068
# epoch 181 loss_pde:0.00234820, loss_ib:0.00005068
# epoch 181 loss_pde:0.00234807, loss_ib:0.00005069
# epoch 181 loss_pde:0.00234828, loss_ib:0.00005067
# epoch 181 loss_pde:0.00234825, loss_ib:0.00005066
# epoch 181 loss_pde:0.00234824, loss_ib:0.00005066
# epoch 181 loss_pde:0.00234831, loss_ib:0.00005065
# epoch 181 loss_pde:0.00234840, loss_ib:0.00005064
# epoch 181 loss_pde:0.00234842, loss_ib:0.00005063
# epoch 181 loss_pde:0.00234854, loss_ib:0.00005062
# epoch 181 loss_pde:0.00234846, loss_ib:0.00005062
# epoch 181 loss_pde:0.00234843, loss_ib:0.00005062
# epoch 181 loss_pde:0.00234839, loss_ib:0.00005061
# epoch 181 loss_pde:0.00234844, loss_ib:0.00005060
# epoch 181 loss_pde:0.00234855, loss_ib:0.00005059
# epoch 181 loss_pde:0.00234862, loss_ib:0.00005057
# epoch 181 loss_pde:0.00234886, loss_ib:0.00005055
# epoch 181 loss_pde:0.00234884, loss_ib:0.00005055
# epoch 181 loss_pde:0.00234885, loss_ib:0.00005055
# epoch 181 loss_pde:0.00234880, loss_ib:0.00005055
# epoch 181: loss 0.002855
# epoch 182 loss_pde:0.00234877, loss_ib:0.00005055
# epoch 182 loss_pde:0.00234876, loss_ib:0.00005054
# epoch 182 loss_pde:0.00234874, loss_ib:0.00005054
# epoch 182 loss_pde:0.00234875, loss_ib:0.00005054
# epoch 182 loss_pde:0.00234874, loss_ib:0.00005053
# epoch 182 loss_pde:0.00234880, loss_ib:0.00005052
# epoch 182 loss_pde:0.00234882, loss_ib:0.00005052
# epoch 182 loss_pde:0.00234871, loss_ib:0.00005053
# epoch 182 loss_pde:0.00234866, loss_ib:0.00005053
# epoch 182 loss_pde:0.00234824, loss_ib:0.00005057
# epoch 182 loss_pde:0.00234828, loss_ib:0.00005056
# epoch 182 loss_pde:0.00234832, loss_ib:0.00005056
# epoch 182: loss 0.002854
# epoch 183 loss_pde:0.00234832, loss_ib:0.00005056
# epoch 183 loss_pde:0.00234825, loss_ib:0.00005056
# epoch 183 loss_pde:0.00234813, loss_ib:0.00005057
# epoch 183 loss_pde:0.00234783, loss_ib:0.00005059
# epoch 183 loss_pde:0.00234804, loss_ib:0.00005059
# epoch 183 loss_pde:0.00234769, loss_ib:0.00005060
# epoch 183 loss_pde:0.00234763, loss_ib:0.00005060
# epoch 183 loss_pde:0.00234746, loss_ib:0.00005061
# epoch 183 loss_pde:0.00234732, loss_ib:0.00005062
# epoch 183 loss_pde:0.00234716, loss_ib:0.00005063
# epoch 183 loss_pde:0.00234713, loss_ib:0.00005063
# epoch 183 loss_pde:0.00234701, loss_ib:0.00005064
# epoch 183 loss_pde:0.00234695, loss_ib:0.00005064
# epoch 183 loss_pde:0.00234684, loss_ib:0.00005064
# epoch 183 loss_pde:0.00234678, loss_ib:0.00005065
# epoch 183 loss_pde:0.00234667, loss_ib:0.00005065
# epoch 183 loss_pde:0.00234675, loss_ib:0.00005064
# epoch 183 loss_pde:0.00234729, loss_ib:0.00005059
# epoch 183: loss 0.002854
# epoch 184 loss_pde:0.00234729, loss_ib:0.00005059
# epoch 184 loss_pde:0.00234703, loss_ib:0.00005061
# epoch 184 loss_pde:0.00234702, loss_ib:0.00005061
# epoch 184 loss_pde:0.00234707, loss_ib:0.00005060
# epoch 184 loss_pde:0.00234716, loss_ib:0.00005058
# epoch 184 loss_pde:0.00234723, loss_ib:0.00005058
# epoch 184 loss_pde:0.00234713, loss_ib:0.00005058
# epoch 184 loss_pde:0.00234698, loss_ib:0.00005059
# epoch 184 loss_pde:0.00234680, loss_ib:0.00005061
# epoch 184 loss_pde:0.00234671, loss_ib:0.00005061
# epoch 184 loss_pde:0.00234672, loss_ib:0.00005060
# epoch 184 loss_pde:0.00234677, loss_ib:0.00005060
# epoch 184 loss_pde:0.00234680, loss_ib:0.00005058
# epoch 184 loss_pde:0.00234676, loss_ib:0.00005058
# epoch 184 loss_pde:0.00234669, loss_ib:0.00005059
# epoch 184 loss_pde:0.00234662, loss_ib:0.00005059
# epoch 184 loss_pde:0.00234659, loss_ib:0.00005059
# epoch 184 loss_pde:0.00234658, loss_ib:0.00005059
# epoch 184 loss_pde:0.00234659, loss_ib:0.00005059
# epoch 184 loss_pde:0.00234668, loss_ib:0.00005057
# epoch 184: loss 0.002853
# epoch 185 loss_pde:0.00234676, loss_ib:0.00005056
# epoch 185 loss_pde:0.00234676, loss_ib:0.00005056
# epoch 185 loss_pde:0.00234681, loss_ib:0.00005055
# epoch 185 loss_pde:0.00234674, loss_ib:0.00005055
# epoch 185 loss_pde:0.00234666, loss_ib:0.00005055
# epoch 185 loss_pde:0.00234657, loss_ib:0.00005056
# epoch 185 loss_pde:0.00234650, loss_ib:0.00005056
# epoch 185 loss_pde:0.00234645, loss_ib:0.00005056
# epoch 185 loss_pde:0.00234647, loss_ib:0.00005056
# epoch 185 loss_pde:0.00234652, loss_ib:0.00005055
# epoch 185 loss_pde:0.00234658, loss_ib:0.00005054
# epoch 185 loss_pde:0.00234659, loss_ib:0.00005053
# epoch 185 loss_pde:0.00234664, loss_ib:0.00005052
# epoch 185 loss_pde:0.00234649, loss_ib:0.00005053
# epoch 185 loss_pde:0.00234641, loss_ib:0.00005053
# epoch 185 loss_pde:0.00234632, loss_ib:0.00005054
# epoch 185 loss_pde:0.00234623, loss_ib:0.00005054
# epoch 185 loss_pde:0.00234618, loss_ib:0.00005054
# epoch 185 loss_pde:0.00234618, loss_ib:0.00005053
# epoch 185 loss_pde:0.00234620, loss_ib:0.00005053
# epoch 185: loss 0.002852
# epoch 186 loss_pde:0.00234623, loss_ib:0.00005052
# epoch 186 loss_pde:0.00234620, loss_ib:0.00005052
# epoch 186 loss_pde:0.00234615, loss_ib:0.00005052
# epoch 186 loss_pde:0.00234613, loss_ib:0.00005052
# epoch 186 loss_pde:0.00234617, loss_ib:0.00005051
# epoch 186 loss_pde:0.00234607, loss_ib:0.00005051
# epoch 186 loss_pde:0.00234643, loss_ib:0.00005049
# epoch 186 loss_pde:0.00234612, loss_ib:0.00005050
# epoch 186 loss_pde:0.00234600, loss_ib:0.00005051
# epoch 186 loss_pde:0.00234576, loss_ib:0.00005053
# epoch 186 loss_pde:0.00234556, loss_ib:0.00005054
# epoch 186 loss_pde:0.00234541, loss_ib:0.00005056
# epoch 186 loss_pde:0.00234532, loss_ib:0.00005056
# epoch 186 loss_pde:0.00234545, loss_ib:0.00005054
# epoch 186 loss_pde:0.00234552, loss_ib:0.00005053
# epoch 186 loss_pde:0.00234561, loss_ib:0.00005052
# epoch 186 loss_pde:0.00234573, loss_ib:0.00005050
# epoch 186 loss_pde:0.00234579, loss_ib:0.00005049
# epoch 186 loss_pde:0.00234585, loss_ib:0.00005048
# epoch 186 loss_pde:0.00234581, loss_ib:0.00005047
# epoch 186: loss 0.002851
# epoch 187 loss_pde:0.00234584, loss_ib:0.00005046
# epoch 187 loss_pde:0.00234490, loss_ib:0.00005064
# epoch 187 loss_pde:0.00234536, loss_ib:0.00005050
# epoch 187 loss_pde:0.00234550, loss_ib:0.00005049
# epoch 187 loss_pde:0.00234540, loss_ib:0.00005049
# epoch 187 loss_pde:0.00234532, loss_ib:0.00005050
# epoch 187 loss_pde:0.00234514, loss_ib:0.00005051
# epoch 187 loss_pde:0.00234502, loss_ib:0.00005052
# epoch 187 loss_pde:0.00234477, loss_ib:0.00005054
# epoch 187 loss_pde:0.00234474, loss_ib:0.00005054
# epoch 187 loss_pde:0.00234473, loss_ib:0.00005053
# epoch 187 loss_pde:0.00234488, loss_ib:0.00005052
# epoch 187 loss_pde:0.00234479, loss_ib:0.00005052
# epoch 187 loss_pde:0.00234468, loss_ib:0.00005053
# epoch 187 loss_pde:0.00234457, loss_ib:0.00005053
# epoch 187 loss_pde:0.00234452, loss_ib:0.00005054
# epoch 187 loss_pde:0.00234448, loss_ib:0.00005053
# epoch 187 loss_pde:0.00234454, loss_ib:0.00005053
# epoch 187 loss_pde:0.00234456, loss_ib:0.00005052
# epoch 187 loss_pde:0.00234463, loss_ib:0.00005051
# epoch 187: loss 0.002850
# epoch 188 loss_pde:0.00234453, loss_ib:0.00005051
# epoch 188 loss_pde:0.00234450, loss_ib:0.00005051
# epoch 188 loss_pde:0.00234446, loss_ib:0.00005051
# epoch 188 loss_pde:0.00234434, loss_ib:0.00005052
# epoch 188 loss_pde:0.00234432, loss_ib:0.00005052
# epoch 188 loss_pde:0.00234426, loss_ib:0.00005052
# epoch 188 loss_pde:0.00234432, loss_ib:0.00005051
# epoch 188 loss_pde:0.00234430, loss_ib:0.00005051
# epoch 188 loss_pde:0.00234430, loss_ib:0.00005051
# epoch 188 loss_pde:0.00234428, loss_ib:0.00005050
# epoch 188 loss_pde:0.00234420, loss_ib:0.00005051
# epoch 188 loss_pde:0.00234407, loss_ib:0.00005051
# epoch 188 loss_pde:0.00234394, loss_ib:0.00005052
# epoch 188 loss_pde:0.00234373, loss_ib:0.00005053
# epoch 188 loss_pde:0.00234363, loss_ib:0.00005054
# epoch 188 loss_pde:0.00234333, loss_ib:0.00005057
# epoch 188 loss_pde:0.00234324, loss_ib:0.00005057
# epoch 188 loss_pde:0.00234327, loss_ib:0.00005056
# epoch 188 loss_pde:0.00234334, loss_ib:0.00005055
# epoch 188 loss_pde:0.00234343, loss_ib:0.00005054
# epoch 188: loss 0.002850
# epoch 189 loss_pde:0.00234349, loss_ib:0.00005053
# epoch 189 loss_pde:0.00234358, loss_ib:0.00005052
# epoch 189 loss_pde:0.00234360, loss_ib:0.00005052
# epoch 189 loss_pde:0.00234359, loss_ib:0.00005051
# epoch 189 loss_pde:0.00234360, loss_ib:0.00005051
# epoch 189 loss_pde:0.00234358, loss_ib:0.00005050
# epoch 189 loss_pde:0.00234359, loss_ib:0.00005050
# epoch 189 loss_pde:0.00234359, loss_ib:0.00005049
# epoch 189 loss_pde:0.00234356, loss_ib:0.00005049
# epoch 189 loss_pde:0.00234333, loss_ib:0.00005050
# epoch 189 loss_pde:0.00234332, loss_ib:0.00005049
# epoch 189 loss_pde:0.00234336, loss_ib:0.00005049
# epoch 189 loss_pde:0.00234330, loss_ib:0.00005049
# epoch 189 loss_pde:0.00234323, loss_ib:0.00005049
# epoch 189 loss_pde:0.00234316, loss_ib:0.00005049
# epoch 189 loss_pde:0.00234307, loss_ib:0.00005050
# epoch 189 loss_pde:0.00234305, loss_ib:0.00005050
# epoch 189 loss_pde:0.00234305, loss_ib:0.00005049
# epoch 189 loss_pde:0.00234310, loss_ib:0.00005049
# epoch 189 loss_pde:0.00234309, loss_ib:0.00005048
# epoch 189: loss 0.002849
# epoch 190 loss_pde:0.00234313, loss_ib:0.00005047
# epoch 190 loss_pde:0.00234318, loss_ib:0.00005047
# epoch 190 loss_pde:0.00234318, loss_ib:0.00005046
# epoch 190 loss_pde:0.00234324, loss_ib:0.00005046
# epoch 190: loss 0.002848
# epoch 191 loss_pde:0.00234324, loss_ib:0.00005046
# epoch 191 loss_pde:0.00234317, loss_ib:0.00005046
# epoch 191 loss_pde:0.00234299, loss_ib:0.00005047
# epoch 191 loss_pde:0.00234292, loss_ib:0.00005047
# epoch 191 loss_pde:0.00234274, loss_ib:0.00005048
# epoch 191 loss_pde:0.00234264, loss_ib:0.00005049
# epoch 191 loss_pde:0.00234264, loss_ib:0.00005049
# epoch 191 loss_pde:0.00234262, loss_ib:0.00005049
# epoch 191 loss_pde:0.00234264, loss_ib:0.00005049
# epoch 191 loss_pde:0.00234264, loss_ib:0.00005048
# epoch 191 loss_pde:0.00234286, loss_ib:0.00005045
# epoch 191 loss_pde:0.00234302, loss_ib:0.00005043
# epoch 191 loss_pde:0.00234303, loss_ib:0.00005043
# epoch 191 loss_pde:0.00234289, loss_ib:0.00005044
# epoch 191 loss_pde:0.00234259, loss_ib:0.00005046
# epoch 191 loss_pde:0.00234233, loss_ib:0.00005048
# epoch 191 loss_pde:0.00234209, loss_ib:0.00005050
# epoch 191 loss_pde:0.00234199, loss_ib:0.00005051
# epoch 191 loss_pde:0.00234212, loss_ib:0.00005049
# epoch 191: loss 0.002848
# epoch 192 loss_pde:0.00234212, loss_ib:0.00005049
# epoch 192 loss_pde:0.00234233, loss_ib:0.00005047
# epoch 192 loss_pde:0.00234220, loss_ib:0.00005048
# epoch 192 loss_pde:0.00234208, loss_ib:0.00005048
# epoch 192 loss_pde:0.00234186, loss_ib:0.00005049
# epoch 192 loss_pde:0.00234175, loss_ib:0.00005050
# epoch 192 loss_pde:0.00234155, loss_ib:0.00005052
# epoch 192 loss_pde:0.00234149, loss_ib:0.00005052
# epoch 192 loss_pde:0.00234138, loss_ib:0.00005052
# epoch 192 loss_pde:0.00234137, loss_ib:0.00005051
# epoch 192 loss_pde:0.00234131, loss_ib:0.00005051
# epoch 192 loss_pde:0.00234145, loss_ib:0.00005049
# epoch 192 loss_pde:0.00234134, loss_ib:0.00005049
# epoch 192 loss_pde:0.00234117, loss_ib:0.00005051
# epoch 192 loss_pde:0.00234097, loss_ib:0.00005052
# epoch 192 loss_pde:0.00234072, loss_ib:0.00005056
# epoch 192 loss_pde:0.00234072, loss_ib:0.00005054
# epoch 192 loss_pde:0.00234073, loss_ib:0.00005054
# epoch 192 loss_pde:0.00234071, loss_ib:0.00005054
# epoch 192 loss_pde:0.00234071, loss_ib:0.00005053
# epoch 192: loss 0.002847
# epoch 193 loss_pde:0.00234072, loss_ib:0.00005053
# epoch 193 loss_pde:0.00234071, loss_ib:0.00005053
# epoch 193 loss_pde:0.00234072, loss_ib:0.00005052
# epoch 193 loss_pde:0.00234076, loss_ib:0.00005051
# epoch 193 loss_pde:0.00234072, loss_ib:0.00005051
# epoch 193 loss_pde:0.00234069, loss_ib:0.00005051
# epoch 193 loss_pde:0.00234062, loss_ib:0.00005051
# epoch 193 loss_pde:0.00234059, loss_ib:0.00005051
# epoch 193 loss_pde:0.00234027, loss_ib:0.00005054
# epoch 193 loss_pde:0.00234036, loss_ib:0.00005052
# epoch 193 loss_pde:0.00234034, loss_ib:0.00005051
# epoch 193 loss_pde:0.00234031, loss_ib:0.00005051
# epoch 193 loss_pde:0.00234028, loss_ib:0.00005050
# epoch 193 loss_pde:0.00234019, loss_ib:0.00005050
# epoch 193 loss_pde:0.00234023, loss_ib:0.00005053
# epoch 193 loss_pde:0.00233966, loss_ib:0.00005055
# epoch 193 loss_pde:0.00233985, loss_ib:0.00005052
# epoch 193 loss_pde:0.00233984, loss_ib:0.00005052
# epoch 193 loss_pde:0.00233969, loss_ib:0.00005053
# epoch 193 loss_pde:0.00233960, loss_ib:0.00005053
# epoch 193: loss 0.002846
# epoch 194 loss_pde:0.00233953, loss_ib:0.00005053
# epoch 194 loss_pde:0.00233941, loss_ib:0.00005054
# epoch 194 loss_pde:0.00233951, loss_ib:0.00005052
# epoch 194 loss_pde:0.00233953, loss_ib:0.00005052
# epoch 194 loss_pde:0.00233958, loss_ib:0.00005051
# epoch 194 loss_pde:0.00233942, loss_ib:0.00005052
# epoch 194 loss_pde:0.00233937, loss_ib:0.00005051
# epoch 194 loss_pde:0.00233927, loss_ib:0.00005051
# epoch 194 loss_pde:0.00233891, loss_ib:0.00005055
# epoch 194 loss_pde:0.00233883, loss_ib:0.00005055
# epoch 194 loss_pde:0.00233898, loss_ib:0.00005052
# epoch 194 loss_pde:0.00233901, loss_ib:0.00005051
# epoch 194 loss_pde:0.00233904, loss_ib:0.00005050
# epoch 194 loss_pde:0.00233896, loss_ib:0.00005051
# epoch 194 loss_pde:0.00233868, loss_ib:0.00005053
# epoch 194 loss_pde:0.00233829, loss_ib:0.00005056
# epoch 194 loss_pde:0.00233781, loss_ib:0.00005060
# epoch 194 loss_pde:0.00233743, loss_ib:0.00005064
# epoch 194 loss_pde:0.00233728, loss_ib:0.00005065
# epoch 194 loss_pde:0.00233723, loss_ib:0.00005065
# epoch 194: loss 0.002845
# epoch 195 loss_pde:0.00233718, loss_ib:0.00005065
# epoch 195 loss_pde:0.00233717, loss_ib:0.00005064
# epoch 195 loss_pde:0.00233713, loss_ib:0.00005064
# epoch 195 loss_pde:0.00233703, loss_ib:0.00005064
# epoch 195 loss_pde:0.00233706, loss_ib:0.00005063
# epoch 195 loss_pde:0.00233717, loss_ib:0.00005062
# epoch 195 loss_pde:0.00233722, loss_ib:0.00005061
# epoch 195 loss_pde:0.00233731, loss_ib:0.00005059
# epoch 195 loss_pde:0.00233733, loss_ib:0.00005059
# epoch 195 loss_pde:0.00233735, loss_ib:0.00005058
# epoch 195 loss_pde:0.00233737, loss_ib:0.00005058
# epoch 195 loss_pde:0.00233741, loss_ib:0.00005057
# epoch 195 loss_pde:0.00233743, loss_ib:0.00005056
# epoch 195 loss_pde:0.00233748, loss_ib:0.00005055
# epoch 195 loss_pde:0.00233753, loss_ib:0.00005054
# epoch 195 loss_pde:0.00233765, loss_ib:0.00005053
# epoch 195 loss_pde:0.00233760, loss_ib:0.00005053
# epoch 195 loss_pde:0.00233761, loss_ib:0.00005053
# epoch 195 loss_pde:0.00233734, loss_ib:0.00005055

# %%
model_path = 'backcorner.pth'
torch.save(model.to('cpu'), model_path)

# %%
device1 = torch.device("cpu")
#model.load_state_dict(torch.load(PATH))
#torch.save(model,'2DRiemanncase8.pt')
#model = torch.save('backcorner.pt')

# %%
#model = model.load_state_dict(torch.load( 'backcorner.pt'))
model = model.to(device)

# %%
model_path = 'backcorner.pth'
model = torch.load(model_path, map_location=torch.device('cpu'))
model = model.to(device)

# %%
# Evaluate on the whole computational domain
for i in range(50):
#u = to_numpy(model(x_test))
#x = to_numpy(x_test)
    x = np.linspace(0.0, 1.0, 401)                                   # Partitioned spatial axis
    y = np.linspace(0.0, 1.0, 400)                                   # Partitioned spatial axis
    t = np.linspace(0.20, 0.20, 1)                                        # Partitioned time axis
    t_grid, x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
    T = t_grid.flatten()[:, None]                                        # Vectorized t_grid
    X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
    Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
    x_test = np.hstack((T, X, Y))                                            # Vectorized whole domain
    x_test = torch.tensor(x_test, dtype=torch.float32).to(device1)
    u = to_numpy(model(x_test))
    #Xp,Yp = meshgrid(x,y)
    
    ue = np.zeros((401,400))
    for i in range(0,401):
        for j in range(0,400):
            ue[i,j] = u[j*400+i,3]
            
    plt.figure()
    plt.contourf(x_grid[:,0,:],y_grid[:,0,:],ue,50)
    #plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.scatter(x_int_train[:,1],)
    #plt.pcolor(x[:],u[:,1])
    #plt.pcolor(x[:],u[:,2])
    ax = plt.gca()
    ax.set_aspect(1)
    plt.savefig("test_rasterization.png", dpi=150)
    plt.show()
 
    #    uo = ue.flatten()[:,None]
    #    uxy= np.hstack((X, Y,uo))                                            # Vectorized whole domain

# %%
#np.savetxt('Riemannv100.txt', uxy)
Nd = 100

t = np.linspace(1.0, 1.0, 1)                                   # Partitioned spatial axis
x = np.linspace(0.0,Lx,Nd)                                   # Partitioned spatial axis
y = np.linspace(0.0,Ly,Nd)                                   # Partitioned spatial axis
t_grid,x_grid,y_grid = np.meshgrid(t,x,y)                                    # (t,x) in [0,0.2]x[a,b]
T = t_grid.flatten()[:, None]                                         # Vectorized x_grid
X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
u = to_numpy(model(x_test))
#Xp,Yp = meshgrid(x,y)


x_test = np.hstack((T,X,Y))                                            # Vectorized whole domain
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,0]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if (x1 < 0.5 and  y1< 1.5):
            ue[i,j] = 2.0
            
uo1 = ue.flatten()[:,None]
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,1]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if (x1 < 0.5 and  y1< 1.5):
            ue[i,j] = 0.0
uo2 = ue.flatten()[:,None]
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,3]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if (x1 < 0.5 and  y1< 1.5):
            ue[i,j] = 0.0
        
uo3 = ue.flatten()[:,None]
ue = np.zeros((Nd,Nd))
for j in range(0,Nd):
    for i in range(0,Nd):
        ue[i,j] = u[i*Nd+j,1]
        x1 = x_test[i*Nd+j,1] 
        y1 = x_test[i*Nd+j,2] 
        if (x1 < 0.5 and  y1< 1.5):
            ue[i,j] = 0.0
uo4 = ue.flatten()[:,None]
uxy= np.hstack((X, Y,uo1,uo2,uo3,uo4))     

#np.savetxt('shockCrho.txt', uxy)# Vectorized whole domain

# %%
plt.figure()
plt.contourf(x_grid[:,0,:],y_grid[:,0,:],ue,50)
#plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.scatter(x_int_train[:,1],)
#plt.pcolor(x[:],u[:,1])
#plt.pcolor(x[:],u[:,2])
ax = plt.gca()
ax.set_aspect(1)
plt.show()
plt.savefig("Riemann2.pdf", dpi=150)

# %%
        #fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#surf = ax.plot_surface(x_grid[:,0,:], y_grid[:,0,:], ue, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)
#
## Customize the z axis.
#ax.set_zlim(0, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
## A StrMethodFormatter is used automatically
#ax.zaxis.set_major_formatter('{x:.02f}')
#
## Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)
#plt.show()

# %%
xlimits = np.array([[0.,Tend],[0.0, 3], [0.0,3]])  #interal
sampling = LHS(xlimits=xlimits)
x_int_train = sampling(num_int)
A = []
for i in range(num_int):
    x = x_int_train[i,1]
    y = x_int_train[i,2]
    if (x< 0.5 and y< 1.5):
        A.append(i)
x_int_train = np.delete(x_int_train,A,axis=0)

# %%
plt.figure()
plt.scatter(x_int_train[1:1000,1],x_int_train[1:1000,2])
#plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.scatter(x_int_train[:,1],)
#plt.pcolor(x[:],u[:,1])
#plt.pcolor(x[:],u[:,2])
ax = plt.gca()
ax.set_aspect(1)
plt.show()

# %%
torch.save(model,'2DRiemanncase8.pt')

# %%
model

# %%
#device1 = torch.device("cpu")
#model.load_state_dict(torch.load(PATH))
#model = model.to(device1)
#torch.save(model,'2DRiemanncase8.pt')
model = torch.load('2DRiemanncase8.pt')

# %%
model
