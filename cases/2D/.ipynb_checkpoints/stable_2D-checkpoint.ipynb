# %%
import torch
import torch.nn as nn
import numpy as np
import time
import scipy.io
import matplotlib.pyplot as plt
from numpy import arange, meshgrid
#
from smt.sampling_methods import LHS
# Seeds
torch.manual_seed(123)
np.random.seed(123)
def train(epoch):
    model.train()
    def closure():
        optimizer.zero_grad()                                                     # Optimizer
      #  loss_bdR = model.bd_OX(x_bcR_train) 
        loss_pde = model.loss_pde(x_int_train)                                    # Loss function of PDE
        loss_bdL = model.loss_bc(x_bcL_train, rho_bcL_train,u_bcL_train,v_bcL_train,p_bcL_train)   # Loss function of IC
        loss_bdR1 = model.loss_bcR(x_bcR1_train)   # Loss function of IC
        loss_bdR2 = model.loss_bcR(x_bcR2_train)   # Loss function of IC
        loss_cut = model.loss_bc1(x_cut_train, rho_cut_train,u_cut_train,v_cut_train,p_cut_train)   # Loss function of IC
      #  loss_bdD = model.loss_bcOY(x_bcD_train) 
      #  loss_bdU = model.loss_bcOY(x_bcU_train) 
        loss_bdI = model.bd_B(x_bcI_train, sin_bcI_train,cos_bcI_train)  
        loss_bd = 10*(loss_bdL + loss_bdI + loss_bdR1 + loss_bdR2)# + loss_bdL +loss_bdU + loss_bdD)
        #loss_bd = 10*(loss_bdL)# + loss_bdL +loss_bdU + loss_bdD)
        loss = loss_pde + loss_bd# + loss_bdR + loss_bdD +loss_bdI)                                         # Total loss function G(theta)
        #loss = loss_pde + 10*(loss_bdL)                                         # Total loss function G(theta)

        # Print iteration, loss of PDE and ICs
        print(f'epoch {epoch} loss_pde:{loss_pde:.8f}, loss_bd:{loss_bd:.8f}')
        loss.backward()
        return loss

    # Optimize loss function
    loss = optimizer.step(closure)
    loss_value = loss.item() if not isinstance(loss, float) else loss
    # Print total loss
    print(f'epoch {epoch}: loss {loss_value:.6f}')
    
# Calculate gradients using torch.autograd.grad
def gradients(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,grad_outputs=torch.ones_like(outputs), create_graph=True)

# Convert torch tensor into np.array
def to_numpy(input):
    if isinstance(input, torch.Tensor):
        return input.detach().cpu().numpy()
    elif isinstance(input, np.ndarray):
        return input
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or ' \
                        'np.ndarray, but got {}'.format(type(input)))

# Initial conditions
def BC_L(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    ms = 3.0
    #rho1 = 4.2
    #p1 = 3.0
    #v1 = 0.0
    #u1 = 2.0 #ms*np.sqrt(gamma)
    rho1 = 1.0
    p1 = 0.71429
    v1 = 0.0
    #u1 = ms*npsqrt(gamma)
    u1 = 5.5 
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] = u1
        v_init[i] = v1
        p_init[i] = p1

    return rho_init, u_init, v_init,p_init
def BC_R(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    ms = 3.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = rho1
        u_init[i] = u1
        v_init[i] = v1
        p_init[i] = p1

    return rho_init, u_init, v_init,p_init
def BC_Cut(x):
    N =x.shape[0]
    rho_init = np.zeros((x.shape[0]))                                              # rho - initial condition
    u_init = np.zeros((x.shape[0]))                                                # u - initial condition
    v_init = np.zeros((x.shape[0]))                                                # u - initial condition
    p_init = np.zeros((x.shape[0]))                                                # p - initial condition
    
    gamma = 1.4
    ms = 3.0
    rho1 = 1.0
    p1 = 1.0
    v1 = 0.0
    u1 = 0
    # rho, p - initial condition
    for i in range(N):
        rho_init[i] = 10.01
        u_init[i] =  0
        v_init[i] = 0
        p_init[i] = 10.01

    return rho_init, u_init, v_init,p_init
 
    
class DNN(nn.Module):

    def __init__(self):
        super(DNN, self).__init__()
        self.net = nn.Sequential()                                                  # Define neural network
        self.net.add_module('Linear_layer_1', nn.Linear(2, 90))                     # First linear layer
        self.net.add_module('Tanh_layer_1', nn.Tanh())                              # First activation Layer

        for num in range(2, 7):                                                     # Number of layers (2 through 7)
            self.net.add_module('Linear_layer_%d' % (num), nn.Linear(90, 90))       # Linear layer
            self.net.add_module('Tanh_layer_%d' % (num), nn.Tanh())                 # Activation Layer
        self.net.add_module('Linear_layer_final', nn.Linear(90, 4))                 # Output Layer

    # Forward Feed
    def forward(self, x):
        return self.net(x)

    def bd_B(self,x,sin,cos):
        yb = self.net(x)
        rhob,pb,ub,vb = yb[:, 0:1], yb[:, 1:2], yb[:, 2:3],yb[:,3:]
        drhob_g = gradients(rhob, x)[0]                                      # Gradient [u_t, u_x]
        rhob_x, rhob_y = drhob_g[:, :1], drhob_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dub_g = gradients(ub, x)[0]                                      # Gradient [u_t, u_x]
        ub_x, ub_y = dub_g[:, :1], dub_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dvb_g = gradients(vb, x)[0]                                      # Gradient [u_t, u_x]
        vb_x, vb_y = dvb_g[:, :1], dvb_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dpb_g = gradients(pb, x)[0]                                      # Gradient [p_t, p_x]
        pb_x, pb_y = dpb_g[:, :1], dpb_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = ub_x + vb_y
        #lam = 0.1*(abs(deltau) - deltau) + 1
        #lam = (deltau) - deltau) + 1
        
        fb = (((ub*cos + vb*sin))**2).mean() #+\
            #(((pb_x*cos + pb_y*sin))**2).mean() +\
            #(((rhob_x*cos + rhob_y*sin))**2).mean()
        return fb
    def bd_OY(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        
        f = ((( u_y)/lam)**2).mean() +\
            ((( v_y)/lam)**2).mean() +\
            ((( p_y)/lam)**2).mean() +\
            ((( rho_y)/lam)**2).mean()
        return f
    
    def bd_OX(self,x):
        y = self.net(x)
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        drho_g = gradients(rho, x)[0]                                  # Gradient [rho_t, rho_x]
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]                    # Partial derivatives rho_t, rho_x
        du_g = gradients(u, x)[0]                                      # Gradient [u_t, u_x]
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dv_g = gradients(v, x)[0]                                      # Gradient [u_t, u_x]
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]                            # Partial derivatives u_t, u_x
        dp_g = gradients(p, x)[0]                                      # Gradient [p_t, p_x]
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]                            # Partial derivatives p_t, p_x
        
        deltau = u_x + v_y
        lam = 0.01*(abs(deltau) - deltau) + 1
        
        f = ((( u_x)/lam)**2).mean() +\
            ((( v_x)/lam)**2).mean() +\
            ((( p_x)/lam)**2).mean() +\
            ((( rho_x)/lam)**2).mean()
        return f
        
    # Loss function for PDE
    def loss_pde(self, x):
        y = self.net(x)                                                # Neural network
        rho,p,u,v = y[:, 0:1], y[:, 1:2], y[:, 2:3],y[:,3:]
        
        gamma = 1.4                                                    # Heat Capacity Ratio

        eps = 1e-8
        
        yL = self.net(x_intL_train)
        yR = self.net(x_intR_train)
        yU = self.net(x_intU_train)
        yD = self.net(x_intD_train)
        rhoL,pL,uL,vL = yL[:, 0:1], yL[:, 1:2], yL[:, 2:3],yL[:,3:]
        rhoR,pR,uR,vR = yR[:, 0:1], yR[:, 1:2], yR[:, 2:3],yR[:,3:]
        rhoU,pU,uU,vU = yU[:, 0:1], yU[:, 1:2], yU[:, 2:3],yU[:,3:]
        rhoD,pD,uD,vD = yD[:, 0:1], yD[:, 1:2], yD[:, 2:3],yD[:,3:]
        
        E = p/rho/0.4 + 0.5*(u**2+v**2)
        EL = pL/rhoL/0.4 + 0.5*(uL**2+vL**2)
        ER = pR/rhoR/0.4 + 0.5*(uR**2+vR**2)
        EU = pU/rhoU/0.4 + 0.5*(uU**2+vU**2)
        ED = pD/rhoD/0.4 + 0.5*(uD**2+vD**2)
        cL = torch.sqrt(1.4*abs(pL)/(abs(rhoL)+eps))
        cR = torch.sqrt(1.4*abs(pR)/(abs(rhoR)+eps))
        c = torch.sqrt(1.4*abs(p)/(abs(rho)+eps))
        
        smax = torch.max(cL+uL,cR+uR)
        smin = torch.min(-cL+uL,-cR+uR)
 
        # Gradients and partial derivatives
        drho_g = gradients(rho, x)[0]                            
        rho_x,rho_y = drho_g[:, :1], drho_g[:, 1:2]
        du_g = gradients(u, x)[0]                                
        u_x, u_y = du_g[:, :1], du_g[:, 1:2]         
        dv_g = gradients(v, x)[0]                    
        v_x, v_y = dv_g[:, :1], dv_g[:, 1:2]         
        dp_g = gradients(p, x)[0]                    
        p_x, p_y = dp_g[:, :1], dp_g[:, 1:2]         
        
       # du_gg = gradients(u_x, x)[0]                                      # Gradient [u_t, u_x]
       # u_xx, u_xy = du_gg[:, :1], du_gg[:, 1:2]                            # Partial derivatives u_t, u_x
       # 
       # dv_gg = gradients(v_y, x)[0]                                      # Gradient [u_t, u_x]
       # v_yx, v_yy = dv_gg[:, :1], dv_gg[:, 1:2]                            # Partial derivatives u_t, u_x
 
        s1 = (u-uL)**2 *rho*rhoL - (p-pL)*(rho - rhoL)
        s2 = (E-EL) *(u-uL)*rho*rhoL - (p*u-pL*uL)*(rho - rhoL)
        s3 = (v-vD)**2 *rho*rhoD - (p-pD)*(rho - rhoD)
        s4 = (E-ED)*(v-vD)*rho*rhoD - (p*v-pD*vD)*(rho -rhoD)
        s5 = (u-uR)**2 *rho*rhoR - (p-pR)*(rho - rhoR)
        s6 = (E-ER) *(u-uR)*rho*rhoR - (p*u-pR*uR)*(rho - rhoR)
        s7 = (v-vU)**2 *rho*rhoU - (p-pU)*(rho - rhoU)
        s8 = (E-EU)*(v-vU)*rho*rhoU - (p*v-pU*vU)*(rho -rhoU)
        
        deltau = u_x + v_y
        lam = 0.1*(abs(deltau) - deltau) + 1
        lam =  1

      #  vis = -0.1*(u_xx + v_yy)
        f = (((rho*deltau+u*rho_x + v*rho_y)/lam)**2).mean() +\
            (((rho*u*u_x+rho*v*u_y+p_x )/lam)**2).mean() +\
            (((rho*u*v_x+rho*v*v_y+p_y )/lam)**2).mean() +\
            (((u*p_x+v*p_y+1.4*p*deltau )/lam)**2).mean() +\
            10*((abs(rho-1) - (rho-1))**2).mean()   + \
            10*((abs(p-0.7) - (p-0.7))**2).mean() 
            #((abs(smax-u-c) -(smax - u-c))**2).mean() +\
            #((abs(smin-u+c)+(smin-u+c))**2).mean() 
         #   10*(s1**2).mean() +\
         #   10*(s2**2).mean() +\
         #   10*(s3**2).mean() +\
         #   10*(s4**2).mean() +\
         #   10*(s5**2).mean() +\
         #   10*(s6**2).mean() +\
         #   10*(s7**2).mean() +\
         #   10*(s8**2).mean() +\
           # 0.1*((abs(eta_t+phi_x)+eta_t+phi_x)).mean()   + \
           # (abs(rho_t)).mean() + (abs(U3_t)).mean() # 
        return f

    # Loss function for initial condition
    def loss_bc(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((u_ic_nn - u_ic) ** 2).mean() + \
               ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() +\
               ((v_ic_nn - v_ic) ** 2).mean()

        return loss_ics
    def loss_bcR(self,x):
        U = self.net(x)                                                      # Initial condition
        rho, p,u,v = U[:, 0], U[:, 1], U[:, 2],U[:,3]            # rho, u, p - initial condition
        E = p/0.4 + 0.5*rho*(u**2 + v**2)

        E0 = 0.71429/0.4 + 0.5*(5.5**2)
        # Loss function for the initial condition
        loss_ics = abs((rho*u*0.8 - 5.5).mean()) + \
                   abs((E*u*0.8 - E0*5.5).mean())
               

        return loss_ics
    def loss_bc1(self, x_ic, rho_ic, u_ic, v_ic,p_ic):
        U_ic = self.net(x_ic)                                                      # Initial condition
        rho_ic_nn, p_ic_nn,u_ic_nn,v_ic_nn = U_ic[:, 0], U_ic[:, 1], U_ic[:, 2],U_ic[:,3]            # rho, u, p - initial condition

        # Loss function for the initial condition
        loss_ics = ((rho_ic_nn- rho_ic) ** 2).mean()  + \
               ((p_ic_nn - p_ic) ** 2).mean() 

        return loss_ics
    
# Solve Euler equations using PINNs
# def main():
  # Initialization
def BD_circle(xc,yc,r,n):
    x = np.zeros((n,2)) 
    sin = np.zeros((n,1)) 
    cos = np.zeros((n,1)) 
    dth = np.pi/n
    for i in range(n):
        the = dth*i
        xd = np.cos(the + np.pi/2)
        yd = np.sin(the + np.pi/2)
    
        x[i,0] = xc  + xd*r
        x[i,1] = yc + yd*r
        cos[i,0] = xd 
        sin[i,0] = yd

        #cos[i,0] = 1
        #sin[i,0] = 0
    return x, sin,cos
def BD_front(n1,n2):
    x = np.zeros((n1+n2,2)) 
    for i in range(n1):
        x[i,0] = 1.0
        x[i,1] = i*(0.2/n1)
    for i in range(n1,n2):
        x[i,0] = 1.0 + (3.0/n1)
        x[i,1] = 0.2
    return x
def Pertur(x, dx):
    N =x.shape[0]
    xL = np.zeros((N,2))
    xR = np.zeros((N,2))
    xU = np.zeros((N,2))
    xD = np.zeros((N,2))
    
    for i in range(N):
        
        xL[i,0] = x[i,0] - dx
        xR[i,0] = x[i,0] + dx
        xU[i,0] = x[i,0]
        xD[i,0] = x[i,0]
        
        xL[i,1] = x[i,1] 
        xR[i,1] = x[i,1]
        xU[i,1] = x[i,1] + dx
        xD[i,1] = x[i,1] - dx
        
    return xL,xR,xU,xD
 
device = torch.device('cuda')                                          # Run on CPU
lr = 0.0011                                                           # Learning rate
num_i_train = 2000                                                 # Random sampled points from IC0
num_f_train = 10000                                                # Random sampled points in interior
num_test = 1000                                                 # Random sampled points in interior

#id_ic = np.random.choice(num_x, num_i_train, replace=False)           # Random sample numbering for IC

xlimits = np.array([[0.0, 10.0], [0.0,20.0]])
sampling = LHS(xlimits=xlimits)
x_int_train = sampling(num_f_train)

A = []
for i in range(num_f_train):
    x = x_int_train[i,0]
    y = x_int_train[i,1]
    if ((x-10)**2 + (y-10)**2 ) < 4:
        A.append(i)
x_int_train = np.delete(x_int_train,A,axis=0)

x_cut_train = np.zeros((num_i_train,2))

x_cut_train = np.zeros((num_i_train,2))
for i in range(num_i_train):
    theta = np.random.rand()*np.pi + np.pi/2
    r = np.random.rand()*0.3
    x_cut_train[i,0] = r*np.cos(theta) + 1
    x_cut_train[i,1] = r*np.sin(theta) + 1



xlimits_ic = np.array([[0.0, 0.0], [0.0,20]])
sampling_ic = LHS(xlimits=xlimits_ic)
x_bcL_train =  sampling_ic(num_i_train)                                           # Vectorized whole domain
xlimits_ic = np.array([[10.0, 10.0], [0.0,8]])
sampling_ic = LHS(xlimits=xlimits_ic)
x_bcR1_train =  sampling_ic(num_i_train)                                           # Vectorized whole domain

xlimits_ic = np.array([[10.0, 10.0], [12,20]])
sampling_ic = LHS(xlimits=xlimits_ic)
x_bcR2_train =  sampling_ic(num_i_train)                                           # Vectorized whole domain

xlimits_ic = np.array([[0.0, 10.0], [20.0,20.0]])
sampling_ic = LHS(xlimits=xlimits_ic)
x_bcU_train =  sampling_ic(num_i_train)                                           # Vectorized whole domain
xlimits_ic = np.array([[0.0, 10.0], [0.0,0.0]])
sampling_ic = LHS(xlimits=xlimits_ic)
x_bcD_train =  sampling_ic(num_i_train)                                           # Vectorized whole domain

x_bcI_train,sin_bcI_train,cos_bcI_train = BD_circle(10.0,10.0,2,1000)

x_intL_train,x_intR_train,x_intU_train,x_intD_train = Pertur(x_int_train, 0.01)

rho_bcL_train, u_bcL_train,v_bcL_train, p_bcL_train = BC_L(x_bcL_train)  
rho_bcR_train, u_bcR_train,v_bcR_train, p_bcR_train = BC_L(x_bcR_train)  
rho_cut_train, u_cut_train,v_cut_train, p_cut_train = BC_Cut(x_cut_train)  

xlimits_test = np.array([[0.2, 0.2], [0.0, 1.0],[0.0, 1.0]])
sampling_test = LHS(xlimits=xlimits_test)
x_test =  sampling_test(num_test)                                           # Vectorized whole domain

x_int_train = torch.tensor(x_int_train, requires_grad=True, dtype=torch.float32).to(device)

rho_bcL_train = torch.tensor(rho_bcL_train, dtype=torch.float32).to(device)
u_bcL_train = torch.tensor(u_bcL_train, dtype=torch.float32).to(device)
v_bcL_train = torch.tensor(v_bcL_train, dtype=torch.float32).to(device)
p_bcL_train = torch.tensor(p_bcL_train, dtype=torch.float32).to(device)

rho_bcR_train = torch.tensor(rho_bcR_train, dtype=torch.float32).to(device)
u_bcR_train = torch.tensor(u_bcR_train, dtype=torch.float32).to(device)
v_bcR_train = torch.tensor(v_bcR_train, dtype=torch.float32).to(device)
p_bcR_train = torch.tensor(p_bcR_train, dtype=torch.float32).to(device)

x_bcD_train = torch.tensor(x_bcD_train,requires_grad=True, dtype=torch.float32).to(device)
x_bcU_train = torch.tensor(x_bcU_train, requires_grad=True, dtype=torch.float32).to(device)
x_bcR_train = torch.tensor(x_bcR_train, requires_grad=True, dtype=torch.float32).to(device)
x_bcL_train = torch.tensor(x_bcL_train, dtype=torch.float32).to(device)
x_bcI_train = torch.tensor(x_bcI_train, requires_grad=True, dtype=torch.float32).to(device)
sin_bcI_train = torch.tensor(sin_bcI_train, dtype=torch.float32).to(device)
cos_bcI_train = torch.tensor(cos_bcI_train, dtype=torch.float32).to(device)

rho_cut_train = torch.tensor(rho_cut_train, dtype=torch.float32).to(device)
u_cut_train = torch.tensor(u_cut_train, dtype=torch.float32).to(device)
v_cut_train = torch.tensor(v_cut_train, dtype=torch.float32).to(device)
p_cut_train = torch.tensor(p_cut_train, dtype=torch.float32).to(device)
x_cut_train = torch.tensor(x_cut_train, dtype=torch.float32).to(device)


x_intL_train = torch.tensor(x_intL_train,dtype=torch.float32).to(device)
x_intR_train = torch.tensor(x_intR_train,dtype=torch.float32).to(device)
x_intU_train = torch.tensor(x_intU_train,dtype=torch.float32).to(device)
x_intD_train = torch.tensor(x_intD_train,dtype=torch.float32).to(device)

#rho_ic_train.clone().detach().requires_grad_(True)
#u_ic_train.clone().detach().requires_grad_(True)
# Initialize neural network

# Loss and optimizer
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=5000)
#



print('Start training...')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 2121
# Start training...

# %%
model = DNN().to(device)

# %%
lr = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#optimizer = torch.optim.LBFGS(model.parameters(),lr=lr,max_iter=5000)
epochs = 20000
tic = time.time()
for epoch in range(1, epochs+1):
    train(epoch)
toc = time.time()
print(f'Total training time: {toc - tic}')
# Out:
# epoch 1 loss_pde:1.92911983, loss_bd:4.45376682
# epoch 1: loss 6.382887
# epoch 2 loss_pde:2.46267700, loss_bd:83.17248535
# epoch 2: loss 85.635162
# epoch 3 loss_pde:3.98784137, loss_bd:70.52840424
# epoch 3: loss 74.516243
# epoch 4 loss_pde:4.29707432, loss_bd:31.07258224
# epoch 4: loss 35.369656
# epoch 5 loss_pde:4.00853729, loss_bd:19.38059616
# epoch 5: loss 23.389133
# epoch 6 loss_pde:2.96572447, loss_bd:34.61151505
# epoch 6: loss 37.577240
# epoch 7 loss_pde:2.44012070, loss_bd:30.96942520
# epoch 7: loss 33.409546
# epoch 8 loss_pde:2.19578266, loss_bd:15.83412647
# epoch 8: loss 18.029909
# epoch 9 loss_pde:2.11890030, loss_bd:20.96086311
# epoch 9: loss 23.079763
# epoch 10 loss_pde:2.17123008, loss_bd:28.39330673
# epoch 10: loss 30.564537
# epoch 11 loss_pde:2.21856856, loss_bd:20.79388046
# epoch 11: loss 23.012449
# epoch 12 loss_pde:2.34590220, loss_bd:3.44390988
# epoch 12: loss 5.789812
# epoch 13 loss_pde:2.83208060, loss_bd:23.51093674
# epoch 13: loss 26.343018
# epoch 14 loss_pde:3.49665689, loss_bd:34.65314484
# epoch 14: loss 38.149803
# epoch 15 loss_pde:3.75320959, loss_bd:33.31650543
# epoch 15: loss 37.069714
# epoch 16 loss_pde:3.47355103, loss_bd:21.92176628
# epoch 16: loss 25.395317
# epoch 17 loss_pde:2.98573923, loss_bd:3.09572363
# epoch 17: loss 6.081463
# epoch 18 loss_pde:2.63879824, loss_bd:23.67075729
# epoch 18: loss 26.309555
# epoch 19 loss_pde:2.57142949, loss_bd:35.23297882
# epoch 19: loss 37.804409
# epoch 20 loss_pde:2.79753137, loss_bd:32.23966599
# epoch 20: loss 35.037197
# epoch 21 loss_pde:2.82291913, loss_bd:8.38141823
# epoch 21: loss 11.204337
# epoch 22 loss_pde:2.36370492, loss_bd:50.62165833
# epoch 22: loss 52.985363
# epoch 23 loss_pde:2.41413093, loss_bd:50.68544769
# epoch 23: loss 53.099579
# epoch 24 loss_pde:2.66737390, loss_bd:26.28903961
# epoch 24: loss 28.956413
# epoch 25 loss_pde:3.30919242, loss_bd:7.15857887
# epoch 25: loss 10.467772
# epoch 26 loss_pde:3.52938318, loss_bd:15.67167282
# epoch 26: loss 19.201056
# epoch 27 loss_pde:3.71952009, loss_bd:11.09910107
# epoch 27: loss 14.818621
# epoch 28 loss_pde:4.09806681, loss_bd:4.85277367
# epoch 28: loss 8.950840
# epoch 29 loss_pde:4.32757664, loss_bd:8.19452858
# epoch 29: loss 12.522105
# epoch 30 loss_pde:4.53546762, loss_bd:2.55040288
# epoch 30: loss 7.085871
# epoch 31 loss_pde:4.76276541, loss_bd:12.52553844
# epoch 31: loss 17.288303
# epoch 32 loss_pde:4.77920723, loss_bd:15.55944824
# epoch 32: loss 20.338655
# epoch 33 loss_pde:4.50844526, loss_bd:9.58745003
# epoch 33: loss 14.095896
# epoch 34 loss_pde:4.06409979, loss_bd:5.69605112
# epoch 34: loss 9.760151
# epoch 35 loss_pde:3.72221088, loss_bd:10.02379990
# epoch 35: loss 13.746011
# epoch 36 loss_pde:3.51275873, loss_bd:6.30144835
# epoch 36: loss 9.814207
# epoch 37 loss_pde:3.42575693, loss_bd:6.88176346
# epoch 37: loss 10.307520
# epoch 38 loss_pde:3.29379940, loss_bd:8.78578949
# epoch 38: loss 12.079589
# epoch 39 loss_pde:3.12276793, loss_bd:1.95080972
# epoch 39: loss 5.073578
# epoch 40 loss_pde:2.94205022, loss_bd:14.10764313
# epoch 40: loss 17.049694
# epoch 41 loss_pde:2.84366727, loss_bd:19.04227066
# epoch 41: loss 21.885939
# epoch 42 loss_pde:2.78818512, loss_bd:15.61513519
# epoch 42: loss 18.403320
# epoch 43 loss_pde:2.76607943, loss_bd:4.53632641
# epoch 43: loss 7.302406
# epoch 44 loss_pde:2.78224540, loss_bd:15.51056385
# epoch 44: loss 18.292809
# epoch 45 loss_pde:2.76047945, loss_bd:23.45353699
# epoch 45: loss 26.214016
# epoch 46 loss_pde:2.70653200, loss_bd:21.66781616
# epoch 46: loss 24.374348
# epoch 47 loss_pde:2.62615442, loss_bd:11.30370140
# epoch 47: loss 13.929855
# epoch 48 loss_pde:2.54831576, loss_bd:7.12686825
# epoch 48: loss 9.675184
# epoch 49 loss_pde:2.51895976, loss_bd:14.53596306
# epoch 49: loss 17.054922
# epoch 50 loss_pde:2.48016310, loss_bd:12.72113991
# epoch 50: loss 15.201303
# epoch 51 loss_pde:2.44223237, loss_bd:2.72191381
# epoch 51: loss 5.164146
# epoch 52 loss_pde:2.46388531, loss_bd:15.26677704
# epoch 52: loss 17.730663
# epoch 53 loss_pde:2.48045468, loss_bd:22.37139130
# epoch 53: loss 24.851847
# epoch 54 loss_pde:2.45137477, loss_bd:20.29797745
# epoch 54: loss 22.749352
# epoch 55 loss_pde:2.38413429, loss_bd:10.12438297
# epoch 55: loss 12.508517
# epoch 56 loss_pde:2.32985234, loss_bd:7.65255165
# epoch 56: loss 9.982404
# epoch 57 loss_pde:2.31748962, loss_bd:14.98376942
# epoch 57: loss 17.301258
# epoch 58 loss_pde:2.30156612, loss_bd:13.69663239
# epoch 58: loss 15.998199
# epoch 59 loss_pde:2.29015326, loss_bd:4.76930904
# epoch 59: loss 7.059463
# epoch 60 loss_pde:2.32413507, loss_bd:11.55751133
# epoch 60: loss 13.881646
# epoch 61 loss_pde:2.35788321, loss_bd:17.82559586
# epoch 61: loss 20.183479
# epoch 62 loss_pde:2.35814905, loss_bd:15.41578388
# epoch 62: loss 17.773933
# epoch 63 loss_pde:2.33485818, loss_bd:5.35151005
# epoch 63: loss 7.686368
# epoch 64 loss_pde:2.32631278, loss_bd:11.60661125
# epoch 64: loss 13.932924
# epoch 65 loss_pde:2.34343791, loss_bd:18.91031075
# epoch 65: loss 21.253748
# epoch 66 loss_pde:2.34479284, loss_bd:17.98963547
# epoch 66: loss 20.334429
# epoch 67 loss_pde:2.33300400, loss_bd:9.70765972
# epoch 67: loss 12.040664
# epoch 68 loss_pde:2.34327102, loss_bd:5.58766127
# epoch 68: loss 7.930932
# epoch 69 loss_pde:2.35329318, loss_bd:11.47687721
# epoch 69: loss 13.830171
# epoch 70 loss_pde:2.33746552, loss_bd:9.05679131
# epoch 70: loss 11.394257
# epoch 71 loss_pde:2.30389357, loss_bd:1.22406375
# epoch 71: loss 3.527957
# epoch 72 loss_pde:2.28764820, loss_bd:3.18071628
# epoch 72: loss 5.468365
# epoch 73 loss_pde:2.27899122, loss_bd:2.70993280
# epoch 73: loss 4.988924
# epoch 74 loss_pde:2.25559974, loss_bd:0.33636209
# epoch 74: loss 2.591962
# epoch 75 loss_pde:2.22799039, loss_bd:9.21145248
# epoch 75: loss 11.439443
# epoch 76 loss_pde:2.20375609, loss_bd:9.93607712
# epoch 76: loss 12.139833
# epoch 77 loss_pde:2.17954421, loss_bd:3.20453167
# epoch 77: loss 5.384076
# epoch 78 loss_pde:2.17976952, loss_bd:10.81240177
# epoch 78: loss 12.992171
# epoch 79 loss_pde:2.17346954, loss_bd:15.46804523
# epoch 79: loss 17.641514
# epoch 80 loss_pde:2.14723563, loss_bd:11.86286449
# epoch 80: loss 14.010100
# epoch 81 loss_pde:2.11677241, loss_bd:0.92306364
# epoch 81: loss 3.039836
# epoch 82 loss_pde:2.11555409, loss_bd:16.72852325
# epoch 82: loss 18.844078
# epoch 83 loss_pde:2.12664795, loss_bd:24.77990913
# epoch 83: loss 26.906557
# epoch 84 loss_pde:2.10989261, loss_bd:24.52778053
# epoch 84: loss 26.637672
# epoch 85 loss_pde:2.07645893, loss_bd:16.85293007
# epoch 85: loss 18.929390
# epoch 86 loss_pde:2.06904054, loss_bd:2.63483143
# epoch 86: loss 4.703872
# epoch 87 loss_pde:2.13121390, loss_bd:17.73187637
# epoch 87: loss 19.863091
# epoch 88 loss_pde:2.19452548, loss_bd:27.91479874
# epoch 88: loss 30.109324
# epoch 89 loss_pde:2.22240829, loss_bd:29.01789093
# epoch 89: loss 31.240299
# epoch 90 loss_pde:2.21979904, loss_bd:21.99487305
# epoch 90: loss 24.214672
# epoch 91 loss_pde:2.21983194, loss_bd:8.00201797
# epoch 91: loss 10.221849
# epoch 92 loss_pde:2.28769159, loss_bd:12.18737793
# epoch 92: loss 14.475069
# epoch 93 loss_pde:2.37016845, loss_bd:22.55261612
# epoch 93: loss 24.922785
# epoch 94 loss_pde:2.36423135, loss_bd:24.47543907
# epoch 94: loss 26.839670
# epoch 95 loss_pde:2.27182388, loss_bd:18.84643745
# epoch 95: loss 21.118261
# epoch 96 loss_pde:2.17587805, loss_bd:6.48378325
# epoch 96: loss 8.659661
# epoch 97 loss_pde:2.15358472, loss_bd:12.50236702
# epoch 97: loss 14.655951
# epoch 98 loss_pde:2.16121936, loss_bd:21.90226555
# epoch 98: loss 24.063484
# epoch 99 loss_pde:2.14526033, loss_bd:22.52970123
# epoch 99: loss 24.674961
# epoch 100 loss_pde:2.10538220, loss_bd:15.22351646
# epoch 100: loss 17.328899
# epoch 101 loss_pde:2.07126689, loss_bd:1.62480462
# epoch 101: loss 3.696072
# epoch 102 loss_pde:2.08604693, loss_bd:18.50093651
# epoch 102: loss 20.586983
# epoch 103 loss_pde:2.12565613, loss_bd:28.41436577
# epoch 103: loss 30.540022
# epoch 104 loss_pde:2.12460208, loss_bd:30.01453781
# epoch 104: loss 32.139141
# epoch 105 loss_pde:2.08399343, loss_bd:24.15959549
# epoch 105: loss 26.243589
# epoch 106 loss_pde:2.05358338, loss_bd:11.67262554
# epoch 106: loss 13.726209
# epoch 107 loss_pde:2.08714724, loss_bd:7.30151272
# epoch 107: loss 9.388660
# epoch 108 loss_pde:2.13547039, loss_bd:16.71974564
# epoch 108: loss 18.855217
# epoch 109 loss_pde:2.15381837, loss_bd:17.55007553
# epoch 109: loss 19.703894
# epoch 110 loss_pde:2.13630652, loss_bd:10.63342094
# epoch 110: loss 12.769728
# epoch 111 loss_pde:2.10175848, loss_bd:3.64991236
# epoch 111: loss 5.751671
# epoch 112 loss_pde:2.09792829, loss_bd:9.10813999
# epoch 112: loss 11.206068
# epoch 113 loss_pde:2.10198569, loss_bd:7.00698805
# epoch 113: loss 9.108974
# epoch 114 loss_pde:2.11084223, loss_bd:2.51731277
# epoch 114: loss 4.628155
# epoch 115 loss_pde:2.10150671, loss_bd:3.38463020
# epoch 115: loss 5.486137
# epoch 116 loss_pde:2.08110237, loss_bd:3.54719782
# epoch 116: loss 5.628300
# epoch 117 loss_pde:2.06941414, loss_bd:2.19343066
# epoch 117: loss 4.262845
# epoch 118 loss_pde:2.06446505, loss_bd:6.68628120
# epoch 118: loss 8.750746
# epoch 119 loss_pde:2.05095482, loss_bd:6.95084000
# epoch 119: loss 9.001795
# epoch 120 loss_pde:2.03418183, loss_bd:0.63034105
# epoch 120: loss 2.664523
# epoch 121 loss_pde:2.02531219, loss_bd:0.91710383
# epoch 121: loss 2.942416
# epoch 122 loss_pde:2.01347303, loss_bd:5.65836811
# epoch 122: loss 7.671841
# epoch 123 loss_pde:1.99917614, loss_bd:3.60441399
# epoch 123: loss 5.603590
# epoch 124 loss_pde:1.99304807, loss_bd:6.04741573
# epoch 124: loss 8.040463
# epoch 125 loss_pde:1.98601925, loss_bd:6.89727783
# epoch 125: loss 8.883297
# epoch 126 loss_pde:1.97170866, loss_bd:0.42196333
# epoch 126: loss 2.393672
# epoch 127 loss_pde:1.96851277, loss_bd:0.71977049
# epoch 127: loss 2.688283
# epoch 128 loss_pde:1.95896602, loss_bd:6.53041315
# epoch 128: loss 8.489379
# epoch 129 loss_pde:1.95199406, loss_bd:5.30514431
# epoch 129: loss 7.257138
# epoch 130 loss_pde:1.95531845, loss_bd:3.59488750
# epoch 130: loss 5.550206
# epoch 131 loss_pde:1.95057344, loss_bd:3.77672625
# epoch 131: loss 5.727300
# epoch 132 loss_pde:1.93419480, loss_bd:3.95214915
# epoch 132: loss 5.886344
# epoch 133 loss_pde:1.92804122, loss_bd:3.15034842
# epoch 133: loss 5.078390
# epoch 134 loss_pde:1.93496537, loss_bd:5.40595055
# epoch 134: loss 7.340916
# epoch 135 loss_pde:1.92938399, loss_bd:5.23738384
# epoch 135: loss 7.166768
# epoch 136 loss_pde:1.91268718, loss_bd:2.21055984
# epoch 136: loss 4.123247
# epoch 137 loss_pde:1.90937531, loss_bd:1.05638778
# epoch 137: loss 2.965763
# epoch 138 loss_pde:1.91971016, loss_bd:7.88144302
# epoch 138: loss 9.801153
# epoch 139 loss_pde:1.91987801, loss_bd:7.91597414
# epoch 139: loss 9.835852
# epoch 140 loss_pde:1.91283810, loss_bd:0.20773080
# epoch 140: loss 2.120569
# epoch 141 loss_pde:1.92318761, loss_bd:14.54462814
# epoch 141: loss 16.467815
# epoch 142 loss_pde:1.93611419, loss_bd:19.95297623
# epoch 142: loss 21.889090
# epoch 143 loss_pde:1.92496836, loss_bd:17.24500275
# epoch 143: loss 19.169971
# epoch 144 loss_pde:1.92000222, loss_bd:7.40645123
# epoch 144: loss 9.326453
# epoch 145 loss_pde:1.96847296, loss_bd:9.21781635
# epoch 145: loss 11.186289
# epoch 146 loss_pde:2.01964211, loss_bd:16.33868217
# epoch 146: loss 18.358324
# epoch 147 loss_pde:2.03783059, loss_bd:14.91330910
# epoch 147: loss 16.951139
# epoch 148 loss_pde:2.03262377, loss_bd:5.91916323
# epoch 148: loss 7.951787
# epoch 149 loss_pde:2.04796314, loss_bd:9.80152225
# epoch 149: loss 11.849485
# epoch 150 loss_pde:2.08172369, loss_bd:16.28169060
# epoch 150: loss 18.363415
# epoch 151 loss_pde:2.07790041, loss_bd:14.82190990
# epoch 151: loss 16.899811
# epoch 152 loss_pde:2.04343557, loss_bd:6.21904945
# epoch 152: loss 8.262486
# epoch 153 loss_pde:2.02792788, loss_bd:9.25420856
# epoch 153: loss 11.282137
# epoch 154 loss_pde:2.02405667, loss_bd:15.49564838
# epoch 154: loss 17.519705
# epoch 155 loss_pde:2.00754523, loss_bd:13.43337250
# epoch 155: loss 15.440918
# epoch 156 loss_pde:1.98943591, loss_bd:3.97732735
# epoch 156: loss 5.966763
# epoch 157 loss_pde:2.00595307, loss_bd:12.12311745
# epoch 157: loss 14.129070
# epoch 158 loss_pde:2.02889705, loss_bd:18.97908401
# epoch 158: loss 21.007980
# epoch 159 loss_pde:2.00798678, loss_bd:17.85274696
# epoch 159: loss 19.860733
# epoch 160 loss_pde:1.96880376, loss_bd:9.56467819
# epoch 160: loss 11.533482
# epoch 161 loss_pde:1.97205281, loss_bd:5.58233356
# epoch 161: loss 7.554386
# epoch 162 loss_pde:1.98614836, loss_bd:11.55796432
# epoch 162: loss 13.544113
# epoch 163 loss_pde:1.97367597, loss_bd:9.32068443
# epoch 163: loss 11.294360
# epoch 164 loss_pde:1.94302344, loss_bd:0.86514020
# epoch 164: loss 2.808164
# epoch 165 loss_pde:1.93932188, loss_bd:2.51221514
# epoch 165: loss 4.451537
# epoch 166 loss_pde:1.94731498, loss_bd:3.38540101
# epoch 166: loss 5.332716
# epoch 167 loss_pde:1.93811226, loss_bd:1.00795627
# epoch 167: loss 2.946069
# epoch 168 loss_pde:1.92396855, loss_bd:8.20528126
# epoch 168: loss 10.129250
# epoch 169 loss_pde:1.91290522, loss_bd:8.81007290
# epoch 169: loss 10.722979
# epoch 170 loss_pde:1.90080142, loss_bd:1.99501276
# epoch 170: loss 3.895814
# epoch 171 loss_pde:1.91525126, loss_bd:12.00585747
# epoch 171: loss 13.921108
# epoch 172 loss_pde:1.92626214, loss_bd:16.73779106
# epoch 172: loss 18.664053
# epoch 173 loss_pde:1.91904414, loss_bd:13.23211575
# epoch 173: loss 15.151160
# epoch 174 loss_pde:1.90794861, loss_bd:2.45333076
# epoch 174: loss 4.361279
# epoch 175 loss_pde:1.93083394, loss_bd:14.88276005
# epoch 175: loss 16.813595
# epoch 176 loss_pde:1.96552563, loss_bd:22.74070930
# epoch 176: loss 24.706234
# epoch 177 loss_pde:1.95728064, loss_bd:22.31609344
# epoch 177: loss 24.273375
# epoch 178 loss_pde:1.93345356, loss_bd:14.60632706
# epoch 178: loss 16.539780
# epoch 179 loss_pde:1.95625353, loss_bd:0.59360671
# epoch 179: loss 2.549860
# epoch 180 loss_pde:2.06374788, loss_bd:19.48295784
# epoch 180: loss 21.546705
# epoch 181 loss_pde:2.14413023, loss_bd:29.46504784
# epoch 181: loss 31.609179
# epoch 182 loss_pde:2.16415262, loss_bd:30.41519547
# epoch 182: loss 32.579350
# epoch 183 loss_pde:2.15510845, loss_bd:23.36712074
# epoch 183: loss 25.522228
# epoch 184 loss_pde:2.18786359, loss_bd:9.55426598
# epoch 184: loss 11.742129
# epoch 185 loss_pde:2.37931299, loss_bd:10.42571545
# epoch 185: loss 12.805029
# epoch 186 loss_pde:2.54131150, loss_bd:20.56299019
# epoch 186: loss 23.104301
# epoch 187 loss_pde:2.45466447, loss_bd:22.22604942
# epoch 187: loss 24.680714
# epoch 188 loss_pde:2.22478008, loss_bd:16.35378456
# epoch 188: loss 18.578564
# epoch 189 loss_pde:2.05502677, loss_bd:3.85070586
# epoch 189: loss 5.905733
# epoch 190 loss_pde:2.00235581, loss_bd:16.10163498
# epoch 190: loss 18.103991
# epoch 191 loss_pde:1.99755788, loss_bd:25.59853745
# epoch 191: loss 27.596096
# epoch 192 loss_pde:1.99393141, loss_bd:25.69367409
# epoch 192: loss 27.687605
# epoch 193 loss_pde:1.98779833, loss_bd:17.71325302
# epoch 193: loss 19.701052
# epoch 194 loss_pde:1.99391770, loss_bd:3.74481177
# epoch 194: loss 5.738729
# epoch 195 loss_pde:2.03218579, loss_bd:16.28744698
# epoch 195: loss 18.319633
# epoch 196 loss_pde:2.09071565, loss_bd:26.11415482
# epoch 196: loss 28.204870
# epoch 197 loss_pde:2.11891484, loss_bd:27.36554146
# epoch 197: loss 29.484457
# epoch 198 loss_pde:2.14648008, loss_bd:20.92668152
# epoch 198: loss 23.073162
# epoch 199 loss_pde:2.23503423, loss_bd:7.73987198
# epoch 199: loss 9.974906
# epoch 200 loss_pde:2.44054675, loss_bd:14.56001091
# epoch 200: loss 17.000557
# epoch 201 loss_pde:2.48147416, loss_bd:24.11007309
# epoch 201: loss 26.591547
# epoch 202 loss_pde:2.34738421, loss_bd:23.56127739
# epoch 202: loss 25.908661
# epoch 203 loss_pde:2.15094447, loss_bd:14.70733643
# epoch 203: loss 16.858280
# epoch 204 loss_pde:2.05317640, loss_bd:1.26001382
# epoch 204: loss 3.313190
# epoch 205 loss_pde:2.12954760, loss_bd:6.89318132
# epoch 205: loss 9.022729
# epoch 206 loss_pde:2.22142673, loss_bd:4.66829538
# epoch 206: loss 6.889722
# epoch 207 loss_pde:2.24921656, loss_bd:6.18335772
# epoch 207: loss 8.432574
# epoch 208 loss_pde:2.24705482, loss_bd:7.57850266
# epoch 208: loss 9.825558
# epoch 209 loss_pde:2.23577380, loss_bd:1.45851827
# epoch 209: loss 3.694292
# epoch 210 loss_pde:2.25624442, loss_bd:12.29772472
# epoch 210: loss 14.553969
# epoch 211 loss_pde:2.24030399, loss_bd:16.34103966
# epoch 211: loss 18.581345
# epoch 212 loss_pde:2.19397449, loss_bd:12.86291218
# epoch 212: loss 15.056887
# epoch 213 loss_pde:2.17859721, loss_bd:2.90374732
# epoch 213: loss 5.082345
# epoch 214 loss_pde:2.23905802, loss_bd:13.68302536
# epoch 214: loss 15.922083
# epoch 215 loss_pde:2.31117654, loss_bd:20.50833130
# epoch 215: loss 22.819508
# epoch 216 loss_pde:2.34280109, loss_bd:19.07124710
# epoch 216: loss 21.414047
# epoch 217 loss_pde:2.33101177, loss_bd:10.30493736
# epoch 217: loss 12.635949
# epoch 218 loss_pde:2.30628848, loss_bd:5.14284039
# epoch 218: loss 7.449129
# epoch 219 loss_pde:2.27008820, loss_bd:11.47718430
# epoch 219: loss 13.747272
# epoch 220 loss_pde:2.19204593, loss_bd:10.03209019
# epoch 220: loss 12.224136
# epoch 221 loss_pde:2.09352255, loss_bd:1.57484627
# epoch 221: loss 3.668369
# epoch 222 loss_pde:2.02042842, loss_bd:13.78213310
# epoch 222: loss 15.802562
# epoch 223 loss_pde:1.95402241, loss_bd:19.89536476
# epoch 223: loss 21.849388
# epoch 224 loss_pde:1.88888466, loss_bd:17.78438377
# epoch 224: loss 19.673269
# epoch 225 loss_pde:1.85328197, loss_bd:8.23376179
# epoch 225: loss 10.087044
# epoch 226 loss_pde:1.90402663, loss_bd:7.99071836
# epoch 226: loss 9.894745
# epoch 227 loss_pde:1.96476090, loss_bd:14.07076836
# epoch 227: loss 16.035530
# epoch 228 loss_pde:1.95357609, loss_bd:11.61410236
# epoch 228: loss 13.567678
# epoch 229 loss_pde:1.94168258, loss_bd:2.35984039
# epoch 229: loss 4.301523
# epoch 230 loss_pde:2.00706530, loss_bd:13.32709122
# epoch 230: loss 15.334156
# epoch 231 loss_pde:2.11869764, loss_bd:19.60895538
# epoch 231: loss 21.727654
# epoch 232 loss_pde:2.23263812, loss_bd:17.69992638
# epoch 232: loss 19.932564
# epoch 233 loss_pde:2.35351777, loss_bd:8.47864914
# epoch 233: loss 10.832167
# epoch 234 loss_pde:2.52016687, loss_bd:7.57232237
# epoch 234: loss 10.092489
# epoch 235 loss_pde:2.55092406, loss_bd:14.20156670
# epoch 235: loss 16.752491
# epoch 236 loss_pde:2.40642214, loss_bd:13.03936100
# epoch 236: loss 15.445784
# epoch 237 loss_pde:2.24674606, loss_bd:4.93095160
# epoch 237: loss 7.177698
# epoch 238 loss_pde:2.16999364, loss_bd:10.14484406
# epoch 238: loss 12.314837
# epoch 239 loss_pde:2.12244225, loss_bd:15.92789078
# epoch 239: loss 18.050333
# epoch 240 loss_pde:2.07249403, loss_bd:13.53021526
# epoch 240: loss 15.602709
# epoch 241 loss_pde:2.04650760, loss_bd:3.90009546
# epoch 241: loss 5.946603
# epoch 242 loss_pde:2.10567141, loss_bd:12.37218380
# epoch 242: loss 14.477856
# epoch 243 loss_pde:2.17158055, loss_bd:19.38466454
# epoch 243: loss 21.556246
# epoch 244 loss_pde:2.13833928, loss_bd:18.43098259
# epoch 244: loss 20.569323
# epoch 245 loss_pde:2.04499412, loss_bd:10.32224751
# epoch 245: loss 12.367242
# epoch 246 loss_pde:1.99843800, loss_bd:4.46340466
# epoch 246: loss 6.461843
# epoch 247 loss_pde:1.99704087, loss_bd:10.30424309
# epoch 247: loss 12.301284
# epoch 248 loss_pde:1.98782909, loss_bd:8.22785473
# epoch 248: loss 10.215684
# epoch 249 loss_pde:1.96000826, loss_bd:1.61097157
# epoch 249: loss 3.570980
# epoch 250 loss_pde:1.94696879, loss_bd:3.37000847
# epoch 250: loss 5.316978
# epoch 251 loss_pde:1.94515765, loss_bd:2.53959298
# epoch 251: loss 4.484751
# epoch 252 loss_pde:1.92361009, loss_bd:0.43812814
# epoch 252: loss 2.361738
# epoch 253 loss_pde:1.91854274, loss_bd:5.00769854
# epoch 253: loss 6.926241
# epoch 254 loss_pde:1.89959145, loss_bd:2.30431342
# epoch 254: loss 4.203905
# epoch 255 loss_pde:1.88423550, loss_bd:7.41059399
# epoch 255: loss 9.294829
# epoch 256 loss_pde:1.88588929, loss_bd:8.44757271
# epoch 256: loss 10.333462
# epoch 257 loss_pde:1.88638139, loss_bd:2.15492749
# epoch 257: loss 4.041309
# epoch 258 loss_pde:1.90147316, loss_bd:11.22925186
# epoch 258: loss 13.130725
# epoch 259 loss_pde:1.91594660, loss_bd:15.54606342
# epoch 259: loss 17.462009
# epoch 260 loss_pde:1.92041576, loss_bd:11.88585663
# epoch 260: loss 13.806273
# epoch 261 loss_pde:1.92855251, loss_bd:1.24553454
# epoch 261: loss 3.174087
# epoch 262 loss_pde:1.97935688, loss_bd:15.72189426
# epoch 262: loss 17.701252
# epoch 263 loss_pde:2.01920485, loss_bd:23.40554810
# epoch 263: loss 25.424753
# epoch 264 loss_pde:1.99315119, loss_bd:23.08955002
# epoch 264: loss 25.082701
# epoch 265 loss_pde:1.95133328, loss_bd:15.75711060
# epoch 265: loss 17.708445
# epoch 266 loss_pde:1.96739697, loss_bd:2.25654411
# epoch 266: loss 4.223941
# epoch 267 loss_pde:2.06890726, loss_bd:17.90913582
# epoch 267: loss 19.978043
# epoch 268 loss_pde:2.14183140, loss_bd:28.18747330
# epoch 268: loss 30.329304
# epoch 269 loss_pde:2.15356302, loss_bd:29.61402702
# epoch 269: loss 31.767590
# epoch 270 loss_pde:2.13751483, loss_bd:23.21861649
# epoch 270: loss 25.356131
# epoch 271 loss_pde:2.15745544, loss_bd:10.21590137
# epoch 271: loss 12.373357
# epoch 272 loss_pde:2.31020880, loss_bd:8.94515324
# epoch 272: loss 11.255362
# epoch 273 loss_pde:2.43540382, loss_bd:18.46629143
# epoch 273: loss 20.901695
# epoch 274 loss_pde:2.34472632, loss_bd:19.76614761
# epoch 274: loss 22.110874
# epoch 275 loss_pde:2.13917518, loss_bd:13.81307220
# epoch 275: loss 15.952248
# epoch 276 loss_pde:1.99558556, loss_bd:1.55696094
# epoch 276: loss 3.552547
# epoch 277 loss_pde:1.96001029, loss_bd:17.92673874
# epoch 277: loss 19.886749
# epoch 278 loss_pde:1.95965254, loss_bd:27.30087090
# epoch 278: loss 29.260523
# epoch 279 loss_pde:1.95345879, loss_bd:27.59829712
# epoch 279: loss 29.551756
# epoch 280 loss_pde:1.94025803, loss_bd:19.94375420
# epoch 280: loss 21.884012
# epoch 281 loss_pde:1.94198132, loss_bd:5.68692875
# epoch 281: loss 7.628910
# epoch 282 loss_pde:2.00270629, loss_bd:15.11841583
# epoch 282: loss 17.121122
# epoch 283 loss_pde:2.07213569, loss_bd:25.06207657
# epoch 283: loss 27.134212
# epoch 284 loss_pde:2.09683561, loss_bd:25.93233871
# epoch 284: loss 28.029175
# epoch 285 loss_pde:2.17742968, loss_bd:19.79749489
# epoch 285: loss 21.974924
# epoch 286 loss_pde:2.35220265, loss_bd:7.52980709
# epoch 286: loss 9.882010
# epoch 287 loss_pde:2.59346914, loss_bd:12.73119831
# epoch 287: loss 15.324667
# epoch 288 loss_pde:2.70078349, loss_bd:21.70675659
# epoch 288: loss 24.407539
# epoch 289 loss_pde:2.65118527, loss_bd:21.49981499
# epoch 289: loss 24.151001
# epoch 290 loss_pde:2.51612496, loss_bd:13.38387585
# epoch 290: loss 15.900001
# epoch 291 loss_pde:2.43063807, loss_bd:2.23249149
# epoch 291: loss 4.663130
# epoch 292 loss_pde:2.37951517, loss_bd:7.50783205
# epoch 292: loss 9.887347
# epoch 293 loss_pde:2.30954432, loss_bd:5.27936363
# epoch 293: loss 7.588908
# epoch 294 loss_pde:2.24929786, loss_bd:5.22738361
# epoch 294: loss 7.476682
# epoch 295 loss_pde:2.24871826, loss_bd:6.50650501
# epoch 295: loss 8.755223
# epoch 296 loss_pde:2.27601576, loss_bd:1.29721951
# epoch 296: loss 3.573235
# epoch 297 loss_pde:2.26290870, loss_bd:1.96417153
# epoch 297: loss 4.227080
# epoch 298 loss_pde:2.25651073, loss_bd:4.53669834
# epoch 298: loss 6.793209
# epoch 299 loss_pde:2.20176053, loss_bd:1.81748402
# epoch 299: loss 4.019245
# epoch 300 loss_pde:2.14837742, loss_bd:7.80965042
# epoch 300: loss 9.958028
# epoch 301 loss_pde:2.13003063, loss_bd:8.40951347
# epoch 301: loss 10.539544
# epoch 302 loss_pde:2.12583661, loss_bd:1.85628951
# epoch 302: loss 3.982126
# epoch 303 loss_pde:2.13130784, loss_bd:11.36152077
# epoch 303: loss 13.492828
# epoch 304 loss_pde:2.12792301, loss_bd:15.84625626
# epoch 304: loss 17.974178
# epoch 305 loss_pde:2.11246681, loss_bd:12.91394711
# epoch 305: loss 15.026414
# epoch 306 loss_pde:2.10086370, loss_bd:3.35816121
# epoch 306: loss 5.459025
# epoch 307 loss_pde:2.10826826, loss_bd:13.33615780
# epoch 307: loss 15.444426
# epoch 308 loss_pde:2.05671740, loss_bd:20.38031769
# epoch 308: loss 22.437035
# epoch 309 loss_pde:1.94828463, loss_bd:18.88656807
# epoch 309: loss 20.834852
# epoch 310 loss_pde:1.84566963, loss_bd:9.80757713
# epoch 310: loss 11.653247
# epoch 311 loss_pde:1.85303831, loss_bd:6.61920166
# epoch 311: loss 8.472240
# epoch 312 loss_pde:1.95009363, loss_bd:12.76180744
# epoch 312: loss 14.711901
# epoch 313 loss_pde:1.98805404, loss_bd:10.39918900
# epoch 313: loss 12.387243
# epoch 314 loss_pde:2.00350118, loss_bd:1.41035461
# epoch 314: loss 3.413856
# epoch 315 loss_pde:2.05366039, loss_bd:14.15515995
# epoch 315: loss 16.208820
# epoch 316 loss_pde:2.12789917, loss_bd:20.28349686
# epoch 316: loss 22.411396
# epoch 317 loss_pde:2.19735026, loss_bd:18.35988617
# epoch 317: loss 20.557236
# epoch 318 loss_pde:2.26524305, loss_bd:9.21616077
# epoch 318: loss 11.481403
# epoch 319 loss_pde:2.38360763, loss_bd:6.79500628
# epoch 319: loss 9.178614
# epoch 320 loss_pde:2.42867422, loss_bd:13.40363026
# epoch 320: loss 15.832304
# epoch 321 loss_pde:2.33766770, loss_bd:12.30614853
# epoch 321: loss 14.643816
# epoch 322 loss_pde:2.21623135, loss_bd:4.36559629
# epoch 322: loss 6.581828
# epoch 323 loss_pde:2.15446758, loss_bd:10.93942261
# epoch 323: loss 13.093890
# epoch 324 loss_pde:2.11535382, loss_bd:16.56063461
# epoch 324: loss 18.675989
# epoch 325 loss_pde:2.07590985, loss_bd:14.05481911
# epoch 325: loss 16.130730
# epoch 326 loss_pde:2.07531333, loss_bd:4.56552124
# epoch 326: loss 6.640835
# epoch 327 loss_pde:2.17281890, loss_bd:10.64319801
# epoch 327: loss 12.816017
# epoch 328 loss_pde:2.24274874, loss_bd:16.84763145
# epoch 328: loss 19.090380
# epoch 329 loss_pde:2.17472005, loss_bd:15.30559063
# epoch 329: loss 17.480310
# epoch 330 loss_pde:2.03534579, loss_bd:6.78365421
# epoch 330: loss 8.819000
# epoch 331 loss_pde:1.94511521, loss_bd:8.32520103
# epoch 331: loss 10.270316
# epoch 332 loss_pde:1.91087401, loss_bd:14.53877449
# epoch 332: loss 16.449648
# epoch 333 loss_pde:1.88132858, loss_bd:12.86056614
# epoch 333: loss 14.741895
# epoch 334 loss_pde:1.84381497, loss_bd:3.98201680
# epoch 334: loss 5.825832
# epoch 335 loss_pde:1.81343663, loss_bd:11.67889595
# epoch 335: loss 13.492332
# epoch 336 loss_pde:1.81201732, loss_bd:18.19952202
# epoch 336: loss 20.011539
# epoch 337 loss_pde:1.81464720, loss_bd:16.98971939
# epoch 337: loss 18.804367
# epoch 338 loss_pde:1.83367729, loss_bd:8.95718193
# epoch 338: loss 10.790859
# epoch 339 loss_pde:1.88677239, loss_bd:5.19523716
# epoch 339: loss 7.082009
# epoch 340 loss_pde:1.92476356, loss_bd:10.26735878
# epoch 340: loss 12.192122
# epoch 341 loss_pde:1.93305337, loss_bd:7.52842617
# epoch 341: loss 9.461479
# epoch 342 loss_pde:1.92367291, loss_bd:2.58781552
# epoch 342: loss 4.511488
# epoch 343 loss_pde:1.91863990, loss_bd:4.14605236
# epoch 343: loss 6.064692
# epoch 344 loss_pde:1.91108847, loss_bd:1.76771283
# epoch 344: loss 3.678801
# epoch 345 loss_pde:1.90145934, loss_bd:0.66789377
# epoch 345: loss 2.569353
# epoch 346 loss_pde:1.89556766, loss_bd:4.82332802
# epoch 346: loss 6.718896
# epoch 347 loss_pde:1.89603794, loss_bd:2.50681901
# epoch 347: loss 4.402857
# epoch 348 loss_pde:1.91745615, loss_bd:6.68472719
# epoch 348: loss 8.602183
# epoch 349 loss_pde:1.91394091, loss_bd:7.35908556
# epoch 349: loss 9.273026
# epoch 350 loss_pde:1.88403511, loss_bd:0.87791777
# epoch 350: loss 2.761953
# epoch 351 loss_pde:1.87979233, loss_bd:12.50997066
# epoch 351: loss 14.389763
# epoch 352 loss_pde:1.89854383, loss_bd:16.93787575
# epoch 352: loss 18.836420
# epoch 353 loss_pde:1.91564310, loss_bd:13.50523567
# epoch 353: loss 15.420878
# epoch 354 loss_pde:1.93359542, loss_bd:3.23886442
# epoch 354: loss 5.172460
# epoch 355 loss_pde:1.97557712, loss_bd:13.28396988
# epoch 355: loss 15.259547
# epoch 356 loss_pde:1.99790895, loss_bd:20.70450783
# epoch 356: loss 22.702417
# epoch 357 loss_pde:1.96442914, loss_bd:20.38568878
# epoch 357: loss 22.350119
# epoch 358 loss_pde:1.91627777, loss_bd:13.24420357
# epoch 358: loss 15.160481
# epoch 359 loss_pde:1.91232240, loss_bd:0.55096859
# epoch 359: loss 2.463291
# epoch 360 loss_pde:1.91059577, loss_bd:5.65596581
# epoch 360: loss 7.566562
# epoch 361 loss_pde:1.88008630, loss_bd:2.93876600
# epoch 361: loss 4.818852
# epoch 362 loss_pde:1.84085190, loss_bd:7.27136230
# epoch 362: loss 9.112214
# epoch 363 loss_pde:1.84138465, loss_bd:8.83651638
# epoch 363: loss 10.677901
# epoch 364 loss_pde:1.86342871, loss_bd:3.37940598
# epoch 364: loss 5.242835
# epoch 365 loss_pde:1.90961504, loss_bd:8.30841541
# epoch 365: loss 10.218031
# epoch 366 loss_pde:1.93714595, loss_bd:11.35224152
# epoch 366: loss 13.289388
# epoch 367 loss_pde:1.93821394, loss_bd:6.93033504
# epoch 367: loss 8.868549
# epoch 368 loss_pde:1.92997921, loss_bd:4.53637600
# epoch 368: loss 6.466355
# epoch 369 loss_pde:1.91640341, loss_bd:7.40879297
# epoch 369: loss 9.325196
# epoch 370 loss_pde:1.88576710, loss_bd:2.94352746
# epoch 370: loss 4.829295
# epoch 371 loss_pde:1.88020194, loss_bd:8.43822861
# epoch 371: loss 10.318431
# epoch 372 loss_pde:1.88063097, loss_bd:11.30413532
# epoch 372: loss 13.184767
# epoch 373 loss_pde:1.86656868, loss_bd:6.76771450
# epoch 373: loss 8.634283
# epoch 374 loss_pde:1.84846449, loss_bd:4.35645628
# epoch 374: loss 6.204921
# epoch 375 loss_pde:1.84523809, loss_bd:6.83870220
# epoch 375: loss 8.683940
# epoch 376 loss_pde:1.84590375, loss_bd:2.09471965
# epoch 376: loss 3.940623
# epoch 377 loss_pde:1.86834502, loss_bd:9.53864288
# epoch 377: loss 11.406988
# epoch 378 loss_pde:1.88362145, loss_bd:12.56316662
# epoch 378: loss 14.446788
# epoch 379 loss_pde:1.88286865, loss_bd:8.03912735
# epoch 379: loss 9.921996
# epoch 380 loss_pde:1.88221598, loss_bd:3.42743278
# epoch 380: loss 5.309649
# epoch 381 loss_pde:1.87919390, loss_bd:6.40272331
# epoch 381: loss 8.281918
# epoch 382 loss_pde:1.85627377, loss_bd:2.03467178
# epoch 382: loss 3.890945
# epoch 383 loss_pde:1.83880150, loss_bd:9.28673935
# epoch 383: loss 11.125541
# epoch 384 loss_pde:1.82717741, loss_bd:12.07670116
# epoch 384: loss 13.903878
# epoch 385 loss_pde:1.81344128, loss_bd:7.24883842
# epoch 385: loss 9.062280
# epoch 386 loss_pde:1.82059884, loss_bd:4.60320997
# epoch 386: loss 6.423809
# epoch 387 loss_pde:1.83281612, loss_bd:7.81135750
# epoch 387: loss 9.644174
# epoch 388 loss_pde:1.82366967, loss_bd:3.57458472
# epoch 388: loss 5.398254
# epoch 389 loss_pde:1.83489084, loss_bd:7.59454203
# epoch 389: loss 9.429433
# epoch 390 loss_pde:1.85363579, loss_bd:10.22395229
# epoch 390: loss 12.077588
# epoch 391 loss_pde:1.85851240, loss_bd:5.35627604
# epoch 391: loss 7.214788
# epoch 392 loss_pde:1.86258698, loss_bd:6.37362576
# epoch 392: loss 8.236213
# epoch 393 loss_pde:1.85976541, loss_bd:9.62309074
# epoch 393: loss 11.482856
# epoch 394 loss_pde:1.83789253, loss_bd:5.56167173
# epoch 394: loss 7.399564
# epoch 395 loss_pde:1.82581317, loss_bd:5.41791058
# epoch 395: loss 7.243724
# epoch 396 loss_pde:1.81502891, loss_bd:7.94770193
# epoch 396: loss 9.762731
# epoch 397 loss_pde:1.79674709, loss_bd:2.95680547
# epoch 397: loss 4.753552
# epoch 398 loss_pde:1.79526818, loss_bd:8.95074654
# epoch 398: loss 10.746015
# epoch 399 loss_pde:1.80658138, loss_bd:12.31938457
# epoch 399: loss 14.125966
# epoch 400 loss_pde:1.80029941, loss_bd:8.32658577
# epoch 400: loss 10.126885
# epoch 401 loss_pde:1.80584621, loss_bd:2.57795072
# epoch 401: loss 4.383797
# epoch 402 loss_pde:1.81651425, loss_bd:5.04633808
# epoch 402: loss 6.862852
# epoch 403 loss_pde:1.81615174, loss_bd:0.39213181
# epoch 403: loss 2.208283
# epoch 404 loss_pde:1.82036531, loss_bd:1.98329663
# epoch 404: loss 3.803662
# epoch 405 loss_pde:1.81718671, loss_bd:3.69646549
# epoch 405: loss 5.513652
# epoch 406 loss_pde:1.81242204, loss_bd:1.55319154
# epoch 406: loss 3.365613
# epoch 407 loss_pde:1.81244886, loss_bd:7.72643948
# epoch 407: loss 9.538888
# epoch 408 loss_pde:1.80661774, loss_bd:8.63996410
# epoch 408: loss 10.446582
# epoch 409 loss_pde:1.79997921, loss_bd:2.79498315
# epoch 409: loss 4.594962
# epoch 410 loss_pde:1.82805896, loss_bd:10.22014523
# epoch 410: loss 12.048204
# epoch 411 loss_pde:1.83507502, loss_bd:13.99373436
# epoch 411: loss 15.828810
# epoch 412 loss_pde:1.79463363, loss_bd:10.22417259
# epoch 412: loss 12.018806
# epoch 413 loss_pde:1.78373861, loss_bd:0.82675469
# epoch 413: loss 2.610493
# epoch 414 loss_pde:1.79880619, loss_bd:3.47265100
# epoch 414: loss 5.271457
# epoch 415 loss_pde:1.80701363, loss_bd:1.48896503
# epoch 415: loss 3.295979
# epoch 416 loss_pde:1.81344306, loss_bd:1.18688202
# epoch 416: loss 3.000325
# epoch 417 loss_pde:1.80789769, loss_bd:4.32234764
# epoch 417: loss 6.130245
# epoch 418 loss_pde:1.79831159, loss_bd:1.97694957
# epoch 418: loss 3.775261
# epoch 419 loss_pde:1.79057455, loss_bd:6.99718857
# epoch 419: loss 8.787764
# epoch 420 loss_pde:1.77978730, loss_bd:7.37512350
# epoch 420: loss 9.154911
# epoch 421 loss_pde:1.78062284, loss_bd:0.76671010
# epoch 421: loss 2.547333
# epoch 422 loss_pde:1.83399868, loss_bd:12.41189861
# epoch 422: loss 14.245897
# epoch 423 loss_pde:1.87368917, loss_bd:16.62308121
# epoch 423: loss 18.496771
# epoch 424 loss_pde:1.83163214, loss_bd:13.30545330
# epoch 424: loss 15.137085
# epoch 425 loss_pde:1.78548896, loss_bd:3.26238585
# epoch 425: loss 5.047875
# epoch 426 loss_pde:1.80531502, loss_bd:13.27862167
# epoch 426: loss 15.083937
# epoch 427 loss_pde:1.84142101, loss_bd:20.71624947
# epoch 427: loss 22.557671
# epoch 428 loss_pde:1.85491490, loss_bd:19.86499977
# epoch 428: loss 21.719915
# epoch 429 loss_pde:1.85077691, loss_bd:11.66511726
# epoch 429: loss 13.515894
# epoch 430 loss_pde:1.85859609, loss_bd:3.08613873
# epoch 430: loss 4.944735
# epoch 431 loss_pde:1.87512863, loss_bd:8.92828846
# epoch 431: loss 10.803417
# epoch 432 loss_pde:1.85898697, loss_bd:7.13335991
# epoch 432: loss 8.992347
# epoch 433 loss_pde:1.82626319, loss_bd:1.73122263
# epoch 433: loss 3.557486
# epoch 434 loss_pde:1.80407929, loss_bd:2.44187570
# epoch 434: loss 4.245955
# epoch 435 loss_pde:1.79411590, loss_bd:4.39107132
# epoch 435: loss 6.185187
# epoch 436 loss_pde:1.78461838, loss_bd:3.21548653
# epoch 436: loss 5.000105
# epoch 437 loss_pde:1.78393805, loss_bd:5.34571600
# epoch 437: loss 7.129654
# epoch 438 loss_pde:1.78615868, loss_bd:5.49642324
# epoch 438: loss 7.282582
# epoch 439 loss_pde:1.78336680, loss_bd:1.78627491
# epoch 439: loss 3.569642
# epoch 440 loss_pde:1.78956807, loss_bd:1.00872183
# epoch 440: loss 2.798290
# epoch 441 loss_pde:1.80471754, loss_bd:7.04049063
# epoch 441: loss 8.845208
# epoch 442 loss_pde:1.80373108, loss_bd:6.89604568
# epoch 442: loss 8.699777
# epoch 443 loss_pde:1.78497493, loss_bd:0.69825113
# epoch 443: loss 2.483226
# epoch 444 loss_pde:1.77132976, loss_bd:0.21653670
# epoch 444: loss 1.987866
# epoch 445 loss_pde:1.76857257, loss_bd:6.99428511
# epoch 445: loss 8.762857
# epoch 446 loss_pde:1.75534487, loss_bd:5.96123505
# epoch 446: loss 7.716580
# epoch 447 loss_pde:1.74696755, loss_bd:2.52343535
# epoch 447: loss 4.270403
# epoch 448 loss_pde:1.74759030, loss_bd:2.69160080
# epoch 448: loss 4.439191
# epoch 449 loss_pde:1.74921656, loss_bd:5.02906132
# epoch 449: loss 6.778278
# epoch 450 loss_pde:1.75066030, loss_bd:4.77910280
# epoch 450: loss 6.529763
# epoch 451 loss_pde:1.74830437, loss_bd:2.34346485
# epoch 451: loss 4.091769
# epoch 452 loss_pde:1.74749863, loss_bd:1.16391432
# epoch 452: loss 2.911413
# epoch 453 loss_pde:1.75220966, loss_bd:7.35465527
# epoch 453: loss 9.106865
# epoch 454 loss_pde:1.75569606, loss_bd:7.48963451
# epoch 454: loss 9.245331
# epoch 455 loss_pde:1.75453019, loss_bd:0.55386966
# epoch 455: loss 2.308400
# epoch 456 loss_pde:1.74902034, loss_bd:0.48424080
# epoch 456: loss 2.233261
# epoch 457 loss_pde:1.74327660, loss_bd:6.67947388
# epoch 457: loss 8.422750
# epoch 458 loss_pde:1.74328911, loss_bd:5.14967871
# epoch 458: loss 6.892968
# epoch 459 loss_pde:1.76902401, loss_bd:3.69825935
# epoch 459: loss 5.467283
# epoch 460 loss_pde:1.78404200, loss_bd:4.26650143
# epoch 460: loss 6.050543
# epoch 461 loss_pde:1.77018368, loss_bd:3.09389687
# epoch 461: loss 4.864080
# epoch 462 loss_pde:1.76349974, loss_bd:2.63955021
# epoch 462: loss 4.403050
# epoch 463 loss_pde:1.75514364, loss_bd:4.84926987
# epoch 463: loss 6.604414
# epoch 464 loss_pde:1.73704934, loss_bd:3.86131811
# epoch 464: loss 5.598368
# epoch 465 loss_pde:1.72984529, loss_bd:4.42400169
# epoch 465: loss 6.153847
# epoch 466 loss_pde:1.72423708, loss_bd:4.42595243
# epoch 466: loss 6.150189
# epoch 467 loss_pde:1.71086836, loss_bd:3.28321648
# epoch 467: loss 4.994085
# epoch 468 loss_pde:1.70374656, loss_bd:3.32034135
# epoch 468: loss 5.024088
# epoch 469 loss_pde:1.70425391, loss_bd:3.34746218
# epoch 469: loss 5.051716
# epoch 470 loss_pde:1.69778788, loss_bd:1.75473952
# epoch 470: loss 3.452528
# epoch 471 loss_pde:1.69375277, loss_bd:6.49357367
# epoch 471: loss 8.187326
# epoch 472 loss_pde:1.69663632, loss_bd:6.45194006
# epoch 472: loss 8.148577
# epoch 473 loss_pde:1.70100164, loss_bd:1.17957771
# epoch 473: loss 2.880579
# epoch 474 loss_pde:1.70267260, loss_bd:1.03797138
# epoch 474: loss 2.740644
# epoch 475 loss_pde:1.70203209, loss_bd:6.43862152
# epoch 475: loss 8.140654
# epoch 476 loss_pde:1.69889092, loss_bd:5.78134012
# epoch 476: loss 7.480231
# epoch 477 loss_pde:1.69884157, loss_bd:2.24998260
# epoch 477: loss 3.948824
# epoch 478 loss_pde:1.69719625, loss_bd:1.96973228
# epoch 478: loss 3.666929
# epoch 479 loss_pde:1.69323790, loss_bd:5.88914919
# epoch 479: loss 7.582387
# epoch 480 loss_pde:1.69446385, loss_bd:6.15003061
# epoch 480: loss 7.844494
# epoch 481 loss_pde:1.69428492, loss_bd:0.97206891
# epoch 481: loss 2.666354
# epoch 482 loss_pde:1.69403744, loss_bd:0.63081151
# epoch 482: loss 2.324849
# epoch 483 loss_pde:1.70093381, loss_bd:5.39864159
# epoch 483: loss 7.099576
# epoch 484 loss_pde:1.70806062, loss_bd:2.95821929
# epoch 484: loss 4.666280
# epoch 485 loss_pde:1.75192475, loss_bd:6.73571014
# epoch 485: loss 8.487635
# epoch 486 loss_pde:1.76427913, loss_bd:7.96095800
# epoch 486: loss 9.725237
# epoch 487 loss_pde:1.73056495, loss_bd:1.78046834
# epoch 487: loss 3.511033
# epoch 488 loss_pde:1.73982084, loss_bd:11.28134155
# epoch 488: loss 13.021162
# epoch 489 loss_pde:1.76440334, loss_bd:15.47750473
# epoch 489: loss 17.241909
# epoch 490 loss_pde:1.77046895, loss_bd:11.72702789
# epoch 490: loss 13.497497
# epoch 491 loss_pde:1.77286267, loss_bd:2.16571355
# epoch 491: loss 3.938576
# epoch 492 loss_pde:1.82080102, loss_bd:15.19729042
# epoch 492: loss 17.018091
# epoch 493 loss_pde:1.84564257, loss_bd:22.30600739
# epoch 493: loss 24.151649
# epoch 494 loss_pde:1.78247726, loss_bd:21.59743118
# epoch 494: loss 23.379908
# epoch 495 loss_pde:1.70438468, loss_bd:14.01208115
# epoch 495: loss 15.716466
# epoch 496 loss_pde:1.68251741, loss_bd:1.26570249
# epoch 496: loss 2.948220
# epoch 497 loss_pde:1.68729937, loss_bd:6.67089510
# epoch 497: loss 8.358194
# epoch 498 loss_pde:1.68633652, loss_bd:4.64304209
# epoch 498: loss 6.329379
# epoch 499 loss_pde:1.68844676, loss_bd:4.86165905
# epoch 499: loss 6.550106
# epoch 500 loss_pde:1.72055149, loss_bd:5.82793331
# epoch 500: loss 7.548485
# epoch 501 loss_pde:1.75600576, loss_bd:0.70179582
# epoch 501: loss 2.457802
# epoch 502 loss_pde:1.76097727, loss_bd:1.59216940
# epoch 502: loss 3.353147
# epoch 503 loss_pde:1.75376177, loss_bd:4.17472839
# epoch 503: loss 5.928490
# epoch 504 loss_pde:1.72677469, loss_bd:1.43167353
# epoch 504: loss 3.158448
# epoch 505 loss_pde:1.71997952, loss_bd:8.66405487
# epoch 505: loss 10.384034
# epoch 506 loss_pde:1.71847141, loss_bd:10.03741074
# epoch 506: loss 11.755882
# epoch 507 loss_pde:1.71127534, loss_bd:3.88643241
# epoch 507: loss 5.597708
# epoch 508 loss_pde:1.76988447, loss_bd:8.99067688
# epoch 508: loss 10.760561
# epoch 509 loss_pde:1.82803369, loss_bd:12.89395428
# epoch 509: loss 14.721988
# epoch 510 loss_pde:1.86111772, loss_bd:8.91979313
# epoch 510: loss 10.780910
# epoch 511 loss_pde:1.90090978, loss_bd:2.35073829
# epoch 511: loss 4.251648
# epoch 512 loss_pde:1.91690159, loss_bd:4.88434124
# epoch 512: loss 6.801243
# epoch 513 loss_pde:1.86870325, loss_bd:0.30738491
# epoch 513: loss 2.176088
# epoch 514 loss_pde:1.84496987, loss_bd:2.04271269
# epoch 514: loss 3.887682
# epoch 515 loss_pde:1.79539108, loss_bd:3.56805372
# epoch 515: loss 5.363445
# epoch 516 loss_pde:1.77899516, loss_bd:1.16353619
# epoch 516: loss 2.942531
# epoch 517 loss_pde:1.80292201, loss_bd:8.55675602
# epoch 517: loss 10.359678
# epoch 518 loss_pde:1.78710294, loss_bd:9.87512970
# epoch 518: loss 11.662232
# epoch 519 loss_pde:1.73378897, loss_bd:4.28746653
# epoch 519: loss 6.021255
# epoch 520 loss_pde:1.70734787, loss_bd:8.21133995
# epoch 520: loss 9.918688
# epoch 521 loss_pde:1.71046126, loss_bd:11.47788525
# epoch 521: loss 13.188347
# epoch 522 loss_pde:1.72015297, loss_bd:7.02640486
# epoch 522: loss 8.746558
# epoch 523 loss_pde:1.74753237, loss_bd:4.34896898
# epoch 523: loss 6.096501
# epoch 524 loss_pde:1.76625490, loss_bd:7.21972227
# epoch 524: loss 8.985977
# epoch 525 loss_pde:1.75382805, loss_bd:2.65881062
# epoch 525: loss 4.412639
# epoch 526 loss_pde:1.74978542, loss_bd:8.95647049
# epoch 526: loss 10.706256
# epoch 527 loss_pde:1.73708093, loss_bd:11.88610840
# epoch 527: loss 13.623189
# epoch 528 loss_pde:1.70330501, loss_bd:7.11893034
# epoch 528: loss 8.822235
# epoch 529 loss_pde:1.68506336, loss_bd:4.88940763
# epoch 529: loss 6.574471
# epoch 530 loss_pde:1.68753874, loss_bd:7.96076775
# epoch 530: loss 9.648307
# epoch 531 loss_pde:1.68382812, loss_bd:3.35031986
# epoch 531: loss 5.034148
# epoch 532 loss_pde:1.72794235, loss_bd:8.06046486
# epoch 532: loss 9.788407
# epoch 533 loss_pde:1.78305459, loss_bd:10.74273014
# epoch 533: loss 12.525784
# epoch 534 loss_pde:1.82961702, loss_bd:5.80395985
# epoch 534: loss 7.633577
# epoch 535 loss_pde:1.88708389, loss_bd:6.18281937
# epoch 535: loss 8.069903
# epoch 536 loss_pde:1.89663327, loss_bd:9.43852139
# epoch 536: loss 11.335155
# epoch 537 loss_pde:1.83986139, loss_bd:5.27003336
# epoch 537: loss 7.109895
# epoch 538 loss_pde:1.78149962, loss_bd:5.89513540
# epoch 538: loss 7.676635
# epoch 539 loss_pde:1.75747335, loss_bd:8.50240135
# epoch 539: loss 10.259874
# epoch 540 loss_pde:1.75521183, loss_bd:3.53476954
# epoch 540: loss 5.289981
# epoch 541 loss_pde:1.80539155, loss_bd:7.82523537
# epoch 541: loss 9.630627
# epoch 542 loss_pde:1.81998193, loss_bd:10.50938511
# epoch 542: loss 12.329367
# epoch 543 loss_pde:1.77182448, loss_bd:5.86875343
# epoch 543: loss 7.640578
# epoch 544 loss_pde:1.74483645, loss_bd:5.62534380
# epoch 544: loss 7.370180
# epoch 545 loss_pde:1.74307930, loss_bd:8.65294075
# epoch 545: loss 10.396020
# epoch 546 loss_pde:1.73251808, loss_bd:4.14344835
# epoch 546: loss 5.875967
# epoch 547 loss_pde:1.71503556, loss_bd:7.35258579
# epoch 547: loss 9.067621
# epoch 548 loss_pde:1.69147551, loss_bd:10.34414864
# epoch 548: loss 12.035625
# epoch 549 loss_pde:1.66610467, loss_bd:6.23127937
# epoch 549: loss 7.897384
# epoch 550 loss_pde:1.66522467, loss_bd:4.66596460
# epoch 550: loss 6.331189
# epoch 551 loss_pde:1.65761065, loss_bd:6.72481441
# epoch 551: loss 8.382425
# epoch 552 loss_pde:1.64166844, loss_bd:1.13031173
# epoch 552: loss 2.771980
# epoch 553 loss_pde:1.67794907, loss_bd:11.67767906
# epoch 553: loss 13.355628
# epoch 554 loss_pde:1.70847070, loss_bd:15.18675995
# epoch 554: loss 16.895231
# epoch 555 loss_pde:1.70036328, loss_bd:11.08066368
# epoch 555: loss 12.781027
# epoch 556 loss_pde:1.74773920, loss_bd:0.66832554
# epoch 556: loss 2.416065
# epoch 557 loss_pde:1.83829021, loss_bd:16.23438644
# epoch 557: loss 18.072678
# epoch 558 loss_pde:1.92339265, loss_bd:23.84562302
# epoch 558: loss 25.769016
# epoch 559 loss_pde:1.98624098, loss_bd:23.12447739
# epoch 559: loss 25.110718
# epoch 560 loss_pde:2.03921294, loss_bd:14.95163918
# epoch 560: loss 16.990852
# epoch 561 loss_pde:2.16667366, loss_bd:0.74233091
# epoch 561: loss 2.909005
# epoch 562 loss_pde:2.57867646, loss_bd:19.15906143
# epoch 562: loss 21.737738
# epoch 563 loss_pde:2.45018721, loss_bd:28.93584251
# epoch 563: loss 31.386030
# epoch 564 loss_pde:1.99289060, loss_bd:30.54933929
# epoch 564: loss 32.542229
# epoch 565 loss_pde:1.77588522, loss_bd:25.36842728
# epoch 565: loss 27.144312
# epoch 566 loss_pde:1.68967116, loss_bd:14.30010605
# epoch 566: loss 15.989778
# epoch 567 loss_pde:1.66617429, loss_bd:5.47838974
# epoch 567: loss 7.144564
# epoch 568 loss_pde:1.65509450, loss_bd:13.17977524
# epoch 568: loss 14.834869
# epoch 569 loss_pde:1.66792798, loss_bd:11.48252106
# epoch 569: loss 13.150449
# epoch 570 loss_pde:1.75846803, loss_bd:7.23382759
# epoch 570: loss 8.992295
# epoch 571 loss_pde:1.92490649, loss_bd:6.16162205
# epoch 571: loss 8.086529
# epoch 572 loss_pde:2.29919600, loss_bd:1.88091397
# epoch 572: loss 4.180110
# epoch 573 loss_pde:3.10585380, loss_bd:1.29654145
# epoch 573: loss 4.402395
# epoch 574 loss_pde:3.98798370, loss_bd:6.34140301
# epoch 574: loss 10.329387
# epoch 575 loss_pde:3.78278589, loss_bd:5.09642029
# epoch 575: loss 8.879206
# epoch 576 loss_pde:2.73075008, loss_bd:4.06520796
# epoch 576: loss 6.795958
# epoch 577 loss_pde:2.24575067, loss_bd:4.21215725
# epoch 577: loss 6.457908
# epoch 578 loss_pde:2.13987279, loss_bd:5.05922508
# epoch 578: loss 7.199098
# epoch 579 loss_pde:2.07746410, loss_bd:5.10795498
# epoch 579: loss 7.185419
# epoch 580 loss_pde:1.95397615, loss_bd:5.12280941
# epoch 580: loss 7.076786
# epoch 581 loss_pde:1.90871572, loss_bd:4.43916273
# epoch 581: loss 6.347878
# epoch 582 loss_pde:1.97975338, loss_bd:4.50553942
# epoch 582: loss 6.485293
# epoch 583 loss_pde:2.08885455, loss_bd:3.83683085
# epoch 583: loss 5.925685
# epoch 584 loss_pde:2.21204758, loss_bd:4.77115536
# epoch 584: loss 6.983203
# epoch 585 loss_pde:2.26119137, loss_bd:4.52241850
# epoch 585: loss 6.783610
# epoch 586 loss_pde:2.17888379, loss_bd:3.98054028
# epoch 586: loss 6.159424
# epoch 587 loss_pde:2.02382064, loss_bd:3.48137951
# epoch 587: loss 5.505200
# epoch 588 loss_pde:1.90089238, loss_bd:4.70866966
# epoch 588: loss 6.609562
# epoch 589 loss_pde:1.82022452, loss_bd:4.15980053
# epoch 589: loss 5.980025
# epoch 590 loss_pde:1.76349771, loss_bd:4.20258760
# epoch 590: loss 5.966085
# epoch 591 loss_pde:1.75910604, loss_bd:4.25148106
# epoch 591: loss 6.010587
# epoch 592 loss_pde:1.78079891, loss_bd:3.69903088
# epoch 592: loss 5.479830
# epoch 593 loss_pde:1.76091361, loss_bd:2.75982761
# epoch 593: loss 4.520741
# epoch 594 loss_pde:1.72324800, loss_bd:5.58124924
# epoch 594: loss 7.304497
# epoch 595 loss_pde:1.71756864, loss_bd:4.99672937
# epoch 595: loss 6.714298
# epoch 596 loss_pde:1.73677111, loss_bd:3.09299731
# epoch 596: loss 4.829768
# epoch 597 loss_pde:1.76032281, loss_bd:2.74569130
# epoch 597: loss 4.506014
# epoch 598 loss_pde:1.77399504, loss_bd:5.46353340
# epoch 598: loss 7.237528
# epoch 599 loss_pde:1.77400303, loss_bd:5.57788134
# epoch 599: loss 7.351884
# epoch 600 loss_pde:1.75784707, loss_bd:1.30350494
# epoch 600: loss 3.061352
# epoch 601 loss_pde:1.72700691, loss_bd:0.56098378
# epoch 601: loss 2.287991
# epoch 602 loss_pde:1.71430993, loss_bd:5.60554218
# epoch 602: loss 7.319852
# epoch 603 loss_pde:1.69592106, loss_bd:3.86595821
# epoch 603: loss 5.561879
# epoch 604 loss_pde:1.67022586, loss_bd:5.21841049
# epoch 604: loss 6.888637
# epoch 605 loss_pde:1.66198170, loss_bd:5.48740864
# epoch 605: loss 7.149390
# epoch 606 loss_pde:1.67518544, loss_bd:2.37347555
# epoch 606: loss 4.048661
# epoch 607 loss_pde:1.67887580, loss_bd:1.85093987
# epoch 607: loss 3.529816
# epoch 608 loss_pde:1.67725539, loss_bd:5.53459644
# epoch 608: loss 7.211852
# epoch 609 loss_pde:1.68562341, loss_bd:4.55120182
# epoch 609: loss 6.236825
# epoch 610 loss_pde:1.69375932, loss_bd:3.94299936
# epoch 610: loss 5.636759
# epoch 611 loss_pde:1.70074105, loss_bd:3.82951832
# epoch 611: loss 5.530259
# epoch 612 loss_pde:1.71075320, loss_bd:4.95211506
# epoch 612: loss 6.662868
# epoch 613 loss_pde:1.70415294, loss_bd:5.07464790
# epoch 613: loss 6.778801
# epoch 614 loss_pde:1.68671143, loss_bd:2.30373240
# epoch 614: loss 3.990444
# epoch 615 loss_pde:1.68330002, loss_bd:0.67567420
# epoch 615: loss 2.358974
# epoch 616 loss_pde:1.71642256, loss_bd:8.22676754
# epoch 616: loss 9.943190
# epoch 617 loss_pde:1.73486781, loss_bd:8.83175564
# epoch 617: loss 10.566624
# epoch 618 loss_pde:1.71918643, loss_bd:2.19915056
# epoch 618: loss 3.918337
# epoch 619 loss_pde:1.74359798, loss_bd:11.25711060
# epoch 619: loss 13.000709
# epoch 620 loss_pde:1.76854801, loss_bd:15.81416512
# epoch 620: loss 17.582714
# epoch 621 loss_pde:1.76615250, loss_bd:12.46023083
# epoch 621: loss 14.226383
# epoch 622 loss_pde:1.75661492, loss_bd:2.36520958
# epoch 622: loss 4.121824
# epoch 623 loss_pde:1.77951550, loss_bd:13.54277515
# epoch 623: loss 15.322290
# epoch 624 loss_pde:1.80430830, loss_bd:20.39170837
# epoch 624: loss 22.196016
# epoch 625 loss_pde:1.77351701, loss_bd:19.49710274
# epoch 625: loss 21.270620
# epoch 626 loss_pde:1.71150696, loss_bd:11.68601036
# epoch 626: loss 13.397517
# epoch 627 loss_pde:1.67774045, loss_bd:2.76421356
# epoch 627: loss 4.441954
# epoch 628 loss_pde:1.67377043, loss_bd:8.42502689
# epoch 628: loss 10.098797
# epoch 629 loss_pde:1.66981399, loss_bd:6.11090422
# epoch 629: loss 7.780718
# epoch 630 loss_pde:1.66371489, loss_bd:3.62621093
# epoch 630: loss 5.289926
# epoch 631 loss_pde:1.67353451, loss_bd:4.87752104
# epoch 631: loss 6.551055
# epoch 632 loss_pde:1.69302893, loss_bd:1.23542893
# epoch 632: loss 2.928458
# epoch 633 loss_pde:1.69954455, loss_bd:1.16512990
# epoch 633: loss 2.864675
# epoch 634 loss_pde:1.71349382, loss_bd:4.04650974
# epoch 634: loss 5.760004
# epoch 635 loss_pde:1.71282208, loss_bd:1.09758067
# epoch 635: loss 2.810403
# ...
# epoch 6339 loss_pde:1.02631879, loss_bd:2.74586082
# epoch 6339: loss 3.772180
# epoch 6340 loss_pde:1.04708695, loss_bd:13.15546131
# epoch 6340: loss 14.202548
# epoch 6341 loss_pde:1.05407906, loss_bd:21.19382095
# epoch 6341: loss 22.247900
# epoch 6342 loss_pde:1.05189908, loss_bd:22.39347839
# epoch 6342: loss 23.445377
# epoch 6343 loss_pde:1.06924129, loss_bd:17.47346497
# epoch 6343: loss 18.542706
# epoch 6344 loss_pde:1.15386093, loss_bd:7.15683556
# epoch 6344: loss 8.310697
# epoch 6345 loss_pde:1.30625188, loss_bd:8.25482941
# epoch 6345: loss 9.561081
# epoch 6346 loss_pde:1.25267971, loss_bd:15.78041267
# epoch 6346: loss 17.033092
# epoch 6347 loss_pde:1.17068541, loss_bd:16.72217751
# epoch 6347: loss 17.892862
# epoch 6348 loss_pde:1.14770043, loss_bd:11.95676041
# epoch 6348: loss 13.104461
# epoch 6349 loss_pde:1.14269602, loss_bd:2.08278561
# epoch 6349: loss 3.225482
# epoch 6350 loss_pde:1.14783633, loss_bd:13.16054153
# epoch 6350: loss 14.308378
# epoch 6351 loss_pde:1.14234853, loss_bd:20.63611221
# epoch 6351: loss 21.778461
# epoch 6352 loss_pde:1.11820400, loss_bd:21.23543549
# epoch 6352: loss 22.353640
# epoch 6353 loss_pde:1.08534479, loss_bd:15.69672966
# epoch 6353: loss 16.782074
# epoch 6354 loss_pde:1.06207108, loss_bd:4.85152149
# epoch 6354: loss 5.913592
# epoch 6355 loss_pde:1.07458520, loss_bd:10.73638153
# epoch 6355: loss 11.810966
# epoch 6356 loss_pde:1.11880791, loss_bd:18.82625580
# epoch 6356: loss 19.945065
# epoch 6357 loss_pde:1.14348102, loss_bd:20.39337921
# epoch 6357: loss 21.536860
# epoch 6358 loss_pde:1.13094056, loss_bd:16.10178375
# epoch 6358: loss 17.232725
# epoch 6359 loss_pde:1.10931301, loss_bd:6.51370144
# epoch 6359: loss 7.623014
# epoch 6360 loss_pde:1.10113919, loss_bd:8.21208954
# epoch 6360: loss 9.313229
# epoch 6361 loss_pde:1.09110332, loss_bd:15.33637047
# epoch 6361: loss 16.427473
# epoch 6362 loss_pde:1.07798445, loss_bd:15.86424351
# epoch 6362: loss 16.942228
# epoch 6363 loss_pde:1.06132650, loss_bd:10.50833225
# epoch 6363: loss 11.569658
# epoch 6364 loss_pde:1.04455197, loss_bd:0.51695335
# epoch 6364: loss 1.561505
# epoch 6365 loss_pde:1.04322588, loss_bd:4.26207447
# epoch 6365: loss 5.305300
# epoch 6366 loss_pde:1.05194318, loss_bd:1.89561939
# epoch 6366: loss 2.947563
# epoch 6367 loss_pde:1.06988561, loss_bd:6.05962992
# epoch 6367: loss 7.129516
# epoch 6368 loss_pde:1.08706641, loss_bd:7.32264137
# epoch 6368: loss 8.409708
# epoch 6369 loss_pde:1.09481466, loss_bd:2.69926310
# epoch 6369: loss 3.794078
# epoch 6370 loss_pde:1.08861554, loss_bd:7.38394070
# epoch 6370: loss 8.472556
# epoch 6371 loss_pde:1.06576657, loss_bd:10.55142021
# epoch 6371: loss 11.617187
# epoch 6372 loss_pde:1.03791809, loss_bd:7.77717590
# epoch 6372: loss 8.815094
# epoch 6373 loss_pde:1.02015340, loss_bd:0.58994466
# epoch 6373: loss 1.610098
# epoch 6374 loss_pde:1.00788975, loss_bd:2.81176376
# epoch 6374: loss 3.819654
# epoch 6375 loss_pde:0.99931645, loss_bd:1.35960364
# epoch 6375: loss 2.358920
# epoch 6376 loss_pde:1.00034869, loss_bd:0.80441087
# epoch 6376: loss 1.804760
# epoch 6377 loss_pde:0.99889344, loss_bd:3.56108236
# epoch 6377: loss 4.559976
# epoch 6378 loss_pde:1.00398803, loss_bd:1.61496508
# epoch 6378: loss 2.618953
# epoch 6379 loss_pde:1.01270449, loss_bd:6.04501534
# epoch 6379: loss 7.057720
# epoch 6380 loss_pde:1.01176679, loss_bd:6.99614477
# epoch 6380: loss 8.007912
# epoch 6381 loss_pde:1.00487971, loss_bd:2.03923869
# epoch 6381: loss 3.044118
# epoch 6382 loss_pde:1.00457549, loss_bd:8.26921272
# epoch 6382: loss 9.273788
# epoch 6383 loss_pde:1.00277746, loss_bd:11.69985199
# epoch 6383: loss 12.702629
# epoch 6384 loss_pde:0.99018282, loss_bd:9.12389183
# epoch 6384: loss 10.114075
# epoch 6385 loss_pde:0.98178226, loss_bd:1.11064613
# epoch 6385: loss 2.092428
# epoch 6386 loss_pde:0.99033403, loss_bd:12.08194542
# epoch 6386: loss 13.072279
# epoch 6387 loss_pde:1.00189924, loss_bd:18.01823044
# epoch 6387: loss 19.020130
# epoch 6388 loss_pde:1.00713682, loss_bd:17.37689781
# epoch 6388: loss 18.384035
# epoch 6389 loss_pde:1.01220894, loss_bd:10.86699963
# epoch 6389: loss 11.879209
# epoch 6390 loss_pde:1.02985227, loss_bd:0.85304391
# epoch 6390: loss 1.882896
# epoch 6391 loss_pde:1.04401219, loss_bd:5.48820591
# epoch 6391: loss 6.532218
# epoch 6392 loss_pde:1.03799760, loss_bd:3.96158028
# epoch 6392: loss 4.999578
# epoch 6393 loss_pde:1.01719427, loss_bd:3.26573873
# epoch 6393: loss 4.282933
# epoch 6394 loss_pde:1.00461936, loss_bd:3.93151665
# epoch 6394: loss 4.936136
# epoch 6395 loss_pde:0.99702442, loss_bd:1.36063004
# epoch 6395: loss 2.357655
# epoch 6396 loss_pde:0.99139577, loss_bd:0.27620134
# epoch 6396: loss 1.267597
# epoch 6397 loss_pde:0.99276263, loss_bd:6.57700062
# epoch 6397: loss 7.569763
# epoch 6398 loss_pde:0.99395484, loss_bd:6.83978939
# epoch 6398: loss 7.833744
# epoch 6399 loss_pde:0.99037737, loss_bd:1.38420284
# epoch 6399: loss 2.374580
# epoch 6400 loss_pde:0.98168445, loss_bd:8.92353821
# epoch 6400: loss 9.905223
# epoch 6401 loss_pde:0.97666848, loss_bd:12.31793308
# epoch 6401: loss 13.294601
# epoch 6402 loss_pde:0.97336942, loss_bd:9.75300694
# epoch 6402: loss 10.726377
# epoch 6403 loss_pde:0.97502190, loss_bd:1.95064604
# epoch 6403: loss 2.925668
# epoch 6404 loss_pde:0.99031746, loss_bd:10.77017307
# epoch 6404: loss 11.760490
# epoch 6405 loss_pde:1.00187552, loss_bd:16.12795258
# epoch 6405: loss 17.129827
# epoch 6406 loss_pde:1.00852001, loss_bd:15.04052067
# epoch 6406: loss 16.049040
# epoch 6407 loss_pde:1.01613688, loss_bd:8.20570564
# epoch 6407: loss 9.221843
# epoch 6408 loss_pde:1.03036964, loss_bd:3.77972722
# epoch 6408: loss 4.810097
# epoch 6409 loss_pde:1.02301109, loss_bd:8.67193890
# epoch 6409: loss 9.694950
# epoch 6410 loss_pde:1.00651169, loss_bd:7.41401148
# epoch 6410: loss 8.420523
# epoch 6411 loss_pde:1.00220609, loss_bd:0.64305693
# epoch 6411: loss 1.645263
# epoch 6412 loss_pde:1.01198244, loss_bd:11.43249416
# epoch 6412: loss 12.444477
# epoch 6413 loss_pde:1.01199639, loss_bd:16.36185837
# epoch 6413: loss 17.373856
# epoch 6414 loss_pde:0.99867558, loss_bd:14.84859943
# epoch 6414: loss 15.847275
# epoch 6415 loss_pde:0.98828435, loss_bd:7.62151909
# epoch 6415: loss 8.609803
# epoch 6416 loss_pde:1.00232339, loss_bd:4.69597626
# epoch 6416: loss 5.698299
# epoch 6417 loss_pde:1.02887177, loss_bd:9.90866375
# epoch 6417: loss 10.937535
# epoch 6418 loss_pde:1.03410876, loss_bd:8.93948936
# epoch 6418: loss 9.973598
# epoch 6419 loss_pde:1.02067292, loss_bd:2.39916873
# epoch 6419: loss 3.419842
# epoch 6420 loss_pde:1.01277113, loss_bd:9.37464809
# epoch 6420: loss 10.387419
# epoch 6421 loss_pde:1.01150095, loss_bd:14.11221313
# epoch 6421: loss 15.123714
# epoch 6422 loss_pde:1.00878131, loss_bd:12.51319790
# epoch 6422: loss 13.521979
# epoch 6423 loss_pde:1.00350201, loss_bd:5.23913860
# epoch 6423: loss 6.242640
# epoch 6424 loss_pde:1.00007689, loss_bd:7.12333393
# epoch 6424: loss 8.123411
# epoch 6425 loss_pde:1.00143647, loss_bd:12.40627480
# epoch 6425: loss 13.407711
# epoch 6426 loss_pde:1.00099337, loss_bd:11.52859783
# epoch 6426: loss 12.529592
# epoch 6427 loss_pde:1.00045276, loss_bd:5.11040163
# epoch 6427: loss 6.110854
# epoch 6428 loss_pde:1.00719702, loss_bd:6.49735975
# epoch 6428: loss 7.504557
# epoch 6429 loss_pde:1.01053071, loss_bd:11.11681557
# epoch 6429: loss 12.127346
# epoch 6430 loss_pde:1.00853765, loss_bd:9.45787239
# epoch 6430: loss 10.466410
# epoch 6431 loss_pde:1.00827658, loss_bd:2.50961924
# epoch 6431: loss 3.517896
# epoch 6432 loss_pde:1.00471032, loss_bd:9.51809406
# epoch 6432: loss 10.522804
# epoch 6433 loss_pde:0.99272364, loss_bd:14.25316811
# epoch 6433: loss 15.245892
# epoch 6434 loss_pde:0.97768617, loss_bd:12.92149067
# epoch 6434: loss 13.899177
# epoch 6435 loss_pde:0.97192502, loss_bd:6.11966801
# epoch 6435: loss 7.091593
# epoch 6436 loss_pde:0.98216259, loss_bd:5.95796776
# epoch 6436: loss 6.940130
# epoch 6437 loss_pde:0.99176025, loss_bd:10.91372490
# epoch 6437: loss 11.905485
# epoch 6438 loss_pde:0.99220347, loss_bd:9.48328876
# epoch 6438: loss 10.475492
# epoch 6439 loss_pde:0.98791921, loss_bd:2.36563206
# epoch 6439: loss 3.353551
# epoch 6440 loss_pde:0.99186915, loss_bd:9.80805206
# epoch 6440: loss 10.799921
# epoch 6441 loss_pde:1.00525641, loss_bd:14.96029282
# epoch 6441: loss 15.965549
# epoch 6442 loss_pde:1.00666010, loss_bd:13.99189091
# epoch 6442: loss 14.998551
# epoch 6443 loss_pde:0.99543422, loss_bd:7.49656391
# epoch 6443: loss 8.491998
# epoch 6444 loss_pde:0.99203604, loss_bd:4.17412043
# epoch 6444: loss 5.166156
# epoch 6445 loss_pde:0.99422479, loss_bd:8.88057709
# epoch 6445: loss 9.874802
# epoch 6446 loss_pde:0.99241793, loss_bd:7.31555748
# epoch 6446: loss 8.307976
# epoch 6447 loss_pde:0.98699623, loss_bd:0.61239833
# epoch 6447: loss 1.599395
# epoch 6448 loss_pde:0.99096406, loss_bd:1.61262846
# epoch 6448: loss 2.603592
# epoch 6449 loss_pde:1.00303698, loss_bd:2.66827846
# epoch 6449: loss 3.671315
# epoch 6450 loss_pde:1.01783419, loss_bd:0.67983741
# epoch 6450: loss 1.697672
# epoch 6451 loss_pde:1.02078545, loss_bd:6.74446106
# epoch 6451: loss 7.765246
# epoch 6452 loss_pde:1.00971103, loss_bd:7.42469501
# epoch 6452: loss 8.434406
# epoch 6453 loss_pde:0.99571878, loss_bd:2.39354873
# epoch 6453: loss 3.389267
# epoch 6454 loss_pde:0.99001336, loss_bd:8.01107597
# epoch 6454: loss 9.001089
# epoch 6455 loss_pde:0.98937517, loss_bd:11.51558113
# epoch 6455: loss 12.504956
# epoch 6456 loss_pde:0.98612112, loss_bd:8.81828690
# epoch 6456: loss 9.804408
# epoch 6457 loss_pde:0.98493171, loss_bd:1.11921144
# epoch 6457: loss 2.104143
# epoch 6458 loss_pde:0.98760271, loss_bd:11.90842056
# epoch 6458: loss 12.896023
# epoch 6459 loss_pde:0.98893934, loss_bd:17.39840317
# epoch 6459: loss 18.387342
# epoch 6460 loss_pde:0.98162562, loss_bd:16.76470566
# epoch 6460: loss 17.746332
# epoch 6461 loss_pde:0.97251976, loss_bd:10.61156273
# epoch 6461: loss 11.584083
# epoch 6462 loss_pde:0.97400135, loss_bd:0.76089847
# epoch 6462: loss 1.734900
# epoch 6463 loss_pde:0.97781730, loss_bd:5.19053459
# epoch 6463: loss 6.168352
# epoch 6464 loss_pde:0.97547674, loss_bd:3.38745141
# epoch 6464: loss 4.362928
# epoch 6465 loss_pde:0.96971792, loss_bd:4.12858295
# epoch 6465: loss 5.098301
# epoch 6466 loss_pde:0.97185469, loss_bd:5.05102634
# epoch 6466: loss 6.022881
# epoch 6467 loss_pde:0.97731948, loss_bd:0.41383958
# epoch 6467: loss 1.391159
# epoch 6468 loss_pde:0.99301350, loss_bd:9.43692493
# epoch 6468: loss 10.429938
# epoch 6469 loss_pde:1.00261295, loss_bd:12.20402622
# epoch 6469: loss 13.206639
# epoch 6470 loss_pde:1.00689805, loss_bd:8.85996532
# epoch 6470: loss 9.866863
# epoch 6471 loss_pde:1.01233840, loss_bd:0.45435214
# epoch 6471: loss 1.466691
# epoch 6472 loss_pde:1.01058531, loss_bd:12.90446281
# epoch 6472: loss 13.915049
# epoch 6473 loss_pde:0.99765438, loss_bd:18.81740952
# epoch 6473: loss 19.815063
# epoch 6474 loss_pde:0.97969532, loss_bd:18.59186935
# epoch 6474: loss 19.571564
# epoch 6475 loss_pde:0.96571708, loss_bd:12.84130001
# epoch 6475: loss 13.807017
# epoch 6476 loss_pde:0.96369362, loss_bd:2.01873803
# epoch 6476: loss 2.982432
# epoch 6477 loss_pde:0.98041171, loss_bd:13.88081932
# epoch 6477: loss 14.861231
# epoch 6478 loss_pde:0.99320489, loss_bd:22.11854744
# epoch 6478: loss 23.111752
# epoch 6479 loss_pde:0.99861956, loss_bd:23.53635788
# epoch 6479: loss 24.534977
# epoch 6480 loss_pde:1.01393783, loss_bd:18.85323715
# epoch 6480: loss 19.867174
# epoch 6481 loss_pde:1.07511222, loss_bd:8.80244064
# epoch 6481: loss 9.877553
# epoch 6482 loss_pde:1.19280696, loss_bd:6.33434486
# epoch 6482: loss 7.527152
# epoch 6483 loss_pde:1.06955552, loss_bd:13.45376396
# epoch 6483: loss 14.523319
# epoch 6484 loss_pde:1.01781535, loss_bd:14.28568459
# epoch 6484: loss 15.303500
# epoch 6485 loss_pde:1.04112411, loss_bd:9.68264484
# epoch 6485: loss 10.723769
# epoch 6486 loss_pde:1.06769812, loss_bd:0.58592266
# epoch 6486: loss 1.653621
# epoch 6487 loss_pde:1.07914853, loss_bd:3.76064634
# epoch 6487: loss 4.839795
# epoch 6488 loss_pde:1.07406116, loss_bd:0.81498289
# epoch 6488: loss 1.889044
# epoch 6489 loss_pde:1.06411529, loss_bd:7.96819687
# epoch 6489: loss 9.032312
# epoch 6490 loss_pde:1.05390751, loss_bd:9.76715469
# epoch 6490: loss 10.821062
# epoch 6491 loss_pde:1.05004728, loss_bd:5.77290535
# epoch 6491: loss 6.822953
# epoch 6492 loss_pde:1.06292295, loss_bd:3.81659698
# epoch 6492: loss 4.879520
# epoch 6493 loss_pde:1.09118354, loss_bd:6.40426588
# epoch 6493: loss 7.495450
# epoch 6494 loss_pde:1.11677194, loss_bd:3.00051808
# epoch 6494: loss 4.117290
# epoch 6495 loss_pde:1.12626135, loss_bd:5.95181370
# epoch 6495: loss 7.078075
# epoch 6496 loss_pde:1.10378981, loss_bd:8.07090664
# epoch 6496: loss 9.174696
# epoch 6497 loss_pde:1.07253718, loss_bd:4.31765556
# epoch 6497: loss 5.390193
# epoch 6498 loss_pde:1.05504358, loss_bd:4.91515923
# epoch 6498: loss 5.970203
# epoch 6499 loss_pde:1.04175985, loss_bd:7.36909342
# epoch 6499: loss 8.410853
# epoch 6500 loss_pde:1.01991522, loss_bd:3.77424049
# epoch 6500: loss 4.794156
# epoch 6501 loss_pde:0.99536484, loss_bd:5.49802589
# epoch 6501: loss 6.493391
# epoch 6502 loss_pde:0.98803937, loss_bd:7.88718176
# epoch 6502: loss 8.875221
# epoch 6503 loss_pde:0.98910195, loss_bd:4.38762856
# epoch 6503: loss 5.376730
# epoch 6504 loss_pde:0.99944049, loss_bd:4.59021997
# epoch 6504: loss 5.589661
# epoch 6505 loss_pde:1.00547326, loss_bd:6.80264568
# epoch 6505: loss 7.808119
# epoch 6506 loss_pde:1.00465894, loss_bd:3.01033521
# epoch 6506: loss 4.014994
# epoch 6507 loss_pde:1.00620699, loss_bd:6.27639103
# epoch 6507: loss 7.282598
# epoch 6508 loss_pde:1.00411630, loss_bd:8.77911758
# epoch 6508: loss 9.783234
# epoch 6509 loss_pde:0.98920840, loss_bd:5.38251591
# epoch 6509: loss 6.371724
# epoch 6510 loss_pde:0.97809488, loss_bd:3.50459528
# epoch 6510: loss 4.482690
# epoch 6511 loss_pde:0.97652698, loss_bd:5.67519283
# epoch 6511: loss 6.651720
# epoch 6512 loss_pde:0.97523409, loss_bd:1.83447218
# epoch 6512: loss 2.809706
# epoch 6513 loss_pde:0.97534001, loss_bd:7.47566223
# epoch 6513: loss 8.451002
# epoch 6514 loss_pde:0.97685468, loss_bd:10.02655411
# epoch 6514: loss 11.003408
# epoch 6515 loss_pde:0.97558093, loss_bd:6.67763519
# epoch 6515: loss 7.653216
# epoch 6516 loss_pde:0.97476977, loss_bd:2.15024614
# epoch 6516: loss 3.125016
# epoch 6517 loss_pde:0.97356200, loss_bd:4.26931429
# epoch 6517: loss 5.242876
# epoch 6518 loss_pde:0.97103530, loss_bd:0.41982120
# epoch 6518: loss 1.390857
# epoch 6519 loss_pde:0.97266489, loss_bd:8.85822105
# epoch 6519: loss 9.830886
# epoch 6520 loss_pde:0.96921211, loss_bd:11.41389084
# epoch 6520: loss 12.383103
# epoch 6521 loss_pde:0.95889467, loss_bd:8.07410622
# epoch 6521: loss 9.033001
# epoch 6522 loss_pde:0.95558602, loss_bd:0.75173742
# epoch 6522: loss 1.707323
# epoch 6523 loss_pde:0.95699477, loss_bd:2.86772609
# epoch 6523: loss 3.824721
# epoch 6524 loss_pde:0.95628589, loss_bd:1.14246023
# epoch 6524: loss 2.098746
# epoch 6525 loss_pde:0.95785767, loss_bd:1.23943901
# epoch 6525: loss 2.197297
# epoch 6526 loss_pde:0.95749378, loss_bd:2.61786222
# epoch 6526: loss 3.575356
# epoch 6527 loss_pde:0.95886016, loss_bd:0.31252187
# epoch 6527: loss 1.271382
# epoch 6528 loss_pde:0.96673876, loss_bd:7.09948444
# epoch 6528: loss 8.066223
# epoch 6529 loss_pde:0.97555828, loss_bd:7.83103371
# epoch 6529: loss 8.806592
# epoch 6530 loss_pde:0.98934746, loss_bd:2.89690018
# epoch 6530: loss 3.886248
# epoch 6531 loss_pde:0.99371016, loss_bd:7.12529087
# epoch 6531: loss 8.119001
# epoch 6532 loss_pde:0.97496283, loss_bd:10.12312031
# epoch 6532: loss 11.098083
# epoch 6533 loss_pde:0.95737386, loss_bd:7.18505287
# epoch 6533: loss 8.142426
# epoch 6534 loss_pde:0.95372248, loss_bd:1.38316977
# epoch 6534: loss 2.336892
# epoch 6535 loss_pde:0.95204353, loss_bd:3.72625303
# epoch 6535: loss 4.678297
# epoch 6536 loss_pde:0.94380248, loss_bd:0.43014321
# epoch 6536: loss 1.373946
# epoch 6537 loss_pde:0.94105643, loss_bd:1.87177658
# epoch 6537: loss 2.812833
# epoch 6538 loss_pde:0.93844008, loss_bd:2.44508886
# epoch 6538: loss 3.383529
# epoch 6539 loss_pde:0.94641918, loss_bd:0.49652916
# epoch 6539: loss 1.442948
# epoch 6540 loss_pde:0.96437776, loss_bd:6.66112137
# epoch 6540: loss 7.625499
# epoch 6541 loss_pde:0.98551792, loss_bd:7.13859558
# epoch 6541: loss 8.124113
# epoch 6542 loss_pde:1.00918639, loss_bd:2.12421513
# epoch 6542: loss 3.133401
# epoch 6543 loss_pde:1.00257838, loss_bd:8.26283836
# epoch 6543: loss 9.265417
# epoch 6544 loss_pde:0.97049522, loss_bd:11.40742493
# epoch 6544: loss 12.377920

# %%
# Evaluate on the whole computational domain
#for i in range(50):
#u = to_numpy(model(x_test))
#x = to_numpy(x_test)
    x = np.linspace(0.0, 3.0, 401)                                   # Partitioned spatial axis
    y = np.linspace(0.0, 2.0, 400)                                   # Partitioned spatial axis
    x_grid,y_grid = np.meshgrid(x,y)                                    # (t,x) in [0,0.2]x[a,b]
    X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
    Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
    x_test = np.hstack((X, Y))                                            # Vectorized whole domain
    x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
    u = to_numpy(model(x_test))
    #Xp,Yp = meshgrid(x,y)
    
    uxy= np.hstack((X, Y,u)) 
    
    ue = np.zeros((401,400))
    for i in range(0,401):
        for j in range(0,400):
            ue[i,j] = u[j*400+i,0]
            
    plt.figure()
    plt.contourf(x_grid[:,:],y_grid[:,:],ue,50)
    #plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
    #plt.scatter(x_int_train[:,1],)
    #plt.pcolor(x[:],u[:,1])
    #plt.pcolor(x[:],u[:,2])
    ax = plt.gca()
    ax.set_aspect(1)
    #plt.savefig("test_rasterization.png", dpi=150)
    plt.show()
 
    #    uo = ue.flatten()[:,None]
    #    uxy= np.hstack((X, Y,uo))                                            # Vectorized whole domain
# Out:
#   Input In [484]
#     x = np.linspace(0.0, 1.0, 401)                                   # Partitioned spatial axis
#     ^
# IndentationError: unexpected indent

# %%
x = np.linspace(0.0, 10.0, 400)                                   # Partitioned spatial axis
y = np.linspace(0.0, 20.0, 400)                                   # Partitioned spatial axis
x_grid,y_grid = np.meshgrid(x,y)                                    # (t,x) in [0,0.2]x[a,b]
X = x_grid.flatten()[:, None]                                         # Vectorized x_grid
Y = y_grid.flatten()[:, None]                                         # Vectorized x_grid
x_test = np.hstack((X,Y))                                            # Vectorized whole domain
x_test = torch.tensor(x_test, dtype=torch.float32).to(device)
u = to_numpy(model(x_test))
#Xp,Yp = meshgrid(x,y)


ue = np.zeros((400,400))
for j in range(0,400):
    for i in range(0,400):
        ue[i,j] = u[i*400+j,0]
uo = ue.flatten()[:,None]
uxy= np.hstack((X, Y,uo))                                            # Vectorized whole domain
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 2123

# %%
np.savetxt('Stablerho.txt', uxy)

# %%
plt.figure()
#plt.contourf(x_grid[:,:],y_grid[:,:],ue,50)
plt.pcolor(x_grid[:,:],y_grid[:,:],ue)
#plt.scatter(x_test[:,0],x_test[:,1],u[:,0],10)
#plt.pcolor(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.colorbar(x_grid[:,0,:],y_grid[:,0,:],ue)
#plt.scatter(x_int_train[:,1],)
#plt.pcolor(x[:],u[:,1])
#plt.pcolor(x[:],u[:,2])
ax = plt.gca()
ax.set_aspect(1)
plt.show()
plt.savefig("Riemann2.pdf", dpi=150)

# %%
#fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#surf = ax.plot_surface(x_grid[:,0,:], y_grid[:,0,:], ue, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)
#
## Customize the z axis.
#ax.set_zlim(0, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
## A StrMethodFormatter is used automatically
#ax.zaxis.set_major_formatter('{x:.02f}')
#
## Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)
#plt.show()

# %%
torch.save(model,'2DRiemanncase8.pt')

# %%
model

# %%
#device1 = torch.device("cpu")
#model.load_state_dict(torch.load(PATH))
#model = model.to(device1)
#torch.save(model,'2DRiemanncase8.pt')
model = torch.load('2DRiemanncase8.pt')

# %%
model
